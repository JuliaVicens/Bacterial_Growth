# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
df2.iloc[:, 3:9]
# Out:
# 0        A1      A2      A3      A4      A5      A6
# 0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
# 1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
# 2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
# 3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
# 4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
# ..      ...     ...     ...     ...     ...     ...
# 337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
# 338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
# 339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
# 340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
# 341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
# [342 rows x 6 columns]

# %%
c=-1
P_exp=np.array(df2.iloc[:, 3:9])[:c]
T_exp=np.array(df2['Time [s]'])[:c]

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max
# Out:
# (6, 230720.9)

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 100 # Number of residual point
N_d = 300 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = T_star.min(0)
ub = T_star.max(0) 

# Initial Condition
xx1 = T_star[::len(T_exp)]
uu1 = P_star[::len(T_exp)]

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu1), replace=False)
xxd = T_star[idx]
uud = P_star[idx]

T_u_train = np.concatenate((xx1,xxd)).reshape([-1,1])
p_train = np.concatenate((uu1,uud)).reshape([-1,1])

T_f_train = lb + (ub-lb)*lhs(1, N_f)

T_u_train_tf = tf.convert_to_tensor(T_u_train, dtype=tf.float32)
p_train_tf =   tf.convert_to_tensor(p_train, dtype=tf.float32)
T_f_train_tf = tf.convert_to_tensor(T_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
# Out:
# 2024-10-11 19:13:57.026391: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-10-11 19:13:57.026670: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2024-10-11 19:13:57.026945: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2024-10-11 19:13:57.027199: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2024-10-11 19:13:57.027449: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2024-10-11 19:13:57.027703: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2024-10-11 19:13:57.027950: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2024-10-11 19:13:57.028198: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2024-10-11 19:13:57.028296: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-10-11 19:13:57.028881: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    A = 2.0*(X - lb)/(ub - lb) - 1.0
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 

def train_vars_total(W, b, lambda_r, lambda_b):
    return W + b + lambda_r + lambda_b

def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r, 1]), dtype=tf.float32)
    return alpha_r, alpha_b

#@tf.function(jit_compile=True)
@tf.function()
def net_f(t, m, W_p, b_p, W_phi, b_phi):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([t])
        u=net(t, W_p, b_p)

        lnp=u[:,0:1]
        lns=u[:,1:2]
        p=tf.exp(lnp)
        s=tf.exp(lns)
        
        phi=net(tf.concat([p, s],1), W_phi, b_phi)

    p_t = tape1.gradient(p, t) 
    s_t = tape1.gradient(s, t) 
    f_p = p_t - phi
    f_s = s_t + m[0]*p
    
    return f_p, f_s


#@tf.function()
@tf.function()
def train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, p_train_tf, X_f_train_tf, lambda_r, lambda_b, m, opt):
    
    t_u = X_u_train_tf
    t_f = X_f_train_tf

    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, lambda_r, lambda_b])
        u_nn = net(t_u, W_p, b_p) 
        lnp=u_nn[:,0:1]
        lns=u_nn[:,1:2]
        p_nn=tf.exp(lnp)
        f_p, f_s = net_f(t_f, m, W_p, b_p, W_phi, b_phi)

        loss_p = tf.square(lambda_b*(p_nn - p_train_tf))
        loss_fp = tf.square(lambda_r*f_p) 
        loss_fs = tf.square(lambda_r*f_s) 
        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)
    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    # grads_m = tape.gradient(loss, m)

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    # opt.apply_gradients(zip(grads_m, m))
   
    return loss, tf.reduce_mean(loss_p), tf.reduce_mean(loss_fp), tf.reduce_mean(loss_fs)



layers = [1, 50, 50, 2]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 50, 50, 1]


W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lambda_r, lambda_b = loss_weight(N_f, N_d)
m = [tf.Variable(tf.ones([1,1])*0.391, dtype=tf.float32)]

# %%
lr = 1e-4
# Nmax = 15000
Nmax = 30000
Nmax=10**5


optimizer = tf.optimizers.Adam(learning_rate=lr)

start_time = time.time()
n=0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []

while n <= Nmax:
    loss_, loss_p, loss_fp, loss_fs = train_step(W_p, b_p, W_phi, b_phi, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, optimizer)
    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)


    if n % 10 == 0:
        print(f"Iteration is: {n}")
        print(f"Total loss is: {loss_}")

        print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p is: {loss_fp}")
        print(f"Physicial loss of s is: {loss_fs}")

    n+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Total loss is: 242215.203125
# Data loss is: 242213.578125
# Physicial loss of p is: 1.6114932298660278
# Physicial loss of s is: 0.007869183085858822
# Iteration is: 10
# Total loss is: 202278.859375
# Data loss is: 202277.84375
# Physicial loss of p is: 1.018896222114563
# Physicial loss of s is: 0.00377141241915524
# Iteration is: 20
# Total loss is: 163627.8125
# Data loss is: 163627.3125
# Physicial loss of p is: 0.5068584680557251
# Physicial loss of s is: 0.0013285827590152621
# Iteration is: 30
# Total loss is: 132285.046875
# Data loss is: 132284.859375
# Physicial loss of p is: 0.18437965214252472
# Physicial loss of s is: 0.00048816323396749794
# Iteration is: 40
# Total loss is: 109822.2890625
# Data loss is: 109822.25
# Physicial loss of p is: 0.0391305573284626
# Physicial loss of s is: 0.00044091802556067705
# Iteration is: 50
# Total loss is: 94458.65625
# Data loss is: 94458.65625
# Physicial loss of p is: 0.0010113519383594394
# Physicial loss of s is: 0.0007468626135960221
# Iteration is: 60
# Total loss is: 83916.5703125
# Data loss is: 83916.5625
# Physicial loss of p is: 0.006741969380527735
# Physicial loss of s is: 0.0011680606985464692
# Iteration is: 70
# Total loss is: 76415.21875
# Data loss is: 76415.203125
# Physicial loss of p is: 0.01951824128627777
# Physicial loss of s is: 0.001578020746819675
# Iteration is: 80
# Total loss is: 70780.78125
# Data loss is: 70780.7578125
# Physicial loss of p is: 0.025773679837584496
# Physicial loss of s is: 0.0019168432336300611
# Iteration is: 90
# Total loss is: 66309.9921875
# Data loss is: 66309.96875
# Physicial loss of p is: 0.024808116257190704
# Physicial loss of s is: 0.002164333825930953
# Iteration is: 100
# Total loss is: 62608.3515625
# Data loss is: 62608.328125
# Physicial loss of p is: 0.020033665001392365
# Physicial loss of s is: 0.002323246095329523
# Iteration is: 110
# Total loss is: 59463.171875
# Data loss is: 59463.15234375
# Physicial loss of p is: 0.014569398947060108
# Physicial loss of s is: 0.002408701693639159
# Iteration is: 120
# Total loss is: 56759.1640625
# Data loss is: 56759.1484375
# Physicial loss of p is: 0.010068478994071484
# Physicial loss of s is: 0.0024408281315118074
# Iteration is: 130
# Total loss is: 54428.92578125
# Data loss is: 54428.9140625
# Physicial loss of p is: 0.006977486424148083
# Physicial loss of s is: 0.0024388853926211596
# Iteration is: 140
# Total loss is: 52426.8359375
# Data loss is: 52426.828125
# Physicial loss of p is: 0.005107982084155083
# Physicial loss of s is: 0.002417563693597913
# Iteration is: 150
# Total loss is: 50716.71484375
# Data loss is: 50716.70703125
# Physicial loss of p is: 0.004077055957168341
# Physicial loss of s is: 0.0023862742818892
# Iteration is: 160
# Total loss is: 49266.52734375
# Data loss is: 49266.51953125
# Physicial loss of p is: 0.0035370481200516224
# Physicial loss of s is: 0.0023504365235567093
# Iteration is: 170
# Total loss is: 48046.55859375
# Data loss is: 48046.55078125
# Physicial loss of p is: 0.0032492452301084995
# Physicial loss of s is: 0.002313078148290515
# Iteration is: 180
# Total loss is: 47028.85546875
# Data loss is: 47028.84765625
# Physicial loss of p is: 0.0030769752338528633
# Physicial loss of s is: 0.0022759437561035156
# Iteration is: 190
# Total loss is: 46187.1875
# Data loss is: 46187.1796875
# Physicial loss of p is: 0.0029527617152780294
# Physicial loss of s is: 0.002240077592432499
# Iteration is: 200
# Total loss is: 45497.1953125
# Data loss is: 45497.1875
# Physicial loss of p is: 0.0028474635910242796
# Physicial loss of s is: 0.002206095727160573
# Iteration is: 210
# Total loss is: 44936.5546875
# Data loss is: 44936.546875
# Physicial loss of p is: 0.002749924547970295
# Physicial loss of s is: 0.0021743380930274725
# Iteration is: 220
# Total loss is: 44485.06640625
# Data loss is: 44485.05859375
# Physicial loss of p is: 0.002656253520399332
# Physicial loss of s is: 0.0021449283231049776
# Iteration is: 230
# Total loss is: 44124.6875
# Data loss is: 44124.6796875
# Physicial loss of p is: 0.0025650993920862675
# Physicial loss of s is: 0.0021178682800382376
# Iteration is: 240
# Total loss is: 43839.54296875
# Data loss is: 43839.53515625
# Physicial loss of p is: 0.0024759124498814344
# Physicial loss of s is: 0.0020930743776261806
# Iteration is: 250
# Total loss is: 43615.86328125
# Data loss is: 43615.85546875
# Physicial loss of p is: 0.0023884333204478025
# Physicial loss of s is: 0.0020704183261841536
# Iteration is: 260
# Total loss is: 43441.84765625
# Data loss is: 43441.83984375
# Physicial loss of p is: 0.002302528126165271
# Physicial loss of s is: 0.002049756934866309
# Iteration is: 270
# Total loss is: 43307.53515625
# Data loss is: 43307.52734375
# Physicial loss of p is: 0.0022181605454534292
# Physicial loss of s is: 0.0020309456158429384
# Iteration is: 280
# Total loss is: 43204.640625
# Data loss is: 43204.6328125
# Physicial loss of p is: 0.002135335700586438
# Physicial loss of s is: 0.002013833960518241
# Iteration is: 290
# Total loss is: 43126.3359375
# Data loss is: 43126.328125
# Physicial loss of p is: 0.002054085023701191
# Physicial loss of s is: 0.0019982780795544386
# Iteration is: 300
# Total loss is: 43067.06640625
# Data loss is: 43067.05859375
# Physicial loss of p is: 0.0019744541496038437
# Physicial loss of s is: 0.0019841440953314304
# Iteration is: 310
# Total loss is: 43022.40625
# Data loss is: 43022.40234375
# Physicial loss of p is: 0.0018964793998748064
# Physicial loss of s is: 0.0019713002257049084
# Iteration is: 320
# Total loss is: 42988.8359375
# Data loss is: 42988.83203125
# Physicial loss of p is: 0.0018202024511992931
# Physicial loss of s is: 0.0019596286583691835
# Iteration is: 330
# Total loss is: 42963.6015625
# Data loss is: 42963.6015625
# Physicial loss of p is: 0.001745658228173852
# Physicial loss of s is: 0.001949011697433889
# Iteration is: 340
# Total loss is: 42944.57421875
# Data loss is: 42944.57421875
# Physicial loss of p is: 0.0016728809569031
# Physicial loss of s is: 0.0019393437542021275
# Iteration is: 350
# Total loss is: 42930.11328125
# Data loss is: 42930.11328125
# Physicial loss of p is: 0.0016019019531086087
# Physicial loss of s is: 0.0019305275054648519
# Iteration is: 360
# Total loss is: 42918.98828125
# Data loss is: 42918.98828125
# Physicial loss of p is: 0.0015327493892982602
# Physicial loss of s is: 0.0019224700517952442
# Iteration is: 370
# Total loss is: 42910.28125
# Data loss is: 42910.28125
# Physicial loss of p is: 0.0014654488768428564
# Physicial loss of s is: 0.001915088389068842
# Iteration is: 380
# Total loss is: 42903.28515625
# Data loss is: 42903.28515625
# Physicial loss of p is: 0.001400028821080923
# Physicial loss of s is: 0.0019083059160038829
# Iteration is: 390
# Total loss is: 42897.515625
# Data loss is: 42897.515625
# Physicial loss of p is: 0.0013365090126171708
# Physicial loss of s is: 0.0019020556937903166
# Iteration is: 400
# Total loss is: 42892.6015625
# Data loss is: 42892.6015625
# Physicial loss of p is: 0.001274898531846702
# Physicial loss of s is: 0.0018962743924930692
# Iteration is: 410
# Total loss is: 42888.2734375
# Data loss is: 42888.2734375
# Physicial loss of p is: 0.0012152132112532854
# Physicial loss of s is: 0.0018909067148342729
# Iteration is: 420
# Total loss is: 42884.34375
# Data loss is: 42884.34375
# Physicial loss of p is: 0.0011574611999094486
# Physicial loss of s is: 0.0018859062111005187
# Iteration is: 430
# Total loss is: 42880.68359375
# Data loss is: 42880.68359375
# Physicial loss of p is: 0.0011016415664926171
# Physicial loss of s is: 0.0018812270136550069
# Iteration is: 440
# Total loss is: 42877.19140625
# Data loss is: 42877.19140625
# Physicial loss of p is: 0.0010477462783455849
# Physicial loss of s is: 0.0018768328009173274
# Iteration is: 450
# Total loss is: 42873.8125
# Data loss is: 42873.8125
# Physicial loss of p is: 0.0009957707952708006
# Physicial loss of s is: 0.0018726906273514032
# Iteration is: 460
# Total loss is: 42870.4921875
# Data loss is: 42870.4921875
# Physicial loss of p is: 0.0009456960833631456
# Physicial loss of s is: 0.001868768478743732
# Iteration is: 470
# Total loss is: 42867.203125
# Data loss is: 42867.203125
# Physicial loss of p is: 0.0008975028758868575
# Physicial loss of s is: 0.0018650428391993046
# Iteration is: 480
# Total loss is: 42863.92578125
# Data loss is: 42863.92578125
# Physicial loss of p is: 0.0008511696942150593
# Physicial loss of s is: 0.0018614912405610085
# Iteration is: 490
# Total loss is: 42860.65234375
# Data loss is: 42860.65234375
# Physicial loss of p is: 0.0008066699374467134
# Physicial loss of s is: 0.001858096569776535
# Iteration is: 500
# Total loss is: 42857.359375
# Data loss is: 42857.359375
# Physicial loss of p is: 0.0007639690302312374
# Physicial loss of s is: 0.0018548434600234032
# Iteration is: 510
# Total loss is: 42854.0546875
# Data loss is: 42854.0546875
# Physicial loss of p is: 0.0007230353076010942
# Physicial loss of s is: 0.0018517142161726952
# Iteration is: 520
# Total loss is: 42850.71875
# Data loss is: 42850.71875
# Physicial loss of p is: 0.0006838302360847592
# Physicial loss of s is: 0.001848702784627676
# Iteration is: 530
# Total loss is: 42847.3671875
# Data loss is: 42847.3671875
# Physicial loss of p is: 0.0006463144673034549
# Physicial loss of s is: 0.0018457946134731174
# Iteration is: 540
# Total loss is: 42843.98828125
# Data loss is: 42843.98828125
# Physicial loss of p is: 0.0006104465574026108
# Physicial loss of s is: 0.0018429792253300548
# Iteration is: 550
# Total loss is: 42840.58203125
# Data loss is: 42840.58203125
# Physicial loss of p is: 0.0005761858192272484
# Physicial loss of s is: 0.0018402572022750974
# Iteration is: 560
# Total loss is: 42837.15234375
# Data loss is: 42837.15234375
# Physicial loss of p is: 0.0005434851627796888
# Physicial loss of s is: 0.0018376174848526716
# Iteration is: 570
# Total loss is: 42833.6953125
# Data loss is: 42833.6953125
# Physicial loss of p is: 0.0005123017472214997
# Physicial loss of s is: 0.0018350542522966862
# Iteration is: 580
# Total loss is: 42830.2109375
# Data loss is: 42830.2109375
# Physicial loss of p is: 0.0004825877258554101
# Physicial loss of s is: 0.0018325643613934517
# Iteration is: 590
# Total loss is: 42826.69921875
# Data loss is: 42826.69921875
# Physicial loss of p is: 0.0004542963288258761
# Physicial loss of s is: 0.0018301430391147733
# Iteration is: 600
# Total loss is: 42823.15234375
# Data loss is: 42823.15234375
# Physicial loss of p is: 0.0004273815720807761
# Physicial loss of s is: 0.0018277871422469616
# Iteration is: 610
# Total loss is: 42819.5859375
# Data loss is: 42819.5859375
# Physicial loss of p is: 0.0004017966566607356
# Physicial loss of s is: 0.0018254942260682583
# Iteration is: 620
# Total loss is: 42815.9921875
# Data loss is: 42815.9921875
# Physicial loss of p is: 0.00037749670445919037
# Physicial loss of s is: 0.0018232634756714106
# Iteration is: 630
# Total loss is: 42812.3671875
# Data loss is: 42812.3671875
# Physicial loss of p is: 0.0003544344799593091
# Physicial loss of s is: 0.0018210936104878783
# Iteration is: 640
# Total loss is: 42808.72265625
# Data loss is: 42808.72265625
# Physicial loss of p is: 0.0003325642319396138
# Physicial loss of s is: 0.0018189795082435012
# Iteration is: 650
# Total loss is: 42805.04296875
# Data loss is: 42805.04296875
# Physicial loss of p is: 0.00031184061663225293
# Physicial loss of s is: 0.0018169218674302101
# Iteration is: 660
# Total loss is: 42801.33984375
# Data loss is: 42801.33984375
# Physicial loss of p is: 0.00029221997829154134
# Physicial loss of s is: 0.0018149182433262467
# Iteration is: 670
# Total loss is: 42797.61328125
# Data loss is: 42797.61328125
# Physicial loss of p is: 0.0002736568567343056
# Physicial loss of s is: 0.00181296665687114
# Iteration is: 680
# Total loss is: 42793.8515625
# Data loss is: 42793.8515625
# Physicial loss of p is: 0.0002561107976362109
# Physicial loss of s is: 0.00181106838863343
# Iteration is: 690
# Total loss is: 42790.06640625
# Data loss is: 42790.06640625
# Physicial loss of p is: 0.00023953698109835386
# Physicial loss of s is: 0.0018092218087986112
# Iteration is: 700
# Total loss is: 42786.26171875
# Data loss is: 42786.26171875
# Physicial loss of p is: 0.0002238977758679539
# Physicial loss of s is: 0.001807425287552178
# Iteration is: 710
# Total loss is: 42782.41796875
# Data loss is: 42782.41796875
# Physicial loss of p is: 0.00020915092318318784
# Physicial loss of s is: 0.001805678941309452
# Iteration is: 720
# Total loss is: 42778.5546875
# Data loss is: 42778.5546875
# Physicial loss of p is: 0.00019525761308614165
# Physicial loss of s is: 0.0018039816059172153
# Iteration is: 730
# Total loss is: 42774.66015625
# Data loss is: 42774.66015625
# Physicial loss of p is: 0.00018218158220406622
# Physicial loss of s is: 0.0018023342126980424
# Iteration is: 740
# Total loss is: 42770.73828125
# Data loss is: 42770.73828125
# Physicial loss of p is: 0.00016988460265565664
# Physicial loss of s is: 0.001800735597498715
# Iteration is: 750
# Total loss is: 42766.7890625
# Data loss is: 42766.7890625
# Physicial loss of p is: 0.00015833083307370543
# Physicial loss of s is: 0.0017991849454119802
# Iteration is: 760
# Total loss is: 42762.81640625
# Data loss is: 42762.81640625
# Physicial loss of p is: 0.00014748542162124068
# Physicial loss of s is: 0.0017976820236071944
# Iteration is: 770
# Total loss is: 42758.81640625
# Data loss is: 42758.81640625
# Physicial loss of p is: 0.00013731572835240513
# Physicial loss of s is: 0.0017962259007617831
# Iteration is: 780
# Total loss is: 42754.78125
# Data loss is: 42754.78125
# Physicial loss of p is: 0.00012778921518474817
# Physicial loss of s is: 0.001794816693291068
# Iteration is: 790
# Total loss is: 42750.71875
# Data loss is: 42750.71875
# Physicial loss of p is: 0.00011887467553606257
# Physicial loss of s is: 0.0017934563802555203
# Iteration is: 800
# Total loss is: 42746.6328125
# Data loss is: 42746.6328125
# Physicial loss of p is: 0.00011054096830775961
# Physicial loss of s is: 0.0017921398393809795
# Iteration is: 810
# Total loss is: 42742.515625
# Data loss is: 42742.515625
# Physicial loss of p is: 0.00010276064131176099
# Physicial loss of s is: 0.001790872192941606
# Iteration is: 820
# Total loss is: 42738.375
# Data loss is: 42738.375
# Physicial loss of p is: 9.550496906740591e-05
# Physicial loss of s is: 0.0017896514618769288
# Iteration is: 830
# Total loss is: 42734.19921875
# Data loss is: 42734.19921875
# Physicial loss of p is: 8.874669583747163e-05
# Physicial loss of s is: 0.0017884777626022696
# Iteration is: 840
# Total loss is: 42730.0
# Data loss is: 42730.0
# Physicial loss of p is: 8.246016659541056e-05
# Physicial loss of s is: 0.0017873491160571575
# Iteration is: 850
# Total loss is: 42725.765625
# Data loss is: 42725.765625
# Physicial loss of p is: 7.662036659894511e-05
# Physicial loss of s is: 0.0017862659879028797
# Iteration is: 860
# Total loss is: 42721.5078125
# Data loss is: 42721.5078125
# Physicial loss of p is: 7.120435475371778e-05
# Physicial loss of s is: 0.0017852302407845855
# Iteration is: 870
# Total loss is: 42717.21484375
# Data loss is: 42717.21484375
# Physicial loss of p is: 6.618919724132866e-05
# Physicial loss of s is: 0.00178423966281116
# Iteration is: 880
# Total loss is: 42712.89453125
# Data loss is: 42712.89453125
# Physicial loss of p is: 6.155333539936692e-05
# Physicial loss of s is: 0.0017832978628575802
# Iteration is: 890
# Total loss is: 42708.546875
# Data loss is: 42708.546875
# Physicial loss of p is: 5.7275592553196475e-05
# Physicial loss of s is: 0.00178240064997226
# Iteration is: 900
# Total loss is: 42704.16015625
# Data loss is: 42704.16015625
# Physicial loss of p is: 5.333680019248277e-05
# Physicial loss of s is: 0.0017815507017076015
# Iteration is: 910
# Total loss is: 42699.74609375
# Data loss is: 42699.74609375
# Physicial loss of p is: 4.971788439434022e-05
# Physicial loss of s is: 0.001780749880708754
# Iteration is: 920
# Total loss is: 42695.30078125
# Data loss is: 42695.30078125
# Physicial loss of p is: 4.640104089048691e-05
# Physicial loss of s is: 0.001779995858669281
# Iteration is: 930
# Total loss is: 42690.8125
# Data loss is: 42690.8125
# Physicial loss of p is: 4.3369065679144114e-05
# Physicial loss of s is: 0.0017792892176657915
# Iteration is: 940
# Total loss is: 42686.3125
# Data loss is: 42686.3125
# Physicial loss of p is: 4.060526407556608e-05
# Physicial loss of s is: 0.0017786300741136074
# Iteration is: 950
# Total loss is: 42681.765625
# Data loss is: 42681.765625
# Physicial loss of p is: 3.8095142372185364e-05
# Physicial loss of s is: 0.0017780171474441886
# Iteration is: 960
# Total loss is: 42677.1875
# Data loss is: 42677.1875
# Physicial loss of p is: 3.582347198971547e-05
# Physicial loss of s is: 0.0017774526495486498
# Iteration is: 970
# Total loss is: 42672.578125
# Data loss is: 42672.578125
# Physicial loss of p is: 3.377716348040849e-05
# Physicial loss of s is: 0.0017769411206245422
# Iteration is: 980
# Total loss is: 42667.9296875
# Data loss is: 42667.9296875
# Physicial loss of p is: 3.194245437043719e-05
# Physicial loss of s is: 0.0017764760414138436
# Iteration is: 990
# Total loss is: 42663.24609375
# Data loss is: 42663.24609375
# Physicial loss of p is: 3.0307392080430873e-05
# Physicial loss of s is: 0.0017760597402229905
# Iteration is: 1000
# Total loss is: 42658.5390625
# Data loss is: 42658.5390625
# Physicial loss of p is: 2.886022048187442e-05
# Physicial loss of s is: 0.001775696175172925
# Iteration is: 1010
# Total loss is: 42653.77734375
# Data loss is: 42653.77734375
# Physicial loss of p is: 2.759024027909618e-05
# Physicial loss of s is: 0.0017753809224814177
# Iteration is: 1020
# Total loss is: 42649.0
# Data loss is: 42649.0
# Physicial loss of p is: 2.6486632123123854e-05
# Physicial loss of s is: 0.0017751180566847324
# Iteration is: 1030
# Total loss is: 42644.16796875
# Data loss is: 42644.16796875
# Physicial loss of p is: 2.5539738999214023e-05
# Physicial loss of s is: 0.0017749053658917546
# Iteration is: 1040
# Total loss is: 42639.30859375
# Data loss is: 42639.30859375
# Physicial loss of p is: 2.474082612025086e-05
# Physicial loss of s is: 0.0017747438978403807
# Iteration is: 1050
# Total loss is: 42634.40234375
# Data loss is: 42634.40234375
# Physicial loss of p is: 2.40812441916205e-05
# Physicial loss of s is: 0.0017746356315910816
# Iteration is: 1060
# Total loss is: 42629.4609375
# Data loss is: 42629.4609375
# Physicial loss of p is: 2.3552858692710288e-05
# Physicial loss of s is: 0.001774580217897892
# Iteration is: 1070
# Total loss is: 42624.484375
# Data loss is: 42624.484375
# Physicial loss of p is: 2.314817174919881e-05
# Physicial loss of s is: 0.0017745807999745011
# Iteration is: 1080
# Total loss is: 42619.453125
# Data loss is: 42619.453125
# Physicial loss of p is: 2.2860294848214835e-05
# Physicial loss of s is: 0.0017746341181918979
# Iteration is: 1090
# Total loss is: 42614.39453125
# Data loss is: 42614.39453125
# Physicial loss of p is: 2.268280331918504e-05
# Physicial loss of s is: 0.0017747414531186223
# Iteration is: 1100
# Total loss is: 42609.28515625
# Data loss is: 42609.28515625
# Physicial loss of p is: 2.260940891574137e-05
# Physicial loss of s is: 0.0017749067628756166
# Iteration is: 1110
# Total loss is: 42604.140625
# Data loss is: 42604.140625
# Physicial loss of p is: 2.2634758352069184e-05
# Physicial loss of s is: 0.0017751272534951568
# Iteration is: 1120
# Total loss is: 42598.9453125
# Data loss is: 42598.9453125
# Physicial loss of p is: 2.2753732991986908e-05
# Physicial loss of s is: 0.001775406301021576
# Iteration is: 1130
# Total loss is: 42593.70703125
# Data loss is: 42593.70703125
# Physicial loss of p is: 2.2961008653510362e-05
# Physicial loss of s is: 0.0017757415771484375
# Iteration is: 1140
# Total loss is: 42588.42578125
# Data loss is: 42588.42578125
# Physicial loss of p is: 2.3252656319527887e-05
# Physicial loss of s is: 0.0017761357594281435
# Iteration is: 1150
# Total loss is: 42583.0859375
# Data loss is: 42583.0859375
# Physicial loss of p is: 2.3624450477655046e-05
# Physicial loss of s is: 0.0017765893135219812
# Iteration is: 1160
# Total loss is: 42577.71484375
# Data loss is: 42577.71484375
# Physicial loss of p is: 2.4072858650470152e-05
# Physicial loss of s is: 0.0017771009588614106
# Iteration is: 1170
# Total loss is: 42572.28515625
# Data loss is: 42572.28515625
# Physicial loss of p is: 2.4594181013526395e-05
# Physicial loss of s is: 0.001777677214704454
# Iteration is: 1180
# Total loss is: 42566.80078125
# Data loss is: 42566.80078125
# Physicial loss of p is: 2.518583096389193e-05
# Physicial loss of s is: 0.0017783158691599965
# Iteration is: 1190
# Total loss is: 42561.2734375
# Data loss is: 42561.2734375
# Physicial loss of p is: 2.5844639822025783e-05
# Physicial loss of s is: 0.001779015059582889
# Iteration is: 1200
# Total loss is: 42555.69140625
# Data loss is: 42555.69140625
# Physicial loss of p is: 2.65680664597312e-05
# Physicial loss of s is: 0.0017797780456021428
# Iteration is: 1210
# Total loss is: 42550.0546875
# Data loss is: 42550.0546875
# Physicial loss of p is: 2.735428097366821e-05
# Physicial loss of s is: 0.0017806062242016196
# Iteration is: 1220
# Total loss is: 42544.3671875
# Data loss is: 42544.3671875
# Physicial loss of p is: 2.8201138775330037e-05
# Physicial loss of s is: 0.001781501341611147
# Iteration is: 1230
# Total loss is: 42538.62109375
# Data loss is: 42538.62109375
# Physicial loss of p is: 2.9106808142387308e-05
# Physicial loss of s is: 0.001782459788955748
# Iteration is: 1240
# Total loss is: 42532.8203125
# Data loss is: 42532.8203125
# Physicial loss of p is: 3.00698920909781e-05
# Physicial loss of s is: 0.0017834880854934454
# Iteration is: 1250
# Total loss is: 42526.9609375
# Data loss is: 42526.9609375
# Physicial loss of p is: 3.108942837570794e-05
# Physicial loss of s is: 0.0017845839029178023
# Iteration is: 1260
# Total loss is: 42521.03515625
# Data loss is: 42521.03515625
# Physicial loss of p is: 3.216410186723806e-05
# Physicial loss of s is: 0.0017857493367046118
# Iteration is: 1270
# Total loss is: 42515.05078125
# Data loss is: 42515.05078125
# Physicial loss of p is: 3.329323953948915e-05
# Physicial loss of s is: 0.0017869856674224138
# Iteration is: 1280
# Total loss is: 42509.0078125
# Data loss is: 42509.0078125
# Physicial loss of p is: 3.447587732807733e-05
# Physicial loss of s is: 0.001788292545825243
# Iteration is: 1290
# Total loss is: 42502.88671875
# Data loss is: 42502.88671875
# Physicial loss of p is: 3.571199340512976e-05
# Physicial loss of s is: 0.0017896724166348577
# Iteration is: 1300
# Total loss is: 42496.71484375
# Data loss is: 42496.71484375
# Physicial loss of p is: 3.7001365853939205e-05
# Physicial loss of s is: 0.0017911273753270507
# Iteration is: 1310
# Total loss is: 42490.46484375
# Data loss is: 42490.46484375
# Physicial loss of p is: 3.834364179056138e-05
# Physicial loss of s is: 0.0017926538130268455
# Iteration is: 1320
# Total loss is: 42484.1484375
# Data loss is: 42484.1484375
# Physicial loss of p is: 3.973918501287699e-05
# Physicial loss of s is: 0.001794260460883379
# Iteration is: 1330
# Total loss is: 42477.765625
# Data loss is: 42477.765625
# Physicial loss of p is: 4.118807555641979e-05
# Physicial loss of s is: 0.0017959421966224909
# Iteration is: 1340
# Total loss is: 42471.3046875
# Data loss is: 42471.3046875
# Physicial loss of p is: 4.269063356332481e-05
# Physicial loss of s is: 0.0017977014649659395
# Iteration is: 1350
# Total loss is: 42464.765625
# Data loss is: 42464.765625
# Physicial loss of p is: 4.424792859936133e-05
# Physicial loss of s is: 0.0017995410598814487
# Iteration is: 1360
# Total loss is: 42458.1484375
# Data loss is: 42458.1484375
# Physicial loss of p is: 4.586017530527897e-05
# Physicial loss of s is: 0.0018014599336311221
# Iteration is: 1370
# Total loss is: 42451.4609375
# Data loss is: 42451.4609375
# Physicial loss of p is: 4.7528912546113133e-05
# Physicial loss of s is: 0.0018034613458439708
# Iteration is: 1380
# Total loss is: 42444.68359375
# Data loss is: 42444.68359375
# Physicial loss of p is: 4.925445682602003e-05
# Physicial loss of s is: 0.001805545063689351
# Iteration is: 1390
# Total loss is: 42437.82421875
# Data loss is: 42437.82421875
# Physicial loss of p is: 5.1038750825682655e-05
# Physicial loss of s is: 0.0018077102722600102
# Iteration is: 1400
# Total loss is: 42430.8828125
# Data loss is: 42430.8828125
# Physicial loss of p is: 5.288231113809161e-05
# Physicial loss of s is: 0.0018099640728905797
# Iteration is: 1410
# Total loss is: 42423.84765625
# Data loss is: 42423.84765625
# Physicial loss of p is: 5.478718230733648e-05
# Physicial loss of s is: 0.0018123030895367265
# Iteration is: 1420
# Total loss is: 42416.71875
# Data loss is: 42416.71875
# Physicial loss of p is: 5.6754892284516245e-05
# Physicial loss of s is: 0.001814727671444416
# Iteration is: 1430
# Total loss is: 42409.50390625
# Data loss is: 42409.50390625
# Physicial loss of p is: 5.878754745936021e-05
# Physicial loss of s is: 0.0018172422423958778
# Iteration is: 1440
# Total loss is: 42402.1875
# Data loss is: 42402.1875
# Physicial loss of p is: 6.088617374189198e-05
# Physicial loss of s is: 0.001819845288991928
# Iteration is: 1450
# Total loss is: 42394.78125
# Data loss is: 42394.78125
# Physicial loss of p is: 6.305393617367372e-05
# Physicial loss of s is: 0.001822538091801107
# Iteration is: 1460
# Total loss is: 42387.26171875
# Data loss is: 42387.26171875
# Physicial loss of p is: 6.529221718665212e-05
# Physicial loss of s is: 0.0018253256566822529
# Iteration is: 1470
# Total loss is: 42379.640625
# Data loss is: 42379.640625
# Physicial loss of p is: 6.760351243428886e-05
# Physicial loss of s is: 0.0018282041419297457
# Iteration is: 1480
# Total loss is: 42371.9140625
# Data loss is: 42371.9140625
# Physicial loss of p is: 6.999112520134076e-05
# Physicial loss of s is: 0.0018311754101887345
# Iteration is: 1490
# Total loss is: 42364.0703125
# Data loss is: 42364.0703125
# Physicial loss of p is: 7.245691085699946e-05
# Physicial loss of s is: 0.0018342434195801616
# Iteration is: 1500
# Total loss is: 42356.12109375
# Data loss is: 42356.12109375
# Physicial loss of p is: 7.500427454942837e-05
# Physicial loss of s is: 0.0018374043283984065
# Iteration is: 1510
# Total loss is: 42348.046875
# Data loss is: 42348.046875
# Physicial loss of p is: 7.763603935018182e-05
# Physicial loss of s is: 0.0018406641902402043
# Iteration is: 1520
# Total loss is: 42339.85546875
# Data loss is: 42339.85546875
# Physicial loss of p is: 8.035520295379683e-05
# Physicial loss of s is: 0.001844021724537015
# Iteration is: 1530
# Total loss is: 42331.53515625
# Data loss is: 42331.53515625
# Physicial loss of p is: 8.31654469948262e-05
# Physicial loss of s is: 0.0018474775133654475
# Iteration is: 1540
# Total loss is: 42323.08984375
# Data loss is: 42323.08984375
# Physicial loss of p is: 8.607057679910213e-05
# Physicial loss of s is: 0.0018510296940803528
# Iteration is: 1550
# Total loss is: 42314.51171875
# Data loss is: 42314.51171875
# Physicial loss of p is: 8.907369920052588e-05
# Physicial loss of s is: 0.001854684785939753
# Iteration is: 1560
# Total loss is: 42305.79296875
# Data loss is: 42305.79296875
# Physicial loss of p is: 9.217958722729236e-05
# Physicial loss of s is: 0.0018584387144073844
# Iteration is: 1570
# Total loss is: 42296.9375
# Data loss is: 42296.9375
# Physicial loss of p is: 9.53919516177848e-05
# Physicial loss of s is: 0.0018622932257130742
# Iteration is: 1580
# Total loss is: 42287.93359375
# Data loss is: 42287.93359375
# Physicial loss of p is: 9.87149978755042e-05
# Physicial loss of s is: 0.0018662502989172935
# Iteration is: 1590
# Total loss is: 42278.78125
# Data loss is: 42278.78125
# Physicial loss of p is: 0.00010215371003141627
# Physicial loss of s is: 0.001870308187790215
# Iteration is: 1600
# Total loss is: 42269.46875
# Data loss is: 42269.46875
# Physicial loss of p is: 0.00010571356688160449
# Physicial loss of s is: 0.0018744671251624823
# Iteration is: 1610
# Total loss is: 42260.00390625
# Data loss is: 42260.00390625
# Physicial loss of p is: 0.00010939877392956987
# Physicial loss of s is: 0.001878727343864739
# Iteration is: 1620
# Total loss is: 42250.375
# Data loss is: 42250.375
# Physicial loss of p is: 0.000113214977318421
# Physicial loss of s is: 0.001883088843896985
# Iteration is: 1630
# Total loss is: 42240.56640625
# Data loss is: 42240.56640625
# Physicial loss of p is: 0.00011716806329786777
# Physicial loss of s is: 0.0018875525565817952
# Iteration is: 1640
# Total loss is: 42230.5859375
# Data loss is: 42230.5859375
# Physicial loss of p is: 0.00012126421643188223
# Physicial loss of s is: 0.001892118714749813
# Iteration is: 1650
# Total loss is: 42220.421875
# Data loss is: 42220.421875
# Physicial loss of p is: 0.0001255095994565636
# Physicial loss of s is: 0.001896783011034131
# Iteration is: 1660
# Total loss is: 42210.078125
# Data loss is: 42210.078125
# Physicial loss of p is: 0.00012991076800972223
# Physicial loss of s is: 0.0019015478901565075
# Iteration is: 1670
# Total loss is: 42199.53515625
# Data loss is: 42199.53515625
# Physicial loss of p is: 0.00013447557284962386
# Physicial loss of s is: 0.0019064072985202074
# Iteration is: 1680
# Total loss is: 42188.7890625
# Data loss is: 42188.7890625
# Physicial loss of p is: 0.0001392097765346989
# Physicial loss of s is: 0.001911367755383253
# Iteration is: 1690
# Total loss is: 42177.83984375
# Data loss is: 42177.83984375
# Physicial loss of p is: 0.00014412225573323667
# Physicial loss of s is: 0.0019164227414876223
# Iteration is: 1700
# Total loss is: 42166.67578125
# Data loss is: 42166.67578125
# Physicial loss of p is: 0.00014922121772542596
# Physicial loss of s is: 0.001921571441926062
# Iteration is: 1710
# Total loss is: 42155.2890625
# Data loss is: 42155.2890625
# Physicial loss of p is: 0.0001545154955238104
# Physicial loss of s is: 0.0019268128089606762
# Iteration is: 1720
# Total loss is: 42143.6796875
# Data loss is: 42143.6796875
# Physicial loss of p is: 0.00016001344192773104
# Physicial loss of s is: 0.0019321419531479478
# Iteration is: 1730
# Total loss is: 42131.828125
# Data loss is: 42131.828125
# Physicial loss of p is: 0.00016572544700466096
# Physicial loss of s is: 0.0019375566625967622
# Iteration is: 1740
# Total loss is: 42119.734375
# Data loss is: 42119.734375
# Physicial loss of p is: 0.00017166120233014226
# Physicial loss of s is: 0.0019430577522143722
# Iteration is: 1750
# Total loss is: 42107.3828125
# Data loss is: 42107.3828125
# Physicial loss of p is: 0.0001778310106601566
# Physicial loss of s is: 0.001948636956512928
# Iteration is: 1760
# Total loss is: 42094.78125
# Data loss is: 42094.77734375
# Physicial loss of p is: 0.00018424679001327604
# Physicial loss of s is: 0.001954292645677924
# Iteration is: 1770
# Total loss is: 42081.90234375
# Data loss is: 42081.8984375
# Physicial loss of p is: 0.00019092028378508985
# Physicial loss of s is: 0.0019600167870521545
# Iteration is: 1780
# Total loss is: 42068.7421875
# Data loss is: 42068.73828125
# Physicial loss of p is: 0.0001978641957975924
# Physicial loss of s is: 0.001965808914974332
# Iteration is: 1790
# Total loss is: 42055.2890625
# Data loss is: 42055.28515625
# Physicial loss of p is: 0.0002050920738838613
# Physicial loss of s is: 0.0019716613460332155
# Iteration is: 1800
# Total loss is: 42041.54296875
# Data loss is: 42041.5390625
# Physicial loss of p is: 0.00021261700021568686
# Physicial loss of s is: 0.001977569656446576
# Iteration is: 1810
# Total loss is: 42027.484375
# Data loss is: 42027.48046875
# Physicial loss of p is: 0.00022045323566999286
# Physicial loss of s is: 0.0019835277926176786
# Iteration is: 1820
# Total loss is: 42013.09765625
# Data loss is: 42013.09375
# Physicial loss of p is: 0.00022861779143568128
# Physicial loss of s is: 0.001989527139812708
# Iteration is: 1830
# Total loss is: 41998.37890625
# Data loss is: 41998.375
# Physicial loss of p is: 0.00023712724214419723
# Physicial loss of s is: 0.0019955590832978487
# Iteration is: 1840
# Total loss is: 41983.31640625
# Data loss is: 41983.3125
# Physicial loss of p is: 0.00024599817697890103
# Physicial loss of s is: 0.0020016152411699295
# Iteration is: 1850
# Total loss is: 41967.8984375
# Data loss is: 41967.89453125
# Physicial loss of p is: 0.0002552493242546916
# Physicial loss of s is: 0.0020076879300177097
# Iteration is: 1860
# Total loss is: 41952.10546875
# Data loss is: 41952.1015625
# Physicial loss of p is: 0.00026490012533031404
# Physicial loss of s is: 0.0020137676037847996
# Iteration is: 1870
# Total loss is: 41935.92578125
# Data loss is: 41935.921875
# Physicial loss of p is: 0.0002749720588326454
# Physicial loss of s is: 0.0020198419224470854
# Iteration is: 1880
# Total loss is: 41919.3515625
# Data loss is: 41919.34765625
# Physicial loss of p is: 0.0002854851190932095
# Physicial loss of s is: 0.00202590087428689
# Iteration is: 1890
# Total loss is: 41902.36328125
# Data loss is: 41902.359375
# Physicial loss of p is: 0.0002964650047942996
# Physicial loss of s is: 0.002031931886449456
# Iteration is: 1900
# Total loss is: 41884.9453125
# Data loss is: 41884.94140625
# Physicial loss of p is: 0.0003079345333389938
# Physicial loss of s is: 0.002037917962297797
# Iteration is: 1910
# Total loss is: 41867.08203125
# Data loss is: 41867.078125
# Physicial loss of p is: 0.0003199199272785336
# Physicial loss of s is: 0.0020438514184206724
# Iteration is: 1920
# Total loss is: 41848.7578125
# Data loss is: 41848.75390625
# Physicial loss of p is: 0.0003324484860058874
# Physicial loss of s is: 0.002049712697044015
# Iteration is: 1930
# Total loss is: 41829.953125
# Data loss is: 41829.94921875
# Physicial loss of p is: 0.0003455509140621871
# Physicial loss of s is: 0.0020554871298372746
# Iteration is: 1940
# Total loss is: 41810.66015625
# Data loss is: 41810.65625
# Physicial loss of p is: 0.000359255907824263
# Physicial loss of s is: 0.0020611565560102463
# Iteration is: 1950
# Total loss is: 41790.84375
# Data loss is: 41790.83984375
# Physicial loss of p is: 0.00037359751877374947
# Physicial loss of s is: 0.0020667039789259434
# Iteration is: 1960
# Total loss is: 41770.49609375
# Data loss is: 41770.4921875
# Physicial loss of p is: 0.0003886108461301774
# Physicial loss of s is: 0.0020721100736409426
# Iteration is: 1970
# Total loss is: 41749.60546875
# Data loss is: 41749.6015625
# Physicial loss of p is: 0.0004043327353429049
# Physicial loss of s is: 0.002077353885397315
# Iteration is: 1980
# Total loss is: 41728.125
# Data loss is: 41728.12109375
# Physicial loss of p is: 0.00042080043931491673
# Physicial loss of s is: 0.0020824128296226263
# Iteration is: 1990
# Total loss is: 41706.0546875
# Data loss is: 41706.05078125
# Physicial loss of p is: 0.0004380578175187111
# Physicial loss of s is: 0.0020872638560831547
# Iteration is: 2000
# Total loss is: 41683.36328125
# Data loss is: 41683.359375
# Physicial loss of p is: 0.0004561478563118726
# Physicial loss of s is: 0.002091884845867753
# Iteration is: 2010
# Total loss is: 41660.03125
# Data loss is: 41660.02734375
# Physicial loss of p is: 0.0004751167434733361
# Physicial loss of s is: 0.002096251817420125
# Iteration is: 2020
# Total loss is: 41636.0390625
# Data loss is: 41636.03515625
# Physicial loss of p is: 0.0004950150032527745
# Physicial loss of s is: 0.0021003354340791702
# Iteration is: 2030
# Total loss is: 41611.34375
# Data loss is: 41611.33984375
# Physicial loss of p is: 0.0005158947315067053
# Physicial loss of s is: 0.002104110550135374
# Iteration is: 2040
# Total loss is: 41585.9296875
# Data loss is: 41585.92578125
# Physicial loss of p is: 0.0005378119531087577
# Physicial loss of s is: 0.0021075450349599123
# Iteration is: 2050
# Total loss is: 41559.78515625
# Data loss is: 41559.78125
# Physicial loss of p is: 0.0005608265637420118
# Physicial loss of s is: 0.002110609319061041
# Iteration is: 2060
# Total loss is: 41532.8515625
# Data loss is: 41532.84765625
# Physicial loss of p is: 0.0005850010202266276
# Physicial loss of s is: 0.0021132775582373142
# Iteration is: 2070
# Total loss is: 41505.125
# Data loss is: 41505.12109375
# Physicial loss of p is: 0.0006104016792960465
# Physicial loss of s is: 0.0021155113354325294
# Iteration is: 2080
# Total loss is: 41476.5625
# Data loss is: 41476.55859375
# Physicial loss of p is: 0.0006371007766574621
# Physicial loss of s is: 0.0021172775886952877
# Iteration is: 2090
# Total loss is: 41447.12890625
# Data loss is: 41447.125
# Physicial loss of p is: 0.0006651721778325737
# Physicial loss of s is: 0.002118542790412903
# Iteration is: 2100
# Total loss is: 41416.8046875
# Data loss is: 41416.80078125
# Physicial loss of p is: 0.0006946967332623899
# Physicial loss of s is: 0.002119270386174321
# Iteration is: 2110
# Total loss is: 41385.55078125
# Data loss is: 41385.546875
# Physicial loss of p is: 0.0007257599500007927
# Physicial loss of s is: 0.002119421726092696
# Iteration is: 2120
# Total loss is: 41353.33203125
# Data loss is: 41353.328125
# Physicial loss of p is: 0.0007584513514302671
# Physicial loss of s is: 0.0021189621184021235
# Iteration is: 2130
# Total loss is: 41320.10546875
# Data loss is: 41320.1015625
# Physicial loss of p is: 0.0007928667473606765
# Physicial loss of s is: 0.0021178468596190214
# Iteration is: 2140
# Total loss is: 41285.83984375
# Data loss is: 41285.8359375
# Physicial loss of p is: 0.0008291086414828897
# Physicial loss of s is: 0.0021160398609936237
# Iteration is: 2150
# Total loss is: 41250.5
# Data loss is: 41250.49609375
# Physicial loss of p is: 0.0008672835538163781
# Physicial loss of s is: 0.0021134973503649235
# Iteration is: 2160
# Total loss is: 41214.04296875
# Data loss is: 41214.0390625
# Physicial loss of p is: 0.0009075068519450724
# Physicial loss of s is: 0.0021101797465234995
# Iteration is: 2170
# Total loss is: 41176.42578125
# Data loss is: 41176.421875
# Physicial loss of p is: 0.0009498997242189944
# Physicial loss of s is: 0.0021060435101389885
# Iteration is: 2180
# Total loss is: 41137.609375
# Data loss is: 41137.60546875
# Physicial loss of p is: 0.0009945911588147283
# Physicial loss of s is: 0.0021010441705584526
# Iteration is: 2190
# Total loss is: 41097.54296875
# Data loss is: 41097.5390625
# Physicial loss of p is: 0.0010417168959975243
# Physicial loss of s is: 0.002095139352604747
# Iteration is: 2200
# Total loss is: 41056.1953125
# Data loss is: 41056.19140625
# Physicial loss of p is: 0.0010914239101111889
# Physicial loss of s is: 0.002088285284116864
# Iteration is: 2210
# Total loss is: 41013.515625
# Data loss is: 41013.51171875
# Physicial loss of p is: 0.0011438599321991205
# Physicial loss of s is: 0.0020804384257644415
# Iteration is: 2220
# Total loss is: 40969.44921875
# Data loss is: 40969.4453125
# Physicial loss of p is: 0.0011991915525868535
# Physicial loss of s is: 0.002071555471047759
# Iteration is: 2230
# Total loss is: 40923.95703125
# Data loss is: 40923.953125
# Physicial loss of p is: 0.0012575900182127953
# Physicial loss of s is: 0.0020615903194993734
# Iteration is: 2240
# Total loss is: 40876.9921875
# Data loss is: 40876.98828125
# Physicial loss of p is: 0.0013192379847168922
# Physicial loss of s is: 0.002050504321232438
# Iteration is: 2250
# Total loss is: 40828.484375
# Data loss is: 40828.48046875
# Physicial loss of p is: 0.0013843239285051823
# Physicial loss of s is: 0.0020382569637149572
# Iteration is: 2260
# Total loss is: 40778.40625
# Data loss is: 40778.40234375
# Physicial loss of p is: 0.0014530521584674716
# Physicial loss of s is: 0.0020248049404472113
# Iteration is: 2270
# Total loss is: 40726.6953125
# Data loss is: 40726.69140625
# Physicial loss of p is: 0.001525637460872531
# Physicial loss of s is: 0.002010112162679434
# Iteration is: 2280
# Total loss is: 40673.296875
# Data loss is: 40673.29296875
# Physicial loss of p is: 0.0016023057978600264
# Physicial loss of s is: 0.001994144171476364
# Iteration is: 2290
# Total loss is: 40618.16796875
# Data loss is: 40618.1640625
# Physicial loss of p is: 0.0016832971014082432
# Physicial loss of s is: 0.0019768623169511557
# Iteration is: 2300
# Total loss is: 40561.2421875
# Data loss is: 40561.23828125
# Physicial loss of p is: 0.0017688573570922017
# Physicial loss of s is: 0.0019582437817007303
# Iteration is: 2310
# Total loss is: 40502.47265625
# Data loss is: 40502.47265625
# Physicial loss of p is: 0.0018592547858133912
# Physicial loss of s is: 0.0019382559694349766
# Iteration is: 2320
# Total loss is: 40441.8046875
# Data loss is: 40441.80078125
# Physicial loss of p is: 0.0019547687843441963
# Physicial loss of s is: 0.001916881650686264
# Iteration is: 2330
# Total loss is: 40379.17578125
# Data loss is: 40379.171875
# Physicial loss of p is: 0.0020556850358843803
# Physicial loss of s is: 0.0018941001035273075
# Iteration is: 2340
# Total loss is: 40314.53125
# Data loss is: 40314.52734375
# Physicial loss of p is: 0.002162315184250474
# Physicial loss of s is: 0.0018699008505791426
# Iteration is: 2350
# Total loss is: 40247.82421875
# Data loss is: 40247.8203125
# Physicial loss of p is: 0.002274974947795272
# Physicial loss of s is: 0.0018442756263539195
# Iteration is: 2360
# Total loss is: 40178.99609375
# Data loss is: 40178.9921875
# Physicial loss of p is: 0.0023940044920891523
# Physicial loss of s is: 0.0018172265263274312
# Iteration is: 2370
# Total loss is: 40107.9921875
# Data loss is: 40107.98828125
# Physicial loss of p is: 0.00251975329592824
# Physicial loss of s is: 0.0017887629801407456
# Iteration is: 2380
# Total loss is: 40034.7578125
# Data loss is: 40034.75390625
# Physicial loss of p is: 0.0026525843422859907
# Physicial loss of s is: 0.0017588986083865166
# Iteration is: 2390
# Total loss is: 39959.2421875
# Data loss is: 39959.23828125
# Physicial loss of p is: 0.0027928866911679506
# Physicial loss of s is: 0.0017276593716815114
# Iteration is: 2400
# Total loss is: 39881.40234375
# Data loss is: 39881.3984375
# Physicial loss of p is: 0.0029410510323941708
# Physicial loss of s is: 0.00169507903046906
# Iteration is: 2410
# Total loss is: 39801.17578125
# Data loss is: 39801.171875
# Physicial loss of p is: 0.0030974922701716423
# Physicial loss of s is: 0.0016612028703093529
# Iteration is: 2420
# Total loss is: 39718.515625
# Data loss is: 39718.51171875
# Physicial loss of p is: 0.003262635786086321
# Physicial loss of s is: 0.0016260829288512468
# Iteration is: 2430
# Total loss is: 39633.390625
# Data loss is: 39633.38671875
# Physicial loss of p is: 0.0034369269851595163
# Physicial loss of s is: 0.0015897861449047923
# Iteration is: 2440
# Total loss is: 39545.7421875
# Data loss is: 39545.73828125
# Physicial loss of p is: 0.0036208205856382847
# Physicial loss of s is: 0.0015523886540904641
# Iteration is: 2450
# Total loss is: 39455.5390625
# Data loss is: 39455.53515625
# Physicial loss of p is: 0.0038147890008985996
# Physicial loss of s is: 0.001513978000730276
# Iteration is: 2460
# Total loss is: 39362.7421875
# Data loss is: 39362.73828125
# Physicial loss of p is: 0.00401931582018733
# Physicial loss of s is: 0.0014746536035090685
# Iteration is: 2470
# Total loss is: 39267.3203125
# Data loss is: 39267.31640625
# Physicial loss of p is: 0.004234905354678631
# Physicial loss of s is: 0.001434527919627726
# Iteration is: 2480
# Total loss is: 39169.2421875
# Data loss is: 39169.23828125
# Physicial loss of p is: 0.004462052136659622
# Physicial loss of s is: 0.0013937195762991905
# Iteration is: 2490
# Total loss is: 39068.4921875
# Data loss is: 39068.48828125
# Physicial loss of p is: 0.004701282363384962
# Physicial loss of s is: 0.0013523651286959648
# Iteration is: 2500
# Total loss is: 38965.03125
# Data loss is: 38965.02734375
# Physicial loss of p is: 0.004953123163431883
# Physicial loss of s is: 0.001310607884079218
# Iteration is: 2510
# Total loss is: 38858.8515625
# Data loss is: 38858.84765625
# Physicial loss of p is: 0.005218110512942076
# Physicial loss of s is: 0.001268597086891532
# Iteration is: 2520
# Total loss is: 38749.94921875
# Data loss is: 38749.9453125
# Physicial loss of p is: 0.005496789235621691
# Physicial loss of s is: 0.0012264931574463844
# Iteration is: 2530
# Total loss is: 38638.3125
# Data loss is: 38638.30859375
# Physicial loss of p is: 0.00578970555216074
# Physicial loss of s is: 0.0011844612890854478
# Iteration is: 2540
# Total loss is: 38523.94921875
# Data loss is: 38523.94140625
# Physicial loss of p is: 0.006097396835684776
# Physicial loss of s is: 0.0011426741257309914
# Iteration is: 2550
# Total loss is: 38406.859375
# Data loss is: 38406.8515625
# Physicial loss of p is: 0.00642042513936758
# Physicial loss of s is: 0.0011013048933818936
# Iteration is: 2560
# Total loss is: 38287.046875
# Data loss is: 38287.0390625
# Physicial loss of p is: 0.00675934087485075
# Physicial loss of s is: 0.0010605216957628727
# Iteration is: 2570
# Total loss is: 38164.546875
# Data loss is: 38164.5390625
# Physicial loss of p is: 0.007114680018275976
# Physicial loss of s is: 0.0010204981081187725
# Iteration is: 2580
# Total loss is: 38039.37890625
# Data loss is: 38039.37109375
# Physicial loss of p is: 0.007486981805413961
# Physicial loss of s is: 0.000981397577561438
# Iteration is: 2590
# Total loss is: 37911.5703125
# Data loss is: 37911.5625
# Physicial loss of p is: 0.007876776158809662
# Physicial loss of s is: 0.0009433759842067957
# Iteration is: 2600
# Total loss is: 37781.171875
# Data loss is: 37781.1640625
# Physicial loss of p is: 0.00828457809984684
# Physicial loss of s is: 0.0009065778576768935
# Iteration is: 2610
# Total loss is: 37648.21484375
# Data loss is: 37648.20703125
# Physicial loss of p is: 0.008710903115570545
# Physicial loss of s is: 0.0008711290429346263
# Iteration is: 2620
# Total loss is: 37512.76953125
# Data loss is: 37512.76171875
# Physicial loss of p is: 0.00915622990578413
# Physicial loss of s is: 0.0008371464791707695
# Iteration is: 2630
# Total loss is: 37374.8828125
# Data loss is: 37374.875
# Physicial loss of p is: 0.00962101761251688
# Physicial loss of s is: 0.0008047210285440087
# Iteration is: 2640
# Total loss is: 37234.625
# Data loss is: 37234.61328125
# Physicial loss of p is: 0.010105744935572147
# Physicial loss of s is: 0.0007739219581708312
# Iteration is: 2650
# Total loss is: 37092.06640625
# Data loss is: 37092.0546875
# Physicial loss of p is: 0.010610832832753658
# Physicial loss of s is: 0.0007447969983331859
# Iteration is: 2660
# Total loss is: 36947.28125
# Data loss is: 36947.26953125
# Physicial loss of p is: 0.011136677116155624
# Physicial loss of s is: 0.0007173661724664271
# Iteration is: 2670
# Total loss is: 36800.36328125
# Data loss is: 36800.3515625
# Physicial loss of p is: 0.011683671735227108
# Physicial loss of s is: 0.0006916266866028309
# Iteration is: 2680
# Total loss is: 36651.40625
# Data loss is: 36651.39453125
# Physicial loss of p is: 0.012252149172127247
# Physicial loss of s is: 0.0006675496697425842
# Iteration is: 2690
# Total loss is: 36500.48828125
# Data loss is: 36500.4765625
# Physicial loss of p is: 0.012842457741498947
# Physicial loss of s is: 0.0006450820947065949
# Iteration is: 2700
# Total loss is: 36347.73046875
# Data loss is: 36347.71875
# Physicial loss of p is: 0.01345489639788866
# Physicial loss of s is: 0.0006241524824872613
# Iteration is: 2710
# Total loss is: 36193.22265625
# Data loss is: 36193.20703125
# Physicial loss of p is: 0.01408973429352045
# Physicial loss of s is: 0.0006046716589480639
# Iteration is: 2720
# Total loss is: 36037.078125
# Data loss is: 36037.0625
# Physicial loss of p is: 0.014747239649295807
# Physicial loss of s is: 0.0005865358398295939
# Iteration is: 2730
# Total loss is: 35879.40625
# Data loss is: 35879.390625
# Physicial loss of p is: 0.015427624806761742
# Physicial loss of s is: 0.0005696312291547656
# Iteration is: 2740
# Total loss is: 35720.328125
# Data loss is: 35720.3125
# Physicial loss of p is: 0.01613112911581993
# Physicial loss of s is: 0.0005538444384001195
# Iteration is: 2750
# Total loss is: 35559.94921875
# Data loss is: 35559.93359375
# Physicial loss of p is: 0.016857914626598358
# Physicial loss of s is: 0.0005390549194999039
# Iteration is: 2760
# Total loss is: 35398.3984375
# Data loss is: 35398.37890625
# Physicial loss of p is: 0.01760818250477314
# Physicial loss of s is: 0.0005251533002592623
# Iteration is: 2770
# Total loss is: 35235.79296875
# Data loss is: 35235.7734375
# Physicial loss of p is: 0.018382109701633453
# Physicial loss of s is: 0.000512034457642585
# Iteration is: 2780
# Total loss is: 35072.25
# Data loss is: 35072.23046875
# Physicial loss of p is: 0.019179852679371834
# Physicial loss of s is: 0.0004996092175133526
# Iteration is: 2790
# Total loss is: 34907.87890625
# Data loss is: 34907.859375
# Physicial loss of p is: 0.020001601427793503
# Physicial loss of s is: 0.0004877960600424558
# Iteration is: 2800
# Total loss is: 34742.8125
# Data loss is: 34742.79296875
# Physicial loss of p is: 0.020847540348768234
# Physicial loss of s is: 0.0004765324993059039
# Iteration is: 2810
# Total loss is: 34577.16015625
# Data loss is: 34577.13671875
# Physicial loss of p is: 0.021717838943004608
# Physicial loss of s is: 0.0004657692334149033
# Iteration is: 2820
# Total loss is: 34411.03515625
# Data loss is: 34411.01171875
# Physicial loss of p is: 0.022612743079662323
# Physicial loss of s is: 0.00045546580804511905
# Iteration is: 2830
# Total loss is: 34244.55078125
# Data loss is: 34244.52734375
# Physicial loss of p is: 0.023532476276159286
# Physicial loss of s is: 0.00044559859088622034
# Iteration is: 2840
# Total loss is: 34077.80859375
# Data loss is: 34077.78515625
# Physicial loss of p is: 0.02447732537984848
# Physicial loss of s is: 0.0004361482569947839
# Iteration is: 2850
# Total loss is: 33910.9140625
# Data loss is: 33910.88671875
# Physicial loss of p is: 0.025447579100728035
# Physicial loss of s is: 0.0004271036304999143
# Iteration is: 2860
# Total loss is: 33743.96875
# Data loss is: 33743.94140625
# Physicial loss of p is: 0.02644362486898899
# Physicial loss of s is: 0.0004184550780337304
# Iteration is: 2870
# Total loss is: 33577.05078125
# ...
# Physicial loss of s is: 0.0001561358367325738
# Iteration is: 99120
# Total loss is: 149.81924438476562
# Data loss is: 149.81903076171875
# Physicial loss of p is: 5.4405551054514945e-05
# Physicial loss of s is: 0.00015612124116159976
# Iteration is: 99130
# Total loss is: 149.8187255859375
# Data loss is: 149.81851196289062
# Physicial loss of p is: 5.441262328531593e-05
# Physicial loss of s is: 0.00015610703849233687
# Iteration is: 99140
# Total loss is: 149.81919860839844
# Data loss is: 149.81898498535156
# Physicial loss of p is: 5.4397532949224114e-05
# Physicial loss of s is: 0.00015609359252266586
# Iteration is: 99150
# Total loss is: 149.81887817382812
# Data loss is: 149.81866455078125
# Physicial loss of p is: 5.4395291954278946e-05
# Physicial loss of s is: 0.00015607867680955678
# Iteration is: 99160
# Total loss is: 149.81919860839844
# Data loss is: 149.81898498535156
# Physicial loss of p is: 5.439631058834493e-05
# Physicial loss of s is: 0.00015606566739734262
# Iteration is: 99170
# Total loss is: 149.8194122314453
# Data loss is: 149.81919860839844
# Physicial loss of p is: 5.43957285117358e-05
# Physicial loss of s is: 0.0001560516539029777
# Iteration is: 99180
# Total loss is: 149.81927490234375
# Data loss is: 149.81906127929688
# Physicial loss of p is: 5.4402797104557976e-05
# Physicial loss of s is: 0.00015603756764903665
# Iteration is: 99190
# Total loss is: 149.8189697265625
# Data loss is: 149.81875610351562
# Physicial loss of p is: 5.438091102405451e-05
# Physicial loss of s is: 0.0001560254895593971
# Iteration is: 99200
# Total loss is: 149.81875610351562
# Data loss is: 149.81854248046875
# Physicial loss of p is: 5.43774149264209e-05
# Physicial loss of s is: 0.0001560109667479992
# Iteration is: 99210
# Total loss is: 149.81951904296875
# Data loss is: 149.81930541992188
# Physicial loss of p is: 5.439916276372969e-05
# Physicial loss of s is: 0.00015599787002429366
# Iteration is: 99220
# Total loss is: 149.8188018798828
# Data loss is: 149.81858825683594
# Physicial loss of p is: 5.438211519503966e-05
# Physicial loss of s is: 0.00015598427853547037
# Iteration is: 99230
# Total loss is: 149.81927490234375
# Data loss is: 149.81906127929688
# Physicial loss of p is: 5.438126754597761e-05
# Physicial loss of s is: 0.00015597055607941002
# Iteration is: 99240
# Total loss is: 149.81906127929688
# Data loss is: 149.81884765625
# Physicial loss of p is: 5.436950959847309e-05
# Physicial loss of s is: 0.00015595815784763545
# Iteration is: 99250
# Total loss is: 149.8190155029297
# Data loss is: 149.8188018798828
# Physicial loss of p is: 5.43760324944742e-05
# Physicial loss of s is: 0.00015594475553371012
# Iteration is: 99260
# Total loss is: 149.8190155029297
# Data loss is: 149.8188018798828
# Physicial loss of p is: 5.435963612399064e-05
# Physicial loss of s is: 0.000155931047629565
# Iteration is: 99270
# Total loss is: 149.8192596435547
# Data loss is: 149.8190460205078
# Physicial loss of p is: 5.437074287328869e-05
# Physicial loss of s is: 0.0001559179654577747
# Iteration is: 99280
# Total loss is: 149.8189697265625
# Data loss is: 149.81875610351562
# Physicial loss of p is: 5.435637285700068e-05
# Physicial loss of s is: 0.000155904985149391
# Iteration is: 99290
# Total loss is: 149.81866455078125
# Data loss is: 149.81845092773438
# Physicial loss of p is: 5.435691855382174e-05
# Physicial loss of s is: 0.00015589114627800882
# Iteration is: 99300
# Total loss is: 149.8190460205078
# Data loss is: 149.81883239746094
# Physicial loss of p is: 5.434946797322482e-05
# Physicial loss of s is: 0.00015587809321004897
# Iteration is: 99310
# Total loss is: 149.81881713867188
# Data loss is: 149.818603515625
# Physicial loss of p is: 5.434634294942953e-05
# Physicial loss of s is: 0.0001558646181365475
# Iteration is: 99320
# Total loss is: 149.81871032714844
# Data loss is: 149.81849670410156
# Physicial loss of p is: 5.434397462522611e-05
# Physicial loss of s is: 0.00015585162327624857
# Iteration is: 99330
# Total loss is: 149.8186492919922
# Data loss is: 149.8184356689453
# Physicial loss of p is: 5.433901969809085e-05
# Physicial loss of s is: 0.00015583803178742528
# Iteration is: 99340
# Total loss is: 149.81886291503906
# Data loss is: 149.8186492919922
# Physicial loss of p is: 5.43350433872547e-05
# Physicial loss of s is: 0.00015582477499265224
# Iteration is: 99350
# Total loss is: 149.81849670410156
# Data loss is: 149.8182830810547
# Physicial loss of p is: 5.433191836345941e-05
# Physicial loss of s is: 0.00015581083425786346
# Iteration is: 99360
# Total loss is: 149.81906127929688
# Data loss is: 149.81884765625
# Physicial loss of p is: 5.433143087429926e-05
# Physicial loss of s is: 0.0001557972136652097
# Iteration is: 99370
# Total loss is: 149.81881713867188
# Data loss is: 149.818603515625
# Physicial loss of p is: 5.432454781839624e-05
# Physicial loss of s is: 0.00015578369493596256
# Iteration is: 99380
# Total loss is: 149.8192901611328
# Data loss is: 149.81907653808594
# Physicial loss of p is: 5.432777470559813e-05
# Physicial loss of s is: 0.00015576973964925855
# Iteration is: 99390
# Total loss is: 149.8187255859375
# Data loss is: 149.81851196289062
# Physicial loss of p is: 5.431825411505997e-05
# Physicial loss of s is: 0.00015575572615489364
# Iteration is: 99400
# Total loss is: 149.81886291503906
# Data loss is: 149.8186492919922
# Physicial loss of p is: 5.4320025810739025e-05
# Physicial loss of s is: 0.00015574286226183176
# Iteration is: 99410
# Total loss is: 149.81887817382812
# Data loss is: 149.81866455078125
# Physicial loss of p is: 5.431712634162977e-05
# Physicial loss of s is: 0.00015572873235214502
# Iteration is: 99420
# Total loss is: 149.81893920898438
# Data loss is: 149.8187255859375
# Physicial loss of p is: 5.4316111345542595e-05
# Physicial loss of s is: 0.00015571447147522122
# Iteration is: 99430
# Total loss is: 149.81932067871094
# Data loss is: 149.81910705566406
# Physicial loss of p is: 5.430587407317944e-05
# Physicial loss of s is: 0.00015570074901916087
# Iteration is: 99440
# Total loss is: 149.81846618652344
# Data loss is: 149.81825256347656
# Physicial loss of p is: 5.4306103265844285e-05
# Physicial loss of s is: 0.00015568644448649138
# Iteration is: 99450
# Total loss is: 149.81871032714844
# Data loss is: 149.81849670410156
# Physicial loss of p is: 5.4303891374729574e-05
# Physicial loss of s is: 0.00015567298396490514
# Iteration is: 99460
# Total loss is: 149.81906127929688
# Data loss is: 149.81884765625
# Physicial loss of p is: 5.430150849861093e-05
# Physicial loss of s is: 0.00015565831563435495
# Iteration is: 99470
# Total loss is: 149.81893920898438
# Data loss is: 149.8187255859375
# Physicial loss of p is: 5.431022509583272e-05
# Physicial loss of s is: 0.0001556451024953276
# Iteration is: 99480
# Total loss is: 149.8186492919922
# Data loss is: 149.8184356689453
# Physicial loss of p is: 5.430337478173897e-05
# Physicial loss of s is: 0.00015563103079330176
# Iteration is: 99490
# Total loss is: 149.8189697265625
# Data loss is: 149.81875610351562
# Physicial loss of p is: 5.4291482229018584e-05
# Physicial loss of s is: 0.00015561682812403888
# Iteration is: 99500
# Total loss is: 149.81887817382812
# Data loss is: 149.81866455078125
# Physicial loss of p is: 5.4286978411255404e-05
# Physicial loss of s is: 0.00015560246538370848
# Iteration is: 99510
# Total loss is: 149.81857299804688
# Data loss is: 149.818359375
# Physicial loss of p is: 5.428312215371989e-05
# Physicial loss of s is: 0.00015558818995486945
# Iteration is: 99520
# Total loss is: 149.8184356689453
# Data loss is: 149.81822204589844
# Physicial loss of p is: 5.428160511655733e-05
# Physicial loss of s is: 0.0001555734925204888
# Iteration is: 99530
# Total loss is: 149.81935119628906
# Data loss is: 149.8191375732422
# Physicial loss of p is: 5.427813084679656e-05
# Physicial loss of s is: 0.00015555962454527617
# Iteration is: 99540
# Total loss is: 149.8187255859375
# Data loss is: 149.81851196289062
# Physicial loss of p is: 5.4288968385662884e-05
# Physicial loss of s is: 0.00015554524725303054
# Iteration is: 99550
# Total loss is: 149.8184814453125
# Data loss is: 149.81826782226562
# Physicial loss of p is: 5.4278447350952774e-05
# Physicial loss of s is: 0.00015552948752883822
# Iteration is: 99560
# Total loss is: 149.81912231445312
# Data loss is: 149.81890869140625
# Physicial loss of p is: 5.4269301472231746e-05
# Physicial loss of s is: 0.00015551592514384538
# Iteration is: 99570
# Total loss is: 149.8186798095703
# Data loss is: 149.81846618652344
# Physicial loss of p is: 5.4275933507597074e-05
# Physicial loss of s is: 0.00015550106763839722
# Iteration is: 99580
# Total loss is: 149.81863403320312
# Data loss is: 149.81842041015625
# Physicial loss of p is: 5.425881681730971e-05
# Physicial loss of s is: 0.0001554866903461516
# Iteration is: 99590
# Total loss is: 149.81895446777344
# Data loss is: 149.81874084472656
# Physicial loss of p is: 5.426788266049698e-05
# Physicial loss of s is: 0.00015547225484624505
# Iteration is: 99600
# Total loss is: 149.8182373046875
# Data loss is: 149.81802368164062
# Physicial loss of p is: 5.426760617410764e-05
# Physicial loss of s is: 0.0001554574555484578
# Iteration is: 99610
# Total loss is: 149.8184356689453
# Data loss is: 149.81822204589844
# Physicial loss of p is: 5.4251253459369764e-05
# Physicial loss of s is: 0.00015544156485702842
# Iteration is: 99620
# Total loss is: 149.8190155029297
# Data loss is: 149.8188018798828
# Physicial loss of p is: 5.425299605121836e-05
# Physicial loss of s is: 0.00015542763867415488
# Iteration is: 99630
# Total loss is: 149.8179473876953
# Data loss is: 149.81773376464844
# Physicial loss of p is: 5.4245509090833366e-05
# Physicial loss of s is: 0.0001554111804580316
# Iteration is: 99640
# Total loss is: 149.81857299804688
# Data loss is: 149.818359375
# Physicial loss of p is: 5.42403467989061e-05
# Physicial loss of s is: 0.0001553970214445144
# Iteration is: 99650
# Total loss is: 149.81845092773438
# Data loss is: 149.8182373046875
# Physicial loss of p is: 5.423449329100549e-05
# Physicial loss of s is: 0.0001553812180645764
# Iteration is: 99660
# Total loss is: 149.81809997558594
# Data loss is: 149.81788635253906
# Physicial loss of p is: 5.423390393843874e-05
# Physicial loss of s is: 0.00015536678256466985
# Iteration is: 99670
# Total loss is: 149.81834411621094
# Data loss is: 149.81813049316406
# Physicial loss of p is: 5.4233689297689125e-05
# Physicial loss of s is: 0.00015535160491708666
# Iteration is: 99680
# Total loss is: 149.8184356689453
# Data loss is: 149.81822204589844
# Physicial loss of p is: 5.4235315474215895e-05
# Physicial loss of s is: 0.00015533651458099484
# Iteration is: 99690
# Total loss is: 149.81846618652344
# Data loss is: 149.81825256347656
# Physicial loss of p is: 5.423479888122529e-05
# Physicial loss of s is: 0.000155321613419801
# Iteration is: 99700
# Total loss is: 149.81857299804688
# Data loss is: 149.818359375
# Physicial loss of p is: 5.421688183560036e-05
# Physicial loss of s is: 0.00015530482050962746
# Iteration is: 99710
# Total loss is: 149.81878662109375
# Data loss is: 149.81857299804688
# Physicial loss of p is: 5.422275353339501e-05
# Physicial loss of s is: 0.0001552893954794854
# Iteration is: 99720
# Total loss is: 149.81884765625
# Data loss is: 149.81863403320312
# Physicial loss of p is: 5.422216054284945e-05
# Physicial loss of s is: 0.00015527501818723977
# Iteration is: 99730
# Total loss is: 149.8184356689453
# Data loss is: 149.81822204589844
# Physicial loss of p is: 5.4217365686781704e-05
# Physicial loss of s is: 0.00015525963681284338
# Iteration is: 99740
# Total loss is: 149.818359375
# Data loss is: 149.81814575195312
# Physicial loss of p is: 5.420468733063899e-05
# Physicial loss of s is: 0.0001552443136461079
# Iteration is: 99750
# Total loss is: 149.81861877441406
# Data loss is: 149.8184051513672
# Physicial loss of p is: 5.420469824457541e-05
# Physicial loss of s is: 0.00015522848116233945
# Iteration is: 99760
# Total loss is: 149.81829833984375
# Data loss is: 149.81808471679688
# Physicial loss of p is: 5.4209795052884147e-05
# Physicial loss of s is: 0.00015521302702836692
# Iteration is: 99770
# Total loss is: 149.8182830810547
# Data loss is: 149.8180694580078
# Physicial loss of p is: 5.420831803348847e-05
# Physicial loss of s is: 0.00015520243323408067
# Iteration is: 99780
# Total loss is: 149.89675903320312
# Data loss is: 149.89651489257812
# Physicial loss of p is: 8.499860996380448e-05
# Physicial loss of s is: 0.00015543465269729495
# Iteration is: 99790
# Total loss is: 150.0188751220703
# Data loss is: 150.01861572265625
# Physicial loss of p is: 0.00010828187805600464
# Physicial loss of s is: 0.00015531026292592287
# Iteration is: 99800
# Total loss is: 152.45758056640625
# Data loss is: 152.4563446044922
# Physicial loss of p is: 0.0010772605892270803
# Physicial loss of s is: 0.00015494131366722286
# Iteration is: 99810
# Total loss is: 150.5355987548828
# Data loss is: 150.5351104736328
# Physicial loss of p is: 0.000330803421093151
# Physicial loss of s is: 0.00015616329619660974
# Iteration is: 99820
# Total loss is: 149.927978515625
# Data loss is: 149.927734375
# Physicial loss of p is: 9.57081574597396e-05
# Physicial loss of s is: 0.00015531425015069544
# Iteration is: 99830
# Total loss is: 149.82534790039062
# Data loss is: 149.82513427734375
# Physicial loss of p is: 5.618633076664992e-05
# Physicial loss of s is: 0.00015548730152659118
# Iteration is: 99840
# Total loss is: 149.81993103027344
# Data loss is: 149.81971740722656
# Physicial loss of p is: 5.4885746067157015e-05
# Physicial loss of s is: 0.0001553657348267734
# Iteration is: 99850
# Total loss is: 149.82177734375
# Data loss is: 149.82156372070312
# Physicial loss of p is: 5.541763312066905e-05
# Physicial loss of s is: 0.00015523159527219832
# Iteration is: 99860
# Total loss is: 149.81971740722656
# Data loss is: 149.8195037841797
# Physicial loss of p is: 5.486651207320392e-05
# Physicial loss of s is: 0.00015526573406532407
# Iteration is: 99870
# Total loss is: 149.81919860839844
# Data loss is: 149.81898498535156
# Physicial loss of p is: 5.449745003716089e-05
# Physicial loss of s is: 0.00015518117288593203
# Iteration is: 99880
# Total loss is: 149.8186798095703
# Data loss is: 149.81846618652344
# Physicial loss of p is: 5.43122660019435e-05
# Physicial loss of s is: 0.00015516637358814478
# Iteration is: 99890
# Total loss is: 149.8186492919922
# Data loss is: 149.8184356689453
# Physicial loss of p is: 5.426057759905234e-05
# Physicial loss of s is: 0.00015512896061409265
# Iteration is: 99900
# Total loss is: 149.8179931640625
# Data loss is: 149.81777954101562
# Physicial loss of p is: 5.42270572623238e-05
# Physicial loss of s is: 0.00015510483353864402
# Iteration is: 99910
# Total loss is: 149.8184051513672
# Data loss is: 149.8181915283203
# Physicial loss of p is: 5.4223630286287516e-05
# Physicial loss of s is: 0.00015508402429986745
# Iteration is: 99920
# Total loss is: 149.8181915283203
# Data loss is: 149.81797790527344
# Physicial loss of p is: 5.4223917686613277e-05
# Physicial loss of s is: 0.00015506026102229953
# Iteration is: 99930
# Total loss is: 149.81834411621094
# Data loss is: 149.81813049316406
# Physicial loss of p is: 5.421238165581599e-05
# Physicial loss of s is: 0.00015504448674619198
# Iteration is: 99940
# Total loss is: 149.81838989257812
# Data loss is: 149.81817626953125
# Physicial loss of p is: 5.421183232101612e-05
# Physicial loss of s is: 0.0001550233137095347
# Iteration is: 99950
# Total loss is: 149.81826782226562
# Data loss is: 149.81805419921875
# Physicial loss of p is: 5.420784145826474e-05
# Physicial loss of s is: 0.00015500692825298756
# Iteration is: 99960
# Total loss is: 149.81838989257812
# Data loss is: 149.81817626953125
# Physicial loss of p is: 5.4197036661207676e-05
# Physicial loss of s is: 0.00015498978609684855
# Iteration is: 99970
# Total loss is: 149.8178253173828
# Data loss is: 149.81761169433594
# Physicial loss of p is: 5.418982254923321e-05
# Physicial loss of s is: 0.00015497501590289176
# Iteration is: 99980
# Total loss is: 149.8179168701172
# Data loss is: 149.8177032470703
# Physicial loss of p is: 5.418504952103831e-05
# Physicial loss of s is: 0.00015495921252295375
# Iteration is: 99990
# Total loss is: 149.8180389404297
# Data loss is: 149.8178253173828
# Physicial loss of p is: 5.4193260439205915e-05
# Physicial loss of s is: 0.0001549441076349467
# Iteration is: 100000
# Total loss is: 149.8181915283203
# Data loss is: 149.81797790527344
# Physicial loss of p is: 5.417766806203872e-05
# Physicial loss of s is: 0.0001549303124193102
# Training time: 228.9236

# %%
it = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(it, np.asarray(loss_data_list), 'b-', linewidth = 2, label = 'Data')  
plt.semilogy(it, np.asarray(loss_phip_list), 'r-', linewidth = 2, label = '$\phi_p$')    
plt.semilogy(it, np.asarray(loss_phis_list), 'g-', linewidth = 2, label = '$\phi_s$')       


plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
m
# Out:
# [<tf.Variable 'Variable:0' shape=(1, 1) dtype=float32, numpy=array([[0.391]], dtype=float32)>]

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
T_star_tf = tf.convert_to_tensor(T_star[:len(T_exp)], dtype=tf.float32)    
u_pred = predict(T_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp=u_pred[:,0:1]
lns=u_pred[:,1:2]
p=tf.exp(lnp)
s=tf.exp(lns)
phi_pred = predict(tf.concat([p, s],1), W_phi, b_phi)
phi_s=np.array(p*m[0])

# %%
plt.plot(T_star_tf, p, label='Prediction P')
plt.plot(T_star_tf, s, label='Prediction S')

# for i in range(N_exp):
#     plt.plot(T_star[i*len(T_exp):(i+1)*len(T_exp)],P_star[i*len(T_exp):(i+1)*len(T_exp)],linestyle=':')

plt.scatter(T_u_train, p_train, marker='x', color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(p, s)
plt.xlabel('P')
plt.ylabel('S')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(p, phi_pred, label='Prediction')
# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(s, phi_pred, label='Prediction')
# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(s, phi_s, label='Prediction')
# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_s(P)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
Nt=10000
T_int=np.zeros(Nt)
P_int=np.zeros(Nt)
S_int=np.zeros(Nt)

dt=0.0001

T_int[0]=0
# P_int[0]=np.mean(uu1) #Initial conditions
P_int[0]=np.array(p[0]) #Initial conditions
S_int[0]=np.array(s[0]) #Initial conditions


for i in range(1,Nt):

    PS_p=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    P_int[i]=P_int[i-1]+predict(PS_p , W_phi, b_phi)*dt
    # P_int[i]=max(P_int[i],0)
    S_int[i]=S_int[i-1]-P_int[i-1]*np.array(m[0])*dt
    # P_int[i]=max(S_int[i],0)
    T_int[i]=T_int[i-1]+dt

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')


plt.plot(T_star_tf, p, label='PINN Prediction P')
plt.plot(T_star_tf, s, label='PINN Prediction S')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
# Create and train the PySR model
model_phi = PySRRegressor(
    niterations=500,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    # unary_operators=["inv(x) = 1/x"],
    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    # constraints={"/": (-1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00001,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
)

# %%
# Fit phi
model_phi.fit(tf.concat([p, s],1), phi_pred)
print(model_phi)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.330e+05
# Head worker occupation: 29.9%
# Progress: 545 / 7500 total iterations (7.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (-4.7893 * x₀) + (x₁ * 11.093)
# 9           2.447e+00  5.368e-02  y = ((-98.555 + (x₁ * 151.99)) * x₁) + 14.641
# 11          6.685e-01  6.488e-01  y = ((38.873 * x₁) + ((x₀ + -0.36154) * -31.833)) * x₀
# 13          6.304e-01  2.937e-02  y = ((((x₀ + -0.41423) * -33.14) + (38.604 * x₁)) * x₀) + -0.8...
#                                   1758
# 15          6.136e-01  1.347e-02  y = (x₀ * (((x₀ + -0.44546) * -36.131) + ((39.684 * x₁) + x₁))...
#                                   ) + -1.4102
# 17          6.025e-01  9.119e-03  y = (x₀ + (((33.445 + (-74.468 * x₀)) + (79.042 * x₁)) * (x₁ *...
#                                    x₀))) + -1.4823
# 19          6.004e-01  1.745e-03  y = (-0.63338 + ((x₁ * x₀) * ((x₁ * 79.478) + ((x₀ * -73.378) ...
#                                   + 34.248)))) + (x₁ * -1.6439)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.450e+05
# Head worker occupation: 28.2%
# Progress: 1216 / 7500 total iterations (16.213%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.7702 * x₀)
# 9           2.254e+00  9.481e-02  y = (x₁ * (-97.635 + (x₁ * 152.67))) + 14.632
# 11          6.684e-01  6.077e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36187) * -31.679))
# 13          6.139e-01  4.257e-02  y = (((40.43 * x₁) + ((-0.44693 + x₀) * -36.082)) * x₀) + -1.4...
#                                   087
# 15          6.064e-01  6.106e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          6.018e-01  3.843e-03  y = -1.6665 + (x₀ * ((((x₀ * 1.7611) + -38.73) * (x₀ + -0.4580...
#                                   6)) + (41.329 * x₁)))
# 19          5.901e-01  9.822e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Head worker occupation: 27.2%
# Progress: 1877 / 7500 total iterations (25.027%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.7702 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.064e-01  5.725e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          6.018e-01  3.843e-03  y = -1.6665 + (x₀ * ((((x₀ * 1.7611) + -38.73) * (x₀ + -0.4580...
#                                   6)) + (41.329 * x₁)))
# 19          5.901e-01  9.822e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+05
# Head worker occupation: 29.7%
# Progress: 2553 / 7500 total iterations (34.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.7702 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.064e-01  5.725e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          6.018e-01  3.843e-03  y = -1.6665 + (x₀ * ((((x₀ * 1.7611) + -38.73) * (x₀ + -0.4580...
#                                   6)) + (41.329 * x₁)))
# 19          5.901e-01  9.822e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+05
# Head worker occupation: 29.1%
# Progress: 3259 / 7500 total iterations (43.453%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.7702 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.064e-01  5.725e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          6.017e-01  3.898e-03  y = -1.6665 + (x₀ * ((((1.9422 * x₀) + -38.73) * (x₀ + -0.4580...
#                                   6)) + (41.329 * x₁)))
# 19          5.901e-01  9.766e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+05
# Head worker occupation: 29.2%
# Progress: 3942 / 7500 total iterations (52.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.77 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.064e-01  5.725e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          6.013e-01  4.202e-03  y = -1.6665 + (x₀ * ((((1.9422 * x₀) + -38.73) * (x₀ + -0.4577...
#                                   5)) + (41.329 * x₁)))
# 19          5.901e-01  9.462e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.000e+05
# Head worker occupation: 27.8%
# Progress: 4613 / 7500 total iterations (61.507%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.77 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.064e-01  5.725e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          5.997e-01  5.593e-03  y = -1.5555 + (x₀ * (((x₀ + -0.4545) * ((-38.816 + x₀) + x₀)) ...
#                                   + (41.212 * x₁)))
# 19          5.901e-01  8.072e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.050e+05
# Head worker occupation: 27.3%
# Progress: 5319 / 7500 total iterations (70.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.77 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.064e-01  5.725e-03  y = (x₀ * (((x₀ + -0.44891) * (-37.397 + x₀)) + (40.734 * x₁))...
#                                   ) + -1.4149
# 17          5.963e-01  8.389e-03  y = (x₁ + x₁) * ((x₀ * ((-37.008 * (x₀ + -0.42192)) + (43.91 *...
#                                    x₁))) + -1.5643)
# 19          5.901e-01  5.275e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.040e+05
# Head worker occupation: 28.5%
# Progress: 6004 / 7500 total iterations (80.053%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.77 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.061e-01  5.987e-03  y = ((((x₀ + -0.45214) * (-37.421 + x₀)) + (40.718 * x₁)) * x₀...
#                                   ) + -1.489
# 17          5.963e-01  8.128e-03  y = (x₁ + x₁) * ((x₀ * ((-37.008 * (x₀ + -0.42192)) + (43.91 *...
#                                    x₁))) + -1.5643)
# 19          5.901e-01  5.275e-03  y = (x₁ + x₁) * ((x₀ * (((-37.536 + x₀) * (-0.42399 + x₀)) + (...
#                                   43.359 * x₁))) + -1.5485)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.030e+05
# Head worker occupation: 29.4%
# Progress: 6702 / 7500 total iterations (89.360%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.77 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.061e-01  5.987e-03  y = ((((x₀ + -0.45214) * (-37.421 + x₀)) + (40.718 * x₁)) * x₀...
#                                   ) + -1.489
# 17          5.963e-01  8.128e-03  y = (x₁ + x₁) * ((x₀ * ((-37.008 * (x₀ + -0.42192)) + (43.91 *...
#                                    x₁))) + -1.5643)
# 19          5.895e-01  5.774e-03  y = (x₁ + x₁) * ((x₀ * (((x₀ + -38.167) * (x₀ + -0.43082)) + (...
#                                   43.588 * x₁))) + -1.6282)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.990e+05
# Head worker occupation: 28.1%
# Progress: 7353 / 7500 total iterations (98.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.719e+00  1.594e+01  y = x₁
# 3           4.513e+00  2.231e-02  y = x₁ * 2.2107
# 5           3.319e+00  1.537e-01  y = (x₁ * 14.066) + -4.5759
# 7           2.724e+00  9.868e-02  y = (x₁ * 11.055) + (-4.77 * x₀)
# 9           1.757e+00  2.193e-01  y = x₀ * ((x₁ * 38.27) + (-17.28 * x₀))
# 11          6.684e-01  4.833e-01  y = x₀ * ((38.663 * x₁) + ((x₀ + -0.36186) * -31.679))
# 13          6.134e-01  4.295e-02  y = ((((x₀ + -0.44822) * -36.482) + (40.89 * x₁)) * x₀) + -1.4...
#                                   604
# 15          6.061e-01  5.987e-03  y = ((((x₀ + -0.45214) * (-37.421 + x₀)) + (40.718 * x₁)) * x₀...
#                                   ) + -1.489
# 17          5.963e-01  8.128e-03  y = (x₁ + x₁) * ((x₀ * ((-37.008 * (x₀ + -0.42192)) + (43.91 *...
#                                    x₁))) + -1.5643)
# 19          5.895e-01  5.774e-03  y = (x₁ + x₁) * ((x₀ * (((x₀ + -38.167) * (x₀ + -0.43082)) + (...
#                                   43.588 * x₁))) + -1.6282)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                                 x1
# 	1        0.022310                                     x1 * 2.2107198
# 	2        0.153724                      (x1 * 14.066211) + -4.5758524
# 	3        0.098681               (x1 * 11.054882) + (-4.7699823 * x0)
# 	4        0.219259        x0 * ((x1 * 38.269894) + (-17.280409 * x0))
# 	5  >>>>  0.483280  x0 * ((38.66269 * x1) + ((x0 + -0.3618633) * -...
# 	6        0.042954  ((((x0 + -0.44821838) * -36.48222) + (40.89022...
# 	7        0.006009  ((((x0 + -0.45263013) * (-37.47262 + x0)) + (4...
# 	8        0.008106  (x1 + x1) * ((x0 * ((-37.007935 * (x0 + -0.421...
# 	9        0.005774  (x1 + x1) * ((x0 * (((x0 + -38.167393) * (x0 +...
#
# 	       loss  complexity
# 	0  4.719294           1
# 	1  4.513344           3
# 	2  3.318757           5
# 	3  2.724345           7
# 	4  1.757181           9
# 	5  0.668413          11
# 	6  0.613389          13
# 	7  0.606061          15
# 	8  0.596315          17
# 	9  0.589468          19
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_phi.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=5
expr=model_phi.sympy(chose)
expr
sympy.expand(expr)
# Out:
# -31.679077*x0**2 + 38.66269*x0*x1 + 11.4634953441741*x0

# %%
symb1=model_phi.predict(tf.concat([p, s],1),chose)
plt.plot(tf.concat([p, s],1), phi_pred, label='PINN prediction')
plt.plot(tf.concat([p, s],1), symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
Nt=10000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)

dt=0.0001

P_symb[0]=np.mean(uu1) #Initial conditions
S_symb[0]=np.array(tf.exp(u_pred[0,1:2])) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    PS_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    P_symb[i]=P_symb[i-1]+model_phi.predict(PS_p,chose)*dt
    S_symb[i]=S_symb[i-1]-P_symb[i-1]*np.array(m[0])*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, P_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, p, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
plt.plot(T_symb, S_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, S_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, s, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('S')
plt.legend()
plt.show()
