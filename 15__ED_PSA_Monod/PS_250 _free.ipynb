# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
df2.iloc[:, 9:15]
# Out:
# 0        A7      A8      A9     A10     A11     A12
# 0    0.0938  0.0933  0.0947   0.094  0.0945  0.0923
# 1    0.0933  0.0932  0.0948  0.0937  0.0937  0.0923
# 2    0.0932  0.0933  0.0948  0.0939  0.0939  0.0927
# 3    0.0934  0.0935   0.095  0.0941  0.0941  0.0926
# 4    0.0938  0.0939  0.0954  0.0945  0.0945  0.0929
# ..      ...     ...     ...     ...     ...     ...
# 337  0.5901  0.6007  0.5678  0.5227  0.5631   0.308
# 338  0.5898  0.6002  0.5683  0.5222  0.5616  0.3055
# 339  0.5889  0.5999  0.5681  0.5221  0.5621  0.3051
# 340  0.5888  0.5992  0.5675  0.5211   0.561  0.3032
# 341  0.5872  0.5982  0.5666  0.5205  0.5609  0.3005
#
# [342 rows x 6 columns]

# %%
c=-1
P_exp=np.array(df2.iloc[:, 13]).reshape([-1,1])
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max
# Out:
# (1, 231399.5)

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 200 # Number of residual point
N_d = 300 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = T_star.min(0)
ub = T_star.max(0) 

# Initial Condition
xx1 = T_star[::len(T_exp)]
uu1 = P_star[::len(T_exp)]

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu1), replace=False)
xxd = T_star[idx]
uud = P_star[idx]

T_u_train = np.concatenate((xx1,xxd)).reshape([-1,1])
p_train = np.concatenate((uu1,uud)).reshape([-1,1])

T_f_train = lb + (ub-lb)*lhs(1, N_f)

T_u_train_tf = tf.convert_to_tensor(T_u_train, dtype=tf.float32)
p_train_tf =   tf.convert_to_tensor(p_train, dtype=tf.float32)
T_f_train_tf = tf.convert_to_tensor(T_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    A = 2.0*(X - lb)/(ub - lb) - 1.0
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 

def train_vars_total(W, b, lambda_r, lambda_b):
    return W + b + lambda_r + lambda_b

def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r, 1]), dtype=tf.float32)
    return alpha_r, alpha_b

#@tf.function(jit_compile=True)
@tf.function()
def net_f(t, m, W_p, b_p, W_phi, b_phi):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([t])
        u=net(t, W_p, b_p)

        lnp=u[:,0:1]
        lns=u[:,1:2]

        p=tf.exp(lnp)
        s=tf.exp(lns)

        
        phi_p=net(s, W_phi, b_phi)

    p_t = tape1.gradient(p, t) 
    s_t = tape1.gradient(s, t) 

    f_p = p_t - phi_p*p
    f_s = s_t - m[0]*phi_p*p
    
    return f_p, f_s


#@tf.function()
@tf.function()
def train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, p_train_tf, X_f_train_tf, lambda_r, lambda_b, m, opt):
    
    t_u = X_u_train_tf
    t_f = X_f_train_tf

    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, lambda_r, lambda_b, m])
        u_nn = net(t_u, W_p, b_p) 
        lnp=u_nn[:,0:1]
        p_nn=tf.exp(lnp)
        f_p, f_s = net_f(t_f, m, W_p, b_p, W_phi, b_phi)

        loss_p = tf.square(lambda_b*(p_nn - p_train_tf))
        loss_fp = tf.square(lambda_r*f_p) 
        loss_fs = tf.square(lambda_r*f_s) 

        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs) 

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phip = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_m = tape.gradient(loss, m)


    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phip, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_m, m))
   
    return loss, tf.reduce_mean(tf.square((p_nn - p_train_tf))), tf.reduce_mean(tf.square(f_p) ), tf.reduce_mean(tf.square(f_s))



layers = [1, 50, 50, 2]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]

W_phi= [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]


lambda_r, lambda_b = loss_weight(N_f, N_d)
m = [tf.Variable(tf.ones([1,1]), dtype=tf.float32)]

# %%
lr = 1e-3
# Nmax = 15000
# Nmax = 150000
Nmax=10**5
# Nmax=50000



optimizer = tf.optimizers.Adam(learning_rate=lr)

start_time = time.time()
n=0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []
loss_fisa = []


while n <= Nmax:
    loss_, loss_p, loss_fp, loss_fs,  = train_step(W_p, b_p, W_phi, b_phi, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, optimizer)
    
    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)
    # loss_fisa.append(loss_fa)



    if n % 10 == 0:
        print(f"Iteration is: {n}")
        print(f"Total loss is: {loss_}")

        print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p is: {loss_fp}")
        print(f"Physicial loss of s is: {loss_fs}")
        # print(f"Physicial loss of a is: {loss_fa}")


    n+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Total loss is: 580843.125
# Data loss is: 0.5808424949645996
# Physicial loss of p is: 0.6043142676353455
# Physicial loss of s is: 0.08281295746564865
# Iteration is: 10
# Total loss is: 239070.59375
# Data loss is: 0.23906555771827698
# Physicial loss of p is: 0.38061797618865967
# Physicial loss of s is: 0.011160319671034813
# Iteration is: 20
# Total loss is: 99189.9921875
# Data loss is: 0.0991843044757843
# Physicial loss of p is: 0.5864971876144409
# Physicial loss of s is: 0.035374224185943604
# Iteration is: 30
# Total loss is: 19459.10546875
# Data loss is: 0.019457703456282616
# Physicial loss of p is: 0.04251773655414581
# Physicial loss of s is: 0.0814349576830864
# Iteration is: 40
# Total loss is: 14390.529296875
# Data loss is: 0.01438921969383955
# Physicial loss of p is: 0.02167562209069729
# Physicial loss of s is: 0.006968153174966574
# Iteration is: 50
# Total loss is: 12013.0546875
# Data loss is: 0.012011677026748657
# Physicial loss of p is: 0.06549781560897827
# Physicial loss of s is: 0.01761915720999241
# Iteration is: 60
# Total loss is: 10604.572265625
# Data loss is: 0.010603180155158043
# Physicial loss of p is: 0.08917152136564255
# Physicial loss of s is: 0.022535977885127068
# Iteration is: 70
# Total loss is: 10462.517578125
# Data loss is: 0.010461080819368362
# Physicial loss of p is: 0.023452673107385635
# Physicial loss of s is: 0.047459956258535385
# Iteration is: 80
# Total loss is: 9939.392578125
# Data loss is: 0.009937924332916737
# Physicial loss of p is: 0.002689103130251169
# Physicial loss of s is: 0.038508251309394836
# Iteration is: 90
# Total loss is: 9927.4658203125
# Data loss is: 0.009925915859639645
# Physicial loss of p is: 0.0034176469780504704
# Physicial loss of s is: 0.02320396713912487
# Iteration is: 100
# Total loss is: 9895.984375
# Data loss is: 0.0098943579941988
# Physicial loss of p is: 0.00440318463370204
# Physicial loss of s is: 0.023777933791279793
# Iteration is: 110
# Total loss is: 9895.70703125
# Data loss is: 0.009893985465168953
# Physicial loss of p is: 0.0032699787989258766
# Physicial loss of s is: 0.0227645356208086
# Iteration is: 120
# Total loss is: 9885.158203125
# Data loss is: 0.009883315302431583
# Physicial loss of p is: 0.0027484549209475517
# Physicial loss of s is: 0.021724365651607513
# Iteration is: 130
# Total loss is: 9882.2890625
# Data loss is: 0.00988032016903162
# Physicial loss of p is: 0.0032041638623923063
# Physicial loss of s is: 0.019837848842144012
# Iteration is: 140
# Total loss is: 9879.3115234375
# Data loss is: 0.009877227246761322
# Physicial loss of p is: 0.0031696916557848454
# Physicial loss of s is: 0.01918414793908596
# Iteration is: 150
# Total loss is: 9876.6982421875
# Data loss is: 0.009874504059553146
# Physicial loss of p is: 0.002549962606281042
# Physicial loss of s is: 0.01881512440741062
# Iteration is: 160
# Total loss is: 9873.8857421875
# Data loss is: 0.009871573187410831
# Physicial loss of p is: 0.0021666043903678656
# Physicial loss of s is: 0.018071526661515236
# Iteration is: 170
# Total loss is: 9871.15625
# Data loss is: 0.009868726134300232
# Physicial loss of p is: 0.00200394238345325
# Physicial loss of s is: 0.017282551154494286
# Iteration is: 180
# Total loss is: 9868.3642578125
# Data loss is: 0.009865815751254559
# Physicial loss of p is: 0.0018253704765811563
# Physicial loss of s is: 0.01665799878537655
# Iteration is: 190
# Total loss is: 9865.5302734375
# Data loss is: 0.009862861596047878
# Physicial loss of p is: 0.0016535399481654167
# Physicial loss of s is: 0.01606188341975212
# Iteration is: 200
# Total loss is: 9862.6533203125
# Data loss is: 0.009859862737357616
# Physicial loss of p is: 0.0015297597274184227
# Physicial loss of s is: 0.015453232452273369
# Iteration is: 210
# Total loss is: 9859.73046875
# Data loss is: 0.009856820106506348
# Physicial loss of p is: 0.001412095152772963
# Physicial loss of s is: 0.014890611171722412
# Iteration is: 220
# Total loss is: 9856.76953125
# Data loss is: 0.009853735566139221
# Physicial loss of p is: 0.0012916636187583208
# Physicial loss of s is: 0.014368057250976562
# Iteration is: 230
# Total loss is: 9853.7705078125
# Data loss is: 0.00985061377286911
# Physicial loss of p is: 0.0011887927539646626
# Physicial loss of s is: 0.013858911581337452
# Iteration is: 240
# Total loss is: 9850.7314453125
# Data loss is: 0.00984745379537344
# Physicial loss of p is: 0.0011025411076843739
# Physicial loss of s is: 0.01336742378771305
# Iteration is: 250
# Total loss is: 9847.6572265625
# Data loss is: 0.009844253771007061
# Physicial loss of p is: 0.0010249133920297027
# Physicial loss of s is: 0.012899369932711124
# Iteration is: 260
# Total loss is: 9844.546875
# Data loss is: 0.009841019287705421
# Physicial loss of p is: 0.0009556481381878257
# Physicial loss of s is: 0.012450366280972958
# Iteration is: 270
# Total loss is: 9841.396484375
# Data loss is: 0.009837744757533073
# Physicial loss of p is: 0.0008944951114244759
# Physicial loss of s is: 0.01201858650892973
# Iteration is: 280
# Total loss is: 9838.2158203125
# Data loss is: 0.009834437631070614
# Physicial loss of p is: 0.0008395310724154115
# Physicial loss of s is: 0.01160444412380457
# Iteration is: 290
# Total loss is: 9834.99609375
# Data loss is: 0.00983109138906002
# Physicial loss of p is: 0.0007902727229520679
# Physicial loss of s is: 0.011206579394638538
# Iteration is: 300
# Total loss is: 9831.7431640625
# Data loss is: 0.00982771348208189
# Physicial loss of p is: 0.0007466088281944394
# Physicial loss of s is: 0.010823642835021019
# Iteration is: 310
# Total loss is: 9828.453125
# Data loss is: 0.009824296459555626
# Physicial loss of p is: 0.0007077684858813882
# Physicial loss of s is: 0.010455158539116383
# Iteration is: 320
# Total loss is: 9825.126953125
# Data loss is: 0.009820844046771526
# Physicial loss of p is: 0.0006731133325956762
# Physicial loss of s is: 0.010100540705025196
# Iteration is: 330
# Total loss is: 9821.7607421875
# Data loss is: 0.009817350655794144
# Physicial loss of p is: 0.0006422621081583202
# Physicial loss of s is: 0.009759034961462021
# Iteration is: 340
# Total loss is: 9818.357421875
# Data loss is: 0.009813820943236351
# Physicial loss of p is: 0.0006148213287815452
# Physicial loss of s is: 0.009430032223463058
# Iteration is: 350
# Total loss is: 9814.9130859375
# Data loss is: 0.009810250252485275
# Physicial loss of p is: 0.0005904453573748469
# Physicial loss of s is: 0.009112987667322159
# Iteration is: 360
# Total loss is: 9811.4296875
# Data loss is: 0.00980664137750864
# Physicial loss of p is: 0.0005688585224561393
# Physicial loss of s is: 0.008807334117591381
# Iteration is: 370
# Total loss is: 9807.90234375
# Data loss is: 0.009802988730370998
# Physicial loss of p is: 0.0005497935926541686
# Physicial loss of s is: 0.00851256214082241
# Iteration is: 380
# Total loss is: 9804.330078125
# Data loss is: 0.009799291379749775
# Physicial loss of p is: 0.0005330127314664423
# Physicial loss of s is: 0.008228208869695663
# Iteration is: 390
# Total loss is: 9800.7138671875
# Data loss is: 0.009795548394322395
# Physicial loss of p is: 0.0005183062748983502
# Physicial loss of s is: 0.007953805848956108
# Iteration is: 400
# Total loss is: 9797.048828125
# Data loss is: 0.009791758842766285
# Physicial loss of p is: 0.000505493429955095
# Physicial loss of s is: 0.007688925135880709
# Iteration is: 410
# Total loss is: 9793.33203125
# Data loss is: 0.00978791806846857
# Physicial loss of p is: 0.0004944142419844866
# Physicial loss of s is: 0.007433148566633463
# Iteration is: 420
# Total loss is: 9789.5625
# Data loss is: 0.009784023277461529
# Physicial loss of p is: 0.00048492287169210613
# Physicial loss of s is: 0.0071860868483781815
# Iteration is: 430
# Total loss is: 9785.7392578125
# Data loss is: 0.00978007260710001
# Physicial loss of p is: 0.0004768898943439126
# Physicial loss of s is: 0.006947369780391455
# Iteration is: 440
# Total loss is: 9781.8583984375
# Data loss is: 0.009776067920029163
# Physicial loss of p is: 0.0004701997968368232
# Physicial loss of s is: 0.006716622039675713
# Iteration is: 450
# Total loss is: 9777.9140625
# Data loss is: 0.009771997109055519
# Physicial loss of p is: 0.0004647540918085724
# Physicial loss of s is: 0.006493514869362116
# Iteration is: 460
# Total loss is: 9773.904296875
# Data loss is: 0.00976786483079195
# Physicial loss of p is: 0.00046045941417105496
# Physicial loss of s is: 0.006277712993323803
# Iteration is: 470
# Total loss is: 9769.828125
# Data loss is: 0.00976366363465786
# Physicial loss of p is: 0.00045724035589955747
# Physicial loss of s is: 0.006068900693207979
# Iteration is: 480
# Total loss is: 9765.6748046875
# Data loss is: 0.009759387001395226
# Physicial loss of p is: 0.00045502514694817364
# Physicial loss of s is: 0.005866783671081066
# Iteration is: 490
# Total loss is: 9761.44921875
# Data loss is: 0.009755038656294346
# Physicial loss of p is: 0.00045375258196145296
# Physicial loss of s is: 0.005671062506735325
# Iteration is: 500
# Total loss is: 9757.142578125
# Data loss is: 0.0097506083548069
# Physicial loss of p is: 0.0004533693427219987
# Physicial loss of s is: 0.0054814694449305534
# Iteration is: 510
# Total loss is: 9752.7470703125
# Data loss is: 0.00974609050899744
# Physicial loss of p is: 0.00045383215183392167
# Physicial loss of s is: 0.005297735799103975
# Iteration is: 520
# Total loss is: 9748.2646484375
# Data loss is: 0.009741484187543392
# Physicial loss of p is: 0.0004550983721856028
# Physicial loss of s is: 0.00511960731819272
# Iteration is: 530
# Total loss is: 9743.6826171875
# Data loss is: 0.009736781008541584
# Physicial loss of p is: 0.000457144487882033
# Physicial loss of s is: 0.004946844652295113
# Iteration is: 540
# Total loss is: 9739.0009765625
# Data loss is: 0.009731974452733994
# Physicial loss of p is: 0.00045993804815225303
# Physicial loss of s is: 0.004779207054525614
# Iteration is: 550
# Total loss is: 9734.212890625
# Data loss is: 0.00972706452012062
# Physicial loss of p is: 0.00046346141607500613
# Physicial loss of s is: 0.0046164775267243385
# Iteration is: 560
# Total loss is: 9729.3046875
# Data loss is: 0.009722036309540272
# Physicial loss of p is: 0.00046770359040237963
# Physicial loss of s is: 0.004458445589989424
# Iteration is: 570
# Total loss is: 9724.27734375
# Data loss is: 0.009716887027025223
# Physicial loss of p is: 0.0004726578190457076
# Physicial loss of s is: 0.004304907750338316
# Iteration is: 580
# Total loss is: 9719.1201171875
# Data loss is: 0.009711609221994877
# Physicial loss of p is: 0.0004783181066159159
# Physicial loss of s is: 0.004155667033046484
# Iteration is: 590
# Total loss is: 9713.8251953125
# Data loss is: 0.009706194512546062
# Physicial loss of p is: 0.00048469434841535985
# Physicial loss of s is: 0.004010540898889303
# Iteration is: 600
# Total loss is: 9708.3828125
# Data loss is: 0.009700631722807884
# Physicial loss of p is: 0.0004917910555377603
# Physicial loss of s is: 0.0038693570531904697
# Iteration is: 610
# Total loss is: 9702.7841796875
# Data loss is: 0.009694915264844894
# Physicial loss of p is: 0.0004996295901946723
# Physicial loss of s is: 0.0037319434341043234
# Iteration is: 620
# Total loss is: 9697.0205078125
# Data loss is: 0.009689033031463623
# Physicial loss of p is: 0.0005082282586954534
# Physicial loss of s is: 0.0035981431137770414
# Iteration is: 630
# Total loss is: 9691.0771484375
# Data loss is: 0.009682971984148026
# Physicial loss of p is: 0.0005176163394935429
# Physicial loss of s is: 0.0034678049851208925
# Iteration is: 640
# Total loss is: 9684.94921875
# Data loss is: 0.00967672374099493
# Physicial loss of p is: 0.0005278306198306382
# Physicial loss of s is: 0.0033407837618142366
# Iteration is: 650
# Total loss is: 9678.6162109375
# Data loss is: 0.009670275263488293
# Physicial loss of p is: 0.0005389106809161603
# Physicial loss of s is: 0.0032169532496482134
# Iteration is: 660
# Total loss is: 9672.0732421875
# Data loss is: 0.009663615375757217
# Physicial loss of p is: 0.0005509050679393113
# Physicial loss of s is: 0.003096171887591481
# Iteration is: 670
# Total loss is: 9665.294921875
# Data loss is: 0.009656719863414764
# Physicial loss of p is: 0.0005638737929984927
# Physicial loss of s is: 0.0029783279169350863
# Iteration is: 680
# Total loss is: 9658.2744140625
# Data loss is: 0.00964958406984806
# Physicial loss of p is: 0.000577881932258606
# Physicial loss of s is: 0.0028633016627281904
# Iteration is: 690
# Total loss is: 9650.9931640625
# Data loss is: 0.009642188437283039
# Physicial loss of p is: 0.0005930018960498273
# Physicial loss of s is: 0.002750988118350506
# Iteration is: 700
# Total loss is: 9643.4287109375
# Data loss is: 0.009634510613977909
# Physicial loss of p is: 0.0006093240808695555
# Physicial loss of s is: 0.002641287399455905
# Iteration is: 710
# Total loss is: 9635.564453125
# Data loss is: 0.009626532904803753
# Physicial loss of p is: 0.0006269398145377636
# Physicial loss of s is: 0.0025341033469885588
# Iteration is: 720
# Total loss is: 9627.3798828125
# Data loss is: 0.009618236683309078
# Physicial loss of p is: 0.0006459648138843477
# Physicial loss of s is: 0.002429346786811948
# Iteration is: 730
# Total loss is: 9618.84765625
# Data loss is: 0.009609593078494072
# Physicial loss of p is: 0.0006665196851827204
# Physicial loss of s is: 0.00232693855650723
# Iteration is: 740
# Total loss is: 9609.947265625
# Data loss is: 0.009600580669939518
# Physicial loss of p is: 0.0006887428462505341
# Physicial loss of s is: 0.002226798329502344
# Iteration is: 750
# Total loss is: 9600.6484375
# Data loss is: 0.009591172449290752
# Physicial loss of p is: 0.000712794135324657
# Physicial loss of s is: 0.0021288602147251368
# Iteration is: 760
# Total loss is: 9590.923828125
# Data loss is: 0.009581338614225388
# Physicial loss of p is: 0.0007388471276499331
# Physicial loss of s is: 0.002033059485256672
# Iteration is: 770
# Total loss is: 9580.7392578125
# Data loss is: 0.009571046568453312
# Physicial loss of p is: 0.0007671029889024794
# Physicial loss of s is: 0.0019393354887142777
# Iteration is: 780
# Total loss is: 9570.0576171875
# Data loss is: 0.009560257196426392
# Physicial loss of p is: 0.0007977864006534219
# Physicial loss of s is: 0.001847638632170856
# Iteration is: 790
# Total loss is: 9558.845703125
# Data loss is: 0.009548940695822239
# Physicial loss of p is: 0.0008311523706652224
# Physicial loss of s is: 0.0017579233972355723
# Iteration is: 800
# Total loss is: 9547.0546875
# Data loss is: 0.009537046775221825
# Physicial loss of p is: 0.0008674843702465296
# Physicial loss of s is: 0.0016701497370377183
# Iteration is: 810
# Total loss is: 9534.646484375
# Data loss is: 0.00952453538775444
# Physicial loss of p is: 0.0009071126696653664
# Physicial loss of s is: 0.001584287267178297
# Iteration is: 820
# Total loss is: 9521.564453125
# Data loss is: 0.009511353448033333
# Physicial loss of p is: 0.0009503958863206208
# Physicial loss of s is: 0.001500310143455863
# Iteration is: 830
# Total loss is: 9507.76171875
# Data loss is: 0.009497452527284622
# Physicial loss of p is: 0.0009977571899071336
# Physicial loss of s is: 0.001418202999047935
# Iteration is: 840
# Total loss is: 9493.17578125
# Data loss is: 0.009482771158218384
# Physicial loss of p is: 0.0010496710892766714
# Physicial loss of s is: 0.001337953843176365
# Iteration is: 850
# Total loss is: 9477.7451171875
# Data loss is: 0.009467242285609245
# Physicial loss of p is: 0.0011066710576415062
# Physicial loss of s is: 0.0012595668667927384
# Iteration is: 860
# Total loss is: 9461.392578125
# Data loss is: 0.009450796991586685
# Physicial loss of p is: 0.0011693763080984354
# Physicial loss of s is: 0.0011830531293526292
# Iteration is: 870
# Total loss is: 9444.046875
# Data loss is: 0.00943335983902216
# Physicial loss of p is: 0.0012384819565340877
# Physicial loss of s is: 0.001108430209569633
# Iteration is: 880
# Total loss is: 9425.6240234375
# Data loss is: 0.009414848871529102
# Physicial loss of p is: 0.0013147947611287236
# Physicial loss of s is: 0.0010357339633628726
# Iteration is: 890
# Total loss is: 9406.02734375
# Data loss is: 0.009395167231559753
# Physicial loss of p is: 0.0013992226449772716
# Physicial loss of s is: 0.0009650108404457569
# Iteration is: 900
# Total loss is: 9385.1591796875
# Data loss is: 0.009374215267598629
# Physicial loss of p is: 0.0014928191667422652
# Physicial loss of s is: 0.0008963205036707222
# Iteration is: 910
# Total loss is: 9362.912109375
# Data loss is: 0.009351887740194798
# Physicial loss of p is: 0.0015967893414199352
# Physicial loss of s is: 0.0008297361200675368
# Iteration is: 920
# Total loss is: 9339.16015625
# Data loss is: 0.00932805985212326
# Physicial loss of p is: 0.0017125150188803673
# Physicial loss of s is: 0.0007653508801013231
# Iteration is: 930
# Total loss is: 9313.7822265625
# Data loss is: 0.009302607737481594
# Physicial loss of p is: 0.0018415841041132808
# Physicial loss of s is: 0.0007032716530375183
# Iteration is: 940
# Total loss is: 9286.625
# Data loss is: 0.00927538238465786
# Physicial loss of p is: 0.00198582885786891
# Physicial loss of s is: 0.0006436218973249197
# Iteration is: 950
# Total loss is: 9257.541015625
# Data loss is: 0.009246233850717545
# Physicial loss of p is: 0.002147353021427989
# Physicial loss of s is: 0.0005865423590876162
# Iteration is: 960
# Total loss is: 9226.3603515625
# Data loss is: 0.009214994497597218
# Physicial loss of p is: 0.0023285923525691032
# Physicial loss of s is: 0.0005321876960806549
# Iteration is: 970
# Total loss is: 9192.90625
# Data loss is: 0.009181485511362553
# Physicial loss of p is: 0.0025323398876935244
# Physicial loss of s is: 0.00048072554636746645
# Iteration is: 980
# Total loss is: 9156.9775390625
# Data loss is: 0.009145506657660007
# Physicial loss of p is: 0.002761828014627099
# Physicial loss of s is: 0.00043233155156485736
# Iteration is: 990
# Total loss is: 9118.3662109375
# Data loss is: 0.009106853976845741
# Physicial loss of p is: 0.003020772011950612
# Physicial loss of s is: 0.00038718414725735784
# Iteration is: 1000
# Total loss is: 9076.8505859375
# Data loss is: 0.009065301157534122
# Physicial loss of p is: 0.0033134615514427423
# Physicial loss of s is: 0.0003454537654761225
# Iteration is: 1010
# Total loss is: 9032.18359375
# Data loss is: 0.009020606987178326
# Physicial loss of p is: 0.0036448296159505844
# Physicial loss of s is: 0.00030729378340765834
# Iteration is: 1020
# Total loss is: 8984.119140625
# Data loss is: 0.008972521871328354
# Physicial loss of p is: 0.0040205540135502815
# Physicial loss of s is: 0.000272824865533039
# Iteration is: 1030
# Total loss is: 8932.3896484375
# Data loss is: 0.008920780383050442
# Physicial loss of p is: 0.0044471388682723045
# Physicial loss of s is: 0.00024212246353272349
# Iteration is: 1040
# Total loss is: 8876.7216796875
# Data loss is: 0.008865110576152802
# Physicial loss of p is: 0.004932045470923185
# Physicial loss of s is: 0.00021518724679481238
# Iteration is: 1050
# Total loss is: 8816.8291015625
# Data loss is: 0.008805226534605026
# Physicial loss of p is: 0.005483797751367092
# Physicial loss of s is: 0.00019193807383999228
# Iteration is: 1060
# Total loss is: 8752.4287109375
# Data loss is: 0.008740843273699284
# Physicial loss of p is: 0.006112094037234783
# Physicial loss of s is: 0.00017218830180354416
# Iteration is: 1070
# Total loss is: 8683.2314453125
# Data loss is: 0.008671676740050316
# Physicial loss of p is: 0.00682794488966465
# Physicial loss of s is: 0.00015562857151962817
# Iteration is: 1080
# Total loss is: 8608.95703125
# Data loss is: 0.00859744567424059
# Physicial loss of p is: 0.007643792778253555
# Physicial loss of s is: 0.00014182983431965113
# Iteration is: 1090
# Total loss is: 8529.3427734375
# Data loss is: 0.008517886511981487
# Physicial loss of p is: 0.008573613129556179
# Physicial loss of s is: 0.0001302532764384523
# Iteration is: 1100
# Total loss is: 8444.140625
# Data loss is: 0.008432756178081036
# Physicial loss of p is: 0.009633027948439121
# Physicial loss of s is: 0.00012027861521346495
# Iteration is: 1110
# Total loss is: 8353.142578125
# Data loss is: 0.008341845124959946
# Physicial loss of p is: 0.010839376598596573
# Physicial loss of s is: 0.00011125892342533916
# Iteration is: 1120
# Total loss is: 8256.1728515625
# Data loss is: 0.008244977332651615
# Physicial loss of p is: 0.012211762368679047
# Physicial loss of s is: 0.00010259980626869947
# Iteration is: 1130
# Total loss is: 8153.11328125
# Data loss is: 0.008142035454511642
# Physicial loss of p is: 0.013771064579486847
# Physicial loss of s is: 9.38535449677147e-05
# Iteration is: 1140
# Total loss is: 8043.8994140625
# Data loss is: 0.008032954297959805
# Physicial loss of p is: 0.015539868734776974
# Physicial loss of s is: 8.481515396852046e-05
# Iteration is: 1150
# Total loss is: 7928.5439453125
# Data loss is: 0.007917750626802444
# Physicial loss of p is: 0.01754235103726387
# Physicial loss of s is: 7.560508674941957e-05
# Iteration is: 1160
# Total loss is: 7807.12646484375
# Data loss is: 0.007796500343829393
# Physicial loss of p is: 0.019804056733846664
# Physicial loss of s is: 6.670655420748517e-05
# Iteration is: 1170
# Total loss is: 7679.82080078125
# Data loss is: 0.007669379003345966
# Physicial loss of p is: 0.022351570427417755
# Physicial loss of s is: 5.8941343013430014e-05
# Iteration is: 1180
# Total loss is: 7546.87109375
# Data loss is: 0.007536630611866713
# Physicial loss of p is: 0.02521211840212345
# Physicial loss of s is: 5.3376072173705325e-05
# Iteration is: 1190
# Total loss is: 7408.61669921875
# Data loss is: 0.007398590911179781
# Physicial loss of p is: 0.028412936255335808
# Physicial loss of s is: 5.11858997924719e-05
# Iteration is: 1200
# Total loss is: 7265.47265625
# Data loss is: 0.007255676668137312
# Physicial loss of p is: 0.03198053687810898
# Physicial loss of s is: 5.3524803661275655e-05
# Iteration is: 1210
# Total loss is: 7117.92138671875
# Data loss is: 0.00710836797952652
# Physicial loss of p is: 0.03593985736370087
# Physicial loss of s is: 6.149244291009381e-05
# Iteration is: 1220
# Total loss is: 6966.51123046875
# Data loss is: 0.006957214791327715
# Physicial loss of p is: 0.040313102304935455
# Physicial loss of s is: 7.627494778716937e-05
# Iteration is: 1230
# Total loss is: 6811.8330078125
# Data loss is: 0.006802803836762905
# Physicial loss of p is: 0.045118432492017746
# Physicial loss of s is: 9.949215018423274e-05
# Iteration is: 1240
# Total loss is: 6654.52099609375
# Data loss is: 0.00664576655253768
# Physicial loss of p is: 0.05036824196577072
# Physicial loss of s is: 0.0001337818830506876
# Iteration is: 1250
# Total loss is: 6495.2236328125
# Data loss is: 0.006486749742180109
# Physicial loss of p is: 0.05606693774461746
# Physicial loss of s is: 0.00018347013974562287
# Iteration is: 1260
# Total loss is: 6334.5986328125
# Data loss is: 0.006326411385089159
# Physicial loss of p is: 0.06220744177699089
# Physicial loss of s is: 0.00025542161893099546
# Iteration is: 1270
# Total loss is: 6173.30029296875
# Data loss is: 0.006165401078760624
# Physicial loss of p is: 0.06876593828201294
# Physicial loss of s is: 0.00036004625144414604
# Iteration is: 1280
# Total loss is: 6011.97314453125
# Data loss is: 0.00600436283275485
# Physicial loss of p is: 0.07569340616464615
# Physicial loss of s is: 0.0005129313212819397
# Iteration is: 1290
# Total loss is: 5851.2392578125
# Data loss is: 0.005843916442245245
# Physicial loss of p is: 0.08290137350559235
# Physicial loss of s is: 0.0007376784342341125
# Iteration is: 1300
# Total loss is: 5691.7001953125
# Data loss is: 0.00568466167896986
# Physicial loss of p is: 0.09023962169885635
# Physicial loss of s is: 0.0010705854510888457
# Iteration is: 1310
# Total loss is: 5533.93115234375
# Data loss is: 0.005527171306312084
# Physicial loss of p is: 0.09746044874191284
# Physicial loss of s is: 0.0015677985502406955
# Iteration is: 1320
# Total loss is: 5378.4814453125
# Data loss is: 0.005371996201574802
# Physicial loss of p is: 0.10416919738054276
# Physicial loss of s is: 0.0023127903696149588
# Iteration is: 1330
# Total loss is: 5225.8798828125
# Data loss is: 0.00521966302767396
# Physicial loss of p is: 0.10977520048618317
# Physicial loss of s is: 0.0034152460284531116
# Iteration is: 1340
# Total loss is: 5076.62890625
# Data loss is: 0.005070675630122423
# Physicial loss of p is: 0.11352863162755966
# Physicial loss of s is: 0.004968589637428522
# Iteration is: 1350
# Total loss is: 4931.21044921875
# Data loss is: 0.0049255178309977055
# Physicial loss of p is: 0.11489933729171753
# Physicial loss of s is: 0.006894188933074474
# Iteration is: 1360
# Total loss is: 4790.07958984375
# Data loss is: 0.004784645512700081
# Physicial loss of p is: 0.1146150603890419
# Physicial loss of s is: 0.008665306493639946
# Iteration is: 1370
# Total loss is: 4653.6796875
# Data loss is: 0.0046484945341944695
# Physicial loss of p is: 0.11543673276901245
# Physicial loss of s is: 0.00942391250282526
# Iteration is: 1380
# Total loss is: 4522.4228515625
# Data loss is: 0.004517466761171818
# Physicial loss of p is: 0.11987300217151642
# Physicial loss of s is: 0.009170240722596645
# Iteration is: 1390
# Total loss is: 4396.68701171875
# Data loss is: 0.004391929600387812
# Physicial loss of p is: 0.12752757966518402
# Physicial loss of s is: 0.009097945876419544
# Iteration is: 1400
# Total loss is: 4276.79296875
# Data loss is: 0.0042722104117274284
# Physicial loss of p is: 0.136943981051445
# Physicial loss of s is: 0.009674565866589546
# Iteration is: 1410
# Total loss is: 4163.0087890625
# Data loss is: 0.004158580210059881
# Physicial loss of p is: 0.14709743857383728
# Physicial loss of s is: 0.010397912003099918
# Iteration is: 1420
# Total loss is: 4055.547119140625
# Data loss is: 0.004051255993545055
# Physicial loss of p is: 0.15782693028450012
# Physicial loss of s is: 0.010959344916045666
# Iteration is: 1430
# Total loss is: 3954.5546875
# Data loss is: 0.003950384445488453
# Physicial loss of p is: 0.16911008954048157
# Physicial loss of s is: 0.011303945444524288
# Iteration is: 1440
# Total loss is: 3860.11279296875
# Data loss is: 0.003856046125292778
# Physicial loss of p is: 0.18068000674247742
# Physicial loss of s is: 0.011607902124524117
# Iteration is: 1450
# Total loss is: 3772.22802734375
# Data loss is: 0.0037682494148612022
# Physicial loss of p is: 0.19229479134082794
# Physicial loss of s is: 0.011972728185355663
# Iteration is: 1460
# Total loss is: 3690.835693359375
# Data loss is: 0.003686928655952215
# Physicial loss of p is: 0.2038591504096985
# Physicial loss of s is: 0.012340955436229706
# Iteration is: 1470
# Total loss is: 3615.80029296875
# Data loss is: 0.0036119509022682905
# Physicial loss of p is: 0.2152705192565918
# Physicial loss of s is: 0.012667479924857616
# Iteration is: 1480
# Total loss is: 3546.928466796875
# Data loss is: 0.0035431217402219772
# Physicial loss of p is: 0.22639647126197815
# Physicial loss of s is: 0.012950041331350803
# Iteration is: 1490
# Total loss is: 3483.96826171875
# Data loss is: 0.0034801915753632784
# Physicial loss of p is: 0.23711137473583221
# Physicial loss of s is: 0.013165402226150036
# Iteration is: 1500
# Total loss is: 3426.623779296875
# Data loss is: 0.003422865876927972
# Physicial loss of p is: 0.24499695003032684
# Physicial loss of s is: 0.014442636631429195
# Iteration is: 1510
# Total loss is: 3374.56396484375
# Data loss is: 0.003370812628418207
# Physicial loss of p is: 0.26045891642570496
# Physicial loss of s is: 0.012222924269735813
# Iteration is: 1520
# Total loss is: 3327.430419921875
# Data loss is: 0.003323677694424987
# Physicial loss of p is: 0.2683619558811188
# Physicial loss of s is: 0.01262118574231863
# Iteration is: 1530
# Total loss is: 3284.854248046875
# Data loss is: 0.0032810934353619814
# Physicial loss of p is: 0.27541184425354004
# Physicial loss of s is: 0.01279685739427805
# Iteration is: 1540
# Total loss is: 3246.4560546875
# Data loss is: 0.0032426819670945406
# Physicial loss of p is: 0.28115445375442505
# Physicial loss of s is: 0.012901434674859047
# Iteration is: 1550
# Total loss is: 3211.860595703125
# Data loss is: 0.00320807215757668
# Physicial loss of p is: 0.2869013249874115
# Physicial loss of s is: 0.012355498969554901
# Iteration is: 1560
# Total loss is: 3180.69921875
# Data loss is: 0.0031768998596817255
# Physicial loss of p is: 0.2929176986217499
# Physicial loss of s is: 0.01121007464826107
# Iteration is: 1570
# Total loss is: 3152.62646484375
# Data loss is: 0.0031488160602748394
# Physicial loss of p is: 0.29851099848747253
# Physicial loss of s is: 0.010188810527324677
# Iteration is: 1580
# Total loss is: 3127.304931640625
# Data loss is: 0.0031234908383339643
# Physicial loss of p is: 0.29943913221359253
# Physicial loss of s is: 0.009504777379333973
# Iteration is: 1590
# Total loss is: 3104.420166015625
# Data loss is: 0.003100615693256259
# Physicial loss of p is: 0.2890748977661133
# Physicial loss of s is: 0.009465344250202179
# Iteration is: 1600
# Total loss is: 3083.683349609375
# Data loss is: 0.0030799040105193853
# Physicial loss of p is: 0.28322264552116394
# Physicial loss of s is: 0.008328885771334171
# Iteration is: 1610
# Total loss is: 3064.8369140625
# Data loss is: 0.003061093855649233
# Physicial loss of p is: 0.2751608192920685
# Physicial loss of s is: 0.007377938833087683
# Iteration is: 1620
# Total loss is: 3047.64599609375
# Data loss is: 0.0030439479742199183
# Physicial loss of p is: 0.2636873722076416
# Physicial loss of s is: 0.0066348593682050705
# Iteration is: 1630
# Total loss is: 3031.880126953125
# Data loss is: 0.0030282523948699236
# Physicial loss of p is: 0.25969257950782776
# Physicial loss of s is: 0.005471870768815279
# Iteration is: 1640
# Total loss is: 3017.394287109375
# Data loss is: 0.003013814566656947
# Physicial loss of p is: 0.26609373092651367
# Physicial loss of s is: 0.004753009416162968
# Iteration is: 1650
# Total loss is: 3003.968017578125
# Data loss is: 0.0030004645232111216
# Physicial loss of p is: 0.2495114952325821
# Physicial loss of s is: 0.004693723749369383
# Iteration is: 1660
# Total loss is: 2991.468994140625
# Data loss is: 0.002988050691783428
# Physicial loss of p is: 0.21888168156147003
# Physicial loss of s is: 0.004905063658952713
# Iteration is: 1670
# Total loss is: 2979.813720703125
# Data loss is: 0.0029764410573989153
# Physicial loss of p is: 0.20325437188148499
# Physicial loss of s is: 0.0050873770378530025
# Iteration is: 1680
# Total loss is: 2968.828369140625
# Data loss is: 0.0029655194375663996
# Physicial loss of p is: 0.20924407243728638
# Physicial loss of s is: 0.004984838422387838
# Iteration is: 1690
# Total loss is: 2958.45263671875
# Data loss is: 0.002955183619633317
# Physicial loss of p is: 0.200368270277977
# Physicial loss of s is: 0.005160301458090544
# Iteration is: 1700
# Total loss is: 2948.614501953125
# Data loss is: 0.0029453467577695847
# Physicial loss of p is: 0.18531616032123566
# Physicial loss of s is: 0.0055290330201387405
# Iteration is: 1710
# Total loss is: 2939.202880859375
# Data loss is: 0.002935931319370866
# Physicial loss of p is: 0.2098764181137085
# Physicial loss of s is: 0.0053707933984696865
# Iteration is: 1720
# Total loss is: 2930.146484375
# Data loss is: 0.0029268732760101557
# Physicial loss of p is: 0.1837240606546402
# Physicial loss of s is: 0.005830452311784029
# Iteration is: 1730
# Total loss is: 2921.396240234375
# Data loss is: 0.002918113488703966
# Physicial loss of p is: 0.20416198670864105
# Physicial loss of s is: 0.005623070057481527
# Iteration is: 1740
# Total loss is: 2912.911865234375
# Data loss is: 0.002909604227170348
# Physicial loss of p is: 0.18650184571743011
# Physicial loss of s is: 0.00595296872779727
# Iteration is: 1750
# Total loss is: 2904.64892578125
# Data loss is: 0.002901302417740226
# Physicial loss of p is: 0.2087724357843399
# Physicial loss of s is: 0.005723525304347277
# Iteration is: 1760
# Total loss is: 2896.5556640625
# Data loss is: 0.0028931733686476946
# Physicial loss of p is: 0.19160611927509308
# Physicial loss of s is: 0.006009645294398069
# Iteration is: 1770
# Total loss is: 2888.595703125
# Data loss is: 0.002885183785110712
# Physicial loss of p is: 0.2070286124944687
# Physicial loss of s is: 0.005786278285086155
# Iteration is: 1780
# Total loss is: 2880.752197265625
# Data loss is: 0.0028773080557584763
# Physicial loss of p is: 0.19953610002994537
# Physicial loss of s is: 0.005875182803720236
# Iteration is: 1790
# Total loss is: 2873.025146484375
# Data loss is: 0.0028695217333734035
# Physicial loss of p is: 0.19976706802845
# Physicial loss of s is: 0.005923838820308447
# Iteration is: 1800
# Total loss is: 2865.35888671875
# Data loss is: 0.0028618022333830595
# Physicial loss of p is: 0.215606227517128
# Physicial loss of s is: 0.005722822155803442
# Iteration is: 1810
# Total loss is: 2857.723388671875
# Data loss is: 0.0028541318606585264
# Physicial loss of p is: 0.20763137936592102
# Physicial loss of s is: 0.005786387715488672
# Iteration is: 1820
# Total loss is: 2850.150146484375
# Data loss is: 0.0028464931529015303
# Physicial loss of p is: 0.207783505320549
# Physicial loss of s is: 0.005821500904858112
# Iteration is: 1830
# Total loss is: 2842.568115234375
# Data loss is: 0.0028388670179992914
# Physicial loss of p is: 0.21739253401756287
# Physicial loss of s is: 0.005663169082254171
# Iteration is: 1840
# Total loss is: 2835.016357421875
# Data loss is: 0.002831236692145467
# Physicial loss of p is: 0.22889190912246704
# Physicial loss of s is: 0.005569714121520519
# Iteration is: 1850
# Total loss is: 2827.408447265625
# Data loss is: 0.0028235865756869316
# Physicial loss of p is: 0.21652035415172577
# Physicial loss of s is: 0.00569494953379035
# Iteration is: 1860
# Total loss is: 2819.774658203125
# Data loss is: 0.0028158947825431824
# Physicial loss of p is: 0.22766433656215668
# Physicial loss of s is: 0.005556153133511543
# Iteration is: 1870
# Total loss is: 2812.08056640625
# Data loss is: 0.002808141754940152
# Physicial loss of p is: 0.22476054728031158
# Physicial loss of s is: 0.005598857533186674
# Iteration is: 1880
# Total loss is: 2804.335693359375
# Data loss is: 0.0028003021143376827
# Physicial loss of p is: 0.22676189243793488
# Physicial loss of s is: 0.0056630754843354225
# Iteration is: 1890
# Total loss is: 2796.437255859375
# Data loss is: 0.0027923460584133863
# Physicial loss of p is: 0.24158629775047302
# Physicial loss of s is: 0.005482214502990246
# Iteration is: 1900
# Total loss is: 2788.40380859375
# Data loss is: 0.002784240525215864
# Physicial loss of p is: 0.2360890954732895
# Physicial loss of s is: 0.005590612068772316
# Iteration is: 1910
# Total loss is: 2780.188232421875
# Data loss is: 0.002775943372398615
# Physicial loss of p is: 0.24720776081085205
# Physicial loss of s is: 0.005523817613720894
# Iteration is: 1920
# Total loss is: 2771.7451171875
# Data loss is: 0.0027674066368490458
# Physicial loss of p is: 0.24887271225452423
# Physicial loss of s is: 0.005593216512352228
# Iteration is: 1930
# Total loss is: 2763.016357421875
# Data loss is: 0.0027585739735513926
# Physicial loss of p is: 0.25673630833625793
# Physicial loss of s is: 0.0056113735772669315
# Iteration is: 1940
# Total loss is: 2753.943359375
# Data loss is: 0.0027493839152157307
# Physicial loss of p is: 0.2652125060558319
# Physicial loss of s is: 0.00564966956153512
# Iteration is: 1950
# Total loss is: 2744.4677734375
# Data loss is: 0.0027397668454796076
# Physicial loss of p is: 0.272670716047287
# Physicial loss of s is: 0.005743227433413267
# Iteration is: 1960
# Total loss is: 2734.50341796875
# Data loss is: 0.002729657804593444
# Physicial loss of p is: 0.2863751947879791
# Physicial loss of s is: 0.005775947589427233
# Iteration is: 1970
# Total loss is: 2724.02294921875
# Data loss is: 0.002718998584896326
# Physicial loss of p is: 0.29802748560905457
# Physicial loss of s is: 0.005900263786315918
# Iteration is: 1980
# Total loss is: 2712.96728515625
# Data loss is: 0.0027077505365014076
# Physicial loss of p is: 0.316226989030838
# Physicial loss of s is: 0.005989858414977789
# Iteration is: 1990
# Total loss is: 2701.3427734375
# Data loss is: 0.00269590737298131
# Physicial loss of p is: 0.3340055048465729
# Physicial loss of s is: 0.006128895096480846
# Iteration is: 2000
# Total loss is: 2689.177490234375
# Data loss is: 0.0026835044845938683
# Physicial loss of p is: 0.35218796133995056
# Physicial loss of s is: 0.006285350304096937
# Iteration is: 2010
# Total loss is: 2676.5498046875
# Data loss is: 0.00267062708735466
# Physicial loss of p is: 0.37114909291267395
# Physicial loss of s is: 0.006437237374484539
# Iteration is: 2020
# Total loss is: 2663.58447265625
# Data loss is: 0.0026574069634079933
# Physicial loss of p is: 0.3902905285358429
# Physicial loss of s is: 0.006564802955836058
# Iteration is: 2030
# Total loss is: 2650.43359375
# Data loss is: 0.002644006861373782
# Physicial loss of p is: 0.40913981199264526
# Physicial loss of s is: 0.006642248015850782
# Iteration is: 2040
# Total loss is: 2637.256591796875
# Data loss is: 0.0026305948849767447
# Physicial loss of p is: 0.42589935660362244
# Physicial loss of s is: 0.00665972288697958
# Iteration is: 2050
# Total loss is: 2624.1962890625
# Data loss is: 0.0026173200458288193
# Physicial loss of p is: 0.4405803382396698
# Physicial loss of s is: 0.006595839746296406
# Iteration is: 2060
# Total loss is: 2611.353759765625
# Data loss is: 0.002604287350550294
# Physicial loss of p is: 0.4525524377822876
# Physicial loss of s is: 0.006448760163038969
# Iteration is: 2070
# Total loss is: 2598.779296875
# Data loss is: 0.0025915487203747034
# Physicial loss of p is: 0.46173739433288574
# Physicial loss of s is: 0.006222343537956476
# Iteration is: 2080
# Total loss is: 2586.479248046875
# Data loss is: 0.0025791104417294264
# Physicial loss of p is: 0.4681481420993805
# Physicial loss of s is: 0.00592847028747201
# Iteration is: 2090
# Total loss is: 2574.426025390625
# Data loss is: 0.0025669450405985117
# Physicial loss of p is: 0.47181594371795654
# Physicial loss of s is: 0.005583111196756363
# Iteration is: 2100
# Total loss is: 2562.5791015625
# Data loss is: 0.0025550120044499636
# Physicial loss of p is: 0.47271671891212463
# Physicial loss of s is: 0.005203193984925747
# Iteration is: 2110
# Total loss is: 2550.899658203125
# Data loss is: 0.002543276408687234
# Physicial loss of p is: 0.47071373462677
# Physicial loss of s is: 0.004804351832717657
# Iteration is: 2120
# Total loss is: 2539.35693359375
# Data loss is: 0.002531710546463728
# Physicial loss of p is: 0.46556368470191956
# Physicial loss of s is: 0.004399431403726339
# Iteration is: 2130
# Total loss is: 2527.931884765625
# Data loss is: 0.0025203032419085503
# Physicial loss of p is: 0.4568179249763489
# Physicial loss of s is: 0.004000461660325527
# Iteration is: 2140
# Total loss is: 2516.613525390625
# Data loss is: 0.002509051701053977
# Physicial loss of p is: 0.44383761286735535
# Physicial loss of s is: 0.003620031988248229
# Iteration is: 2150
# Total loss is: 2505.395751953125
# Data loss is: 0.002497962908819318
# Physicial loss of p is: 0.42578059434890747
# Physicial loss of s is: 0.0032752426341176033
# Iteration is: 2160
# Total loss is: 2494.274658203125
# Data loss is: 0.002487047342583537
# Physicial loss of p is: 0.40173494815826416
# Physicial loss of s is: 0.0029916518833488226
# Iteration is: 2170
# Total loss is: 2483.251220703125
# Data loss is: 0.0024763166438788176
# Physicial loss of p is: 0.3711225092411041
# Physicial loss of s is: 0.0028064812067896128
# Iteration is: 2180
# Total loss is: 2472.33642578125
# Data loss is: 0.0024657826870679855
# Physicial loss of p is: 0.3344784677028656
# Physicial loss of s is: 0.002765744226053357
# Iteration is: 2190
# Total loss is: 2461.56591796875
# Data loss is: 0.002455458976328373
# Physicial loss of p is: 0.2944490313529968
# Physicial loss of s is: 0.002908494556322694
# Iteration is: 2200
# Total loss is: 2451.002685546875
# Data loss is: 0.002445356920361519
# Physicial loss of p is: 0.2562401592731476
# Physicial loss of s is: 0.0032393515575677156
# Iteration is: 2210
# Total loss is: 2443.430419921875
# Data loss is: 0.0024354946799576283
# Physicial loss of p is: 0.5685941576957703
# Physicial loss of s is: 0.003570978995412588
# Iteration is: 2220
# Total loss is: 2431.06689453125
# Data loss is: 0.0024258652701973915
# Physicial loss of p is: 0.2224956899881363
# Physicial loss of s is: 0.0038152048364281654
# Iteration is: 2230
# Total loss is: 2421.66748046875
# Data loss is: 0.0024165029171854258
# Physicial loss of p is: 0.21913832426071167
# Physicial loss of s is: 0.003974173218011856
# Iteration is: 2240
# Total loss is: 2412.542236328125
# Data loss is: 0.0024074078537523746
# Physicial loss of p is: 0.2144242823123932
# Physicial loss of s is: 0.004167482722550631
# Iteration is: 2250
# Total loss is: 2403.687255859375
# Data loss is: 0.002398581011220813
# Physicial loss of p is: 0.2139141708612442
# Physicial loss of s is: 0.004296635743230581
# Iteration is: 2260
# Total loss is: 2395.11865234375
# Data loss is: 0.002390019129961729
# Physicial loss of p is: 0.21599669754505157
# Physicial loss of s is: 0.004407638218253851
# Iteration is: 2270
# Total loss is: 2386.820556640625
# Data loss is: 0.0023817182518541813
# Physicial loss of p is: 0.21301662921905518
# Physicial loss of s is: 0.004564221017062664
# Iteration is: 2280
# Total loss is: 2378.785400390625
# Data loss is: 0.002373672788962722
# Physicial loss of p is: 0.2153819501399994
# Physicial loss of s is: 0.004641156177967787
# Iteration is: 2290
# Total loss is: 2371.011962890625
# Data loss is: 0.0023658741265535355
# Physicial loss of p is: 0.21761000156402588
# Physicial loss of s is: 0.004709167871624231
# Iteration is: 2300
# Total loss is: 2363.483642578125
# Data loss is: 0.0023583141155540943
# Physicial loss of p is: 0.21876877546310425
# Physicial loss of s is: 0.00476917065680027
# Iteration is: 2310
# Total loss is: 2356.189208984375
# Data loss is: 0.0023509827442467213
# Physicial loss of p is: 0.21989277005195618
# Physicial loss of s is: 0.004811887629330158
# Iteration is: 2320
# Total loss is: 2349.11572265625
# Data loss is: 0.0023438693024218082
# Physicial loss of p is: 0.22104337811470032
# Physicial loss of s is: 0.0048364601098001
# Iteration is: 2330
# Total loss is: 2342.25146484375
# Data loss is: 0.002336962381377816
# Physicial loss of p is: 0.22213879227638245
# Physicial loss of s is: 0.004846842493861914
# Iteration is: 2340
# Total loss is: 2335.58447265625
# Data loss is: 0.0023302508052438498
# Physicial loss of p is: 0.22316282987594604
# Physicial loss of s is: 0.00484630698338151
# Iteration is: 2350
# Total loss is: 2329.103271484375
# Data loss is: 0.002323722466826439
# Physicial loss of p is: 0.22413265705108643
# Physicial loss of s is: 0.004836857784539461
# Iteration is: 2360
# Total loss is: 2322.79541015625
# Data loss is: 0.0023173666559159756
# Physicial loss of p is: 0.22509296238422394
# Physicial loss of s is: 0.004820006899535656
# Iteration is: 2370
# Total loss is: 2316.650146484375
# Data loss is: 0.0023111721966415644
# Physicial loss of p is: 0.2260788381099701
# Physicial loss of s is: 0.004796839784830809
# Iteration is: 2380
# Total loss is: 2310.657470703125
# Data loss is: 0.002305128611624241
# Physicial loss of p is: 0.22711268067359924
# Physicial loss of s is: 0.004768048413097858
# Iteration is: 2390
# Total loss is: 2304.806884765625
# Data loss is: 0.0022992254234850407
# Physicial loss of p is: 0.22820602357387543
# Physicial loss of s is: 0.004734122660011053
# Iteration is: 2400
# Total loss is: 2299.088623046875
# Data loss is: 0.002293454483151436
# Physicial loss of p is: 0.2293604612350464
# Physicial loss of s is: 0.004695381037890911
# Iteration is: 2410
# Total loss is: 2293.495361328125
# Data loss is: 0.0022878069430589676
# Physicial loss of p is: 0.23057512938976288
# Physicial loss of s is: 0.004651988856494427
# Iteration is: 2420
# Total loss is: 2288.017333984375
# Data loss is: 0.0022822737228125334
# Physicial loss of p is: 0.23184211552143097
# Physicial loss of s is: 0.004604090005159378
# Iteration is: 2430
# Total loss is: 2282.6494140625
# Data loss is: 0.0022768499329686165
# Physicial loss of p is: 0.23315449059009552
# Physicial loss of s is: 0.004551729653030634
# Iteration is: 2440
# Total loss is: 2277.38525390625
# Data loss is: 0.0022715290542691946
# Physicial loss of p is: 0.2345021367073059
# Physicial loss of s is: 0.004494979977607727
# Iteration is: 2450
# Total loss is: 2272.21923828125
# Data loss is: 0.0022663057316094637
# Physicial loss of p is: 0.2358783334493637
# Physicial loss of s is: 0.004433912690728903
# Iteration is: 2460
# Total loss is: 2267.147705078125
# Data loss is: 0.0022611760068684816
# Physicial loss of p is: 0.23727233707904816
# Physicial loss of s is: 0.004368580412119627
# Iteration is: 2470
# Total loss is: 2262.16552734375
# Data loss is: 0.002256135456264019
# Physicial loss of p is: 0.23867328464984894
# Physicial loss of s is: 0.004299078602343798
# Iteration is: 2480
# Total loss is: 2257.27197265625
# Data loss is: 0.002251183148473501
# Physicial loss of p is: 0.24007311463356018
# Physicial loss of s is: 0.004225504584610462
# Iteration is: 2490
# Total loss is: 2252.463623046875
# Data loss is: 0.002246315823867917
# Physicial loss of p is: 0.24146167933940887
# Physicial loss of s is: 0.004147973842918873
# Iteration is: 2500
# Total loss is: 2247.73828125
# Data loss is: 0.0022415316198021173
# Physicial loss of p is: 0.24282924830913544
# Physicial loss of s is: 0.004066613502800465
# Iteration is: 2510
# Total loss is: 2243.095458984375
# Data loss is: 0.0022368296049535275
# Physicial loss of p is: 0.24416793882846832
# Physicial loss of s is: 0.003981560468673706
# Iteration is: 2520
# Total loss is: 2238.533935546875
# Data loss is: 0.0022322090808302164
# Physicial loss of p is: 0.24546730518341064
# Physicial loss of s is: 0.0038929723668843508
# Iteration is: 2530
# Total loss is: 2234.052001953125
# Data loss is: 0.002227668184787035
# Physicial loss of p is: 0.2467186003923416
# Physicial loss of s is: 0.0038010149728506804
# Iteration is: 2540
# Total loss is: 2229.64892578125
# Data loss is: 0.0022232066839933395
# Physicial loss of p is: 0.2479103058576584
# Physicial loss of s is: 0.0037058645393699408
# Iteration is: 2550
# Total loss is: 2225.32373046875
# Data loss is: 0.002218823879957199
# Physicial loss of p is: 0.24903526902198792
# Physicial loss of s is: 0.003607677761465311
# Iteration is: 2560
# Total loss is: 2221.075439453125
# Data loss is: 0.0022145183756947517
# Physicial loss of p is: 0.25008469820022583
# Physicial loss of s is: 0.003506632521748543
# Iteration is: 2570
# Total loss is: 2216.902099609375
# Data loss is: 0.0022102887742221355
# Physicial loss of p is: 0.25104549527168274
# Physicial loss of s is: 0.0034029067028313875
# Iteration is: 2580
# Total loss is: 2212.801513671875
# Data loss is: 0.0022061332128942013
# Physicial loss of p is: 0.2519131898880005
# Physicial loss of s is: 0.0032966560684144497
# Iteration is: 2590
# Total loss is: 2208.773193359375
# Data loss is: 0.0022020507603883743
# Physicial loss of p is: 0.25267523527145386
# Physicial loss of s is: 0.003188061760738492
# Iteration is: 2600
# Total loss is: 2204.814453125
# Data loss is: 0.0021980388555675745
# Physicial loss of p is: 0.2533332407474518
# Physicial loss of s is: 0.0030771982856094837
# Iteration is: 2610
# Total loss is: 2200.92333984375
# Data loss is: 0.0021940956357866526
# Physicial loss of p is: 0.2544071078300476
# Physicial loss of s is: 0.002960247453302145
# Iteration is: 2620
# Total loss is: 2197.206298828125
# Data loss is: 0.0021902204025536776
# Physicial loss of p is: 0.26748913526535034
# Physicial loss of s is: 0.0028135310858488083
# Iteration is: 2630
# Total loss is: 2193.650146484375
# Data loss is: 0.002186416881158948
# Physicial loss of p is: 0.28490668535232544
# Physicial loss of s is: 0.002667049178853631
# Iteration is: 2640
# Total loss is: 2189.765869140625
# Data loss is: 0.002182678086683154
# Physicial loss of p is: 0.2560676336288452
# Physicial loss of s is: 0.0026089148595929146
# Iteration is: 2650
# Total loss is: 2186.193359375
# Data loss is: 0.0021790063474327326
# Physicial loss of p is: 0.2585985064506531
# Physicial loss of s is: 0.0025197435170412064
# Iteration is: 2660
# Total loss is: 2182.56298828125
# Data loss is: 0.00217539444565773
# Physicial loss of p is: 0.256978303194046
# Physicial loss of s is: 0.0023806393146514893
# Iteration is: 2670
# Total loss is: 2179.06640625
# Data loss is: 0.0021718365605920553
# Physicial loss of p is: 0.25942492485046387
# Physicial loss of s is: 0.002272505545988679
# Iteration is: 2680
# Total loss is: 2175.60693359375
# Data loss is: 0.0021683278027921915
# Physicial loss of p is: 0.2580646276473999
# Physicial loss of s is: 0.0021865563467144966
# Iteration is: 2690
# Total loss is: 2172.197998046875
# Data loss is: 0.0021648667752742767
# Physicial loss of p is: 0.2586347162723541
# Physicial loss of s is: 0.002087072003632784
# Iteration is: 2700
# Total loss is: 2168.83203125
# Data loss is: 0.0021614497527480125
# Physicial loss of p is: 0.25922393798828125
# Physicial loss of s is: 0.001984516391530633
# Iteration is: 2710
# Total loss is: 2165.507568359375
# Data loss is: 0.002158073941245675
# Physicial loss of p is: 0.25935253500938416
# Physicial loss of s is: 0.0018857866525650024
# Iteration is: 2720
# Total loss is: 2162.22119140625
# Data loss is: 0.002154737710952759
# Physicial loss of p is: 0.2599203586578369
# Physicial loss of s is: 0.0017842997331172228
# Iteration is: 2730
# Total loss is: 2159.246826171875
# Data loss is: 0.002151440130546689
# Physicial loss of p is: 0.2888103425502777
# Physicial loss of s is: 0.0016666469164192677
# Iteration is: 2740
# Total loss is: 2155.848876953125
# Data loss is: 0.0021481821313500404
# Physicial loss of p is: 0.26728060841560364
# ...
# Physicial loss of p is: 0.011987504549324512
# Physicial loss of s is: 0.006308272015303373
# Iteration is: 99130
# Total loss is: 128.48989868164062
# Data loss is: 1.392712783854222e-05
# Physicial loss of p is: 0.009427131153643131
# Physicial loss of s is: 0.00662300456315279
# Iteration is: 99140
# Total loss is: 83.79912567138672
# Data loss is: 1.0669720722944476e-05
# Physicial loss of p is: 0.0030132830142974854
# Physicial loss of s is: 0.0065216487273573875
# Iteration is: 99150
# Total loss is: 145.65127563476562
# Data loss is: 1.0139020560018253e-05
# Physicial loss of p is: 0.012031960301101208
# Physicial loss of s is: 0.006316399667412043
# Iteration is: 99160
# Total loss is: 87.40113830566406
# Data loss is: 1.3391133506956976e-05
# Physicial loss of p is: 0.0026754303835332394
# Physicial loss of s is: 0.006361088715493679
# Iteration is: 99170
# Total loss is: 102.09590911865234
# Data loss is: 1.4690224816149566e-05
# Physicial loss of p is: 0.005038375034928322
# Physicial loss of s is: 0.006210876163095236
# Iteration is: 99180
# Total loss is: 171.88401794433594
# Data loss is: 1.0098279744852334e-05
# Physicial loss of p is: 0.016081424430012703
# Physicial loss of s is: 0.0060808295384049416
# Iteration is: 99190
# Total loss is: 138.64202880859375
# Data loss is: 1.173479813587619e-05
# Physicial loss of p is: 0.011827065609395504
# Physicial loss of s is: 0.006139438133686781
# Iteration is: 99200
# Total loss is: 94.53910827636719
# Data loss is: 1.2001934010186233e-05
# Physicial loss of p is: 0.004057384096086025
# Physicial loss of s is: 0.006410393863916397
# Iteration is: 99210
# Total loss is: 77.05155944824219
# Data loss is: 1.2275389963178895e-05
# Physicial loss of p is: 0.0013037833850830793
# Physicial loss of s is: 0.00619805883616209
# Iteration is: 99220
# Total loss is: 118.13774108886719
# Data loss is: 1.0960744475596584e-05
# Physicial loss of p is: 0.008007551543414593
# Physicial loss of s is: 0.006309585180133581
# Iteration is: 99230
# Total loss is: 80.3263931274414
# Data loss is: 1.0805826605064794e-05
# Physicial loss of p is: 0.0023576177190989256
# Physicial loss of s is: 0.0064163850620388985
# Iteration is: 99240
# Total loss is: 108.55354309082031
# Data loss is: 1.0394484888820443e-05
# Physicial loss of p is: 0.00631674425676465
# Physicial loss of s is: 0.006252369377762079
# Iteration is: 99250
# Total loss is: 87.93904113769531
# Data loss is: 1.1135298336739652e-05
# Physicial loss of p is: 0.003015735652297735
# Physicial loss of s is: 0.006204779725521803
# Iteration is: 99260
# Total loss is: 221.71697998046875
# Data loss is: 1.258381780644413e-05
# Physicial loss of p is: 0.02523893304169178
# Physicial loss of s is: 0.006182777229696512
# Iteration is: 99270
# Total loss is: 159.34518432617188
# Data loss is: 1.3431599654722959e-05
# Physicial loss of p is: 0.01396663673222065
# Physicial loss of s is: 0.00647657411172986
# Iteration is: 99280
# Total loss is: 88.18339538574219
# Data loss is: 1.8776556316879578e-05
# Physicial loss of p is: 0.0022951511200517416
# Physicial loss of s is: 0.00608971668407321
# Iteration is: 99290
# Total loss is: 206.52853393554688
# Data loss is: 2.1577192455879413e-05
# Physicial loss of p is: 0.020143212750554085
# Physicial loss of s is: 0.006550456862896681
# Iteration is: 99300
# Total loss is: 82.12580108642578
# Data loss is: 1.0866445336432662e-05
# Physicial loss of p is: 0.0022224599961191416
# Physicial loss of s is: 0.006145660765469074
# Iteration is: 99310
# Total loss is: 108.18399047851562
# Data loss is: 1.216581222251989e-05
# Physicial loss of p is: 0.005975967738777399
# Physicial loss of s is: 0.0061477599665522575
# Iteration is: 99320
# Total loss is: 207.7261962890625
# Data loss is: 1.1253184311499353e-05
# Physicial loss of p is: 0.022088026627898216
# Physicial loss of s is: 0.0063105132430791855
# Iteration is: 99330
# Total loss is: 140.83001708984375
# Data loss is: 1.0760531949927099e-05
# Physicial loss of p is: 0.011051523499190807
# Physicial loss of s is: 0.006287253927439451
# Iteration is: 99340
# Total loss is: 88.83029174804688
# Data loss is: 1.0805705642269459e-05
# Physicial loss of p is: 0.003529782872647047
# Physicial loss of s is: 0.00646083103492856
# Iteration is: 99350
# Total loss is: 116.61915588378906
# Data loss is: 1.3971505723020528e-05
# Physicial loss of p is: 0.007447282783687115
# Physicial loss of s is: 0.0065376609563827515
# Iteration is: 99360
# Total loss is: 153.48403930664062
# Data loss is: 1.2779823009623215e-05
# Physicial loss of p is: 0.012893931940197945
# Physicial loss of s is: 0.006041062995791435
# Iteration is: 99370
# Total loss is: 97.72148132324219
# Data loss is: 1.3189424862503074e-05
# Physicial loss of p is: 0.004628228023648262
# Physicial loss of s is: 0.0064708758145570755
# Iteration is: 99380
# Total loss is: 97.71438598632812
# Data loss is: 1.2714878721453715e-05
# Physicial loss of p is: 0.004851276054978371
# Physicial loss of s is: 0.006147561129182577
# Iteration is: 99390
# Total loss is: 136.86550903320312
# Data loss is: 1.0088823728438001e-05
# Physicial loss of p is: 0.01047823391854763
# Physicial loss of s is: 0.006264353170990944
# Iteration is: 99400
# Total loss is: 83.34196472167969
# Data loss is: 1.1496348633954767e-05
# Physicial loss of p is: 0.002415883354842663
# Physicial loss of s is: 0.0063791172578930855
# Iteration is: 99410
# Total loss is: 135.81629943847656
# Data loss is: 1.3214116734161507e-05
# Physicial loss of p is: 0.011032093316316605
# Physicial loss of s is: 0.006137102376669645
# Iteration is: 99420
# Total loss is: 130.846435546875
# Data loss is: 1.0053641744889319e-05
# Physicial loss of p is: 0.009549143724143505
# Physicial loss of s is: 0.006197754293680191
# Iteration is: 99430
# Total loss is: 87.27360534667969
# Data loss is: 1.1131125575047918e-05
# Physicial loss of p is: 0.003165743313729763
# Physicial loss of s is: 0.006415836047381163
# Iteration is: 99440
# Total loss is: 118.15162658691406
# Data loss is: 1.3033712093601935e-05
# Physicial loss of p is: 0.008061625063419342
# Physicial loss of s is: 0.006572934333235025
# Iteration is: 99450
# Total loss is: 178.76974487304688
# Data loss is: 1.1242590517213102e-05
# Physicial loss of p is: 0.01786685176193714
# Physicial loss of s is: 0.006607163697481155
# Iteration is: 99460
# Total loss is: 159.20620727539062
# Data loss is: 1.095354491553735e-05
# Physicial loss of p is: 0.015067420899868011
# Physicial loss of s is: 0.006164131686091423
# Iteration is: 99470
# Total loss is: 96.2483139038086
# Data loss is: 1.160787451226497e-05
# Physicial loss of p is: 0.004226344637572765
# Physicial loss of s is: 0.006333049386739731
# Iteration is: 99480
# Total loss is: 85.17450714111328
# Data loss is: 1.4079781067266595e-05
# Physicial loss of p is: 0.002038503298535943
# Physicial loss of s is: 0.006296646781265736
# Iteration is: 99490
# Total loss is: 133.95571899414062
# Data loss is: 1.1109230399597436e-05
# Physicial loss of p is: 0.010421511717140675
# Physicial loss of s is: 0.006292958278208971
# Iteration is: 99500
# Total loss is: 72.33222198486328
# Data loss is: 1.0925413334916811e-05
# Physicial loss of p is: 0.0006903035682626069
# Physicial loss of s is: 0.006280407775193453
# Iteration is: 99510
# Total loss is: 169.10006713867188
# Data loss is: 1.4921938600309659e-05
# Physicial loss of p is: 0.015460031107068062
# Physicial loss of s is: 0.006532188504934311
# Iteration is: 99520
# Total loss is: 182.25233459472656
# Data loss is: 1.8595566871226765e-05
# Physicial loss of p is: 0.016687948256731033
# Physicial loss of s is: 0.00629756273701787
# Iteration is: 99530
# Total loss is: 88.00061798095703
# Data loss is: 2.0818701159441844e-05
# Physicial loss of p is: 0.00137221603654325
# Physicial loss of s is: 0.0061795348301529884
# Iteration is: 99540
# Total loss is: 126.26637268066406
# Data loss is: 1.318786326010013e-05
# Physicial loss of p is: 0.008497691713273525
# Physicial loss of s is: 0.00614589499309659
# Iteration is: 99550
# Total loss is: 168.40631103515625
# Data loss is: 1.1053183698095381e-05
# Physicial loss of p is: 0.015808384865522385
# Physicial loss of s is: 0.00652740616351366
# Iteration is: 99560
# Total loss is: 128.6409149169922
# Data loss is: 1.2165910447947681e-05
# Physicial loss of p is: 0.008857800625264645
# Physicial loss of s is: 0.006172503344714642
# Iteration is: 99570
# Total loss is: 76.67774963378906
# Data loss is: 1.0396462130302098e-05
# Physicial loss of p is: 0.0014830827713012695
# Physicial loss of s is: 0.00622979924082756
# Iteration is: 99580
# Total loss is: 121.35175323486328
# Data loss is: 1.1297142009425443e-05
# Physicial loss of p is: 0.008916896767914295
# Physicial loss of s is: 0.00613508652895689
# Iteration is: 99590
# Total loss is: 116.35806274414062
# Data loss is: 1.0625854883983266e-05
# Physicial loss of p is: 0.007889918982982635
# Physicial loss of s is: 0.006001934874802828
# Iteration is: 99600
# Total loss is: 75.81656646728516
# Data loss is: 1.0405172361060977e-05
# Physicial loss of p is: 0.001241150195710361
# Physicial loss of s is: 0.006245402153581381
# Iteration is: 99610
# Total loss is: 155.94900512695312
# Data loss is: 1.1203546819160692e-05
# Physicial loss of p is: 0.01397382840514183
# Physicial loss of s is: 0.006465733516961336
# Iteration is: 99620
# Total loss is: 71.37125396728516
# Data loss is: 1.0250733794237021e-05
# Physicial loss of p is: 0.0006407359032891691
# Physicial loss of s is: 0.006270715966820717
# Iteration is: 99630
# Total loss is: 204.74139404296875
# Data loss is: 1.1698212802002672e-05
# Physicial loss of p is: 0.022059522569179535
# Physicial loss of s is: 0.0066163791343569756
# Iteration is: 99640
# Total loss is: 191.60629272460938
# Data loss is: 1.1593164344958495e-05
# Physicial loss of p is: 0.019785471260547638
# Physicial loss of s is: 0.00620013615116477
# Iteration is: 99650
# Total loss is: 120.38923645019531
# Data loss is: 1.1737550266843755e-05
# Physicial loss of p is: 0.007882374338805676
# Physicial loss of s is: 0.006386744324117899
# Iteration is: 99660
# Total loss is: 71.92498016357422
# Data loss is: 1.086349948309362e-05
# Physicial loss of p is: 0.0005884606507606804
# Physicial loss of s is: 0.0062210094183683395
# Iteration is: 99670
# Total loss is: 129.25872802734375
# Data loss is: 1.1383494893379975e-05
# Physicial loss of p is: 0.009973802603781223
# Physicial loss of s is: 0.006152545101940632
# Iteration is: 99680
# Total loss is: 86.88228607177734
# Data loss is: 1.1953456123592332e-05
# Physicial loss of p is: 0.003294222056865692
# Physicial loss of s is: 0.006443332880735397
# Iteration is: 99690
# Total loss is: 108.17192840576172
# Data loss is: 1.0084474524774123e-05
# Physicial loss of p is: 0.006152306217700243
# Physicial loss of s is: 0.006167194340378046
# Iteration is: 99700
# Total loss is: 136.87210083007812
# Data loss is: 1.4770154848520178e-05
# Physicial loss of p is: 0.010414927266538143
# Physicial loss of s is: 0.005987843498587608
# Iteration is: 99710
# Total loss is: 207.31082153320312
# Data loss is: 1.3986965313961264e-05
# Physicial loss of p is: 0.021260710433125496
# Physicial loss of s is: 0.006533087696880102
# Iteration is: 99720
# Total loss is: 139.65652465820312
# Data loss is: 1.1324410479573999e-05
# Physicial loss of p is: 0.010700109414756298
# Physicial loss of s is: 0.006122070364654064
# Iteration is: 99730
# Total loss is: 80.08454895019531
# Data loss is: 1.09434131445596e-05
# Physicial loss of p is: 0.0018462629523128271
# Physicial loss of s is: 0.006288452073931694
# Iteration is: 99740
# Total loss is: 93.78231811523438
# Data loss is: 1.1010724847437814e-05
# Physicial loss of p is: 0.004436437971889973
# Physicial loss of s is: 0.006141133140772581
# Iteration is: 99750
# Total loss is: 121.82682800292969
# Data loss is: 1.1656419701466803e-05
# Physicial loss of p is: 0.008389142341911793
# Physicial loss of s is: 0.006010199896991253
# Iteration is: 99760
# Total loss is: 78.41513061523438
# Data loss is: 1.0591487807687372e-05
# Physicial loss of p is: 0.001837381743825972
# Physicial loss of s is: 0.0063447505235672
# Iteration is: 99770
# Total loss is: 102.79795837402344
# Data loss is: 1.2013825653411914e-05
# Physicial loss of p is: 0.005179811734706163
# Physicial loss of s is: 0.006301249377429485
# Iteration is: 99780
# Total loss is: 95.19512176513672
# Data loss is: 1.1369485036993865e-05
# Physicial loss of p is: 0.004194722510874271
# Physicial loss of s is: 0.006385671906173229
# Iteration is: 99790
# Total loss is: 215.6781005859375
# Data loss is: 1.2008189514745027e-05
# Physicial loss of p is: 0.022895418107509613
# Physicial loss of s is: 0.006365546956658363
# Iteration is: 99800
# Total loss is: 174.24160766601562
# Data loss is: 1.1041149264201522e-05
# Physicial loss of p is: 0.016200149431824684
# Physicial loss of s is: 0.0064146267250180244
# Iteration is: 99810
# Total loss is: 110.72044372558594
# Data loss is: 1.2702262210950721e-05
# Physicial loss of p is: 0.00629617553204298
# Physicial loss of s is: 0.00628314632922411
# Iteration is: 99820
# Total loss is: 79.34486389160156
# Data loss is: 1.2629131560970563e-05
# Physicial loss of p is: 0.0016496166354045272
# Physicial loss of s is: 0.006139043718576431
# Iteration is: 99830
# Total loss is: 148.00291442871094
# Data loss is: 1.0603955161059275e-05
# Physicial loss of p is: 0.01266308780759573
# Physicial loss of s is: 0.005950433202087879
# Iteration is: 99840
# Total loss is: 72.74087524414062
# Data loss is: 1.0738743185356725e-05
# Physicial loss of p is: 0.0008779552299529314
# Physicial loss of s is: 0.006119345314800739
# Iteration is: 99850
# Total loss is: 197.43795776367188
# Data loss is: 1.2799771866411902e-05
# Physicial loss of p is: 0.02067389339208603
# Physicial loss of s is: 0.006138581782579422
# Iteration is: 99860
# Total loss is: 124.86843872070312
# Data loss is: 1.1123336662421934e-05
# Physicial loss of p is: 0.00846127886325121
# Physicial loss of s is: 0.006110661197453737
# Iteration is: 99870
# Total loss is: 83.86305236816406
# Data loss is: 1.1069892934756353e-05
# Physicial loss of p is: 0.0024703049566596746
# Physicial loss of s is: 0.006226350087672472
# Iteration is: 99880
# Total loss is: 98.33499145507812
# Data loss is: 1.314142718911171e-05
# Physicial loss of p is: 0.005218707490712404
# Physicial loss of s is: 0.0060584284365177155
# Iteration is: 99890
# Total loss is: 119.62004852294922
# Data loss is: 1.0214928806817625e-05
# Physicial loss of p is: 0.007735993713140488
# Physicial loss of s is: 0.006189547944813967
# Iteration is: 99900
# Total loss is: 109.82958984375
# Data loss is: 1.0647753697412554e-05
# Physicial loss of p is: 0.006873197387903929
# Physicial loss of s is: 0.006133549381047487
# Iteration is: 99910
# Total loss is: 77.58905029296875
# Data loss is: 1.4773218936170451e-05
# Physicial loss of p is: 0.0009119648020714521
# Physicial loss of s is: 0.006139477714896202
# Iteration is: 99920
# Total loss is: 147.2722930908203
# Data loss is: 1.6959373169811442e-05
# Physicial loss of p is: 0.010903551243245602
# Physicial loss of s is: 0.006333212833851576
# Iteration is: 99930
# Total loss is: 175.35992431640625
# Data loss is: 1.6281248463201337e-05
# Physicial loss of p is: 0.016491202637553215
# Physicial loss of s is: 0.006133717484772205
# Iteration is: 99940
# Total loss is: 109.160888671875
# Data loss is: 1.440116193407448e-05
# Physicial loss of p is: 0.006453222129493952
# Physicial loss of s is: 0.006518515292555094
# Iteration is: 99950
# Total loss is: 128.32737731933594
# Data loss is: 1.3268992006487679e-05
# Physicial loss of p is: 0.009563082829117775
# Physicial loss of s is: 0.0059401653707027435
# Iteration is: 99960
# Total loss is: 96.26404571533203
# Data loss is: 1.1301976883260068e-05
# Physicial loss of p is: 0.00473162392154336
# Physicial loss of s is: 0.006443492136895657
# Iteration is: 99970
# Total loss is: 149.05340576171875
# Data loss is: 1.2146696462878026e-05
# Physicial loss of p is: 0.012530638836324215
# Physicial loss of s is: 0.006231902167201042
# Iteration is: 99980
# Total loss is: 106.73274230957031
# Data loss is: 1.0387863767391536e-05
# Physicial loss of p is: 0.005783253815025091
# Physicial loss of s is: 0.006231389008462429
# Iteration is: 99990
# Total loss is: 97.28407287597656
# Data loss is: 1.2661085747822654e-05
# Physicial loss of p is: 0.005322969518601894
# Physicial loss of s is: 0.005964253563433886
# Iteration is: 100000
# Total loss is: 196.83187866210938
# Data loss is: 1.4837199159956072e-05
# Physicial loss of p is: 0.01930219493806362
# Physicial loss of s is: 0.006452809553593397
# Training time: 137.2141

# %%
it = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]
loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]
# loss_phia_list = [loss_fisa[i].numpy() for i in range(0,Nmax)]


plt.semilogy(it, np.asarray(loss_phip_list), 'r-', linewidth = 2, label = '$\phi_p$') 
plt.semilogy(it, np.asarray(loss_data_list), 'b-', linewidth = 2, label = 'Data')  

plt.semilogy(it, np.asarray(loss_phis_list), 'g-', linewidth = 2, label = '$\phi_s$')    
# plt.semilogy(it, np.asarray(loss_phia_list), 'y-', linewidth = 2, label = '$\phi_a$')       



plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
m
# Out:
# [<tf.Variable 'Variable:0' shape=(1, 1) dtype=float32, numpy=array([[-0.08753037]], dtype=float32)>]

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
T_star_tf = tf.convert_to_tensor(T_star[:len(T_exp)], dtype=tf.float32)    
u_pred = predict(T_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp=u_pred[:,0:1]
lns=u_pred[:,1:2]

p=tf.exp(lnp)
s=tf.exp(lns)

phi_p = predict(s, W_phi, b_phi)

phi_s=m[0]*phi_p*p

# %%
plt.plot(T_star_tf, p, label='Prediction P')
plt.plot(T_star_tf, s, label='Prediction S')


# for i in range(N_exp):
#     plt.plot(T_star[i*len(T_exp):(i+1)*len(T_exp)],P_star[i*len(T_exp):(i+1)*len(T_exp)],linestyle=':')

plt.scatter(T_u_train, p_train, marker='x', color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(p, phi_p, label='Prediction')

# %%
plt.plot(s, phi_p, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
Nt=10000
T_int=np.zeros(Nt)
P_int=np.zeros(Nt)
S_int=np.zeros(Nt)
A_int=np.zeros(Nt)


dt=0.0001

T_int[0]=0
# P_int[0]=np.mean(uu1) #Initial conditions
P_int[0]=np.array(p[0]) #Initial conditions
S_int[0]=np.array(s[0]) #Initial conditions



for i in range(1,Nt):

    # PSA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    # PA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)

    PHI_P=predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi)

    P_int[i]=P_int[i-1]+PHI_P*P_int[i-1]*dt
    S_int[i]=S_int[i-1]+m[0]*PHI_P*P_int[i-1]*dt
    T_int[i]=T_int[i-1]+dt

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')
# plt.plot(T_int, A_int, color='green', linestyle='--', label='Numeric integration dAdT')



plt.plot(T_star_tf, p, label='PINN Prediction P')
plt.plot(T_star_tf, s, label='PINN Prediction S')
# plt.plot(T_star_tf, a, label='PINN Prediction A')

plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
# Create and train the PySR model
model_phip = PySRRegressor(
    niterations=500,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    # unary_operators=["inv(x) = 1/x"],
    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    # constraints={"/": (-1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00001,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
    maxsize=30,
)

# %%
# Fit phi
model_phip.fit(tf.concat([p, s, a],1), phi_p)
print(model_phip)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.520e+05
# Head worker occupation: 40.1%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 569 / 7500 total iterations (7.587%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.197e+00  6.000e-03  y = (x₂ + -0.36086) * (1.6571 + x₀)
# 9           8.563e-01  1.674e-01  y = ((43.097 * (x₂ + -0.36749)) * x₀) + -2.3652
# 11          8.412e-01  8.881e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4597) * x₀) + -2.2226
# 13          8.412e-01  1.743e-05  y = (x₀ * (((x₂ * 1.2497) + -0.47636) * (0.07713 + 34.606))) +...
#                                    -2.2125
# 15          7.481e-01  5.863e-02  y = x₂ * (((x₂ * -9.2251) * x₁) + (((-0.42149 + x₂) * 76.659) ...
#                                   * x₀))
# 17          7.306e-01  1.183e-02  y = (x₂ * (((x₂ * -9.2251) * x₁) + (((-0.42149 + x₂) * 76.659)...
#                                    * x₀))) + -0.1601
# 19          6.612e-01  4.996e-02  y = 10.069 + (((-22.514 + (-7.5181 * x₂)) * x₁) + ((((x₂ + -0....
#                                   44466) * 93.526) * x₀) + -0.56047))
# 21          5.158e-01  1.241e-01  y = 15.472 + (((-45.439 + (-11.527 * x₂)) * x₁) + (((((x₂ + -0...
#                                   .46974) * 110.88) * x₀) + x₁) + 5.7663))
# 23          4.527e-01  6.528e-02  y = (6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.848 * x₂))) + (...
#                                   (x₀ * ((x₂ + -0.49001) * 116.6)) + 11.362)))) * 1.1122
# 25          4.506e-01  2.255e-03  y = (6.8747 + (((x₁ * (-64.706 + (-12.848 * x₂))) + ((((x₂ + -...
#                                   0.49001) * (116.6 + x₂)) * x₀) + 11.362)) + 13.374)) * 1.1122
# 27          4.499e-01  7.727e-04  y = (6.9829 + (((x₁ * (-64.714 + (-12.508 * (x₂ + 0.075684))))...
#                                    + (((((x₂ + -0.49377) * 116.6) + x₂) * x₀) + 11.47)) + 13.482...
#                                   )) * 1.1315
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Head worker occupation: 36.8%
# Progress: 1224 / 7500 total iterations (16.320%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.197e+00  6.000e-03  y = (x₂ + -0.36086) * (1.6571 + x₀)
# 9           8.412e-01  1.763e-01  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          8.369e-01  2.590e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4648) * (x₀ + -0.0024676)...
#                                   ) + -2.2226
# 15          7.481e-01  5.604e-02  y = x₂ * (((x₂ * -9.2251) * x₁) + (((-0.42149 + x₂) * 76.659) ...
#                                   * x₀))
# 17          7.170e-01  2.126e-02  y = x₂ * ((((x₂ * -11.723) * x₁) + x₀) + (((x₂ + -0.43702) * 9...
#                                   0.477) * x₀))
# 19          6.612e-01  4.053e-02  y = 10.069 + (((-22.514 + (-7.5181 * x₂)) * x₁) + ((((x₂ + -0....
#                                   44466) * 93.526) * x₀) + -0.56047))
# 21          4.691e-01  1.716e-01  y = 6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.848 * x₂))) + ((...
#                                   x₀ * ((x₂ + -0.49001) * 116.6)) + 11.362)))
# 23          4.526e-01  1.786e-02  y = (6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.844 * x₂))) + (...
#                                   (x₀ * ((x₂ + -0.49001) * 116.6)) + 11.362)))) * 1.1122
# 25          4.501e-01  2.823e-03  y = ((((x₁ * ((x₂ * (-12.844 + x₁)) + -64.801)) + ((x₀ * ((x₂ ...
#                                   + -0.48885) * 116.56)) + 11.319)) + 13.331) + 6.8316) * 1.1234
# 27          4.364e-01  1.537e-02  y = ((6.7997 + (13.299 + ((x₁ * (-64.747 + ((x₂ * -12.815) + x...
#                                   ₁))) + (11.287 + (((x₂ + -0.48941) * 116.61) * x₀))))) * 2.375...
#                                   8) * x₁
# 29          4.325e-01  4.484e-03  y = (((6.8747 + (13.374 + (((x₀ * ((-0.49001 + x₂) * 116.6)) +...
#                                    11.362) + (x₁ * (-64.706 + (x₂ * -12.848)))))) * 1.2453) * x₁...
#                                   ) * (1.3947 + x₁)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+05
# Head worker occupation: 33.2%
# Progress: 1866 / 7500 total iterations (24.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.197e+00  6.000e-03  y = (x₂ + -0.36086) * (1.6571 + x₀)
# 9           8.412e-01  1.763e-01  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          8.369e-01  2.590e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4648) * (x₀ + -0.0024676)...
#                                   ) + -2.2226
# 15          7.095e-01  8.254e-02  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * 97.287) * x₀)) ...
#                                   * x₂
# 17          7.080e-01  1.054e-03  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * (x₂ + 97.287)) ...
#                                   * x₀)) * x₂
# 19          6.612e-01  3.423e-02  y = 10.069 + (((-22.514 + (-7.5181 * x₂)) * x₁) + ((((x₂ + -0....
#                                   44466) * 93.526) * x₀) + -0.56047))
# 21          4.591e-01  1.823e-01  y = 6.7994 + (13.298 + ((x₁ * (-64.747 + (-12.141 * x₂))) + ((...
#                                   x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287)))
# 23          4.519e-01  7.952e-03  y = (6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.844 * x₂))) + (...
#                                   (((-0.49001 + x₂) * 116.6) * x₀) + 11.362)))) * 1.1373
# 25          4.377e-01  1.599e-02  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.141 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3409
# 27          4.354e-01  2.632e-03  y = (x₁ * (((((((x₂ + -0.48804) * (116.83 + -1.1456)) * x₀) + ...
#                                   11.287) + (x₁ * (-64.747 + (-12.141 * x₂)))) + 13.298) + 6.799...
#                                   4)) * 2.3409
# 29          4.325e-01  3.272e-03  y = (((6.8747 + (13.374 + (((x₀ * ((-0.49001 + x₂) * 116.6)) +...
#                                    11.362) + (x₁ * (-64.706 + (x₂ * -12.848)))))) * 1.2453) * x₁...
#                                   ) * (1.3947 + x₁)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.760e+05
# Head worker occupation: 32.8%
# Progress: 2526 / 7500 total iterations (33.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.131e+00  3.441e-02  y = (29.776 * x₀) * (-0.46942 + x₂)
# 9           8.412e-01  1.479e-01  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          8.368e-01  2.604e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4648) * (x₀ + -0.0024842)...
#                                   ) + -2.2226
# 15          7.095e-01  8.253e-02  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * 97.287) * x₀)) ...
#                                   * x₂
# 17          7.080e-01  1.054e-03  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * (x₂ + 97.287)) ...
#                                   * x₀)) * x₂
# 19          6.164e-01  6.930e-02  y = ((x₁ * (((-4.3012 + -5.1621) * x₂) + -23.074)) + (((-0.448...
#                                   43 + x₂) * 92.615) * x₀)) + 10.466
# 21          4.591e-01  1.472e-01  y = 6.7994 + (13.298 + ((x₁ * (-64.747 + (-12.141 * x₂))) + ((...
#                                   x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287)))
# 23          4.516e-01  8.320e-03  y = (6.7994 + (13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + ...
#                                   11.287) + (x₁ * (-64.747 + (-12.141 * x₂)))))) * 1.115
# 25          4.365e-01  1.701e-02  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3409
# 27          4.354e-01  1.257e-03  y = (x₁ * (((((((x₂ + -0.48804) * (116.83 + -1.1893)) * x₀) + ...
#                                   11.287) + (x₁ * (-64.747 + (-12.141 * x₂)))) + 13.298) + 6.799...
#                                   4)) * 2.3409
# 29          4.277e-01  8.888e-03  y = ((((6.7994 + ((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287...
#                                   ) + (x₁ * (-64.747 + (x₂ * -12.374)))) + 13.298)) * 2.257) * x...
#                                   ₁) * 2.3409) * x₁
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+05
# Head worker occupation: 32.8%
# Progress: 3169 / 7500 total iterations (42.253%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.092e-02  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 19          6.164e-01  3.462e-02  y = ((x₁ * (((-4.3012 + -5.1621) * x₂) + -23.074)) + (((-0.448...
#                                   43 + x₂) * 92.615) * x₀)) + 10.466
# 21          4.589e-01  1.476e-01  y = 6.8086 + (13.308 + ((x₁ * (-64.813 + (-11.933 * x₂))) + (1...
#                                   1.296 + (x₀ * ((x₂ + -0.48825) * 117.01)))))
# 23          4.512e-01  8.452e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.365e-01  1.657e-02  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3409
# 27          4.353e-01  1.327e-03  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (((-64....
#                                   747 + (-12.374 * x₂)) * x₁) + 0.10989)) + 13.298) + 6.7224) * ...
#                                   x₁) * 2.3409
# 29          4.277e-01  8.819e-03  y = ((((6.7994 + ((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287...
#                                   ) + (x₁ * (-64.747 + (x₂ * -12.374)))) + 13.298)) * 2.257) * x...
#                                   ₁) * 2.3409) * x₁
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+05
# Head worker occupation: 29.0%
# Progress: 3808 / 7500 total iterations (50.773%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.078e-01  5.818e-05  y = x₂ * ((((x₂ + -0.42974) * (97.292 + 0.23239)) * x₀) + ((-1...
#                                   2.349 * x₂) * x₁))
# 19          5.448e-01  1.309e-01  y = ((17.423 + (x₀ * ((x₂ + -0.48452) * 118.54))) + (x₁ * (-63...
#                                   .006 + (-12.99 * x₂)))) + 12.934
# 21          4.567e-01  8.817e-02  y = 6.8484 + ((((-65.252 + (-11.962 * x₂)) * x₁) + (11.337 + (...
#                                   x₀ * ((-0.48764 + x₂) * 118.42)))) + 13.349)
# 23          4.512e-01  6.078e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.362e-01  1.686e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.679e-03  y = ((((((-64.929 + (x₂ * -12.703)) * x₁) + (((((-0.35746 + -0...
#                                   .13282) + x₂) * 116.66) * x₀) + 11.416)) + 13.428) + 6.8516) *...
#                                    x₁) * 2.3542
# 29          4.230e-01  1.366e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.860e+05
# Head worker occupation: 29.7%
# Progress: 4433 / 7500 total iterations (59.107%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.073e-01  4.164e-04  y = x₂ * ((((x₂ + -0.42879) * (97.209 + x₂)) * x₀) + (x₁ * (-1...
#                                   2.612 * x₂)))
# 19          4.719e-01  2.023e-01  y = 13.172 + ((x₁ * ((-13.34 * x₂) + -63.133)) + (17.661 + (((...
#                                   x₂ + -0.4867) * 118.57) * x₀)))
# 21          4.566e-01  1.654e-02  y = 6.9118 + (((x₁ * ((-12.387 * x₂) + -65.266)) + (((118.53 *...
#                                    (-0.489 + x₂)) * x₀) + 11.401)) + 13.413)
# 23          4.512e-01  5.948e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.362e-01  1.686e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.679e-03  y = ((((((-64.929 + (x₂ * -12.703)) * x₁) + (((((-0.35746 + -0...
#                                   .13282) + x₂) * 116.66) * x₀) + 11.416)) + 13.428) + 6.8516) *...
#                                    x₁) * 2.3542
# 29          4.230e-01  1.366e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+05
# Head worker occupation: 32.8%
# Progress: 5065 / 7500 total iterations (67.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.073e-01  4.164e-04  y = x₂ * ((((x₂ + -0.42879) * (97.209 + x₂)) * x₀) + (x₁ * (-1...
#                                   2.612 * x₂)))
# 19          4.719e-01  2.023e-01  y = 13.172 + ((x₁ * ((-13.34 * x₂) + -63.133)) + (17.661 + (((...
#                                   x₂ + -0.4867) * 118.57) * x₀)))
# 21          4.566e-01  1.654e-02  y = 6.9118 + (((x₁ * ((-12.387 * x₂) + -65.266)) + (((118.53 *...
#                                    (-0.489 + x₂)) * x₀) + 11.401)) + 13.413)
# 23          4.512e-01  5.948e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.362e-01  1.686e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.679e-03  y = ((((((-64.929 + (x₂ * -12.703)) * x₁) + (((((-0.35746 + -0...
#                                   .13282) + x₂) * 116.66) * x₀) + 11.416)) + 13.428) + 6.8516) *...
#                                    x₁) * 2.3542
# 29          4.230e-01  1.366e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+05
# Head worker occupation: 33.4%
# Progress: 5709 / 7500 total iterations (76.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.918e-01  3.025e-02  y = ((((x₂ + -0.4056) * 29.752) * 1.8782) * (x₀ + -0.038143)) ...
#                                   + -2.0602
# 15          7.079e-01  5.600e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.073e-01  4.164e-04  y = x₂ * ((((x₂ + -0.42879) * (97.209 + x₂)) * x₀) + (x₁ * (-1...
#                                   2.612 * x₂)))
# 19          4.719e-01  2.023e-01  y = 13.172 + ((x₁ * ((-13.34 * x₂) + -63.133)) + (17.661 + (((...
#                                   x₂ + -0.4867) * 118.57) * x₀)))
# 21          4.545e-01  1.884e-02  y = 13.058 + ((x₁ * ((-12.161 * x₂) + -63.259)) + (17.547 + ((...
#                                   ((-0.49053 + x₂) * 118.81) + x₀) * x₀)))
# 23          4.502e-01  4.741e-03  y = (13.058 + ((x₁ * ((-12.161 * x₂) + -63.259)) + (17.547 + (...
#                                   (((-0.49053 + x₂) * 118.81) + x₀) * x₀)))) * 1.0595
# 25          4.362e-01  1.577e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.688e-03  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * (1.794...
#                                   8 + x₁)
# 29          4.230e-01  1.365e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+05
# Head worker occupation: 34.0%
# Progress: 6341 / 7500 total iterations (84.547%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.143e-02  y = (-9.3086 + (19.967 * x₂)) * x₀
# 9           8.412e-01  9.084e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.916e-01  3.040e-02  y = ((((x₂ + -0.4056) * 29.752) * 1.8782) * (x₀ + -0.038143)) ...
#                                   + -2.0326
# 15          7.079e-01  5.585e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          5.141e-01  1.599e-01  y = ((x₁ * (-75.369 + (-12.187 * x₂))) + (((x₂ + -0.50164) * 1...
#                                   20.43) * x₀)) + 36.683
# 19          4.565e-01  5.950e-02  y = ((x₁ * (-75.081 + (x₂ * -14.358))) + (((-0.56954 + (1.1589...
#                                    * x₂)) * 113.34) * x₀)) + 36.744
# 21          4.321e-01  2.739e-02  y = ((x₀ * ((-0.48463 + x₂) * 119.79)) + (x₁ * ((-80.753 + (x₂...
#                                    * (x₂ * -12.525))) * x₁))) + 16.347
# 23          4.284e-01  4.334e-03  y = ((x₀ * ((-0.48463 + x₂) * 119.79)) + (x₁ * ((-80.753 + ((x...
#                                   ₂ * (x₂ * -12.525)) + -0.21999)) * x₁))) + 16.347
# 25          4.255e-01  3.349e-03  y = 15.672 + ((((-0.47831 + x₂) * 120.4) * x₀) + (((-80.752 + ...
#                                   (((x₂ * -8.4032) * (x₂ + x₀)) * x₂)) * x₁) * x₁))
# 27          4.209e-01  5.469e-03  y = 15.672 + ((((-80.752 + ((-8.4032 * x₂) * ((x₂ * x₂) + x₀))...
#                                   ) * x₁) * x₁) + ((((-0.47831 + x₂) * 120.4) + x₀) * x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+05
# Head worker occupation: 31.5%
# Progress: 6995 / 7500 total iterations (93.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.143e-02  y = (-9.3086 + (19.967 * x₂)) * x₀
# 9           8.412e-01  9.084e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.916e-01  3.040e-02  y = ((((x₂ + -0.4056) * 29.752) * 1.8782) * (x₀ + -0.038143)) ...
#                                   + -2.0326
# 15          7.079e-01  5.585e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          5.141e-01  1.599e-01  y = ((x₁ * (-75.369 + (-12.187 * x₂))) + (((x₂ + -0.50164) * 1...
#                                   20.43) * x₀)) + 36.683
# 19          4.565e-01  5.950e-02  y = ((x₁ * (-75.081 + (x₂ * -14.358))) + (((-0.56954 + (1.1589...
#                                    * x₂)) * 113.34) * x₀)) + 36.744
# 21          4.276e-01  3.269e-02  y = ((x₀ * ((-0.4871 + x₂) * 119.38)) + (((-82.661 + (x₂ * (x₂...
#                                    * -12.598))) * x₁) * x₁)) + 16.825
# 23          4.243e-01  3.853e-03  y = 16.903 + (((((-0.49353 + x₂) * 119.66) + x₀) * x₀) + (x₁ *...
#                                    ((-82.661 + ((x₂ * -12.598) * x₂)) * x₁)))
# 25          4.226e-01  2.007e-03  y = 16.903 + (((((-0.49353 + x₂) * 119.66) + x₀) * x₀) + (x₁ *...
#                                    (((((x₂ * -13.238) + 0.79779) * x₂) + -82.72) * x₁)))
# 27          4.209e-01  2.001e-03  y = 15.672 + ((((-80.752 + ((-8.4032 * x₂) * ((x₂ * x₂) + x₀))...
#                                   ) * x₁) * x₁) + ((((-0.47831 + x₂) * 120.4) + x₀) * x₀))
# 29          4.181e-01  3.358e-03  y = 15.672 + ((((-80.752 + ((-8.4032 * x₂) * ((x₂ * x₂) + x₀))...
#                                   ) * x₁) * x₁) + ((((-0.47831 + x₂) * 120.4) + (x₀ + -0.10672))...
#                                    * x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                                 x2
# 	1         4.842331e-03                                   -0.10953539 + x2
# 	2         8.819936e-03                     (1.7507865 * x2) + -0.55600756
# 	3         9.143341e-02                  (-9.30858 + (19.96653 * x2)) * x0
# 	4         9.084055e-02  -2.2122555 + (x0 * ((43.339825 * x2) + -16.520...
# 	5         4.160702e-08  (((29.723581 * (-0.3811865 + x2)) * 1.4580895)...
# 	6         3.444665e-02  ((x1 * -15.374885) + (((x2 + -0.42598626) * 46...
# 	7         5.180171e-02  x2 * ((((x2 + -0.42973825) * 97.291626) * x0) ...
# 	8   >>>>  1.599252e-01  ((x1 * (-75.36943 + (-12.186699 * x2))) + (((x...
# 	9         5.949527e-02  ((x1 * (-75.08056 + (x2 * -14.358229))) + (((-...
# 	10        3.268603e-02  ((x0 * ((-0.4870994 + x2) * 119.38031)) + (((-...
# 	11        3.852949e-03  16.903307 + (((((-0.49353454 + x2) * 119.66418...
# 	12        2.006812e-03  16.903307 + (((((-0.49353454 + x2) * 119.66418...
# 	13        7.257215e-03  (16.903307 + (((((-0.49353454 + x2) * 119.6641...
# 	14        1.244917e-03  (16.903307 + ((x0 * (((-0.49353454 + x2) * 119...
#
# 	        loss  complexity
# 	0   1.244771           1
# 	1   1.232774           3
# 	2   1.211219           5
# 	3   1.008799           7
# 	4   0.841204           9
# 	5   0.841204          11
# 	6   0.785202          13
# 	7   0.707925          15
# 	8   0.514136          17
# 	9   0.456458          19
# 	10  0.427573          21
# 	11  0.424291          23
# 	12  0.422591          25
# 	13  0.416502          27
# 	14  0.415466          29
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_phip.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=10
expr=model_phip.sympy(chose)
expr
sympy.expand(expr)
# Out:
# 119.38031*x0*x2 - 58.150077372814*x0 - 12.598289*x1**2*x2**2 - 82.660515*x1**2 + 16.824549

# %%
symb1=model_phip.predict(tf.concat([p, s, a],1),chose)
plt.plot(tf.concat([p, s, a],1), phi_p, label='PINN prediction')
plt.plot(tf.concat([p, s, a],1), symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.legend()
plt.show()

# %%
Nt=10000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)
A_symb=np.zeros(Nt)


dt=0.0001

# P_symb[0]=np.mean(uu1) #Initial conditions
P_symb[0]=np.array(p[0])  #Initial conditions
S_symb[0]=np.array(s[0]) #Initial conditions
A_symb[0]=np.array(a[0])  #Initial conditions
T_symb[0]=0

for i in range(1,Nt):
    PSA_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(A_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    P_symb[i]=P_symb[i-1]+model_phip.predict(PSA_p,chose)*dt
    S_symb[i]=S_symb[i-1]-P_symb[i-1]*S_symb[i-1]*np.array(m[0])*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, P_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, p, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
plt.plot(T_symb, S_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, S_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, s, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('S')
plt.legend()
plt.show()

# %%
plt.plot(T_symb, A_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, A_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, a, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('A')
plt.legend()
plt.show()
