# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
df2.iloc[:, 9:15]
# Out:
# 0        A7      A8      A9     A10     A11     A12
# 0    0.0938  0.0933  0.0947   0.094  0.0945  0.0923
# 1    0.0933  0.0932  0.0948  0.0937  0.0937  0.0923
# 2    0.0932  0.0933  0.0948  0.0939  0.0939  0.0927
# 3    0.0934  0.0935   0.095  0.0941  0.0941  0.0926
# 4    0.0938  0.0939  0.0954  0.0945  0.0945  0.0929
# ..      ...     ...     ...     ...     ...     ...
# 337  0.5901  0.6007  0.5678  0.5227  0.5631   0.308
# 338  0.5898  0.6002  0.5683  0.5222  0.5616  0.3055
# 339  0.5889  0.5999  0.5681  0.5221  0.5621  0.3051
# 340  0.5888  0.5992  0.5675  0.5211   0.561  0.3032
# 341  0.5872  0.5982  0.5666  0.5205  0.5609  0.3005
#
# [342 rows x 6 columns]

# %%
c=-1
P_exp=np.array(df2.iloc[:, 13]).reshape([-1,1])
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max
# Out:
# (1, 231399.5)

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 100 # Number of residual point
N_d = 300 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = T_star.min(0)
ub = T_star.max(0) 

# Initial Condition
xx1 = T_star[::len(T_exp)]
uu1 = P_star[::len(T_exp)]

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu1), replace=False)
xxd = T_star[idx]
uud = P_star[idx]

T_u_train = np.concatenate((xx1,xxd)).reshape([-1,1])
p_train = np.concatenate((uu1,uud)).reshape([-1,1])

T_f_train = lb + (ub-lb)*lhs(1, N_f)

T_u_train_tf = tf.convert_to_tensor(T_u_train, dtype=tf.float32)
p_train_tf =   tf.convert_to_tensor(p_train, dtype=tf.float32)
T_f_train_tf = tf.convert_to_tensor(T_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    A = 2.0*(X - lb)/(ub - lb) - 1.0
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 

def train_vars_total(W, b, lambda_r, lambda_b):
    return W + b + lambda_r + lambda_b

def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r, 1]), dtype=tf.float32)
    return alpha_r, alpha_b

#@tf.function(jit_compile=True)
@tf.function()
def net_f(t, m, W_p, b_p, W_phip, b_phip, W_phia, b_phia):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([t])
        u=net(t, W_p, b_p)

        lnp=u[:,0:1]
        lns=u[:,1:2]
        lna=u[:,2:3]

        p=tf.exp(lnp)
        s=tf.exp(lns)
        a=tf.exp(lna)

        
        phi_p=net(tf.concat([p, s, a],1), W_phip, b_phip)
        phi_a=net(tf.concat([p, a],1), W_phia, b_phia)

    p_t = tape1.gradient(p, t) 
    s_t = tape1.gradient(s, t) 
    a_t = tape1.gradient(a, t) 

    f_p = p_t - phi_p
    f_a = a_t - phi_a
    f_s = s_t + m[0]*p*s
    
    return f_p, f_s, f_a


#@tf.function()
@tf.function()
def train_step(W_p, b_p, W_phip, b_phip, W_phia, b_phia, X_u_train_tf, p_train_tf, X_f_train_tf, lambda_r, lambda_b, m, opt):
    
    t_u = X_u_train_tf
    t_f = X_f_train_tf

    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phip, b_phip, W_phia, b_phia, lambda_r, lambda_b])
        u_nn = net(t_u, W_p, b_p) 
        lnp=u_nn[:,0:1]
        p_nn=tf.exp(lnp)
        f_p, f_s, f_a = net_f(t_f, m, W_p, b_p, W_phip, b_phip, W_phia, b_phia)

        loss_p = tf.square(lambda_b*(p_nn - p_train_tf))
        loss_fp = tf.square(lambda_r*f_p) 
        loss_fs = tf.square(lambda_r*f_s) 
        loss_fa = tf.square(lambda_r*f_a) 

        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs) + tf.reduce_mean(loss_fa)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phip = tape.gradient(loss, train_vars(W_phip, b_phip))
    grads_phia = tape.gradient(loss, train_vars(W_phia, b_phia))
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    # grads_m = tape.gradient(loss, m)


    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phip, train_vars(W_phip, b_phip)))
    opt.apply_gradients(zip(grads_phia, train_vars(W_phia, b_phia)))
    # opt.apply_gradients(zip(grads_m, m))
   
    return loss, tf.reduce_mean(loss_p), tf.reduce_mean(loss_fp), tf.reduce_mean(loss_fs), tf.reduce_mean(loss_fa)



layers = [1, 50, 50, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [3, 50, 50, 1]

W_phip = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phip = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 50, 50, 1]

W_phia = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phia = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lambda_r, lambda_b = loss_weight(N_f, N_d)
m = [tf.Variable(tf.ones([1,1])*0.391, dtype=tf.float32)]

# %%
# lr = 1e-4
# # Nmax = 15000
# # Nmax = 150000
# # Nmax=10**5
# Nmax=50000



# optimizer = tf.optimizers.Adam(learning_rate=lr)

# start_time = time.time()
# n=0
# loss = []
# loss_d = []
# loss_fisp = []
# loss_fiss = []
# loss_fisa = []


# while n <= Nmax:
#     loss_, loss_p, loss_fp, loss_fs, loss_fa = train_step(W_p, b_p, W_phip, b_phip, W_phia, b_phia, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, optimizer)
    
#     loss.append(loss_)
#     loss_d.append(loss_p)
#     loss_fisp.append(loss_fp)
#     loss_fiss.append(loss_fs)
#     loss_fisa.append(loss_fa)



#     if n % 10 == 0:
#         print(f"Iteration is: {n}")
#         print(f"Total loss is: {loss_}")

#         print(f"Data loss is: {loss_p}")
#         print(f"Physicial loss of p is: {loss_fp}")
#         print(f"Physicial loss of s is: {loss_fs}")
#         print(f"Physicial loss of a is: {loss_fa}")


#     n+=1

# elapsed = time.time() - start_time                
# print('Training time: %.4f' % (elapsed))

# %%
import tensorflow as tf
import time
import scipy.optimize as opt

lr = 1e-4
Nmax = 30000
threshold = 10**4  # Iteración en la que cambias a L-BFGS

optimizer_adam = tf.optimizers.Adam(learning_rate=lr)
optimizer_lbfgs = tf.optimizers.RMSprop()  # Inicializa el optimizador L-BFGS después

start_time = time.time()
n = 0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []
loss_fisa = []

# Función de pérdida para L-BFGS
def loss_function_for_lbfgs():
    loss_, _, _, _, _ = train_step(W_p, b_p, W_phip, b_phip, W_phia, b_phia, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, None)
    return loss_

# Conversión de las variables de TensorFlow a numpy (necesario para L-BFGS)
def convert_to_numpy():
    variables = [W_p, b_p, W_phip, b_phip, W_phia, b_phia]
    
    # Si las variables son listas de tensores, aplanamos cada lista y luego convertimos cada tensor a numpy.
    return [var.numpy().flatten() if isinstance(var, tf.Tensor) else [v.numpy().flatten() for v in var] for var in variables]


# Función que recibe el gradiente y devuelve numpy (para L-BFGS)
def flatten_gradients(gradients):
    return tf.concat([tf.reshape(g, [-1]) for g in gradients], 0).numpy()

while n <= Nmax:
    if n <= threshold:
        # Fase de Adam optimizer
        loss_, loss_p, loss_fp, loss_fs, loss_fa = train_step(W_p, b_p, W_phip, b_phip, W_phia, b_phia, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, optimizer_adam)
    else:
        loss_, loss_p, loss_fp, loss_fs, loss_fa = train_step(W_p, b_p, W_phip, b_phip, W_phia, b_phia, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, optimizer_adam)


    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)
    loss_fisa.append(loss_fa)

    if n % 10 == 0:
        print(f"Iteration is: {n}")
        print(f"Total loss is: {loss_}")
        print(f"Data loss is: {loss_p}")
        print(f"Physical loss of p is: {loss_fp}")
        print(f"Physical loss of s is: {loss_fs}")
        print(f"Physical loss of a is: {loss_fa}")

    n += 1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Total loss is: 384358.21875
# Data loss is: 384357.84375
# Physical loss of p is: 0.06000983715057373
# Physical loss of s is: 0.04238966852426529
# Physical loss of a is: 0.2804889380931854
# Iteration is: 10
# Total loss is: 366893.25
# Data loss is: 366893.0
# Physical loss of p is: 0.008602892979979515
# Physical loss of s is: 0.05130033567547798
# Physical loss of a is: 0.19347737729549408
# Iteration is: 20
# Total loss is: 339696.71875
# Data loss is: 339696.625
# Physical loss of p is: 0.006546148099005222
# Physical loss of s is: 0.04563559591770172
# Physical loss of a is: 0.06861589103937149
# Iteration is: 30
# Total loss is: 307998.5
# Data loss is: 307998.46875
# Physical loss of p is: 0.001385639887303114
# Physical loss of s is: 0.036965031176805496
# Physical loss of a is: 0.009821126237511635
# Iteration is: 40
# Total loss is: 273824.09375
# Data loss is: 273824.0625
# Physical loss of p is: 0.0006046005291864276
# Physical loss of s is: 0.0354284793138504
# Physical loss of a is: 0.0007126430282369256
# Iteration is: 50
# Total loss is: 238289.53125
# Data loss is: 238289.5
# Physical loss of p is: 0.00012336866348050535
# Physical loss of s is: 0.03215932473540306
# Physical loss of a is: 0.0013403968187049031
# Iteration is: 60
# Total loss is: 202604.671875
# Data loss is: 202604.640625
# Physical loss of p is: 9.017059346660972e-05
# Physical loss of s is: 0.030787644907832146
# Physical loss of a is: 0.0012174048461019993
# Iteration is: 70
# Total loss is: 168202.75
# Data loss is: 168202.71875
# Physical loss of p is: 0.00023813251755200326
# Physical loss of s is: 0.03146545588970184
# Physical loss of a is: 0.0013468542601913214
# Iteration is: 80
# Total loss is: 136473.109375
# Data loss is: 136473.078125
# Physical loss of p is: 0.00012873747618868947
# Physical loss of s is: 0.03235896676778793
# Physical loss of a is: 0.0020894655026495457
# Iteration is: 90
# Total loss is: 108489.3359375
# Data loss is: 108489.3046875
# Physical loss of p is: 0.00018240597273688763
# Physical loss of s is: 0.03359682857990265
# Physical loss of a is: 0.002786580240353942
# Iteration is: 100
# Total loss is: 84860.078125
# Data loss is: 84860.046875
# Physical loss of p is: 0.0002674005227163434
# Physical loss of s is: 0.03473084792494774
# Physical loss of a is: 0.0032235844992101192
# Iteration is: 110
# Total loss is: 65699.8828125
# Data loss is: 65699.84375
# Physical loss of p is: 0.00025858625303953886
# Physical loss of s is: 0.035199299454689026
# Physical loss of a is: 0.003451224882155657
# Iteration is: 120
# Total loss is: 50712.078125
# Data loss is: 50712.0390625
# Physical loss of p is: 0.00028016394935548306
# Physical loss of s is: 0.03491625189781189
# Physical loss of a is: 0.003614286193624139
# Iteration is: 130
# Total loss is: 39338.9609375
# Data loss is: 39338.921875
# Physical loss of p is: 0.0002803382812999189
# Physical loss of s is: 0.03380117565393448
# Physical loss of a is: 0.0037229948211461306
# Iteration is: 140
# Total loss is: 30917.08203125
# Data loss is: 30917.046875
# Physical loss of p is: 0.00025819591246545315
# Physical loss of s is: 0.03188987076282501
# Physical loss of a is: 0.0037486094515770674
# Iteration is: 150
# Total loss is: 24795.84375
# Data loss is: 24795.810546875
# Physical loss of p is: 0.0002382741658948362
# Physical loss of s is: 0.029370250180363655
# Physical loss of a is: 0.0036883102729916573
# Iteration is: 160
# Total loss is: 20406.21875
# Data loss is: 20406.1875
# Physical loss of p is: 0.00020662829047068954
# Physical loss of s is: 0.026455216109752655
# Physical loss of a is: 0.0035455867182463408
# Iteration is: 170
# Total loss is: 17286.908203125
# Data loss is: 17286.880859375
# Physical loss of p is: 0.0001727566559566185
# Physical loss of s is: 0.02336929552257061
# Physical loss of a is: 0.0033363658003509045
# Iteration is: 180
# Total loss is: 15082.93359375
# Data loss is: 15082.91015625
# Physical loss of p is: 0.00013889060937799513
# Physical loss of s is: 0.020319387316703796
# Physical loss of a is: 0.0030812383629381657
# Iteration is: 190
# Total loss is: 13530.7392578125
# Data loss is: 13530.71875
# Physical loss of p is: 0.00010689666669350117
# Physical loss of s is: 0.0174602959305048
# Physical loss of a is: 0.0027976303827017546
# Iteration is: 200
# Total loss is: 12439.2978515625
# Data loss is: 12439.2802734375
# Physical loss of p is: 7.992323662620038e-05
# Physical loss of s is: 0.014893805608153343
# Physical loss of a is: 0.0025012835394591093
# Iteration is: 210
# Total loss is: 11672.23828125
# Data loss is: 11672.2236328125
# Physical loss of p is: 5.8170026022708043e-05
# Physical loss of s is: 0.01267212349921465
# Physical loss of a is: 0.00220582727342844
# Iteration is: 220
# Total loss is: 11133.12109375
# Data loss is: 11133.1083984375
# Physical loss of p is: 4.1856386815197766e-05
# Physical loss of s is: 0.010806193575263023
# Physical loss of a is: 0.0019221598049625754
# Iteration is: 230
# Total loss is: 10754.068359375
# Data loss is: 10754.056640625
# Physical loss of p is: 3.0112230888335034e-05
# Physical loss of s is: 0.009278788231313229
# Physical loss of a is: 0.0016583262477070093
# Iteration is: 240
# Total loss is: 10487.4130859375
# Data loss is: 10487.404296875
# Physical loss of p is: 2.2047979655326344e-05
# Physical loss of s is: 0.008055601269006729
# Physical loss of a is: 0.00141941849142313
# Iteration is: 250
# Total loss is: 10299.70703125
# Data loss is: 10299.69921875
# Physical loss of p is: 1.6724265151424333e-05
# Physical loss of s is: 0.007094118744134903
# Physical loss of a is: 0.0012078749714419246
# Iteration is: 260
# Total loss is: 10167.4482421875
# Data loss is: 10167.4404296875
# Physical loss of p is: 1.3356318049773108e-05
# Physical loss of s is: 0.006350264418870211
# Physical loss of a is: 0.0010240805568173528
# Iteration is: 270
# Total loss is: 10074.1240234375
# Data loss is: 10074.1171875
# Physical loss of p is: 1.1326395906507969e-05
# Physical loss of s is: 0.005782419349998236
# Physical loss of a is: 0.0008669591043144464
# Iteration is: 280
# Total loss is: 10008.12109375
# Data loss is: 10008.115234375
# Physical loss of p is: 1.016472015180625e-05
# Physical loss of s is: 0.005353664048016071
# Physical loss of a is: 0.0007344998884946108
# Iteration is: 290
# Total loss is: 9961.2705078125
# Data loss is: 9961.2646484375
# Physical loss of p is: 9.535457138554193e-06
# Physical loss of s is: 0.005032727029174566
# Physical loss of a is: 0.0006241828086785972
# Iteration is: 300
# Total loss is: 9927.818359375
# Data loss is: 9927.8125
# Physical loss of p is: 9.20009824767476e-06
# Physical loss of s is: 0.004793971311300993
# Physical loss of a is: 0.0005332864238880575
# Iteration is: 310
# Total loss is: 9903.7216796875
# Data loss is: 9903.716796875
# Physical loss of p is: 8.999238161777612e-06
# Physical loss of s is: 0.004616929683834314
# Physical loss of a is: 0.0004591030883602798
# Iteration is: 320
# Total loss is: 9886.14453125
# Data loss is: 9886.1396484375
# Physical loss of p is: 8.832221283228137e-06
# Physical loss of s is: 0.004485661163926125
# Physical loss of a is: 0.0003990796103607863
# Iteration is: 330
# Total loss is: 9873.0908203125
# Data loss is: 9873.0869140625
# Physical loss of p is: 8.640427040518261e-06
# Physical loss of s is: 0.004387943539768457
# Physical loss of a is: 0.00035089137963950634
# Iteration is: 340
# Total loss is: 9863.1689453125
# Data loss is: 9863.1650390625
# Physical loss of p is: 8.394586984650232e-06
# Physical loss of s is: 0.004314584191888571
# Physical loss of a is: 0.0003124912327621132
# Iteration is: 350
# Total loss is: 9855.41015625
# Data loss is: 9855.40625
# Physical loss of p is: 8.085174158622976e-06
# Physical loss of s is: 0.004258741158992052
# Physical loss of a is: 0.0002821071248035878
# Iteration is: 360
# Total loss is: 9849.1318359375
# Data loss is: 9849.1279296875
# Physical loss of p is: 7.714921594015323e-06
# Physical loss of s is: 0.004215408116579056
# Physical loss of a is: 0.0002582352899480611
# Iteration is: 370
# Total loss is: 9843.87109375
# Data loss is: 9843.8671875
# Physical loss of p is: 7.294185706996359e-06
# Physical loss of s is: 0.004180938471108675
# Physical loss of a is: 0.00023962072737049311
# Iteration is: 380
# Total loss is: 9839.2978515625
# Data loss is: 9839.2939453125
# Physical loss of p is: 6.837053206254495e-06
# Physical loss of s is: 0.004152711480855942
# Physical loss of a is: 0.00022522214567288756
# Iteration is: 390
# Total loss is: 9835.1904296875
# Data loss is: 9835.1865234375
# Physical loss of p is: 6.359268354572123e-06
# Physical loss of s is: 0.004128872882574797
# Physical loss of a is: 0.0002141903096344322
# Iteration is: 400
# Total loss is: 9831.3984375
# Data loss is: 9831.39453125
# Physical loss of p is: 5.876531758985948e-06
# Physical loss of s is: 0.0041081043891608715
# Physical loss of a is: 0.00020583634614013135
# Iteration is: 410
# Total loss is: 9827.8193359375
# Data loss is: 9827.8154296875
# Physical loss of p is: 5.403271643444896e-06
# Physical loss of s is: 0.004089486785233021
# Physical loss of a is: 0.00019960217468906194
# Iteration is: 420
# Total loss is: 9824.3740234375
# Data loss is: 9824.3701171875
# Physical loss of p is: 4.95321228299872e-06
# Physical loss of s is: 0.004072380252182484
# Physical loss of a is: 0.0001950441364897415
# Iteration is: 430
# Total loss is: 9821.0205078125
# Data loss is: 9821.0166015625
# Physical loss of p is: 4.537848781183129e-06
# Physical loss of s is: 0.00405634380877018
# Physical loss of a is: 0.00019180754316039383
# Iteration is: 440
# Total loss is: 9817.7275390625
# Data loss is: 9817.7236328125
# Physical loss of p is: 4.167430233792402e-06
# Physical loss of s is: 0.004041075240820646
# Physical loss of a is: 0.00018961066962219775
# Iteration is: 450
# Total loss is: 9814.470703125
# Data loss is: 9814.466796875
# Physical loss of p is: 3.850484972645063e-06
# Physical loss of s is: 0.004026371985673904
# Physical loss of a is: 0.00018823124992195517
# Iteration is: 460
# Total loss is: 9811.23828125
# Data loss is: 9811.234375
# Physical loss of p is: 3.594130021156161e-06
# Physical loss of s is: 0.004012095741927624
# Physical loss of a is: 0.00018749346781987697
# Iteration is: 470
# Total loss is: 9808.017578125
# Data loss is: 9808.013671875
# Physical loss of p is: 3.4043735013256082e-06
# Physical loss of s is: 0.003998154308646917
# Physical loss of a is: 0.00018725958943832666
# Iteration is: 480
# Total loss is: 9804.806640625
# Data loss is: 9804.802734375
# Physical loss of p is: 3.285903403593693e-06
# Physical loss of s is: 0.00398448808118701
# Physical loss of a is: 0.0001874213630799204
# Iteration is: 490
# Total loss is: 9801.59375
# Data loss is: 9801.58984375
# Physical loss of p is: 3.2428185932076303e-06
# Physical loss of s is: 0.0039710537530481815
# Physical loss of a is: 0.00018789291789289564
# Iteration is: 500
# Total loss is: 9798.3857421875
# Data loss is: 9798.3818359375
# Physical loss of p is: 3.2781554182292894e-06
# Physical loss of s is: 0.003957825712859631
# Physical loss of a is: 0.00018860861018765718
# Iteration is: 510
# Total loss is: 9795.17578125
# Data loss is: 9795.171875
# Physical loss of p is: 3.3946428175113397e-06
# Physical loss of s is: 0.003944786731153727
# Physical loss of a is: 0.00018951515085063875
# Iteration is: 520
# Total loss is: 9791.9619140625
# Data loss is: 9791.9580078125
# Physical loss of p is: 3.59411410499888e-06
# Physical loss of s is: 0.0039319247007369995
# Physical loss of a is: 0.00019057154713664204
# Iteration is: 530
# Total loss is: 9788.74609375
# Data loss is: 9788.7421875
# Physical loss of p is: 3.8785160541010555e-06
# Physical loss of s is: 0.003919233568012714
# Physical loss of a is: 0.00019174549379386008
# Iteration is: 540
# Total loss is: 9785.52734375
# Data loss is: 9785.5234375
# Physical loss of p is: 4.248932327755028e-06
# Physical loss of s is: 0.003906704019755125
# Physical loss of a is: 0.00019301180145703256
# Iteration is: 550
# Total loss is: 9782.3017578125
# Data loss is: 9782.2978515625
# Physical loss of p is: 4.706662366515957e-06
# Physical loss of s is: 0.003894334426149726
# Physical loss of a is: 0.0001943507813848555
# Iteration is: 560
# Total loss is: 9779.072265625
# Data loss is: 9779.068359375
# Physical loss of p is: 5.2523600970744155e-06
# Physical loss of s is: 0.0038821243215352297
# Physical loss of a is: 0.00019574617908801883
# Iteration is: 570
# Total loss is: 9775.8369140625
# Data loss is: 9775.8330078125
# Physical loss of p is: 5.887112820346374e-06
# Physical loss of s is: 0.003870065324008465
# Physical loss of a is: 0.000197186425793916
# Iteration is: 580
# Total loss is: 9772.595703125
# Data loss is: 9772.591796875
# Physical loss of p is: 6.611207936657593e-06
# Physical loss of s is: 0.0038581567350775003
# Physical loss of a is: 0.00019865996728185564
# Iteration is: 590
# Total loss is: 9769.3505859375
# Data loss is: 9769.3466796875
# Physical loss of p is: 7.425540843541967e-06
# Physical loss of s is: 0.0038464015815407038
# Physical loss of a is: 0.00020016092457808554
# Iteration is: 600
# Total loss is: 9766.1005859375
# Data loss is: 9766.0966796875
# Physical loss of p is: 8.33027752378257e-06
# Physical loss of s is: 0.0038347914814949036
# Physical loss of a is: 0.00020168251649010926
# Iteration is: 610
# Total loss is: 9762.8408203125
# Data loss is: 9762.8369140625
# Physical loss of p is: 9.326115105068311e-06
# Physical loss of s is: 0.003823324339464307
# Physical loss of a is: 0.00020322046475484967
# Iteration is: 620
# Total loss is: 9759.5791015625
# Data loss is: 9759.5751953125
# Physical loss of p is: 1.0413537893327884e-05
# Physical loss of s is: 0.0038120043464004993
# Physical loss of a is: 0.00020476982172112912
# Iteration is: 630
# Total loss is: 9756.3076171875
# Data loss is: 9756.3037109375
# Physical loss of p is: 1.1592830560402945e-05
# Physical loss of s is: 0.0038008198607712984
# Physical loss of a is: 0.0002063283754978329
# Iteration is: 640
# Total loss is: 9753.03125
# Data loss is: 9753.02734375
# Physical loss of p is: 1.2864607015217189e-05
# Physical loss of s is: 0.003789776936173439
# Physical loss of a is: 0.0002078940306091681
# Iteration is: 650
# Total loss is: 9749.7470703125
# Data loss is: 9749.7431640625
# Physical loss of p is: 1.4228829058993142e-05
# Physical loss of s is: 0.003778870217502117
# Physical loss of a is: 0.00020946547738276422
# Iteration is: 660
# Total loss is: 9746.455078125
# Data loss is: 9746.451171875
# Physical loss of p is: 1.5686706319684163e-05
# Physical loss of s is: 0.0037680973764508963
# Physical loss of a is: 0.00021103996550664306
# Iteration is: 670
# Total loss is: 9743.1552734375
# Data loss is: 9743.1513671875
# Physical loss of p is: 1.7238122381968424e-05
# Physical loss of s is: 0.00375745864585042
# Physical loss of a is: 0.00021261736401356757
# Iteration is: 680
# Total loss is: 9739.84765625
# Data loss is: 9739.84375
# Physical loss of p is: 1.888378756120801e-05
# Physical loss of s is: 0.003746946342289448
# Physical loss of a is: 0.00021419714903458953
# Iteration is: 690
# Total loss is: 9736.5341796875
# Data loss is: 9736.5302734375
# Physical loss of p is: 2.0624222088372335e-05
# Physical loss of s is: 0.0037365658208727837
# Physical loss of a is: 0.00021577920415438712
# Iteration is: 700
# Total loss is: 9733.20703125
# Data loss is: 9733.203125
# Physical loss of p is: 2.2459844331024215e-05
# Physical loss of s is: 0.003726312890648842
# Physical loss of a is: 0.00021736219059675932
# Iteration is: 710
# Total loss is: 9729.8759765625
# Data loss is: 9729.8720703125
# Physical loss of p is: 2.4391278202529065e-05
# Physical loss of s is: 0.003716182429343462
# Physical loss of a is: 0.00021894637029618025
# Iteration is: 720
# Total loss is: 9726.53125
# Data loss is: 9726.52734375
# Physical loss of p is: 2.6419260393595323e-05
# Physical loss of s is: 0.0037061767652630806
# Physical loss of a is: 0.00022053277643863112
# Iteration is: 730
# Total loss is: 9723.1787109375
# Data loss is: 9723.1748046875
# Physical loss of p is: 2.8544174710987136e-05
# Physical loss of s is: 0.0036962872836738825
# Physical loss of a is: 0.00022211961913853884
# Iteration is: 740
# Total loss is: 9719.818359375
# Data loss is: 9719.814453125
# Physical loss of p is: 3.076681969105266e-05
# Physical loss of s is: 0.00368652050383389
# Physical loss of a is: 0.00022370913939084858
# Iteration is: 750
# Total loss is: 9716.4423828125
# Data loss is: 9716.4384765625
# Physical loss of p is: 3.308823943370953e-05
# Physical loss of s is: 0.0036768687423318624
# Physical loss of a is: 0.00022530011483468115
# Iteration is: 760
# Total loss is: 9713.05859375
# Data loss is: 9713.0546875
# Physical loss of p is: 3.550808105501346e-05
# Physical loss of s is: 0.0036673361901193857
# Physical loss of a is: 0.00022689407342113554
# Iteration is: 770
# Total loss is: 9709.6640625
# Data loss is: 9709.66015625
# Physical loss of p is: 3.802828359766863e-05
# Physical loss of s is: 0.003657911904156208
# Physical loss of a is: 0.00022849049128126353
# Iteration is: 780
# Total loss is: 9706.2578125
# Data loss is: 9706.25390625
# Physical loss of p is: 4.064869062858634e-05
# Physical loss of s is: 0.003648601472377777
# Physical loss of a is: 0.0002300906926393509
# Iteration is: 790
# Total loss is: 9702.8359375
# Data loss is: 9702.83203125
# Physical loss of p is: 4.33706481999252e-05
# Physical loss of s is: 0.003639400703832507
# Physical loss of a is: 0.00023169447376858443
# Iteration is: 800
# Total loss is: 9699.404296875
# Data loss is: 9699.400390625
# Physical loss of p is: 4.619503306457773e-05
# Physical loss of s is: 0.0036303079687058926
# Physical loss of a is: 0.00023330282419919968
# Iteration is: 810
# Total loss is: 9695.9599609375
# Data loss is: 9695.9560546875
# Physical loss of p is: 4.912318763672374e-05
# Physical loss of s is: 0.003621321404352784
# Physical loss of a is: 0.00023491606407333165
# Iteration is: 820
# Total loss is: 9692.5009765625
# Data loss is: 9692.4970703125
# Physical loss of p is: 5.2154566219542176e-05
# Physical loss of s is: 0.0036124377511441708
# Physical loss of a is: 0.00023653551761526614
# Iteration is: 830
# Total loss is: 9689.0302734375
# Data loss is: 9689.0263671875
# Physical loss of p is: 5.529167174245231e-05
# Physical loss of s is: 0.0036036609672009945
# Physical loss of a is: 0.00023816055909264833
# Iteration is: 840
# Total loss is: 9685.541015625
# Data loss is: 9685.537109375
# Physical loss of p is: 5.853510447195731e-05
# Physical loss of s is: 0.0035949856974184513
# Physical loss of a is: 0.00023979292018339038
# Iteration is: 850
# Total loss is: 9682.041015625
# Data loss is: 9682.037109375
# Physical loss of p is: 6.188604311319068e-05
# Physical loss of s is: 0.0035864103119820356
# Physical loss of a is: 0.0002414332702755928
# Iteration is: 860
# Total loss is: 9678.525390625
# Data loss is: 9678.521484375
# Physical loss of p is: 6.534488056786358e-05
# Physical loss of s is: 0.0035779334139078856
# Physical loss of a is: 0.00024308059073518962
# Iteration is: 870
# Total loss is: 9674.9951171875
# Data loss is: 9674.9912109375
# Physical loss of p is: 6.891311932122335e-05
# Physical loss of s is: 0.00356955174356699
# Physical loss of a is: 0.00024473731173202395
# Iteration is: 880
# Total loss is: 9671.4423828125
# Data loss is: 9671.4384765625
# Physical loss of p is: 7.259362610056996e-05
# Physical loss of s is: 0.003561269724741578
# Physical loss of a is: 0.00024640405899845064
# Iteration is: 890
# Total loss is: 9667.876953125
# Data loss is: 9667.873046875
# Physical loss of p is: 7.638525130460039e-05
# Physical loss of s is: 0.0035530822351574898
# Physical loss of a is: 0.00024808093439787626
# Iteration is: 900
# Total loss is: 9664.296875
# Data loss is: 9664.29296875
# Physical loss of p is: 8.029067976167426e-05
# Physical loss of s is: 0.0035449834540486336
# Physical loss of a is: 0.00024976939312182367
# Iteration is: 910
# Total loss is: 9660.697265625
# Data loss is: 9660.693359375
# Physical loss of p is: 8.431068272329867e-05
# Physical loss of s is: 0.0035369812976568937
# Physical loss of a is: 0.0002514690859243274
# Iteration is: 920
# Total loss is: 9657.0810546875
# Data loss is: 9657.0771484375
# Physical loss of p is: 8.844684634823352e-05
# Physical loss of s is: 0.0035290676169097424
# Physical loss of a is: 0.00025318199186585844
# Iteration is: 930
# Total loss is: 9653.4423828125
# Data loss is: 9653.4384765625
# Physical loss of p is: 9.270189912058413e-05
# Physical loss of s is: 0.003521244041621685
# Physical loss of a is: 0.0002549082855693996
# Iteration is: 940
# Total loss is: 9649.7880859375
# Data loss is: 9649.7841796875
# Physical loss of p is: 9.707512072054669e-05
# Physical loss of s is: 0.0035135066136717796
# Physical loss of a is: 0.0002566482871770859
# Iteration is: 950
# Total loss is: 9646.1123046875
# Data loss is: 9646.1083984375
# Physical loss of p is: 0.0001015695816022344
# Physical loss of s is: 0.003505854634568095
# Physical loss of a is: 0.00025840388843789697
# Iteration is: 960
# Total loss is: 9642.4169921875
# Data loss is: 9642.4130859375
# Physical loss of p is: 0.0001061871662386693
# Physical loss of s is: 0.003498291363939643
# Physical loss of a is: 0.00026017456548288465
# Iteration is: 970
# Total loss is: 9638.7021484375
# Data loss is: 9638.6982421875
# Physical loss of p is: 0.00011092874046880752
# Physical loss of s is: 0.003490813309326768
# Physical loss of a is: 0.0002619617443997413
# Iteration is: 980
# Total loss is: 9634.9619140625
# Data loss is: 9634.9580078125
# Physical loss of p is: 0.00011579621786950156
# Physical loss of s is: 0.0034834127873182297
# Physical loss of a is: 0.00026376641471870244
# Iteration is: 990
# Total loss is: 9631.203125
# Data loss is: 9631.19921875
# Physical loss of p is: 0.00012079216685378924
# Physical loss of s is: 0.003476096084341407
# Physical loss of a is: 0.00026558968238532543
# Iteration is: 1000
# Total loss is: 9627.421875
# Data loss is: 9627.41796875
# Physical loss of p is: 0.00012591815902851522
# Physical loss of s is: 0.003468862734735012
# Physical loss of a is: 0.000267431401880458
# Iteration is: 1010
# Total loss is: 9623.6181640625
# Data loss is: 9623.6142578125
# Physical loss of p is: 0.00013117621710989624
# Physical loss of s is: 0.0034617059864103794
# Physical loss of a is: 0.00026929419254884124
# Iteration is: 1020
# Total loss is: 9619.7880859375
# Data loss is: 9619.7841796875
# Physical loss of p is: 0.00013656802184414119
# Physical loss of s is: 0.0034546309616416693
# Physical loss of a is: 0.00027117697754874825
# Iteration is: 1030
# Total loss is: 9615.9365234375
# Data loss is: 9615.9326171875
# Physical loss of p is: 0.00014209680375643075
# Physical loss of s is: 0.00344762927852571
# Physical loss of a is: 0.0002730812120717019
# Iteration is: 1040
# Total loss is: 9612.060546875
# Data loss is: 9612.056640625
# Physical loss of p is: 0.00014776279567740858
# Physical loss of s is: 0.003440710250288248
# Physical loss of a is: 0.00027500794385559857
# Iteration is: 1050
# Total loss is: 9608.1572265625
# Data loss is: 9608.1533203125
# Physical loss of p is: 0.0001535707851871848
# Physical loss of s is: 0.003433859907090664
# Physical loss of a is: 0.0002769583952613175
# Iteration is: 1060
# Total loss is: 9604.228515625
# Data loss is: 9604.224609375
# Physical loss of p is: 0.0001595208013895899
# Physical loss of s is: 0.0034270882606506348
# Physical loss of a is: 0.0002789334685076028
# Iteration is: 1070
# Total loss is: 9600.2744140625
# Data loss is: 9600.2705078125
# Physical loss of p is: 0.0001656173844821751
# Physical loss of s is: 0.0034203899558633566
# Physical loss of a is: 0.0002809334546327591
# Iteration is: 1080
# Total loss is: 9596.2919921875
# Data loss is: 9596.2890625
# Physical loss of p is: 0.0001718614948913455
# Physical loss of s is: 0.0034137621987611055
# Physical loss of a is: 0.0002829600707627833
# Iteration is: 1090
# Total loss is: 9592.28125
# Data loss is: 9592.2783203125
# Physical loss of p is: 0.0001782558101695031
# Physical loss of s is: 0.003407210810109973
# Physical loss of a is: 0.00028501314227469265
# Iteration is: 1100
# Total loss is: 9588.244140625
# Data loss is: 9588.2412109375
# Physical loss of p is: 0.00018480478320270777
# Physical loss of s is: 0.0034007269423455
# Physical loss of a is: 0.000287094822851941
# Iteration is: 1110
# Total loss is: 9584.177734375
# Data loss is: 9584.1748046875
# Physical loss of p is: 0.00019150847219862044
# Physical loss of s is: 0.003394310362637043
# Physical loss of a is: 0.0002892053744290024
# Iteration is: 1120
# Total loss is: 9580.0830078125
# Data loss is: 9580.080078125
# Physical loss of p is: 0.00019837170839309692
# Physical loss of s is: 0.003387966426089406
# Physical loss of a is: 0.00029134625219739974
# Iteration is: 1130
# Total loss is: 9575.9560546875
# Data loss is: 9575.953125
# Physical loss of p is: 0.00020539671822916716
# Physical loss of s is: 0.0033816921059042215
# Physical loss of a is: 0.000293517776299268
# Iteration is: 1140
# Total loss is: 9571.796875
# Data loss is: 9571.7939453125
# Physical loss of p is: 0.00021258801280055195
# Physical loss of s is: 0.0033754841424524784
# Physical loss of a is: 0.0002957216929644346
# Iteration is: 1150
# Total loss is: 9567.607421875
# Data loss is: 9567.6044921875
# Physical loss of p is: 0.00021994566486682743
# Physical loss of s is: 0.0033693439327180386
# Physical loss of a is: 0.0002979589335154742
# Iteration is: 1160
# Total loss is: 9563.384765625
# Data loss is: 9563.3818359375
# Physical loss of p is: 0.0002274756843689829
# Physical loss of s is: 0.0033632677514106035
# Physical loss of a is: 0.0003002306038979441
# Iteration is: 1170
# Total loss is: 9559.130859375
# Data loss is: 9559.1279296875
# Physical loss of p is: 0.00023517898807767779
# Physical loss of s is: 0.00335725792683661
# Physical loss of a is: 0.0003025374317076057
# Iteration is: 1180
# Total loss is: 9554.841796875
# Data loss is: 9554.8388671875
# Physical loss of p is: 0.00024306248815264553
# Physical loss of s is: 0.00335131399333477
# Physical loss of a is: 0.0003048803482670337
# Iteration is: 1190
# Total loss is: 9550.521484375
# Data loss is: 9550.5185546875
# Physical loss of p is: 0.0002511265338398516
# Physical loss of s is: 0.0033454326912760735
# Physical loss of a is: 0.00030726069235242903
# Iteration is: 1200
# Total loss is: 9546.1650390625
# Data loss is: 9546.162109375
# Physical loss of p is: 0.0002593762765172869
# Physical loss of s is: 0.003339613089337945
# Physical loss of a is: 0.0003096795699093491
# Iteration is: 1210
# Total loss is: 9541.771484375
# Data loss is: 9541.7685546875
# Physical loss of p is: 0.00026781449560076
# Physical loss of s is: 0.0033338572829961777
# Physical loss of a is: 0.00031213858164846897
# Iteration is: 1220
# Total loss is: 9537.3388671875
# Data loss is: 9537.3359375
# Physical loss of p is: 0.00027644820511341095
# Physical loss of s is: 0.0033281638752669096
# Physical loss of a is: 0.00031463790219277143
# Iteration is: 1230
# Total loss is: 9532.873046875
# Data loss is: 9532.8701171875
# Physical loss of p is: 0.0002852757170330733
# Physical loss of s is: 0.0033225310035049915
# Physical loss of a is: 0.0003171797434333712
# Iteration is: 1240
# Total loss is: 9528.3671875
# Data loss is: 9528.3642578125
# Physical loss of p is: 0.00029430590802803636
# Physical loss of s is: 0.00331696099601686
# Physical loss of a is: 0.00031976483296602964
# Iteration is: 1250
# Total loss is: 9523.8232421875
# Data loss is: 9523.8203125
# Physical loss of p is: 0.00030354084447026253
# Physical loss of s is: 0.0033114475663751364
# Physical loss of a is: 0.0003223938401788473
# Iteration is: 1260
# Total loss is: 9519.2392578125
# Data loss is: 9519.236328125
# Physical loss of p is: 0.0003129853284917772
# Physical loss of s is: 0.003305995836853981
# Physical loss of a is: 0.00032506926800124347
# Iteration is: 1270
# Total loss is: 9514.6142578125
# Data loss is: 9514.611328125
# Physical loss of p is: 0.000322643289109692
# Physical loss of s is: 0.00330060301348567
# Physical loss of a is: 0.0003277911164332181
# Iteration is: 1280
# Total loss is: 9509.94921875
# Data loss is: 9509.9462890625
# Physical loss of p is: 0.0003325201687403023
# Physical loss of s is: 0.0032952663023024797
# Physical loss of a is: 0.00033056235406547785
# Iteration is: 1290
# Total loss is: 9505.244140625
# Data loss is: 9505.2412109375
# Physical loss of p is: 0.00034262053668498993
# Physical loss of s is: 0.0032899873331189156
# Physical loss of a is: 0.0003333819331601262
# Iteration is: 1300
# Total loss is: 9500.494140625
# Data loss is: 9500.4912109375
# Physical loss of p is: 0.0003529494279064238
# Physical loss of s is: 0.003284766571596265
# Physical loss of a is: 0.00033625244395807385
# Iteration is: 1310
# Total loss is: 9495.701171875
# Data loss is: 9495.6982421875
# Physical loss of p is: 0.00036350995651446283
# Physical loss of s is: 0.0032796005252748728
# Physical loss of a is: 0.00033917545806616545
# Iteration is: 1320
# Total loss is: 9490.86328125
# Data loss is: 9490.8603515625
# Physical loss of p is: 0.00037430948577821255
# Physical loss of s is: 0.003274490125477314
# Physical loss of a is: 0.0003421519650146365
# Iteration is: 1330
# Total loss is: 9485.9833984375
# Data loss is: 9485.98046875
# Physical loss of p is: 0.0003853522357530892
# Physical loss of s is: 0.0032694339752197266
# Physical loss of a is: 0.0003451838856562972
# Iteration is: 1340
# Total loss is: 9481.0537109375
# Data loss is: 9481.05078125
# Physical loss of p is: 0.0003966434160247445
# Physical loss of s is: 0.0032644367311149836
# Physical loss of a is: 0.0003482717147562653
# Iteration is: 1350
# Total loss is: 9476.078125
# Data loss is: 9476.0751953125
# Physical loss of p is: 0.0004081892257090658
# Physical loss of s is: 0.003259488847106695
# Physical loss of a is: 0.0003514173731673509
# Iteration is: 1360
# Total loss is: 9471.052734375
# Data loss is: 9471.0498046875
# Physical loss of p is: 0.0004199940012767911
# Physical loss of s is: 0.0032545984722673893
# Physical loss of a is: 0.00035462260711938143
# Iteration is: 1370
# Total loss is: 9465.984375
# Data loss is: 9465.9814453125
# Physical loss of p is: 0.0004320660955272615
# Physical loss of s is: 0.003249756759032607
# Physical loss of a is: 0.000357889017323032
# Iteration is: 1380
# Total loss is: 9460.861328125
# Data loss is: 9460.8583984375
# Physical loss of p is: 0.00044440908823162317
# Physical loss of s is: 0.003244970925152302
# Physical loss of a is: 0.00036121770972386
# Iteration is: 1390
# Total loss is: 9455.689453125
# Data loss is: 9455.6865234375
# Physical loss of p is: 0.0004570296441670507
# Physical loss of s is: 0.00324023375287652
# Physical loss of a is: 0.00036460949922911823
# Iteration is: 1400
# Total loss is: 9450.46875
# Data loss is: 9450.4658203125
# Physical loss of p is: 0.0004699331184383482
# Physical loss of s is: 0.0032355475705116987
# Physical loss of a is: 0.00036806706339120865
# Iteration is: 1410
# Total loss is: 9445.19140625
# Data loss is: 9445.1884765625
# Physical loss of p is: 0.0004831288824789226
# Physical loss of s is: 0.0032309130765497684
# Physical loss of a is: 0.00037159110070206225
# Iteration is: 1420
# Total loss is: 9439.86328125
# Data loss is: 9439.859375
# Physical loss of p is: 0.0004966211854480207
# Physical loss of s is: 0.003226329106837511
# Physical loss of a is: 0.00037518475437536836
# Iteration is: 1430
# Total loss is: 9434.48046875
# Data loss is: 9434.4765625
# Physical loss of p is: 0.0005104176816530526
# Physical loss of s is: 0.0032217949628829956
# Physical loss of a is: 0.0003788482863456011
# Iteration is: 1440
# Total loss is: 9429.04296875
# Data loss is: 9429.0390625
# Physical loss of p is: 0.0005245255888439715
# Physical loss of s is: 0.0032173050567507744
# Physical loss of a is: 0.0003825838794000447
# Iteration is: 1450
# Total loss is: 9423.548828125
# Data loss is: 9423.544921875
# Physical loss of p is: 0.0005389488069340587
# Physical loss of s is: 0.00321286846883595
# Physical loss of a is: 0.00038639307604171336
# Iteration is: 1460
# Total loss is: 9417.9970703125
# Data loss is: 9417.9931640625
# Physical loss of p is: 0.0005536999087780714
# Physical loss of s is: 0.0032084768172353506
# Physical loss of a is: 0.0003902780881617218
# Iteration is: 1470
# Total loss is: 9412.3896484375
# Data loss is: 9412.3857421875
# Physical loss of p is: 0.0005687816883437335
# Physical loss of s is: 0.0032041340600699186
# Physical loss of a is: 0.00039424013812094927
# Iteration is: 1480
# Total loss is: 9406.7197265625
# Data loss is: 9406.7158203125
# Physical loss of p is: 0.0005842056125402451
# Physical loss of s is: 0.0031998353078961372
# Physical loss of a is: 0.00039828085573390126
# Iteration is: 1490
# Total loss is: 9400.9921875
# Data loss is: 9400.98828125
# Physical loss of p is: 0.0005999777931720018
# Physical loss of s is: 0.0031955838203430176
# Physical loss of a is: 0.0004024020454380661
# Iteration is: 1500
# Total loss is: 9395.2021484375
# Data loss is: 9395.1982421875
# Physical loss of p is: 0.0006161044584587216
# Physical loss of s is: 0.0031913777347654104
# Physical loss of a is: 0.00040660661761648953
# Iteration is: 1510
# Total loss is: 9389.349609375
# Data loss is: 9389.345703125
# Physical loss of p is: 0.0006325982394628227
# Physical loss of s is: 0.0031872147228568792
# Physical loss of a is: 0.0004108959692530334
# Iteration is: 1520
# Total loss is: 9383.43359375
# Data loss is: 9383.4296875
# Physical loss of p is: 0.0006494632107205689
# Physical loss of s is: 0.003183095483109355
# Physical loss of a is: 0.00041527036228217185
# Iteration is: 1530
# Total loss is: 9377.4560546875
# Data loss is: 9377.4521484375
# Physical loss of p is: 0.0006667107809334993
# Physical loss of s is: 0.00317901698872447
# Physical loss of a is: 0.00041973547195084393
# Iteration is: 1540
# Total loss is: 9371.41015625
# Data loss is: 9371.40625
# Physical loss of p is: 0.0006843473529443145
# Physical loss of s is: 0.003174983896315098
# Physical loss of a is: 0.0004242889117449522
# Iteration is: 1550
# Total loss is: 9365.2978515625
# Data loss is: 9365.2939453125
# Physical loss of p is: 0.0007023855578154325
# Physical loss of s is: 0.003170992713421583
# Physical loss of a is: 0.0004289356293156743
# Iteration is: 1560
# Total loss is: 9359.1171875
# Data loss is: 9359.11328125
# Physical loss of p is: 0.0007208313327282667
# Physical loss of s is: 0.003167041577398777
# Physical loss of a is: 0.00043367722537368536
# Iteration is: 1570
# Total loss is: 9352.8701171875
# Data loss is: 9352.8662109375
# Physical loss of p is: 0.0007396943401545286
# Physical loss of s is: 0.0031631309539079666
# Physical loss of a is: 0.0004385150969028473
# Iteration is: 1580
# Total loss is: 9346.548828125
# Data loss is: 9346.544921875
# Physical loss of p is: 0.0007589858723804355
# Physical loss of s is: 0.0031592559535056353
# Physical loss of a is: 0.000443451339378953
# Iteration is: 1590
# Total loss is: 9340.16015625
# Data loss is: 9340.15625
# Physical loss of p is: 0.0007787190261296928
# Physical loss of s is: 0.0031554221641272306
# Physical loss of a is: 0.0004484878736548126
# Iteration is: 1600
# Total loss is: 9333.69921875
# Data loss is: 9333.6953125
# Physical loss of p is: 0.000798896246124059
# Physical loss of s is: 0.003151626093313098
# Physical loss of a is: 0.00045362822129391134
# Iteration is: 1610
# Total loss is: 9327.1611328125
# Data loss is: 9327.1572265625
# Physical loss of p is: 0.0008195327245630324
# Physical loss of s is: 0.0031478675082325935
# Physical loss of a is: 0.0004588736919686198
# Iteration is: 1620
# Total loss is: 9320.5517578125
# Data loss is: 9320.5478515625
# Physical loss of p is: 0.0008406405686400831
# Physical loss of s is: 0.0031441431492567062
# Physical loss of a is: 0.0004642270505428314
# Iteration is: 1630
# Total loss is: 9313.8642578125
# Data loss is: 9313.8603515625
# Physical loss of p is: 0.0008622240275144577
# Physical loss of s is: 0.0031404539477080107
# Physical loss of a is: 0.0004696889081969857
# Iteration is: 1640
# Total loss is: 9307.099609375
# Data loss is: 9307.095703125
# Physical loss of p is: 0.0008843006216920912
# Physical loss of s is: 0.0031367980409413576
# Physical loss of a is: 0.00047526322305202484
# Iteration is: 1650
# Total loss is: 9300.255859375
# Data loss is: 9300.251953125
# Physical loss of p is: 0.000906884204596281
# Physical loss of s is: 0.0031331777572631836
# Physical loss of a is: 0.0004809523234143853
# Iteration is: 1660
# Total loss is: 9293.3349609375
# Data loss is: 9293.3310546875
# Physical loss of p is: 0.0009299764060415328
# Physical loss of s is: 0.003129589604213834
# Physical loss of a is: 0.0004867581301368773
# Iteration is: 1670
# Total loss is: 9286.330078125
# Data loss is: 9286.3251953125
# Physical loss of p is: 0.0009535969002172351
# Physical loss of s is: 0.00312603241764009
# Physical loss of a is: 0.0004926835536025465
# Iteration is: 1680
# Total loss is: 9279.240234375
# Data loss is: 9279.2353515625
# Physical loss of p is: 0.000977752381004393
# Physical loss of s is: 0.0031225041020661592
# Physical loss of a is: 0.000498731154948473
# Iteration is: 1690
# Total loss is: 9272.0712890625
# Data loss is: 9272.06640625
# Physical loss of p is: 0.0010024587390944362
# Physical loss of s is: 0.003119006985798478
# Physical loss of a is: 0.0005049016326665878
# Iteration is: 1700
# Total loss is: 9264.8134765625
# Data loss is: 9264.80859375
# Physical loss of p is: 0.00102773099206388
# Physical loss of s is: 0.003115535480901599
# Physical loss of a is: 0.0005112006328999996
# Iteration is: 1710
# Total loss is: 9257.4697265625
# Data loss is: 9257.46484375
# Physical loss of p is: 0.0010535778710618615
# Physical loss of s is: 0.00311209331266582
# Physical loss of a is: 0.0005176272825337946
# Iteration is: 1720
# Total loss is: 9250.0361328125
# Data loss is: 9250.03125
# Physical loss of p is: 0.001080013345927
# Physical loss of s is: 0.003108676988631487
# Physical loss of a is: 0.0005241869948804379
# Iteration is: 1730
# Total loss is: 9242.5146484375
# Data loss is: 9242.509765625
# Physical loss of p is: 0.0011070535983890295
# Physical loss of s is: 0.003105283947661519
# Physical loss of a is: 0.0005308813415467739
# Iteration is: 1740
# Total loss is: 9234.90234375
# Data loss is: 9234.8974609375
# Physical loss of p is: 0.0011347034014761448
# Physical loss of s is: 0.003101918613538146
# Physical loss of a is: 0.0005377125344239175
# Iteration is: 1750
# Total loss is: 9227.1962890625
# Data loss is: 9227.19140625
# Physical loss of p is: 0.0011629861546680331
# Physical loss of s is: 0.00309857283718884
# Physical loss of a is: 0.0005446847062557936
# Iteration is: 1760
# Total loss is: 9219.396484375
# Data loss is: 9219.3916015625
# Physical loss of p is: 0.0011919151293113828
# Physical loss of s is: 0.0030952466186136007
# Physical loss of a is: 0.0005517995450645685
# Iteration is: 1770
# Total loss is: 9211.5009765625
# Data loss is: 9211.49609375
# Physical loss of p is: 0.0012215019669383764
# Physical loss of s is: 0.0030919439159333706
# Physical loss of a is: 0.0005590604851022363
# Iteration is: 1780
# Total loss is: 9203.505859375
# Data loss is: 9203.5009765625
# Physical loss of p is: 0.0012517607538029552
# Physical loss of s is: 0.0030886565800756216
# Physical loss of a is: 0.0005664705531671643
# Iteration is: 1790
# Total loss is: 9195.4130859375
# Data loss is: 9195.408203125
# Physical loss of p is: 0.0012827072059735656
# Physical loss of s is: 0.003085390431806445
# Physical loss of a is: 0.0005740317865274847
# Iteration is: 1800
# Total loss is: 9187.2216796875
# Data loss is: 9187.216796875
# Physical loss of p is: 0.0013143578544259071
# Physical loss of s is: 0.003082140116021037
# Physical loss of a is: 0.0005817493656650186
# Iteration is: 1810
# Total loss is: 9178.92578125
# Data loss is: 9178.9208984375
# Physical loss of p is: 0.0013467270182445645
# Physical loss of s is: 0.003078905399888754
# Physical loss of a is: 0.000589623989071697
# Iteration is: 1820
# Total loss is: 9170.52734375
# Data loss is: 9170.5224609375
# Physical loss of p is: 0.0013798326253890991
# Physical loss of s is: 0.003075680462643504
# Physical loss of a is: 0.0005976598476991057
# Iteration is: 1830
# Total loss is: 9162.0234375
# Data loss is: 9162.0185546875
# Physical loss of p is: 0.0014136877143755555
# Physical loss of s is: 0.003072471125051379
# Physical loss of a is: 0.000605861539952457
# Iteration is: 1840
# Total loss is: 9153.4111328125
# Data loss is: 9153.40625
# Physical loss of p is: 0.001448313589207828
# Physical loss of s is: 0.003069269936531782
# Physical loss of a is: 0.0006142298807390034
# Iteration is: 1850
# Total loss is: 9144.6904296875
# Data loss is: 9144.6845703125
# Physical loss of p is: 0.0014837231719866395
# Physical loss of s is: 0.0030660820193588734
# Physical loss of a is: 0.0006227694684639573
# Iteration is: 1860
# Total loss is: 9135.857421875
# Data loss is: 9135.8515625
# Physical loss of p is: 0.0015199343906715512
# Physical loss of s is: 0.003062899224460125
# Physical loss of a is: 0.0006314848433248699
# Iteration is: 1870
# Total loss is: 9126.9150390625
# Data loss is: 9126.9091796875
# Physical loss of p is: 0.001556961564347148
# Physical loss of s is: 0.0030597231816500425
# Physical loss of a is: 0.0006403766456060112
# Iteration is: 1880
# Total loss is: 9117.857421875
# Data loss is: 9117.8515625
# Physical loss of p is: 0.0015948254149407148
# Physical loss of s is: 0.003056550631299615
# Physical loss of a is: 0.0006494513363577425
# Iteration is: 1890
# Total loss is: 9108.6806640625
# Data loss is: 9108.6748046875
# Physical loss of p is: 0.0016335444524884224
# Physical loss of s is: 0.003053384367376566
# Physical loss of a is: 0.0006587121170014143
# Iteration is: 1900
# Total loss is: 9099.3876953125
# Data loss is: 9099.3818359375
# Physical loss of p is: 0.0016731360228732228
# Physical loss of s is: 0.003050218801945448
# Physical loss of a is: 0.0006681603263132274
# Iteration is: 1910
# Total loss is: 9089.9736328125
# Data loss is: 9089.9677734375
# Physical loss of p is: 0.001713617704808712
# Physical loss of s is: 0.00304705323651433
# Physical loss of a is: 0.0006778048118576407
# Iteration is: 1920
# Total loss is: 9080.4375
# Data loss is: 9080.431640625
# Physical loss of p is: 0.001755010336637497
# Physical loss of s is: 0.0030438853427767754
# Physical loss of a is: 0.0006876448751427233
# Iteration is: 1930
# Total loss is: 9070.779296875
# Data loss is: 9070.7734375
# Physical loss of p is: 0.0017973349895328283
# Physical loss of s is: 0.0030407141894102097
# Physical loss of a is: 0.0006976883742026985
# Iteration is: 1940
# Total loss is: 9060.9912109375
# Data loss is: 9060.9853515625
# Physical loss of p is: 0.0018406062154099345
# Physical loss of s is: 0.0030375400092452765
# Physical loss of a is: 0.0007079382194206119
# Iteration is: 1950
# Total loss is: 9051.076171875
# Data loss is: 9051.0703125
# Physical loss of p is: 0.001884845900349319
# Physical loss of s is: 0.0030343583784997463
# Physical loss of a is: 0.0007183978450484574
# Iteration is: 1960
# Total loss is: 9041.03125
# Data loss is: 9041.025390625
# Physical loss of p is: 0.0019300744170323014
# Physical loss of s is: 0.0030311651062220335
# Physical loss of a is: 0.0007290741777978837
# Iteration is: 1970
# Total loss is: 9030.8525390625
# Data loss is: 9030.8466796875
# Physical loss of p is: 0.0019763142336159945
# Physical loss of s is: 0.0030279660131782293
# Physical loss of a is: 0.0007399698370136321
# Iteration is: 1980
# Total loss is: 9020.5419921875
# Data loss is: 9020.5361328125
# Physical loss of p is: 0.0020235865376889706
# Physical loss of s is: 0.0030247513204813004
# Physical loss of a is: 0.0007510919822379947
# Iteration is: 1990
# Total loss is: 9010.0927734375
# Data loss is: 9010.0869140625
# Physical loss of p is: 0.0020719135645776987
# Physical loss of s is: 0.003021523356437683
# Physical loss of a is: 0.0007624468998983502
# Iteration is: 2000
# Total loss is: 8999.5029296875
# Data loss is: 8999.4970703125
# Physical loss of p is: 0.002121315337717533
# Physical loss of s is: 0.003018283285200596
# Physical loss of a is: 0.0007740363362245262
# Iteration is: 2010
# Total loss is: 8988.7724609375
# Data loss is: 8988.7666015625
# Physical loss of p is: 0.002171814674511552
# Physical loss of s is: 0.0030150243546813726
# Physical loss of a is: 0.0007858691969886422
# Iteration is: 2020
# Total loss is: 8977.8955078125
# Data loss is: 8977.8896484375
# Physical loss of p is: 0.0022234367206692696
# Physical loss of s is: 0.0030117430724203587
# Physical loss of a is: 0.000797951826825738
# Iteration is: 2030
# Total loss is: 8966.875
# Data loss is: 8966.869140625
# Physical loss of p is: 0.0022762035951018333
# Physical loss of s is: 0.003008446656167507
# Physical loss of a is: 0.0008102899882942438
# Iteration is: 2040
# Total loss is: 8955.7041015625
# Data loss is: 8955.6982421875
# Physical loss of p is: 0.0023301420733332634
# Physical loss of s is: 0.003005117876455188
# Physical loss of a is: 0.0008228887454606593
# Iteration is: 2050
# Total loss is: 8944.3837890625
# Data loss is: 8944.3779296875
# Physical loss of p is: 0.0023852665908634663
# Physical loss of s is: 0.003001771867275238
# Physical loss of a is: 0.0008357592159882188
# Iteration is: 2060
# Total loss is: 8932.9072265625
# Data loss is: 8932.900390625
# Physical loss of p is: 0.00244162674061954
# Physical loss of s is: 0.0029983932618051767
# Physical loss of a is: 0.0008489055908285081
# Iteration is: 2070
# Total loss is: 8921.275390625
# Data loss is: 8921.2685546875
# Physical loss of p is: 0.0024992262478917837
# Physical loss of s is: 0.0029949871823191643
# Physical loss of a is: 0.0008623391622677445
# Iteration is: 2080
# Total loss is: 8909.482421875
# Data loss is: 8909.4755859375
# Physical loss of p is: 0.0025581037625670433
# Physical loss of s is: 0.002991548739373684
# Physical loss of a is: 0.000876065285410732
# Iteration is: 2090
# Total loss is: 8897.5283203125
# Data loss is: 8897.521484375
# Physical loss of p is: 0.0026182925794273615
# Physical loss of s is: 0.0029880767688155174
# Physical loss of a is: 0.0008900959510356188
# Iteration is: 2100
# Total loss is: 8885.4091796875
# Data loss is: 8885.40234375
# Physical loss of p is: 0.002679807599633932
# Physical loss of s is: 0.0029845654498785734
# Physical loss of a is: 0.0009044400067068636
# Iteration is: 2110
# Total loss is: 8873.1220703125
# Data loss is: 8873.115234375
# Physical loss of p is: 0.0027426867745816708
# Physical loss of s is: 0.002981020137667656
# Physical loss of a is: 0.0009191067656502128
# Iteration is: 2120
# Total loss is: 8860.6630859375
# Data loss is: 8860.65625
# Physical loss of p is: 0.0028069764375686646
# Physical loss of s is: 0.0029774338472634554
# Physical loss of a is: 0.0009341094410046935
# Iteration is: 2130
# Total loss is: 8848.0283203125
# Data loss is: 8848.021484375
# Physical loss of p is: 0.002872697776183486
# Physical loss of s is: 0.0029738014563918114
# Physical loss of a is: 0.0009494581609033048
# Iteration is: 2140
# Total loss is: 8835.21875
# Data loss is: 8835.2119140625
# Physical loss of p is: 0.002939885947853327
# Physical loss of s is: 0.0029701259918510914
# Physical loss of a is: 0.0009651678847149014
# Iteration is: 2150
# Total loss is: 8822.228515625
# Data loss is: 8822.2216796875
# Physical loss of p is: 0.003008574480190873
# Physical loss of s is: 0.002966400934383273
# Physical loss of a is: 0.000981248333118856
# Iteration is: 2160
# Total loss is: 8809.052734375
# Data loss is: 8809.0458984375
# Physical loss of p is: 0.003078821813687682
# Physical loss of s is: 0.0029626234900206327
# Physical loss of a is: 0.000997717957943678
# Iteration is: 2170
# Total loss is: 8795.689453125
# Data loss is: 8795.6826171875
# Physical loss of p is: 0.0031506503000855446
# Physical loss of s is: 0.002958797151222825
# Physical loss of a is: 0.0010145949199795723
# Iteration is: 2180
# Total loss is: 8782.1357421875
# Data loss is: 8782.12890625
# Physical loss of p is: 0.0032241172157227993
# Physical loss of s is: 0.002954913303256035
# Physical loss of a is: 0.001031890045851469
# Iteration is: 2190
# Total loss is: 8768.388671875
# Data loss is: 8768.3818359375
# Physical loss of p is: 0.003299269126728177
# Physical loss of s is: 0.0029509696178138256
# Physical loss of a is: 0.001049625687301159
# Iteration is: 2200
# Total loss is: 8754.4453125
# Data loss is: 8754.4384765625
# Physical loss of p is: 0.0033761465456336737
# Physical loss of s is: 0.0029469665605574846
# Physical loss of a is: 0.0010678207036107779
# Iteration is: 2210
# Total loss is: 8740.2978515625
# Data loss is: 8740.2900390625
# Physical loss of p is: 0.0034548204857856035
# Physical loss of s is: 0.0029428976122289896
# Physical loss of a is: 0.001086497912183404
# Iteration is: 2220
# Total loss is: 8725.9423828125
# Data loss is: 8725.9345703125
# Physical loss of p is: 0.003535330295562744
# Physical loss of s is: 0.002938761143013835
# Physical loss of a is: 0.0011056768707931042
# Iteration is: 2230
# Total loss is: 8711.380859375
# Data loss is: 8711.373046875
# Physical loss of p is: 0.003617748385295272
# Physical loss of s is: 0.0029345538932830095
# Physical loss of a is: 0.001125384820625186
# Iteration is: 2240
# Total loss is: 8696.6015625
# Data loss is: 8696.59375
# Physical loss of p is: 0.0037021590396761894
# Physical loss of s is: 0.002930269343778491
# Physical loss of a is: 0.0011456492356956005
# Iteration is: 2250
# Total loss is: 8681.6025390625
# Data loss is: 8681.5947265625
# Physical loss of p is: 0.0037885932251811028
# Physical loss of s is: 0.0029259140137583017
# Physical loss of a is: 0.0011664958437904716
# Iteration is: 2260
# Total loss is: 8666.380859375
# Data loss is: 8666.373046875
# Physical loss of p is: 0.003877165261656046
# ...
# Physical loss of p is: 0.009601693600416183
# Physical loss of s is: 0.010059050284326077
# Physical loss of a is: 0.005688803270459175
# Iteration is: 29280
# Total loss is: 52.561222076416016
# Data loss is: 52.535987854003906
# Physical loss of p is: 0.009461707435548306
# Physical loss of s is: 0.01007061917334795
# Physical loss of a is: 0.0057024769484996796
# Iteration is: 29290
# Total loss is: 52.557865142822266
# Data loss is: 52.53263854980469
# Physical loss of p is: 0.009455215185880661
# Physical loss of s is: 0.010070023126900196
# Physical loss of a is: 0.005698755849152803
# Iteration is: 29300
# Total loss is: 52.554100036621094
# Data loss is: 52.528892517089844
# Physical loss of p is: 0.009457382373511791
# Physical loss of s is: 0.010064387694001198
# Physical loss of a is: 0.005686804186552763
# Iteration is: 29310
# Total loss is: 52.55048370361328
# Data loss is: 52.52528762817383
# Physical loss of p is: 0.009438792243599892
# Physical loss of s is: 0.010067255236208439
# Physical loss of a is: 0.005689944140613079
# Iteration is: 29320
# Total loss is: 52.54684829711914
# Data loss is: 52.521671295166016
# Physical loss of p is: 0.009435082785785198
# Physical loss of s is: 0.010064155794680119
# Physical loss of a is: 0.005680829286575317
# Iteration is: 29330
# Total loss is: 52.543006896972656
# Data loss is: 52.51784133911133
# Physical loss of p is: 0.009424117393791676
# Physical loss of s is: 0.010064615868031979
# Physical loss of a is: 0.00567823788151145
# Iteration is: 29340
# Total loss is: 52.539676666259766
# Data loss is: 52.514522552490234
# Physical loss of p is: 0.00941825844347477
# Physical loss of s is: 0.010062784887850285
# Physical loss of a is: 0.005673137493431568
# Iteration is: 29350
# Total loss is: 52.53584289550781
# Data loss is: 52.510704040527344
# Physical loss of p is: 0.009409967809915543
# Physical loss of s is: 0.010061812587082386
# Physical loss of a is: 0.005666617304086685
# Iteration is: 29360
# Total loss is: 52.53226852416992
# Data loss is: 52.50714111328125
# Physical loss of p is: 0.009401854127645493
# Physical loss of s is: 0.010061139240860939
# Physical loss of a is: 0.0056632040068507195
# Iteration is: 29370
# Total loss is: 52.52861404418945
# Data loss is: 52.503501892089844
# Physical loss of p is: 0.009393940679728985
# Physical loss of s is: 0.010060532949864864
# Physical loss of a is: 0.005658391863107681
# Iteration is: 29380
# Total loss is: 52.52480697631836
# Data loss is: 52.49970245361328
# Physical loss of p is: 0.00938694179058075
# Physical loss of s is: 0.01006009615957737
# Physical loss of a is: 0.005656431894749403
# Iteration is: 29390
# Total loss is: 52.52113342285156
# Data loss is: 52.496002197265625
# Physical loss of p is: 0.009408905170857906
# Physical loss of s is: 0.010063818655908108
# Physical loss of a is: 0.005661721341311932
# Iteration is: 29400
# Total loss is: 52.519222259521484
# Data loss is: 52.492496490478516
# Physical loss of p is: 0.010861831717193127
# Physical loss of s is: 0.01009431853890419
# Physical loss of a is: 0.005770513787865639
# Iteration is: 29410
# Total loss is: 52.53989028930664
# Data loss is: 52.5139274597168
# Physical loss of p is: 0.01005534641444683
# Physical loss of s is: 0.01002577506005764
# Physical loss of a is: 0.005882613826543093
# Iteration is: 29420
# Total loss is: 76.38780212402344
# Data loss is: 76.18453979492188
# Physical loss of p is: 0.1652095466852188
# Physical loss of s is: 0.009920296259224415
# Physical loss of a is: 0.028139423578977585
# Iteration is: 29430
# Total loss is: 53.61191940307617
# Data loss is: 53.57738494873047
# Physical loss of p is: 0.01657201535999775
# Physical loss of s is: 0.01042003184556961
# Physical loss of a is: 0.007539759855717421
# Iteration is: 29440
# Total loss is: 54.097633361816406
# Data loss is: 54.06313705444336
# Physical loss of p is: 0.019693052396178246
# Physical loss of s is: 0.01035667397081852
# Physical loss of a is: 0.004447073210030794
# Iteration is: 29450
# Total loss is: 53.242218017578125
# Data loss is: 53.21059799194336
# Physical loss of p is: 0.014204992912709713
# Physical loss of s is: 0.010067340917885303
# Physical loss of a is: 0.007347047328948975
# Iteration is: 29460
# Total loss is: 52.77074432373047
# Data loss is: 52.74464416503906
# Physical loss of p is: 0.011084195226430893
# Physical loss of s is: 0.010095669887959957
# Physical loss of a is: 0.0049165696837008
# Iteration is: 29470
# Total loss is: 52.58216857910156
# Data loss is: 52.55610656738281
# Physical loss of p is: 0.009911278262734413
# Physical loss of s is: 0.010076272301375866
# Physical loss of a is: 0.006075539626181126
# Iteration is: 29480
# Total loss is: 52.511470794677734
# Data loss is: 52.4865608215332
# Physical loss of p is: 0.009440538473427296
# Physical loss of s is: 0.010107926093041897
# Physical loss of a is: 0.005357934162020683
# Iteration is: 29490
# Total loss is: 52.491817474365234
# Data loss is: 52.4667854309082
# Physical loss of p is: 0.009324837476015091
# Physical loss of s is: 0.01010034792125225
# Physical loss of a is: 0.005606557242572308
# Iteration is: 29500
# Total loss is: 52.48855972290039
# Data loss is: 52.46355438232422
# Physical loss of p is: 0.009314092807471752
# Physical loss of s is: 0.01009275671094656
# Physical loss of a is: 0.005595052149146795
# Iteration is: 29510
# Total loss is: 52.48611831665039
# Data loss is: 52.461212158203125
# Physical loss of p is: 0.009309260174632072
# Physical loss of s is: 0.010092547163367271
# Physical loss of a is: 0.005505367647856474
# Iteration is: 29520
# Total loss is: 52.48274612426758
# Data loss is: 52.457763671875
# Physical loss of p is: 0.009300753474235535
# Physical loss of s is: 0.010091151110827923
# Physical loss of a is: 0.005593061447143555
# Iteration is: 29530
# Total loss is: 52.47932815551758
# Data loss is: 52.45439910888672
# Physical loss of p is: 0.009288614615797997
# Physical loss of s is: 0.010092364624142647
# Physical loss of a is: 0.005545979831367731
# Iteration is: 29540
# Total loss is: 52.476356506347656
# Data loss is: 52.451438903808594
# Physical loss of p is: 0.009283993393182755
# Physical loss of s is: 0.010089892894029617
# Physical loss of a is: 0.00554253114387393
# Iteration is: 29550
# Total loss is: 52.47339630126953
# Data loss is: 52.4484748840332
# Physical loss of p is: 0.009277229197323322
# Physical loss of s is: 0.010087152943015099
# Physical loss of a is: 0.005559228826314211
# Iteration is: 29560
# Total loss is: 52.47016525268555
# Data loss is: 52.44525909423828
# Physical loss of p is: 0.00927150622010231
# Physical loss of s is: 0.01008531078696251
# Physical loss of a is: 0.00554957939311862
# Iteration is: 29570
# Total loss is: 52.467308044433594
# Data loss is: 52.44241714477539
# Physical loss of p is: 0.009263699874281883
# Physical loss of s is: 0.010084464214742184
# Physical loss of a is: 0.005541324615478516
# Iteration is: 29580
# Total loss is: 52.46441650390625
# Data loss is: 52.43952941894531
# Physical loss of p is: 0.00925749633461237
# Physical loss of s is: 0.010082763619720936
# Physical loss of a is: 0.005544853396713734
# Iteration is: 29590
# Total loss is: 52.46141052246094
# Data loss is: 52.4365348815918
# Physical loss of p is: 0.009250316768884659
# Physical loss of s is: 0.010080814361572266
# Physical loss of a is: 0.005542071536183357
# Iteration is: 29600
# Total loss is: 52.4585075378418
# Data loss is: 52.43364334106445
# Physical loss of p is: 0.009245271794497967
# Physical loss of s is: 0.010078823193907738
# Physical loss of a is: 0.005538423545658588
# Iteration is: 29610
# Total loss is: 52.45539855957031
# Data loss is: 52.430545806884766
# Physical loss of p is: 0.00923866592347622
# Physical loss of s is: 0.01007715705782175
# Physical loss of a is: 0.005535557400435209
# Iteration is: 29620
# Total loss is: 52.45220947265625
# Data loss is: 52.4273681640625
# Physical loss of p is: 0.00923417042940855
# Physical loss of s is: 0.010074686259031296
# Physical loss of a is: 0.005532686598598957
# Iteration is: 29630
# Total loss is: 52.449317932128906
# Data loss is: 52.42446517944336
# Physical loss of p is: 0.009260568767786026
# Physical loss of s is: 0.010068430565297604
# Physical loss of a is: 0.005522685591131449
# Iteration is: 29640
# Total loss is: 52.447750091552734
# Data loss is: 52.421531677246094
# Physical loss of p is: 0.010673768818378448
# Physical loss of s is: 0.010030889883637428
# Physical loss of a is: 0.005511209834367037
# Iteration is: 29650
# Total loss is: 52.443702697753906
# Data loss is: 52.418270111083984
# Physical loss of p is: 0.009755789302289486
# Physical loss of s is: 0.010094323195517063
# Physical loss of a is: 0.005584399681538343
# Iteration is: 29660
# Total loss is: 52.44044876098633
# Data loss is: 52.41526412963867
# Physical loss of p is: 0.00963272713124752
# Physical loss of s is: 0.010047807358205318
# Physical loss of a is: 0.005504340399056673
# Iteration is: 29670
# Total loss is: 52.43716812133789
# Data loss is: 52.412322998046875
# Physical loss of p is: 0.009276647120714188
# Physical loss of s is: 0.010059532709419727
# Physical loss of a is: 0.005508821457624435
# Iteration is: 29680
# Total loss is: 52.43387985229492
# Data loss is: 52.40904998779297
# Physical loss of p is: 0.009228848852217197
# Physical loss of s is: 0.01007392443716526
# Physical loss of a is: 0.00552920950576663
# Iteration is: 29690
# Total loss is: 52.43087387084961
# Data loss is: 52.406105041503906
# Physical loss of p is: 0.009186635725200176
# Physical loss of s is: 0.010066756047308445
# Physical loss of a is: 0.005515984259545803
# Iteration is: 29700
# Total loss is: 52.42765426635742
# Data loss is: 52.402889251708984
# Physical loss of p is: 0.00919773243367672
# Physical loss of s is: 0.010060726664960384
# Physical loss of a is: 0.005506852641701698
# Iteration is: 29710
# Total loss is: 52.424625396728516
# Data loss is: 52.399879455566406
# Physical loss of p is: 0.009173211641609669
# Physical loss of s is: 0.010064349509775639
# Physical loss of a is: 0.005509488750249147
# Iteration is: 29720
# Total loss is: 52.42139434814453
# Data loss is: 52.39665985107422
# Physical loss of p is: 0.009169922210276127
# Physical loss of s is: 0.010061160661280155
# Physical loss of a is: 0.005504169501364231
# Iteration is: 29730
# Total loss is: 52.41830825805664
# Data loss is: 52.39358139038086
# Physical loss of p is: 0.009161046706140041
# Physical loss of s is: 0.010060676373541355
# Physical loss of a is: 0.005502806510776281
# Iteration is: 29740
# Total loss is: 52.41509246826172
# Data loss is: 52.390380859375
# Physical loss of p is: 0.009154949337244034
# Physical loss of s is: 0.010059041902422905
# Physical loss of a is: 0.005498409271240234
# Iteration is: 29750
# Total loss is: 52.411808013916016
# Data loss is: 52.387107849121094
# Physical loss of p is: 0.009147283621132374
# Physical loss of s is: 0.010058346204459667
# Physical loss of a is: 0.005493542645126581
# Iteration is: 29760
# Total loss is: 52.408546447753906
# Data loss is: 52.38386154174805
# Physical loss of p is: 0.009141307324171066
# Physical loss of s is: 0.010056703351438046
# Physical loss of a is: 0.005490705370903015
# Iteration is: 29770
# Total loss is: 52.4053955078125
# Data loss is: 52.380714416503906
# Physical loss of p is: 0.009135511703789234
# Physical loss of s is: 0.010055341757833958
# Physical loss of a is: 0.005487669259309769
# Iteration is: 29780
# Total loss is: 52.402339935302734
# Data loss is: 52.3776741027832
# Physical loss of p is: 0.009128260426223278
# Physical loss of s is: 0.01005441416054964
# Physical loss of a is: 0.005483200773596764
# Iteration is: 29790
# Total loss is: 52.398929595947266
# Data loss is: 52.37427520751953
# Physical loss of p is: 0.00912073440849781
# Physical loss of s is: 0.010053375735878944
# Physical loss of a is: 0.005481684114784002
# Iteration is: 29800
# Total loss is: 52.3956413269043
# Data loss is: 52.37099838256836
# Physical loss of p is: 0.009112242609262466
# Physical loss of s is: 0.010052784346044064
# Physical loss of a is: 0.005477014929056168
# Iteration is: 29810
# Total loss is: 52.39255142211914
# Data loss is: 52.367897033691406
# Physical loss of p is: 0.0091157928109169
# Physical loss of s is: 0.01005509402602911
# Physical loss of a is: 0.005479881539940834
# Iteration is: 29820
# Total loss is: 52.390342712402344
# Data loss is: 52.36453628540039
# Physical loss of p is: 0.010164916515350342
# Physical loss of s is: 0.010083547793328762
# Physical loss of a is: 0.005557335447520018
# Iteration is: 29830
# Total loss is: 52.38605880737305
# Data loss is: 52.361183166503906
# Physical loss of p is: 0.00939505361020565
# Physical loss of s is: 0.010029929690063
# Physical loss of a is: 0.005451264791190624
# Iteration is: 29840
# Total loss is: 52.383155822753906
# Data loss is: 52.357967376708984
# Physical loss of p is: 0.009598447009921074
# Physical loss of s is: 0.010068561881780624
# Physical loss of a is: 0.005524586886167526
# Iteration is: 29850
# Total loss is: 52.379173278808594
# Data loss is: 52.35456848144531
# Physical loss of p is: 0.009089085273444653
# Physical loss of s is: 0.010049156844615936
# Physical loss of a is: 0.005466061644256115
# Iteration is: 29860
# Total loss is: 52.37583541870117
# Data loss is: 52.35118865966797
# Physical loss of p is: 0.00916392169892788
# Physical loss of s is: 0.0100361667573452
# Physical loss of a is: 0.00544643122702837
# Iteration is: 29870
# Total loss is: 52.3725700378418
# Data loss is: 52.34800720214844
# Physical loss of p is: 0.009067362174391747
# Physical loss of s is: 0.010043833404779434
# Physical loss of a is: 0.0054493434727191925
# Iteration is: 29880
# Total loss is: 52.36930465698242
# Data loss is: 52.34474563598633
# Physical loss of p is: 0.00906413048505783
# Physical loss of s is: 0.010045476257801056
# Physical loss of a is: 0.005452555604279041
# Iteration is: 29890
# Total loss is: 52.36585998535156
# Data loss is: 52.34131622314453
# Physical loss of p is: 0.009062053635716438
# Physical loss of s is: 0.010039526969194412
# Physical loss of a is: 0.005440707318484783
# Iteration is: 29900
# Total loss is: 52.362525939941406
# Data loss is: 52.33799743652344
# Physical loss of p is: 0.009046623483300209
# Physical loss of s is: 0.010041194036602974
# Physical loss of a is: 0.00544109707698226
# Iteration is: 29910
# Total loss is: 52.3590202331543
# Data loss is: 52.334503173828125
# Physical loss of p is: 0.009041144512593746
# Physical loss of s is: 0.010039236396551132
# Physical loss of a is: 0.005436713807284832
# Iteration is: 29920
# Total loss is: 52.35551834106445
# Data loss is: 52.331016540527344
# Physical loss of p is: 0.009033815935254097
# Physical loss of s is: 0.010038189589977264
# Physical loss of a is: 0.005431592930108309
# Iteration is: 29930
# Total loss is: 52.35226821899414
# Data loss is: 52.32777786254883
# Physical loss of p is: 0.0090273292735219
# Physical loss of s is: 0.01003690343350172
# Physical loss of a is: 0.005427294876426458
# Iteration is: 29940
# Total loss is: 52.349021911621094
# Data loss is: 52.32453918457031
# Physical loss of p is: 0.009020836092531681
# Physical loss of s is: 0.010035484097898006
# Physical loss of a is: 0.0054261405020952225
# Iteration is: 29950
# Total loss is: 52.345584869384766
# Data loss is: 52.32109832763672
# Physical loss of p is: 0.009014580398797989
# Physical loss of s is: 0.010033909231424332
# Physical loss of a is: 0.005439962260425091
# Iteration is: 29960
# Total loss is: 52.406654357910156
# Data loss is: 52.38132095336914
# Physical loss of p is: 0.009442262351512909
# Physical loss of s is: 0.010022268630564213
# Physical loss of a is: 0.0058709303848445415
# Iteration is: 29970
# Total loss is: 66.63033294677734
# Data loss is: 66.49748229980469
# Physical loss of p is: 0.10234635323286057
# Physical loss of s is: 0.009922543540596962
# Physical loss of a is: 0.020574461668729782
# Iteration is: 29980
# Total loss is: 56.48469161987305
# Data loss is: 56.42727279663086
# Physical loss of p is: 0.03630872070789337
# Physical loss of s is: 0.010196823626756668
# Physical loss of a is: 0.010913141071796417
# Iteration is: 29990
# Total loss is: 52.69553756713867
# Data loss is: 52.66754150390625
# Physical loss of p is: 0.011384519748389721
# Physical loss of s is: 0.010144151747226715
# Physical loss of a is: 0.0064711663872003555
# Iteration is: 30000
# Total loss is: 52.55109786987305
# Data loss is: 52.525840759277344
# Physical loss of p is: 0.010430941358208656
# Physical loss of s is: 0.010072968900203705
# Physical loss of a is: 0.004753586370497942
# Training time: 102.4018

# %%
it = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]
loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]
loss_phia_list = [loss_fisa[i].numpy() for i in range(0,Nmax)]


plt.semilogy(it, np.asarray(loss_data_list), 'b-', linewidth = 2, label = 'Data')  
plt.semilogy(it, np.asarray(loss_phip_list), 'r-', linewidth = 2, label = '$\phi_p$')    
plt.semilogy(it, np.asarray(loss_phis_list), 'g-', linewidth = 2, label = '$\phi_s$')    
plt.semilogy(it, np.asarray(loss_phia_list), 'y-', linewidth = 2, label = '$\phi_a$')       



plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
m
# Out:
# [<tf.Variable 'Variable:0' shape=(1, 1) dtype=float32, numpy=array([[0.391]], dtype=float32)>]

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
T_star_tf = tf.convert_to_tensor(T_star[:len(T_exp)], dtype=tf.float32)    
u_pred = predict(T_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp=u_pred[:,0:1]
lns=u_pred[:,1:2]
lna=u_pred[:,2:3]

p=tf.exp(lnp)
s=tf.exp(lns)
a=tf.exp(lna)
phi_p = predict(tf.concat([p, s, a],1), W_phip, b_phip)
phi_a = predict(tf.concat([p, a],1), W_phia, b_phia)

phi_s=np.array(p*s*m[0])

# %%
plt.plot(T_star_tf, p, label='Prediction P')
plt.plot(T_star_tf, s, label='Prediction S')
plt.plot(T_star_tf, a, label='Prediction A')


# for i in range(N_exp):
#     plt.plot(T_star[i*len(T_exp):(i+1)*len(T_exp)],P_star[i*len(T_exp):(i+1)*len(T_exp)],linestyle=':')

plt.scatter(T_u_train, p_train, marker='x', color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(p, s)
plt.plot(a, s)

plt.xlabel('P')
plt.ylabel('S')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(a, phi_p, label='Prediction')
plt.plot(a, phi_a, label='Prediction')

# %%
plt.plot(p, phi_p, label='Prediction')
plt.plot(p, phi_a, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(s, phi_p, label='Prediction')
plt.plot(s, phi_a, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(s, phi_s, label='Prediction')
# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_s(P)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
Nt=10000
T_int=np.zeros(Nt)
P_int=np.zeros(Nt)
S_int=np.zeros(Nt)
A_int=np.zeros(Nt)


dt=0.0001

T_int[0]=0
# P_int[0]=np.mean(uu1) #Initial conditions
P_int[0]=np.array(p[0]) #Initial conditions
S_int[0]=np.array(s[0]) #Initial conditions
A_int[0]=np.array(a[0]) #Initial conditions



for i in range(1,Nt):

    PSA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    PA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)

    PHI_P=predict(PSA , W_phip, b_phip)
    PHI_A=predict(PA , W_phia, b_phia)

    P_int[i]=P_int[i-1]+PHI_P*dt
    A_int[i]=A_int[i-1]+PHI_A*dt
    S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m[0])*dt
    T_int[i]=T_int[i-1]+dt

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')
plt.plot(T_int, A_int, color='green', linestyle='--', label='Numeric integration dAdT')



plt.plot(T_star_tf, p, label='PINN Prediction P')
plt.plot(T_star_tf, s, label='PINN Prediction S')
plt.plot(T_star_tf, a, label='PINN Prediction A')

plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
# Create and train the PySR model
model_phip = PySRRegressor(
    niterations=500,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    # unary_operators=["inv(x) = 1/x"],
    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    # constraints={"/": (-1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00001,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
    maxsize=30,
)

# %%
# Fit phi
model_phip.fit(tf.concat([p, s, a],1), phi_p)
print(model_phip)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.520e+05
# Head worker occupation: 40.1%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 569 / 7500 total iterations (7.587%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.197e+00  6.000e-03  y = (x₂ + -0.36086) * (1.6571 + x₀)
# 9           8.563e-01  1.674e-01  y = ((43.097 * (x₂ + -0.36749)) * x₀) + -2.3652
# 11          8.412e-01  8.881e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4597) * x₀) + -2.2226
# 13          8.412e-01  1.743e-05  y = (x₀ * (((x₂ * 1.2497) + -0.47636) * (0.07713 + 34.606))) +...
#                                    -2.2125
# 15          7.481e-01  5.863e-02  y = x₂ * (((x₂ * -9.2251) * x₁) + (((-0.42149 + x₂) * 76.659) ...
#                                   * x₀))
# 17          7.306e-01  1.183e-02  y = (x₂ * (((x₂ * -9.2251) * x₁) + (((-0.42149 + x₂) * 76.659)...
#                                    * x₀))) + -0.1601
# 19          6.612e-01  4.996e-02  y = 10.069 + (((-22.514 + (-7.5181 * x₂)) * x₁) + ((((x₂ + -0....
#                                   44466) * 93.526) * x₀) + -0.56047))
# 21          5.158e-01  1.241e-01  y = 15.472 + (((-45.439 + (-11.527 * x₂)) * x₁) + (((((x₂ + -0...
#                                   .46974) * 110.88) * x₀) + x₁) + 5.7663))
# 23          4.527e-01  6.528e-02  y = (6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.848 * x₂))) + (...
#                                   (x₀ * ((x₂ + -0.49001) * 116.6)) + 11.362)))) * 1.1122
# 25          4.506e-01  2.255e-03  y = (6.8747 + (((x₁ * (-64.706 + (-12.848 * x₂))) + ((((x₂ + -...
#                                   0.49001) * (116.6 + x₂)) * x₀) + 11.362)) + 13.374)) * 1.1122
# 27          4.499e-01  7.727e-04  y = (6.9829 + (((x₁ * (-64.714 + (-12.508 * (x₂ + 0.075684))))...
#                                    + (((((x₂ + -0.49377) * 116.6) + x₂) * x₀) + 11.47)) + 13.482...
#                                   )) * 1.1315
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Head worker occupation: 36.8%
# Progress: 1224 / 7500 total iterations (16.320%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.197e+00  6.000e-03  y = (x₂ + -0.36086) * (1.6571 + x₀)
# 9           8.412e-01  1.763e-01  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          8.369e-01  2.590e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4648) * (x₀ + -0.0024676)...
#                                   ) + -2.2226
# 15          7.481e-01  5.604e-02  y = x₂ * (((x₂ * -9.2251) * x₁) + (((-0.42149 + x₂) * 76.659) ...
#                                   * x₀))
# 17          7.170e-01  2.126e-02  y = x₂ * ((((x₂ * -11.723) * x₁) + x₀) + (((x₂ + -0.43702) * 9...
#                                   0.477) * x₀))
# 19          6.612e-01  4.053e-02  y = 10.069 + (((-22.514 + (-7.5181 * x₂)) * x₁) + ((((x₂ + -0....
#                                   44466) * 93.526) * x₀) + -0.56047))
# 21          4.691e-01  1.716e-01  y = 6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.848 * x₂))) + ((...
#                                   x₀ * ((x₂ + -0.49001) * 116.6)) + 11.362)))
# 23          4.526e-01  1.786e-02  y = (6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.844 * x₂))) + (...
#                                   (x₀ * ((x₂ + -0.49001) * 116.6)) + 11.362)))) * 1.1122
# 25          4.501e-01  2.823e-03  y = ((((x₁ * ((x₂ * (-12.844 + x₁)) + -64.801)) + ((x₀ * ((x₂ ...
#                                   + -0.48885) * 116.56)) + 11.319)) + 13.331) + 6.8316) * 1.1234
# 27          4.364e-01  1.537e-02  y = ((6.7997 + (13.299 + ((x₁ * (-64.747 + ((x₂ * -12.815) + x...
#                                   ₁))) + (11.287 + (((x₂ + -0.48941) * 116.61) * x₀))))) * 2.375...
#                                   8) * x₁
# 29          4.325e-01  4.484e-03  y = (((6.8747 + (13.374 + (((x₀ * ((-0.49001 + x₂) * 116.6)) +...
#                                    11.362) + (x₁ * (-64.706 + (x₂ * -12.848)))))) * 1.2453) * x₁...
#                                   ) * (1.3947 + x₁)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+05
# Head worker occupation: 33.2%
# Progress: 1866 / 7500 total iterations (24.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.197e+00  6.000e-03  y = (x₂ + -0.36086) * (1.6571 + x₀)
# 9           8.412e-01  1.763e-01  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          8.369e-01  2.590e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4648) * (x₀ + -0.0024676)...
#                                   ) + -2.2226
# 15          7.095e-01  8.254e-02  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * 97.287) * x₀)) ...
#                                   * x₂
# 17          7.080e-01  1.054e-03  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * (x₂ + 97.287)) ...
#                                   * x₀)) * x₂
# 19          6.612e-01  3.423e-02  y = 10.069 + (((-22.514 + (-7.5181 * x₂)) * x₁) + ((((x₂ + -0....
#                                   44466) * 93.526) * x₀) + -0.56047))
# 21          4.591e-01  1.823e-01  y = 6.7994 + (13.298 + ((x₁ * (-64.747 + (-12.141 * x₂))) + ((...
#                                   x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287)))
# 23          4.519e-01  7.952e-03  y = (6.8747 + (13.374 + ((x₁ * (-64.706 + (-12.844 * x₂))) + (...
#                                   (((-0.49001 + x₂) * 116.6) * x₀) + 11.362)))) * 1.1373
# 25          4.377e-01  1.599e-02  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.141 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3409
# 27          4.354e-01  2.632e-03  y = (x₁ * (((((((x₂ + -0.48804) * (116.83 + -1.1456)) * x₀) + ...
#                                   11.287) + (x₁ * (-64.747 + (-12.141 * x₂)))) + 13.298) + 6.799...
#                                   4)) * 2.3409
# 29          4.325e-01  3.272e-03  y = (((6.8747 + (13.374 + (((x₀ * ((-0.49001 + x₂) * 116.6)) +...
#                                    11.362) + (x₁ * (-64.706 + (x₂ * -12.848)))))) * 1.2453) * x₁...
#                                   ) * (1.3947 + x₁)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.760e+05
# Head worker occupation: 32.8%
# Progress: 2526 / 7500 total iterations (33.680%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.131e+00  3.441e-02  y = (29.776 * x₀) * (-0.46942 + x₂)
# 9           8.412e-01  1.479e-01  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          8.368e-01  2.604e-03  y = ((((-0.38058 + x₂) * 29.725) * 1.4648) * (x₀ + -0.0024842)...
#                                   ) + -2.2226
# 15          7.095e-01  8.253e-02  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * 97.287) * x₀)) ...
#                                   * x₂
# 17          7.080e-01  1.054e-03  y = ((x₁ * (x₂ * -12.374)) + (((x₂ + -0.431) * (x₂ + 97.287)) ...
#                                   * x₀)) * x₂
# 19          6.164e-01  6.930e-02  y = ((x₁ * (((-4.3012 + -5.1621) * x₂) + -23.074)) + (((-0.448...
#                                   43 + x₂) * 92.615) * x₀)) + 10.466
# 21          4.591e-01  1.472e-01  y = 6.7994 + (13.298 + ((x₁ * (-64.747 + (-12.141 * x₂))) + ((...
#                                   x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287)))
# 23          4.516e-01  8.320e-03  y = (6.7994 + (13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + ...
#                                   11.287) + (x₁ * (-64.747 + (-12.141 * x₂)))))) * 1.115
# 25          4.365e-01  1.701e-02  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3409
# 27          4.354e-01  1.257e-03  y = (x₁ * (((((((x₂ + -0.48804) * (116.83 + -1.1893)) * x₀) + ...
#                                   11.287) + (x₁ * (-64.747 + (-12.141 * x₂)))) + 13.298) + 6.799...
#                                   4)) * 2.3409
# 29          4.277e-01  8.888e-03  y = ((((6.7994 + ((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287...
#                                   ) + (x₁ * (-64.747 + (x₂ * -12.374)))) + 13.298)) * 2.257) * x...
#                                   ₁) * 2.3409) * x₁
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+05
# Head worker occupation: 32.8%
# Progress: 3169 / 7500 total iterations (42.253%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.092e-02  y = (((x₂ + -0.38133) * 43.11) * x₀) + -2.1954
# 11          8.412e-01  7.480e-06  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 19          6.164e-01  3.462e-02  y = ((x₁ * (((-4.3012 + -5.1621) * x₂) + -23.074)) + (((-0.448...
#                                   43 + x₂) * 92.615) * x₀)) + 10.466
# 21          4.589e-01  1.476e-01  y = 6.8086 + (13.308 + ((x₁ * (-64.813 + (-11.933 * x₂))) + (1...
#                                   1.296 + (x₀ * ((x₂ + -0.48825) * 117.01)))))
# 23          4.512e-01  8.452e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.365e-01  1.657e-02  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3409
# 27          4.353e-01  1.327e-03  y = ((((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287) + (((-64....
#                                   747 + (-12.374 * x₂)) * x₁) + 0.10989)) + 13.298) + 6.7224) * ...
#                                   x₁) * 2.3409
# 29          4.277e-01  8.819e-03  y = ((((6.7994 + ((((((x₂ + -0.48804) * 116.83) * x₀) + 11.287...
#                                   ) + (x₁ * (-64.747 + (x₂ * -12.374)))) + 13.298)) * 2.257) * x...
#                                   ₁) * 2.3409) * x₁
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+05
# Head worker occupation: 29.0%
# Progress: 3808 / 7500 total iterations (50.773%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.078e-01  5.818e-05  y = x₂ * ((((x₂ + -0.42974) * (97.292 + 0.23239)) * x₀) + ((-1...
#                                   2.349 * x₂) * x₁))
# 19          5.448e-01  1.309e-01  y = ((17.423 + (x₀ * ((x₂ + -0.48452) * 118.54))) + (x₁ * (-63...
#                                   .006 + (-12.99 * x₂)))) + 12.934
# 21          4.567e-01  8.817e-02  y = 6.8484 + ((((-65.252 + (-11.962 * x₂)) * x₁) + (11.337 + (...
#                                   x₀ * ((-0.48764 + x₂) * 118.42)))) + 13.349)
# 23          4.512e-01  6.078e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.362e-01  1.686e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.679e-03  y = ((((((-64.929 + (x₂ * -12.703)) * x₁) + (((((-0.35746 + -0...
#                                   .13282) + x₂) * 116.66) * x₀) + 11.416)) + 13.428) + 6.8516) *...
#                                    x₁) * 2.3542
# 29          4.230e-01  1.366e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.860e+05
# Head worker occupation: 29.7%
# Progress: 4433 / 7500 total iterations (59.107%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.073e-01  4.164e-04  y = x₂ * ((((x₂ + -0.42879) * (97.209 + x₂)) * x₀) + (x₁ * (-1...
#                                   2.612 * x₂)))
# 19          4.719e-01  2.023e-01  y = 13.172 + ((x₁ * ((-13.34 * x₂) + -63.133)) + (17.661 + (((...
#                                   x₂ + -0.4867) * 118.57) * x₀)))
# 21          4.566e-01  1.654e-02  y = 6.9118 + (((x₁ * ((-12.387 * x₂) + -65.266)) + (((118.53 *...
#                                    (-0.489 + x₂)) * x₀) + 11.401)) + 13.413)
# 23          4.512e-01  5.948e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.362e-01  1.686e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.679e-03  y = ((((((-64.929 + (x₂ * -12.703)) * x₁) + (((((-0.35746 + -0...
#                                   .13282) + x₂) * 116.66) * x₀) + 11.416)) + 13.428) + 6.8516) *...
#                                    x₁) * 2.3542
# 29          4.230e-01  1.366e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+05
# Head worker occupation: 32.8%
# Progress: 5065 / 7500 total iterations (67.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.920e-01  3.015e-02  y = ((((-0.40592 + x₂) * 29.751) * 1.869) * (x₀ + -0.038664)) ...
#                                   + -1.9979
# 15          7.079e-01  5.610e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.073e-01  4.164e-04  y = x₂ * ((((x₂ + -0.42879) * (97.209 + x₂)) * x₀) + (x₁ * (-1...
#                                   2.612 * x₂)))
# 19          4.719e-01  2.023e-01  y = 13.172 + ((x₁ * ((-13.34 * x₂) + -63.133)) + (17.661 + (((...
#                                   x₂ + -0.4867) * 118.57) * x₀)))
# 21          4.566e-01  1.654e-02  y = 6.9118 + (((x₁ * ((-12.387 * x₂) + -65.266)) + (((118.53 *...
#                                    (-0.489 + x₂)) * x₀) + 11.401)) + 13.413)
# 23          4.512e-01  5.948e-03  y = ((13.298 + (((x₀ * ((x₂ + -0.48804) * 116.83)) + 11.287) +...
#                                    (x₁ * (-64.747 + (-12.141 * x₂))))) + 6.7994) * 1.0853
# 25          4.362e-01  1.686e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.679e-03  y = ((((((-64.929 + (x₂ * -12.703)) * x₁) + (((((-0.35746 + -0...
#                                   .13282) + x₂) * 116.66) * x₀) + 11.416)) + 13.428) + 6.8516) *...
#                                    x₁) * 2.3542
# 29          4.230e-01  1.366e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+05
# Head worker occupation: 33.4%
# Progress: 5709 / 7500 total iterations (76.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.135e-02  y = ((x₂ * 20.255) + -9.4378) * x₀
# 9           8.412e-01  9.093e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.918e-01  3.025e-02  y = ((((x₂ + -0.4056) * 29.752) * 1.8782) * (x₀ + -0.038143)) ...
#                                   + -2.0602
# 15          7.079e-01  5.600e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          7.073e-01  4.164e-04  y = x₂ * ((((x₂ + -0.42879) * (97.209 + x₂)) * x₀) + (x₁ * (-1...
#                                   2.612 * x₂)))
# 19          4.719e-01  2.023e-01  y = 13.172 + ((x₁ * ((-13.34 * x₂) + -63.133)) + (17.661 + (((...
#                                   x₂ + -0.4867) * 118.57) * x₀)))
# 21          4.545e-01  1.884e-02  y = 13.058 + ((x₁ * ((-12.161 * x₂) + -63.259)) + (17.547 + ((...
#                                   ((-0.49053 + x₂) * 118.81) + x₀) * x₀)))
# 23          4.502e-01  4.741e-03  y = (13.058 + ((x₁ * ((-12.161 * x₂) + -63.259)) + (17.547 + (...
#                                   (((-0.49053 + x₂) * 118.81) + x₀) * x₀)))) * 1.0595
# 25          4.362e-01  1.577e-02  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * 2.3542
# 27          4.347e-01  1.688e-03  y = ((((((((x₂ + -0.48804) * 117.41) * x₀) + 11.287) + (x₁ * (...
#                                   -64.747 + (-12.374 * x₂)))) + 13.298) + 6.7994) * x₁) * (1.794...
#                                   8 + x₁)
# 29          4.230e-01  1.365e-02  y = (7.3355 + (((x₁ * (-64.633 + (x₂ * -13.665))) + (11.823 + ...
#                                   (x₀ * ((-0.61879 + (x₂ + ((0.35662 * x₀) * x₂))) * 116.92)))) ...
#                                   + 13.835)) + 0.87348
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+05
# Head worker occupation: 34.0%
# Progress: 6341 / 7500 total iterations (84.547%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.143e-02  y = (-9.3086 + (19.967 * x₂)) * x₀
# 9           8.412e-01  9.084e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.916e-01  3.040e-02  y = ((((x₂ + -0.4056) * 29.752) * 1.8782) * (x₀ + -0.038143)) ...
#                                   + -2.0326
# 15          7.079e-01  5.585e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          5.141e-01  1.599e-01  y = ((x₁ * (-75.369 + (-12.187 * x₂))) + (((x₂ + -0.50164) * 1...
#                                   20.43) * x₀)) + 36.683
# 19          4.565e-01  5.950e-02  y = ((x₁ * (-75.081 + (x₂ * -14.358))) + (((-0.56954 + (1.1589...
#                                    * x₂)) * 113.34) * x₀)) + 36.744
# 21          4.321e-01  2.739e-02  y = ((x₀ * ((-0.48463 + x₂) * 119.79)) + (x₁ * ((-80.753 + (x₂...
#                                    * (x₂ * -12.525))) * x₁))) + 16.347
# 23          4.284e-01  4.334e-03  y = ((x₀ * ((-0.48463 + x₂) * 119.79)) + (x₁ * ((-80.753 + ((x...
#                                   ₂ * (x₂ * -12.525)) + -0.21999)) * x₁))) + 16.347
# 25          4.255e-01  3.349e-03  y = 15.672 + ((((-0.47831 + x₂) * 120.4) * x₀) + (((-80.752 + ...
#                                   (((x₂ * -8.4032) * (x₂ + x₀)) * x₂)) * x₁) * x₁))
# 27          4.209e-01  5.469e-03  y = 15.672 + ((((-80.752 + ((-8.4032 * x₂) * ((x₂ * x₂) + x₀))...
#                                   ) * x₁) * x₁) + ((((-0.47831 + x₂) * 120.4) + x₀) * x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+05
# Head worker occupation: 31.5%
# Progress: 6995 / 7500 total iterations (93.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.245e+00  1.594e+01  y = x₂
# 3           1.233e+00  4.842e-03  y = -0.10954 + x₂
# 5           1.211e+00  8.820e-03  y = (1.7508 * x₂) + -0.55601
# 7           1.009e+00  9.143e-02  y = (-9.3086 + (19.967 * x₂)) * x₀
# 9           8.412e-01  9.084e-02  y = -2.2123 + (x₀ * ((43.34 * x₂) + -16.52))
# 11          8.412e-01  -0.000e+00  y = (((29.724 * (-0.38119 + x₂)) * 1.4581) * x₀) + -2.2122
# 13          7.916e-01  3.040e-02  y = ((((x₂ + -0.4056) * 29.752) * 1.8782) * (x₀ + -0.038143)) ...
#                                   + -2.0326
# 15          7.079e-01  5.585e-02  y = x₂ * ((((x₂ + -0.42974) * 97.292) * x₀) + (x₁ * (-12.349 *...
#                                    x₂)))
# 17          5.141e-01  1.599e-01  y = ((x₁ * (-75.369 + (-12.187 * x₂))) + (((x₂ + -0.50164) * 1...
#                                   20.43) * x₀)) + 36.683
# 19          4.565e-01  5.950e-02  y = ((x₁ * (-75.081 + (x₂ * -14.358))) + (((-0.56954 + (1.1589...
#                                    * x₂)) * 113.34) * x₀)) + 36.744
# 21          4.276e-01  3.269e-02  y = ((x₀ * ((-0.4871 + x₂) * 119.38)) + (((-82.661 + (x₂ * (x₂...
#                                    * -12.598))) * x₁) * x₁)) + 16.825
# 23          4.243e-01  3.853e-03  y = 16.903 + (((((-0.49353 + x₂) * 119.66) + x₀) * x₀) + (x₁ *...
#                                    ((-82.661 + ((x₂ * -12.598) * x₂)) * x₁)))
# 25          4.226e-01  2.007e-03  y = 16.903 + (((((-0.49353 + x₂) * 119.66) + x₀) * x₀) + (x₁ *...
#                                    (((((x₂ * -13.238) + 0.79779) * x₂) + -82.72) * x₁)))
# 27          4.209e-01  2.001e-03  y = 15.672 + ((((-80.752 + ((-8.4032 * x₂) * ((x₂ * x₂) + x₀))...
#                                   ) * x₁) * x₁) + ((((-0.47831 + x₂) * 120.4) + x₀) * x₀))
# 29          4.181e-01  3.358e-03  y = 15.672 + ((((-80.752 + ((-8.4032 * x₂) * ((x₂ * x₂) + x₀))...
#                                   ) * x₁) * x₁) + ((((-0.47831 + x₂) * 120.4) + (x₀ + -0.10672))...
#                                    * x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                                 x2
# 	1         4.842331e-03                                   -0.10953539 + x2
# 	2         8.819936e-03                     (1.7507865 * x2) + -0.55600756
# 	3         9.143341e-02                  (-9.30858 + (19.96653 * x2)) * x0
# 	4         9.084055e-02  -2.2122555 + (x0 * ((43.339825 * x2) + -16.520...
# 	5         4.160702e-08  (((29.723581 * (-0.3811865 + x2)) * 1.4580895)...
# 	6         3.444665e-02  ((x1 * -15.374885) + (((x2 + -0.42598626) * 46...
# 	7         5.180171e-02  x2 * ((((x2 + -0.42973825) * 97.291626) * x0) ...
# 	8   >>>>  1.599252e-01  ((x1 * (-75.36943 + (-12.186699 * x2))) + (((x...
# 	9         5.949527e-02  ((x1 * (-75.08056 + (x2 * -14.358229))) + (((-...
# 	10        3.268603e-02  ((x0 * ((-0.4870994 + x2) * 119.38031)) + (((-...
# 	11        3.852949e-03  16.903307 + (((((-0.49353454 + x2) * 119.66418...
# 	12        2.006812e-03  16.903307 + (((((-0.49353454 + x2) * 119.66418...
# 	13        7.257215e-03  (16.903307 + (((((-0.49353454 + x2) * 119.6641...
# 	14        1.244917e-03  (16.903307 + ((x0 * (((-0.49353454 + x2) * 119...
#
# 	        loss  complexity
# 	0   1.244771           1
# 	1   1.232774           3
# 	2   1.211219           5
# 	3   1.008799           7
# 	4   0.841204           9
# 	5   0.841204          11
# 	6   0.785202          13
# 	7   0.707925          15
# 	8   0.514136          17
# 	9   0.456458          19
# 	10  0.427573          21
# 	11  0.424291          23
# 	12  0.422591          25
# 	13  0.416502          27
# 	14  0.415466          29
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_phip.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=10
expr=model_phip.sympy(chose)
expr
sympy.expand(expr)
# Out:
# 119.38031*x0*x2 - 58.150077372814*x0 - 12.598289*x1**2*x2**2 - 82.660515*x1**2 + 16.824549

# %%
symb1=model_phip.predict(tf.concat([p, s, a],1),chose)
plt.plot(tf.concat([p, s, a],1), phi_p, label='PINN prediction')
plt.plot(tf.concat([p, s, a],1), symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.legend()
plt.show()

# %%
Nt=10000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)
A_symb=np.zeros(Nt)


dt=0.0001

# P_symb[0]=np.mean(uu1) #Initial conditions
P_symb[0]=np.array(p[0])  #Initial conditions
S_symb[0]=np.array(s[0]) #Initial conditions
A_symb[0]=np.array(a[0])  #Initial conditions
T_symb[0]=0

for i in range(1,Nt):
    PSA_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(A_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    P_symb[i]=P_symb[i-1]+model_phip.predict(PSA_p,chose)*dt
    S_symb[i]=S_symb[i-1]-P_symb[i-1]*S_symb[i-1]*np.array(m[0])*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, P_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, p, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
plt.plot(T_symb, S_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, S_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, s, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('S')
plt.legend()
plt.show()

# %%
plt.plot(T_symb, A_symb, label='Numeric integration symb dPdT')
plt.plot(T_int, A_int, label='Numeric integration PINN dPdT')
plt.plot(T_star_tf, a, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('A')
plt.legend()
plt.show()
