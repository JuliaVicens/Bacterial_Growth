# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# tf.debugging.set_log_device_placement(True)
# Out:
# []
# Num GPUs Available:  0

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x2374ab88f70>,
#  <matplotlib.lines.Line2D at 0x2374ab88fd0>,
#  <matplotlib.lines.Line2D at 0x2374b5ef040>,
#  <matplotlib.lines.Line2D at 0x2375f8b5f70>,
#  <matplotlib.lines.Line2D at 0x2375f8b5e20>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.hstack((P0_exp,P1_exp,P2_exp,P3_exp))
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
n=np.array([P0_exp.shape[1],P1_exp.shape[1],P2_exp.shape[1],P3_exp.shape[1]])
A_orig=np.array([0, 1.25, 2.50, 3.75])
A=(A_orig-min(A_orig))/max(A_orig)
N_exp,T_max, T_exp.shape, P_exp.shape, 342*23
# Out:
# (19, 231399.5, (342,), (342, 19), 7866)

# %%
A
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)

plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 1500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
Xa_star=[]
P0_star=np.empty((0, 1))
A0_star=np.empty((0, 1))
X_star = np.empty((0, 3))
for i in range(len(A)):
    P0=P_exp[0:1, np.sum(n[:i]):np.sum(n[:i+1])]
    P0_star=np.concatenate((P0_star,P0.T))
    A0_star=np.concatenate((A0_star, np.array([A[i]]*n[i]).reshape([-1,1])))
    T_meshgrid, P0_meshgrid, A_meshgrid = np.meshgrid(T_exp, P0, A[i])
    x=np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None], A_meshgrid.flatten()[:,None]))
    Xa_star += [x]
    X_star=np.vstack((X_star,x))


u_star=np.hstack((P_star,X_star[:,1:2]))

# %%
# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0_star)).reshape([-1,1]), P0_star.reshape([-1,1]), xx0[...,2:3]))

xx01=np.vstack((xx0, xx1))
uu01_s=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

uu01_a=np.array(list(A0_star.reshape([1,-1])[0])+[0]*N_exp).reshape([-1,1])


# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(3, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_s_tf = tf.convert_to_tensor(uu01_s, dtype=tf.float32)
uu01_a_tf = tf.convert_to_tensor(uu01_a, dtype=tf.float32)

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        plt.plot(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_exp[:, (i + np.sum(n[:k]))], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('P0')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,2], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('A')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 3]), dtype=tf.float32)
    # alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1))) 
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp * 2 * 2), (N_exp * 2, 2)))
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p, W_phi, b_phi, W_a, b_a):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)

        lnp=u[:,0:1]
        lns=u[:,1:2]
        lna=u[:,2:3]

        p=tf.exp(lnp)
        s=tf.exp(lns)
        # m=tf.exp(lnv[0:1])
        a=tf.exp(lna)
        
        phi_pa=net(tf.concat([p, a],1), W_a, b_a)
        phi_ps=net(tf.concat([p, s],1), W_phi, b_phi)
        phi_p_s=tf.exp(phi_ps[...,0:1])
        phi_s=tf.exp(phi_ps[...,1:2])
        phi_p_a=tf.exp(phi_pa[...,0:1])
        phi_a=tf.exp(phi_pa[...,1:2])

    p_t = tape1.gradient(p, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]
    a_t = tape1.gradient(a, X_f)[...,0:1]

    f_p = p_t - phi_p_s*s*p + phi_p_a*a*p
    f_s = s_t + phi_s*s*p
    f_a = a_t + phi_a*a*p

    
    return f_p, f_s, f_a




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi, b_phi,  W_a, b_a,  X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, W_a, b_a, lambda_b, lambda_r, lambda_0])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp=u_nn[:,0:1]
        p_nn=tf.exp(lnp)
        f_p, f_s, f_a = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a)

        u_00 = net(xx01_tf, W_p, b_p) 
        s_00=tf.exp(u_00[:,1:2])
        u_00 = net(xx01_tf[:N_exp], W_p, b_p) 
        a_00=tf.exp(u_00[:,2:3])

        loss_p = tf.square(lambda_b*(p_nn - P_train_tf))
        loss_0s = tf.square(lambda_0[:,0:1]*(s_00 - uu01_s_tf))
        loss_0a = tf.square(lambda_0[:N_exp:,1:2]*(a_00 - xx01_tf[:N_exp,2:3]))
        loss_fp = tf.square(lambda_r[:,0:1]*f_p) 
        loss_fs = tf.square(lambda_r[:,1:2]*f_s)
        loss_fa = tf.square(lambda_r[:,2:3]*f_a) 

        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_fa)+ tf.reduce_mean(loss_0s)+ tf.reduce_mean(loss_0a)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    # grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)


    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    # opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s)), tf.reduce_mean(tf.square(f_a)), tf.reduce_mean(tf.square((a_00 - xx01_tf[:N_exp,2:3])))
    # return loss, tf.reduce_mean(tf.square((p_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s)), tf.reduce_mean(tf.square(f_a)), tf.reduce_mean(tf.square((a_00 - uu01_a_tf)))



layers = [3, 20, 20, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 20, 20, 2]

W_a = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_a = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 20, 20, 2]
L = len(layers)

W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 6), (6, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
def train_dynamic_step( W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_phi, b_phi, W_a, b_a, lambda_r, lnv])

        f_p, f_s, f_a = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        loss_fp = tf.square(lambda_r[0:1]*f_p) 
        loss_fs = tf.square(lambda_r[1:2]*f_s) 
        loss_fa = tf.square(lambda_r[2:3]*f_a) 

        loss =  tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_fa)


    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)



    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))

   
    return loss, -1, tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s)), tf.reduce_mean(tf.square(f_a))

# %%
lr = 3e-3


optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/3)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []
loss_fisa = []
loss_0=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf,  lambda_r, lambda_b, lambda_0, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0, optimizer2)
# train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=2*10**5


while it <= Nmax:
    # if it<5*10**4:
    loss_, loss_p, loss_fp, loss_fs, loss_fa, loss_f0a = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0)
    # else:
    #     loss_, loss_p, loss_fp, loss_fs, loss_fa, loss_f0a = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0)
    # else:
    #     loss_, loss_p, loss_fp, loss_fs, loss_fa = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)
    loss_fisa.append(loss_fa)
    loss_0.append(loss_f0a)




    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p is: {loss_fp}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 117480
# Data loss is: 0.0011199925793334842
# Physicial loss of p is: 0.0005387066630646586
# Physicial loss of s is: 0.00018182143685407937
# Iteration is: 117490
# Data loss is: 0.001120031694881618
# Physicial loss of p is: 0.0005504427244886756
# Physicial loss of s is: 0.00017624895554035902
# Iteration is: 117500
# Data loss is: 0.0011206192430108786
# Physicial loss of p is: 0.0006322073168121278
# Physicial loss of s is: 0.00017389528511557728
# Iteration is: 117510
# Data loss is: 0.0011386694386601448
# Physicial loss of p is: 0.002746809273958206
# Physicial loss of s is: 0.0002973257505800575
# Iteration is: 117520
# Data loss is: 0.0011231572134420276
# Physicial loss of p is: 0.0009040533332154155
# Physicial loss of s is: 0.004112995229661465
# Iteration is: 117530
# Data loss is: 0.0011215097038075328
# Physicial loss of p is: 0.0007979724905453622
# Physicial loss of s is: 0.0013142245588824153
# Iteration is: 117540
# Data loss is: 0.0011216270504519343
# Physicial loss of p is: 0.0007497601909562945
# Physicial loss of s is: 0.0006713162292726338
# Iteration is: 117550
# Data loss is: 0.0011200838489457965
# Physicial loss of p is: 0.0005509554175660014
# Physicial loss of s is: 0.000245108938543126
# Iteration is: 117560
# Data loss is: 0.0011200057342648506
# Physicial loss of p is: 0.0005586989573203027
# Physicial loss of s is: 0.00019344947941135615
# Iteration is: 117570
# Data loss is: 0.0011202724417671561
# Physicial loss of p is: 0.0005458011873997748
# Physicial loss of s is: 0.0001832606503739953
# Iteration is: 117580
# Data loss is: 0.0011198766296729445
# Physicial loss of p is: 0.0005401134258136153
# Physicial loss of s is: 0.00017644323816057295
# Iteration is: 117590
# Data loss is: 0.0011198113206773996
# Physicial loss of p is: 0.0005370179424062371
# Physicial loss of s is: 0.00017523586575407535
# Iteration is: 117600
# Data loss is: 0.0011199470609426498
# Physicial loss of p is: 0.0005571888759732246
# Physicial loss of s is: 0.000182411604328081
# Iteration is: 117610
# Data loss is: 0.0011316058225929737
# Physicial loss of p is: 0.0020826421678066254
# Physicial loss of s is: 0.00038821299676783383
# Iteration is: 117620
# Data loss is: 0.0011238331208005548
# Physicial loss of p is: 0.0008547811303287745
# Physicial loss of s is: 0.003470352152362466
# Iteration is: 117630
# Data loss is: 0.001122355810366571
# Physicial loss of p is: 0.0012328277807682753
# Physicial loss of s is: 0.0008515949011780322
# Iteration is: 117640
# Data loss is: 0.001122523215599358
# Physicial loss of p is: 0.0007619781536050141
# Physicial loss of s is: 0.00043367251055315137
# Iteration is: 117650
# Data loss is: 0.0011198889696970582
# Physicial loss of p is: 0.0005721712368540466
# Physicial loss of s is: 0.00023774500004947186
# Iteration is: 117660
# Data loss is: 0.001120137982070446
# Physicial loss of p is: 0.0005746957031078637
# Physicial loss of s is: 0.00023741030599921942
# Iteration is: 117670
# Data loss is: 0.0011199075961485505
# Physicial loss of p is: 0.000543995585758239
# Physicial loss of s is: 0.0001787473156582564
# Iteration is: 117680
# Data loss is: 0.0011199008440598845
# Physicial loss of p is: 0.0005436650826595724
# Physicial loss of s is: 0.00017750270490068942
# Iteration is: 117690
# Data loss is: 0.0011197582352906466
# Physicial loss of p is: 0.0005383882089518011
# Physicial loss of s is: 0.00017310137627646327
# Iteration is: 117700
# Data loss is: 0.0011196507839486003
# Physicial loss of p is: 0.0005370181752368808
# Physicial loss of s is: 0.0001722873275866732
# Iteration is: 117710
# Data loss is: 0.001119630760513246
# Physicial loss of p is: 0.0005380065995268524
# Physicial loss of s is: 0.00017334939911961555
# Iteration is: 117720
# Data loss is: 0.0011198405409231782
# Physicial loss of p is: 0.0005739423795603216
# Physicial loss of s is: 0.00018593335698824376
# Iteration is: 117730
# Data loss is: 0.0011320040794089437
# Physicial loss of p is: 0.002281470224261284
# Physicial loss of s is: 0.0008929134346544743
# Iteration is: 117740
# Data loss is: 0.0011206328636035323
# Physicial loss of p is: 0.0007378155714832246
# Physicial loss of s is: 0.0013653049245476723
# Iteration is: 117750
# Data loss is: 0.0011229499941691756
# Physicial loss of p is: 0.002151043387129903
# Physicial loss of s is: 0.00038658585981465876
# Iteration is: 117760
# Data loss is: 0.0011200421722605824
# Physicial loss of p is: 0.0007891765562817454
# Physicial loss of s is: 0.00033714284654706717
# Iteration is: 117770
# Data loss is: 0.0011198425199836493
# Physicial loss of p is: 0.0005774444434791803
# Physicial loss of s is: 0.00024164993374142796
# Iteration is: 117780
# Data loss is: 0.0011195690603926778
# Physicial loss of p is: 0.0006161679630167782
# Physicial loss of s is: 0.0002326192188775167
# Iteration is: 117790
# Data loss is: 0.0011196283157914877
# Physicial loss of p is: 0.0005525003653019667
# Physicial loss of s is: 0.00018060553702525795
# Iteration is: 117800
# Data loss is: 0.0011196023551747203
# Physicial loss of p is: 0.0005391862941905856
# Physicial loss of s is: 0.00017667055362835526
# Iteration is: 117810
# Data loss is: 0.001119503052905202
# Physicial loss of p is: 0.0005387679557316005
# Physicial loss of s is: 0.00017318544269073755
# Iteration is: 117820
# Data loss is: 0.0011194911785423756
# Physicial loss of p is: 0.000538373424205929
# Physicial loss of s is: 0.0001723809982649982
# Iteration is: 117830
# Data loss is: 0.001119461958296597
# Physicial loss of p is: 0.0005370747530832887
# Physicial loss of s is: 0.00017272740660700947
# Iteration is: 117840
# Data loss is: 0.0011194582330062985
# Physicial loss of p is: 0.0005385907716117799
# Physicial loss of s is: 0.00017353499424643815
# Iteration is: 117850
# Data loss is: 0.0011200322769582272
# Physicial loss of p is: 0.0005971197970211506
# Physicial loss of s is: 0.00018042323063127697
# Iteration is: 117860
# Data loss is: 0.0011494149221107364
# Physicial loss of p is: 0.003477060003206134
# Physicial loss of s is: 0.0003853784583043307
# Iteration is: 117870
# Data loss is: 0.0011407939018681645
# Physicial loss of p is: 0.0017624626634642482
# Physicial loss of s is: 0.0037157752085477114
# Iteration is: 117880
# Data loss is: 0.0011211404344066978
# Physicial loss of p is: 0.0007447322714142501
# Physicial loss of s is: 0.001292040920816362
# Iteration is: 117890
# Data loss is: 0.0011205964256078005
# Physicial loss of p is: 0.0005971547798253596
# Physicial loss of s is: 0.0003998474858235568
# Iteration is: 117900
# Data loss is: 0.0011214312398806214
# Physicial loss of p is: 0.0006393095827661455
# Physicial loss of s is: 0.0002890849718824029
# Iteration is: 117910
# Data loss is: 0.0011200940934941173
# Physicial loss of p is: 0.0005710023106075823
# Physicial loss of s is: 0.00021584190835710615
# Iteration is: 117920
# Data loss is: 0.0011194855906069279
# Physicial loss of p is: 0.0005363533855415881
# Physicial loss of s is: 0.00018684488895814866
# Iteration is: 117930
# Data loss is: 0.001119540655054152
# Physicial loss of p is: 0.0005417000502347946
# Physicial loss of s is: 0.0001759024162311107
# Iteration is: 117940
# Data loss is: 0.0011193823302164674
# Physicial loss of p is: 0.0005354634486138821
# Physicial loss of s is: 0.00017098446551244706
# Iteration is: 117950
# Data loss is: 0.001119330176152289
# Physicial loss of p is: 0.0005384428659453988
# Physicial loss of s is: 0.00017306652443949133
# Iteration is: 117960
# Data loss is: 0.0011193634709343314
# Physicial loss of p is: 0.0005484155844897032
# Physicial loss of s is: 0.00018031985382549465
# Iteration is: 117970
# Data loss is: 0.0011214781552553177
# Physicial loss of p is: 0.0013285238528624177
# Physicial loss of s is: 0.0008495975635014474
# Iteration is: 117980
# Data loss is: 0.001136339153163135
# Physicial loss of p is: 0.0020958753302693367
# Physicial loss of s is: 0.001554075046442449
# Iteration is: 117990
# Data loss is: 0.0011251643300056458
# Physicial loss of p is: 0.002228871453553438
# Physicial loss of s is: 0.000640968675725162
# Iteration is: 118000
# Data loss is: 0.0011225225171074271
# Physicial loss of p is: 0.0007523283129557967
# Physicial loss of s is: 0.0003383189323358238
# Iteration is: 118010
# Data loss is: 0.0011213445104658604
# Physicial loss of p is: 0.000811709207482636
# Physicial loss of s is: 0.00017905871209222823
# Iteration is: 118020
# Data loss is: 0.0011198518332093954
# Physicial loss of p is: 0.0006723653059452772
# Physicial loss of s is: 0.00017935846699401736
# Iteration is: 118030
# Data loss is: 0.0011193002574145794
# Physicial loss of p is: 0.0005405456759035587
# Physicial loss of s is: 0.00017459514492657036
# Iteration is: 118040
# Data loss is: 0.0011192639358341694
# Physicial loss of p is: 0.000536927895154804
# Physicial loss of s is: 0.00017686336650513113
# Iteration is: 118050
# Data loss is: 0.0011192058445885777
# Physicial loss of p is: 0.0005381927476264536
# Physicial loss of s is: 0.00017394835595041513
# Iteration is: 118060
# Data loss is: 0.0011191865196451545
# Physicial loss of p is: 0.0005362009978853166
# Physicial loss of s is: 0.00017293880227953196
# Iteration is: 118070
# Data loss is: 0.0011191582307219505
# Physicial loss of p is: 0.0005361468065530062
# Physicial loss of s is: 0.00017248920630663633
# Iteration is: 118080
# Data loss is: 0.0011191359953954816
# Physicial loss of p is: 0.0005370736471377313
# Physicial loss of s is: 0.0001718517014523968
# Iteration is: 118090
# Data loss is: 0.001119110151194036
# Physicial loss of p is: 0.0005362387746572495
# Physicial loss of s is: 0.00017186962941195816
# Iteration is: 118100
# Data loss is: 0.0011190860532224178
# Physicial loss of p is: 0.0005360911600291729
# Physicial loss of s is: 0.00017225980991497636
# Iteration is: 118110
# Data loss is: 0.00111906579695642
# Physicial loss of p is: 0.0005365825491026044
# Physicial loss of s is: 0.00017589781782589853
# Iteration is: 118120
# Data loss is: 0.0011194855906069279
# Physicial loss of p is: 0.0006304400158114731
# Physicial loss of s is: 0.00040470814565196633
# Iteration is: 118130
# Data loss is: 0.001176162390038371
# Physicial loss of p is: 0.007634012494236231
# Physicial loss of s is: 0.00736153544858098
# Iteration is: 118140
# Data loss is: 0.0011243728222325444
# Physicial loss of p is: 0.0018020740244537592
# Physicial loss of s is: 0.0012420529965311289
# Iteration is: 118150
# Data loss is: 0.0011195256374776363
# Physicial loss of p is: 0.0005978898261673748
# Physicial loss of s is: 0.0003677400527521968
# Iteration is: 118160
# Data loss is: 0.0011204922338947654
# Physicial loss of p is: 0.000564547604881227
# Physicial loss of s is: 0.00021223041403573006
# Iteration is: 118170
# Data loss is: 0.0011193816317245364
# Physicial loss of p is: 0.0005549818743020296
# Physicial loss of s is: 0.0001790046226233244
# Iteration is: 118180
# Data loss is: 0.001119424938224256
# Physicial loss of p is: 0.000545065791811794
# Physicial loss of s is: 0.00020986376330256462
# Iteration is: 118190
# Data loss is: 0.0011191347148269415
# Physicial loss of p is: 0.0005402695387601852
# Physicial loss of s is: 0.00018855056259781122
# Iteration is: 118200
# Data loss is: 0.0011190623044967651
# Physicial loss of p is: 0.0005361056537367404
# Physicial loss of s is: 0.0001715625694487244
# Iteration is: 118210
# Data loss is: 0.0011190270306542516
# Physicial loss of p is: 0.0005356684559956193
# Physicial loss of s is: 0.00017515194485895336
# Iteration is: 118220
# Data loss is: 0.0011189973447471857
# Physicial loss of p is: 0.0005369302816689014
# Physicial loss of s is: 0.00017560746346134692
# Iteration is: 118230
# Data loss is: 0.001119171385653317
# Physicial loss of p is: 0.0006422864971682429
# Physicial loss of s is: 0.00022195577912498266
# Iteration is: 118240
# Data loss is: 0.0011314000003039837
# Physicial loss of p is: 0.006044032983481884
# Physicial loss of s is: 0.0026924225967377424
# Iteration is: 118250
# Data loss is: 0.0011277985759079456
# Physicial loss of p is: 0.0031557418406009674
# Physicial loss of s is: 0.0014550035120919347
# Iteration is: 118260
# Data loss is: 0.0011273047421127558
# Physicial loss of p is: 0.0007730239885859191
# Physicial loss of s is: 0.0008408996509388089
# Iteration is: 118270
# Data loss is: 0.0011190848890691996
# Physicial loss of p is: 0.000542550056707114
# Physicial loss of s is: 0.00020847788255196065
# Iteration is: 118280
# Data loss is: 0.0011203816393390298
# Physicial loss of p is: 0.0005888160085305572
# Physicial loss of s is: 0.00022854882990941405
# Iteration is: 118290
# Data loss is: 0.0011192400706931949
# Physicial loss of p is: 0.0006056010024622083
# Physicial loss of s is: 0.00017467408906668425
# Iteration is: 118300
# Data loss is: 0.0011189389042556286
# Physicial loss of p is: 0.0005534869851544499
# Physicial loss of s is: 0.00017892717733047903
# Iteration is: 118310
# Data loss is: 0.0011188777862116694
# Physicial loss of p is: 0.0005359653732739389
# Physicial loss of s is: 0.00018134835409000516
# Iteration is: 118320
# Data loss is: 0.001118833082728088
# Physicial loss of p is: 0.0005359029746614397
# Physicial loss of s is: 0.00017181622388307005
# Iteration is: 118330
# Data loss is: 0.001118839136324823
# Physicial loss of p is: 0.0005375081091187894
# Physicial loss of s is: 0.00017186845070682466
# Iteration is: 118340
# Data loss is: 0.0011187804630026221
# Physicial loss of p is: 0.0005382304661907256
# Physicial loss of s is: 0.0001721658481983468
# Iteration is: 118350
# Data loss is: 0.001118813524954021
# Physicial loss of p is: 0.0005419317167252302
# Physicial loss of s is: 0.00017262535402551293
# Iteration is: 118360
# Data loss is: 0.0011196770938113332
# Physicial loss of p is: 0.0006591405835933983
# Physicial loss of s is: 0.00019786672783084214
# Iteration is: 118370
# Data loss is: 0.001151081989519298
# Physicial loss of p is: 0.004676245152950287
# Physicial loss of s is: 0.001529049128293991
# Iteration is: 118380
# Data loss is: 0.0011303701903671026
# Physicial loss of p is: 0.001701219123788178
# Physicial loss of s is: 0.0005123572773300111
# Iteration is: 118390
# Data loss is: 0.001119249383918941
# Physicial loss of p is: 0.0008994636591523886
# Physicial loss of s is: 0.001186793320812285
# Iteration is: 118400
# Data loss is: 0.0011190923396497965
# Physicial loss of p is: 0.0006530566606670618
# Physicial loss of s is: 0.0005133032100275159
# Iteration is: 118410
# Data loss is: 0.0011192321544513106
# Physicial loss of p is: 0.0006284831324592233
# Physicial loss of s is: 0.00017967326857615262
# Iteration is: 118420
# Data loss is: 0.001119083259254694
# Physicial loss of p is: 0.0005863707046955824
# Physicial loss of s is: 0.00017721304902806878
# Iteration is: 118430
# Data loss is: 0.0011187256313860416
# Physicial loss of p is: 0.0005487593007273972
# Physicial loss of s is: 0.00018391894991509616
# Iteration is: 118440
# Data loss is: 0.0011187070049345493
# Physicial loss of p is: 0.0005386697594076395
# Physicial loss of s is: 0.00018098914006259292
# Iteration is: 118450
# Data loss is: 0.0011185964103788137
# Physicial loss of p is: 0.0005376098561100662
# Physicial loss of s is: 0.00017566740280017257
# Iteration is: 118460
# Data loss is: 0.0011185721959918737
# Physicial loss of p is: 0.0005355278844945133
# Physicial loss of s is: 0.00017257618310395628
# Iteration is: 118470
# Data loss is: 0.0011185628827661276
# Physicial loss of p is: 0.0005362219526432455
# Physicial loss of s is: 0.00017277109145652503
# Iteration is: 118480
# Data loss is: 0.0011193533428013325
# Physicial loss of p is: 0.0006126306252554059
# Physicial loss of s is: 0.0001856657472671941
# Iteration is: 118490
# Data loss is: 0.001183265820145607
# Physicial loss of p is: 0.00752938212826848
# Physicial loss of s is: 0.0011451431782916188
# Iteration is: 118500
# Data loss is: 0.0011208901414647698
# Physicial loss of p is: 0.0009380303672514856
# Physicial loss of s is: 0.00028248733724467456
# Iteration is: 118510
# Data loss is: 0.0011239962186664343
# Physicial loss of p is: 0.0007614974747411907
# Physicial loss of s is: 0.0006641526706516743
# Iteration is: 118520
# Data loss is: 0.0011252720141783357
# Physicial loss of p is: 0.0008450074237771332
# Physicial loss of s is: 0.00025201760581694543
# Iteration is: 118530
# Data loss is: 0.0011206027120351791
# Physicial loss of p is: 0.0006152007845230401
# Physicial loss of s is: 0.00023747525119688362
# Iteration is: 118540
# Data loss is: 0.0011186952469870448
# Physicial loss of p is: 0.0005388598656281829
# Physicial loss of s is: 0.0001741283922456205
# Iteration is: 118550
# Data loss is: 0.0011187662603333592
# Physicial loss of p is: 0.0005438367370516062
# Physicial loss of s is: 0.00017623748863115907
# Iteration is: 118560
# Data loss is: 0.0011185467010363936
# Physicial loss of p is: 0.000538050546310842
# Physicial loss of s is: 0.00017654128896538168
# Iteration is: 118570
# Data loss is: 0.0011185489129275084
# Physicial loss of p is: 0.00053531548473984
# Physicial loss of s is: 0.00017314589058514684
# Iteration is: 118580
# Data loss is: 0.0011184782488271594
# Physicial loss of p is: 0.0005348199629224837
# Physicial loss of s is: 0.00017246748029720038
# Iteration is: 118590
# Data loss is: 0.0011184593895450234
# Physicial loss of p is: 0.0005372135201469064
# Physicial loss of s is: 0.00017222210590261966
# Iteration is: 118600
# Data loss is: 0.0011184975737705827
# Physicial loss of p is: 0.0005809002905152738
# Physicial loss of s is: 0.00018184215878136456
# Iteration is: 118610
# Data loss is: 0.0011207711650058627
# Physicial loss of p is: 0.0026379262562841177
# Physicial loss of s is: 0.0005283726495690644
# Iteration is: 118620
# Data loss is: 0.0011206059716641903
# Physicial loss of p is: 0.0006755715585313737
# Physicial loss of s is: 0.0036003654822707176
# Iteration is: 118630
# Data loss is: 0.0011209479998797178
# Physicial loss of p is: 0.001380237634293735
# Physicial loss of s is: 0.0012935902923345566
# Iteration is: 118640
# Data loss is: 0.0011240182211622596
# Physicial loss of p is: 0.000691424822434783
# Physicial loss of s is: 0.0002702491474337876
# Iteration is: 118650
# Data loss is: 0.0011190794175490737
# Physicial loss of p is: 0.0005571035435423255
# Physicial loss of s is: 0.00024324021069332957
# Iteration is: 118660
# Data loss is: 0.0011188521748408675
# Physicial loss of p is: 0.0005543541628867388
# Physicial loss of s is: 0.00023948404123075306
# Iteration is: 118670
# Data loss is: 0.001118469750508666
# Physicial loss of p is: 0.0005729118129238486
# Physicial loss of s is: 0.0001871674758149311
# Iteration is: 118680
# Data loss is: 0.0011184337781742215
# Physicial loss of p is: 0.0005419887020252645
# Physicial loss of s is: 0.00017207840573973954
# Iteration is: 118690
# Data loss is: 0.0011183855822309852
# Physicial loss of p is: 0.0005360084469430149
# Physicial loss of s is: 0.00018508244829718024
# Iteration is: 118700
# Data loss is: 0.0011191704543307424
# Physicial loss of p is: 0.0006596804014407098
# Physicial loss of s is: 0.0002925074950326234
# Iteration is: 118710
# Data loss is: 0.0011403897078707814
# Physicial loss of p is: 0.004751209169626236
# Physicial loss of s is: 0.00445982301607728
# Iteration is: 118720
# Data loss is: 0.0011322814971208572
# Physicial loss of p is: 0.002563536399975419
# Physicial loss of s is: 0.002173329470679164
# Iteration is: 118730
# Data loss is: 0.0011214985279366374
# Physicial loss of p is: 0.0009099346352741122
# Physicial loss of s is: 0.0005912078777328134
# Iteration is: 118740
# Data loss is: 0.0011184014147147536
# Physicial loss of p is: 0.0005414045299403369
# Physicial loss of s is: 0.0001841794146457687
# Iteration is: 118750
# Data loss is: 0.0011185017647221684
# Physicial loss of p is: 0.0005605538608506322
# Physicial loss of s is: 0.0002252837730338797
# Iteration is: 118760
# Data loss is: 0.0011182980379089713
# Physicial loss of p is: 0.000551297445781529
# Physicial loss of s is: 0.00020486411813180894
# Iteration is: 118770
# Data loss is: 0.0011182281887158751
# Physicial loss of p is: 0.0005397394997999072
# Physicial loss of s is: 0.00017687292711343616
# Iteration is: 118780
# Data loss is: 0.0011182166635990143
# Physicial loss of p is: 0.0005370674771256745
# Physicial loss of s is: 0.00017298829334322363
# Iteration is: 118790
# Data loss is: 0.001118201413191855
# Physicial loss of p is: 0.0005405191332101822
# Physicial loss of s is: 0.00017135798407252878
# Iteration is: 118800
# Data loss is: 0.0011181517038494349
# Physicial loss of p is: 0.0005351341096684337
# Physicial loss of s is: 0.00017287796072196215
# Iteration is: 118810
# Data loss is: 0.0011181265581399202
# Physicial loss of p is: 0.0005348158883862197
# Physicial loss of s is: 0.00017142815340775996
# Iteration is: 118820
# Data loss is: 0.0011181039735674858
# Physicial loss of p is: 0.0005347765982151031
# Physicial loss of s is: 0.0001714331447146833
# Iteration is: 118830
# Data loss is: 0.0011180834844708443
# Physicial loss of p is: 0.0005350399878807366
# Physicial loss of s is: 0.00017162699077744037
# Iteration is: 118840
# Data loss is: 0.0011184554314240813
# Physicial loss of p is: 0.0006003479356877506
# Physicial loss of s is: 0.000174646163941361
# Iteration is: 118850
# Data loss is: 0.0011745280353352427
# Physicial loss of p is: 0.010726199485361576
# Physicial loss of s is: 0.0007413053535856307
# Iteration is: 118860
# Data loss is: 0.0011225277557969093
# Physicial loss of p is: 0.0014579187845811248
# Physicial loss of s is: 0.0016676384257152677
# Iteration is: 118870
# Data loss is: 0.001119375810958445
# Physicial loss of p is: 0.0008184409816749394
# Physicial loss of s is: 0.0004561437526717782
# Iteration is: 118880
# Data loss is: 0.0011193177197128534
# Physicial loss of p is: 0.0006389847840182483
# Physicial loss of s is: 0.0002888921299017966
# Iteration is: 118890
# Data loss is: 0.0011187688214704394
# Physicial loss of p is: 0.0005573613452725112
# Physicial loss of s is: 0.000217047258047387
# Iteration is: 118900
# Data loss is: 0.0011184512404724956
# Physicial loss of p is: 0.0005443302216008306
# Physicial loss of s is: 0.00017477049550507218
# Iteration is: 118910
# Data loss is: 0.0011182536836713552
# Physicial loss of p is: 0.0005350880674086511
# Physicial loss of s is: 0.0001703678717603907
# Iteration is: 118920
# Data loss is: 0.0011182137532159686
# Physicial loss of p is: 0.000534874270670116
# Physicial loss of s is: 0.00017294792633038014
# Iteration is: 118930
# Data loss is: 0.0011181887239217758
# Physicial loss of p is: 0.0005353898741304874
# Physicial loss of s is: 0.00017064234998542815
# Iteration is: 118940
# Data loss is: 0.0011180996662005782
# Physicial loss of p is: 0.0005342108779586852
# Physicial loss of s is: 0.00017078571545425802
# Iteration is: 118950
# Data loss is: 0.001118040643632412
# Physicial loss of p is: 0.0005349133280105889
# Physicial loss of s is: 0.00017127952014561743
# Iteration is: 118960
# Data loss is: 0.0011180021101608872
# Physicial loss of p is: 0.0005383985699154437
# Physicial loss of s is: 0.00018652841390576214
# Iteration is: 118970
# Data loss is: 0.001118146232329309
# Physicial loss of p is: 0.000660687917843461
# Physicial loss of s is: 0.0007958865026012063
# Iteration is: 118980
# Data loss is: 0.0011279465397819877
# Physicial loss of p is: 0.0024977801367640495
# Physicial loss of s is: 0.003768215188756585
# Iteration is: 118990
# Data loss is: 0.0011268046218901873
# Physicial loss of p is: 0.00156970729585737
# Physicial loss of s is: 0.0003571996057871729
# Iteration is: 119000
# Data loss is: 0.0011186817428097129
# Physicial loss of p is: 0.0011318360920995474
# Physicial loss of s is: 0.0003313228953629732
# Iteration is: 119010
# Data loss is: 0.001118572661653161
# Physicial loss of p is: 0.0007682993891648948
# Physicial loss of s is: 0.0001989762095035985
# Iteration is: 119020
# Data loss is: 0.0011189435608685017
# Physicial loss of p is: 0.0006170023698359728
# Physicial loss of s is: 0.00017772638238966465
# Iteration is: 119030
# Data loss is: 0.001117964624427259
# Physicial loss of p is: 0.000544681737665087
# Physicial loss of s is: 0.000174874032381922
# Iteration is: 119040
# Data loss is: 0.0011179355205968022
# Physicial loss of p is: 0.0005403812392614782
# Physicial loss of s is: 0.00017509088502265513
# Iteration is: 119050
# Data loss is: 0.0011178534477949142
# Physicial loss of p is: 0.0005341802607290447
# Physicial loss of s is: 0.00017104187281802297
# Iteration is: 119060
# Data loss is: 0.0011178160784766078
# Physicial loss of p is: 0.0005395303014665842
# Physicial loss of s is: 0.00017194556130561978
# Iteration is: 119070
# Data loss is: 0.0011180179426446557
# Physicial loss of p is: 0.0005891503533348441
# Physicial loss of s is: 0.00018184712098445743
# Iteration is: 119080
# Data loss is: 0.0011292572598904371
# Physicial loss of p is: 0.0030509186908602715
# Physicial loss of s is: 0.0006905183545313776
# Iteration is: 119090
# Data loss is: 0.001120635773986578
# Physicial loss of p is: 0.0011752346763387322
# Physicial loss of s is: 0.001151950447820127
# Iteration is: 119100
# Data loss is: 0.0011187370400875807
# Physicial loss of p is: 0.0018039069836959243
# Physicial loss of s is: 0.0006087159854359925
# Iteration is: 119110
# Data loss is: 0.001118168351240456
# Physicial loss of p is: 0.0005451517063193023
# Physicial loss of s is: 0.0002192665997426957
# Iteration is: 119120
# Data loss is: 0.0011180647416040301
# Physicial loss of p is: 0.0006223614909686148
# Physicial loss of s is: 0.00028591457521542907
# Iteration is: 119130
# Data loss is: 0.0011182914022356272
# Physicial loss of p is: 0.0005588197964243591
# Physicial loss of s is: 0.0001886381214717403
# Iteration is: 119140
# Data loss is: 0.0011182070011273026
# Physicial loss of p is: 0.0005494682118296623
# Physicial loss of s is: 0.00018284059478901327
# Iteration is: 119150
# Data loss is: 0.0011178732383996248
# Physicial loss of p is: 0.0005404328112490475
# Physicial loss of s is: 0.00017105790902860463
# Iteration is: 119160
# Data loss is: 0.0011177227133885026
# Physicial loss of p is: 0.0005340336938388646
# Physicial loss of s is: 0.00017063991981558502
# Iteration is: 119170
# Data loss is: 0.001117696170695126
# Physicial loss of p is: 0.0005351366708055139
# Physicial loss of s is: 0.00017168416525237262
# Iteration is: 119180
# Data loss is: 0.001117665902711451
# Physicial loss of p is: 0.0005357294576242566
# Physicial loss of s is: 0.00017221117741428316
# Iteration is: 119190
# Data loss is: 0.001117944484576583
# Physicial loss of p is: 0.0005701722111552954
# Physicial loss of s is: 0.00020959136600140482
# Iteration is: 119200
# Data loss is: 0.00113549898378551
# Physicial loss of p is: 0.0029217649716883898
# Physicial loss of s is: 0.001853726920671761
# Iteration is: 119210
# Data loss is: 0.0011307552922517061
# Physicial loss of p is: 0.0017178596463054419
# Physicial loss of s is: 0.0002592017117422074
# Iteration is: 119220
# Data loss is: 0.0011220414889976382
# Physicial loss of p is: 0.0016576263587921858
# Physicial loss of s is: 0.0009787174640223384
# Iteration is: 119230
# Data loss is: 0.0011184923350811005
# Physicial loss of p is: 0.0005838616634719074
# Physicial loss of s is: 0.00030853133648633957
# Iteration is: 119240
# Data loss is: 0.0011186064220964909
# Physicial loss of p is: 0.0007481957436539233
# Physicial loss of s is: 0.00017838497296907008
# Iteration is: 119250
# Data loss is: 0.0011178824352100492
# Physicial loss of p is: 0.0006414775853045285
# Physicial loss of s is: 0.00018566608196124434
# Iteration is: 119260
# Data loss is: 0.0011176274856552482
# Physicial loss of p is: 0.0005780847277492285
# Physicial loss of s is: 0.0001791393879102543
# Iteration is: 119270
# Data loss is: 0.0011176086263731122
# Physicial loss of p is: 0.0005483981221914291
# Physicial loss of s is: 0.00017274367564823478
# Iteration is: 119280
# Data loss is: 0.0011175323743373156
# Physicial loss of p is: 0.0005410204757936299
# Physicial loss of s is: 0.00017262583423871547
# Iteration is: 119290
# Data loss is: 0.0011175203835591674
# Physicial loss of p is: 0.0005342629156075418
# Physicial loss of s is: 0.00017406315600965172
# Iteration is: 119300
# Data loss is: 0.0011174792889505625
# Physicial loss of p is: 0.0005341611104086041
# Physicial loss of s is: 0.00017181035946123302
# Iteration is: 119310
# Data loss is: 0.0011174572864547372
# Physicial loss of p is: 0.0005341687938198447
# Physicial loss of s is: 0.00017177431436721236
# Iteration is: 119320
# Data loss is: 0.0011175023391842842
# Physicial loss of p is: 0.0005446431459859014
# Physicial loss of s is: 0.00017806838150136173
# Iteration is: 119330
# Data loss is: 0.0011232211254537106
# Physicial loss of p is: 0.001322151510976255
# Physicial loss of s is: 0.0004611071490217
# Iteration is: 119340
# Data loss is: 0.0011181039735674858
# Physicial loss of p is: 0.0008735673618502915
# Physicial loss of s is: 0.0020118090324103832
# Iteration is: 119350
# Data loss is: 0.001140017295256257
# Physicial loss of p is: 0.0015334634808823466
# Physicial loss of s is: 0.0004528063291218132
# Iteration is: 119360
# Data loss is: 0.0011179678840562701
# Physicial loss of p is: 0.000554162310436368
# Physicial loss of s is: 0.00029001134680584073
# Iteration is: 119370
# Data loss is: 0.0011215059785172343
# Physicial loss of p is: 0.0006506516947411001
# Physicial loss of s is: 0.00024583927006460726
# Iteration is: 119380
# Data loss is: 0.0011175081599503756
# Physicial loss of p is: 0.0005473786732181907
# Physicial loss of s is: 0.00017713637498673052
# Iteration is: 119390
# Data loss is: 0.0011177279520779848
# Physicial loss of p is: 0.0005512245115824044
# Physicial loss of s is: 0.00024825072614476085
# Iteration is: 119400
# Data loss is: 0.0011180368019267917
# Physicial loss of p is: 0.0009470704826526344
# Physicial loss of s is: 0.0009380746632814407
# Iteration is: 119410
# Data loss is: 0.001120931119658053
# Physicial loss of p is: 0.0015189895639196038
# Physicial loss of s is: 0.0014247072394937277
# Iteration is: 119420
# Data loss is: 0.0011235203128308058
# Physicial loss of p is: 0.0011646413477137685
# Physicial loss of s is: 0.000611365307122469
# Iteration is: 119430
# Data loss is: 0.0011203791946172714
# Physicial loss of p is: 0.0008106842869892716
# Physicial loss of s is: 0.0003230996080674231
# Iteration is: 119440
# Data loss is: 0.0011175153777003288
# Physicial loss of p is: 0.0005409465520642698
# Physicial loss of s is: 0.0001827754604164511
# Iteration is: 119450
# Data loss is: 0.0011174039682373405
# Physicial loss of p is: 0.0005846731946803629
# Physicial loss of s is: 0.0002051525079878047
# Iteration is: 119460
# Data loss is: 0.0011173342354595661
# Physicial loss of p is: 0.000551313569303602
# Physicial loss of s is: 0.00017336437304038554
# Iteration is: 119470
# Data loss is: 0.0011172943050041795
# Physicial loss of p is: 0.0005459204548969865
# Physicial loss of s is: 0.00017955813382286578
# Iteration is: 119480
# Data loss is: 0.001118089770898223
# Physicial loss of p is: 0.0007707972545176744
# Physicial loss of s is: 0.0002681743644643575
# Iteration is: 119490
# Data loss is: 0.001132652279920876
# Physicial loss of p is: 0.005686748307198286
# Physicial loss of s is: 0.0025700924452394247
# Iteration is: 119500
# Data loss is: 0.0011198986321687698
# Physicial loss of p is: 0.0032601740676909685
# Physicial loss of s is: 0.0007020496414043009
# Iteration is: 119510
# Data loss is: 0.0011196584673598409
# Physicial loss of p is: 0.00085212173871696
# Physicial loss of s is: 0.00017915655917022377
# Iteration is: 119520
# Data loss is: 0.0011192611418664455
# Physicial loss of p is: 0.0006164673250168562
# Physicial loss of s is: 0.000270963559160009
# Iteration is: 119530
# Data loss is: 0.0011174174724146724
# Physicial loss of p is: 0.0005590294022113085
# Physicial loss of s is: 0.00019406346837058663
# Iteration is: 119540
# Data loss is: 0.0011172244558110833
# Physicial loss of p is: 0.0005375054897740483
# Physicial loss of s is: 0.00017228386423084885
# Iteration is: 119550
# Data loss is: 0.0011172669474035501
# Physicial loss of p is: 0.000548197072930634
# Physicial loss of s is: 0.0001729862706270069
# Iteration is: 119560
# Data loss is: 0.0011171704391017556
# Physicial loss of p is: 0.0005430741584859788
# Physicial loss of s is: 0.00017859466606751084
# Iteration is: 119570
# Data loss is: 0.0011171953519806266
# Physicial loss of p is: 0.0005348214763216674
# Physicial loss of s is: 0.00018839041877072304
# Iteration is: 119580
# Data loss is: 0.0011173553066328168
# Physicial loss of p is: 0.000551573175471276
# Physicial loss of s is: 0.0005685283686034381
# Iteration is: 119590
# Data loss is: 0.0011295242002233863
# Physicial loss of p is: 0.0018724574474617839
# Physicial loss of s is: 0.005732865538448095
# Iteration is: 119600
# Data loss is: 0.0011170725338160992
# Physicial loss of p is: 0.0006174290319904685
# Physicial loss of s is: 0.0013090649154037237
# Iteration is: 119610
# Data loss is: 0.0011194098042324185
# Physicial loss of p is: 0.000904338841792196
# Physicial loss of s is: 0.00020541410776786506
# Iteration is: 119620
# Data loss is: 0.001119502354413271
# Physicial loss of p is: 0.0008864628034643829
# Physicial loss of s is: 0.0003205623070243746
# Iteration is: 119630
# Data loss is: 0.001118129352107644
# Physicial loss of p is: 0.0006121285259723663
# Physicial loss of s is: 0.00018477046978659928
# Iteration is: 119640
# Data loss is: 0.0011175369145348668
# Physicial loss of p is: 0.0005439288215711713
# Physicial loss of s is: 0.0001802884362405166
# Iteration is: 119650
# Data loss is: 0.0011170641519129276
# Physicial loss of p is: 0.0005494935903698206
# Physicial loss of s is: 0.0001833651476772502
# Iteration is: 119660
# Data loss is: 0.0011171231744810939
# Physicial loss of p is: 0.0005357894115149975
# Physicial loss of s is: 0.00017392158042639494
# Iteration is: 119670
# Data loss is: 0.0011170337675139308
# Physicial loss of p is: 0.0005353516316972673
# Physicial loss of s is: 0.00017474449123255908
# Iteration is: 119680
# Data loss is: 0.0011174117680639029
# Physicial loss of p is: 0.0005896201473660767
# Physicial loss of s is: 0.0001742303866194561
# Iteration is: 119690
# Data loss is: 0.0011304246727377176
# Physicial loss of p is: 0.002571426099166274
# Physicial loss of s is: 0.0004478598712012172
# Iteration is: 119700
# Data loss is: 0.001122544868849218
# Physicial loss of p is: 0.0007955397595651448
# Physicial loss of s is: 0.0017773716244846582
# Iteration is: 119710
# Data loss is: 0.0011201262241229415
# Physicial loss of p is: 0.0008628592477180064
# Physicial loss of s is: 0.0004908639821223915
# Iteration is: 119720
# Data loss is: 0.0011170392390340567
# Physicial loss of p is: 0.0006806872552260756
# Physicial loss of s is: 0.00026260086451657116
# Iteration is: 119730
# Data loss is: 0.0011180295841768384
# Physicial loss of p is: 0.0006130412220954895
# Physicial loss of s is: 0.0002574457321316004
# Iteration is: 119740
# Data loss is: 0.0011174583341926336
# Physicial loss of p is: 0.0005769902491010725
# Physicial loss of s is: 0.00022348242055159062
# Iteration is: 119750
# Data loss is: 0.0011172577505931258
# Physicial loss of p is: 0.0005450387834571302
# Physicial loss of s is: 0.00018695430480875075
# Iteration is: 119760
# Data loss is: 0.0011169052449986339
# Physicial loss of p is: 0.0005377564812079072
# Physicial loss of s is: 0.00017903921252582222
# Iteration is: 119770
# Data loss is: 0.0011168904602527618
# Physicial loss of p is: 0.000534184742718935
# Physicial loss of s is: 0.00017342422506771982
# Iteration is: 119780
# Data loss is: 0.0011168617056682706
# Physicial loss of p is: 0.0005352084408514202
# Physicial loss of s is: 0.00017155635578092188
# Iteration is: 119790
# Data loss is: 0.001117131905630231
# Physicial loss of p is: 0.0005790979485027492
# Physicial loss of s is: 0.00017848446441348642
# Iteration is: 119800
# Data loss is: 0.0011461306130513549
# Physicial loss of p is: 0.00345159531570971
# Physicial loss of s is: 0.0009596942691132426
# Iteration is: 119810
# Data loss is: 0.0011384693207219243
# Physicial loss of p is: 0.0021064202301204205
# Physicial loss of s is: 0.0007970327278599143
# Iteration is: 119820
# Data loss is: 0.001118483254685998
# Physicial loss of p is: 0.0011912782210856676
# Physicial loss of s is: 0.0010565081611275673
# Iteration is: 119830
# Data loss is: 0.0011169870849698782
# Physicial loss of p is: 0.0005930550396442413
# Physicial loss of s is: 0.00020754069555550814
# Iteration is: 119840
# Data loss is: 0.001118475222028792
# Physicial loss of p is: 0.0005980583373457193
# Physicial loss of s is: 0.0003107605443801731
# Iteration is: 119850
# Data loss is: 0.0011171435471624136
# Physicial loss of p is: 0.0005450983298942447
# Physicial loss of s is: 0.000179834954906255
# Iteration is: 119860
# Data loss is: 0.0011172075755894184
# Physicial loss of p is: 0.0005490966723300517
# Physicial loss of s is: 0.00018369097961112857
# Iteration is: 119870
# Data loss is: 0.0011167682241648436
# Physicial loss of p is: 0.0005337827606126666
# Physicial loss of s is: 0.0001721821608953178
# Iteration is: 119880
# Data loss is: 0.0011167626362293959
# Physicial loss of p is: 0.0005334707093425095
# Physicial loss of s is: 0.00017258319712709635
# Iteration is: 119890
# Data loss is: 0.001116710714995861
# Physicial loss of p is: 0.0005338852643035352
# Physicial loss of s is: 0.0001726243062876165
# Iteration is: 119900
# Data loss is: 0.001116681843996048
# Physicial loss of p is: 0.0005325997481122613
# Physicial loss of s is: 0.0001716762490104884
# Iteration is: 119910
# Data loss is: 0.0011166483163833618
# Physicial loss of p is: 0.0005330132553353906
# Physicial loss of s is: 0.00017224717885255814
# Iteration is: 119920
# Data loss is: 0.0011167277116328478
# Physicial loss of p is: 0.0006065143388696015
# Physicial loss of s is: 0.0002266049850732088
# Iteration is: 119930
# Data loss is: 0.0011259866878390312
# Physicial loss of p is: 0.00598247442394495
# Physicial loss of s is: 0.00238456460647285
# Iteration is: 119940
# Data loss is: 0.0011316954623907804
# Physicial loss of p is: 0.002347182482481003
# Physicial loss of s is: 0.0009689955040812492
# Iteration is: 119950
# Data loss is: 0.0011212045792490244
# Physicial loss of p is: 0.0006787799648009241
# Physicial loss of s is: 0.0003584347723517567
# Iteration is: 119960
# Data loss is: 0.0011204549809917808
# Physicial loss of p is: 0.0007184243877418339
# Physicial loss of s is: 0.00022930731938686222
# Iteration is: 119970
# Data loss is: 0.001118187210522592
# Physicial loss of p is: 0.0006304624257609248
# Physicial loss of s is: 0.0001725849142530933
# Iteration is: 119980
# Data loss is: 0.0011168429628014565
# Physicial loss of p is: 0.0005344439996406436
# Physicial loss of s is: 0.0002460468385834247
# Iteration is: 119990
# Data loss is: 0.0011169874342158437
# Physicial loss of p is: 0.0008100084378384054
# Physicial loss of s is: 0.0007971822051331401
# Iteration is: 120000
# Data loss is: 0.0011272800620645285
# Physicial loss of p is: 0.0023830952122807503
# Physicial loss of s is: 0.0024871239438652992
# Iteration is: 120010
# Data loss is: 0.0011238689767196774
# Physicial loss of p is: 0.0015455710235983133
# Physicial loss of s is: 0.0007240045815706253
# Iteration is: 120020
# Data loss is: 0.001119235297665
# Physicial loss of p is: 0.0009985336801037192
# Physicial loss of s is: 0.0003248330031055957
# Iteration is: 120030
# Data loss is: 0.0011168578639626503
# Physicial loss of p is: 0.0006251589511521161
# Physicial loss of s is: 0.00019839585002046078
# Iteration is: 120040
# Data loss is: 0.001116573461331427
# Physicial loss of p is: 0.0005354871391318738
# Physicial loss of s is: 0.00018819754768628627
# Iteration is: 120050
# Data loss is: 0.0011166713666170835
# Physicial loss of p is: 0.0005556734977290034
# Physicial loss of s is: 0.00019797010463662446
# Iteration is: 120060
# Data loss is: 0.00111668324097991
# Physicial loss of p is: 0.0005767575930804014
# Physicial loss of s is: 0.00018210666894447058
# Iteration is: 120070
# Data loss is: 0.0011170660145580769
# Physicial loss of p is: 0.0006456073024310172
# Physicial loss of s is: 0.00024863280123099685
# Iteration is: 120080
# Data loss is: 0.0011251454707235098
# Physicial loss of p is: 0.002074721036478877
# Physicial loss of s is: 0.0011007236316800117
# Iteration is: 120090
# Data loss is: 0.0011174242245033383
# Physicial loss of p is: 0.0006750611355528235
# Physicial loss of s is: 0.000685355975292623
# Iteration is: 120100
# Data loss is: 0.0011173002421855927
# Physicial loss of p is: 0.0006254889303818345
# Physicial loss of s is: 0.0005467343144118786
# Iteration is: 120110
# Data loss is: 0.001117722480557859
# Physicial loss of p is: 0.0006599746993742883
# Physicial loss of s is: 0.0004047850670758635
# Iteration is: 120120
# Data loss is: 0.0011171704391017556
# Physicial loss of p is: 0.0006310108583420515
# Physicial loss of s is: 0.0002652238472364843
# Iteration is: 120130
# Data loss is: 0.0011163580929860473
# Physicial loss of p is: 0.0005329735577106476
# Physicial loss of s is: 0.00017190717335324734
# Iteration is: 120140
# Data loss is: 0.0011167372576892376
# Physicial loss of p is: 0.0005676309810951352
# Physicial loss of s is: 0.00019376538693904877
# Iteration is: 120150
# Data loss is: 0.0011172316735610366
# Physicial loss of p is: 0.0007021602359600365
# Physicial loss of s is: 0.0001949853467522189
# Iteration is: 120160
# Data loss is: 0.0011249326635152102
# Physicial loss of p is: 0.0020973237697035074
# Physicial loss of s is: 0.000346595945302397
# Iteration is: 120170
# Data loss is: 0.0011166107142344117
# Physicial loss of p is: 0.0008237516158260405
# Physicial loss of s is: 0.0013992555905133486
# Iteration is: 120180
# Data loss is: 0.0011173554230481386
# Physicial loss of p is: 0.0010305080795660615
# Physicial loss of s is: 0.00048329352284781635
# Iteration is: 120190
# Data loss is: 0.0011164811439812183
# Physicial loss of p is: 0.0007587957079522312
# Physicial loss of s is: 0.0004271555517334491
# Iteration is: 120200
# Data loss is: 0.0011164509924128652
# Physicial loss of p is: 0.0006179652409628034
# Physicial loss of s is: 0.00024005841987673193
# Iteration is: 120210
# Data loss is: 0.0011170344660058618
# Physicial loss of p is: 0.0005633999826386571
# Physicial loss of s is: 0.00020926685829181224
# Iteration is: 120220
# Data loss is: 0.0011163355084136128
# Physicial loss of p is: 0.0005584571626968682
# Physicial loss of s is: 0.00017743119678925723
# Iteration is: 120230
# Data loss is: 0.001118270680308342
# Physicial loss of p is: 0.0007249062764458358
# Physicial loss of s is: 0.00018481240840628743
# Iteration is: 120240
# Data loss is: 0.0011556412791833282
# Physicial loss of p is: 0.005179723259061575
# Physicial loss of s is: 0.0022359448485076427
# Iteration is: 120250
# Data loss is: 0.0011194031685590744
# Physicial loss of p is: 0.001889559905976057
# Physicial loss of s is: 0.0008231155225075781
# Iteration is: 120260
# Data loss is: 0.0011167279444634914
# Physicial loss of p is: 0.0008813751046545804
# Physicial loss of s is: 0.000677171628922224
# Iteration is: 120270
# Data loss is: 0.0011196716222912073
# Physicial loss of p is: 0.0006960693281143904
# Physicial loss of s is: 0.00043940628529526293
# Iteration is: 120280
# Data loss is: 0.0011162316659465432
# Physicial loss of p is: 0.0005351844010874629
# Physicial loss of s is: 0.0001731664378894493
# Iteration is: 120290
# Data loss is: 0.0011164620518684387
# Physicial loss of p is: 0.000559779757168144
# Physicial loss of s is: 0.00020964145369362086
# Iteration is: 120300
# Data loss is: 0.0011161951115354896
# Physicial loss of p is: 0.0005356573965400457
# Physicial loss of s is: 0.0001715247635729611
# Iteration is: 120310
# Data loss is: 0.00111630919855088
# Physicial loss of p is: 0.0005377804045565426
# Physicial loss of s is: 0.0001753976393956691
# Iteration is: 120320
# Data loss is: 0.0011160931317135692
# Physicial loss of p is: 0.0005360487848520279
# Physicial loss of s is: 0.00017310369003098458
# Iteration is: 120330
# Data loss is: 0.0011161031434312463
# Physicial loss of p is: 0.0005324275698512793
# Physicial loss of s is: 0.00017120306438300759
# Iteration is: 120340
# Data loss is: 0.0011160766007378697
# Physicial loss of p is: 0.0005358773632906377
# Physicial loss of s is: 0.00017111697525251657
# Iteration is: 120350
# Data loss is: 0.0011171071091666818
# Physicial loss of p is: 0.0006738908705301583
# Physicial loss of s is: 0.00017177652625832707
# Iteration is: 120360
# Data loss is: 0.0011647683568298817
# Physicial loss of p is: 0.0073639871552586555
# Physicial loss of s is: 0.0002407467836746946
# Iteration is: 120370
# Data loss is: 0.001119219814427197
# Physicial loss of p is: 0.001979762688279152
# Physicial loss of s is: 0.0005243228515610099
# Iteration is: 120380
# Data loss is: 0.0011239747982472181
# Physicial loss of p is: 0.000800489739049226
# Physicial loss of s is: 0.0007298097480088472
# Iteration is: 120390
# Data loss is: 0.0011162558803334832
# Physicial loss of p is: 0.000569922209251672
# Physicial loss of s is: 0.0002255232393508777
# Iteration is: 120400
# Data loss is: 0.0011174083920195699
# Physicial loss of p is: 0.0005745654925704002
# Physicial loss of s is: 0.00023324428184423596
# Iteration is: 120410
# Data loss is: 0.0011164384195581079
# Physicial loss of p is: 0.0005459354142658412
# Physicial loss of s is: 0.00023419494391418993
# Iteration is: 120420
# Data loss is: 0.001116173225454986
# Physicial loss of p is: 0.0005837818025611341
# Physicial loss of s is: 0.0014913621125742793
# Iteration is: 120430
# Data loss is: 0.0011191439116373658
# Physicial loss of p is: 0.0009917302522808313
# Physicial loss of s is: 0.0009738302323967218
# Iteration is: 120440
# Data loss is: 0.0011171892983838916
# Physicial loss of p is: 0.0008810731815174222
# Physicial loss of s is: 0.00037259788950905204
# Iteration is: 120450
# Data loss is: 0.0011160901049152017
# Physicial loss of p is: 0.000585220055654645
# Physicial loss of s is: 0.00018337112851440907
# Iteration is: 120460
# Data loss is: 0.0011162646114826202
# Physicial loss of p is: 0.0005818323697894812
# Physicial loss of s is: 0.00017946938169188797
# Iteration is: 120470
# Data loss is: 0.001115994993597269
# Physicial loss of p is: 0.0005466973525471985
# Physicial loss of s is: 0.00017130434571299702
# Iteration is: 120480
# Data loss is: 0.0011161117581650615
# Physicial loss of p is: 0.000557810184545815
# Physicial loss of s is: 0.00022806000197306275
# Iteration is: 120490
# Data loss is: 0.0011188136413693428
# Physicial loss of p is: 0.001085840747691691
# Physicial loss of s is: 0.00030126754427328706
# Iteration is: 120500
# Data loss is: 0.0011295652948319912
# Physicial loss of p is: 0.003452393226325512
# Physicial loss of s is: 0.0019445499638095498
# Iteration is: 120510
# Data loss is: 0.0011177901178598404
# Physicial loss of p is: 0.0015260952059179544
# Physicial loss of s is: 0.000413046742323786
# Iteration is: 120520
# Data loss is: 0.001116337487474084
# Physicial loss of p is: 0.0008190686930902302
# Physicial loss of s is: 0.00021926243789494038
# Iteration is: 120530
# Data loss is: 0.0011159110581502318
# Physicial loss of p is: 0.0005543463048525155
# Physicial loss of s is: 0.00029505410930141807
# Iteration is: 120540
# Data loss is: 0.001115902210585773
# Physicial loss of p is: 0.0005445709102787077
# Physicial loss of s is: 0.00026542568230070174
# Iteration is: 120550
# Data loss is: 0.001115936553105712
# Physicial loss of p is: 0.0005450706230476499
# Physicial loss of s is: 0.00017209687212016433
# Iteration is: 120560
# Data loss is: 0.0011160500580444932
# Physicial loss of p is: 0.0005743784713558853
# Physicial loss of s is: 0.00017649562505539507
# Iteration is: 120570
# Data loss is: 0.0011180629953742027
# Physicial loss of p is: 0.0009205439710058272
# Physicial loss of s is: 0.00018292429740540683
# Iteration is: 120580
# Data loss is: 0.0011410387232899666
# Physicial loss of p is: 0.004439855460077524
# Physicial loss of s is: 0.001476355129852891
# Iteration is: 120590
# Data loss is: 0.00111765309702605
# Physicial loss of p is: 0.001973742386326194
# Physicial loss of s is: 0.0005729192052967846
# Iteration is: 120600
# Data loss is: 0.001116169267334044
# Physicial loss of p is: 0.0010313316015526652
# Physicial loss of s is: 0.000453218468464911
# Iteration is: 120610
# Data loss is: 0.0011159322457388043
# Physicial loss of p is: 0.0005563708255067468
# Physicial loss of s is: 0.00017464353004470468
# Iteration is: 120620
# Data loss is: 0.0011161152506247163
# Physicial loss of p is: 0.0005523344152607024
# Physicial loss of s is: 0.000188984238775447
# Iteration is: 120630
# Data loss is: 0.001115821534767747
# Physicial loss of p is: 0.0005622039316222072
# Physicial loss of s is: 0.00019560115470085293
# Iteration is: 120640
# Data loss is: 0.0011160842841491103
# Physicial loss of p is: 0.0005411499296315014
# Physicial loss of s is: 0.00017947258311323822
# Iteration is: 120650
# Data loss is: 0.0011156715918332338
# Physicial loss of p is: 0.0005459438543766737
# Physicial loss of s is: 0.0001731310912873596
# Iteration is: 120660
# Data loss is: 0.001116995932534337
# Physicial loss of p is: 0.0006459034630097449
# Physicial loss of s is: 0.00020464236149564385
# Iteration is: 120670
# Data loss is: 0.0011526790913194418
# Physicial loss of p is: 0.004667061846703291
# Physicial loss of s is: 0.0009424495510756969
# Iteration is: 120680
# Data loss is: 0.0011264885542914271
# Physicial loss of p is: 0.0018816639203578234
# Physicial loss of s is: 0.0005814691539853811
# Iteration is: 120690
# Data loss is: 0.0011164171155542135
# Physicial loss of p is: 0.0008984340820461512
# Physicial loss of s is: 0.0005649451049976051
# Iteration is: 120700
# ...
# Physicial loss of s is: 0.00012306543067097664
# Iteration is: 172360
# Data loss is: 0.001049150014296174
# Physicial loss of p is: 0.0004382322367746383
# Physicial loss of s is: 0.0001178356324089691
# Iteration is: 172370
# Data loss is: 0.0010491105495020747
# Physicial loss of p is: 0.0004759644507430494
# Physicial loss of s is: 0.00011896889191120863
# Iteration is: 172380
# Data loss is: 0.001061350223608315
# Physicial loss of p is: 0.0031829760409891605
# Physicial loss of s is: 0.0005256212898530066
# Iteration is: 172390
# Data loss is: 0.0010571993188932538
# Physicial loss of p is: 0.0015874664532020688
# Physicial loss of s is: 0.00037161484942771494
# Iteration is: 172400
# Data loss is: 0.0010506234830245376
# Physicial loss of p is: 0.0013817910803481936
# Physicial loss of s is: 0.0004094126634299755
# Iteration is: 172410
# Data loss is: 0.0010501405922695994
# Physicial loss of p is: 0.0005219835438765585
# Physicial loss of s is: 0.0002649746893439442
# Iteration is: 172420
# Data loss is: 0.0010491723660379648
# Physicial loss of p is: 0.0005170365911908448
# Physicial loss of s is: 0.00019382726168259978
# Iteration is: 172430
# Data loss is: 0.001049440004862845
# Physicial loss of p is: 0.0004558073414955288
# Physicial loss of s is: 0.0001262155274162069
# Iteration is: 172440
# Data loss is: 0.0010491603752598166
# Physicial loss of p is: 0.0004332641256041825
# Physicial loss of s is: 0.00011600551806623116
# Iteration is: 172450
# Data loss is: 0.0010489575797691941
# Physicial loss of p is: 0.0004299077845644206
# Physicial loss of s is: 0.00011278442980255932
# Iteration is: 172460
# Data loss is: 0.0010488902917131782
# Physicial loss of p is: 0.00043028569780290127
# Physicial loss of s is: 0.00011341582285240293
# Iteration is: 172470
# Data loss is: 0.001048867590725422
# Physicial loss of p is: 0.00042903804569505155
# Physicial loss of s is: 0.00011460688983788714
# Iteration is: 172480
# Data loss is: 0.001048828475177288
# Physicial loss of p is: 0.0004284727037884295
# Physicial loss of s is: 0.00011326903040753677
# Iteration is: 172490
# Data loss is: 0.0010488154366612434
# Physicial loss of p is: 0.0004269445489626378
# Physicial loss of s is: 0.00011314239236526191
# Iteration is: 172500
# Data loss is: 0.0010488192783668637
# Physicial loss of p is: 0.0004285458999220282
# Physicial loss of s is: 0.00011323823855491355
# Iteration is: 172510
# Data loss is: 0.0010512638837099075
# Physicial loss of p is: 0.0006991686532273889
# Physicial loss of s is: 0.00016192525799851865
# Iteration is: 172520
# Data loss is: 0.0010795191628858447
# Physicial loss of p is: 0.006314374040812254
# Physicial loss of s is: 0.009246394038200378
# Iteration is: 172530
# Data loss is: 0.0010498444316908717
# Physicial loss of p is: 0.0017410587752237916
# Physicial loss of s is: 0.0005107885226607323
# Iteration is: 172540
# Data loss is: 0.0010507055558264256
# Physicial loss of p is: 0.0006533102132380009
# Physicial loss of s is: 0.00036665855441242456
# Iteration is: 172550
# Data loss is: 0.001053485437296331
# Physicial loss of p is: 0.0006538178422488272
# Physicial loss of s is: 0.00018345397256780416
# Iteration is: 172560
# Data loss is: 0.0010507403640076518
# Physicial loss of p is: 0.0006471574888564646
# Physicial loss of s is: 0.00013103956007398665
# Iteration is: 172570
# Data loss is: 0.0010491420980542898
# Physicial loss of p is: 0.0004463582008611411
# Physicial loss of s is: 0.00012753198097925633
# Iteration is: 172580
# Data loss is: 0.0010490425629541278
# Physicial loss of p is: 0.00043742998968809843
# Physicial loss of s is: 0.00012934824917465448
# Iteration is: 172590
# Data loss is: 0.001048868871293962
# Physicial loss of p is: 0.0004301967564970255
# Physicial loss of s is: 0.00011627846834016964
# Iteration is: 172600
# Data loss is: 0.0010488355765119195
# Physicial loss of p is: 0.00042987437336705625
# Physicial loss of s is: 0.00011473808262962848
# Iteration is: 172610
# Data loss is: 0.0010487879626452923
# Physicial loss of p is: 0.00042836403008550406
# Physicial loss of s is: 0.00011401790106901899
# Iteration is: 172620
# Data loss is: 0.0010487501276656985
# Physicial loss of p is: 0.0004289767239242792
# Physicial loss of s is: 0.00011423585237935185
# Iteration is: 172630
# Data loss is: 0.0010487291729077697
# Physicial loss of p is: 0.00042719574412330985
# Physicial loss of s is: 0.00011414028267608956
# Iteration is: 172640
# Data loss is: 0.0010487041436135769
# Physicial loss of p is: 0.00042686957749538124
# Physicial loss of s is: 0.0001141905304393731
# Iteration is: 172650
# Data loss is: 0.0010486794635653496
# Physicial loss of p is: 0.00042719722841866314
# Physicial loss of s is: 0.00011452696344349533
# Iteration is: 172660
# Data loss is: 0.0010486770188435912
# Physicial loss of p is: 0.00043347597238607705
# Physicial loss of s is: 0.00012240977957844734
# Iteration is: 172670
# Data loss is: 0.0010493418667465448
# Physicial loss of p is: 0.0008738593314774334
# Physicial loss of s is: 0.00065458012977615
# Iteration is: 172680
# Data loss is: 0.001069657620973885
# Physicial loss of p is: 0.002622462110593915
# Physicial loss of s is: 0.0002340510836802423
# Iteration is: 172690
# Data loss is: 0.0010518309427425265
# Physicial loss of p is: 0.0006105481297709048
# Physicial loss of s is: 0.0004326377820689231
# Iteration is: 172700
# Data loss is: 0.0010554634500294924
# Physicial loss of p is: 0.0007110521546564996
# Physicial loss of s is: 0.00017203246534336358
# Iteration is: 172710
# Data loss is: 0.0010490070562809706
# Physicial loss of p is: 0.0004372214316390455
# Physicial loss of s is: 0.00011891272151842713
# Iteration is: 172720
# Data loss is: 0.001049348502419889
# Physicial loss of p is: 0.00046953975106589496
# Physicial loss of s is: 0.0001265106984646991
# Iteration is: 172730
# Data loss is: 0.0010487425606697798
# Physicial loss of p is: 0.00043585911043919623
# Physicial loss of s is: 0.00011616356641752645
# Iteration is: 172740
# Data loss is: 0.00104879483114928
# Physicial loss of p is: 0.00042806306737475097
# Physicial loss of s is: 0.00012384180445224047
# Iteration is: 172750
# Data loss is: 0.0010486663086339831
# Physicial loss of p is: 0.0004688035405706614
# Physicial loss of s is: 0.00013483891962096095
# Iteration is: 172760
# Data loss is: 0.0010546845151111484
# Physicial loss of p is: 0.0019006752409040928
# Physicial loss of s is: 0.0009035205002874136
# Iteration is: 172770
# Data loss is: 0.0010497313924133778
# Physicial loss of p is: 0.0004571744939312339
# Physicial loss of s is: 0.0002887117734644562
# Iteration is: 172780
# Data loss is: 0.001049910904839635
# Physicial loss of p is: 0.00141912663821131
# Physicial loss of s is: 0.0002548607881180942
# Iteration is: 172790
# Data loss is: 0.001049965270794928
# Physicial loss of p is: 0.0008870212477631867
# Physicial loss of s is: 0.00017201085574924946
# Iteration is: 172800
# Data loss is: 0.0010487176477909088
# Physicial loss of p is: 0.00045357804629020393
# Physicial loss of s is: 0.00012114315904909745
# Iteration is: 172810
# Data loss is: 0.0010486423270776868
# Physicial loss of p is: 0.0004286551848053932
# Physicial loss of s is: 0.00011755435116356239
# Iteration is: 172820
# Data loss is: 0.0010486413957551122
# Physicial loss of p is: 0.0004275972896721214
# Physicial loss of s is: 0.00011330848064972088
# Iteration is: 172830
# Data loss is: 0.0010486183455213904
# Physicial loss of p is: 0.00043423890019766986
# Physicial loss of s is: 0.00011403863754821941
# Iteration is: 172840
# Data loss is: 0.0010485408129170537
# Physicial loss of p is: 0.0004337467544246465
# Physicial loss of s is: 0.00011416510096751153
# Iteration is: 172850
# Data loss is: 0.0010484985541552305
# Physicial loss of p is: 0.0004275921965017915
# Physicial loss of s is: 0.000114693000796251
# Iteration is: 172860
# Data loss is: 0.001048527890816331
# Physicial loss of p is: 0.00042899121763184667
# Physicial loss of s is: 0.00013915251474827528
# Iteration is: 172870
# Data loss is: 0.0010516137117519975
# Physicial loss of p is: 0.0005057869711890817
# Physicial loss of s is: 0.0012543981429189444
# Iteration is: 172880
# Data loss is: 0.0010552684543654323
# Physicial loss of p is: 0.002540114102885127
# Physicial loss of s is: 0.0008450975292362273
# Iteration is: 172890
# Data loss is: 0.0010500811040401459
# Physicial loss of p is: 0.0011302399216219783
# Physicial loss of s is: 0.0008536393870599568
# Iteration is: 172900
# Data loss is: 0.0010523409582674503
# Physicial loss of p is: 0.0006259371293708682
# Physicial loss of s is: 0.00019868533127009869
# Iteration is: 172910
# Data loss is: 0.0010493623558431864
# Physicial loss of p is: 0.0004641445120796561
# Physicial loss of s is: 0.00014121255662757903
# Iteration is: 172920
# Data loss is: 0.0010495322057977319
# Physicial loss of p is: 0.0004516183980740607
# Physicial loss of s is: 0.000152057153172791
# Iteration is: 172930
# Data loss is: 0.0010486254468560219
# Physicial loss of p is: 0.0004374046402517706
# Physicial loss of s is: 0.0001163182023447007
# Iteration is: 172940
# Data loss is: 0.0010484990198165178
# Physicial loss of p is: 0.0004284721799194813
# Physicial loss of s is: 0.00012091078679077327
# Iteration is: 172950
# Data loss is: 0.001048498903401196
# Physicial loss of p is: 0.0004640814440790564
# Physicial loss of s is: 0.00011716314475052059
# Iteration is: 172960
# Data loss is: 0.0010517865885049105
# Physicial loss of p is: 0.0011702125193551183
# Physicial loss of s is: 0.0002968155313283205
# Iteration is: 172970
# Data loss is: 0.00105538428761065
# Physicial loss of p is: 0.0029900481458753347
# Physicial loss of s is: 0.001716897590085864
# Iteration is: 172980
# Data loss is: 0.0010495843598619103
# Physicial loss of p is: 0.0005418793298304081
# Physicial loss of s is: 0.0005034262430854142
# Iteration is: 172990
# Data loss is: 0.001048882259055972
# Physicial loss of p is: 0.0005813216557726264
# Physicial loss of s is: 0.00026007951237261295
# Iteration is: 173000
# Data loss is: 0.001048721605911851
# Physicial loss of p is: 0.0005642804899252951
# Physicial loss of s is: 0.0002073420473607257
# Iteration is: 173010
# Data loss is: 0.0010485511738806963
# Physicial loss of p is: 0.0004709344357252121
# Physicial loss of s is: 0.000161231160745956
# Iteration is: 173020
# Data loss is: 0.0010484425583854318
# Physicial loss of p is: 0.00044110053568147123
# Physicial loss of s is: 0.000149092884385027
# Iteration is: 173030
# Data loss is: 0.001048391219228506
# Physicial loss of p is: 0.0004282206646166742
# Physicial loss of s is: 0.00011986195022473112
# Iteration is: 173040
# Data loss is: 0.0010483305668458343
# Physicial loss of p is: 0.00042692202259786427
# Physicial loss of s is: 0.00011487789015518501
# Iteration is: 173050
# Data loss is: 0.001048343488946557
# Physicial loss of p is: 0.0004366865032352507
# Physicial loss of s is: 0.00011320947669446468
# Iteration is: 173060
# Data loss is: 0.0010489225387573242
# Physicial loss of p is: 0.0005348197882995009
# Physicial loss of s is: 0.0001303994213230908
# Iteration is: 173070
# Data loss is: 0.0010695334058254957
# Physicial loss of p is: 0.003820571815595031
# Physicial loss of s is: 0.0016103985253721476
# Iteration is: 173080
# Data loss is: 0.001052242936566472
# Physicial loss of p is: 0.0022847687359899282
# Physicial loss of s is: 0.0004025291418656707
# Iteration is: 173090
# Data loss is: 0.0010495622409507632
# Physicial loss of p is: 0.0012261774390935898
# Physicial loss of s is: 0.0004800159076694399
# Iteration is: 173100
# Data loss is: 0.0010491564171388745
# Physicial loss of p is: 0.00044845076627098024
# Physicial loss of s is: 0.00012501771561801434
# Iteration is: 173110
# Data loss is: 0.0010483524529263377
# Physicial loss of p is: 0.0004785214550793171
# Physicial loss of s is: 0.00014714286953676492
# Iteration is: 173120
# Data loss is: 0.001048396690748632
# Physicial loss of p is: 0.0004454390436876565
# Physicial loss of s is: 0.00012978236190974712
# Iteration is: 173130
# Data loss is: 0.001048357575200498
# Physicial loss of p is: 0.0004288605123292655
# Physicial loss of s is: 0.00011350898421369493
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 6
#       1 Nmax=2*10**5
#       4 while it <= Nmax:
#       5     # if it<5*10**4:
# ----> 6     loss_, loss_p, loss_fp, loss_fs, loss_fa, loss_f0a = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0)
#       7     # else:
#       8     #     loss_, loss_p, loss_fp, loss_fs, loss_fa, loss_f0a = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0)
#       9     # else:
#      10     #     loss_, loss_p, loss_fp, loss_fs, loss_fa = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)
#      12     loss.append(loss_)
#
# File c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\tensorflow\python\eager\function.py:1601, in ConcreteFunction.__call__(self, *args, **kwargs)
#    1551 def __call__(self, *args, **kwargs):
#    1552   """Executes the wrapped function.
#    1553
#    1554   ConcreteFunctions have two signatures:
#    (...)
#    1599     TypeError: If the arguments do not match the function's signature.
#    1600   """
# -> 1601   return self._call_impl(args, kwargs)
#
# File c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\tensorflow\python\eager\function.py:1610, in ConcreteFunction._call_impl(self, args, kwargs, cancellation_manager)
#    1608 if self._function_spec is not None:
#    1609   try:
# -> 1610     return self._call_with_structured_signature(args, kwargs,
#    1611                                                 cancellation_manager)
#    1612   except TypeError as structured_err:
#    1613     try:
#
# File c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\tensorflow\python\eager\function.py:1691, in ConcreteFunction._call_with_structured_signature(self, args, kwargs, cancellation_manager)
#    1689 self._structured_signature_check_unexpected_args(args, kwargs)
#    1690 self._structured_signature_check_arg_types(args, kwargs)
# -> 1691 return self._call_flat(
#    1692     filtered_flat_args,
#    1693     captured_inputs=self.captured_inputs,
#    1694     cancellation_manager=cancellation_manager)
#
# File c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]
loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]
loss_phia_list = [loss_fisa[i].numpy() for i in range(0,Nmax)]
loss_0_list = [loss_0[i].numpy() for i in range(0,Nmax)]





plt.semilogy(ep, np.asarray(loss_data_list), 'b-', linewidth = 2, alpha=0.6, label = 'Data')  
plt.semilogy(ep, np.asarray(loss_phip_list), 'r-', linewidth = 2, alpha=0.6, label = '$\phi_p$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\phi_s$') 
plt.semilogy(ep, np.asarray(loss_phia_list), 'y-', linewidth = 2, alpha=0.6, label = '$\phi_a$')    
# plt.semilogy(ep, np.asarray(loss_0_list), color='orange', linestyle='-', linewidth = 2, alpha=0.6, label = '$a_0$')       




plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
lnv[0], tf.exp(lnv[0]), lnv[1], tf.exp(lnv[1])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([2.7182817], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([2.7182817], dtype=float32)>)

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp=u_pred[:,0:1]
lns=u_pred[:,1:2]
lna=u_pred[:,2:3]


p=tf.exp(lnp)
s=tf.exp(lns)
a=tf.exp(lna)


phi_pa=net(tf.concat([p, a],1), W_a, b_a)
phi_ps=net(tf.concat([p, s],1), W_phi, b_phi)
phi_p_s=tf.exp(phi_ps[...,0:1])
phi_s=tf.exp(phi_ps[...,1:2])
phi_p_a=tf.exp(phi_pa[...,0:1])
phi_a=tf.exp(phi_pa[...,1:2])


s_t=-phi_s*s*p
a_t=-phi_a*a*p

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],s[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')



plt.xlabel('t (ms)')
plt.ylabel('S')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],a[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')




plt.xlabel('t (ms)')
plt.ylabel('A')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
# plt.scatter(p, phi_s, s=3, label='Prediction')
plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
# plt.scatter(p, phi_s, s=3, label='Prediction')
plt.scatter(a, phi_a, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.scatter(p, phi_s, s=3, label='Prediction')

plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
A
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
Nt=1000

# A_0=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
# A_0=np.array([0,1.25, 2.5,3.75])

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)
    A_int=np.zeros(Nt)



    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    A_int[0]=np.array(a) #Initial conditions
    S_int[0]=np.array(s[0]) #Initial conditions

    # l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        PS=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)
        PA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)

        # REVISAAAAAR
        PHI_PS=predict(PS, W_phi, b_phi)
        PHI_PA=predict(PA , W_a, b_a)

        P_int[i]=P_int[i-1]+(P_int[i-1]*S_int[i-1]*tf.exp(PHI_PS[:,0:1]) - P_int[i-1]*A_int[i-1]*tf.exp(PHI_PA[:,0:1]))*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*tf.exp(PHI_PS[:,1:2])*dt
        A_int[i]=A_int[i-1]-P_int[i-1]*A_int[i-1]*tf.exp(PHI_PA[:,1:2])*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')
    # plt.plot(T_int, A_int,  linestyle=':', label=f'Numeric integration dAdT {a}')


plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %%
ghjk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 ghjk
#
# NameError: name 'ghjk' is not defined

# %%
bnm,

# %%
Nt=1000

# A_0=np.array([0,0.75, 1.25,2, 2.5,3,3.75])


L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors
A_0=np.array([0,1.25, 2.5,3.75])

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)
    A_int=np.zeros(Nt)



    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    A_int[0]=np.array(a) #Initial conditions
    S_int[0]=np.array(s[0]) #Initial conditions

    # l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        PHI_A=tf.exp(predict(tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_a, b_a))

        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI_S - P_int[i-1]*PHI_A)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m)*dt
        A_int[i]=A_int[i-1]-P_int[i-1]*A_int[i-1]*np.array(l)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    # plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')
    # plt.plot(T_int, A_int,  linestyle=':', label=f'Numeric integration dAdT {a}')

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
# plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')


# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
c=0
d=-1
plt.scatter( p[c:d], np.exp(phi[c:d]), s=2, label='Prediction P')
plt.scatter( s[c:d], np.exp(phi[c:d]), s=2, label='Prediction S')
# plt.plot( a[c:d], phi_p[c:d], label='Prediction S')


plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
X_star_tf[c:d][0], X_star_tf[c:d][-1]
# Out:
# (<tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.    , 0.0938], dtype=float32)>,
#  <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.9970674, 0.0923   ], dtype=float32)>)

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')




plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')


plt.vlines(X_star_tf[c:d][:,0][0],0,1.2, color='red', linestyle=':')
plt.vlines(X_star_tf[c:d][:,0][-1],0,1.2, color='red', linestyle=':')


plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
model = PySRRegressor(
    niterations=200,
    binary_operators=["+", "*", "inv(x, y) = x/(x + y)"],
    # binary_operators=["+", "*", "inv(x, y) = x/(x + y)", "^"],

    # unary_operators=[ "exp"],
    # unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={
            "inv": lambda x, y: x/(x+y),
        },
    # extra_sympy_mappings={"inv": lambda x: 1/x},
    constraints={"exp": 3, 'inv': (1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00000001,
    # denoise=True,
    # complexity_of_variables=2,
    # complexity_of_constants=2,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
    select_k_features=1,
    maxsize=40,
)

# %%
# p1s=tf.concat([p1[c:d], s[c:d]], axis=1)

min_cols_phi= tf.math.reduce_min(phi[c:d], axis=0)
max_cols_phi= tf.math.reduce_max(phi[c:d], axis=0)

phi_scaled = (phi[c:d]-min_cols_phi)/(max_cols_phi-min_cols_phi)
PS_tf=tf.concat([p[c:d], s[c:d]],1)

model.fit( PS_tf,phi_scaled)
print(model)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Using features ['x1']
# [ Info: Started!
# Expressions evaluated per second: 2.780e+04
# Head worker occupation: 22.9%
# Progress: 75 / 3000 total iterations (2.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           3.955e-02  5.314e+00  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.478e-02  2.859e-02  y = ((inv(x1, 0.10223) * -0.30208) + (0.15902 + x1)) + 0.09950...
#                                   7
# 13          2.370e-02  2.218e-02  y = 0.099507 + ((0.18993 + x1) + ((-0.30208 * 1.3452) * inv(x1...
#                                   , 0.10223)))
# 17          2.215e-02  1.688e-02  y = 0.18608 + ((x1 + (((-1.0119 * x1) * x1) * (x1 * x1))) * (x...
#                                   1 + x1))
# 19          1.947e-02  6.449e-02  y = 0.25455 + (((((-0.85623 * x1) * x1) * x1) + x1) * ((x1 + 0...
#                                   .14507) + (-0.30395 + x1)))
# 21          1.793e-02  4.126e-02  y = 0.25004 + (((x1 + (((x1 + x1) + -0.66889) * 2.4278)) * (-0...
#                                   .39674 + inv(0.85065, x1))) * (x1 + x1))
# 25          1.672e-02  1.743e-02  y = (x1 * ((((x1 + x1) + -0.080258) * ((inv(x1, x1) + ((x1 * -...
#                                   0.92223) * (x1 * x1))) + 0.95982)) + -0.82044)) + 0.2704
# 27          1.306e-02  1.236e-01  y = ((((inv(1.4462, 2.2953) + ((x1 * (0.16588 + x1)) * -0.8808...
#                                   2)) + 0.62528) * ((x1 + ((2.9017 * x1) + -1.2808)) + x1)) * x1...
#                                   ) + 0.26349
# 31          1.115e-02  3.957e-02  y = (((((1.9312 + ((x1 * (0.56703 + x1)) * -1.3051)) + -0.1458...
#                                   1) * ((x1 + ((1.3124 * x1) + -1.0317)) + x1)) + ((-0.59911 + x...
#                                   1) + 0.079291)) * x1) + 0.29135
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.800e+04
# Head worker occupation: 19.6%
# Progress: 172 / 3000 total iterations (5.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 15          1.863e-02  3.620e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.855e-02  2.179e-03  y = 0.2407 + (((x1 * (((x1 * -0.96546) * x1) * x1)) + x1) * (x...
#                                   1 + x1))
# 19          1.180e-02  2.260e-01  y = ((((x1 + -0.9667) * 3.1557) * ((x1 * -2.4664) + inv(0.8407...
#                                   1, x1))) * x1) + (0.19285 + 0.10635)
# 21          1.096e-02  3.683e-02  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.19285 + 0.10635)
# 23          1.063e-02  1.558e-02  y = ((x1 * ((x1 + (x1 + (x1 + (x1 + -1.3504)))) * ((-1.5055 * ...
#                                   (x1 * 1.2765)) + 1.9003))) + 0.242) * 1.2304
# 29          1.061e-02  2.597e-04  y = (((((-1.2701 + (x1 + (inv(-0.22109, 1.2369) + x1))) + ((-0...
#                                   .23128 + x1) + x1)) + x1) * (((x1 * 0.97839) * -1.9394) + 1.87...
#                                   65)) * x1) + 0.30126
# 31          1.056e-02  2.149e-03  y = (1.0965 * ((((((x1 * x1) * -0.47626) + x1) + ((x1 + -0.415...
#                                   78) * (1.5945 + inv(-0.6427, 0.35635)))) * ((x1 * -1.9534) + 1...
#                                   .9355)) * x1)) + (0.27317 + 0.029663)
# 37          1.054e-02  4.362e-04  y = 0.29991 + (x1 * ((((((((x1 + x1) + -0.84768) + x1) + x1) +...
#                                    (((-0.041061 * x1) * x1) + ((-1.7349 + -1.0641) + x1))) + -1....
#                                   3884) + inv(0.15367, x1)) * ((x1 * -2.079) + 0.72708)))
# 39          1.003e-02  2.451e-02  y = (x1 * ((((x1 * (-1.9266 * 0.87892)) * x1) + 1.8833) * (((1...
#                                   .8833 + (x1 * ((-1.5986 * x1) + -0.2367))) * (((x1 + -1.3044) ...
#                                   + (x1 + 0.15884)) + (x1 + inv(0.047572, x1)))) + 0.043323))) +...
#                                    0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Head worker occupation: 15.9%
# Progress: 250 / 3000 total iterations (8.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          2.136e-02  3.898e-03  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * (x1 * 1.0785)...
#                                   )
# 15          1.863e-02  6.850e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.245e-02  2.014e-01  y = (0.19285 + 0.086001) + ((((x1 + -0.9667) * 3.1557) * (0.90...
#                                   662 + (-2.7585 * x1))) * x1)
# 19          1.140e-02  4.434e-02  y = (((-0.10278 + (3.1557 * (x1 + -0.9667))) * ((x1 * -2.4664)...
#                                    + 0.84071)) * x1) + (0.10635 + 0.19285)
# 21          1.092e-02  2.120e-02  y = (((-0.10278 + ((-0.9667 + x1) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.095392 + 0.19285)
# 23          1.062e-02  1.392e-02  y = ((x1 + -0.081559) * (((-2.2871 * x1) + 2.3214) * ((x1 * 2....
#                                   2758) + ((-1.1269 + x1) + (x1 + 0.11778))))) + 0.11195
# 27          1.045e-02  4.143e-03  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + ((0.84071 + inv(...
#                                   x1, -1.3214)) + x1)))) * ((x1 * -2.4664) + 0.84071)) * x1) + (...
#                                   0.19285 + 0.10635)
# 29          1.041e-02  1.637e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + -0.33894) ...
#                                   * ((x1 + inv(0.047572, x1)) + (x1 + -1.3044))) + x1) + (x1 * 1...
#                                   .1842)))) + 0.30147
# 31          1.008e-02  1.639e-02  y = (x1 * (((-1.9266 * x1) + 1.8833) * (((1.8833 + 0.077362) *...
#                                    ((x1 + (inv(0.047572, x1) + -0.064585)) + ((x1 + x1) + -1.304...
#                                   4))) + (0.30147 * 1.1842)))) + 0.30147
# 37          9.843e-03  3.925e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + inv(0.0773...
#                                   62, x1)) * ((x1 + inv(0.047572, x1)) + (inv(0.043323, 0.15884)...
#                                    + (x1 + -1.3044)))) + x1) + (x1 * inv(1.1842, 0.91425))))) + ...
#                                   0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.700e+04
# Head worker occupation: 14.5%
# Progress: 329 / 3000 total iterations (10.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.617e-02  1.432e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.4051)) *...
#                                    x1)
# 15          1.224e-02  1.390e-01  y = 0.28154 + (x1 * ((x1 + -0.99589) * (((-5.2648 + -1.9302) *...
#                                    x1) + 2.2863)))
# 17          1.167e-02  2.394e-02  y = 0.28154 + (x1 * ((x1 + -0.99589) * ((((-5.2648 + -1.1021) ...
#                                   + -1.2315) * x1) + 2.2863)))
# 19          1.070e-02  4.356e-02  y = 0.30839 + (x1 * (((1.8937 * (x1 + (-0.8686 + x1))) + x1) *...
#                                    (1.9877 + (x1 * -2.0051))))
# 23          1.061e-02  2.016e-03  y = 0.30131 + ((x1 * 1.6833) * (((-1.9277 * x1) + 1.9069) * ((...
#                                   0.54582 + (((0.51804 + -1.3234) + x1) * 1.9209)) + x1)))
# 27          9.929e-03  1.662e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + x1)))
# 29          9.905e-03  1.218e-03  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * ((1.8246 + x1) * inv(x1, 0...
#                                   .31499))) + x1)))
# 31          8.648e-03  6.782e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1....
#                                   9302)) * (((x1 + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + (0.20664 * inv(x1, x1)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.150e+04
# Head worker occupation: 14.2%
# Progress: 426 / 3000 total iterations (14.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.052e-02  2.579e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * (((-4.6...
#                                   638 + (x1 * (x1 + -0.67368))) * x1) + 1.6117)))
# 25          1.050e-02  9.160e-04  y = (0.21074 + (x1 * ((-1.0022 + x1) * (2.4464 + ((-2.5247 + (...
#                                   (-5.2844 + (x1 * (x1 + x1))) * 0.9772)) * x1))))) * 1.4173
# 27          9.528e-03  4.841e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (-1.9302 * x1)) ...
#                                   * (((x1 + (inv(-0.83605, 1.6945) + x1)) * (1.9019 * inv(x1, 0....
#                                   31499))) + x1)))
# 29          8.448e-03  6.015e-02  y = (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1.9302)) * (...
#                                   ((1.8246 * inv(x1, 0.20664)) * (x1 + (-0.83605 + inv(x1, 0.791...
#                                   32)))) + 0.20664))) + 0.29387
# 33          5.125e-03  1.249e-01  y = ((inv(x1, 0.0098097) * 0.87837) * ((1.9533 + ((x1 * x1) * ...
#                                   -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2292)) * (x1 + (inv(x...
#                                   1, 0.7733) + -0.77502))) + 0.2292))) + 0.2292
# 35          4.691e-03  4.421e-02  y = ((inv(x1, 0.0098097) * 0.87837) * (((x1 * (-1.9397 * x1)) ...
#                                   + 1.8885) * (((((1.8202 + x1) + 0.20894) * inv(x1, 0.20894)) *...
#                                    ((-0.77502 + inv(x1, 0.7733)) + x1)) + 0.25046))) + 0.2292
# 37          3.741e-03  1.132e-01  y = (((inv(x1, 0.0098097) * 0.87837) + (-0.22058 * x1)) * ((1....
#                                   9533 + ((x1 * x1) * -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2...
#                                   292)) * (x1 + (inv(x1, 0.7733) + -0.77502))) + 0.2292))) + 0.2...
#                                   292
# 39          3.216e-03  7.559e-02  y = (((inv(x1, 0.0041438) * 0.87769) + (-0.22025 * (x1 + -0.15...
#                                   79))) * ((1.9537 + ((x1 * x1) * -1.9389)) * (0.22256 + (((1.95...
#                                   4 + x1) * inv(x1, 0.21981)) * (x1 + (inv(x1, 0.77348) + -0.778...
#                                   73)))))) + 0.19528
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.950e+04
# Head worker occupation: 14.8%
# Progress: 535 / 3000 total iterations (17.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.367e-03  y = 0.3052 + (x1 * ((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 ...
#                                   + ((x1 * 1.1883) * x1)) * x1) + 1.6117)))
# 25          2.667e-03  6.852e-01  y = (((0.26613 + ((inv(x1, 0.19528) * 1.9537) * (x1 + (-0.7787...
#                                   3 + x1)))) * (1.9537 + (x1 * -1.9389))) * inv(x1, 0.0041438)) ...
#                                   + 0.19528
# 27          2.108e-03  1.176e-01  y = 0.19528 + (((0.26613 + ((x1 + (x1 + -0.77873)) * (inv(x1, ...
#                                   0.19528) * 1.9537))) * (1.9537 + ((0.97698 * x1) * -1.9389))) ...
#                                   * inv(x1, 0.0041438))
# 29          1.636e-03  1.269e-01  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 37          1.339e-03  1.250e-03  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.100e+04
# Head worker occupation: 15.0%
# Progress: 639 / 3000 total iterations (21.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.636e-03  9.570e-02  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.341e-03  1.548e-03  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + (x1 * 0.93073)) +...
#                                    inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.158...
#                                   87
# 37          1.339e-03  9.526e-04  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# 39          1.215e-03  4.855e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * (inv(1.2861, 0.84669) + -0.15182)))) * ((...
#                                   x1 + -0.87651) + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1...
#                                   , 0.0056867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 731 / 3000 total iterations (24.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.631e-03  9.701e-02  y = 0.15887 + (((0.75672 * (1.9752 + (-1.9035 * x1))) * (((x1 ...
#                                   + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x1)) + 0.4196...
#                                   2)) * inv(x1, 0.0056867))
# 31          1.403e-03  7.550e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.294e-03  1.938e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * ((((x1 + (inv(x1...
#                                   , 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651) ...
#                                   + x1)) + 0.41962) * 1.1182)) * inv(x1, 0.0056867)) + 0.15887
# 37          1.177e-03  4.740e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651)...
#                                    + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1, 0.0056867)) ...
#                                   + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+04
# Head worker occupation: 14.3%
# Progress: 828 / 3000 total iterations (27.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          8.340e-03  1.185e-01  y = ((((x1 * -1.9035) + 1.9752) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  6.129e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.491e-03  2.480e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + inv(0.41962, 0.72301))) * inv(x1, 0...
#                                   .0056867)) + 0.15887
# 31          1.403e-03  1.520e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.191e-03  6.093e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((inv(x1, 1.4938) + inv(x1, 0.060135)) + x1) * ((-0.876...
#                                   51 + x1) + x1)) + 0.41962))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.173e-03  7.562e-03  y = ((((-1.9035 * x1) + 1.9752) * (((((inv(x1, 0.060135) + x1)...
#                                    + (inv(x1, 1.9457) * x1)) * ((-0.87651 + x1) + x1)) * inv(1.0...
#                                   821, 0.092927)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)...
#                                   ) + 0.15887
# 39          1.147e-03  1.132e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((((inv(x1, 1.4938) * x1) + inv(x1, 0.060135)) * 1.0811...
#                                   ) + x1) * ((-0.87651 + x1) + x1)) + 0.41962))) * inv(x1, 0.005...
#                                   6867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 941 / 3000 total iterations (31.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  3.101e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.309e-03  3.131e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.248e-03  2.389e-02  y = ((inv(x1, 0.0056867) + -0.012119) * (((((inv(x1, 0.060135)...
#                                    + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9...
#                                   752 + (-1.9035 * x1)))) + 0.15887
# 31          1.247e-03  2.635e-04  y = ((inv(x1, 0.0056867) + (-0.012119 * 1.1739)) * (((((inv(x1...
#                                   , 0.060135) + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41...
#                                   962) * (1.9752 + (-1.9035 * x1)))) + 0.15887
# 35          1.162e-03  1.770e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.300e+04
# Head worker occupation: 15.3%
# Progress: 1029 / 3000 total iterations (34.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.240e-03  2.677e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * 0.89975)))) + 0.15887
# 31          1.214e-03  1.062e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.89975, 0.21942))))) + 0.15887
# 33          1.192e-03  9.391e-03  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.180e+04
# Head worker occupation: 15.1%
# Progress: 1119 / 3000 total iterations (37.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.222e-03  3.409e-02  y = (((1.9752 + (-1.9035 * x1)) * (((((inv(x1, 0.060135) + x1)...
#                                    * ((x1 + -0.87651) + x1)) + 0.41962) + -0.04569) + 0.0067754)...
#                                   ) * inv(x1, 0.0056867)) + 0.15887
# 31          1.193e-03  1.213e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.192e-03  5.541e-04  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.920e+04
# Head worker occupation: 15.3%
# Progress: 1201 / 3000 total iterations (40.033%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.193e-03  1.789e-03  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.175e-03  7.800e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962)...
#                                    + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.259e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# 37          1.089e-03  2.505e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.650e+04
# Head worker occupation: 15.8%
# Progress: 1277 / 3000 total iterations (42.567%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.176e-03  8.842e-03  y = (((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1) ...
#                                   * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) + 0.15887
# 33          1.171e-03  2.279e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.11004)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.106e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# ...
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.048e-03  4.028e-01  y = 0.16158 + ((inv(x1, 0.014288) + x1) * ((((-2.1275 * x1) * ...
#                                   x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ))))
# 27          9.974e-04  2.466e-02  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * ((((-2.12...
#                                   75 * x1) * x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1...
#                                   , 0.016826)))))
# 29          9.888e-04  4.331e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.710e+04
# Head worker occupation: 16.4%
# Progress: 2823 / 3000 total iterations (94.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.640e+04
# Head worker occupation: 16.6%
# Progress: 2906 / 3000 total iterations (96.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.820e+04
# Head worker occupation: 16.3%
# Progress: 2999 / 3000 total iterations (99.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 21          9.452e-03  9.432e-03  y = (0.19018 + (inv(x1, 0.0097537) * (1.9599 * (0.62748 + ((in...
#                                   v(x1, 0.40694) + -1.0054) * inv(x1, 0.0212)))))) + -0.048795
# 23          2.345e-03  6.969e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 35          9.688e-04  6.415e-04  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * ((x1 + -1.0184) * 1.1219))) * x1)) + 2.1916)...
#                                    * (((-1.0184 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  4.520e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                           0.310787
# 	1         0.084607                                    0.19077079 + x1
# 	2         0.173234                      (0.5607476 * x1) + 0.24348809
# 	3         0.027205              (x1 * inv(x1, 0.5479253)) + 0.2523965
# 	4         0.054837  (inv(x1, 0.080867134) * (-0.32800326 + x1)) + ...
# 	5         0.059941  (((-3.07164 * x1) + 3.3362021) * (x1 * x1)) + ...
# 	6         0.168797  (((-1.0817221 + x1) * ((x1 * -4.7079844) + 1.2...
# 	7         0.173619  ((((-4.6741557 * x1) + 1.5998087) * (-1.980577...
# 	8         0.024327  0.15983854 + (inv(x1, 0.014288435) * ((((inv(x...
# 	9         0.009432  (0.19018486 + (inv(x1, 0.009753697) * (1.95994...
# 	10        0.696936  (((inv(x1, 0.014288435) + inv(x1, -1.4914056))...
# 	11  >>>>  0.417967  ((x1 + inv(x1, 0.014288435)) * ((((-2.1275125 ...
# 	12        0.011980  0.15983854 + ((inv(x1, 0.014288435) + (x1 * 1....
# 	13        0.001834  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	14        0.000325  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	15        0.009251  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	16        0.000642  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	17        0.045198  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
# 	18        0.002793  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
#
# 	        loss  complexity
# 	0   0.046845           1
# 	1   0.039553           3
# 	2   0.027971           5
# 	3   0.026490           7
# 	4   0.023738           9
# 	5   0.021056          11
# 	6   0.015023          13
# 	7   0.010616          15
# 	8   0.009632          19
# 	9   0.009452          21
# 	10  0.002345          23
# 	11  0.001017          25
# 	12  0.000992          27
# 	13  0.000989          29
# 	14  0.000988          31
# 	15  0.000970          33
# 	16  0.000969          35
# 	17  0.000885          37
# 	18  0.000880          39
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.yscale('log')
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=17
expr=model.sympy(chose)*(max_cols_phi-min_cols_phi)+min_cols_phi
expr
# Out:
# 21.7206382751465*((x1/(x1 + 0.016826037))*(x1 - 1.0184498) + 0.7157937)*(x1*x1*x1*(-2.1275125 + 0.16839427) + 2.1915646)*(x1*x1*(-1.0264988)*x1 + x1 + x1/(x1 + 0.014288435)) + 4.61513426687202

# %%
sympy.expand(expr)
# Out:
# 43.6809097560371*x1**8/(x1 + 0.016826037) - 44.4868138048541*x1**7/(x1 + 0.016826037) + 31.2665200136399*x1**6 - 42.5532984120752*x1**6/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 42.5532984120752*x1**6/(x1 + 0.016826037) + 43.3383982571183*x1**5/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 5.52518437470967*x1**5/(x1 + 0.016826037) - 30.4593829175835*x1**4 + 49.7651059586687*x1**4/(x1 + 0.016826037) - 30.4593829175835*x1**4/(x1 + 0.014288435) - 34.9762446072919*x1**3 + 47.6021819332161*x1**3/(x1**2 + 0.031114472*x1 + 0.000240417735982095) + 47.6021819332161*x1**3/(x1 + 0.016826037) - 48.4804326694475*x1**2/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 48.4804326694475*x1**2/(x1 + 0.016826037) + 34.0733419340499*x1 + 34.0733419340499*x1/(x1 + 0.014288435) + 4.61513426687202

# %%
sympy.simplify(expr)
# Out:
# (21.7206382751465*x1*(2.1915646 - 1.95911823*x1**3)*((1 - 1.0264988*x1**2)*(x1 + 0.014288435) + 1)*(x1*(x1 - 1.0184498) + 0.7157937*x1 + 0.0120439712805669) + 4.61513426687202*(x1 + 0.014288435)*(x1 + 0.016826037))/((x1 + 0.014288435)*(x1 + 0.016826037))

# %%
sympy.factor(expr)
# Out:
# 79.1383687168112*(0.55195615558295*x1**9 - 0.159166307767832*x1**8 - 0.533446731117839*x1**7 - 1.0*x1**6 + 0.336640788383156*x1**5 + 0.590170698599522*x1**4 + 0.427944668557383*x1**3 - 0.119088781949323*x1**2 + 0.00916254183022982*x1 + 1.40205079999211e-5)/((1.0*x1 + 0.014288435)*(1.0*x1 + 0.016826037))

# %%
symb_s=model.predict(tf.concat([p, s],1),chose)
symb_s=symb_s*(max_cols_phi-min_cols_phi)+min_cols_phi
plt.scatter(s, phi, s=3, label='PINN prediction')
plt.scatter(s, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
plt.scatter(p, phi, s=3, label='PINN prediction')
plt.scatter(p, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
# plt.plot(tf.concat([p, s],1), 15.38-1.18*s, linestyle='--', label=r'$s\approx 0$')

# plt.plot( s, 200/(13+s), label='Real S')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.legend()
plt.show()
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)

# %%
Nt=1000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)

dt=0.001

P_symb[0]=np.mean(P0) #Initial conditions
# P_symb[0]=np.mean(1) #Initial conditions

S_symb[0]=np.array(s[0]) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    PS_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    # PHI=predict(PS_p , W_phi, b_phi)
    # P_symb[i]=P_symb[i-1]+(PHI)*P_symb[i-1]*dt

    P_symb[i]=P_symb[i-1]+(model.predict(PS_p,chose)*(max_cols_phi-min_cols_phi)+min_cols_phi-np.array(l))*P_symb[i-1]*dt
    S_symb[i]=S_symb[i-1]-np.maximum(0, P_symb[i-1]*S_symb[i-1]*np.array(m))*dt
    T_symb[i]=T_symb[i-1]+dt
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.ylim(0,1)
plt.legend()
plt.show()

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
import sympy as sp

P, S = sp.symbols('P S')

# Definir la función que representa el sistema de ecuaciones
def system(vars):
    P, S = vars
    f_S = expr.subs({'x1': S})-6.1390066  # Cambia esta expresión por la de tu función f(S)
    dP = f_S * P 
    dS = -42.86948 * S * P
    return [dP, dS]


# Definir variables simbólicas
# P, S = sp.symbols('P S')
# Define tu función f(S) y asegúrate de que solo depende de S
f_S = expr.subs({'x1': S})-6.1390066   # Define aquí la función f(S) correctamente

# Convertir f(S) en una función numérica
f_S_func = sp.lambdify(S, f_S, 'numpy')

# Rango para el diagrama de fases
S_values = np.linspace(0, 1, 50)
P_values = np.linspace(0, 1, 50)

# Crear la cuadrícula
P_grid, S_grid = np.meshgrid(P_values, S_values)
dP_vals = f_S_func(S_grid) * P_grid
dS_vals = -42.86948 * S_grid * P_grid

# Encontrar los puntos fijos usando fsolve
fixed_points = []
for P_init in np.linspace(0, 1, 50):  # Asegúrate de elegir un buen rango de inicialización
    for S_init in np.linspace(0, 1, 50):
        point = fsolve(system, [P_init, S_init])
        # Evitar duplicados al agregar puntos
        if not any(np.allclose(point, fp) for fp in fixed_points):
            fixed_points.append(point)



import scipy.optimize as opt


# Usar fsolve para encontrar las raíces de f(S) en un rango inicial
S_initial_guesses = np.linspace(0, 1, 20)  # Puedes ajustar el rango de las conjeturas iniciales
S_roots = [opt.fsolve(f_S_func, S0) for S0 in S_initial_guesses]

# Imprimir las soluciones
S_roots = np.unique(np.array(S_roots).flatten())  # Aplanar el resultado para eliminar listas anidadas
print("Soluciones de f(S) = 0:", S_roots)

# Graficar las soluciones
S_values = np.linspace(0, 1, 100)
f_values = f_S_func(S_values)

plt.plot(S_values, f_values, label="f(S)")
plt.axhline(0, color='black', linestyle='--')
plt.scatter(S_roots, f_S_func(S_roots), color='red', label='Raíces')
plt.xlabel('S')
plt.ylabel('f(S)')
plt.legend()
plt.xlim(0,1)
plt.show()
# Out:
# Soluciones de f(S) = 0: [7.00220078e-04 3.67713783e-02 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 2.89489556e-01 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 1.02094028e+00 1.02094028e+00 1.02094028e+00
#  1.31517768e+00]

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')



plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.ylim(0,1)
plt.xlim(0,1)

plt.legend()
plt.grid()
plt.show()

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')


plt.plot(P_int, S_int, color='green')
plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.legend()
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid()
plt.show()
