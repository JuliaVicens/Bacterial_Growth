# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Cambia el número según la GPU que quieras usar

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x1c3add4b820>,
#  <matplotlib.lines.Line2D at 0x1c3add4b880>,
#  <matplotlib.lines.Line2D at 0x1c3add4b8b0>,
#  <matplotlib.lines.Line2D at 0x1c3add4b9a0>,
#  <matplotlib.lines.Line2D at 0x1c3add4ba90>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.hstack((P0_exp,P1_exp,P2_exp,P3_exp))
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
n=np.array([P0_exp.shape[1],P1_exp.shape[1],P2_exp.shape[1],P3_exp.shape[1],])
A=np.array([0, 1.25, 2.50, 3.75])
N_exp,T_max, T_exp.shape, P_exp.shape, 342*23
# Out:
# (19, 231399.5, (342,), (342, 19), 7866)

# %%
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)

plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 1500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
Xa_star=[]
P0_star=np.empty((0, 1))
X_star = np.empty((0, 3))
for i in range(len(A)):
    P0=P_exp[0:1, np.sum(n[:i]):np.sum(n[:i+1])]
    P0_star=np.concatenate((P0_star,P0.T))
    T_meshgrid, P0_meshgrid, A_meshgrid = np.meshgrid(T_exp, P0, A[i])
    x=np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None], A_meshgrid.flatten()[:,None]))
    Xa_star += [x]
    X_star=np.vstack((X_star,x))


u_star=np.hstack((P_star,X_star[:,1:2]))

# %%
# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0_star)).reshape([-1,1]), P0_star.reshape([-1,1]), xx0[...,2:3]))

xx01=np.vstack((xx0, xx1))
uu01=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(3, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_tf = tf.convert_to_tensor(uu01, dtype=tf.float32)
# Out:
# 2024-12-16 10:57:57.941816: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-16 10:57:58.362726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3420 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:08:00.0, compute capability: 7.5

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        plt.plot(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_exp[:, (i + np.sum(n[:k]))], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('P0')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,2], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('A')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 2]), dtype=tf.float32)
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1))) 
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)

        lnp=u[:,0:1]
        lns=u[:,1:2]

        p=tf.exp(lnp)
        s=tf.exp(lns)
        # m=tf.exp(lnv[0:1])
        a=X_f[...,2:3]
        lnvar=net(a, W_a, b_a)
        m=tf.exp(lnvar[:,0:1])
        l=tf.exp(lnvar[:,1:2])
        phi=tf.exp(net(tf.concat([s, a],1), W_phi, b_phi))
        # phi=tf.exp(net(s, W_phi, b_phi))



    p_t = tape1.gradient(p, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]

    f_p = p_t - phi*p + l*p
    f_s = s_t + m*p*s
    
    return f_p, f_s




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi, b_phi,  W_a, b_a,  X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, W_a, b_a, lambda_b, lambda_r, lambda_0, lnv])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp=u_nn[:,0:1]
        p_nn=tf.exp(lnp)
        f_p, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        u_00 = net(xx01_tf, W_p, b_p) 
        lns_0=u_00[:,1:2]
        s_00=tf.exp(lns_0)


        loss_p = tf.square(lambda_b*(p_nn - P_train_tf))
        loss_0s = tf.square(lambda_0*(s_00 - uu01_tf))
        loss_fp = tf.square(lambda_r[:,0:1]*f_p) 
        loss_fs = tf.square(lambda_r[:,1:2]*f_s) 


        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    # grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)


    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    # opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s))


layers = [3, 20, 20, 2]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 2]

W_a = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_a = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 20, 20, 1]
L = len(layers)

W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 1), (1, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
def train_dynamic_step( W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_phi, b_phi, W_a, b_a, lambda_r, lnv])

        f_p, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        loss_fp = tf.square(lambda_r[0:1]*f_p) 
        loss_fs = tf.square(lambda_r[1:2]*f_s) 


        loss =  tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)


    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    # grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)



    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    # opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))

   
    return loss, 0, tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s))

# %%
lr = 5e-3




optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/10)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []
loss_reg=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf,  lambda_r, lambda_b, lambda_0, lnv, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, optimizer2)
# train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=2*10**5


while it <= Nmax:
    if it<4*10**4:
        loss_, loss_p, loss_fp, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    else:
        loss_, loss_p, loss_fp, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else:
    #     loss_, loss_p, loss_fp, loss_fs = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)
    # loss_fisa.append(loss_fa)



    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p is: {loss_fp}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 70990
# Data loss is: 0.0011071523185819387
# Physicial loss of p is: 0.0005747925024479628
# Physicial loss of s is: 0.0007345935446210206
# Iteration is: 71000
# Data loss is: 0.0011071235639974475
# Physicial loss of p is: 0.0005734446458518505
# Physicial loss of s is: 0.0007343933102674782
# Iteration is: 71010
# Data loss is: 0.0011071356711909175
# Physicial loss of p is: 0.0005969873163849115
# Physicial loss of s is: 0.0007347901700995862
# Iteration is: 71020
# Data loss is: 0.0011072875931859016
# Physicial loss of p is: 0.0011982679134234786
# Physicial loss of s is: 0.000770233862567693
# Iteration is: 71030
# Data loss is: 0.0011071842163801193
# Physicial loss of p is: 0.0007281816215254366
# Physicial loss of s is: 0.0007504290551878512
# Iteration is: 71040
# Data loss is: 0.0011071705957874656
# Physicial loss of p is: 0.0006883240421302617
# Physicial loss of s is: 0.0007447186508215964
# Iteration is: 71050
# Data loss is: 0.0011071014450863004
# Physicial loss of p is: 0.0006063526961952448
# Physicial loss of s is: 0.0007385147036984563
# Iteration is: 71060
# Data loss is: 0.001107091549783945
# Physicial loss of p is: 0.0005746500683017075
# Physicial loss of s is: 0.0007343135075643659
# Iteration is: 71070
# Data loss is: 0.001107075484469533
# Physicial loss of p is: 0.000570334552321583
# Physicial loss of s is: 0.0007344329496845603
# Iteration is: 71080
# Data loss is: 0.0011070696637034416
# Physicial loss of p is: 0.0005702170892618597
# Physicial loss of s is: 0.000733938766643405
# Iteration is: 71090
# Data loss is: 0.0011070643085986376
# Physicial loss of p is: 0.0005704544018954039
# Physicial loss of s is: 0.0007341766031458974
# Iteration is: 71100
# Data loss is: 0.0011070569744333625
# Physicial loss of p is: 0.0005705623771063983
# Physicial loss of s is: 0.0007337395800277591
# Iteration is: 71110
# Data loss is: 0.0011070522014051676
# Physicial loss of p is: 0.0005703344359062612
# Physicial loss of s is: 0.0007337007555179298
# Iteration is: 71120
# Data loss is: 0.0011070449836552143
# Physicial loss of p is: 0.0005704674986191094
# Physicial loss of s is: 0.0007336486014537513
# Iteration is: 71130
# Data loss is: 0.0011070396285504103
# Physicial loss of p is: 0.00057049939641729
# Physicial loss of s is: 0.0007336338749155402
# Iteration is: 71140
# Data loss is: 0.0011070605833083391
# Physicial loss of p is: 0.0005711843841709197
# Physicial loss of s is: 0.0007351666572503746
# Iteration is: 71150
# Data loss is: 0.001108252559788525
# Physicial loss of p is: 0.0006139118922874331
# Physicial loss of s is: 0.0007827995577827096
# Iteration is: 71160
# Data loss is: 0.0011070657055824995
# Physicial loss of p is: 0.0007692030048929155
# Physicial loss of s is: 0.0007411938859149814
# Iteration is: 71170
# Data loss is: 0.001107236836105585
# Physicial loss of p is: 0.0006150240660645068
# Physicial loss of s is: 0.0007418403401970863
# Iteration is: 71180
# Data loss is: 0.0011072170455008745
# Physicial loss of p is: 0.0009672275627963245
# Physicial loss of s is: 0.000742846867069602
# Iteration is: 71190
# Data loss is: 0.0011071457993239164
# Physicial loss of p is: 0.0005731255514547229
# Physicial loss of s is: 0.0007360802846960723
# Iteration is: 71200
# Data loss is: 0.0011069818865507841
# Physicial loss of p is: 0.0005772776785306633
# Physicial loss of s is: 0.0007338905124925077
# Iteration is: 71210
# Data loss is: 0.0011069788597524166
# Physicial loss of p is: 0.0005700671463273466
# Physicial loss of s is: 0.0007333880639635026
# Iteration is: 71220
# Data loss is: 0.0011069723404943943
# Physicial loss of p is: 0.0005725567461922765
# Physicial loss of s is: 0.000733303080778569
# Iteration is: 71230
# Data loss is: 0.0011069700121879578
# Physicial loss of p is: 0.0005740402266383171
# Physicial loss of s is: 0.0007331210072152317
# Iteration is: 71240
# Data loss is: 0.0011069679167121649
# Physicial loss of p is: 0.0005721364868804812
# Physicial loss of s is: 0.0007333118701353669
# Iteration is: 71250
# Data loss is: 0.001106954994611442
# Physicial loss of p is: 0.0005704089999198914
# Physicial loss of s is: 0.0007328452193178236
# Iteration is: 71260
# Data loss is: 0.0011069515021517873
# Physicial loss of p is: 0.0005702401394955814
# Physicial loss of s is: 0.0007325380574911833
# Iteration is: 71270
# Data loss is: 0.001106944284401834
# Physicial loss of p is: 0.0005714003345929086
# Physicial loss of s is: 0.0007323921890929341
# Iteration is: 71280
# Data loss is: 0.0011069460306316614
# Physicial loss of p is: 0.0005899672396481037
# Physicial loss of s is: 0.0007328853826038539
# Iteration is: 71290
# Data loss is: 0.001107079442590475
# Physicial loss of p is: 0.0011100542033091187
# Physicial loss of s is: 0.0007615156937390566
# Iteration is: 71300
# Data loss is: 0.0011069240281358361
# Physicial loss of p is: 0.000651464331895113
# Physicial loss of s is: 0.0007391814142465591
# Iteration is: 71310
# Data loss is: 0.001106944982893765
# Physicial loss of p is: 0.0006866573821753263
# Physicial loss of s is: 0.000738717382773757
# Iteration is: 71320
# Data loss is: 0.0011069125030189753
# Physicial loss of p is: 0.0006161925848573446
# Physicial loss of s is: 0.0007359518203884363
# Iteration is: 71330
# Data loss is: 0.0011069078464061022
# Physicial loss of p is: 0.0005765573005191982
# Physicial loss of s is: 0.0007325697224587202
# Iteration is: 71340
# Data loss is: 0.0011068929452449083
# Physicial loss of p is: 0.0005701351328752935
# Physicial loss of s is: 0.0007324590114876628
# Iteration is: 71350
# Data loss is: 0.0011068902676925063
# Physicial loss of p is: 0.0005695264553651214
# Physicial loss of s is: 0.0007321975426748395
# Iteration is: 71360
# Data loss is: 0.0011068811872974038
# Physicial loss of p is: 0.0005698981112800539
# Physicial loss of s is: 0.000732103013433516
# Iteration is: 71370
# Data loss is: 0.0011068747844547033
# Physicial loss of p is: 0.0005700649926438928
# Physicial loss of s is: 0.0007318874122574925
# Iteration is: 71380
# Data loss is: 0.0011068665189668536
# Physicial loss of p is: 0.0005699205794371665
# Physicial loss of s is: 0.0007318170391954482
# Iteration is: 71390
# Data loss is: 0.0011068584863096476
# Physicial loss of p is: 0.0005701539921574295
# Physicial loss of s is: 0.0007316431147046387
# Iteration is: 71400
# Data loss is: 0.0011069070314988494
# Physicial loss of p is: 0.0005770678981207311
# Physicial loss of s is: 0.0007322300225496292
# Iteration is: 71410
# Data loss is: 0.001108665601350367
# Physicial loss of p is: 0.0008531506755389273
# Physicial loss of s is: 0.0007637309608981013
# Iteration is: 71420
# Data loss is: 0.0011071150656789541
# Physicial loss of p is: 0.0007897628820501268
# Physicial loss of s is: 0.0007322890451177955
# Iteration is: 71430
# Data loss is: 0.001106870942749083
# Physicial loss of p is: 0.0005836682394146919
# Physicial loss of s is: 0.0007328676292672753
# Iteration is: 71440
# Data loss is: 0.0011068235617130995
# Physicial loss of p is: 0.0005883968551643193
# Physicial loss of s is: 0.0007319615106098354
# Iteration is: 71450
# Data loss is: 0.001106943585909903
# Physicial loss of p is: 0.0005872235051356256
# Physicial loss of s is: 0.0007354039116762578
# Iteration is: 71460
# Data loss is: 0.0011068363673985004
# Physicial loss of p is: 0.0006541962502524257
# Physicial loss of s is: 0.000736162590328604
# Iteration is: 71470
# Data loss is: 0.0011068759486079216
# Physicial loss of p is: 0.000871002790518105
# Physicial loss of s is: 0.0007510859286412597
# Iteration is: 71480
# Data loss is: 0.001106807729229331
# Physicial loss of p is: 0.0005848667351529002
# Physicial loss of s is: 0.0007317655836232007
# Iteration is: 71490
# Data loss is: 0.0011067950399592519
# Physicial loss of p is: 0.0005858167423866689
# Physicial loss of s is: 0.0007317255367524922
# Iteration is: 71500
# Data loss is: 0.001106794341467321
# Physicial loss of p is: 0.0005856245406903327
# Physicial loss of s is: 0.0007325825863517821
# Iteration is: 71510
# Data loss is: 0.0011067843297496438
# Physicial loss of p is: 0.0005759107298217714
# Physicial loss of s is: 0.0007314261165447533
# Iteration is: 71520
# Data loss is: 0.0011067745508626103
# Physicial loss of p is: 0.0005703247734345496
# Physicial loss of s is: 0.0007309167413040996
# Iteration is: 71530
# Data loss is: 0.0011067697778344154
# Physicial loss of p is: 0.0005707722157239914
# Physicial loss of s is: 0.0007309293723665178
# Iteration is: 71540
# Data loss is: 0.0011067718733102083
# Physicial loss of p is: 0.000590255600400269
# Physicial loss of s is: 0.0007327466155402362
# Iteration is: 71550
# Data loss is: 0.0011070193722844124
# Physicial loss of p is: 0.0012580858310684562
# Physicial loss of s is: 0.0007825616630725563
# Iteration is: 71560
# Data loss is: 0.0011068970197811723
# Physicial loss of p is: 0.0008018857915885746
# Physicial loss of s is: 0.000751839077565819
# Iteration is: 71570
# Data loss is: 0.0011069222819060087
# Physicial loss of p is: 0.0007110906881280243
# Physicial loss of s is: 0.000749159837141633
# Iteration is: 71580
# Data loss is: 0.0011067278683185577
# Physicial loss of p is: 0.0005738119361922145
# Physicial loss of s is: 0.0007309949141927063
# Iteration is: 71590
# Data loss is: 0.001106728333979845
# Physicial loss of p is: 0.0005744554800912738
# Physicial loss of s is: 0.000731316686142236
# Iteration is: 71600
# Data loss is: 0.001106739742681384
# Physicial loss of p is: 0.0005755558959208429
# Physicial loss of s is: 0.0007318129064515233
# Iteration is: 71610
# Data loss is: 0.0011067111045122147
# Physicial loss of p is: 0.000571416225284338
# Physicial loss of s is: 0.0007304191822186112
# Iteration is: 71620
# Data loss is: 0.0011067086597904563
# Physicial loss of p is: 0.0005701014306396246
# Physicial loss of s is: 0.0007305569597519934
# Iteration is: 71630
# Data loss is: 0.0011066971346735954
# Physicial loss of p is: 0.0005694025312550366
# Physicial loss of s is: 0.0007302046869881451
# Iteration is: 71640
# Data loss is: 0.001106720301322639
# Physicial loss of p is: 0.0005696372245438397
# Physicial loss of s is: 0.000731683277990669
# Iteration is: 71650
# Data loss is: 0.0011074063368141651
# Physicial loss of p is: 0.0005884469137527049
# Physicial loss of s is: 0.0007614585338160396
# Iteration is: 71660
# Data loss is: 0.0011067437008023262
# Physicial loss of p is: 0.0006269091391004622
# Physicial loss of s is: 0.0007359107257798314
# Iteration is: 71670
# Data loss is: 0.0011067314771935344
# Physicial loss of p is: 0.0005936049856245518
# Physicial loss of s is: 0.0007309464272111654
# Iteration is: 71680
# Data loss is: 0.0011066780425608158
# Physicial loss of p is: 0.0005714613944292068
# Physicial loss of s is: 0.0007309065549634397
# Iteration is: 71690
# Data loss is: 0.0011066588340327144
# Physicial loss of p is: 0.0005791321746073663
# Physicial loss of s is: 0.0007293656235560775
# Iteration is: 71700
# Data loss is: 0.0011066580191254616
# Physicial loss of p is: 0.0006066861096769571
# Physicial loss of s is: 0.0007333600078709424
# Iteration is: 71710
# Data loss is: 0.0011067339219152927
# Physicial loss of p is: 0.0010552448220551014
# Physicial loss of s is: 0.0007536903722211719
# Iteration is: 71720
# Data loss is: 0.0011067955056205392
# Physicial loss of p is: 0.0006288089789450169
# Physicial loss of s is: 0.0007296467083506286
# Iteration is: 71730
# Data loss is: 0.0011067130835726857
# Physicial loss of p is: 0.0006094482960179448
# Physicial loss of s is: 0.0007303449092432857
# Iteration is: 71740
# Data loss is: 0.0011067645391449332
# Physicial loss of p is: 0.0005919397808611393
# Physicial loss of s is: 0.0007316413684748113
# Iteration is: 71750
# Data loss is: 0.0011066437000408769
# Physicial loss of p is: 0.0005786195397377014
# Physicial loss of s is: 0.0007298900163732469
# Iteration is: 71760
# Data loss is: 0.0011066299630329013
# Physicial loss of p is: 0.0005705833318643272
# Physicial loss of s is: 0.0007294524111784995
# Iteration is: 71770
# Data loss is: 0.0011066041188314557
# Physicial loss of p is: 0.0005709348479285836
# Physicial loss of s is: 0.0007293278467841446
# Iteration is: 71780
# Data loss is: 0.0011065979488193989
# Physicial loss of p is: 0.0005711918347515166
# Physicial loss of s is: 0.0007292376249097288
# Iteration is: 71790
# Data loss is: 0.001106615993194282
# Physicial loss of p is: 0.0005779977072961628
# Physicial loss of s is: 0.0007304984028451145
# Iteration is: 71800
# Data loss is: 0.0011067958548665047
# Physicial loss of p is: 0.0007214976358227432
# Physicial loss of s is: 0.0007457195315510035
# Iteration is: 71810
# Data loss is: 0.0011068907333537936
# Physicial loss of p is: 0.0008605548646301031
# Physicial loss of s is: 0.0007591544999741018
# Iteration is: 71820
# Data loss is: 0.0011066475417464972
# Physicial loss of p is: 0.0006159250042401254
# Physicial loss of s is: 0.0007339596631936729
# Iteration is: 71830
# Data loss is: 0.0011065553408116102
# Physicial loss of p is: 0.0005707577220164239
# Physicial loss of s is: 0.0007291382644325495
# Iteration is: 71840
# Data loss is: 0.0011065626749768853
# Physicial loss of p is: 0.0005704530049115419
# Physicial loss of s is: 0.000729058519937098
# Iteration is: 71850
# Data loss is: 0.0011065505677834153
# Physicial loss of p is: 0.0005698172026313841
# Physicial loss of s is: 0.0007284772582352161
# Iteration is: 71860
# Data loss is: 0.0011065466096624732
# Physicial loss of p is: 0.0005694481660611928
# Physicial loss of s is: 0.0007285408792085946
# Iteration is: 71870
# Data loss is: 0.001106544048525393
# Physicial loss of p is: 0.0005705560906790197
# Physicial loss of s is: 0.0007285022875294089
# Iteration is: 71880
# Data loss is: 0.0011065546423196793
# Physicial loss of p is: 0.0005896310904063284
# Physicial loss of s is: 0.0007284999592229724
# Iteration is: 71890
# Data loss is: 0.0011069360189139843
# Physicial loss of p is: 0.0009665899560786784
# Physicial loss of s is: 0.000730180530808866
# Iteration is: 71900
# Data loss is: 0.0011068342719227076
# Physicial loss of p is: 0.00062297418480739
# Physicial loss of s is: 0.0007338984287343919
# Iteration is: 71910
# Data loss is: 0.0011068168096244335
# Physicial loss of p is: 0.0005934374057687819
# Physicial loss of s is: 0.000738601665943861
# Iteration is: 71920
# Data loss is: 0.0011065162252634764
# Physicial loss of p is: 0.000582245527766645
# Physicial loss of s is: 0.0007296851836144924
# Iteration is: 71930
# Data loss is: 0.0011064991122111678
# Physicial loss of p is: 0.0005770214484073222
# Physicial loss of s is: 0.0007303852471522987
# Iteration is: 71940
# Data loss is: 0.0011064872378483415
# Physicial loss of p is: 0.0005699569010175765
# Physicial loss of s is: 0.0007277582189999521
# Iteration is: 71950
# Data loss is: 0.0011064786231145263
# Physicial loss of p is: 0.0005708890967071056
# Physicial loss of s is: 0.0007278254488483071
# Iteration is: 71960
# Data loss is: 0.001106475479900837
# Physicial loss of p is: 0.0005703160422854125
# Physicial loss of s is: 0.0007275142706930637
# Iteration is: 71970
# Data loss is: 0.0011064684949815273
# Physicial loss of p is: 0.0005733337602578104
# Physicial loss of s is: 0.0007275869138538837
# Iteration is: 71980
# Data loss is: 0.0011064972495660186
# Physicial loss of p is: 0.0006457105628214777
# Physicial loss of s is: 0.0007328776409849524
# Iteration is: 71990
# Data loss is: 0.0011068203020840883
# Physicial loss of p is: 0.0013143497053533792
# Physicial loss of s is: 0.0007929587154649198
# Iteration is: 72000
# Data loss is: 0.0011067272862419486
# Physicial loss of p is: 0.0007888359832577407
# Physicial loss of s is: 0.0007591514731757343
# Iteration is: 72010
# Data loss is: 0.0011064806021749973
# Physicial loss of p is: 0.0006139085162431002
# Physicial loss of s is: 0.0007328352658078074
# Iteration is: 72020
# Data loss is: 0.0011064235586673021
# Physicial loss of p is: 0.0005736799794249237
# Physicial loss of s is: 0.0007289079949259758
# Iteration is: 72030
# Data loss is: 0.0011064340360462666
# Physicial loss of p is: 0.0005685424548573792
# Physicial loss of s is: 0.0007273410446941853
# Iteration is: 72040
# Data loss is: 0.0011064223945140839
# Physicial loss of p is: 0.0005683561903424561
# Physicial loss of s is: 0.0007273289957083762
# Iteration is: 72050
# Data loss is: 0.001106409472413361
# Physicial loss of p is: 0.0005688006640411913
# Physicial loss of s is: 0.0007271233480423689
# Iteration is: 72060
# Data loss is: 0.0011064087739214301
# Physicial loss of p is: 0.0005692463601008058
# Physicial loss of s is: 0.0007274041417986155
# Iteration is: 72070
# Data loss is: 0.0011063968995586038
# Physicial loss of p is: 0.0005687385564669967
# Physicial loss of s is: 0.0007268842309713364
# Iteration is: 72080
# Data loss is: 0.0011063901474699378
# Physicial loss of p is: 0.0005689967074431479
# Physicial loss of s is: 0.000726693426258862
# Iteration is: 72090
# Data loss is: 0.0011063923593610525
# Physicial loss of p is: 0.0005738172330893576
# Physicial loss of s is: 0.0007263001753017306
# Iteration is: 72100
# Data loss is: 0.0011071361368522048
# Physicial loss of p is: 0.0008591129444539547
# Physicial loss of s is: 0.0007299829740077257
# Iteration is: 72110
# Data loss is: 0.0011071116896346211
# Physicial loss of p is: 0.0007474401500076056
# Physicial loss of s is: 0.0007327247876673937
# Iteration is: 72120
# Data loss is: 0.0011063767597079277
# Physicial loss of p is: 0.0006447357591241598
# Physicial loss of s is: 0.0007267975597642362
# Iteration is: 72130
# Data loss is: 0.0011063654674217105
# Physicial loss of p is: 0.0006056997808627784
# Physicial loss of s is: 0.0007291806978173554
# Iteration is: 72140
# Data loss is: 0.0011064118007197976
# Physicial loss of p is: 0.0005732610588893294
# Physicial loss of s is: 0.0007293140515685081
# Iteration is: 72150
# Data loss is: 0.0011063506826758385
# Physicial loss of p is: 0.0005698672612197697
# Physicial loss of s is: 0.0007265246822498739
# Iteration is: 72160
# Data loss is: 0.0011063407873734832
# Physicial loss of p is: 0.0005717938765883446
# Physicial loss of s is: 0.0007267307373695076
# Iteration is: 72170
# Data loss is: 0.0011063351994380355
# Physicial loss of p is: 0.0005826604901812971
# Physicial loss of s is: 0.0007270083879120648
# Iteration is: 72180
# Data loss is: 0.0011064008576795459
# Physicial loss of p is: 0.0007651519845239818
# Physicial loss of s is: 0.000737762835342437
# Iteration is: 72190
# Data loss is: 0.0011064239079132676
# Physicial loss of p is: 0.0007327647763304412
# Physicial loss of s is: 0.0007393769337795675
# Iteration is: 72200
# Data loss is: 0.0011063646525144577
# Physicial loss of p is: 0.0006443707388825715
# Physicial loss of s is: 0.0007341821328736842
# Iteration is: 72210
# Data loss is: 0.0011063124984502792
# Physicial loss of p is: 0.0006024467293173075
# Physicial loss of s is: 0.000728051585610956
# Iteration is: 72220
# Data loss is: 0.0011063066776841879
# Physicial loss of p is: 0.0005858433432877064
# Physicial loss of s is: 0.0007282220176421106
# Iteration is: 72230
# Data loss is: 0.001106291078031063
# Physicial loss of p is: 0.0005735397571697831
# Physicial loss of s is: 0.0007261452847160399
# Iteration is: 72240
# Data loss is: 0.001106283743865788
# Physicial loss of p is: 0.0005681471084244549
# Physicial loss of s is: 0.000725888239685446
# Iteration is: 72250
# Data loss is: 0.0011062801349908113
# Physicial loss of p is: 0.0005701935151591897
# Physicial loss of s is: 0.0007261449936777353
# Iteration is: 72260
# Data loss is: 0.0011062728008255363
# Physicial loss of p is: 0.0005699500325135887
# Physicial loss of s is: 0.0007259768899530172
# Iteration is: 72270
# Data loss is: 0.0011062698904424906
# Physicial loss of p is: 0.000573257973883301
# Physicial loss of s is: 0.0007263026782311499
# Iteration is: 72280
# Data loss is: 0.0011063042329624295
# Physicial loss of p is: 0.000639669131487608
# Physicial loss of s is: 0.0007325817714445293
# Iteration is: 72290
# Data loss is: 0.0011067199520766735
# Physicial loss of p is: 0.0013093202142044902
# Physicial loss of s is: 0.0007928268169052899
# Iteration is: 72300
# Data loss is: 0.0011064654681831598
# Physicial loss of p is: 0.0007829652749933302
# Physicial loss of s is: 0.0007470130221918225
# Iteration is: 72310
# Data loss is: 0.0011064064456149936
# Physicial loss of p is: 0.0006323728011921048
# Physicial loss of s is: 0.0007363302865996957
# Iteration is: 72320
# Data loss is: 0.0011062459088861942
# Physicial loss of p is: 0.000584442459512502
# Physicial loss of s is: 0.0007273888331837952
# Iteration is: 72330
# Data loss is: 0.0011062456760555506
# Physicial loss of p is: 0.0005730503471568227
# Physicial loss of s is: 0.0007271768990904093
# Iteration is: 72340
# Data loss is: 0.0011062175035476685
# Physicial loss of p is: 0.0005705435760319233
# Physicial loss of s is: 0.0007253930089063942
# Iteration is: 72350
# Data loss is: 0.0011062175035476685
# Physicial loss of p is: 0.0005697174929082394
# Physicial loss of s is: 0.0007257206598296762
# Iteration is: 72360
# Data loss is: 0.0011061993427574635
# Physicial loss of p is: 0.0005682666669599712
# Physicial loss of s is: 0.0007249724585562944
# Iteration is: 72370
# Data loss is: 0.001106192241422832
# Physicial loss of p is: 0.0005685422220267355
# Physicial loss of s is: 0.0007248413749039173
# Iteration is: 72380
# Data loss is: 0.0011062165722250938
# Physicial loss of p is: 0.0005762552027590573
# Physicial loss of s is: 0.0007248216425068676
# Iteration is: 72390
# Data loss is: 0.0011074948124587536
# Physicial loss of p is: 0.0008466211147606373
# Physicial loss of s is: 0.0007301499135792255
# Iteration is: 72400
# Data loss is: 0.0011068079620599747
# Physicial loss of p is: 0.0008486381266266108
# Physicial loss of s is: 0.0007500285864807665
# Iteration is: 72410
# Data loss is: 0.0011062235571444035
# Physicial loss of p is: 0.0005894853384234011
# Physicial loss of s is: 0.0007264408050104976
# Iteration is: 72420
# Data loss is: 0.001106157200410962
# Physicial loss of p is: 0.0005931066116318107
# Physicial loss of s is: 0.0007253283401951194
# Iteration is: 72430
# Data loss is: 0.0011062016710639
# Physicial loss of p is: 0.0005714675644412637
# Physicial loss of s is: 0.0007242835708893836
# Iteration is: 72440
# Data loss is: 0.0011061487020924687
# Physicial loss of p is: 0.0005765852401964366
# Physicial loss of s is: 0.0007259486010298133
# Iteration is: 72450
# Data loss is: 0.0011061379918828607
# Physicial loss of p is: 0.0006061084568500519
# Physicial loss of s is: 0.0007263850420713425
# Iteration is: 72460
# Data loss is: 0.001106283743865788
# Physicial loss of p is: 0.0008863710681907833
# Physicial loss of s is: 0.0007503052474930882
# Iteration is: 72470
# Data loss is: 0.0011061264667659998
# Physicial loss of p is: 0.0005799891659989953
# Physicial loss of s is: 0.0007249579066410661
# Iteration is: 72480
# Data loss is: 0.0011061300756409764
# Physicial loss of p is: 0.0006026393384672701
# Physicial loss of s is: 0.0007254619849845767
# Iteration is: 72490
# Data loss is: 0.0011061164550483227
# Physicial loss of p is: 0.0005984952440485358
# Physicial loss of s is: 0.0007265728781931102
# Iteration is: 72500
# Data loss is: 0.0011061065597459674
# Physicial loss of p is: 0.0005747613031417131
# Physicial loss of s is: 0.000724413781426847
# Iteration is: 72510
# Data loss is: 0.0011061024852097034
# Physicial loss of p is: 0.0005695171421393752
# Physicial loss of s is: 0.0007240470149554312
# Iteration is: 72520
# Data loss is: 0.0011060932883992791
# Physicial loss of p is: 0.0005689690005965531
# Physicial loss of s is: 0.0007240691338665783
# Iteration is: 72530
# Data loss is: 0.0011060868855565786
# Physicial loss of p is: 0.0005733867292292416
# Physicial loss of s is: 0.0007243071449920535
# Iteration is: 72540
# Data loss is: 0.0011060935212299228
# Physicial loss of p is: 0.0006129280081950128
# Physicial loss of s is: 0.0007271969807334244
# Iteration is: 72550
# Data loss is: 0.0011062407866120338
# Physicial loss of p is: 0.0010960110230371356
# Physicial loss of s is: 0.0007606989238411188
# Iteration is: 72560
# Data loss is: 0.0011060837423428893
# Physicial loss of p is: 0.0006275621708482504
# Physicial loss of s is: 0.0007269183406606317
# Iteration is: 72570
# Data loss is: 0.001106077921576798
# Physicial loss of p is: 0.000587901275139302
# Physicial loss of s is: 0.0007259244448505342
# Iteration is: 72580
# Data loss is: 0.0011060454417020082
# Physicial loss of p is: 0.0005718405009247363
# Physicial loss of s is: 0.0007241163984872401
# Iteration is: 72590
# Data loss is: 0.0011060521937906742
# Physicial loss of p is: 0.0005676362779922783
# Physicial loss of s is: 0.0007235602242872119
# Iteration is: 72600
# Data loss is: 0.0011060349643230438
# Physicial loss of p is: 0.0005696918233297765
# Physicial loss of s is: 0.0007237793761305511
# Iteration is: 72610
# Data loss is: 0.0011060299584642053
# Physicial loss of p is: 0.0005697824526578188
# Physicial loss of s is: 0.000723440432921052
# Iteration is: 72620
# Data loss is: 0.0011061342665925622
# Physicial loss of p is: 0.0005732601857744157
# Physicial loss of s is: 0.0007264317246153951
# Iteration is: 72630
# Data loss is: 0.001106998068280518
# Physicial loss of p is: 0.0006594178266823292
# Physicial loss of s is: 0.0007504290551878512
# Iteration is: 72640
# Data loss is: 0.0011060504475608468
# Physicial loss of p is: 0.0005767932161688805
# Physicial loss of s is: 0.0007236000383272767
# Iteration is: 72650
# Data loss is: 0.00110611820127815
# Physicial loss of p is: 0.0005735562881454825
# Physicial loss of s is: 0.0007293413509614766
# Iteration is: 72660
# Data loss is: 0.0011060063261538744
# Physicial loss of p is: 0.000590565032325685
# Physicial loss of s is: 0.0007267448236234486
# Iteration is: 72670
# Data loss is: 0.0011060101678594947
# Physicial loss of p is: 0.0007763859466649592
# Physicial loss of s is: 0.0007335231057368219
# Iteration is: 72680
# Data loss is: 0.0011060076067224145
# Physicial loss of p is: 0.0008010515011847019
# Physicial loss of s is: 0.0007354861008934677
# Iteration is: 72690
# Data loss is: 0.0011060104006901383
# Physicial loss of p is: 0.0006639588391408324
# Physicial loss of s is: 0.0007266686297953129
# Iteration is: 72700
# Data loss is: 0.0011059684911742806
# Physicial loss of p is: 0.0006082853069528937
# Physicial loss of s is: 0.0007269821362569928
# Iteration is: 72710
# Data loss is: 0.0011059667449444532
# Physicial loss of p is: 0.0005864818813279271
# Physicial loss of s is: 0.000723554752767086
# Iteration is: 72720
# Data loss is: 0.0011059537064284086
# Physicial loss of p is: 0.0005743976216763258
# Physicial loss of s is: 0.0007234944496303797
# Iteration is: 72730
# Data loss is: 0.0011059495154768229
# Physicial loss of p is: 0.0005673449486494064
# Physicial loss of s is: 0.0007226125453598797
# Iteration is: 72740
# Data loss is: 0.0011059425305575132
# Physicial loss of p is: 0.0005693732528015971
# Physicial loss of s is: 0.000722388387657702
# Iteration is: 72750
# Data loss is: 0.00110593531280756
# Physicial loss of p is: 0.0005681110196746886
# Physicial loss of s is: 0.0007222812855616212
# Iteration is: 72760
# Data loss is: 0.0011059277458116412
# Physicial loss of p is: 0.0005685380892828107
# Physicial loss of s is: 0.0007221627747640014
# Iteration is: 72770
# Data loss is: 0.0011059266980737448
# Physicial loss of p is: 0.0005815579788759351
# Physicial loss of s is: 0.0007226933958008885
# Iteration is: 72780
# Data loss is: 0.0011062773410230875
# Physicial loss of p is: 0.000984786543995142
# Physicial loss of s is: 0.0007544652908109128
# Iteration is: 72790
# Data loss is: 0.0011062051635235548
# Physicial loss of p is: 0.0007463504443876445
# Physicial loss of s is: 0.0007252483628690243
# Iteration is: 72800
# Data loss is: 0.0011065230937674642
# Physicial loss of p is: 0.0006763429846614599
# Physicial loss of s is: 0.0007329249638132751
# Iteration is: 72810
# Data loss is: 0.0011058941017836332
# Physicial loss of p is: 0.0005738905165344477
# Physicial loss of s is: 0.0007220844272524118
# Iteration is: 72820
# Data loss is: 0.0011059577809646726
# Physicial loss of p is: 0.0005781281506642699
# Physicial loss of s is: 0.0007242349674925208
# Iteration is: 72830
# Data loss is: 0.0011058802483603358
# Physicial loss of p is: 0.0005727173993363976
# Physicial loss of s is: 0.0007218289538286626
# Iteration is: 72840
# Data loss is: 0.0011058809468522668
# Physicial loss of p is: 0.0005674057174474001
# Physicial loss of s is: 0.000722123309969902
# Iteration is: 72850
# Data loss is: 0.0011058701202273369
# Physicial loss of p is: 0.0005676767323166132
# Physicial loss of s is: 0.0007217853562906384
# Iteration is: 72860
# Data loss is: 0.0011058562668040395
# Physicial loss of p is: 0.0005681969923898578
# Physicial loss of s is: 0.0007216566009446979
# Iteration is: 72870
# Data loss is: 0.0011058490490540862
# Physicial loss of p is: 0.0005810688599012792
# Physicial loss of s is: 0.0007224245928227901
# Iteration is: 72880
# Data loss is: 0.0011059519601985812
# Physicial loss of p is: 0.0011067362502217293
# Physicial loss of s is: 0.0007410782272927463
# Iteration is: 72890
# Data loss is: 0.0011059880489483476
# Physicial loss of p is: 0.0006774224457331002
# Physicial loss of s is: 0.000724905519746244
# Iteration is: 72900
# Data loss is: 0.0011058965465053916
# Physicial loss of p is: 0.0006786023732274771
# Physicial loss of s is: 0.0007353865657933056
# Iteration is: 72910
# Data loss is: 0.0011059190146625042
# Physicial loss of p is: 0.0006055273697711527
# Physicial loss of s is: 0.0007267832988873124
# Iteration is: 72920
# Data loss is: 0.001105812261812389
# Physicial loss of p is: 0.0005730038392357528
# Physicial loss of s is: 0.0007223331485874951
# Iteration is: 72930
# Data loss is: 0.001105824252590537
# Physicial loss of p is: 0.0005683675990439951
# Physicial loss of s is: 0.0007213615463115275
# Iteration is: 72940
# Data loss is: 0.001105801435187459
# Physicial loss of p is: 0.000567161594517529
# Physicial loss of s is: 0.0007214383804239333
# Iteration is: 72950
# Data loss is: 0.0011057972442358732
# Physicial loss of p is: 0.0005672016413882375
# Physicial loss of s is: 0.0007210667827166617
# Iteration is: 72960
# Data loss is: 0.0011057916563004255
# Physicial loss of p is: 0.0005674741114489734
# Physicial loss of s is: 0.000721199088729918
# Iteration is: 72970
# Data loss is: 0.0011057826923206449
# Physicial loss of p is: 0.0005672920378856361
# Physicial loss of s is: 0.0007209298200905323
# Iteration is: 72980
# Data loss is: 0.0011057789670303464
# Physicial loss of p is: 0.0005672965780831873
# Physicial loss of s is: 0.000720830459613353
# Iteration is: 72990
# Data loss is: 0.0011057723313570023
# Physicial loss of p is: 0.0005672939005307853
# Physicial loss of s is: 0.0007208242896012962
# Iteration is: 73000
# Data loss is: 0.0011057708179578185
# Physicial loss of p is: 0.0005673689302057028
# Physicial loss of s is: 0.0007213463541120291
# Iteration is: 73010
# Data loss is: 0.0011059355456382036
# Physicial loss of p is: 0.0005737589672207832
# Physicial loss of s is: 0.0007348866784013808
# Iteration is: 73020
# Data loss is: 0.0011058948002755642
# Physicial loss of p is: 0.0006034817197360098
# Physicial loss of s is: 0.0007229591719806194
# Iteration is: 73030
# Data loss is: 0.0011060484685003757
# Physicial loss of p is: 0.0012432067887857556
# Physicial loss of s is: 0.0007913672598078847
# Iteration is: 73040
# Data loss is: 0.0011057922383770347
# Physicial loss of p is: 0.0007402957417070866
# Physicial loss of s is: 0.0007313225069083273
# Iteration is: 73050
# Data loss is: 0.001105790608562529
# Physicial loss of p is: 0.0006922073080204427
# Physicial loss of s is: 0.0007225774461403489
# Iteration is: 73060
# Data loss is: 0.0011057308875024319
# Physicial loss of p is: 0.0005929102189838886
# Physicial loss of s is: 0.00072243477916345
# Iteration is: 73070
# Data loss is: 0.0011058322852477431
# Physicial loss of p is: 0.0005715733859688044
# Physicial loss of s is: 0.0007241115090437233
# Iteration is: 73080
# Data loss is: 0.0011057108640670776
# Physicial loss of p is: 0.0005702517810277641
# Physicial loss of s is: 0.0007204397697933018
# Iteration is: 73090
# Data loss is: 0.0011057143565267324
# Physicial loss of p is: 0.0005687001394107938
# Physicial loss of s is: 0.0007204165449365973
# Iteration is: 73100
# Data loss is: 0.001105691073462367
# Physicial loss of p is: 0.0005675639840774238
# Physicial loss of s is: 0.0007201607222668827
# Iteration is: 73110
# Data loss is: 0.001105690491385758
# Physicial loss of p is: 0.0005671553080901504
# Physicial loss of s is: 0.0007201713742688298
# Iteration is: 73120
# Data loss is: 0.0011056801304221153
# Physicial loss of p is: 0.0005671697435900569
# Physicial loss of s is: 0.000719958043191582
# Iteration is: 73130
# Data loss is: 0.001105675590224564
# Physicial loss of p is: 0.0005670504760928452
# Physicial loss of s is: 0.0007198523380793631
# Iteration is: 73140
# Data loss is: 0.0011056687217205763
# Physicial loss of p is: 0.0005671818507835269
# Physicial loss of s is: 0.0007196773658506572
# Iteration is: 73150
# Data loss is: 0.0011056609218940139
# Physicial loss of p is: 0.0005675347638316453
# Physicial loss of s is: 0.0007195303332991898
# Iteration is: 73160
# Data loss is: 0.0011056627845391631
# Physicial loss of p is: 0.0005809428985230625
# Physicial loss of s is: 0.0007202700944617391
# Iteration is: 73170
# Data loss is: 0.0011064724531024694
# Physicial loss of p is: 0.0013063206570222974
# Physicial loss of s is: 0.0007945889374241233
# Iteration is: 73180
# Data loss is: 0.001107082818634808
# Physicial loss of p is: 0.0009673940949141979
# Physicial loss of s is: 0.0007736207917332649
# Iteration is: 73190
# Data loss is: 0.0011056477669626474
# Physicial loss of p is: 0.0005721005727536976
# Physicial loss of s is: 0.0007203674176707864
# Iteration is: 73200
# Data loss is: 0.001105769770219922
# Physicial loss of p is: 0.0006170514388941228
# Physicial loss of s is: 0.0007264770101755857
# Iteration is: 73210
# Data loss is: 0.0011056252988055348
# Physicial loss of p is: 0.0005677342414855957
# Physicial loss of s is: 0.000719831557944417
# Iteration is: 73220
# Data loss is: 0.001105621224269271
# Physicial loss of p is: 0.000574359844904393
# Physicial loss of s is: 0.0007205777219496667
# Iteration is: 73230
# Data loss is: 0.0011056032963097095
# Physicial loss of p is: 0.0005669141537509859
# Physicial loss of s is: 0.000719455536454916
# Iteration is: 73240
# Data loss is: 0.001105597009882331
# Physicial loss of p is: 0.0005673611885868013
# Physicial loss of s is: 0.0007191694458015263
# Iteration is: 73250
# Data loss is: 0.001105595612898469
# Physicial loss of p is: 0.0005667717196047306
# Physicial loss of s is: 0.0007192667108029127
# Iteration is: 73260
# Data loss is: 0.0011055887443944812
# Physicial loss of p is: 0.0005667935474775732
# Physicial loss of s is: 0.0007189891184680164
# Iteration is: 73270
# Data loss is: 0.00110558420419693
# Physicial loss of p is: 0.0005678331363014877
# Physicial loss of s is: 0.0007188579766079783
# Iteration is: 73280
# Data loss is: 0.001105613075196743
# Physicial loss of p is: 0.0006003537564538419
# Physicial loss of s is: 0.0007188789895735681
# Iteration is: 73290
# Data loss is: 0.0011060887482017279
# Physicial loss of p is: 0.0012511739041656256
# Physicial loss of s is: 0.0007254324737004936
# Iteration is: 73300
# Data loss is: 0.0011055782670155168
# Physicial loss of p is: 0.0007619221578352153
# Physicial loss of s is: 0.0007220745319500566
# Iteration is: 73310
# Data loss is: 0.0011055648792535067
# Physicial loss of p is: 0.0006386295426636934
# Physicial loss of s is: 0.0007218132959678769
# Iteration is: 73320
# Data loss is: 0.0011055463692173362
# Physicial loss of p is: 0.0005833915784023702
# Physicial loss of s is: 0.0007221365231089294
# Iteration is: 73330
# Data loss is: 0.0011055461363866925
# Physicial loss of p is: 0.0005738589679822326
# Physicial loss of s is: 0.0007189634488895535
# Iteration is: 73340
# Data loss is: 0.0011055401992052794
# Physicial loss of p is: 0.0005689505487680435
# Physicial loss of s is: 0.0007199118845164776
# Iteration is: 73350
# Data loss is: 0.0011055230861529708
# Physicial loss of p is: 0.0005680402973666787
# Physicial loss of s is: 0.0007184137357398868
# Iteration is: 73360
# Data loss is: 0.0011055212235078216
# Physicial loss of p is: 0.0005669837701134384
# Physicial loss of s is: 0.0007184401620179415
# Iteration is: 73370
# Data loss is: 0.0011055092327296734
# Physicial loss of p is: 0.0005670651444233954
# Physicial loss of s is: 0.0007183898705989122
# Iteration is: 73380
# Data loss is: 0.0011055063223466277
# Physicial loss of p is: 0.0005668451776728034
# Physicial loss of s is: 0.0007182160625234246
# Iteration is: 73390
# Data loss is: 0.0011054982896894217
# Physicial loss of p is: 0.000566848844755441
# Physicial loss of s is: 0.0007180623360909522
# Iteration is: 73400
# Data loss is: 0.0011054914211854339
# Physicial loss of p is: 0.0005671360995620489
# Physicial loss of s is: 0.0007180391112342477
# Iteration is: 73410
# Data loss is: 0.0011054876958951354
# Physicial loss of p is: 0.0005768947885371745
# Physicial loss of s is: 0.0007193934288807213
# Iteration is: 73420
# Data loss is: 0.0011057460214942694
# Physicial loss of p is: 0.0012816612143069506
# Physicial loss of s is: 0.0007875837036408484
# Iteration is: 73430
# Data loss is: 0.0011056734947487712
# Physicial loss of p is: 0.0009973552078008652
# Physicial loss of s is: 0.0007593839545734227
# Iteration is: 73440
# Data loss is: 0.0011056936345994473
# Physicial loss of p is: 0.0006140205659903586
# Physicial loss of s is: 0.0007302803569473326
# Iteration is: 73450
# Data loss is: 0.0011054504429921508
# Physicial loss of p is: 0.00064605608349666
# Physicial loss of s is: 0.0007264160667546093
# Iteration is: 73460
# Data loss is: 0.0011054381029680371
# Physicial loss of p is: 0.0005662719486281276
# Physicial loss of s is: 0.0007185838767327368
# Iteration is: 73470
# Data loss is: 0.0011054504429921508
# Physicial loss of p is: 0.0005762124201282859
# Physicial loss of s is: 0.0007181669352576137
# Iteration is: 73480
# Data loss is: 0.001105432165786624
# Physicial loss of p is: 0.0005658657173626125
# Physicial loss of s is: 0.0007179135573096573
# Iteration is: 73490
# Data loss is: 0.0011054283240810037
# Physicial loss of p is: 0.000567294133361429
# Physicial loss of s is: 0.0007182839908637106
# Iteration is: 73500
# Data loss is: 0.0011054197093471885
# Physicial loss of p is: 0.0005662777693942189
# Physicial loss of s is: 0.0007176020299084485
# Iteration is: 73510
# Data loss is: 0.0011054128408432007
# Physicial loss of p is: 0.0005662040784955025
# Physicial loss of s is: 0.0007175589562393725
# Iteration is: 73520
# Data loss is: 0.0011054073693230748
# Physicial loss of p is: 0.0005662717740051448
# Physicial loss of s is: 0.0007174527854658663
# Iteration is: 73530
# Data loss is: 0.0011054002679884434
# Physicial loss of p is: 0.0005663476185873151
# Physicial loss of s is: 0.0007172789191827178
# Iteration is: 73540
# Data loss is: 0.0011053945636376739
# Physicial loss of p is: 0.0005663474439643323
# Physicial loss of s is: 0.0007172840996645391
# Iteration is: 73550
# Data loss is: 0.0011054130736738443
# Physicial loss of p is: 0.0005670518730767071
# Physicial loss of s is: 0.0007186238071881235
# Iteration is: 73560
# Data loss is: 0.0011070024920627475
# Physicial loss of p is: 0.0006743671256117523
# Physicial loss of s is: 0.0007413747953251004
# Iteration is: 73570
# Data loss is: 0.0011054427595809102
# Physicial loss of p is: 0.000600792292971164
# Physicial loss of s is: 0.0007207429152913392
# Iteration is: 73580
# Data loss is: 0.0011055117938667536
# Physicial loss of p is: 0.0005887893494218588
# Physicial loss of s is: 0.0007179683889262378
# Iteration is: 73590
# Data loss is: 0.0011053552152588964
# Physicial loss of p is: 0.0005686639924533665
# Physicial loss of s is: 0.0007169876480475068
# Iteration is: 73600
# Data loss is: 0.0011053727939724922
# Physicial loss of p is: 0.0005709242541342974
# Physicial loss of s is: 0.0007172490004450083
# Iteration is: 73610
# Data loss is: 0.001105360803194344
# Physicial loss of p is: 0.0005737486644648015
# Physicial loss of s is: 0.0007163880509324372
# Iteration is: 73620
# Data loss is: 0.0011054151691496372
# Physicial loss of p is: 0.0007118236389942467
# Physicial loss of s is: 0.000723912613466382
# Iteration is: 73630
# Data loss is: 0.0011056014336645603
# Physicial loss of p is: 0.0008142711594700813
# Physicial loss of s is: 0.0007397669833153486
# Iteration is: 73640
# Data loss is: 0.0011053464841097593
# Physicial loss of p is: 0.0006119496538303792
# Physicial loss of s is: 0.0007207052549347281
# Iteration is: 73650
# Data loss is: 0.0011054916540160775
# Physicial loss of p is: 0.0005967775359749794
# Physicial loss of s is: 0.0007177460938692093
# Iteration is: 73660
# Data loss is: 0.001105326577089727
# Physicial loss of p is: 0.0005828696303069592
# Physicial loss of s is: 0.0007167364819906652
# Iteration is: 73670
# Data loss is: 0.0011053262278437614
# Physicial loss of p is: 0.0005694167921319604
# Physicial loss of s is: 0.0007167852018028498
# Iteration is: 73680
# Data loss is: 0.0011052994523197412
# Physicial loss of p is: 0.0005668236408382654
# Physicial loss of s is: 0.0007162187248468399
# Iteration is: 73690
# Data loss is: 0.00110529619269073
# Physicial loss of p is: 0.0005668092053383589
# Physicial loss of s is: 0.0007161375833675265
# Iteration is: 73700
# Data loss is: 0.001105286879464984
# Physicial loss of p is: 0.0005677614826709032
# Physicial loss of s is: 0.000715981877874583
# Iteration is: 73710
# Data loss is: 0.0011052937479689717
# Physicial loss of p is: 0.0005860226810909808
# Physicial loss of s is: 0.0007161805988289416
# Iteration is: 73720
# Data loss is: 0.0011054084170609713
# Physicial loss of p is: 0.0010610937606543303
# Physicial loss of s is: 0.000735684297978878
# Iteration is: 73730
# Data loss is: 0.0011052697664126754
# Physicial loss of p is: 0.000609277340117842
# Physicial loss of s is: 0.0007179048261605203
# Iteration is: 73740
# Data loss is: 0.0011053106281906366
# Physicial loss of p is: 0.0006443097372539341
# Physicial loss of s is: 0.0007175666396506131
# Iteration is: 73750
# Data loss is: 0.0011052427580580115
# Physicial loss of p is: 0.0006100059254094958
# Physicial loss of s is: 0.000717695860657841
# Iteration is: 73760
# Data loss is: 0.00110524648334831
# Physicial loss of p is: 0.0005783439264632761
# Physicial loss of s is: 0.0007164213457144797
# Iteration is: 73770
# Data loss is: 0.001105245086364448
# Physicial loss of p is: 0.0005689552635885775
# Physicial loss of s is: 0.0007166860159486532
# Iteration is: 73780
# Data loss is: 0.0011052305344492197
# Physicial loss of p is: 0.0005666791694238782
# Physicial loss of s is: 0.0007157204090617597
# Iteration is: 73790
# Data loss is: 0.0011052206391468644
# Physicial loss of p is: 0.0005662531475536525
# Physicial loss of s is: 0.0007156968931667507
# Iteration is: 73800
# Data loss is: 0.001105226227082312
# Physicial loss of p is: 0.0005662175826728344
# Physicial loss of s is: 0.0007156962528824806
# Iteration is: 73810
# Data loss is: 0.0011052089976146817
# Physicial loss of p is: 0.0005660420283675194
# Physicial loss of s is: 0.0007154433988034725
# Iteration is: 73820
# Data loss is: 0.0011052011977881193
# Physicial loss of p is: 0.0005661902250722051
# Physicial loss of s is: 0.0007152576581574976
# Iteration is: 73830
# Data loss is: 0.0011051945621147752
# Physicial loss of p is: 0.0005664490745402873
# Physicial loss of s is: 0.0007151387981139123
# Iteration is: 73840
# Data loss is: 0.0011052092304453254
# Physicial loss of p is: 0.0005735416198149323
# Physicial loss of s is: 0.0007159287924878299
# Iteration is: 73850
# Data loss is: 0.0011062492849305272
# Physicial loss of p is: 0.0008885390125215054
# Physicial loss of s is: 0.0007670581107959151
# Iteration is: 73860
# Data loss is: 0.0011059597600251436
# Physicial loss of p is: 0.0007909737178124487
# Physicial loss of s is: 0.0007255615200847387
# Iteration is: 73870
# Data loss is: 0.0011055521899834275
# Physicial loss of p is: 0.000681799603626132
# Physicial loss of s is: 0.0007211421616375446
# Iteration is: 73880
# Data loss is: 0.001105194678530097
# Physicial loss of p is: 0.0005956832901574671
# Physicial loss of s is: 0.0007171184988692403
# Iteration is: 73890
# Data loss is: 0.0011052002664655447
# Physicial loss of p is: 0.0005751120042987168
# Physicial loss of s is: 0.0007173045887611806
# Iteration is: 73900
# Data loss is: 0.001105189905501902
# Physicial loss of p is: 0.0005710424156859517
# Physicial loss of s is: 0.0007152785547077656
# Iteration is: 73910
# Data loss is: 0.0011051392648369074
# Physicial loss of p is: 0.0005666394135914743
# Physicial loss of s is: 0.0007148876902647316
# Iteration is: 73920
# Data loss is: 0.0011051329784095287
# Physicial loss of p is: 0.0005662221228703856
# Physicial loss of s is: 0.000714645313564688
# Iteration is: 73930
# Data loss is: 0.001105132861994207
# Physicial loss of p is: 0.0005665635108016431
# Physicial loss of s is: 0.0007148969452828169
# Iteration is: 73940
# Data loss is: 0.0011051190085709095
# Physicial loss of p is: 0.0005670919199474156
# Physicial loss of s is: 0.0007145503768697381
# Iteration is: 73950
# Data loss is: 0.0011051135370507836
# Physicial loss of p is: 0.0005840049707330763
# Physicial loss of s is: 0.0007151517202146351
# Iteration is: 73960
# Data loss is: 0.0011051725596189499
# Physicial loss of p is: 0.0011112443171441555
# Physicial loss of s is: 0.0007327625062316656
# Iteration is: 73970
# Data loss is: 0.0011051594046875834
# Physicial loss of p is: 0.0006664613028988242
# Physicial loss of s is: 0.0007162282709032297
# Iteration is: 73980
# Data loss is: 0.0011050968896597624
# Physicial loss of p is: 0.0007036090828478336
# Physicial loss of s is: 0.0007208653842099011
# Iteration is: 73990
# Data loss is: 0.0011050956090912223
# Physicial loss of p is: 0.0006027500494383276
# Physicial loss of s is: 0.0007171969627961516
# Iteration is: 74000
# Data loss is: 0.0011050980538129807
# Physicial loss of p is: 0.0005679074092768133
# Physicial loss of s is: 0.0007163963164202869
# Iteration is: 74010
# Data loss is: 0.0011050712782889605
# Physicial loss of p is: 0.00056560238590464
# Physicial loss of s is: 0.0007142407703213394
# Iteration is: 74020
# Data loss is: 0.0011050747707486153
# Physicial loss of p is: 0.0005652488325722516
# Physicial loss of s is: 0.0007147332071326673
# Iteration is: 74030
# Data loss is: 0.0011050562607124448
# Physicial loss of p is: 0.000565600988920778
# Physicial loss of s is: 0.0007140004308894277
# Iteration is: 74040
# Data loss is: 0.0011050562607124448
# Physicial loss of p is: 0.0005656284047290683
# Physicial loss of s is: 0.000714393041562289
# Iteration is: 74050
# Data loss is: 0.001105044037103653
# Physicial loss of p is: 0.0005657128058373928
# Physicial loss of s is: 0.0007138550863601267
# Iteration is: 74060
# Data loss is: 0.0011050376342609525
# Physicial loss of p is: 0.0005657318397425115
# Physicial loss of s is: 0.0007137623033486307
# Iteration is: 74070
# Data loss is: 0.0011050329776480794
# Physicial loss of p is: 0.0005657344590872526
# Physicial loss of s is: 0.0007137461798265576
# Iteration is: 74080
# Data loss is: 0.001105027156881988
# Physicial loss of p is: 0.0005657882429659367
# Physicial loss of s is: 0.0007136698695831001
# Iteration is: 74090
# Data loss is: 0.0011050214525312185
# Physicial loss of p is: 0.0005659768357872963
# Physicial loss of s is: 0.0007137204520404339
# Iteration is: 74100
# Data loss is: 0.0011050454340875149
# Physicial loss of p is: 0.0005732308491133153
# Physicial loss of s is: 0.000716293987352401
# Iteration is: 74110
# Data loss is: 0.0011061306577175856
# Physicial loss of p is: 0.0012069998774677515
# Physicial loss of s is: 0.0008329625125043094
# Iteration is: 74120
# Data loss is: 0.001106042298488319
# Physicial loss of p is: 0.00085016357479617
# Physicial loss of s is: 0.0007898518815636635
# Iteration is: 74130
# Data loss is: 0.0011050415923818946
# Physicial loss of p is: 0.0005958374822512269
# Physicial loss of s is: 0.0007140855886973441
# Iteration is: 74140
# Data loss is: 0.001104994909837842
# Physicial loss of p is: 0.0005795532488264143
# Physicial loss of s is: 0.0007135366322472692
# Iteration is: 74150
# Data loss is: 0.001104986877180636
# Physicial loss of p is: 0.0005820935475639999
# Physicial loss of s is: 0.0007141933892853558
# Iteration is: 74160
# Data loss is: 0.001104994909837842
# Physicial loss of p is: 0.0005662191542796791
# Physicial loss of s is: 0.0007130334852263331
# Iteration is: 74170
# Data loss is: 0.0011049758177250624
# Physicial loss of p is: 0.0005655893473885953
# Physicial loss of s is: 0.0007133253384381533
# Iteration is: 74180
# Data loss is: 0.0011049648746848106
# Physicial loss of p is: 0.0005659942980855703
# Physicial loss of s is: 0.0007130946032702923
# Iteration is: 74190
# Data loss is: 0.0011049500899389386
# Physicial loss of p is: 0.0005654205451719463
# Physicial loss of s is: 0.0007131377351470292
# Iteration is: 74200
# Data loss is: 0.0011049408931285143
# Physicial loss of p is: 0.0005653939442709088
# Physicial loss of s is: 0.0007129747536964715
# Iteration is: 74210
# Data loss is: 0.0011049367021769285
# Physicial loss of p is: 0.0005655109416693449
# Physicial loss of s is: 0.0007128971628844738
# Iteration is: 74220
# Data loss is: 0.00110493169631809
# Physicial loss of p is: 0.0005655289860442281
# Physicial loss of s is: 0.0007127851713448763
# Iteration is: 74230
# Data loss is: 0.001104926224797964
# Physicial loss of p is: 0.0005657858564518392
# Physicial loss of s is: 0.0007126915152184665
# Iteration is: 74240
# ...
# Physicial loss of s is: 0.0006255765911191702
# Iteration is: 173800
# Data loss is: 0.0010257473913952708
# Physicial loss of p is: 0.0013012076960876584
# Physicial loss of s is: 0.000528732081875205
# Iteration is: 173810
# Data loss is: 0.0010253718355670571
# Physicial loss of p is: 0.0009333213092759252
# Physicial loss of s is: 0.0005039489478804171
# Iteration is: 173820
# Data loss is: 0.0010253863874822855
# Physicial loss of p is: 0.0009747836156748235
# Physicial loss of s is: 0.0005062228883616626
# Iteration is: 173830
# Data loss is: 0.0010254142107442021
# Physicial loss of p is: 0.0009629711275920272
# Physicial loss of s is: 0.0005059725372120738
# Iteration is: 173840
# Data loss is: 0.0010253783548250794
# Physicial loss of p is: 0.0009427134646102786
# Physicial loss of s is: 0.0005042801494710147
# Iteration is: 173850
# Data loss is: 0.001025384059175849
# Physicial loss of p is: 0.0009367419988848269
# Physicial loss of s is: 0.0005038793315179646
# Iteration is: 173860
# Data loss is: 0.0010253703221678734
# Physicial loss of p is: 0.000933922128751874
# Physicial loss of s is: 0.0005035757785663009
# Iteration is: 173870
# Data loss is: 0.001025374629534781
# Physicial loss of p is: 0.0009348881430923939
# Physicial loss of s is: 0.0005039948737248778
# Iteration is: 173880
# Data loss is: 0.0010259408736601472
# Physicial loss of p is: 0.0010007875971496105
# Physicial loss of s is: 0.0005348320701159537
# Iteration is: 173890
# Data loss is: 0.0010254532098770142
# Physicial loss of p is: 0.0009381527779623866
# Physicial loss of s is: 0.0005052162450738251
# Iteration is: 173900
# Data loss is: 0.0010253627551719546
# Physicial loss of p is: 0.0009356954833492637
# Physicial loss of s is: 0.000504068098962307
# Iteration is: 173910
# Data loss is: 0.0010253569344058633
# Physicial loss of p is: 0.0009344086865894496
# Physicial loss of s is: 0.0005033903871662915
# Iteration is: 173920
# Data loss is: 0.0010253572836518288
# Physicial loss of p is: 0.0009346637525595725
# Physicial loss of s is: 0.000503323448356241
# Iteration is: 173930
# Data loss is: 0.0010253379587084055
# Physicial loss of p is: 0.0009353855857625604
# Physicial loss of s is: 0.0005030067404732108
# Iteration is: 173940
# Data loss is: 0.0010253704385831952
# Physicial loss of p is: 0.0010133489267900586
# Physicial loss of s is: 0.0005083506111986935
# Iteration is: 173950
# Data loss is: 0.0010269198101013899
# Physicial loss of p is: 0.004308290313929319
# Physicial loss of s is: 0.0007058042683638632
# Iteration is: 173960
# Data loss is: 0.0010258794063702226
# Physicial loss of p is: 0.001496251905336976
# Physicial loss of s is: 0.0005408339784480631
# Iteration is: 173970
# Data loss is: 0.0010254653170704842
# Physicial loss of p is: 0.001243747305124998
# Physicial loss of s is: 0.0005208321381360292
# Iteration is: 173980
# Data loss is: 0.0010252670617774129
# Physicial loss of p is: 0.0009364279685541987
# Physicial loss of s is: 0.0005042622215114534
# Iteration is: 173990
# Data loss is: 0.0010252899955958128
# Physicial loss of p is: 0.0009824075968936086
# Physicial loss of s is: 0.0005059264367446303
# Iteration is: 174000
# Data loss is: 0.0010252833599224687
# Physicial loss of p is: 0.0009328864980489016
# Physicial loss of s is: 0.0005037256050854921
# Iteration is: 174010
# Data loss is: 0.0010252980282530189
# Physicial loss of p is: 0.0009396284003742039
# Physicial loss of s is: 0.0005041114054620266
# Iteration is: 174020
# Data loss is: 0.0010252828942611814
# Physicial loss of p is: 0.0009329220047220588
# Physicial loss of s is: 0.000503452611155808
# Iteration is: 174030
# Data loss is: 0.0010252795182168484
# Physicial loss of p is: 0.0009327614097855985
# Physicial loss of s is: 0.0005033568595536053
# Iteration is: 174040
# Data loss is: 0.001025276375003159
# Physicial loss of p is: 0.0009330808534286916
# Physicial loss of s is: 0.0005032978951931
# Iteration is: 174050
# Data loss is: 0.0010252713691443205
# Physicial loss of p is: 0.0009329217718914151
# Physicial loss of s is: 0.0005031535401940346
# Iteration is: 174060
# Data loss is: 0.0010252698557451367
# Physicial loss of p is: 0.0009329973254352808
# Physicial loss of s is: 0.0005030996981076896
# Iteration is: 174070
# Data loss is: 0.0010252643842250109
# Physicial loss of p is: 0.0009330231696367264
# Physicial loss of s is: 0.0005029885214753449
# Iteration is: 174080
# Data loss is: 0.001025262288749218
# Physicial loss of p is: 0.0009332980844192207
# Physicial loss of s is: 0.0005029733292758465
# Iteration is: 174090
# Data loss is: 0.001025283127091825
# Physicial loss of p is: 0.0009374429937452078
# Physicial loss of s is: 0.000503522518556565
# Iteration is: 174100
# Data loss is: 0.0010261349380016327
# Physicial loss of p is: 0.0011284025385975838
# Physicial loss of s is: 0.0005271488334983587
# Iteration is: 174110
# Data loss is: 0.001025348319672048
# Physicial loss of p is: 0.0010184335988014936
# Physicial loss of s is: 0.0005036518559791148
# Iteration is: 174120
# Data loss is: 0.0010254653170704842
# Physicial loss of p is: 0.0010034794686362147
# Physicial loss of s is: 0.000514824700076133
# Iteration is: 174130
# Data loss is: 0.0010252358624711633
# Physicial loss of p is: 0.0009351886692456901
# Physicial loss of s is: 0.000502667622640729
# Iteration is: 174140
# Data loss is: 0.001025257632136345
# Physicial loss of p is: 0.0009501148015260696
# Physicial loss of s is: 0.000504650583025068
# Iteration is: 174150
# Data loss is: 0.0010252621723338962
# Physicial loss of p is: 0.001101676607504487
# Physicial loss of s is: 0.0005089992773719132
# Iteration is: 174160
# Data loss is: 0.0010259832488372922
# Physicial loss of p is: 0.0025245188735425472
# Physicial loss of s is: 0.0005936759989708662
# Iteration is: 174170
# Data loss is: 0.0010255726519972086
# Physicial loss of p is: 0.0014705831417813897
# Physicial loss of s is: 0.0005325255915522575
# Iteration is: 174180
# Data loss is: 0.0010252675274387002
# Physicial loss of p is: 0.0011155583197250962
# Physicial loss of s is: 0.0005138798733241856
# Iteration is: 174190
# Data loss is: 0.0010252540232613683
# Physicial loss of p is: 0.00099236483220011
# Physicial loss of s is: 0.000507855846080929
# Iteration is: 174200
# Data loss is: 0.0010251865023747087
# Physicial loss of p is: 0.0009544565109536052
# Physicial loss of s is: 0.0005043174605816603
# Iteration is: 174210
# Data loss is: 0.0010251991916447878
# Physicial loss of p is: 0.0009446504409424961
# Physicial loss of s is: 0.0005037469090893865
# Iteration is: 174220
# Data loss is: 0.0010251804487779737
# Physicial loss of p is: 0.0009365558507852256
# Physicial loss of s is: 0.0005029294989071786
# Iteration is: 174230
# Data loss is: 0.0010251777712255716
# Physicial loss of p is: 0.00093344651395455
# Physicial loss of s is: 0.0005027378210797906
# Iteration is: 174240
# Data loss is: 0.0010251777712255716
# Physicial loss of p is: 0.0009347760933451355
# Physicial loss of s is: 0.0005028086598031223
# Iteration is: 174250
# Data loss is: 0.0010251726489514112
# Physicial loss of p is: 0.0009346511797048151
# Physicial loss of s is: 0.0005027130828239024
# Iteration is: 174260
# Data loss is: 0.0010251710191369057
# Physicial loss of p is: 0.0009368593455292284
# Physicial loss of s is: 0.0005028179730288684
# Iteration is: 174270
# Data loss is: 0.0010252132778987288
# Physicial loss of p is: 0.0009850735077634454
# Physicial loss of s is: 0.000505940814036876
# Iteration is: 174280
# Data loss is: 0.0010263612493872643
# Physicial loss of p is: 0.00245346175506711
# Physicial loss of s is: 0.0005991964717395604
# Iteration is: 174290
# Data loss is: 0.0010254117660224438
# Physicial loss of p is: 0.0013601933605968952
# Physicial loss of s is: 0.0005313880392350256
# Iteration is: 174300
# Data loss is: 0.0010254408698529005
# Physicial loss of p is: 0.0012822875287383795
# Physicial loss of s is: 0.0005266729858703911
# Iteration is: 174310
# Data loss is: 0.0010251199128106236
# Physicial loss of p is: 0.0009719627560116351
# Physicial loss of s is: 0.0005054262583144009
# Iteration is: 174320
# Data loss is: 0.001025110250338912
# Physicial loss of p is: 0.0009354451321996748
# Physicial loss of s is: 0.0005031690816394985
# Iteration is: 174330
# Data loss is: 0.0010251286439597607
# Physicial loss of p is: 0.0009422872681170702
# Physicial loss of s is: 0.0005037080263718963
# Iteration is: 174340
# Data loss is: 0.0010251146741211414
# Physicial loss of p is: 0.0009380111587233841
# Physicial loss of s is: 0.0005030708853155375
# Iteration is: 174350
# Data loss is: 0.0010251164203509688
# Physicial loss of p is: 0.0009355546208098531
# Physicial loss of s is: 0.0005029499880038202
# Iteration is: 174360
# Data loss is: 0.0010251074563711882
# Physicial loss of p is: 0.0009338878444395959
# Physicial loss of s is: 0.00050265749450773
# Iteration is: 174370
# Data loss is: 0.0010251026833429933
# Physicial loss of p is: 0.0009337521623820066
# Physicial loss of s is: 0.0005025665159337223
# Iteration is: 174380
# Data loss is: 0.0010251012863591313
# Physicial loss of p is: 0.0009341373224742711
# Physicial loss of s is: 0.000502531009260565
# Iteration is: 174390
# Data loss is: 0.0010250962805002928
# Physicial loss of p is: 0.000933989358600229
# Physicial loss of s is: 0.0005024010897614062
# Iteration is: 174400
# Data loss is: 0.0010250897612422705
# Physicial loss of p is: 0.000934095005504787
# Physicial loss of s is: 0.0005022925324738026
# Iteration is: 174410
# Data loss is: 0.0010251482017338276
# Physicial loss of p is: 0.0009452909580431879
# Physicial loss of s is: 0.0005063355201855302
# Iteration is: 174420
# Data loss is: 0.0010257993126288056
# Physicial loss of p is: 0.0013515696628019214
# Physicial loss of s is: 0.0005150589859113097
# Iteration is: 174430
# Data loss is: 0.0010251220082864165
# Physicial loss of p is: 0.001050344668328762
# Physicial loss of s is: 0.0005022959667257965
# Iteration is: 174440
# Data loss is: 0.0010252645006403327
# Physicial loss of p is: 0.001175846322439611
# Physicial loss of s is: 0.0005132683436386287
# Iteration is: 174450
# Data loss is: 0.001026208745315671
# Physicial loss of p is: 0.002855003345757723
# Physicial loss of s is: 0.0006090745446272194
# Iteration is: 174460
# Data loss is: 0.0010254338849335909
# Physicial loss of p is: 0.0013500071363523602
# Physicial loss of s is: 0.0005289658438414335
# Iteration is: 174470
# Data loss is: 0.0010250252671539783
# Physicial loss of p is: 0.0009435092215426266
# Physicial loss of s is: 0.0005043806741014123
# Iteration is: 174480
# Data loss is: 0.0010250428458675742
# Physicial loss of p is: 0.000957620155531913
# Physicial loss of s is: 0.000506464100908488
# Iteration is: 174490
# Data loss is: 0.0010250277118757367
# Physicial loss of p is: 0.0009569540270604193
# Physicial loss of s is: 0.00050332274986431
# Iteration is: 174500
# Data loss is: 0.0010250410996377468
# Physicial loss of p is: 0.0009453378734178841
# Physicial loss of s is: 0.0005038250237703323
# Iteration is: 174510
# Data loss is: 0.0010250259656459093
# Physicial loss of p is: 0.0009377876413054764
# Physicial loss of s is: 0.0005026909639127553
# Iteration is: 174520
# Data loss is: 0.0010250279447063804
# Physicial loss of p is: 0.0009354844805784523
# Physicial loss of s is: 0.0005025311256758869
# Iteration is: 174530
# Data loss is: 0.0010250199120491743
# Physicial loss of p is: 0.0009342188131995499
# Physicial loss of s is: 0.0005023478297516704
# Iteration is: 174540
# Data loss is: 0.0010250136256217957
# Physicial loss of p is: 0.0009344719001092017
# Physicial loss of s is: 0.0005022634286433458
# Iteration is: 174550
# Data loss is: 0.0010250096675008535
# Physicial loss of p is: 0.0009343458223156631
# Physicial loss of s is: 0.0005022017285227776
# Iteration is: 174560
# Data loss is: 0.0010250071063637733
# Physicial loss of p is: 0.0009345062426291406
# Physicial loss of s is: 0.0005021386314183474
# Iteration is: 174570
# Data loss is: 0.0010250036139041185
# Physicial loss of p is: 0.0009350411128252745
# Physicial loss of s is: 0.0005021104589104652
# Iteration is: 174580
# Data loss is: 0.0010250132763758302
# Physicial loss of p is: 0.0009464623290114105
# Physicial loss of s is: 0.0005028982413932681
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 8
#       6     loss_, loss_p, loss_fp, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#       7 else:
# ----> 8     loss_, loss_p, loss_fp, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#       9 # else:
#      10 #     loss_, loss_p, loss_fp, loss_fs = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)
#      12 loss.append(loss_)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1601, in ConcreteFunction.__call__(self, *args, **kwargs)
#    1551 def __call__(self, *args, **kwargs):
#    1552   """Executes the wrapped function.
#    1553
#    1554   ConcreteFunctions have two signatures:
#    (...)
#    1599     TypeError: If the arguments do not match the function's signature.
#    1600   """
# -> 1601   return self._call_impl(args, kwargs)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1610, in ConcreteFunction._call_impl(self, args, kwargs, cancellation_manager)
#    1608 if self._function_spec is not None:
#    1609   try:
# -> 1610     return self._call_with_structured_signature(args, kwargs,
#    1611                                                 cancellation_manager)
#    1612   except TypeError as structured_err:
#    1613     try:
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1691, in ConcreteFunction._call_with_structured_signature(self, args, kwargs, cancellation_manager)
#    1689 self._structured_signature_check_unexpected_args(args, kwargs)
#    1690 self._structured_signature_check_arg_types(args, kwargs)
# -> 1691 return self._call_flat(
#    1692     filtered_flat_args,
#    1693     captured_inputs=self.captured_inputs,
#    1694     cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(ep, np.asarray(loss_data_list), 'b-', linewidth = 2, alpha=0.6, label = 'Data')  
plt.semilogy(ep, np.asarray(loss_phip_list), 'r-', linewidth = 2, alpha=0.6, label = '$\phi_p$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\phi_s$')       


plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
# lnv[0], tf.exp(lnv[0]), #lnv[1], tf.exp(lnv[1])
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp=u_pred[:,0:1]
lns=u_pred[:,1:2]

p=tf.exp(lnp)
s=tf.exp(lns)
a=X_star_tf[...,2:3]
lnl=predict(a, W_a, b_a)
m=tf.exp(lnl[:,0:1])
l=tf.exp(lnl[:,1:2])
phi = tf.exp(predict(tf.concat([s, a],1), W_phi, b_phi))
# phi = tf.exp(predict(s, W_phi, b_phi))


# m=tf.exp(lnv[0:1])
# l=tf.exp(lnv[1:2])


phi_s=-np.array(p*s*m)

# %%
X_star_tf.shape, p.shape
# Out:
# (TensorShape([6498, 3]), TensorShape([6498, 1]))

# %%
X_star_tf[...,2:3]
# Out:
# <tf.Tensor: shape=(6498, 1), dtype=float32, numpy=
# array([[0.  ],
#        [0.  ],
#        [0.  ],
#        ...,
#        [3.75],
#        [3.75],
#        [3.75]], dtype=float32)>

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],s[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')



plt.xlabel('t (ms)')
plt.ylabel('S')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
l
# Out:
# <tf.Tensor: shape=(6498, 1), dtype=float32, numpy=
# array([[11.699274],
#        [11.699274],
#        [11.699274],
#        ...,
#        [11.329064],
#        [11.329064],
#        [11.329064]], dtype=float32)>

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,2],l[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, label='Prediction P')



plt.xlabel('A')
plt.ylabel('death rate')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(p, phi, s=3, label='Prediction')
plt.scatter(s, phi, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.scatter(p, phi_s, s=3, label='Prediction')

plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
Nt=1000

A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    # P_int[0]=np.array(p[0]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    lnvar=predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a)
    m=tf.exp(lnvar[:,0:1])
    l=tf.exp(lnvar[:,1:2])
    # l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        PSA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32)],1)

        # REVISAAAAAR
        PHI=tf.exp(predict(PSA[:,1:], W_phi, b_phi))
        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI - P_int[i-1]*l)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*m*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %%
Nt=1000

A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    # P_int[0]=np.array(p[0]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    lnvar=predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a)
    m=tf.exp(lnvar[:,0:1])
    l=tf.exp(lnvar[:,1:2])
    # l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        PSA=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32)],1)

        # REVISAAAAAR
        PHI=tf.exp(predict(PSA[:,1:], W_phi, b_phi))
        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI - P_int[i-1]*l)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*m*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    # plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
# plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors
Nt=1000

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    # P_int[0]=np.array(p[0]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(PSL , W_phi, b_phi))
        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI_S - P_int[i-1]*l)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    # plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
# plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Symbolic Regresion

# %%
c=0
d=-1
plt.scatter( p[c:d], np.exp(phi[c:d]), s=2, label='Prediction P')
plt.scatter( s[c:d], np.exp(phi[c:d]), s=2, label='Prediction S')
# plt.plot( a[c:d], phi_p[c:d], label='Prediction S')


plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
X_star_tf[c:d][0], X_star_tf[c:d][-1]
# Out:
# (<tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.    , 0.0938], dtype=float32)>,
#  <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.9970674, 0.0923   ], dtype=float32)>)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')




plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')


plt.vlines(X_star_tf[c:d][:,0][0],0,1.2, color='red', linestyle=':')
plt.vlines(X_star_tf[c:d][:,0][-1],0,1.2, color='red', linestyle=':')


plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model = PySRRegressor(
    niterations=200,
    binary_operators=["+", "*", "inv(x, y) = x/(x + y)"],
    # binary_operators=["+", "*", "inv(x, y) = x/(x + y)", "^"],

    # unary_operators=[ "exp"],
    # unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={
            "inv": lambda x, y: x/(x+y),
        },
    # extra_sympy_mappings={"inv": lambda x: 1/x},
    constraints={"exp": 3, 'inv': (1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00000001,
    # denoise=True,
    # complexity_of_variables=2,
    # complexity_of_constants=2,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
    select_k_features=1,
    maxsize=40,
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# p1s=tf.concat([p1[c:d], s[c:d]], axis=1)

min_cols_phi= tf.math.reduce_min(phi[c:d], axis=0)
max_cols_phi= tf.math.reduce_max(phi[c:d], axis=0)

phi_scaled = (phi[c:d]-min_cols_phi)/(max_cols_phi-min_cols_phi)
PS_tf=tf.concat([p[c:d], s[c:d]],1)

model.fit( PS_tf,phi_scaled)
print(model)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Using features ['x1']
# [ Info: Started!
# Expressions evaluated per second: 2.780e+04
# Head worker occupation: 22.9%
# Progress: 75 / 3000 total iterations (2.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           3.955e-02  5.314e+00  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.478e-02  2.859e-02  y = ((inv(x1, 0.10223) * -0.30208) + (0.15902 + x1)) + 0.09950...
#                                   7
# 13          2.370e-02  2.218e-02  y = 0.099507 + ((0.18993 + x1) + ((-0.30208 * 1.3452) * inv(x1...
#                                   , 0.10223)))
# 17          2.215e-02  1.688e-02  y = 0.18608 + ((x1 + (((-1.0119 * x1) * x1) * (x1 * x1))) * (x...
#                                   1 + x1))
# 19          1.947e-02  6.449e-02  y = 0.25455 + (((((-0.85623 * x1) * x1) * x1) + x1) * ((x1 + 0...
#                                   .14507) + (-0.30395 + x1)))
# 21          1.793e-02  4.126e-02  y = 0.25004 + (((x1 + (((x1 + x1) + -0.66889) * 2.4278)) * (-0...
#                                   .39674 + inv(0.85065, x1))) * (x1 + x1))
# 25          1.672e-02  1.743e-02  y = (x1 * ((((x1 + x1) + -0.080258) * ((inv(x1, x1) + ((x1 * -...
#                                   0.92223) * (x1 * x1))) + 0.95982)) + -0.82044)) + 0.2704
# 27          1.306e-02  1.236e-01  y = ((((inv(1.4462, 2.2953) + ((x1 * (0.16588 + x1)) * -0.8808...
#                                   2)) + 0.62528) * ((x1 + ((2.9017 * x1) + -1.2808)) + x1)) * x1...
#                                   ) + 0.26349
# 31          1.115e-02  3.957e-02  y = (((((1.9312 + ((x1 * (0.56703 + x1)) * -1.3051)) + -0.1458...
#                                   1) * ((x1 + ((1.3124 * x1) + -1.0317)) + x1)) + ((-0.59911 + x...
#                                   1) + 0.079291)) * x1) + 0.29135
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.800e+04
# Head worker occupation: 19.6%
# Progress: 172 / 3000 total iterations (5.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 15          1.863e-02  3.620e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.855e-02  2.179e-03  y = 0.2407 + (((x1 * (((x1 * -0.96546) * x1) * x1)) + x1) * (x...
#                                   1 + x1))
# 19          1.180e-02  2.260e-01  y = ((((x1 + -0.9667) * 3.1557) * ((x1 * -2.4664) + inv(0.8407...
#                                   1, x1))) * x1) + (0.19285 + 0.10635)
# 21          1.096e-02  3.683e-02  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.19285 + 0.10635)
# 23          1.063e-02  1.558e-02  y = ((x1 * ((x1 + (x1 + (x1 + (x1 + -1.3504)))) * ((-1.5055 * ...
#                                   (x1 * 1.2765)) + 1.9003))) + 0.242) * 1.2304
# 29          1.061e-02  2.597e-04  y = (((((-1.2701 + (x1 + (inv(-0.22109, 1.2369) + x1))) + ((-0...
#                                   .23128 + x1) + x1)) + x1) * (((x1 * 0.97839) * -1.9394) + 1.87...
#                                   65)) * x1) + 0.30126
# 31          1.056e-02  2.149e-03  y = (1.0965 * ((((((x1 * x1) * -0.47626) + x1) + ((x1 + -0.415...
#                                   78) * (1.5945 + inv(-0.6427, 0.35635)))) * ((x1 * -1.9534) + 1...
#                                   .9355)) * x1)) + (0.27317 + 0.029663)
# 37          1.054e-02  4.362e-04  y = 0.29991 + (x1 * ((((((((x1 + x1) + -0.84768) + x1) + x1) +...
#                                    (((-0.041061 * x1) * x1) + ((-1.7349 + -1.0641) + x1))) + -1....
#                                   3884) + inv(0.15367, x1)) * ((x1 * -2.079) + 0.72708)))
# 39          1.003e-02  2.451e-02  y = (x1 * ((((x1 * (-1.9266 * 0.87892)) * x1) + 1.8833) * (((1...
#                                   .8833 + (x1 * ((-1.5986 * x1) + -0.2367))) * (((x1 + -1.3044) ...
#                                   + (x1 + 0.15884)) + (x1 + inv(0.047572, x1)))) + 0.043323))) +...
#                                    0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Head worker occupation: 15.9%
# Progress: 250 / 3000 total iterations (8.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          2.136e-02  3.898e-03  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * (x1 * 1.0785)...
#                                   )
# 15          1.863e-02  6.850e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.245e-02  2.014e-01  y = (0.19285 + 0.086001) + ((((x1 + -0.9667) * 3.1557) * (0.90...
#                                   662 + (-2.7585 * x1))) * x1)
# 19          1.140e-02  4.434e-02  y = (((-0.10278 + (3.1557 * (x1 + -0.9667))) * ((x1 * -2.4664)...
#                                    + 0.84071)) * x1) + (0.10635 + 0.19285)
# 21          1.092e-02  2.120e-02  y = (((-0.10278 + ((-0.9667 + x1) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.095392 + 0.19285)
# 23          1.062e-02  1.392e-02  y = ((x1 + -0.081559) * (((-2.2871 * x1) + 2.3214) * ((x1 * 2....
#                                   2758) + ((-1.1269 + x1) + (x1 + 0.11778))))) + 0.11195
# 27          1.045e-02  4.143e-03  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + ((0.84071 + inv(...
#                                   x1, -1.3214)) + x1)))) * ((x1 * -2.4664) + 0.84071)) * x1) + (...
#                                   0.19285 + 0.10635)
# 29          1.041e-02  1.637e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + -0.33894) ...
#                                   * ((x1 + inv(0.047572, x1)) + (x1 + -1.3044))) + x1) + (x1 * 1...
#                                   .1842)))) + 0.30147
# 31          1.008e-02  1.639e-02  y = (x1 * (((-1.9266 * x1) + 1.8833) * (((1.8833 + 0.077362) *...
#                                    ((x1 + (inv(0.047572, x1) + -0.064585)) + ((x1 + x1) + -1.304...
#                                   4))) + (0.30147 * 1.1842)))) + 0.30147
# 37          9.843e-03  3.925e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + inv(0.0773...
#                                   62, x1)) * ((x1 + inv(0.047572, x1)) + (inv(0.043323, 0.15884)...
#                                    + (x1 + -1.3044)))) + x1) + (x1 * inv(1.1842, 0.91425))))) + ...
#                                   0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.700e+04
# Head worker occupation: 14.5%
# Progress: 329 / 3000 total iterations (10.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.617e-02  1.432e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.4051)) *...
#                                    x1)
# 15          1.224e-02  1.390e-01  y = 0.28154 + (x1 * ((x1 + -0.99589) * (((-5.2648 + -1.9302) *...
#                                    x1) + 2.2863)))
# 17          1.167e-02  2.394e-02  y = 0.28154 + (x1 * ((x1 + -0.99589) * ((((-5.2648 + -1.1021) ...
#                                   + -1.2315) * x1) + 2.2863)))
# 19          1.070e-02  4.356e-02  y = 0.30839 + (x1 * (((1.8937 * (x1 + (-0.8686 + x1))) + x1) *...
#                                    (1.9877 + (x1 * -2.0051))))
# 23          1.061e-02  2.016e-03  y = 0.30131 + ((x1 * 1.6833) * (((-1.9277 * x1) + 1.9069) * ((...
#                                   0.54582 + (((0.51804 + -1.3234) + x1) * 1.9209)) + x1)))
# 27          9.929e-03  1.662e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + x1)))
# 29          9.905e-03  1.218e-03  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * ((1.8246 + x1) * inv(x1, 0...
#                                   .31499))) + x1)))
# 31          8.648e-03  6.782e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1....
#                                   9302)) * (((x1 + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + (0.20664 * inv(x1, x1)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.150e+04
# Head worker occupation: 14.2%
# Progress: 426 / 3000 total iterations (14.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.052e-02  2.579e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * (((-4.6...
#                                   638 + (x1 * (x1 + -0.67368))) * x1) + 1.6117)))
# 25          1.050e-02  9.160e-04  y = (0.21074 + (x1 * ((-1.0022 + x1) * (2.4464 + ((-2.5247 + (...
#                                   (-5.2844 + (x1 * (x1 + x1))) * 0.9772)) * x1))))) * 1.4173
# 27          9.528e-03  4.841e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (-1.9302 * x1)) ...
#                                   * (((x1 + (inv(-0.83605, 1.6945) + x1)) * (1.9019 * inv(x1, 0....
#                                   31499))) + x1)))
# 29          8.448e-03  6.015e-02  y = (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1.9302)) * (...
#                                   ((1.8246 * inv(x1, 0.20664)) * (x1 + (-0.83605 + inv(x1, 0.791...
#                                   32)))) + 0.20664))) + 0.29387
# 33          5.125e-03  1.249e-01  y = ((inv(x1, 0.0098097) * 0.87837) * ((1.9533 + ((x1 * x1) * ...
#                                   -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2292)) * (x1 + (inv(x...
#                                   1, 0.7733) + -0.77502))) + 0.2292))) + 0.2292
# 35          4.691e-03  4.421e-02  y = ((inv(x1, 0.0098097) * 0.87837) * (((x1 * (-1.9397 * x1)) ...
#                                   + 1.8885) * (((((1.8202 + x1) + 0.20894) * inv(x1, 0.20894)) *...
#                                    ((-0.77502 + inv(x1, 0.7733)) + x1)) + 0.25046))) + 0.2292
# 37          3.741e-03  1.132e-01  y = (((inv(x1, 0.0098097) * 0.87837) + (-0.22058 * x1)) * ((1....
#                                   9533 + ((x1 * x1) * -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2...
#                                   292)) * (x1 + (inv(x1, 0.7733) + -0.77502))) + 0.2292))) + 0.2...
#                                   292
# 39          3.216e-03  7.559e-02  y = (((inv(x1, 0.0041438) * 0.87769) + (-0.22025 * (x1 + -0.15...
#                                   79))) * ((1.9537 + ((x1 * x1) * -1.9389)) * (0.22256 + (((1.95...
#                                   4 + x1) * inv(x1, 0.21981)) * (x1 + (inv(x1, 0.77348) + -0.778...
#                                   73)))))) + 0.19528
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.950e+04
# Head worker occupation: 14.8%
# Progress: 535 / 3000 total iterations (17.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.367e-03  y = 0.3052 + (x1 * ((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 ...
#                                   + ((x1 * 1.1883) * x1)) * x1) + 1.6117)))
# 25          2.667e-03  6.852e-01  y = (((0.26613 + ((inv(x1, 0.19528) * 1.9537) * (x1 + (-0.7787...
#                                   3 + x1)))) * (1.9537 + (x1 * -1.9389))) * inv(x1, 0.0041438)) ...
#                                   + 0.19528
# 27          2.108e-03  1.176e-01  y = 0.19528 + (((0.26613 + ((x1 + (x1 + -0.77873)) * (inv(x1, ...
#                                   0.19528) * 1.9537))) * (1.9537 + ((0.97698 * x1) * -1.9389))) ...
#                                   * inv(x1, 0.0041438))
# 29          1.636e-03  1.269e-01  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 37          1.339e-03  1.250e-03  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.100e+04
# Head worker occupation: 15.0%
# Progress: 639 / 3000 total iterations (21.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.636e-03  9.570e-02  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.341e-03  1.548e-03  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + (x1 * 0.93073)) +...
#                                    inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.158...
#                                   87
# 37          1.339e-03  9.526e-04  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# 39          1.215e-03  4.855e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * (inv(1.2861, 0.84669) + -0.15182)))) * ((...
#                                   x1 + -0.87651) + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1...
#                                   , 0.0056867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 731 / 3000 total iterations (24.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.631e-03  9.701e-02  y = 0.15887 + (((0.75672 * (1.9752 + (-1.9035 * x1))) * (((x1 ...
#                                   + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x1)) + 0.4196...
#                                   2)) * inv(x1, 0.0056867))
# 31          1.403e-03  7.550e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.294e-03  1.938e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * ((((x1 + (inv(x1...
#                                   , 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651) ...
#                                   + x1)) + 0.41962) * 1.1182)) * inv(x1, 0.0056867)) + 0.15887
# 37          1.177e-03  4.740e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651)...
#                                    + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1, 0.0056867)) ...
#                                   + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+04
# Head worker occupation: 14.3%
# Progress: 828 / 3000 total iterations (27.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          8.340e-03  1.185e-01  y = ((((x1 * -1.9035) + 1.9752) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  6.129e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.491e-03  2.480e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + inv(0.41962, 0.72301))) * inv(x1, 0...
#                                   .0056867)) + 0.15887
# 31          1.403e-03  1.520e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.191e-03  6.093e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((inv(x1, 1.4938) + inv(x1, 0.060135)) + x1) * ((-0.876...
#                                   51 + x1) + x1)) + 0.41962))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.173e-03  7.562e-03  y = ((((-1.9035 * x1) + 1.9752) * (((((inv(x1, 0.060135) + x1)...
#                                    + (inv(x1, 1.9457) * x1)) * ((-0.87651 + x1) + x1)) * inv(1.0...
#                                   821, 0.092927)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)...
#                                   ) + 0.15887
# 39          1.147e-03  1.132e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((((inv(x1, 1.4938) * x1) + inv(x1, 0.060135)) * 1.0811...
#                                   ) + x1) * ((-0.87651 + x1) + x1)) + 0.41962))) * inv(x1, 0.005...
#                                   6867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 941 / 3000 total iterations (31.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  3.101e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.309e-03  3.131e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.248e-03  2.389e-02  y = ((inv(x1, 0.0056867) + -0.012119) * (((((inv(x1, 0.060135)...
#                                    + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9...
#                                   752 + (-1.9035 * x1)))) + 0.15887
# 31          1.247e-03  2.635e-04  y = ((inv(x1, 0.0056867) + (-0.012119 * 1.1739)) * (((((inv(x1...
#                                   , 0.060135) + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41...
#                                   962) * (1.9752 + (-1.9035 * x1)))) + 0.15887
# 35          1.162e-03  1.770e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.300e+04
# Head worker occupation: 15.3%
# Progress: 1029 / 3000 total iterations (34.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.240e-03  2.677e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * 0.89975)))) + 0.15887
# 31          1.214e-03  1.062e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.89975, 0.21942))))) + 0.15887
# 33          1.192e-03  9.391e-03  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.180e+04
# Head worker occupation: 15.1%
# Progress: 1119 / 3000 total iterations (37.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.222e-03  3.409e-02  y = (((1.9752 + (-1.9035 * x1)) * (((((inv(x1, 0.060135) + x1)...
#                                    * ((x1 + -0.87651) + x1)) + 0.41962) + -0.04569) + 0.0067754)...
#                                   ) * inv(x1, 0.0056867)) + 0.15887
# 31          1.193e-03  1.213e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.192e-03  5.541e-04  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.920e+04
# Head worker occupation: 15.3%
# Progress: 1201 / 3000 total iterations (40.033%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.193e-03  1.789e-03  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.175e-03  7.800e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962)...
#                                    + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.259e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# 37          1.089e-03  2.505e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.650e+04
# Head worker occupation: 15.8%
# Progress: 1277 / 3000 total iterations (42.567%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.176e-03  8.842e-03  y = (((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1) ...
#                                   * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) + 0.15887
# 33          1.171e-03  2.279e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.11004)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.106e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# ...
#                                   ))))
# 27          9.974e-04  2.466e-02  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * ((((-2.12...
#                                   75 * x1) * x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1...
#                                   , 0.016826)))))
# 29          9.888e-04  4.331e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.710e+04
# Head worker occupation: 16.4%
# Progress: 2823 / 3000 total iterations (94.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.640e+04
# Head worker occupation: 16.6%
# Progress: 2906 / 3000 total iterations (96.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.820e+04
# Head worker occupation: 16.3%
# Progress: 2999 / 3000 total iterations (99.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 21          9.452e-03  9.432e-03  y = (0.19018 + (inv(x1, 0.0097537) * (1.9599 * (0.62748 + ((in...
#                                   v(x1, 0.40694) + -1.0054) * inv(x1, 0.0212)))))) + -0.048795
# 23          2.345e-03  6.969e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 35          9.688e-04  6.415e-04  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * ((x1 + -1.0184) * 1.1219))) * x1)) + 2.1916)...
#                                    * (((-1.0184 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  4.520e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                           0.310787
# 	1         0.084607                                    0.19077079 + x1
# 	2         0.173234                      (0.5607476 * x1) + 0.24348809
# 	3         0.027205              (x1 * inv(x1, 0.5479253)) + 0.2523965
# 	4         0.054837  (inv(x1, 0.080867134) * (-0.32800326 + x1)) + ...
# 	5         0.059941  (((-3.07164 * x1) + 3.3362021) * (x1 * x1)) + ...
# 	6         0.168797  (((-1.0817221 + x1) * ((x1 * -4.7079844) + 1.2...
# 	7         0.173619  ((((-4.6741557 * x1) + 1.5998087) * (-1.980577...
# 	8         0.024327  0.15983854 + (inv(x1, 0.014288435) * ((((inv(x...
# 	9         0.009432  (0.19018486 + (inv(x1, 0.009753697) * (1.95994...
# 	10        0.696936  (((inv(x1, 0.014288435) + inv(x1, -1.4914056))...
# 	11  >>>>  0.417967  ((x1 + inv(x1, 0.014288435)) * ((((-2.1275125 ...
# 	12        0.011980  0.15983854 + ((inv(x1, 0.014288435) + (x1 * 1....
# 	13        0.001834  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	14        0.000325  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	15        0.009251  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	16        0.000642  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	17        0.045198  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
# 	18        0.002793  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
#
# 	        loss  complexity
# 	0   0.046845           1
# 	1   0.039553           3
# 	2   0.027971           5
# 	3   0.026490           7
# 	4   0.023738           9
# 	5   0.021056          11
# 	6   0.015023          13
# 	7   0.010616          15
# 	8   0.009632          19
# 	9   0.009452          21
# 	10  0.002345          23
# 	11  0.001017          25
# 	12  0.000992          27
# 	13  0.000989          29
# 	14  0.000988          31
# 	15  0.000970          33
# 	16  0.000969          35
# 	17  0.000885          37
# 	18  0.000880          39
# ]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Extraer las métricas de las ecuaciones
equations_df = model.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.yscale('log')
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
chose=17
expr=model.sympy(chose)*(max_cols_phi-min_cols_phi)+min_cols_phi
expr
# Out:
# 21.7206382751465*((x1/(x1 + 0.016826037))*(x1 - 1.0184498) + 0.7157937)*(x1*x1*x1*(-2.1275125 + 0.16839427) + 2.1915646)*(x1*x1*(-1.0264988)*x1 + x1 + x1/(x1 + 0.014288435)) + 4.61513426687202
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sympy.expand(expr)
# Out:
# 43.6809097560371*x1**8/(x1 + 0.016826037) - 44.4868138048541*x1**7/(x1 + 0.016826037) + 31.2665200136399*x1**6 - 42.5532984120752*x1**6/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 42.5532984120752*x1**6/(x1 + 0.016826037) + 43.3383982571183*x1**5/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 5.52518437470967*x1**5/(x1 + 0.016826037) - 30.4593829175835*x1**4 + 49.7651059586687*x1**4/(x1 + 0.016826037) - 30.4593829175835*x1**4/(x1 + 0.014288435) - 34.9762446072919*x1**3 + 47.6021819332161*x1**3/(x1**2 + 0.031114472*x1 + 0.000240417735982095) + 47.6021819332161*x1**3/(x1 + 0.016826037) - 48.4804326694475*x1**2/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 48.4804326694475*x1**2/(x1 + 0.016826037) + 34.0733419340499*x1 + 34.0733419340499*x1/(x1 + 0.014288435) + 4.61513426687202
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sympy.simplify(expr)
# Out:
# (21.7206382751465*x1*(2.1915646 - 1.95911823*x1**3)*((1 - 1.0264988*x1**2)*(x1 + 0.014288435) + 1)*(x1*(x1 - 1.0184498) + 0.7157937*x1 + 0.0120439712805669) + 4.61513426687202*(x1 + 0.014288435)*(x1 + 0.016826037))/((x1 + 0.014288435)*(x1 + 0.016826037))
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sympy.factor(expr)
# Out:
# 79.1383687168112*(0.55195615558295*x1**9 - 0.159166307767832*x1**8 - 0.533446731117839*x1**7 - 1.0*x1**6 + 0.336640788383156*x1**5 + 0.590170698599522*x1**4 + 0.427944668557383*x1**3 - 0.119088781949323*x1**2 + 0.00916254183022982*x1 + 1.40205079999211e-5)/((1.0*x1 + 0.014288435)*(1.0*x1 + 0.016826037))
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
symb_s=model.predict(tf.concat([p, s],1),chose)
symb_s=symb_s*(max_cols_phi-min_cols_phi)+min_cols_phi
plt.scatter(s, phi, s=3, label='PINN prediction')
plt.scatter(s, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
plt.scatter(p, phi, s=3, label='PINN prediction')
plt.scatter(p, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
# plt.plot(tf.concat([p, s],1), 15.38-1.18*s, linestyle='--', label=r'$s\approx 0$')

# plt.plot( s, 200/(13+s), label='Real S')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.legend()
plt.show()
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
Nt=1000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)

dt=0.001

P_symb[0]=np.mean(P0) #Initial conditions
# P_symb[0]=np.mean(1) #Initial conditions

S_symb[0]=np.array(s[0]) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    PS_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    # PHI=predict(PS_p , W_phi, b_phi)
    # P_symb[i]=P_symb[i-1]+(PHI)*P_symb[i-1]*dt

    P_symb[i]=P_symb[i-1]+(model.predict(PS_p,chose)*(max_cols_phi-min_cols_phi)+min_cols_phi-np.array(l))*P_symb[i-1]*dt
    S_symb[i]=S_symb[i-1]-np.maximum(0, P_symb[i-1]*S_symb[i-1]*np.array(m))*dt
    T_symb[i]=T_symb[i-1]+dt
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.ylim(0,1)
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
import sympy as sp

P, S = sp.symbols('P S')

# Definir la función que representa el sistema de ecuaciones
def system(vars):
    P, S = vars
    f_S = expr.subs({'x1': S})-6.1390066  # Cambia esta expresión por la de tu función f(S)
    dP = f_S * P 
    dS = -42.86948 * S * P
    return [dP, dS]


# Definir variables simbólicas
# P, S = sp.symbols('P S')
# Define tu función f(S) y asegúrate de que solo depende de S
f_S = expr.subs({'x1': S})-6.1390066   # Define aquí la función f(S) correctamente

# Convertir f(S) en una función numérica
f_S_func = sp.lambdify(S, f_S, 'numpy')

# Rango para el diagrama de fases
S_values = np.linspace(0, 1, 50)
P_values = np.linspace(0, 1, 50)

# Crear la cuadrícula
P_grid, S_grid = np.meshgrid(P_values, S_values)
dP_vals = f_S_func(S_grid) * P_grid
dS_vals = -42.86948 * S_grid * P_grid

# Encontrar los puntos fijos usando fsolve
fixed_points = []
for P_init in np.linspace(0, 1, 50):  # Asegúrate de elegir un buen rango de inicialización
    for S_init in np.linspace(0, 1, 50):
        point = fsolve(system, [P_init, S_init])
        # Evitar duplicados al agregar puntos
        if not any(np.allclose(point, fp) for fp in fixed_points):
            fixed_points.append(point)



import scipy.optimize as opt


# Usar fsolve para encontrar las raíces de f(S) en un rango inicial
S_initial_guesses = np.linspace(0, 1, 20)  # Puedes ajustar el rango de las conjeturas iniciales
S_roots = [opt.fsolve(f_S_func, S0) for S0 in S_initial_guesses]

# Imprimir las soluciones
S_roots = np.unique(np.array(S_roots).flatten())  # Aplanar el resultado para eliminar listas anidadas
print("Soluciones de f(S) = 0:", S_roots)

# Graficar las soluciones
S_values = np.linspace(0, 1, 100)
f_values = f_S_func(S_values)

plt.plot(S_values, f_values, label="f(S)")
plt.axhline(0, color='black', linestyle='--')
plt.scatter(S_roots, f_S_func(S_roots), color='red', label='Raíces')
plt.xlabel('S')
plt.ylabel('f(S)')
plt.legend()
plt.xlim(0,1)
plt.show()
# Out:
# Soluciones de f(S) = 0: [7.00220078e-04 3.67713783e-02 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 2.89489556e-01 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 1.02094028e+00 1.02094028e+00 1.02094028e+00
#  1.31517768e+00]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')



plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.ylim(0,1)
plt.xlim(0,1)

plt.legend()
plt.grid()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')


plt.plot(P_int, S_int, color='green')
plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.legend()
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
