# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x17a8cccd580>,
#  <matplotlib.lines.Line2D at 0x17a8cccd5e0>,
#  <matplotlib.lines.Line2D at 0x17936b4f280>,
#  <matplotlib.lines.Line2D at 0x179452d4430>,
#  <matplotlib.lines.Line2D at 0x178a2dc0370>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.hstack((P0_exp,P1_exp,P2_exp,P3_exp))
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
n=np.array([P0_exp.shape[1],P1_exp.shape[1],P2_exp.shape[1],P3_exp.shape[1]])
A_orig=np.array([0, 1.25, 2.50, 3.75])
A=(A_orig-min(A_orig))/max(A_orig)
N_exp,T_max, T_exp.shape, P_exp.shape, 342*23
# Out:
# (19, 231399.5, (342,), (342, 19), 7866)

# %%
A
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)

plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 1500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
Xa_star=[]
P0_star=np.empty((0, 1))
A0_star=np.empty((0, 1))
X_star = np.empty((0, 3))
for i in range(len(A)):
    P0=P_exp[0:1, np.sum(n[:i]):np.sum(n[:i+1])]
    P0_star=np.concatenate((P0_star,P0.T))
    A0_star=np.concatenate((A0_star, np.array([A[i]]*n[i]).reshape([-1,1])))
    T_meshgrid, P0_meshgrid, A_meshgrid = np.meshgrid(T_exp, P0, A[i])
    x=np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None], A_meshgrid.flatten()[:,None]))
    Xa_star += [x]
    X_star=np.vstack((X_star,x))


u_star=np.hstack((P_star,X_star[:,1:2]))

# %%
# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0_star)).reshape([-1,1]), P0_star.reshape([-1,1]), xx0[...,2:3]))

xx01=np.vstack((xx0, xx1))
uu01_s=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

uu01_a=np.array(list(A0_star.reshape([1,-1])[0])+[0]*N_exp).reshape([-1,1])


# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(3, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_s_tf = tf.convert_to_tensor(uu01_s, dtype=tf.float32)
uu01_a_tf = tf.convert_to_tensor(uu01_a, dtype=tf.float32)

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        plt.plot(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_exp[:, (i + np.sum(n[:k]))], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('P0')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,2], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('A')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 3]), dtype=tf.float32)
    # alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1))) 
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp * 2 * 2), (N_exp * 2, 2)))
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)

        lnp=u[:,0:1]
        lns=u[:,1:2]
        lna=u[:,2:3]


        p=tf.exp(lnp)
        s=tf.exp(lns)
        a=tf.exp(lna)

        m=tf.exp(lnv[0:1])
        l=tf.exp(lnv[1:2])

        # phi=tf.exp(net(tf.concat([p, s, l],1), W_phi, b_phi))
        phi_s=tf.exp(net(s, W_phi, b_phi))
        phi_a=tf.exp(net(a, W_a, b_a))




    p_t = tape1.gradient(p, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]
    a_t = tape1.gradient(a, X_f)[...,0:1]


    f_p = p_t - phi_s*p + phi_a*p
    f_s = s_t + m*p*s
    f_a = a_t + l*p*a

    
    return f_p, f_s, f_a




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi, b_phi,  W_a, b_a,  X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, W_a, b_a, lambda_b, lambda_r, lambda_0, lnv])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp=u_nn[:,0:1]
        p_nn=tf.exp(lnp)
        f_p, f_s, f_a = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        u_00 = net(xx01_tf, W_p, b_p) 
        s_00=tf.exp(u_00[:,1:2])
        u_00 = net(xx01_tf[:N_exp], W_p, b_p) 
        a_00=tf.exp(u_00[:,2:3])

        loss_p = tf.square(lambda_b*(p_nn - P_train_tf))
        loss_0s = tf.square(lambda_0[:,0:1]*(s_00 - uu01_s_tf))
        loss_0a = tf.square(lambda_0[:N_exp:,1:2]*(a_00 - xx01_tf[:N_exp,2:3]))
        loss_fp = tf.square(lambda_r[:,0:1]*f_p) 
        loss_fs = tf.square(lambda_r[:,1:2]*f_s)
        loss_fa = tf.square(lambda_r[:,2:3]*f_a) 

        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_fa)+ tf.reduce_mean(loss_0s)+ tf.reduce_mean(loss_0a)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)


    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s)), tf.reduce_mean(tf.square(f_a)), tf.reduce_mean(tf.square((a_00 - xx01_tf[:N_exp,2:3])))
    # return loss, tf.reduce_mean(tf.square((p_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s)), tf.reduce_mean(tf.square(f_a)), tf.reduce_mean(tf.square((a_00 - uu01_a_tf)))



layers = [3, 20, 20, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]

W_a = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_a = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]
L = len(layers)

W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 2), (2, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
def train_dynamic_step( W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_phi, b_phi, W_a, b_a, lambda_r, lnv])

        f_p, f_s, f_a = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        loss_fp = tf.square(lambda_r[0:1]*f_p) 
        loss_fs = tf.square(lambda_r[1:2]*f_s) 
        loss_fa = tf.square(lambda_r[2:3]*f_a) 

        loss =  tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_fa)


    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)



    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))

   
    return loss, -1, tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s)), tf.reduce_mean(tf.square(f_a))

# %%
lr = 3e-3


optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/30)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []
loss_fisa = []
loss_0=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf,  lambda_r, lambda_b, lambda_0, lnv, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0, lnv, optimizer2)
train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=10**5


while it <= Nmax:
    if it<5*10**4:
        loss_, loss_p, loss_fp, loss_fs, loss_fa, loss_f0a = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0, lnv)
    else:
        loss_, loss_p, loss_fp, loss_fs, loss_fa, loss_f0a = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_s_tf, uu01_a_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else:
    #     loss_, loss_p, loss_fp, loss_fs, loss_fa = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)
    loss_fisa.append(loss_fa)
    loss_0.append(loss_f0a)




    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p is: {loss_fp}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Data loss is: 0.22005607187747955
# Physicial loss of p is: 0.019874559715390205
# Physicial loss of s is: 2.6857964992523193
# Iteration is: 10
# Data loss is: 0.07255835831165314
# Physicial loss of p is: 0.00402211956679821
# Physicial loss of s is: 0.1739947646856308
# Iteration is: 20
# Data loss is: 0.04781877622008324
# Physicial loss of p is: 0.005603695288300514
# Physicial loss of s is: 0.13726623356342316
# Iteration is: 30
# Data loss is: 0.04164079204201698
# Physicial loss of p is: 0.013095948845148087
# Physicial loss of s is: 0.4911574125289917
# Iteration is: 40
# Data loss is: 0.03973439708352089
# Physicial loss of p is: 0.013702997006475925
# Physicial loss of s is: 0.6963202357292175
# Iteration is: 50
# Data loss is: 0.037306949496269226
# Physicial loss of p is: 0.003652210347354412
# Physicial loss of s is: 0.7872103452682495
# Iteration is: 60
# Data loss is: 0.03653287887573242
# Physicial loss of p is: 0.003298889147117734
# Physicial loss of s is: 0.979103684425354
# Iteration is: 70
# Data loss is: 0.035660553723573685
# Physicial loss of p is: 0.005060648545622826
# Physicial loss of s is: 1.0143121480941772
# Iteration is: 80
# Data loss is: 0.034947749227285385
# Physicial loss of p is: 0.005931878462433815
# Physicial loss of s is: 1.0003626346588135
# Iteration is: 90
# Data loss is: 0.03420793265104294
# Physicial loss of p is: 0.007280157413333654
# Physicial loss of s is: 1.017106294631958
# Iteration is: 100
# Data loss is: 0.03337490186095238
# Physicial loss of p is: 0.008905681781470776
# Physicial loss of s is: 1.0273693799972534
# Iteration is: 110
# Data loss is: 0.03248278424143791
# Physicial loss of p is: 0.010761442594230175
# Physicial loss of s is: 1.0301858186721802
# Iteration is: 120
# Data loss is: 0.03156586363911629
# Physicial loss of p is: 0.012372169643640518
# Physicial loss of s is: 1.0269372463226318
# Iteration is: 130
# Data loss is: 0.030637042596936226
# Physicial loss of p is: 0.014308998361229897
# Physicial loss of s is: 1.0198880434036255
# Iteration is: 140
# Data loss is: 0.029705652967095375
# Physicial loss of p is: 0.017244931310415268
# Physicial loss of s is: 1.0106894969940186
# Iteration is: 150
# Data loss is: 0.0287923626601696
# Physicial loss of p is: 0.01639697700738907
# Physicial loss of s is: 1.0009056329727173
# Iteration is: 160
# Data loss is: 0.027912374585866928
# Physicial loss of p is: 0.00963300745934248
# Physicial loss of s is: 0.991935670375824
# Iteration is: 170
# Data loss is: 0.027076145634055138
# Physicial loss of p is: 0.00595405139029026
# Physicial loss of s is: 0.9835451245307922
# Iteration is: 180
# Data loss is: 0.026292230933904648
# Physicial loss of p is: 0.004469013307243586
# Physicial loss of s is: 0.9775882959365845
# Iteration is: 190
# Data loss is: 0.025566279888153076
# Physicial loss of p is: 0.003960713278502226
# Physicial loss of s is: 0.975530743598938
# Iteration is: 200
# Data loss is: 0.024898339062929153
# Physicial loss of p is: 0.004269035533070564
# Physicial loss of s is: 0.9787137508392334
# Iteration is: 210
# Data loss is: 0.024284126237034798
# Physicial loss of p is: 0.004088031593710184
# Physicial loss of s is: 0.9893388748168945
# Iteration is: 220
# Data loss is: 0.023716766387224197
# Physicial loss of p is: 0.004383362364023924
# Physicial loss of s is: 1.0093162059783936
# Iteration is: 230
# Data loss is: 0.023187784478068352
# Physicial loss of p is: 0.004878676030784845
# Physicial loss of s is: 1.040337324142456
# Iteration is: 240
# Data loss is: 0.022687507793307304
# Physicial loss of p is: 0.006179518532007933
# Physicial loss of s is: 1.0820165872573853
# Iteration is: 250
# Data loss is: 0.022206151857972145
# Physicial loss of p is: 0.006416513118892908
# Physicial loss of s is: 1.130920171737671
# Iteration is: 260
# Data loss is: 0.02173435129225254
# Physicial loss of p is: 0.007413760293275118
# Physicial loss of s is: 1.1801769733428955
# Iteration is: 270
# Data loss is: 0.02126353792846203
# Physicial loss of p is: 0.00823292974382639
# Physicial loss of s is: 1.221866250038147
# Iteration is: 280
# Data loss is: 0.020786209031939507
# Physicial loss of p is: 0.009485028684139252
# Physicial loss of s is: 1.2513054609298706
# Iteration is: 290
# Data loss is: 0.020296111702919006
# Physicial loss of p is: 0.010345211252570152
# Physicial loss of s is: 1.2694357633590698
# Iteration is: 300
# Data loss is: 0.01978830248117447
# Physicial loss of p is: 0.011651195585727692
# Physicial loss of s is: 1.2805551290512085
# Iteration is: 310
# Data loss is: 0.019259236752986908
# Physicial loss of p is: 0.013201321475207806
# Physicial loss of s is: 1.2883471250534058
# Iteration is: 320
# Data loss is: 0.01870683580636978
# Physicial loss of p is: 0.016432244330644608
# Physicial loss of s is: 1.2942454814910889
# Iteration is: 330
# Data loss is: 0.018130581825971603
# Physicial loss of p is: 0.01850896328687668
# Physicial loss of s is: 1.2981560230255127
# Iteration is: 340
# Data loss is: 0.017531555145978928
# Physicial loss of p is: 0.01941940188407898
# Physicial loss of s is: 1.2996021509170532
# Iteration is: 350
# Data loss is: 0.016912374645471573
# Physicial loss of p is: 0.022862091660499573
# Physicial loss of s is: 1.298367977142334
# Iteration is: 360
# Data loss is: 0.0162770114839077
# Physicial loss of p is: 0.026350533589720726
# Physicial loss of s is: 1.2947460412979126
# Iteration is: 370
# Data loss is: 0.0156304482370615
# Physicial loss of p is: 0.029693441465497017
# Physicial loss of s is: 1.2895630598068237
# Iteration is: 380
# Data loss is: 0.014978185296058655
# Physicial loss of p is: 0.03546230122447014
# Physicial loss of s is: 1.2840219736099243
# Iteration is: 390
# Data loss is: 0.014325781725347042
# Physicial loss of p is: 0.03947071731090546
# Physicial loss of s is: 1.2794241905212402
# Iteration is: 400
# Data loss is: 0.013678474351763725
# Physicial loss of p is: 0.044864729046821594
# Physicial loss of s is: 1.276915192604065
# Iteration is: 410
# Data loss is: 0.01304100826382637
# Physicial loss of p is: 0.0518711619079113
# Physicial loss of s is: 1.277339220046997
# Iteration is: 420
# Data loss is: 0.01241761539131403
# Physicial loss of p is: 0.05769732594490051
# Physicial loss of s is: 1.2811933755874634
# Iteration is: 430
# Data loss is: 0.011812099255621433
# Physicial loss of p is: 0.06463125348091125
# Physicial loss of s is: 1.2886323928833008
# Iteration is: 440
# Data loss is: 0.011227822862565517
# Physicial loss of p is: 0.07266449183225632
# Physicial loss of s is: 1.2995048761367798
# Iteration is: 450
# Data loss is: 0.010667549446225166
# Physicial loss of p is: 0.08034949004650116
# Physicial loss of s is: 1.3134105205535889
# Iteration is: 460
# Data loss is: 0.010133213363587856
# Physicial loss of p is: 0.08903685957193375
# Physicial loss of s is: 1.329805612564087
# Iteration is: 470
# Data loss is: 0.009625730104744434
# Physicial loss of p is: 0.0977078527212143
# Physicial loss of s is: 1.3481221199035645
# Iteration is: 480
# Data loss is: 0.009144958108663559
# Physicial loss of p is: 0.10690351575613022
# Physicial loss of s is: 1.3678827285766602
# Iteration is: 490
# Data loss is: 0.008689855225384235
# Physicial loss of p is: 0.11727995425462723
# Physicial loss of s is: 1.3887500762939453
# Iteration is: 500
# Data loss is: 0.008258813992142677
# Physicial loss of p is: 0.12683704495429993
# Physicial loss of s is: 1.4105420112609863
# Iteration is: 510
# Data loss is: 0.00785013660788536
# Physicial loss of p is: 0.13954821228981018
# Physicial loss of s is: 1.4332045316696167
# Iteration is: 520
# Data loss is: 0.0074625760316848755
# Physicial loss of p is: 0.14953014254570007
# Physicial loss of s is: 1.456784963607788
# Iteration is: 530
# Data loss is: 0.007095824461430311
# Physicial loss of p is: 0.16367964446544647
# Physicial loss of s is: 1.4814039468765259
# Iteration is: 540
# Data loss is: 0.006750824395567179
# Physicial loss of p is: 0.17498214542865753
# Physicial loss of s is: 1.5072247982025146
# Iteration is: 550
# Data loss is: 0.0064296601340174675
# Physicial loss of p is: 0.1901833564043045
# Physicial loss of s is: 1.5344470739364624
# Iteration is: 560
# Data loss is: 0.006134976167231798
# Physicial loss of p is: 0.20284555852413177
# Physicial loss of s is: 1.5632598400115967
# Iteration is: 570
# Data loss is: 0.005869063548743725
# Physicial loss of p is: 0.21790368854999542
# Physicial loss of s is: 1.5938042402267456
# Iteration is: 580
# Data loss is: 0.005633019842207432
# Physicial loss of p is: 0.23238994181156158
# Physicial loss of s is: 1.6260995864868164
# Iteration is: 590
# Data loss is: 0.005426324438303709
# Physicial loss of p is: 0.2463536411523819
# Physicial loss of s is: 1.6600035429000854
# Iteration is: 600
# Data loss is: 0.005246961489319801
# Physicial loss of p is: 0.26138854026794434
# Physicial loss of s is: 1.695192575454712
# Iteration is: 610
# Data loss is: 0.00509188137948513
# Physicial loss of p is: 0.2734321653842926
# Physicial loss of s is: 1.7312252521514893
# Iteration is: 620
# Data loss is: 0.0049575637094676495
# Physicial loss of p is: 0.2871805429458618
# Physicial loss of s is: 1.7676105499267578
# Iteration is: 630
# Data loss is: 0.004840479698032141
# Physicial loss of p is: 0.29803377389907837
# Physicial loss of s is: 1.8039088249206543
# Iteration is: 640
# Data loss is: 0.004737414885312319
# Physicial loss of p is: 0.31075018644332886
# Physicial loss of s is: 1.8397666215896606
# Iteration is: 650
# Data loss is: 0.004645623732358217
# Physicial loss of p is: 0.3203372359275818
# Physicial loss of s is: 1.8749767541885376
# Iteration is: 660
# Data loss is: 0.004562865477055311
# Physicial loss of p is: 0.33162641525268555
# Physicial loss of s is: 1.9094305038452148
# Iteration is: 670
# Data loss is: 0.004487381782382727
# Physicial loss of p is: 0.34058523178100586
# Physicial loss of s is: 1.943126916885376
# Iteration is: 680
# Data loss is: 0.004417811054736376
# Physicial loss of p is: 0.34487396478652954
# Physicial loss of s is: 1.9761238098144531
# Iteration is: 690
# Data loss is: 0.004353102296590805
# Physicial loss of p is: 0.30356961488723755
# Physicial loss of s is: 2.0081253051757812
# Iteration is: 700
# Data loss is: 0.004292427096515894
# Physicial loss of p is: 0.2771049737930298
# Physicial loss of s is: 2.0395209789276123
# Iteration is: 710
# Data loss is: 0.004235161002725363
# Physicial loss of p is: 0.2637490928173065
# Physicial loss of s is: 2.070513963699341
# Iteration is: 720
# Data loss is: 0.004180846735835075
# Physicial loss of p is: 0.2601032257080078
# Physicial loss of s is: 2.1011266708374023
# Iteration is: 730
# Data loss is: 0.004129109438508749
# Physicial loss of p is: 0.25811800360679626
# Physicial loss of s is: 2.1317741870880127
# Iteration is: 740
# Data loss is: 0.004079628735780716
# Physicial loss of p is: 0.2540997564792633
# Physicial loss of s is: 2.162450075149536
# Iteration is: 750
# Data loss is: 0.004032153636217117
# Physicial loss of p is: 0.2514917552471161
# Physicial loss of s is: 2.1931612491607666
# Iteration is: 760
# Data loss is: 0.003986482508480549
# Physicial loss of p is: 0.24913974106311798
# Physicial loss of s is: 2.22391414642334
# Iteration is: 770
# Data loss is: 0.003942437004297972
# Physicial loss of p is: 0.24582016468048096
# Physicial loss of s is: 2.25472092628479
# Iteration is: 780
# Data loss is: 0.003899871837347746
# Physicial loss of p is: 0.24131672084331512
# Physicial loss of s is: 2.2856101989746094
# Iteration is: 790
# Data loss is: 0.0038586673326790333
# Physicial loss of p is: 0.23911301791667938
# Physicial loss of s is: 2.3165829181671143
# Iteration is: 800
# Data loss is: 0.0038187226746231318
# Physicial loss of p is: 0.2437761276960373
# Physicial loss of s is: 2.347656726837158
# Iteration is: 810
# Data loss is: 0.003779947990551591
# Physicial loss of p is: 0.23262830078601837
# Physicial loss of s is: 2.378833293914795
# Iteration is: 820
# Data loss is: 0.0037422606255859137
# Physicial loss of p is: 0.20720326900482178
# Physicial loss of s is: 2.4100120067596436
# Iteration is: 830
# Data loss is: 0.0037056365981698036
# Physicial loss of p is: 0.2290947288274765
# Physicial loss of s is: 2.4413046836853027
# Iteration is: 840
# Data loss is: 0.003670041449368
# Physicial loss of p is: 0.2002142071723938
# Physicial loss of s is: 2.4722635746002197
# Iteration is: 850
# Data loss is: 0.003635326400399208
# Physicial loss of p is: 0.19157850742340088
# Physicial loss of s is: 2.5036206245422363
# Iteration is: 860
# Data loss is: 0.0036014874931424856
# Physicial loss of p is: 0.1922779679298401
# Physicial loss of s is: 2.534766912460327
# Iteration is: 870
# Data loss is: 0.0035684911999851465
# Physicial loss of p is: 0.1913064867258072
# Physicial loss of s is: 2.565701484680176
# Iteration is: 880
# Data loss is: 0.003536313772201538
# Physicial loss of p is: 0.19190719723701477
# Physicial loss of s is: 2.5965070724487305
# Iteration is: 890
# Data loss is: 0.0035049228463321924
# Physicial loss of p is: 0.19144071638584137
# Physicial loss of s is: 2.6271073818206787
# Iteration is: 900
# Data loss is: 0.0034742928110063076
# Physicial loss of p is: 0.19155414402484894
# Physicial loss of s is: 2.657496929168701
# Iteration is: 910
# Data loss is: 0.0034443992190063
# Physicial loss of p is: 0.1917116343975067
# Physicial loss of s is: 2.6876468658447266
# Iteration is: 920
# Data loss is: 0.0034152166917920113
# Physicial loss of p is: 0.1919625848531723
# Physicial loss of s is: 2.717515230178833
# Iteration is: 930
# Data loss is: 0.0033867228776216507
# Physicial loss of p is: 0.19220006465911865
# Physicial loss of s is: 2.7470812797546387
# Iteration is: 940
# Data loss is: 0.0033588975202292204
# Physicial loss of p is: 0.1925182193517685
# Physicial loss of s is: 2.7762930393218994
# Iteration is: 950
# Data loss is: 0.003331718035042286
# Physicial loss of p is: 0.1927207112312317
# Physicial loss of s is: 2.8051304817199707
# Iteration is: 960
# Data loss is: 0.0033051669597625732
# Physicial loss of p is: 0.19296948611736298
# Physicial loss of s is: 2.8335421085357666
# Iteration is: 970
# Data loss is: 0.003279224969446659
# Physicial loss of p is: 0.19318456947803497
# Physicial loss of s is: 2.861499309539795
# Iteration is: 980
# Data loss is: 0.003253870876505971
# Physicial loss of p is: 0.19339574873447418
# Physicial loss of s is: 2.888969898223877
# Iteration is: 990
# Data loss is: 0.0032290893141180277
# Physicial loss of p is: 0.19358175992965698
# Physicial loss of s is: 2.915922164916992
# Iteration is: 1000
# Data loss is: 0.003204864449799061
# Physicial loss of p is: 0.193742573261261
# Physicial loss of s is: 2.94231915473938
# Iteration is: 1010
# Data loss is: 0.0031811778899282217
# Physicial loss of p is: 0.19387294352054596
# Physicial loss of s is: 2.9681308269500732
# Iteration is: 1020
# Data loss is: 0.0031580133363604546
# Physicial loss of p is: 0.19396260380744934
# Physicial loss of s is: 2.993325710296631
# Iteration is: 1030
# Data loss is: 0.003135356353595853
# Physicial loss of p is: 0.19400320947170258
# Physicial loss of s is: 3.017869472503662
# Iteration is: 1040
# Data loss is: 0.003113191807642579
# Physicial loss of p is: 0.19398710131645203
# Physicial loss of s is: 3.0417356491088867
# Iteration is: 1050
# Data loss is: 0.003091506427153945
# Physicial loss of p is: 0.19390831887722015
# Physicial loss of s is: 3.064894914627075
# Iteration is: 1060
# Data loss is: 0.003070285078138113
# Physicial loss of p is: 0.19376567006111145
# Physicial loss of s is: 3.0873124599456787
# Iteration is: 1070
# Data loss is: 0.0030495156534016132
# Physicial loss of p is: 0.1935681700706482
# Physicial loss of s is: 3.1089608669281006
# Iteration is: 1080
# Data loss is: 0.0030291860457509756
# Physicial loss of p is: 0.19319738447666168
# Physicial loss of s is: 3.129817485809326
# Iteration is: 1090
# Data loss is: 0.0030092881061136723
# Physicial loss of p is: 0.19315415620803833
# Physicial loss of s is: 3.1501264572143555
# Iteration is: 1100
# Data loss is: 0.0029898062348365784
# Physicial loss of p is: 0.19308122992515564
# Physicial loss of s is: 3.168813705444336
# Iteration is: 1110
# Data loss is: 0.0029707218054682016
# Physicial loss of p is: 0.19336365163326263
# Physicial loss of s is: 3.187459945678711
# Iteration is: 1120
# Data loss is: 0.002952027367427945
# Physicial loss of p is: 0.19299060106277466
# Physicial loss of s is: 3.204832077026367
# Iteration is: 1130
# Data loss is: 0.0029337143059819937
# Physicial loss of p is: 0.19293156266212463
# Physicial loss of s is: 3.221219062805176
# Iteration is: 1140
# Data loss is: 0.002915774006396532
# Physicial loss of p is: 0.19281171262264252
# Physicial loss of s is: 3.236809492111206
# Iteration is: 1150
# Data loss is: 0.002898194594308734
# Physicial loss of p is: 0.1930721551179886
# Physicial loss of s is: 3.251356363296509
# Iteration is: 1160
# Data loss is: 0.0028809646610170603
# Physicial loss of p is: 0.1932574361562729
# Physicial loss of s is: 3.264885663986206
# Iteration is: 1170
# Data loss is: 0.002864076057448983
# Physicial loss of p is: 0.1930670589208603
# Physicial loss of s is: 3.2774417400360107
# Iteration is: 1180
# Data loss is: 0.0028475183062255383
# Physicial loss of p is: 0.19326741993427277
# Physicial loss of s is: 3.2889530658721924
# Iteration is: 1190
# Data loss is: 0.0028312825597822666
# Physicial loss of p is: 0.1932455450296402
# Physicial loss of s is: 3.299415349960327
# Iteration is: 1200
# Data loss is: 0.0028153597377240658
# Physicial loss of p is: 0.19330686330795288
# Physicial loss of s is: 3.308786392211914
# Iteration is: 1210
# Data loss is: 0.0027997412253171206
# Physicial loss of p is: 0.19335831701755524
# Physicial loss of s is: 3.317060947418213
# Iteration is: 1220
# Data loss is: 0.0027844165451824665
# Physicial loss of p is: 0.19337786734104156
# Physicial loss of s is: 3.3242335319519043
# Iteration is: 1230
# Data loss is: 0.0027693777810782194
# Physicial loss of p is: 0.19336482882499695
# Physicial loss of s is: 3.330284833908081
# Iteration is: 1240
# Data loss is: 0.0027546174824237823
# Physicial loss of p is: 0.19332869350910187
# Physicial loss of s is: 3.3351948261260986
# Iteration is: 1250
# Data loss is: 0.00274012447334826
# Physicial loss of p is: 0.19326789677143097
# Physicial loss of s is: 3.338953971862793
# Iteration is: 1260
# Data loss is: 0.002725892001762986
# Physicial loss of p is: 0.19318461418151855
# Physicial loss of s is: 3.3415491580963135
# Iteration is: 1270
# Data loss is: 0.002711912151426077
# Physicial loss of p is: 0.19307801127433777
# Physicial loss of s is: 3.3429675102233887
# Iteration is: 1280
# Data loss is: 0.0026981753762811422
# Physicial loss of p is: 0.192953422665596
# Physicial loss of s is: 3.3432042598724365
# Iteration is: 1290
# Data loss is: 0.00268467515707016
# Physicial loss of p is: 0.19281412661075592
# Physicial loss of s is: 3.3422608375549316
# Iteration is: 1300
# Data loss is: 0.002671402646228671
# Physicial loss of p is: 0.19265802204608917
# Physicial loss of s is: 3.340121030807495
# Iteration is: 1310
# Data loss is: 0.002658350160345435
# Physicial loss of p is: 0.19248999655246735
# Physicial loss of s is: 3.336758613586426
# Iteration is: 1320
# Data loss is: 0.002645509783178568
# Physicial loss of p is: 0.19230930507183075
# Physicial loss of s is: 3.3321902751922607
# Iteration is: 1330
# Data loss is: 0.0026328747626394033
# Physicial loss of p is: 0.19211633503437042
# Physicial loss of s is: 3.326460123062134
# Iteration is: 1340
# Data loss is: 0.0026204369496554136
# Physicial loss of p is: 0.19191180169582367
# Physicial loss of s is: 3.319499969482422
# Iteration is: 1350
# Data loss is: 0.0026081895921379328
# Physicial loss of p is: 0.1916951835155487
# Physicial loss of s is: 3.311328411102295
# Iteration is: 1360
# Data loss is: 0.0025961254723370075
# Physicial loss of p is: 0.19146744906902313
# Physicial loss of s is: 3.302001476287842
# Iteration is: 1370
# Data loss is: 0.0025842373725026846
# Physicial loss of p is: 0.1912268102169037
# Physicial loss of s is: 3.2914633750915527
# Iteration is: 1380
# Data loss is: 0.0025725180748850107
# Physicial loss of p is: 0.19093099236488342
# Physicial loss of s is: 3.279759407043457
# Iteration is: 1390
# Data loss is: 0.0025609612930566072
# Physicial loss of p is: 0.1903173327445984
# Physicial loss of s is: 3.2667925357818604
# Iteration is: 1400
# Data loss is: 0.0025495649315416813
# Physicial loss of p is: 0.1923920065164566
# Physicial loss of s is: 3.251649856567383
# Iteration is: 1410
# Data loss is: 0.0025383159518241882
# Physicial loss of p is: 0.19130085408687592
# Physicial loss of s is: 3.237067461013794
# Iteration is: 1420
# Data loss is: 0.0025272094644606113
# Physicial loss of p is: 0.19102081656455994
# Physicial loss of s is: 3.2210593223571777
# Iteration is: 1430
# Data loss is: 0.002516239881515503
# Physicial loss of p is: 0.19028408825397491
# Physicial loss of s is: 3.2030029296875
# Iteration is: 1440
# Data loss is: 0.0025054123252630234
# Physicial loss of p is: 0.18952155113220215
# Physicial loss of s is: 3.1788368225097656
# Iteration is: 1450
# Data loss is: 0.002495120745152235
# Physicial loss of p is: 0.1881994903087616
# Physicial loss of s is: 3.1127026081085205
# Iteration is: 1460
# Data loss is: 0.0024843765422701836
# Physicial loss of p is: 0.19149252772331238
# Physicial loss of s is: 3.1851959228515625
# Iteration is: 1470
# Data loss is: 0.0024738789070397615
# Physicial loss of p is: 0.18803717195987701
# Physicial loss of s is: 3.1102817058563232
# Iteration is: 1480
# Data loss is: 0.002463539596647024
# Physicial loss of p is: 0.1878645122051239
# Physicial loss of s is: 3.093690872192383
# Iteration is: 1490
# Data loss is: 0.002453278051689267
# Physicial loss of p is: 0.18848830461502075
# Physicial loss of s is: 3.090205192565918
# Iteration is: 1500
# Data loss is: 0.0024431466590613127
# Physicial loss of p is: 0.18750923871994019
# Physicial loss of s is: 3.058985471725464
# Iteration is: 1510
# Data loss is: 0.0024331004824489355
# Physicial loss of p is: 0.18708907067775726
# Physicial loss of s is: 3.0340030193328857
# Iteration is: 1520
# Data loss is: 0.0024231343995779753
# Physicial loss of p is: 0.18706735968589783
# Physicial loss of s is: 3.0137221813201904
# Iteration is: 1530
# Data loss is: 0.00241327122785151
# Physicial loss of p is: 0.18644772469997406
# Physicial loss of s is: 2.9858522415161133
# Iteration is: 1540
# Data loss is: 0.0024034820962697268
# Physicial loss of p is: 0.18626590073108673
# Physicial loss of s is: 2.9620983600616455
# Iteration is: 1550
# Data loss is: 0.0023937791120260954
# Physicial loss of p is: 0.18614161014556885
# Physicial loss of s is: 2.935199737548828
# Iteration is: 1560
# Data loss is: 0.0023841490037739277
# Physicial loss of p is: 0.18577153980731964
# Physicial loss of s is: 2.9084770679473877
# Iteration is: 1570
# Data loss is: 0.002374588744714856
# Physicial loss of p is: 0.1874290108680725
# Physicial loss of s is: 2.8817694187164307
# Iteration is: 1580
# Data loss is: 0.002365092048421502
# Physicial loss of p is: 0.18432585895061493
# Physicial loss of s is: 2.8560173511505127
# Iteration is: 1590
# Data loss is: 0.0023556610103696585
# Physicial loss of p is: 0.1853734403848648
# Physicial loss of s is: 2.8322715759277344
# Iteration is: 1600
# Data loss is: 0.002346397377550602
# Physicial loss of p is: 0.1870998591184616
# Physicial loss of s is: 2.8276255130767822
# Iteration is: 1610
# Data loss is: 0.002337106503546238
# Physicial loss of p is: 0.18619967997074127
# Physicial loss of s is: 2.780963897705078
# Iteration is: 1620
# Data loss is: 0.002327956259250641
# Physicial loss of p is: 0.18410491943359375
# Physicial loss of s is: 2.739154100418091
# Iteration is: 1630
# Data loss is: 0.0023188109043985605
# Physicial loss of p is: 0.18331611156463623
# Physicial loss of s is: 2.707733631134033
# Iteration is: 1640
# Data loss is: 0.002309646224603057
# Physicial loss of p is: 0.1830994188785553
# Physicial loss of s is: 2.6872751712799072
# Iteration is: 1650
# Data loss is: 0.0023005688562989235
# Physicial loss of p is: 0.1824677735567093
# Physicial loss of s is: 2.6544711589813232
# Iteration is: 1660
# Data loss is: 0.002291514305397868
# Physicial loss of p is: 0.18223358690738678
# Physicial loss of s is: 2.6265335083007812
# Iteration is: 1670
# Data loss is: 0.002282490022480488
# Physicial loss of p is: 0.18255312740802765
# Physicial loss of s is: 2.601818084716797
# Iteration is: 1680
# Data loss is: 0.0022735369857400656
# Physicial loss of p is: 0.18279105424880981
# Physicial loss of s is: 2.5719845294952393
# Iteration is: 1690
# Data loss is: 0.002264621900394559
# Physicial loss of p is: 0.18336832523345947
# Physicial loss of s is: 2.543724298477173
# Iteration is: 1700
# Data loss is: 0.002255737781524658
# Physicial loss of p is: 0.18248526751995087
# Physicial loss of s is: 2.5172314643859863
# Iteration is: 1710
# Data loss is: 0.00224687228910625
# Physicial loss of p is: 0.18155483901500702
# Physicial loss of s is: 2.4967360496520996
# Iteration is: 1720
# Data loss is: 0.002238749759271741
# Physicial loss of p is: 0.18598151206970215
# Physicial loss of s is: 2.517426013946533
# Iteration is: 1730
# Data loss is: 0.0022305345628410578
# Physicial loss of p is: 0.1793539822101593
# Physicial loss of s is: 2.3945815563201904
# Iteration is: 1740
# Data loss is: 0.00222109560854733
# Physicial loss of p is: 0.1798059344291687
# Physicial loss of s is: 2.4129066467285156
# Iteration is: 1750
# Data loss is: 0.002212467836216092
# Physicial loss of p is: 0.1798148900270462
# Physicial loss of s is: 2.393815279006958
# Iteration is: 1760
# Data loss is: 0.0022039925679564476
# Physicial loss of p is: 0.1794930249452591
# Physicial loss of s is: 2.351123094558716
# Iteration is: 1770
# Data loss is: 0.002195330336689949
# Physicial loss of p is: 0.17963582277297974
# Physicial loss of s is: 2.3320460319519043
# Iteration is: 1780
# Data loss is: 0.00218675984069705
# Physicial loss of p is: 0.17946235835552216
# Physicial loss of s is: 2.310698986053467
# Iteration is: 1790
# Data loss is: 0.002178305061534047
# Physicial loss of p is: 0.1788841336965561
# Physicial loss of s is: 2.283033609390259
# Iteration is: 1800
# Data loss is: 0.0021698246710002422
# Physicial loss of p is: 0.17902375757694244
# Physicial loss of s is: 2.2619845867156982
# Iteration is: 1810
# Data loss is: 0.002161439275369048
# Physicial loss of p is: 0.17872977256774902
# Physicial loss of s is: 2.2372243404388428
# Iteration is: 1820
# Data loss is: 0.0021530832163989544
# Physicial loss of p is: 0.17829826474189758
# Physicial loss of s is: 2.214085817337036
# Iteration is: 1830
# Data loss is: 0.0021447688341140747
# Physicial loss of p is: 0.17775732278823853
# Physicial loss of s is: 2.1915228366851807
# Iteration is: 1840
# Data loss is: 0.002136525698006153
# Physicial loss of p is: 0.17764124274253845
# Physicial loss of s is: 2.1677067279815674
# Iteration is: 1850
# Data loss is: 0.002128364285454154
# Physicial loss of p is: 0.1774187535047531
# Physicial loss of s is: 2.1422805786132812
# Iteration is: 1860
# Data loss is: 0.002120859920978546
# Physicial loss of p is: 0.1770637482404709
# Physicial loss of s is: 2.099541425704956
# Iteration is: 1870
# Data loss is: 0.0021130796521902084
# Physicial loss of p is: 0.17754536867141724
# Physicial loss of s is: 2.0789151191711426
# Iteration is: 1880
# Data loss is: 0.002104766434058547
# Physicial loss of p is: 0.1781373769044876
# Physicial loss of s is: 2.069532871246338
# Iteration is: 1890
# Data loss is: 0.002096550539135933
# Physicial loss of p is: 0.18047140538692474
# Physicial loss of s is: 2.074702262878418
# Iteration is: 1900
# Data loss is: 0.0020888689905405045
# Physicial loss of p is: 0.17684856057167053
# Physicial loss of s is: 2.0330426692962646
# Iteration is: 1910
# Data loss is: 0.0020808414556086063
# Physicial loss of p is: 0.17699696123600006
# Physicial loss of s is: 2.0196685791015625
# Iteration is: 1920
# Data loss is: 0.0020730076357722282
# Physicial loss of p is: 0.17679694294929504
# Physicial loss of s is: 2.001129388809204
# Iteration is: 1930
# Data loss is: 0.0020652986131608486
# Physicial loss of p is: 0.1773713231086731
# Physicial loss of s is: 1.9797241687774658
# Iteration is: 1940
# Data loss is: 0.0020576096139848232
# Physicial loss of p is: 0.1761503368616104
# Physicial loss of s is: 1.960561752319336
# Iteration is: 1950
# Data loss is: 0.002049982314929366
# Physicial loss of p is: 0.17612594366073608
# Physicial loss of s is: 1.9418963193893433
# Iteration is: 1960
# Data loss is: 0.002042473526671529
# Physicial loss of p is: 0.1767517477273941
# Physicial loss of s is: 1.9210829734802246
# Iteration is: 1970
# Data loss is: 0.0020350120030343533
# Physicial loss of p is: 0.18009671568870544
# Physicial loss of s is: 1.901399850845337
# Iteration is: 1980
# Data loss is: 0.0020276266150176525
# Physicial loss of p is: 0.17543062567710876
# Physicial loss of s is: 1.8810921907424927
# Iteration is: 1990
# Data loss is: 0.002020770451053977
# Physicial loss of p is: 0.1752210259437561
# Physicial loss of s is: 1.8499367237091064
# Iteration is: 2000
# Data loss is: 0.0020199634600430727
# Physicial loss of p is: 0.1824912130832672
# Physicial loss of s is: 1.78597891330719
# Iteration is: 2010
# Data loss is: 0.0020065384451299906
# Physicial loss of p is: 0.17541567981243134
# Physicial loss of s is: 1.83133864402771
# Iteration is: 2020
# Data loss is: 0.002000069711357355
# Physicial loss of p is: 0.17911863327026367
# Physicial loss of s is: 1.824120283126831
# Iteration is: 2030
# Data loss is: 0.0019928726833313704
# Physicial loss of p is: 0.1765175610780716
# Physicial loss of s is: 1.784291386604309
# Iteration is: 2040
# Data loss is: 0.001986125251278281
# Physicial loss of p is: 0.1754072904586792
# Physicial loss of s is: 1.7633289098739624
# Iteration is: 2050
# Data loss is: 0.001978896325454116
# Physicial loss of p is: 0.1758599728345871
# Physicial loss of s is: 1.7553187608718872
# Iteration is: 2060
# Data loss is: 0.00197223131544888
# Physicial loss of p is: 0.175535187125206
# Physicial loss of s is: 1.733152151107788
# Iteration is: 2070
# Data loss is: 0.0019655590876936913
# Physicial loss of p is: 0.17551979422569275
# Physicial loss of s is: 1.7154409885406494
# Iteration is: 2080
# Data loss is: 0.001958975801244378
# Physicial loss of p is: 0.17517031729221344
# Physicial loss of s is: 1.6976169347763062
# Iteration is: 2090
# Data loss is: 0.00195248459931463
# Physicial loss of p is: 0.17539583146572113
# Physicial loss of s is: 1.6794118881225586
# Iteration is: 2100
# Data loss is: 0.001946100383065641
# Physicial loss of p is: 0.17508350312709808
# Physicial loss of s is: 1.6604012250900269
# Iteration is: 2110
# Data loss is: 0.0019397716969251633
# Physicial loss of p is: 0.1746107041835785
# Physicial loss of s is: 1.642317533493042
# Iteration is: 2120
# Data loss is: 0.001933543011546135
# Physicial loss of p is: 0.1807122677564621
# Physicial loss of s is: 1.6236052513122559
# Iteration is: 2130
# Data loss is: 0.0019274433143436909
# Physicial loss of p is: 0.17413310706615448
# Physicial loss of s is: 1.6034809350967407
# Iteration is: 2140
# Data loss is: 0.001922189723700285
# Physicial loss of p is: 0.17524175345897675
# Physicial loss of s is: 1.574965000152588
# Iteration is: 2150
# Data loss is: 0.001938109751790762
# Physicial loss of p is: 0.1723182648420334
# Physicial loss of s is: 1.5085031986236572
# Iteration is: 2160
# Data loss is: 0.0019133968744426966
# Physicial loss of p is: 0.17598624527454376
# Physicial loss of s is: 1.5638586282730103
# Iteration is: 2170
# Data loss is: 0.0019073843723163009
# Physicial loss of p is: 0.17591038346290588
# Physicial loss of s is: 1.5462285280227661
# Iteration is: 2180
# Data loss is: 0.0018996447324752808
# Physicial loss of p is: 0.17428836226463318
# Physicial loss of s is: 1.5064969062805176
# Iteration is: 2190
# Data loss is: 0.001894087647087872
# Physicial loss of p is: 0.17464357614517212
# Physicial loss of s is: 1.4897600412368774
# Iteration is: 2200
# Data loss is: 0.0018882519798353314
# Physicial loss of p is: 0.17465771734714508
# Physicial loss of s is: 1.4813742637634277
# Iteration is: 2210
# Data loss is: 0.0018828737083822489
# Physicial loss of p is: 0.17453768849372864
# Physicial loss of s is: 1.4591147899627686
# Iteration is: 2220
# Data loss is: 0.0018775429343804717
# Physicial loss of p is: 0.1752108633518219
# Physicial loss of s is: 1.4425115585327148
# Iteration is: 2230
# Data loss is: 0.0018724182154983282
# Physicial loss of p is: 0.18424451351165771
# Physicial loss of s is: 1.4251954555511475
# Iteration is: 2240
# Data loss is: 0.001867264392785728
# Physicial loss of p is: 0.17373019456863403
# Physicial loss of s is: 1.4077181816101074
# Iteration is: 2250
# Data loss is: 0.0018622145289555192
# Physicial loss of p is: 0.17425471544265747
# Physicial loss of s is: 1.3896747827529907
# Iteration is: 2260
# Data loss is: 0.0018572555854916573
# Physicial loss of p is: 0.17353057861328125
# Physicial loss of s is: 1.3726438283920288
# Iteration is: 2270
# Data loss is: 0.0018523900071159005
# Physicial loss of p is: 0.17367687821388245
# Physicial loss of s is: 1.3553155660629272
# Iteration is: 2280
# Data loss is: 0.001847594860009849
# Physicial loss of p is: 0.17373649775981903
# Physicial loss of s is: 1.3382974863052368
# Iteration is: 2290
# Data loss is: 0.0018430656054988503
# Physicial loss of p is: 0.17425093054771423
# Physicial loss of s is: 1.3243154287338257
# Iteration is: 2300
# Data loss is: 0.0018621470080688596
# Physicial loss of p is: 0.17582422494888306
# Physicial loss of s is: 1.3378217220306396
# Iteration is: 2310
# Data loss is: 0.001846893923357129
# Physicial loss of p is: 0.17208325862884521
# Physicial loss of s is: 1.2573903799057007
# Iteration is: 2320
# Data loss is: 0.0018346309661865234
# Physicial loss of p is: 0.17712350189685822
# Physicial loss of s is: 1.2811942100524902
# Iteration is: 2330
# Data loss is: 0.0018282170640304685
# Physicial loss of p is: 0.17432163655757904
# Physicial loss of s is: 1.2610541582107544
# Iteration is: 2340
# Data loss is: 0.001822741935029626
# Physicial loss of p is: 0.17458859086036682
# Physicial loss of s is: 1.2312840223312378
# Iteration is: 2350
# Data loss is: 0.0018187579698860645
# Physicial loss of p is: 0.1758602112531662
# Physicial loss of s is: 1.216002106666565
# Iteration is: 2360
# Data loss is: 0.0018138408195227385
# Physicial loss of p is: 0.17590239644050598
# Physicial loss of s is: 1.2063484191894531
# Iteration is: 2370
# Data loss is: 0.001809899928048253
# Physicial loss of p is: 0.17338880896568298
# Physicial loss of s is: 1.1881412267684937
# Iteration is: 2380
# Data loss is: 0.0018059611320495605
# Physicial loss of p is: 0.1739472895860672
# Physicial loss of s is: 1.1730828285217285
# Iteration is: 2390
# Data loss is: 0.0018021110445261002
# Physicial loss of p is: 0.17319878935813904
# Physicial loss of s is: 1.1581190824508667
# Iteration is: 2400
# Data loss is: 0.001798328710719943
# Physicial loss of p is: 0.17454147338867188
# Physicial loss of s is: 1.143109679222107
# Iteration is: 2410
# Data loss is: 0.0017946232110261917
# Physicial loss of p is: 0.1763862520456314
# Physicial loss of s is: 1.127577781677246
# Iteration is: 2420
# Data loss is: 0.0017909877933561802
# Physicial loss of p is: 0.17399273812770844
# Physicial loss of s is: 1.1129745244979858
# Iteration is: 2430
# Data loss is: 0.001787378336302936
# Physicial loss of p is: 0.17366071045398712
# Physicial loss of s is: 1.098281979560852
# Iteration is: 2440
# Data loss is: 0.0017838624771684408
# Physicial loss of p is: 0.17430035769939423
# Physicial loss of s is: 1.0837643146514893
# Iteration is: 2450
# Data loss is: 0.001781980856321752
# Physicial loss of p is: 0.1745644509792328
# Physicial loss of s is: 1.0712298154830933
# Iteration is: 2460
# Data loss is: 0.0017887945286929607
# Physicial loss of p is: 0.17594264447689056
# Physicial loss of s is: 1.071527123451233
# Iteration is: 2470
# Data loss is: 0.0017770194681361318
# Physicial loss of p is: 0.17627489566802979
# Physicial loss of s is: 1.055389642715454
# Iteration is: 2480
# Data loss is: 0.0017732273554429412
# Physicial loss of p is: 0.17363829910755157
# Physicial loss of s is: 1.034664273262024
# Iteration is: 2490
# Data loss is: 0.0017726343357935548
# Physicial loss of p is: 0.17272472381591797
# Physicial loss of s is: 1.0016140937805176
# Iteration is: 2500
# Data loss is: 0.0017655495321378112
# Physicial loss of p is: 0.1738211065530777
# Physicial loss of s is: 0.9998505115509033
# Iteration is: 2510
# Data loss is: 0.0017624406609684229
# Physicial loss of p is: 0.17396675050258636
# Physicial loss of s is: 0.9894132018089294
# Iteration is: 2520
# Data loss is: 0.0017599042039364576
# Physicial loss of p is: 0.17371530830860138
# Physicial loss of s is: 0.9720242023468018
# Iteration is: 2530
# Data loss is: 0.001756237936206162
# Physicial loss of p is: 0.17336107790470123
# Physicial loss of s is: 0.963355302810669
# Iteration is: 2540
# Data loss is: 0.0017533533973619342
# Physicial loss of p is: 0.17335374653339386
# Physicial loss of s is: 0.9491597414016724
# Iteration is: 2550
# Data loss is: 0.0017503591952845454
# Physicial loss of p is: 0.1730518341064453
# Physicial loss of s is: 0.9386498928070068
# Iteration is: 2560
# Data loss is: 0.0017475609201937914
# Physicial loss of p is: 0.17278139293193817
# Physicial loss of s is: 0.9261468052864075
# Iteration is: 2570
# Data loss is: 0.001744779641740024
# Physicial loss of p is: 0.17544260621070862
# Physicial loss of s is: 0.9146332144737244
# Iteration is: 2580
# Data loss is: 0.0017424792749807239
# Physicial loss of p is: 0.17794840037822723
# Physicial loss of s is: 0.9042708873748779
# Iteration is: 2590
# Data loss is: 0.0017395666800439358
# Physicial loss of p is: 0.17657263576984406
# Physicial loss of s is: 0.8946378827095032
# Iteration is: 2600
# Data loss is: 0.0017474022461101413
# Physicial loss of p is: 0.17372344434261322
# Physicial loss of s is: 0.8903672099113464
# Iteration is: 2610
# Data loss is: 0.0017498073866590858
# Physicial loss of p is: 0.17494997382164001
# Physicial loss of s is: 0.8920546174049377
# Iteration is: 2620
# Data loss is: 0.0017357772449031472
# Physicial loss of p is: 0.17197193205356598
# Physicial loss of s is: 0.8449497818946838
# Iteration is: 2630
# Data loss is: 0.001731573254801333
# Physicial loss of p is: 0.17275811731815338
# Physicial loss of s is: 0.8545333743095398
# Iteration is: 2640
# Data loss is: 0.0017302820924669504
# Physicial loss of p is: 0.17166362702846527
# Physicial loss of s is: 0.8330930471420288
# Iteration is: 2650
# Data loss is: 0.0017258354928344488
# Physicial loss of p is: 0.17232589423656464
# Physicial loss of s is: 0.8297472596168518
# Iteration is: 2660
# Data loss is: 0.0017227218486368656
# Physicial loss of p is: 0.17366157472133636
# Physicial loss of s is: 0.8167129755020142
# Iteration is: 2670
# Data loss is: 0.0017202005255967379
# Physicial loss of p is: 0.17159047722816467
# Physicial loss of s is: 0.8075689673423767
# Iteration is: 2680
# Data loss is: 0.0017177591798827052
# Physicial loss of p is: 0.17160989344120026
# Physicial loss of s is: 0.7993232607841492
# Iteration is: 2690
# Data loss is: 0.0017167067853733897
# Physicial loss of p is: 0.17167195677757263
# Physicial loss of s is: 0.7912483215332031
# Iteration is: 2700
# Data loss is: 0.0017166665056720376
# Physicial loss of p is: 0.1730392575263977
# Physicial loss of s is: 0.7860947251319885
# Iteration is: 2710
# Data loss is: 0.001742175780236721
# Physicial loss of p is: 0.17482350766658783
# Physicial loss of s is: 0.7903951406478882
# Iteration is: 2720
# Data loss is: 0.0017123661236837506
# Physicial loss of p is: 0.17666684091091156
# Physicial loss of s is: 0.7558792233467102
# Iteration is: 2730
# Data loss is: 0.0017076765652745962
# Physicial loss of p is: 0.17341096699237823
# Physicial loss of s is: 0.7562720775604248
# Iteration is: 2740
# Data loss is: 0.0017049225280061364
# Physicial loss of p is: 0.1704413890838623
# Physicial loss of s is: 0.7433765530586243
# Iteration is: 2750
# Data loss is: 0.0017029778100550175
# Physicial loss of p is: 0.17052724957466125
# Physicial loss of s is: 0.7361915111541748
# Iteration is: 2760
# Data loss is: 0.0017009243601933122
# Physicial loss of p is: 0.17000211775302887
# Physicial loss of s is: 0.7302960157394409
# Iteration is: 2770
# Data loss is: 0.0016985135152935982
# Physicial loss of p is: 0.17121662199497223
# Physicial loss of s is: 0.7202516198158264
# Iteration is: 2780
# Data loss is: 0.0016964804381132126
# Physicial loss of p is: 0.17071475088596344
# Physicial loss of s is: 0.7128258943557739
# Iteration is: 2790
# Data loss is: 0.0016953728627413511
# Physicial loss of p is: 0.17887605726718903
# Physicial loss of s is: 0.7052048444747925
# Iteration is: 2800
# Data loss is: 0.0016981699736788869
# Physicial loss of p is: 0.168128103017807
# Physicial loss of s is: 0.695592999458313
# Iteration is: 2810
# Data loss is: 0.0017076304648071527
# Physicial loss of p is: 0.16656985878944397
# Physicial loss of s is: 0.6779155135154724
# Iteration is: 2820
# Data loss is: 0.0016975029138848186
# Physicial loss of p is: 0.17071732878684998
# Physicial loss of s is: 0.6801113486289978
# Iteration is: 2830
# Data loss is: 0.0016888942336663604
# Physicial loss of p is: 0.17349374294281006
# Physicial loss of s is: 0.6736084222793579
# Iteration is: 2840
# Data loss is: 0.0016850319225341082
# Physicial loss of p is: 0.16802725195884705
# Physicial loss of s is: 0.6715202331542969
# Iteration is: 2850
# Data loss is: 0.0016843198100104928
# Physicial loss of p is: 0.166976660490036
# Physicial loss of s is: 0.6600566506385803
# Iteration is: 2860
# Data loss is: 0.0016818724106997252
# Physicial loss of p is: 0.16818968951702118
# Physicial loss of s is: 0.6571316123008728
# Iteration is: 2870
# Data loss is: 0.001679549808613956
# Physicial loss of p is: 0.1677606999874115
# Physicial loss of s is: 0.6491972804069519
# Iteration is: 2880
# Data loss is: 0.0016775192925706506
# Physicial loss of p is: 0.16639651358127594
# Physicial loss of s is: 0.643486499786377
# Iteration is: 2890
# Data loss is: 0.0016756344120949507
# Physicial loss of p is: 0.16628943383693695
# Physicial loss of s is: 0.6380638480186462
# Iteration is: 2900
# Data loss is: 0.0016737413825467229
# Physicial loss of p is: 0.16595733165740967
# Physicial loss of s is: 0.6318506002426147
# Iteration is: 2910
# Data loss is: 0.001672562095336616
# Physicial loss of p is: 0.17191313207149506
# Physicial loss of s is: 0.626167893409729
# Iteration is: 2920
# Data loss is: 0.0016724480083212256
# Physicial loss of p is: 0.16578003764152527
# Physicial loss of s is: 0.6215909719467163
# Iteration is: 2930
# Data loss is: 0.001678090775385499
# Physicial loss of p is: 0.16626299917697906
# Physicial loss of s is: 0.6211269497871399
# Iteration is: 2940
# Data loss is: 0.001699548913165927
# Physicial loss of p is: 0.17348971962928772
# Physicial loss of s is: 0.6240051984786987
# Iteration is: 2950
# Data loss is: 0.0016817409778013825
# Physicial loss of p is: 0.16308541595935822
# Physicial loss of s is: 0.5942946672439575
# Iteration is: 2960
# Data loss is: 0.001667427713982761
# Physicial loss of p is: 0.16495493054389954
# Physicial loss of s is: 0.5970831513404846
# Iteration is: 2970
# Data loss is: 0.0016622609691694379
# Physicial loss of p is: 0.1735299974679947
# Physicial loss of s is: 0.5916880369186401
# Iteration is: 2980
# Data loss is: 0.0016602720133960247
# Physicial loss of p is: 0.1648983210325241
# Physicial loss of s is: 0.5848211646080017
# Iteration is: 2990
# Data loss is: 0.0016585246194154024
# Physicial loss of p is: 0.16361647844314575
# Physicial loss of s is: 0.5815514922142029
# Iteration is: 3000
# Data loss is: 0.0016568161081522703
# Physicial loss of p is: 0.16287922859191895
# Physicial loss of s is: 0.5761218667030334
# Iteration is: 3010
# Data loss is: 0.0016551869921386242
# Physicial loss of p is: 0.16387389600276947
# Physicial loss of s is: 0.5714772939682007
# Iteration is: 3020
# Data loss is: 0.001653409330174327
# Physicial loss of p is: 0.16159850358963013
# Physicial loss of s is: 0.5670265555381775
# Iteration is: 3030
# Data loss is: 0.0016517400508746505
# Physicial loss of p is: 0.16121575236320496
# Physicial loss of s is: 0.5624380111694336
# Iteration is: 3040
# Data loss is: 0.0016512644942849874
# Physicial loss of p is: 0.17056430876255035
# Physicial loss of s is: 0.558300256729126
# Iteration is: 3050
# Data loss is: 0.001657067914493382
# Physicial loss of p is: 0.16528649628162384
# Physicial loss of s is: 0.5555808544158936
# Iteration is: 3060
# Data loss is: 0.0016550978180021048
# Physicial loss of p is: 0.16154038906097412
# Physicial loss of s is: 0.5558152794837952
# Iteration is: 3070
# Data loss is: 0.0016574612818658352
# Physicial loss of p is: 0.16606372594833374
# Physicial loss of s is: 0.5519432425498962
# Iteration is: 3080
# Data loss is: 0.0016495242016389966
# Physicial loss of p is: 0.15808573365211487
# Physicial loss of s is: 0.5344035029411316
# Iteration is: 3090
# Data loss is: 0.0016438878374174237
# Physicial loss of p is: 0.15987667441368103
# Physicial loss of s is: 0.5356668829917908
# Iteration is: 3100
# Data loss is: 0.0016410552198067307
# Physicial loss of p is: 0.1588166356086731
# Physicial loss of s is: 0.53001868724823
# Iteration is: 3110
# Data loss is: 0.001639538910239935
# Physicial loss of p is: 0.15759149193763733
# Physicial loss of s is: 0.5259015560150146
# Iteration is: 3120
# Data loss is: 0.0016378808068111539
# Physicial loss of p is: 0.15716271102428436
# Physicial loss of s is: 0.5224892497062683
# Iteration is: 3130
# Data loss is: 0.0016361315501853824
# Physicial loss of p is: 0.156862273812294
# Physicial loss of s is: 0.5191572308540344
# Iteration is: 3140
# Data loss is: 0.0016347531927749515
# Physicial loss of p is: 0.15614518523216248
# Physicial loss of s is: 0.515134871006012
# Iteration is: 3150
# Data loss is: 0.0016363536706194282
# Physicial loss of p is: 0.1584479659795761
# Physicial loss of s is: 0.5122807621955872
# Iteration is: 3160
# Data loss is: 0.0016776828560978174
# Physicial loss of p is: 0.1581527292728424
# Physicial loss of s is: 0.5138061046600342
# Iteration is: 3170
# Data loss is: 0.001630607875995338
# Physicial loss of p is: 0.16608011722564697
# Physicial loss of s is: 0.5104219913482666
# Iteration is: 3180
# Data loss is: 0.0016295101959258318
# Physicial loss of p is: 0.153187558054924
# Physicial loss of s is: 0.49414053559303284
# Iteration is: 3190
# Data loss is: 0.0016288579208776355
# Physicial loss of p is: 0.15386773645877838
# Physicial loss of s is: 0.49704286456108093
# Iteration is: 3200
# Data loss is: 0.0016275208909064531
# Physicial loss of p is: 0.152498260140419
# Physicial loss of s is: 0.49030986428260803
# Iteration is: 3210
# Data loss is: 0.0016244921134784818
# Physicial loss of p is: 0.15249504148960114
# Physicial loss of s is: 0.48818734288215637
# Iteration is: 3220
# Data loss is: 0.0016228863969445229
# Physicial loss of p is: 0.15208317339420319
# Physicial loss of s is: 0.48517879843711853
# Iteration is: 3230
# Data loss is: 0.0016214560018852353
# Physicial loss of p is: 0.15192767977714539
# Physicial loss of s is: 0.481381356716156
# Iteration is: 3240
# Data loss is: 0.0016199329402297735
# Physicial loss of p is: 0.15059106051921844
# Physicial loss of s is: 0.4778729975223541
# Iteration is: 3250
# Data loss is: 0.0016188276931643486
# Physicial loss of p is: 0.1503058522939682
# Physicial loss of s is: 0.4742251932621002
# Iteration is: 3260
# Data loss is: 0.0016284433659166098
# Physicial loss of p is: 0.16388998925685883
# Physicial loss of s is: 0.468215674161911
# Iteration is: 3270
# Data loss is: 0.0016513144364580512
# Physicial loss of p is: 0.14761003851890564
# Physicial loss of s is: 0.45664751529693604
# Iteration is: 3280
# Data loss is: 0.0016188373556360602
# Physicial loss of p is: 0.14991281926631927
# Physicial loss of s is: 0.47032591700553894
# Iteration is: 3290
# Data loss is: 0.0016170010203495622
# Physicial loss of p is: 0.1488378345966339
# Physicial loss of s is: 0.45754483342170715
# Iteration is: 3300
# Data loss is: 0.001613350585103035
# Physicial loss of p is: 0.14844061434268951
# Physicial loss of s is: 0.4579094350337982
# Iteration is: 3310
# Data loss is: 0.0016115938778966665
# Physicial loss of p is: 0.149686798453331
# Physicial loss of s is: 0.4545383155345917
# Iteration is: 3320
# Data loss is: 0.0016095456667244434
# Physicial loss of p is: 0.14646537601947784
# Physicial loss of s is: 0.4519112706184387
# Iteration is: 3330
# Data loss is: 0.0016079810447990894
# Physicial loss of p is: 0.14685961604118347
# Physicial loss of s is: 0.44894400238990784
# Iteration is: 3340
# Data loss is: 0.0016060150228440762
# Physicial loss of p is: 0.1452561318874359
# Physicial loss of s is: 0.44643062353134155
# Iteration is: 3350
# Data loss is: 0.0016046217642724514
# Physicial loss of p is: 0.1447111815214157
# Physicial loss of s is: 0.44385042786598206
# Iteration is: 3360
# Data loss is: 0.001603146200068295
# Physicial loss of p is: 0.14416727423667908
# Physicial loss of s is: 0.4411385655403137
# Iteration is: 3370
# Data loss is: 0.0016023587668314576
# Physicial loss of p is: 0.15116450190544128
# Physicial loss of s is: 0.43860599398612976
# Iteration is: 3380
# Data loss is: 0.0016161848325282335
# Physicial loss of p is: 0.14483946561813354
# Physicial loss of s is: 0.4378030300140381
# Iteration is: 3390
# Data loss is: 0.0016145515255630016
# Physicial loss of p is: 0.1456734836101532
# Physicial loss of s is: 0.4394987225532532
# Iteration is: 3400
# Data loss is: 0.0016001858748495579
# Physicial loss of p is: 0.14239287376403809
# Physicial loss of s is: 0.4298357367515564
# Iteration is: 3410
# ...
# Physicial loss of s is: 0.0016071619465947151
# Iteration is: 98930
# Data loss is: 0.0011698374291881919
# Physicial loss of p is: 0.0022653620690107346
# Physicial loss of s is: 0.00160557113122195
# Iteration is: 98940
# Data loss is: 0.0011698342859745026
# Physicial loss of p is: 0.002254392020404339
# Physicial loss of s is: 0.0016050460981205106
# Iteration is: 98950
# Data loss is: 0.0011698311427608132
# Physicial loss of p is: 0.002222497249022126
# Physicial loss of s is: 0.0016053550643846393
# Iteration is: 98960
# Data loss is: 0.0011698241578415036
# Physicial loss of p is: 0.0022094720043241978
# Physicial loss of s is: 0.0016056490130722523
# Iteration is: 98970
# Data loss is: 0.0011698190355673432
# Physicial loss of p is: 0.002209949539974332
# Physicial loss of s is: 0.0016057024477049708
# Iteration is: 98980
# Data loss is: 0.0011698128655552864
# Physicial loss of p is: 0.002209201455116272
# Physicial loss of s is: 0.001605500583536923
# Iteration is: 98990
# Data loss is: 0.001169808441773057
# Physicial loss of p is: 0.002209434052929282
# Physicial loss of s is: 0.001605219324119389
# Iteration is: 99000
# Data loss is: 0.0011698029702529311
# Physicial loss of p is: 0.002209289465099573
# Physicial loss of s is: 0.0016050804406404495
# Iteration is: 99010
# Data loss is: 0.0011697980808094144
# Physicial loss of p is: 0.002208985621109605
# Physicial loss of s is: 0.001604978577233851
# Iteration is: 99020
# Data loss is: 0.0011697928421199322
# Physicial loss of p is: 0.0022090140264481306
# Physicial loss of s is: 0.0016048793913796544
# Iteration is: 99030
# Data loss is: 0.0011697878362610936
# Physicial loss of p is: 0.0022088983096182346
# Physicial loss of s is: 0.0016048179240897298
# Iteration is: 99040
# Data loss is: 0.0011697831796482205
# Physicial loss of p is: 0.0022088035475462675
# Physicial loss of s is: 0.001604705466888845
# Iteration is: 99050
# Data loss is: 0.001169777475297451
# Physicial loss of p is: 0.002208780264481902
# Physicial loss of s is: 0.0016046062810346484
# Iteration is: 99060
# Data loss is: 0.001169772818684578
# Physicial loss of p is: 0.0022086179815232754
# Physicial loss of s is: 0.001604504999704659
# Iteration is: 99070
# Data loss is: 0.0011697676964104176
# Physicial loss of p is: 0.0022086489479988813
# Physicial loss of s is: 0.0016044166404753923
# Iteration is: 99080
# Data loss is: 0.0011697623413056135
# Physicial loss of p is: 0.0022085250820964575
# Physicial loss of s is: 0.0016043188516050577
# Iteration is: 99090
# Data loss is: 0.0011697576846927404
# Physicial loss of p is: 0.0022084906231611967
# Physicial loss of s is: 0.0016042247880250216
# Iteration is: 99100
# Data loss is: 0.0011697523295879364
# Physicial loss of p is: 0.0022082929499447346
# Physicial loss of s is: 0.0016041675116866827
# Iteration is: 99110
# Data loss is: 0.001169747207313776
# Physicial loss of p is: 0.002208296675235033
# Physicial loss of s is: 0.0016040276968851686
# Iteration is: 99120
# Data loss is: 0.0011697416193783283
# Physicial loss of p is: 0.0022081953939050436
# Physicial loss of s is: 0.0016039269976317883
# Iteration is: 99130
# Data loss is: 0.0011697361478582025
# Physicial loss of p is: 0.0022092058788985014
# Physicial loss of s is: 0.0016040261834859848
# Iteration is: 99140
# Data loss is: 0.001169732422567904
# Physicial loss of p is: 0.0023348452523350716
# Physicial loss of s is: 0.001605438650585711
# Iteration is: 99150
# Data loss is: 0.0011697416193783283
# Physicial loss of p is: 0.0028026746585965157
# Physicial loss of s is: 0.0016036367742344737
# Iteration is: 99160
# Data loss is: 0.0011697335867211223
# Physicial loss of p is: 0.0024318615905940533
# Physicial loss of s is: 0.0016178571386262774
# Iteration is: 99170
# Data loss is: 0.001169723691418767
# Physicial loss of p is: 0.0022133353631943464
# Physicial loss of s is: 0.001605231431312859
# Iteration is: 99180
# Data loss is: 0.0011697130976244807
# Physicial loss of p is: 0.0022533698938786983
# Physicial loss of s is: 0.0016027214005589485
# Iteration is: 99190
# Data loss is: 0.0011697050649672747
# Physicial loss of p is: 0.002217849250882864
# Physicial loss of s is: 0.0016026368830353022
# Iteration is: 99200
# Data loss is: 0.0011696995934471488
# Physicial loss of p is: 0.0022084496449679136
# Physicial loss of s is: 0.0016034255968406796
# Iteration is: 99210
# Data loss is: 0.001169694704003632
# Physicial loss of p is: 0.0022085553500801325
# Physicial loss of s is: 0.0016034196596592665
# Iteration is: 99220
# Data loss is: 0.0011696903966367245
# Physicial loss of p is: 0.0022078619804233313
# Physicial loss of s is: 0.0016028974205255508
# Iteration is: 99230
# Data loss is: 0.0011696858564391732
# Physicial loss of p is: 0.0022077716421335936
# Physicial loss of s is: 0.0016030234983190894
# Iteration is: 99240
# Data loss is: 0.0011696807341650128
# Physicial loss of p is: 0.002207282930612564
# Physicial loss of s is: 0.0016030502738431096
# Iteration is: 99250
# Data loss is: 0.0011696757283061743
# Physicial loss of p is: 0.0022074475418776274
# Physicial loss of s is: 0.0016028274549171329
# Iteration is: 99260
# Data loss is: 0.0011696703732013702
# Physicial loss of p is: 0.0022072733845561743
# Physicial loss of s is: 0.0016027408419176936
# Iteration is: 99270
# Data loss is: 0.0011696652509272099
# Physicial loss of p is: 0.002207139041274786
# Physicial loss of s is: 0.0016026314115151763
# Iteration is: 99280
# Data loss is: 0.0011696602450683713
# Physicial loss of p is: 0.0022071064449846745
# Physicial loss of s is: 0.0016025603981688619
# Iteration is: 99290
# Data loss is: 0.0011696546571329236
# Physicial loss of p is: 0.0022069967817515135
# Physicial loss of s is: 0.0016024521319195628
# Iteration is: 99300
# Data loss is: 0.0011696500005200505
# Physicial loss of p is: 0.002206998411566019
# Physicial loss of s is: 0.0016023736679926515
# Iteration is: 99310
# Data loss is: 0.0011696446454152465
# Physicial loss of p is: 0.0022068750113248825
# Physicial loss of s is: 0.0016023117350414395
# Iteration is: 99320
# Data loss is: 0.0011696394067257643
# Physicial loss of p is: 0.0022068095859140158
# Physicial loss of s is: 0.001602419652044773
# Iteration is: 99330
# Data loss is: 0.0011696373112499714
# Physicial loss of p is: 0.002206832403317094
# Physicial loss of s is: 0.0016039499314501882
# Iteration is: 99340
# Data loss is: 0.0011696715373545885
# Physicial loss of p is: 0.002240178408101201
# Physicial loss of s is: 0.0016113185556605458
# Iteration is: 99350
# Data loss is: 0.0011696527944877744
# Physicial loss of p is: 0.002938695251941681
# Physicial loss of s is: 0.0016033691354095936
# Iteration is: 99360
# Data loss is: 0.0011696361470967531
# Physicial loss of p is: 0.002391368616372347
# Physicial loss of s is: 0.0016004089266061783
# Iteration is: 99370
# Data loss is: 0.0011696177534759045
# Physicial loss of p is: 0.0023140532430261374
# Physicial loss of s is: 0.0016011937987059355
# Iteration is: 99380
# Data loss is: 0.0011696100700646639
# Physicial loss of p is: 0.002241862006485462
# Physicial loss of s is: 0.0016027234960347414
# Iteration is: 99390
# Data loss is: 0.001169609371572733
# Physicial loss of p is: 0.002221266273409128
# Physicial loss of s is: 0.001602032221853733
# Iteration is: 99400
# Data loss is: 0.0011695994762703776
# Physicial loss of p is: 0.0022106755059212446
# Physicial loss of s is: 0.00160188355948776
# Iteration is: 99410
# Data loss is: 0.0011695942375808954
# Physicial loss of p is: 0.0022088561672717333
# Physicial loss of s is: 0.0016011764528229833
# Iteration is: 99420
# Data loss is: 0.0011695883003994823
# Physicial loss of p is: 0.0022060340270400047
# Physicial loss of s is: 0.0016012168489396572
# Iteration is: 99430
# Data loss is: 0.0011695836437866092
# Physicial loss of p is: 0.002206007717177272
# Physicial loss of s is: 0.0016012848354876041
# Iteration is: 99440
# Data loss is: 0.0011695792200043797
# Physicial loss of p is: 0.0022062885109335184
# Physicial loss of s is: 0.0016010596882551908
# Iteration is: 99450
# Data loss is: 0.0011695742141455412
# Physicial loss of p is: 0.0022082775831222534
# Physicial loss of s is: 0.0016009315149858594
# Iteration is: 99460
# Data loss is: 0.0011695707216858864
# Physicial loss of p is: 0.00222411984577775
# Physicial loss of s is: 0.0016007362864911556
# Iteration is: 99470
# Data loss is: 0.00116958178114146
# Physicial loss of p is: 0.0025361357256770134
# Physicial loss of s is: 0.0016007776139304042
# Iteration is: 99480
# Data loss is: 0.001169562921859324
# Physicial loss of p is: 0.002241285052150488
# Physicial loss of s is: 0.0016013719141483307
# Iteration is: 99490
# Data loss is: 0.0011695519788190722
# Physicial loss of p is: 0.0022072275169193745
# Physicial loss of s is: 0.0015998933231458068
# Iteration is: 99500
# Data loss is: 0.0011695502325892448
# Physicial loss of p is: 0.002214237581938505
# Physicial loss of s is: 0.0016014017164707184
# Iteration is: 99510
# Data loss is: 0.0011695452267304063
# Physicial loss of p is: 0.0022152315359562635
# Physicial loss of s is: 0.0016005780780687928
# Iteration is: 99520
# Data loss is: 0.0011695369612425566
# Physicial loss of p is: 0.0022076163440942764
# Physicial loss of s is: 0.0016001182375475764
# Iteration is: 99530
# Data loss is: 0.0011695338180288672
# Physicial loss of p is: 0.0022057811729609966
# Physicial loss of s is: 0.0016005035722628236
# Iteration is: 99540
# Data loss is: 0.001169527997262776
# Physicial loss of p is: 0.0022058195900171995
# Physicial loss of s is: 0.0016001116018742323
# Iteration is: 99550
# Data loss is: 0.0011695224093273282
# Physicial loss of p is: 0.002205268945544958
# Physicial loss of s is: 0.001600174349732697
# Iteration is: 99560
# Data loss is: 0.0011695169378072023
# Physicial loss of p is: 0.0022051334381103516
# Physicial loss of s is: 0.0015999856404960155
# Iteration is: 99570
# Data loss is: 0.0011695121647790074
# Physicial loss of p is: 0.0022060235496610403
# Physicial loss of s is: 0.0015998529270291328
# Iteration is: 99580
# Data loss is: 0.001169507042504847
# Physicial loss of p is: 0.002209091791883111
# Physicial loss of s is: 0.001599800307303667
# Iteration is: 99590
# Data loss is: 0.0011695068096742034
# Physicial loss of p is: 0.002260038862004876
# Physicial loss of s is: 0.001599776092916727
# Iteration is: 99600
# Data loss is: 0.0011695512803271413
# Physicial loss of p is: 0.00298800109885633
# Physicial loss of s is: 0.0016004062490537763
# Iteration is: 99610
# Data loss is: 0.0011694964487105608
# Physicial loss of p is: 0.0024492875672876835
# Physicial loss of s is: 0.0015999235911294818
# Iteration is: 99620
# Data loss is: 0.0011694926070049405
# Physicial loss of p is: 0.0023178819101303816
# Physicial loss of s is: 0.0015995162539184093
# Iteration is: 99630
# Data loss is: 0.0011694804998114705
# Physicial loss of p is: 0.0022308677434921265
# Physicial loss of s is: 0.0015996347647160292
# Iteration is: 99640
# Data loss is: 0.0011694758431985974
# Physicial loss of p is: 0.0022135551553219557
# Physicial loss of s is: 0.0015991964610293508
# Iteration is: 99650
# Data loss is: 0.0011694697896018624
# Physicial loss of p is: 0.0022065117955207825
# Physicial loss of s is: 0.0015994356945157051
# Iteration is: 99660
# Data loss is: 0.0011694651329889894
# Physicial loss of p is: 0.0022070053964853287
# Physicial loss of s is: 0.0015991685213521123
# Iteration is: 99670
# Data loss is: 0.0011694584973156452
# Physicial loss of p is: 0.0022048414684832096
# Physicial loss of s is: 0.0015990319661796093
# Iteration is: 99680
# Data loss is: 0.001169453258626163
# Physicial loss of p is: 0.0022042621858417988
# Physicial loss of s is: 0.00159886060282588
# Iteration is: 99690
# Data loss is: 0.0011694474378600717
# Physicial loss of p is: 0.002204547869041562
# Physicial loss of s is: 0.001598575385287404
# Iteration is: 99700
# Data loss is: 0.001169442548416555
# Physicial loss of p is: 0.002204880816861987
# Physicial loss of s is: 0.001598058850504458
# Iteration is: 99710
# Data loss is: 0.0011694617569446564
# Physicial loss of p is: 0.002207815879955888
# Physicial loss of s is: 0.0016018773894757032
# Iteration is: 99720
# Data loss is: 0.001169435796327889
# Physicial loss of p is: 0.0022114820312708616
# Physicial loss of s is: 0.001599827199243009
# Iteration is: 99730
# Data loss is: 0.0011694477871060371
# Physicial loss of p is: 0.0024578096345067024
# Physicial loss of s is: 0.0015979334712028503
# Iteration is: 99740
# Data loss is: 0.0011694321874529123
# Physicial loss of p is: 0.002361961407586932
# Physicial loss of s is: 0.0015993748093023896
# Iteration is: 99750
# Data loss is: 0.0011694174027070403
# Physicial loss of p is: 0.0022132021840661764
# Physicial loss of s is: 0.0015978855080902576
# Iteration is: 99760
# Data loss is: 0.001169412164017558
# Physicial loss of p is: 0.0022510148119181395
# Physicial loss of s is: 0.001598146976903081
# Iteration is: 99770
# Data loss is: 0.001169411581940949
# Physicial loss of p is: 0.0022280020639300346
# Physicial loss of s is: 0.001599016017280519
# Iteration is: 99780
# Data loss is: 0.0011694013373926282
# Physicial loss of p is: 0.00220741075463593
# Physicial loss of s is: 0.0015979865565896034
# Iteration is: 99790
# Data loss is: 0.0011693969136103988
# Physicial loss of p is: 0.0022051972337067127
# Physicial loss of s is: 0.0015977321891114116
# Iteration is: 99800
# Data loss is: 0.0011693922569975257
# Physicial loss of p is: 0.002203245647251606
# Physicial loss of s is: 0.0015982163604348898
# Iteration is: 99810
# Data loss is: 0.001169386669062078
# Physicial loss of p is: 0.0022038316819816828
# Physicial loss of s is: 0.0015977100702002645
# Iteration is: 99820
# Data loss is: 0.0011693814303725958
# Physicial loss of p is: 0.0022030617110431194
# Physicial loss of s is: 0.0015977839939296246
# Iteration is: 99830
# Data loss is: 0.0011693764245137572
# Physicial loss of p is: 0.0022031127009540796
# Physicial loss of s is: 0.0015976452268660069
# Iteration is: 99840
# Data loss is: 0.001169371185824275
# Physicial loss of p is: 0.002203048439696431
# Physicial loss of s is: 0.0015975349815562367
# Iteration is: 99850
# Data loss is: 0.001169365830719471
# Physicial loss of p is: 0.0022028775420039892
# Physicial loss of s is: 0.0015974495327100158
# Iteration is: 99860
# Data loss is: 0.0011693605920299888
# Physicial loss of p is: 0.002202838659286499
# Physicial loss of s is: 0.0015973177505657077
# Iteration is: 99870
# Data loss is: 0.0011693552369251847
# Physicial loss of p is: 0.002202725037932396
# Physicial loss of s is: 0.0015972392866387963
# Iteration is: 99880
# Data loss is: 0.0011693499982357025
# Physicial loss of p is: 0.0022059883922338486
# Physicial loss of s is: 0.0015972250839695334
# Iteration is: 99890
# Data loss is: 0.001169355120509863
# Physicial loss of p is: 0.0026147719472646713
# Physicial loss of s is: 0.0015987083315849304
# Iteration is: 99900
# Data loss is: 0.0011693410342559218
# Physicial loss of p is: 0.002357371849939227
# Physicial loss of s is: 0.0015973156550899148
# Iteration is: 99910
# Data loss is: 0.0011693370761349797
# Physicial loss of p is: 0.002369089052081108
# Physicial loss of s is: 0.0015987245133146644
# Iteration is: 99920
# Data loss is: 0.0011693401029333472
# Physicial loss of p is: 0.00230407458730042
# Physicial loss of s is: 0.0016031456179916859
# Iteration is: 99930
# Data loss is: 0.0011693265987560153
# Physicial loss of p is: 0.002206929959356785
# Physicial loss of s is: 0.0015978394076228142
# Iteration is: 99940
# Data loss is: 0.0011693182168528438
# Physicial loss of p is: 0.002209675731137395
# Physicial loss of s is: 0.001596233225427568
# Iteration is: 99950
# Data loss is: 0.0011693134438246489
# Physicial loss of p is: 0.0022079073823988438
# Physicial loss of s is: 0.001596342190168798
# Iteration is: 99960
# Data loss is: 0.0011693085543811321
# Physicial loss of p is: 0.002202049596235156
# Physicial loss of s is: 0.0015965997008606791
# Iteration is: 99970
# Data loss is: 0.0011693040141835809
# Physicial loss of p is: 0.0022022125776857138
# Physicial loss of s is: 0.001596608548425138
# Iteration is: 99980
# Data loss is: 0.0011692991247400641
# Physicial loss of p is: 0.002202277071774006
# Physicial loss of s is: 0.001596383168362081
# Iteration is: 99990
# Data loss is: 0.001169293187558651
# Physicial loss of p is: 0.0022020344622433186
# Physicial loss of s is: 0.0015962448669597507
# Iteration is: 100000
# Data loss is: 0.0011692880652844906
# Physicial loss of p is: 0.002201780676841736
# Physicial loss of s is: 0.0015962393954396248
# Training time: 1369.6225

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]
loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]
loss_phia_list = [loss_fisa[i].numpy() for i in range(0,Nmax)]
loss_0_list = [loss_0[i].numpy() for i in range(0,Nmax)]





plt.semilogy(ep, np.asarray(loss_data_list), 'b-', linewidth = 2, alpha=0.6, label = 'Data')  
plt.semilogy(ep, np.asarray(loss_phip_list), 'r-', linewidth = 2, alpha=0.6, label = '$\phi_p$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\phi_s$') 
plt.semilogy(ep, np.asarray(loss_phia_list), 'y-', linewidth = 2, alpha=0.6, label = '$\phi_a$')    
# plt.semilogy(ep, np.asarray(loss_0_list), color='orange', linestyle='-', linewidth = 2, alpha=0.6, label = '$a_0$')       




plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
lnv[0], tf.exp(lnv[0]), lnv[1], tf.exp(lnv[1])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([6.5075984], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([670.2149], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([2.109295], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([8.242428], dtype=float32)>)

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp=u_pred[:,0:1]
lns=u_pred[:,1:2]
lna=u_pred[:,2:3]


p=tf.exp(lnp)
s=tf.exp(lns)
a=tf.exp(lna)


# phi = tf.exp(predict(tf.concat([p, s, l],1), W_phi, b_phi))
phi_s = tf.exp(predict(s, W_phi, b_phi))
phi_a = tf.exp(predict(a, W_a, b_a))



m=tf.exp(lnv[0:1])
l=tf.exp(lnv[1:2])


s_t=-np.array(p*s*m)
a_t=-np.array(p*a*l)

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],s[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')



plt.xlabel('t (ms)')
plt.ylabel('S')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],a[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')




plt.xlabel('t (ms)')
plt.ylabel('A')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
# plt.scatter(p, phi_s, s=3, label='Prediction')
plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
# plt.scatter(p, phi_s, s=3, label='Prediction')
plt.scatter(a, phi_a, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.scatter(p, phi_s, s=3, label='Prediction')

plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
A
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
Nt=1000

# A_0=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
A_0=np.array([0,1.25, 2.5,3.75])

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)
    A_int=np.zeros(Nt)



    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    A_int[0]=np.array(a) #Initial conditions
    S_int[0]=np.array(s[0]) #Initial conditions

    # l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        PHI_A=tf.exp(predict(tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_a, b_a))

        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI_S - P_int[i-1]*PHI_A)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m)*dt
        A_int[i]=A_int[i-1]-P_int[i-1]*A_int[i-1]*np.array(l)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')
    # plt.plot(T_int, A_int,  linestyle=':', label=f'Numeric integration dAdT {a}')


plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %%
Nt=1000

# A_0=np.array([0,0.75, 1.25,2, 2.5,3,3.75])


L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors
A_0=np.array([0,1.25, 2.5,3.75])

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)
    A_int=np.zeros(Nt)



    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    A_int[0]=np.array(a) #Initial conditions
    S_int[0]=np.array(s[0]) #Initial conditions

    # l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        PHI_A=tf.exp(predict(tf.convert_to_tensor(A_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_a, b_a))

        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI_S - P_int[i-1]*PHI_A)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m)*dt
        A_int[i]=A_int[i-1]-P_int[i-1]*A_int[i-1]*np.array(l)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    # plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')
    # plt.plot(T_int, A_int,  linestyle=':', label=f'Numeric integration dAdT {a}')

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
# plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')


# plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
c=0
d=-1
plt.scatter( p[c:d], np.exp(phi[c:d]), s=2, label='Prediction P')
plt.scatter( s[c:d], np.exp(phi[c:d]), s=2, label='Prediction S')
# plt.plot( a[c:d], phi_p[c:d], label='Prediction S')


plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
X_star_tf[c:d][0], X_star_tf[c:d][-1]
# Out:
# (<tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.    , 0.0938], dtype=float32)>,
#  <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.9970674, 0.0923   ], dtype=float32)>)

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')




plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')


plt.vlines(X_star_tf[c:d][:,0][0],0,1.2, color='red', linestyle=':')
plt.vlines(X_star_tf[c:d][:,0][-1],0,1.2, color='red', linestyle=':')


plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
model = PySRRegressor(
    niterations=200,
    binary_operators=["+", "*", "inv(x, y) = x/(x + y)"],
    # binary_operators=["+", "*", "inv(x, y) = x/(x + y)", "^"],

    # unary_operators=[ "exp"],
    # unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={
            "inv": lambda x, y: x/(x+y),
        },
    # extra_sympy_mappings={"inv": lambda x: 1/x},
    constraints={"exp": 3, 'inv': (1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00000001,
    # denoise=True,
    # complexity_of_variables=2,
    # complexity_of_constants=2,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
    select_k_features=1,
    maxsize=40,
)

# %%
# p1s=tf.concat([p1[c:d], s[c:d]], axis=1)

min_cols_phi= tf.math.reduce_min(phi[c:d], axis=0)
max_cols_phi= tf.math.reduce_max(phi[c:d], axis=0)

phi_scaled = (phi[c:d]-min_cols_phi)/(max_cols_phi-min_cols_phi)
PS_tf=tf.concat([p[c:d], s[c:d]],1)

model.fit( PS_tf,phi_scaled)
print(model)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Using features ['x1']
# [ Info: Started!
# Expressions evaluated per second: 2.780e+04
# Head worker occupation: 22.9%
# Progress: 75 / 3000 total iterations (2.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           3.955e-02  5.314e+00  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.478e-02  2.859e-02  y = ((inv(x1, 0.10223) * -0.30208) + (0.15902 + x1)) + 0.09950...
#                                   7
# 13          2.370e-02  2.218e-02  y = 0.099507 + ((0.18993 + x1) + ((-0.30208 * 1.3452) * inv(x1...
#                                   , 0.10223)))
# 17          2.215e-02  1.688e-02  y = 0.18608 + ((x1 + (((-1.0119 * x1) * x1) * (x1 * x1))) * (x...
#                                   1 + x1))
# 19          1.947e-02  6.449e-02  y = 0.25455 + (((((-0.85623 * x1) * x1) * x1) + x1) * ((x1 + 0...
#                                   .14507) + (-0.30395 + x1)))
# 21          1.793e-02  4.126e-02  y = 0.25004 + (((x1 + (((x1 + x1) + -0.66889) * 2.4278)) * (-0...
#                                   .39674 + inv(0.85065, x1))) * (x1 + x1))
# 25          1.672e-02  1.743e-02  y = (x1 * ((((x1 + x1) + -0.080258) * ((inv(x1, x1) + ((x1 * -...
#                                   0.92223) * (x1 * x1))) + 0.95982)) + -0.82044)) + 0.2704
# 27          1.306e-02  1.236e-01  y = ((((inv(1.4462, 2.2953) + ((x1 * (0.16588 + x1)) * -0.8808...
#                                   2)) + 0.62528) * ((x1 + ((2.9017 * x1) + -1.2808)) + x1)) * x1...
#                                   ) + 0.26349
# 31          1.115e-02  3.957e-02  y = (((((1.9312 + ((x1 * (0.56703 + x1)) * -1.3051)) + -0.1458...
#                                   1) * ((x1 + ((1.3124 * x1) + -1.0317)) + x1)) + ((-0.59911 + x...
#                                   1) + 0.079291)) * x1) + 0.29135
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.800e+04
# Head worker occupation: 19.6%
# Progress: 172 / 3000 total iterations (5.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 15          1.863e-02  3.620e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.855e-02  2.179e-03  y = 0.2407 + (((x1 * (((x1 * -0.96546) * x1) * x1)) + x1) * (x...
#                                   1 + x1))
# 19          1.180e-02  2.260e-01  y = ((((x1 + -0.9667) * 3.1557) * ((x1 * -2.4664) + inv(0.8407...
#                                   1, x1))) * x1) + (0.19285 + 0.10635)
# 21          1.096e-02  3.683e-02  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.19285 + 0.10635)
# 23          1.063e-02  1.558e-02  y = ((x1 * ((x1 + (x1 + (x1 + (x1 + -1.3504)))) * ((-1.5055 * ...
#                                   (x1 * 1.2765)) + 1.9003))) + 0.242) * 1.2304
# 29          1.061e-02  2.597e-04  y = (((((-1.2701 + (x1 + (inv(-0.22109, 1.2369) + x1))) + ((-0...
#                                   .23128 + x1) + x1)) + x1) * (((x1 * 0.97839) * -1.9394) + 1.87...
#                                   65)) * x1) + 0.30126
# 31          1.056e-02  2.149e-03  y = (1.0965 * ((((((x1 * x1) * -0.47626) + x1) + ((x1 + -0.415...
#                                   78) * (1.5945 + inv(-0.6427, 0.35635)))) * ((x1 * -1.9534) + 1...
#                                   .9355)) * x1)) + (0.27317 + 0.029663)
# 37          1.054e-02  4.362e-04  y = 0.29991 + (x1 * ((((((((x1 + x1) + -0.84768) + x1) + x1) +...
#                                    (((-0.041061 * x1) * x1) + ((-1.7349 + -1.0641) + x1))) + -1....
#                                   3884) + inv(0.15367, x1)) * ((x1 * -2.079) + 0.72708)))
# 39          1.003e-02  2.451e-02  y = (x1 * ((((x1 * (-1.9266 * 0.87892)) * x1) + 1.8833) * (((1...
#                                   .8833 + (x1 * ((-1.5986 * x1) + -0.2367))) * (((x1 + -1.3044) ...
#                                   + (x1 + 0.15884)) + (x1 + inv(0.047572, x1)))) + 0.043323))) +...
#                                    0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Head worker occupation: 15.9%
# Progress: 250 / 3000 total iterations (8.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          2.136e-02  3.898e-03  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * (x1 * 1.0785)...
#                                   )
# 15          1.863e-02  6.850e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.245e-02  2.014e-01  y = (0.19285 + 0.086001) + ((((x1 + -0.9667) * 3.1557) * (0.90...
#                                   662 + (-2.7585 * x1))) * x1)
# 19          1.140e-02  4.434e-02  y = (((-0.10278 + (3.1557 * (x1 + -0.9667))) * ((x1 * -2.4664)...
#                                    + 0.84071)) * x1) + (0.10635 + 0.19285)
# 21          1.092e-02  2.120e-02  y = (((-0.10278 + ((-0.9667 + x1) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.095392 + 0.19285)
# 23          1.062e-02  1.392e-02  y = ((x1 + -0.081559) * (((-2.2871 * x1) + 2.3214) * ((x1 * 2....
#                                   2758) + ((-1.1269 + x1) + (x1 + 0.11778))))) + 0.11195
# 27          1.045e-02  4.143e-03  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + ((0.84071 + inv(...
#                                   x1, -1.3214)) + x1)))) * ((x1 * -2.4664) + 0.84071)) * x1) + (...
#                                   0.19285 + 0.10635)
# 29          1.041e-02  1.637e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + -0.33894) ...
#                                   * ((x1 + inv(0.047572, x1)) + (x1 + -1.3044))) + x1) + (x1 * 1...
#                                   .1842)))) + 0.30147
# 31          1.008e-02  1.639e-02  y = (x1 * (((-1.9266 * x1) + 1.8833) * (((1.8833 + 0.077362) *...
#                                    ((x1 + (inv(0.047572, x1) + -0.064585)) + ((x1 + x1) + -1.304...
#                                   4))) + (0.30147 * 1.1842)))) + 0.30147
# 37          9.843e-03  3.925e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + inv(0.0773...
#                                   62, x1)) * ((x1 + inv(0.047572, x1)) + (inv(0.043323, 0.15884)...
#                                    + (x1 + -1.3044)))) + x1) + (x1 * inv(1.1842, 0.91425))))) + ...
#                                   0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.700e+04
# Head worker occupation: 14.5%
# Progress: 329 / 3000 total iterations (10.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.617e-02  1.432e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.4051)) *...
#                                    x1)
# 15          1.224e-02  1.390e-01  y = 0.28154 + (x1 * ((x1 + -0.99589) * (((-5.2648 + -1.9302) *...
#                                    x1) + 2.2863)))
# 17          1.167e-02  2.394e-02  y = 0.28154 + (x1 * ((x1 + -0.99589) * ((((-5.2648 + -1.1021) ...
#                                   + -1.2315) * x1) + 2.2863)))
# 19          1.070e-02  4.356e-02  y = 0.30839 + (x1 * (((1.8937 * (x1 + (-0.8686 + x1))) + x1) *...
#                                    (1.9877 + (x1 * -2.0051))))
# 23          1.061e-02  2.016e-03  y = 0.30131 + ((x1 * 1.6833) * (((-1.9277 * x1) + 1.9069) * ((...
#                                   0.54582 + (((0.51804 + -1.3234) + x1) * 1.9209)) + x1)))
# 27          9.929e-03  1.662e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + x1)))
# 29          9.905e-03  1.218e-03  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * ((1.8246 + x1) * inv(x1, 0...
#                                   .31499))) + x1)))
# 31          8.648e-03  6.782e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1....
#                                   9302)) * (((x1 + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + (0.20664 * inv(x1, x1)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.150e+04
# Head worker occupation: 14.2%
# Progress: 426 / 3000 total iterations (14.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.052e-02  2.579e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * (((-4.6...
#                                   638 + (x1 * (x1 + -0.67368))) * x1) + 1.6117)))
# 25          1.050e-02  9.160e-04  y = (0.21074 + (x1 * ((-1.0022 + x1) * (2.4464 + ((-2.5247 + (...
#                                   (-5.2844 + (x1 * (x1 + x1))) * 0.9772)) * x1))))) * 1.4173
# 27          9.528e-03  4.841e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (-1.9302 * x1)) ...
#                                   * (((x1 + (inv(-0.83605, 1.6945) + x1)) * (1.9019 * inv(x1, 0....
#                                   31499))) + x1)))
# 29          8.448e-03  6.015e-02  y = (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1.9302)) * (...
#                                   ((1.8246 * inv(x1, 0.20664)) * (x1 + (-0.83605 + inv(x1, 0.791...
#                                   32)))) + 0.20664))) + 0.29387
# 33          5.125e-03  1.249e-01  y = ((inv(x1, 0.0098097) * 0.87837) * ((1.9533 + ((x1 * x1) * ...
#                                   -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2292)) * (x1 + (inv(x...
#                                   1, 0.7733) + -0.77502))) + 0.2292))) + 0.2292
# 35          4.691e-03  4.421e-02  y = ((inv(x1, 0.0098097) * 0.87837) * (((x1 * (-1.9397 * x1)) ...
#                                   + 1.8885) * (((((1.8202 + x1) + 0.20894) * inv(x1, 0.20894)) *...
#                                    ((-0.77502 + inv(x1, 0.7733)) + x1)) + 0.25046))) + 0.2292
# 37          3.741e-03  1.132e-01  y = (((inv(x1, 0.0098097) * 0.87837) + (-0.22058 * x1)) * ((1....
#                                   9533 + ((x1 * x1) * -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2...
#                                   292)) * (x1 + (inv(x1, 0.7733) + -0.77502))) + 0.2292))) + 0.2...
#                                   292
# 39          3.216e-03  7.559e-02  y = (((inv(x1, 0.0041438) * 0.87769) + (-0.22025 * (x1 + -0.15...
#                                   79))) * ((1.9537 + ((x1 * x1) * -1.9389)) * (0.22256 + (((1.95...
#                                   4 + x1) * inv(x1, 0.21981)) * (x1 + (inv(x1, 0.77348) + -0.778...
#                                   73)))))) + 0.19528
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.950e+04
# Head worker occupation: 14.8%
# Progress: 535 / 3000 total iterations (17.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.367e-03  y = 0.3052 + (x1 * ((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 ...
#                                   + ((x1 * 1.1883) * x1)) * x1) + 1.6117)))
# 25          2.667e-03  6.852e-01  y = (((0.26613 + ((inv(x1, 0.19528) * 1.9537) * (x1 + (-0.7787...
#                                   3 + x1)))) * (1.9537 + (x1 * -1.9389))) * inv(x1, 0.0041438)) ...
#                                   + 0.19528
# 27          2.108e-03  1.176e-01  y = 0.19528 + (((0.26613 + ((x1 + (x1 + -0.77873)) * (inv(x1, ...
#                                   0.19528) * 1.9537))) * (1.9537 + ((0.97698 * x1) * -1.9389))) ...
#                                   * inv(x1, 0.0041438))
# 29          1.636e-03  1.269e-01  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 37          1.339e-03  1.250e-03  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.100e+04
# Head worker occupation: 15.0%
# Progress: 639 / 3000 total iterations (21.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.636e-03  9.570e-02  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.341e-03  1.548e-03  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + (x1 * 0.93073)) +...
#                                    inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.158...
#                                   87
# 37          1.339e-03  9.526e-04  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# 39          1.215e-03  4.855e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * (inv(1.2861, 0.84669) + -0.15182)))) * ((...
#                                   x1 + -0.87651) + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1...
#                                   , 0.0056867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 731 / 3000 total iterations (24.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.631e-03  9.701e-02  y = 0.15887 + (((0.75672 * (1.9752 + (-1.9035 * x1))) * (((x1 ...
#                                   + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x1)) + 0.4196...
#                                   2)) * inv(x1, 0.0056867))
# 31          1.403e-03  7.550e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.294e-03  1.938e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * ((((x1 + (inv(x1...
#                                   , 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651) ...
#                                   + x1)) + 0.41962) * 1.1182)) * inv(x1, 0.0056867)) + 0.15887
# 37          1.177e-03  4.740e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651)...
#                                    + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1, 0.0056867)) ...
#                                   + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+04
# Head worker occupation: 14.3%
# Progress: 828 / 3000 total iterations (27.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          8.340e-03  1.185e-01  y = ((((x1 * -1.9035) + 1.9752) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  6.129e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.491e-03  2.480e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + inv(0.41962, 0.72301))) * inv(x1, 0...
#                                   .0056867)) + 0.15887
# 31          1.403e-03  1.520e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.191e-03  6.093e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((inv(x1, 1.4938) + inv(x1, 0.060135)) + x1) * ((-0.876...
#                                   51 + x1) + x1)) + 0.41962))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.173e-03  7.562e-03  y = ((((-1.9035 * x1) + 1.9752) * (((((inv(x1, 0.060135) + x1)...
#                                    + (inv(x1, 1.9457) * x1)) * ((-0.87651 + x1) + x1)) * inv(1.0...
#                                   821, 0.092927)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)...
#                                   ) + 0.15887
# 39          1.147e-03  1.132e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((((inv(x1, 1.4938) * x1) + inv(x1, 0.060135)) * 1.0811...
#                                   ) + x1) * ((-0.87651 + x1) + x1)) + 0.41962))) * inv(x1, 0.005...
#                                   6867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 941 / 3000 total iterations (31.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  3.101e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.309e-03  3.131e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.248e-03  2.389e-02  y = ((inv(x1, 0.0056867) + -0.012119) * (((((inv(x1, 0.060135)...
#                                    + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9...
#                                   752 + (-1.9035 * x1)))) + 0.15887
# 31          1.247e-03  2.635e-04  y = ((inv(x1, 0.0056867) + (-0.012119 * 1.1739)) * (((((inv(x1...
#                                   , 0.060135) + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41...
#                                   962) * (1.9752 + (-1.9035 * x1)))) + 0.15887
# 35          1.162e-03  1.770e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.300e+04
# Head worker occupation: 15.3%
# Progress: 1029 / 3000 total iterations (34.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.240e-03  2.677e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * 0.89975)))) + 0.15887
# 31          1.214e-03  1.062e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.89975, 0.21942))))) + 0.15887
# 33          1.192e-03  9.391e-03  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.180e+04
# Head worker occupation: 15.1%
# Progress: 1119 / 3000 total iterations (37.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.222e-03  3.409e-02  y = (((1.9752 + (-1.9035 * x1)) * (((((inv(x1, 0.060135) + x1)...
#                                    * ((x1 + -0.87651) + x1)) + 0.41962) + -0.04569) + 0.0067754)...
#                                   ) * inv(x1, 0.0056867)) + 0.15887
# 31          1.193e-03  1.213e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.192e-03  5.541e-04  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.920e+04
# Head worker occupation: 15.3%
# Progress: 1201 / 3000 total iterations (40.033%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.193e-03  1.789e-03  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.175e-03  7.800e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962)...
#                                    + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.259e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# 37          1.089e-03  2.505e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.650e+04
# Head worker occupation: 15.8%
# Progress: 1277 / 3000 total iterations (42.567%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.176e-03  8.842e-03  y = (((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1) ...
#                                   * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) + 0.15887
# 33          1.171e-03  2.279e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.11004)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.106e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# ...
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.048e-03  4.028e-01  y = 0.16158 + ((inv(x1, 0.014288) + x1) * ((((-2.1275 * x1) * ...
#                                   x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ))))
# 27          9.974e-04  2.466e-02  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * ((((-2.12...
#                                   75 * x1) * x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1...
#                                   , 0.016826)))))
# 29          9.888e-04  4.331e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.710e+04
# Head worker occupation: 16.4%
# Progress: 2823 / 3000 total iterations (94.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.640e+04
# Head worker occupation: 16.6%
# Progress: 2906 / 3000 total iterations (96.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.820e+04
# Head worker occupation: 16.3%
# Progress: 2999 / 3000 total iterations (99.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 21          9.452e-03  9.432e-03  y = (0.19018 + (inv(x1, 0.0097537) * (1.9599 * (0.62748 + ((in...
#                                   v(x1, 0.40694) + -1.0054) * inv(x1, 0.0212)))))) + -0.048795
# 23          2.345e-03  6.969e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 35          9.688e-04  6.415e-04  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * ((x1 + -1.0184) * 1.1219))) * x1)) + 2.1916)...
#                                    * (((-1.0184 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  4.520e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                           0.310787
# 	1         0.084607                                    0.19077079 + x1
# 	2         0.173234                      (0.5607476 * x1) + 0.24348809
# 	3         0.027205              (x1 * inv(x1, 0.5479253)) + 0.2523965
# 	4         0.054837  (inv(x1, 0.080867134) * (-0.32800326 + x1)) + ...
# 	5         0.059941  (((-3.07164 * x1) + 3.3362021) * (x1 * x1)) + ...
# 	6         0.168797  (((-1.0817221 + x1) * ((x1 * -4.7079844) + 1.2...
# 	7         0.173619  ((((-4.6741557 * x1) + 1.5998087) * (-1.980577...
# 	8         0.024327  0.15983854 + (inv(x1, 0.014288435) * ((((inv(x...
# 	9         0.009432  (0.19018486 + (inv(x1, 0.009753697) * (1.95994...
# 	10        0.696936  (((inv(x1, 0.014288435) + inv(x1, -1.4914056))...
# 	11  >>>>  0.417967  ((x1 + inv(x1, 0.014288435)) * ((((-2.1275125 ...
# 	12        0.011980  0.15983854 + ((inv(x1, 0.014288435) + (x1 * 1....
# 	13        0.001834  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	14        0.000325  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	15        0.009251  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	16        0.000642  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	17        0.045198  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
# 	18        0.002793  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
#
# 	        loss  complexity
# 	0   0.046845           1
# 	1   0.039553           3
# 	2   0.027971           5
# 	3   0.026490           7
# 	4   0.023738           9
# 	5   0.021056          11
# 	6   0.015023          13
# 	7   0.010616          15
# 	8   0.009632          19
# 	9   0.009452          21
# 	10  0.002345          23
# 	11  0.001017          25
# 	12  0.000992          27
# 	13  0.000989          29
# 	14  0.000988          31
# 	15  0.000970          33
# 	16  0.000969          35
# 	17  0.000885          37
# 	18  0.000880          39
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.yscale('log')
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=17
expr=model.sympy(chose)*(max_cols_phi-min_cols_phi)+min_cols_phi
expr
# Out:
# 21.7206382751465*((x1/(x1 + 0.016826037))*(x1 - 1.0184498) + 0.7157937)*(x1*x1*x1*(-2.1275125 + 0.16839427) + 2.1915646)*(x1*x1*(-1.0264988)*x1 + x1 + x1/(x1 + 0.014288435)) + 4.61513426687202

# %%
sympy.expand(expr)
# Out:
# 43.6809097560371*x1**8/(x1 + 0.016826037) - 44.4868138048541*x1**7/(x1 + 0.016826037) + 31.2665200136399*x1**6 - 42.5532984120752*x1**6/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 42.5532984120752*x1**6/(x1 + 0.016826037) + 43.3383982571183*x1**5/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 5.52518437470967*x1**5/(x1 + 0.016826037) - 30.4593829175835*x1**4 + 49.7651059586687*x1**4/(x1 + 0.016826037) - 30.4593829175835*x1**4/(x1 + 0.014288435) - 34.9762446072919*x1**3 + 47.6021819332161*x1**3/(x1**2 + 0.031114472*x1 + 0.000240417735982095) + 47.6021819332161*x1**3/(x1 + 0.016826037) - 48.4804326694475*x1**2/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 48.4804326694475*x1**2/(x1 + 0.016826037) + 34.0733419340499*x1 + 34.0733419340499*x1/(x1 + 0.014288435) + 4.61513426687202

# %%
sympy.simplify(expr)
# Out:
# (21.7206382751465*x1*(2.1915646 - 1.95911823*x1**3)*((1 - 1.0264988*x1**2)*(x1 + 0.014288435) + 1)*(x1*(x1 - 1.0184498) + 0.7157937*x1 + 0.0120439712805669) + 4.61513426687202*(x1 + 0.014288435)*(x1 + 0.016826037))/((x1 + 0.014288435)*(x1 + 0.016826037))

# %%
sympy.factor(expr)
# Out:
# 79.1383687168112*(0.55195615558295*x1**9 - 0.159166307767832*x1**8 - 0.533446731117839*x1**7 - 1.0*x1**6 + 0.336640788383156*x1**5 + 0.590170698599522*x1**4 + 0.427944668557383*x1**3 - 0.119088781949323*x1**2 + 0.00916254183022982*x1 + 1.40205079999211e-5)/((1.0*x1 + 0.014288435)*(1.0*x1 + 0.016826037))

# %%
symb_s=model.predict(tf.concat([p, s],1),chose)
symb_s=symb_s*(max_cols_phi-min_cols_phi)+min_cols_phi
plt.scatter(s, phi, s=3, label='PINN prediction')
plt.scatter(s, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
plt.scatter(p, phi, s=3, label='PINN prediction')
plt.scatter(p, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
# plt.plot(tf.concat([p, s],1), 15.38-1.18*s, linestyle='--', label=r'$s\approx 0$')

# plt.plot( s, 200/(13+s), label='Real S')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.legend()
plt.show()
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)

# %%
Nt=1000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)

dt=0.001

P_symb[0]=np.mean(P0) #Initial conditions
# P_symb[0]=np.mean(1) #Initial conditions

S_symb[0]=np.array(s[0]) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    PS_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    # PHI=predict(PS_p , W_phi, b_phi)
    # P_symb[i]=P_symb[i-1]+(PHI)*P_symb[i-1]*dt

    P_symb[i]=P_symb[i-1]+(model.predict(PS_p,chose)*(max_cols_phi-min_cols_phi)+min_cols_phi-np.array(l))*P_symb[i-1]*dt
    S_symb[i]=S_symb[i-1]-np.maximum(0, P_symb[i-1]*S_symb[i-1]*np.array(m))*dt
    T_symb[i]=T_symb[i-1]+dt
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.ylim(0,1)
plt.legend()
plt.show()

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
import sympy as sp

P, S = sp.symbols('P S')

# Definir la función que representa el sistema de ecuaciones
def system(vars):
    P, S = vars
    f_S = expr.subs({'x1': S})-6.1390066  # Cambia esta expresión por la de tu función f(S)
    dP = f_S * P 
    dS = -42.86948 * S * P
    return [dP, dS]


# Definir variables simbólicas
# P, S = sp.symbols('P S')
# Define tu función f(S) y asegúrate de que solo depende de S
f_S = expr.subs({'x1': S})-6.1390066   # Define aquí la función f(S) correctamente

# Convertir f(S) en una función numérica
f_S_func = sp.lambdify(S, f_S, 'numpy')

# Rango para el diagrama de fases
S_values = np.linspace(0, 1, 50)
P_values = np.linspace(0, 1, 50)

# Crear la cuadrícula
P_grid, S_grid = np.meshgrid(P_values, S_values)
dP_vals = f_S_func(S_grid) * P_grid
dS_vals = -42.86948 * S_grid * P_grid

# Encontrar los puntos fijos usando fsolve
fixed_points = []
for P_init in np.linspace(0, 1, 50):  # Asegúrate de elegir un buen rango de inicialización
    for S_init in np.linspace(0, 1, 50):
        point = fsolve(system, [P_init, S_init])
        # Evitar duplicados al agregar puntos
        if not any(np.allclose(point, fp) for fp in fixed_points):
            fixed_points.append(point)



import scipy.optimize as opt


# Usar fsolve para encontrar las raíces de f(S) en un rango inicial
S_initial_guesses = np.linspace(0, 1, 20)  # Puedes ajustar el rango de las conjeturas iniciales
S_roots = [opt.fsolve(f_S_func, S0) for S0 in S_initial_guesses]

# Imprimir las soluciones
S_roots = np.unique(np.array(S_roots).flatten())  # Aplanar el resultado para eliminar listas anidadas
print("Soluciones de f(S) = 0:", S_roots)

# Graficar las soluciones
S_values = np.linspace(0, 1, 100)
f_values = f_S_func(S_values)

plt.plot(S_values, f_values, label="f(S)")
plt.axhline(0, color='black', linestyle='--')
plt.scatter(S_roots, f_S_func(S_roots), color='red', label='Raíces')
plt.xlabel('S')
plt.ylabel('f(S)')
plt.legend()
plt.xlim(0,1)
plt.show()
# Out:
# Soluciones de f(S) = 0: [7.00220078e-04 3.67713783e-02 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 2.89489556e-01 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 1.02094028e+00 1.02094028e+00 1.02094028e+00
#  1.31517768e+00]

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')



plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.ylim(0,1)
plt.xlim(0,1)

plt.legend()
plt.grid()
plt.show()

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')


plt.plot(P_int, S_int, color='green')
plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.legend()
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid()
plt.show()
