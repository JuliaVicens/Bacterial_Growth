# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import pandas as pd
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2 kanamycin 1.25 ug/mL Unnamed: 4  \
# 0    Cycle Nr.   Time [s]  Temp. [°C]                   A1         A2
# 1            1          0          30               0.0929     0.0971
# 2            2      678.6        30.5               0.0925     0.0962
# 3            3     1357.2        30.1               0.0926     0.0962
# 4            4     2035.8          30               0.0928     0.0981
# ..         ...        ...         ...                  ...        ...
# 338        338   228685.2        29.9               0.5954     0.6453
# 339        339   229363.7        29.8               0.5937     0.6448
# 340        340   230042.3        29.9               0.5923     0.6429
# 341        341   230720.9        30.3               0.5912     0.6419
# 342        342   231399.5        30.8               0.5902     0.6415
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 kanamycin 2.50 ug/mL  ...  \
# 0           A3         A4         A5         A6                   A7  ...
# 1       0.0948     0.0961     0.0939     0.0934               0.0938  ...
# 2       0.0946     0.0953     0.0935     0.0931               0.0933  ...
# 3        0.095     0.0954     0.0936     0.0932               0.0932  ...
# 4       0.0949     0.0956     0.0937     0.0934               0.0934  ...
# ..         ...        ...        ...        ...                  ...  ...
# 338     0.6513     0.6593     0.6599     0.6576               0.5901  ...
# 339     0.6495     0.6568     0.6572     0.6564               0.5898  ...
# 340     0.6487     0.6575     0.6589     0.6572               0.5889  ...
# 341     0.6484     0.6568      0.657     0.6548               0.5888  ...
# 342     0.6481     0.6563     0.6565     0.6552               0.5872  ...
#
#     Unnamed: 88 Unnamed: 89 Unnamed: 90 Unnamed: 91 Unnamed: 92      LB  \
# 0            H2          H3          H4          H5          H6      H7
# 1        0.0913      0.0914      0.0924      0.0916      0.0925  0.0921
# 2        0.0913      0.0916      0.0926       0.092      0.0914  0.0921
# 3        0.0916      0.0917      0.0927      0.0918      0.0917  0.0922
# 4         0.092      0.0921      0.0931      0.0922      0.0922  0.0928
# ..          ...         ...         ...         ...         ...     ...
# 338      0.0926      0.0926      0.0935      0.0924      0.0949  1.0018
# 339      0.0926      0.0927      0.0934      0.0926      0.0953  1.0017
# 340      0.0925      0.0925      0.0933      0.0923      0.0947  1.0009
# 341      0.0923      0.0924      0.0932      0.0921      0.0942  1.0004
# 342      0.0923      0.0924      0.0933      0.0921      0.0934  1.0014
#
#     Unnamed: 94 Unnamed: 95 Unnamed: 96 Unnamed: 97
# 0            H8          H9         H10         H11
# 1         0.092       0.093      0.0927       0.093
# 2        0.0921      0.0931      0.0932      0.0925
# 3        0.0923      0.0932      0.0932      0.0927
# 4        0.0926      0.0936      0.0937       0.093
# ..          ...         ...         ...         ...
# 338      0.9769      0.9848      0.9871      0.9972
# 339        0.98      0.9857      0.9868      0.9976
# 340      0.9758      0.9833      0.9846      0.9963
# 341      0.9763      0.9843      0.9845      0.9981
# 342      0.9772      0.9853      0.9843      0.9956
#
# [343 rows x 98 columns]

# %%
df1.iloc[:, 3:]
# Out:
#          G4      G5      G6      G7      G8      G9     G10     G11     G12  \
# 0    0.0922  0.0928  0.0928  0.0931  0.0928  0.0927  0.0916  0.0921  0.0911
# 1    0.0951  0.0957  0.0959  0.0959  0.0957  0.0953  0.0947  0.0951  0.0941
# 2    0.0951  0.0958  0.0957  0.0960  0.0958  0.0954  0.0947  0.0951  0.0943
# 3    0.0955  0.0962  0.0961  0.0965  0.0964  0.0958  0.0950  0.0957  0.0947
# 4    0.0960  0.0969  0.0965  0.0968  0.0968  0.0964  0.0956  0.0963  0.0953
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8186  0.8214  0.8188  0.8198  0.8221  0.8201  0.8296  0.8418  0.8292
# 495  0.8184  0.8222  0.8185  0.8178  0.8201  0.8182  0.8277  0.8379  0.8274
# 496  0.8183  0.8222  0.8169  0.8204  0.8214  0.8186  0.8287  0.8409  0.8289
# 497  0.8172  0.8211  0.8194  0.8206  0.8227  0.8201  0.8303  0.8417  0.8280
# 498  0.8191  0.8200  0.8186  0.8207  0.8226  0.8196  0.8285  0.8389  0.8276
#
#          H1      H2      H3      H4      H5      H6
# 0    0.0936  0.0925  0.0918  0.0929  0.0931  0.0931
# 1    0.0970  0.0958  0.0951  0.0963  0.0963  0.0962
# 2    0.0971  0.0959  0.0952  0.0965  0.0964  0.0963
# 3    0.0975  0.0964  0.0957  0.0969  0.0969  0.0969
# 4    0.0981  0.0969  0.0961  0.0974  0.0973  0.0973
# ..      ...     ...     ...     ...     ...     ...
# 494  0.4360  0.7711  0.8043  0.8181  0.8181  0.8153
# 495  0.4379  0.7729  0.8038  0.8198  0.8180  0.8154
# 496  0.4304  0.7719  0.8040  0.8187  0.8172  0.8154
# 497  0.4321  0.7717  0.8043  0.8194  0.8173  0.8143
# 498  0.4285  0.7712  0.8035  0.8189  0.8177  0.8150
#
# [499 rows x 15 columns]

# %%
N_exp=df1.iloc[:, 3:].shape[1]

# %%
for i in range(N_exp):
    plt.plot(df1['Time [s]'],df1.iloc[:, 3+i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
c=-1
P_exp=np.array(df1.iloc[:, 3:].drop('H1',axis=1))[:c]
T_exp=np.array(df1['Time [s]'])[:c]

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max
# Out:
# (14, 337235.3)

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 100 # Number of residual point
N_d = 300 #Number of data

u_star = P_exp.T.flatten().reshape([-1,1])
X_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
ub = X_star.max(0)  

# Initial Condition
xx1 = X_star[::len(T_exp)]
uu1 = u_star[::len(T_exp)]

# Additional data
idx = np.random.choice(u_star.shape[0], N_d-len(uu1), replace=False)
xxd = X_star[idx]
uud = u_star[idx]

X_u_train = np.concatenate((xx1,xxd)).reshape([-1,1])
u_train = np.concatenate((uu1,uud)).reshape([-1,1])

X_f_train = lb + (ub-lb)*lhs(1, N_f)
# X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
u_train_tf =   tf.convert_to_tensor(u_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
u_star_tf = tf.convert_to_tensor(u_star, dtype=tf.float32)
# Out:
# 2024-10-09 17:04:01.649324: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-10-09 17:04:01.649630: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2024-10-09 17:04:01.649891: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2024-10-09 17:04:01.650143: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2024-10-09 17:04:01.650388: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2024-10-09 17:04:01.650633: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2024-10-09 17:04:01.650889: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2024-10-09 17:04:01.651130: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2024-10-09 17:04:01.651219: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-10-09 17:04:01.651805: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    A = 2.0*(X - lb)/(ub - lb) - 1.0
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 

def train_vars_total(W, b, lambda_r, lambda_b):
    return W + b + lambda_r + lambda_b

def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r, 1]), dtype=tf.float32)
    return alpha_r, alpha_b

#@tf.function(jit_compile=True)
@tf.function()
def net_f(t, W_p, b_p, W_phi, b_phi):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([t])
        p=net(t, W_p, b_p)
        phi=net(tf.concat([p,t],1), W_phi, b_phi)
    p_t = tape1.gradient(p, t) 
    f = p_t - phi
    return f


#@tf.function()
@tf.function()
def train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, u_train_tf, X_f_train_tf, u_star_tf, lambda_r, lambda_b, opt):
    t_u = X_u_train_tf
    t_f = X_f_train_tf

    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, lambda_r, lambda_b])
        u_nn = net(t_u, W_p, b_p) 
        f_nn = net_f(t_f, W_p, b_p, W_phi, b_phi)
        loss_u = tf.square(lambda_b*(u_nn - u_train_tf))
        loss_f = tf.square(lambda_r*f_nn) 
        loss =  tf.reduce_mean(loss_u) + tf.reduce_mean(loss_f)
    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
   
    return loss, tf.reduce_mean(loss_u), tf.reduce_mean(loss_f)



layers = [1, 50, 50, 1]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 50, 50, 1]


W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lambda_r, lambda_b = loss_weight(N_f, N_d)

# %%
plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')

for i in range(N_exp):
    plt.plot(X_star[i*len(T_exp):(i+1)*len(T_exp)],u_star[i*len(T_exp):(i+1)*len(T_exp)])

# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('t (ms)')
plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
lr = 1e-4
# Nmax = 4*10**4
Nmax = 15000



optimizer = tf.optimizers.Adam(learning_rate=lr)

start_time = time.time()
n=0
loss = []
loss_unk=[]
while n <= Nmax:
    loss_, loss_u, loss_f = train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, u_train_tf, X_f_train_tf,u_star_tf,  lambda_r, lambda_b, optimizer)
    loss.append(loss_)
    loss_unk.append(loss_f)
    if n % 10 == 0:
        print(f"Iteration is: {n}")
        print(f"Total loss is: {loss_}")

        print(f"Data loss is: {loss_u}")
        print(f"Physicial loss is: {loss_f}")

    n+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Total loss is: 774701.75
# Data loss is: 774701.625
# Physicial loss is: 0.12025676667690277
# Iteration is: 10
# Total loss is: 742122.125
# Data loss is: 742122.125
# Physicial loss is: 0.031119434162974358
# Iteration is: 20
# Total loss is: 707785.3125
# Data loss is: 707785.3125
# Physicial loss is: 0.023746062070131302
# Iteration is: 30
# Total loss is: 674360.1875
# Data loss is: 674360.125
# Physicial loss is: 0.03881597891449928
# Iteration is: 40
# Total loss is: 640416.6875
# Data loss is: 640416.6875
# Physicial loss is: 0.022825874388217926
# Iteration is: 50
# Total loss is: 604580.25
# Data loss is: 604580.25
# Physicial loss is: 0.0038696452975273132
# Iteration is: 60
# Total loss is: 567077.25
# Data loss is: 567077.25
# Physicial loss is: 0.0003028932842426002
# Iteration is: 70
# Total loss is: 528014.625
# Data loss is: 528014.625
# Physicial loss is: 0.0012532168766483665
# Iteration is: 80
# Total loss is: 487423.03125
# Data loss is: 487423.03125
# Physicial loss is: 0.0006723308470100164
# Iteration is: 90
# Total loss is: 445589.6875
# Data loss is: 445589.6875
# Physicial loss is: 0.0001945183757925406
# Iteration is: 100
# Total loss is: 402983.125
# Data loss is: 402983.125
# Physicial loss is: 0.00021911240764893591
# Iteration is: 110
# Total loss is: 360203.25
# Data loss is: 360203.25
# Physicial loss is: 0.000270492018898949
# Iteration is: 120
# Total loss is: 317970.28125
# Data loss is: 317970.28125
# Physicial loss is: 0.0002863231347873807
# Iteration is: 130
# Total loss is: 277090.09375
# Data loss is: 277090.09375
# Physicial loss is: 0.00031794951064512134
# Iteration is: 140
# Total loss is: 238410.984375
# Data loss is: 238410.984375
# Physicial loss is: 0.00036663797800429165
# Iteration is: 150
# Total loss is: 202766.59375
# Data loss is: 202766.59375
# Physicial loss is: 0.0004300996661186218
# Iteration is: 160
# Total loss is: 170901.03125
# Data loss is: 170901.03125
# Physicial loss is: 0.0005110435304231942
# Iteration is: 170
# Total loss is: 143386.609375
# Data loss is: 143386.609375
# Physicial loss is: 0.0005991614889353514
# Iteration is: 180
# Total loss is: 120549.8125
# Data loss is: 120549.8125
# Physicial loss is: 0.0006651945877820253
# Iteration is: 190
# Total loss is: 102422.1328125
# Data loss is: 102422.1328125
# Physicial loss is: 0.0006744429701939225
# Iteration is: 200
# Iteration is: 1770
# Total loss is: 21240.369140625
# Data loss is: 21240.169921875
# Physicial loss is: 0.1982843428850174
# Iteration is: 1780
# Total loss is: 21223.28125
# Data loss is: 21223.095703125
# Physicial loss is: 0.186283677816391
# Iteration is: 1790
# Total loss is: 21206.30078125
# Data loss is: 21206.126953125
# Physicial loss is: 0.17479053139686584
# Iteration is: 1800
# Total loss is: 21189.388671875
# Data loss is: 21189.224609375
# Physicial loss is: 0.16381315886974335
# Iteration is: 1810
# Total loss is: 21172.552734375
# Data loss is: 21172.3984375
# Physicial loss is: 0.15335611999034882
# Iteration is: 1820
# Total loss is: 21155.775390625
# Data loss is: 21155.6328125
# Physicial loss is: 0.14342047274112701
# Iteration is: 1830
# Total loss is: 21139.072265625
# Data loss is: 21138.9375
# Physicial loss is: 0.1340038925409317
# Iteration is: 1840
# Total loss is: 21122.41796875
# Data loss is: 21122.29296875
# Physicial loss is: 0.12510117888450623
# Iteration is: 1850
# Total loss is: 21105.814453125
# Data loss is: 21105.697265625
# Physicial loss is: 0.11670374870300293
# Iteration is: 1860
# Total loss is: 21089.2734375
# Data loss is: 21089.1640625
# Physicial loss is: 0.10880088806152344
# Iteration is: 1870
# Total loss is: 21072.755859375
# Data loss is: 21072.654296875
# Physicial loss is: 0.10137919336557388
# Iteration is: 1880
# Total loss is: 21056.314453125
# Data loss is: 21056.220703125
# Physicial loss is: 0.09442339092493057
# Iteration is: 1890
# Total loss is: 21039.900390625
# Data loss is: 21039.8125
# Physicial loss is: 0.08791627734899521
# Iteration is: 1900
# Total loss is: 21023.54296875
# Data loss is: 21023.4609375
# Physicial loss is: 0.08183921873569489
# Iteration is: 1910
# Total loss is: 21007.220703125
# Data loss is: 21007.14453125
# Physicial loss is: 0.0761728435754776
# Iteration is: 1920
# Total loss is: 20990.947265625
# Data loss is: 20990.876953125
# Physicial loss is: 0.07089641690254211
# Iteration is: 1930
# Total loss is: 20974.70703125
# Data loss is: 20974.640625
# Physicial loss is: 0.06598936021327972
# Iteration is: 1940
# Total loss is: 20958.505859375
# Data loss is: 20958.4453125
# Physicial loss is: 0.061430539935827255
# Iteration is: 1950
# Total loss is: 20942.359375
# Data loss is: 20942.302734375
# Physicial loss is: 0.05719883739948273
# Iteration is: 1960
# Total loss is: 20926.244140625
# Data loss is: 20926.19140625
# Physicial loss is: 0.05327357351779938
# Iteration is: 1970
# Total loss is: 20910.16796875
# Data loss is: 20910.119140625
# Physicial loss is: 0.0496344268321991
# Iteration is: 1980
# Total loss is: 20894.1328125
# Data loss is: 20894.0859375
# Physicial loss is: 0.04626171663403511
# Iteration is: 1990
# Total loss is: 20878.138671875
# Data loss is: 20878.095703125
# Physicial loss is: 0.043136466294527054
# Iteration is: 2000
# Total loss is: 20862.18359375
# Data loss is: 20862.142578125
# Physicial loss is: 0.0402408130466938
# Iteration is: 2010
# Total loss is: 20846.27734375
# Data loss is: 20846.240234375
# Physicial loss is: 0.03755766153335571
# Iteration is: 2020
# Total loss is: 20830.384765625
# Data loss is: 20830.349609375
# Physicial loss is: 0.03507094830274582
# Iteration is: 2030
# Total loss is: 20814.544921875
# Data loss is: 20814.51171875
# Physicial loss is: 0.03276564180850983
# Iteration is: 2040
# Total loss is: 20798.73828125
# Data loss is: 20798.70703125
# Physicial loss is: 0.030627675354480743
# Iteration is: 2050
# Total loss is: 20782.96484375
# Data loss is: 20782.935546875
# Physicial loss is: 0.028644146397709846
# Iteration is: 2060
# Total loss is: 20767.244140625
# Data loss is: 20767.216796875
# Physicial loss is: 0.026803044602274895
# Iteration is: 2070
# Total loss is: 20751.546875
# Data loss is: 20751.521484375
# Physicial loss is: 0.025093309581279755
# Iteration is: 2080
# Total loss is: 20735.88671875
# Data loss is: 20735.86328125
# Physicial loss is: 0.02350490540266037
# Iteration is: 2090
# Total loss is: 20720.267578125
# Data loss is: 20720.24609375
# Physicial loss is: 0.02202843874692917
# Iteration is: 2100
# Total loss is: 20704.6953125
# Data loss is: 20704.673828125
# Physicial loss is: 0.020655395463109016
# Iteration is: 2110
# Total loss is: 20689.14453125
# Data loss is: 20689.125
# Physicial loss is: 0.019377997145056725
# Iteration is: 2120
# Total loss is: 20673.64453125
# Data loss is: 20673.626953125
# Physicial loss is: 0.018189160153269768
# Iteration is: 2130
# Total loss is: 20658.1640625
# Data loss is: 20658.146484375
# Physicial loss is: 0.017082378268241882
# Iteration is: 2140
# Total loss is: 20642.7265625
# Data loss is: 20642.7109375
# Physicial loss is: 0.016051724553108215
# Iteration is: 2150
# Total loss is: 20627.328125
# Data loss is: 20627.3125
# Physicial loss is: 0.01509165670722723
# Iteration is: 2160
# Total loss is: 20611.958984375
# Data loss is: 20611.9453125
# Physicial loss is: 0.014197271317243576
# Iteration is: 2170
# Total loss is: 20596.6328125
# Data loss is: 20596.619140625
# Physicial loss is: 0.013363966718316078
# Iteration is: 2180
# Total loss is: 20581.34375
# Data loss is: 20581.33203125
# Physicial loss is: 0.012587550096213818
# Iteration is: 2190
# Total loss is: 20566.0859375
# Data loss is: 20566.07421875
# Physicial loss is: 0.011864092200994492
# Iteration is: 2200
# Total loss is: 20550.869140625
# Data loss is: 20550.857421875
# Physicial loss is: 0.011190004646778107
# Iteration is: 2210
# Total loss is: 20535.681640625
# Data loss is: 20535.671875
# Physicial loss is: 0.010561969131231308
# Iteration is: 2220
# Total loss is: 20520.53125
# Data loss is: 20520.521484375
# Physicial loss is: 0.009976854547858238
# Iteration is: 2230
# Total loss is: 20505.416015625
# Data loss is: 20505.40625
# Physicial loss is: 0.009431887418031693
# Iteration is: 2240
# Total loss is: 20490.33203125
# Data loss is: 20490.322265625
# Physicial loss is: 0.008924338035285473
# Iteration is: 2250
# Total loss is: 20475.291015625
# Data loss is: 20475.283203125
# Physicial loss is: 0.00845173466950655
# Iteration is: 2260
# Total loss is: 20460.296875
# Data loss is: 20460.2890625
# Physicial loss is: 0.0080117741599679
# Iteration is: 2270
# Total loss is: 20445.33203125
# Data loss is: 20445.32421875
# Physicial loss is: 0.007602233439683914
# Iteration is: 2280
# Total loss is: 20430.388671875
# Data loss is: 20430.380859375
# Physicial loss is: 0.007221117150038481
# Iteration is: 2290
# Total loss is: 20415.498046875
# Data loss is: 20415.490234375
# Physicial loss is: 0.006866512354463339
# Iteration is: 2300
# Total loss is: 20400.634765625
# Data loss is: 20400.62890625
# Physicial loss is: 0.006536645814776421
# Iteration is: 2310
# Total loss is: 20385.806640625
# Data loss is: 20385.80078125
# Physicial loss is: 0.006229817867279053
# Iteration is: 2320
# Total loss is: 20371.0234375
# Data loss is: 20371.017578125
# Physicial loss is: 0.005944497417658567
# Iteration is: 2330
# Total loss is: 20356.275390625
# Data loss is: 20356.26953125
# Physicial loss is: 0.00567921157926321
# Iteration is: 2340
# Total loss is: 20341.568359375
# Data loss is: 20341.5625
# Physicial loss is: 0.005432509817183018
# Iteration is: 2350
# Total loss is: 20326.888671875
# Data loss is: 20326.8828125
# Physicial loss is: 0.00520316231995821
# Iteration is: 2360
# Total loss is: 20312.259765625
# Data loss is: 20312.25390625
# Physicial loss is: 0.004989943001419306
# Iteration is: 2370
# Total loss is: 20297.646484375
# Data loss is: 20297.642578125
# Physicial loss is: 0.004791680723428726
# Iteration is: 2380
# Total loss is: 20283.095703125
# Data loss is: 20283.091796875
# Physicial loss is: 0.004607336595654488
# Iteration is: 2390
# Total loss is: 20268.572265625
# Data loss is: 20268.568359375
# Physicial loss is: 0.004435899201780558
# Iteration is: 2400
# Total loss is: 20254.09375
# Data loss is: 20254.08984375
# Physicial loss is: 0.0042764306999742985
# Iteration is: 2410
# Total loss is: 20239.6640625
# Data loss is: 20239.66015625
# Physicial loss is: 0.00412805937230587
# Iteration is: 2420
# Total loss is: 20225.248046875
# Data loss is: 20225.244140625
# Physicial loss is: 0.003989955876022577
# Iteration is: 2430
# Total loss is: 20210.890625
# Data loss is: 20210.88671875
# Physicial loss is: 0.0038613653741776943
# Iteration is: 2440
# Total loss is: 20196.57421875
# Data loss is: 20196.5703125
# Physicial loss is: 0.0037415814585983753
# Iteration is: 2450
# Total loss is: 20182.29296875
# Data loss is: 20182.2890625
# Physicial loss is: 0.003629939164966345
# Iteration is: 2460
# Total loss is: 20168.0546875
# Data loss is: 20168.05078125
# Physicial loss is: 0.003525793319568038
# Iteration is: 2470
# Total loss is: 20153.849609375
# Data loss is: 20153.845703125
# Physicial loss is: 0.0034285932779312134
# Iteration is: 2480
# Total loss is: 20139.693359375
# Data loss is: 20139.689453125
# Physicial loss is: 0.00333780562505126
# Iteration is: 2490
# Total loss is: 20125.58984375
# Data loss is: 20125.5859375
# Physicial loss is: 0.0032529078889638186
# Iteration is: 2500
# Total loss is: 20111.52734375
# Data loss is: 20111.5234375
# Physicial loss is: 0.003173460252583027
# Iteration is: 2510
# Total loss is: 20097.5078125
# Data loss is: 20097.50390625
# Physicial loss is: 0.0030990606173872948
# Iteration is: 2520
# Total loss is: 20083.5234375
# Data loss is: 20083.51953125
# Physicial loss is: 0.0030292808078229427
# Iteration is: 2530
# Total loss is: 20069.59375
# Data loss is: 20069.58984375
# Physicial loss is: 0.0029637408442795277
# Iteration is: 2540
# Total loss is: 20055.701171875
# Data loss is: 20055.69921875
# Data loss is: 609.2617797851562
# Physicial loss is: 0.0023721656762063503
# Iteration is: 14970
# Total loss is: 608.9596557617188
# Data loss is: 608.957275390625
# Physicial loss is: 0.0023847289849072695
# Iteration is: 14980
# Total loss is: 608.6580810546875
# Data loss is: 608.6557006835938
# Physicial loss is: 0.002397929085418582
# Iteration is: 14990
# Total loss is: 608.4623413085938
# Data loss is: 608.4598999023438
# Physicial loss is: 0.0024236817844212055
# Iteration is: 15000
# Total loss is: 608.61669921875
# Data loss is: 608.6141967773438
# Physicial loss is: 0.0025066060479730368
# Training time: 13.1155

# %%
it = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,int(Nmax))]
loss_phi_list = [loss_unk[i].numpy() for i in range(0,int(Nmax))]

plt.semilogy(it, np.asarray(loss_list), 'b-', linewidth = 2, label = 'Total')  
plt.semilogy(it, np.asarray(loss_phi_list), 'r-', linewidth = 2, label = '$\phi$')       

plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
def predict(X_star_tf, w, b):
    x_star = X_star_tf
    u_pred = net(x_star, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star[:len(T_exp)], dtype=tf.float32)    
u_pred = predict(X_star_tf, W_p, b_p)

## Evaluating unknown function
u_pred_tf = tf.convert_to_tensor(u_pred, dtype=tf.float32) 
phi_pred = predict(tf.concat([u_pred_tf,X_star[:len(T_exp)]],1), W_phi, b_phi)

# %%
plt.plot(X_star[:len(T_exp)], u_pred, label='Prediction')
# for i in range(N_exp):
#     plt.plot(X_star[i*len(T_exp):(i+1)*len(T_exp)],u_star[i*len(T_exp):(i+1)*len(T_exp)],linestyle=':')

plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(u_pred, phi_pred, label='Prediction')
# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(X_star[:len(T_exp)], phi_pred, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
Nt=10000
T_symb=np.zeros(Nt)
P_int=np.zeros(Nt)
dt=0.0001

T_symb[0]=0
P_int[0]=np.mean(uu1) #Initial conditions

for i in range(1,Nt):

    X_p=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(T_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    P_int[i]=P_int[i-1]+predict(X_p , W_phi, b_phi)*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_int, label='Numeric integration symb dPdT')

plt.plot(X_star[:len(T_exp)], u_pred, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# Si N_max es muy alto, hay overfitting y la reconstrucción no es buena. Las pinns aprenden primero las frecuencas más pequeñas, es decir los rasgos más genersles. Esto, para físicos amantes de las vacas redondas nos viene excelentemente bien. Por tanto, buscaremos el punto donde haya aprendido el caso más general con éxito

# %%
# Create and train the PySR model
model_phi = PySRRegressor(
    niterations=1000,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    # unary_operators=[ "exp",  "inv(x) = 1/x"],
    # unary_operators=["inv(x) = 1/x"],

    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # maxsize=50,
    # ^ Allow greater complexity.
    maxdepth=6
    # ^ But, avoid deep nesting.
)

# Fit phi
model_phi.fit(tf.concat([u_pred_tf,X_star[:len(T_exp)]],1), np.array(phi_pred))
print(model_phi)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 2.120e+05
# Head worker occupation: 41.6%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 501 / 15000 total iterations (3.340%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = (-5.684 * (x₁ + x₀)) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.91 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          2.476e-01  5.911e-02  y = x₀ * (-20.843 * (-1.5773 + ((-0.1779 + x₀) * (x₁ + 1.5908)...
#                                   )))
# 15          7.103e-02  6.243e-01  y = (x₀ + (-0.72981 * x₁)) * (-21.829 * (-2.0432 + ((1.7196 + ...
#                                   x₁) * x₀)))
# 17          5.105e-02  1.652e-01  y = (x₀ + ((-0.72981 + -0.11121) * x₁)) * (-21.829 * (-2.0432 ...
#                                   + ((1.7196 + x₁) * x₀)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.380e+05
# Head worker occupation: 33.0%
# Progress: 1145 / 15000 total iterations (7.633%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.702e-01  2.465e-01  y = x₀ * ((((x₁ + 0.78355) * (x₀ + -0.47254)) + -0.58288) * -3...
#                                   9.539)
# 15          5.029e-02  6.096e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.892e-02  1.373e-02  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * (((x₁ + 0.0...
#                                   02422) * -0.85283) + x₀)
# 19          4.528e-02  3.871e-02  y = ((((1.7212 + x₁) * x₀) + -2.0441) * -22.409) * ((x₀ + (-0....
#                                   83837 * x₁)) + (-0.026416 * 0.36967))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.570e+05
# Head worker occupation: 29.0%
# Progress: 1801 / 15000 total iterations (12.007%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.701e-01  2.470e-01  y = x₀ * ((-0.56791 + ((x₁ + 0.76759) * (x₀ + -0.47833))) * -4...
#                                   0.224)
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.848e-02  1.832e-02  y = (((x₀ * (1.6925 + x₁)) + -2.0151) * -22.223) * ((x₁ * -0.8...
#                                   5358) + (x₀ + -0.0051576))
# 19          4.528e-02  3.412e-02  y = ((((1.7212 + x₁) * x₀) + -2.0441) * -22.409) * ((x₀ + (-0....
#                                   83837 * x₁)) + (-0.026416 * 0.36967))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+05
# Head worker occupation: 27.7%
# Progress: 2428 / 15000 total iterations (16.187%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = (-40.398 * (((x₁ + 0.76361) * (x₀ + -0.47978)) + -0.56423)...
#                                   ) * x₀
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.568e-02  4.802e-02  y = ((-2.0441 + ((1.7212 + x₁) * x₀)) * -22.409) * (x₀ + ((-0....
#                                   83837 * x₁) + -0.0077294))
# 19          4.528e-02  4.421e-03  y = ((((1.7212 + x₁) * x₀) + -2.0441) * -22.409) * ((x₀ + (-0....
#                                   83837 * x₁)) + (-0.026416 * 0.36967))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.680e+05
# Head worker occupation: 28.0%
# Progress: 2986 / 15000 total iterations (19.907%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = (-40.398 * (((x₁ + 0.76361) * (x₀ + -0.47978)) + -0.56423)...
#                                   ) * x₀
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.568e-02  4.802e-02  y = ((-2.0441 + ((1.7212 + x₁) * x₀)) * -22.409) * (x₀ + ((-0....
#                                   83837 * x₁) + -0.0077294))
# 19          4.528e-02  4.421e-03  y = ((((1.7212 + x₁) * x₀) + -2.0441) * -22.409) * ((x₀ + (-0....
#                                   83837 * x₁)) + (-0.026416 * 0.36967))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.610e+05
# Head worker occupation: 27.3%
# Progress: 3548 / 15000 total iterations (23.653%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.471e-02  5.880e-02  y = (((x₀ * (x₁ + 1.7169)) + -2.0397) * -22.646) * (((-0.83748...
#                                    * x₁) + -0.011682) + x₀)
# 19          4.458e-02  1.407e-03  y = (((x₀ * (x₁ + 1.7169)) + -2.0397) * (-22.646 + x₁)) * (((-...
#                                   0.83748 * x₁) + -0.011682) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Head worker occupation: 27.4%
# Progress: 4204 / 15000 total iterations (28.027%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.470e-02  5.885e-02  y = (((x₀ * (x₁ + 1.7148)) + -2.0375) * -22.675) * (x₀ + (-0.0...
#                                   12267 + (x₁ * -0.83574)))
# 19          4.457e-02  1.446e-03  y = (((x₀ * (x₁ + 1.7148)) + -2.0375) * (-22.675 + x₁)) * (x₀ ...
#                                   + (-0.012267 + (x₁ * -0.83574)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+05
# Head worker occupation: 28.5%
# Progress: 4873 / 15000 total iterations (32.487%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.464e-02  5.958e-02  y = (-22.771 * ((x₀ * (x₁ + 1.7128)) + -2.0354)) * ((-0.012526...
#                                    + (x₁ * -0.83733)) + x₀)
# 19          4.423e-02  4.636e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.750e+05
# Head worker occupation: 28.8%
# Progress: 5533 / 15000 total iterations (36.887%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.464e-02  5.958e-02  y = (-22.771 * ((x₀ * (x₁ + 1.7128)) + -2.0354)) * ((-0.012526...
#                                    + (x₁ * -0.83733)) + x₀)
# 19          4.423e-02  4.636e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.930e+05
# Head worker occupation: 27.6%
# Progress: 6222 / 15000 total iterations (41.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = (-8.4026 * x₀) + 8.092
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.464e-02  5.958e-02  y = (-22.771 * ((x₀ * (x₁ + 1.7128)) + -2.0354)) * ((-0.012526...
#                                    + (x₁ * -0.83733)) + x₀)
# 19          4.423e-02  4.636e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.960e+05
# Head worker occupation: 26.4%
# Progress: 6893 / 15000 total iterations (45.953%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          4.423e-02  4.606e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.980e+05
# Head worker occupation: 25.7%
# Progress: 7567 / 15000 total iterations (50.447%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          4.423e-02  4.606e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.000e+05
# Head worker occupation: 26.2%
# Progress: 8249 / 15000 total iterations (54.993%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          4.423e-02  4.606e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.940e+05
# Head worker occupation: 26.3%
# Progress: 8884 / 15000 total iterations (59.227%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          1.700e-01  2.470e-01  y = x₀ * (-40.379 * (-0.56464 + ((x₁ + 0.76404) * (x₀ + -0.479...
#                                   62))))
# 15          5.029e-02  6.092e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          4.423e-02  4.606e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.950e+05
# Head worker occupation: 27.4%
# Progress: 9564 / 15000 total iterations (63.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (((x₁ + x₀) * (-36.472 + (x₁ * 12.738))) + 42.854) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          4.423e-02  4.606e-03  y = ((-22.903 + x₁) * ((x₀ * (x₁ + 1.7097)) + -2.032)) * (x₀ +...
#                                    ((x₁ * -0.8361) + -0.012985))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.960e+05
# Head worker occupation: 26.5%
# Progress: 10230 / 15000 total iterations (68.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (((x₀ + x₁) * (-36.472 + (12.738 * x₁))) + 42.853) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.950e+05
# Head worker occupation: 25.6%
# Progress: 10888 / 15000 total iterations (72.587%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (((x₀ + x₁) * (-36.472 + (12.738 * x₁))) + 42.853) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.000e+05
# Head worker occupation: 26.3%
# Progress: 11555 / 15000 total iterations (77.033%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (((x₀ + x₁) * (-36.472 + (12.738 * x₁))) + 42.853) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.980e+05
# Head worker occupation: 27.9%
# Progress: 12211 / 15000 total iterations (81.407%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (42.853 + ((x₀ + x₁) * (-36.472 + (12.737 * x₁)))) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+05
# Head worker occupation: 29.3%
# Progress: 12859 / 15000 total iterations (85.727%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (42.853 + ((x₀ + x₁) * ((x₁ * 12.737) + -36.472))) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.060e+05
# Head worker occupation: 26.9%
# Progress: 13587 / 15000 total iterations (90.580%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.777 * (-2.4038 + ((2.0713 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (42.853 + ((x₀ + x₁) * ((x₁ * 12.737) + -36.472))) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.140e+05
# Head worker occupation: 25.3%
# Progress: 14310 / 15000 total iterations (95.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.905e+00  1.594e+01  y = 0.74037
# 5           5.236e+00  1.030e-01  y = 8.092 + (-8.4025 * x₀)
# 7           3.671e+00  1.776e-01  y = ((x₀ + x₁) * -5.6839) + 8.5554
# 9           1.581e+00  4.212e-01  y = (((-78.911 * x₀) + 58.053) * x₁) + 6.6134
# 11          2.787e-01  8.678e-01  y = x₀ * (-16.778 * (-2.4037 + ((2.0712 + x₁) * x₀)))
# 13          7.402e-02  6.629e-01  y = (42.853 + ((x₀ + x₁) * ((x₁ * 12.737) + -36.472))) * x₀
# 15          5.029e-02  1.933e-01  y = (-22.223 * ((x₀ * (1.6925 + x₁)) + -2.0151)) * ((x₁ * -0.8...
#                                   5283) + x₀)
# 17          4.463e-02  5.961e-02  y = (-22.771 * (-2.037 + (x₀ * (x₁ + 1.7145)))) * ((-0.012682 ...
#                                   + (-0.83722 * x₁)) + x₀)
# 19          3.754e-02  8.659e-02  y = (-22.922 * ((x₀ * (x₁ + 1.6682)) + -1.9887)) * ((((x₁ * x₀...
#                                   ) * -1.0095) + -0.023183) + x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                         0.74036556
# 	1        0.102982                        8.091992 + (-8.402537 * x0)
# 	2        0.177606                ((x0 + x1) * -5.6839323) + 8.555369
# 	3        0.421227  (((-78.910774 * x0) + 58.052868) * x1) + 6.613415
# 	4        0.867847  x0 * (-16.777615 * (-2.4037266 + ((2.0712366 +...
# 	5        0.662854  (42.85338 + ((x0 + x1) * ((x1 * 12.73747) + -3...
# 	6  >>>>  0.193295  (-22.223284 * ((x0 * (1.6924802 + x1)) + -2.01...
# 	7        0.059610  (-22.771355 * (-2.0370398 + (x0 * (x1 + 1.7144...
# 	8        0.086589  (-22.921783 * ((x0 * (x1 + 1.6681548)) + -1.98...
#
# 	       loss  complexity
# 	0  7.905485           1
# 	1  5.236366           5
# 	2  3.670820           7
# 	3  1.580847           9
# 	4  0.278668          11
# 	5  0.074018          13
# 	6  0.050286          15
# 	7  0.044634          17
# 	8  0.037537          19
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_phi.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
import sympy 
chose=4
expr=model_phi.sympy(chose)
sympy.together(expr)
# Out:
# -16.777615*x0*(x0*(x1 + 2.0712366) - 2.4037266)

# %%
symb1=model_phi.predict(tf.concat([u_pred_tf,X_star[:len(T_exp)]],1),chose)
plt.plot(u_pred, phi_pred, label='PINN prediction')
plt.plot(u_pred, symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('P')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
plt.plot(X_star[:len(T_exp)], phi_pred, label='PINN prediction')
plt.plot(X_star[:len(T_exp)], symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('t')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
Nt=10000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
dt=0.0001

P_symb[0]=np.mean(uu1) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    # P_symb[i]=P_symb[i-1]+(1/(T_symb[i-1]*(P_symb[i-1]-0.598)+0.068)+1.607/(P_symb[i-1]*(P_symb[i-1]-1.314)))*dt
    P_symb[i]=P_symb[i-1]+model_phi.predict(tf.concat([np.reshape(P_symb[i-1],[-1,1]),np.reshape(T_symb[i-1],[-1,1])],1),chose)*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')
plt.plot(T_symb, P_int, label='Numeric integration PINN dPdT')
plt.plot(X_star[:len(T_exp)], u_pred, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# Debería hacer una tabla donde haga ticks en los términos que aparecen que hace que se ajuste
# ¿Debería probar dependencia con dP/dt?

# %%
Nt=1000
dt=0.001
P=np.zeros(Nt)
T=np.zeros(Nt)

P[0]=0.09 #Initial conditions
T[0]=0
# r=40.33
# a=-34.75
# b=-16.78

r=40.33
a=-34.75
b=-16.78
for r in [30,40,50]:
    for i in range(1,Nt):
        # P[i]=P[i-1]+(1/(T[i-1]*(P[i-1]-0.598)+0.068)+1.607/(P[i-1]*(P[i-1]-1.314)))*dt
        P[i]=P[i-1]+(r*P[i-1]+a*P[i-1]**2+b*T[i-1]*P[i-1]**2)*dt
        T[i]=T[i-1]+dt

    plt.plot(T,P,label=f'a = {r}')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')

plt.show()


r=40.33
a=-34.75
b=-16.78
for a in [-50,-30,-10]:
    for i in range(1,Nt):
        # P[i]=P[i-1]+(1/(T[i-1]*(P[i-1]-0.598)+0.068)+1.607/(P[i-1]*(P[i-1]-1.314)))*dt
        P[i]=P[i-1]+(r*P[i-1]+a*P[i-1]**2+b*T[i-1]*P[i-1]**2)*dt
        T[i]=T[i-1]+dt

    plt.plot(T,P,label=f'b = {a}')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')
plt.show()

r=40.33
a=-34.75
b=-16.78
for b in [0,-15,-30]:
    for i in range(1,Nt):
        # P[i]=P[i-1]+(1/(T[i-1]*(P[i-1]-0.598)+0.068)+1.607/(P[i-1]*(P[i-1]-1.314)))*dt
        P[i]=P[i-1]+(r*P[i-1]+a*P[i-1]**2+b*T[i-1]*P[i-1]**2)*dt
        T[i]=T[i-1]+dt

    plt.plot(T,P,label=f'c = {b}')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')
plt.show()

# %%
Nt=1000
dt=0.001
P=np.zeros(Nt)
T=np.zeros(Nt)

P[0]=0.09 #Initial conditions
T[0]=0
# r=40.33
# a=-34.75
# b=-16.78

r=40.33
a=-34.75
b=-16.78
for r in [30,40,50]:
    for i in range(1,Nt):
        # P[i]=P[i-1]+(1/(T[i-1]*(P[i-1]-0.598)+0.068)+1.607/(P[i-1]*(P[i-1]-1.314)))*dt
        P[i]=P[i-1]+(r*P[i-1]+a*P[i-1]**2+b*T[i-1]*P[i-1])*dt
        T[i]=T[i-1]+dt

    plt.plot(T,P,label=f'a = {r}')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')

plt.show()


r=40.33
a=-34.75
b=-16.78
for a in [-50,-30,-10]:
    for i in range(1,Nt):
        # P[i]=P[i-1]+(1/(T[i-1]*(P[i-1]-0.598)+0.068)+1.607/(P[i-1]*(P[i-1]-1.314)))*dt
        P[i]=P[i-1]+(r*P[i-1]+a*P[i-1]**2+b*T[i-1]*P[i-1])*dt
        T[i]=T[i-1]+dt

    plt.plot(T,P,label=f'b = {a}')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')
plt.show()

r=40.33
a=-34.75
b=-16.78
for b in [0,-15,-30]:
    for i in range(1,Nt):
        # P[i]=P[i-1]+(1/(T[i-1]*(P[i-1]-0.598)+0.068)+1.607/(P[i-1]*(P[i-1]-1.314)))*dt
        P[i]=P[i-1]+(r*P[i-1]+a*P[i-1]**2+b*T[i-1]*P[i-1])*dt
        T[i]=T[i-1]+dt

    plt.plot(T,P,label=f'c = {b}')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')
plt.show()

# %%
# Fit dP/dt
# Create and train the PySR model
model_dPdT = PySRRegressor(
    niterations=50,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    unary_operators=[ "exp",  "inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # complexity_of_operators={"exp": 2},
    constraints={'exp': (1)},
    weight_randomize=0.1,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # maxsize=50,
    # ^ Allow greater complexity.
    maxdepth=6
    # ^ But, avoid deep nesting.
)

model_dPdT.fit(X_star[:len(T_exp)], u_pred)
print(model_dPdT)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.950e+05
# Head worker occupation: 38.3%
# Progress: 483 / 750 total iterations (64.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.963e-02  1.594e+01  y = 0.87312
# 5           3.942e-02  1.329e-03  y = 0.84806 + (0.050131 * x₀)
# 6           1.960e-02  6.987e-01  y = x₀ * inv(x₀ + 0.030431)
# 8           1.285e-02  2.112e-01  y = inv(exp(exp(2.0005 + (x₀ * -40.851))))
# 9           7.483e-03  5.407e-01  y = (x₀ * inv(exp(x₀) + -0.9352)) * 1.4362
# 11          5.554e-03  1.490e-01  y = (x₀ + x₀) * inv(-0.89112 + exp(1.2925 * x₀))
# 13          4.679e-03  8.568e-02  y = inv(-0.87067 + (exp(x₀) + (x₀ * x₀))) * (x₀ + x₀)
# 15          4.109e-03  6.501e-02  y = inv(-0.89303 + (exp(x₀) + (x₀ * x₀))) * ((-0.018023 + x₀) ...
#                                   + x₀)
# 19          3.600e-03  3.308e-02  y = inv(exp(3.1532 * x₀) + (inv(-0.82133) + 0.57066)) * ((exp(...
#                                   exp(x₀)) + exp(1.0605)) * x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          0.8731237
# 	1        0.001329                     0.8480602 + (0.050130635 * x0)
# 	2        0.698659                         x0 * inv(x0 + 0.030430797)
# 	3        0.211207        inv(exp(exp(2.0004773 + (x0 * -40.85126))))
# 	4        0.706799        (x0 * 1.384012) * inv(-0.9351896 + exp(x0))
# 	5  >>>>  0.101912  x0 * inv(-0.9417839 + (exp(x0) + (x0 * -0.3978...
# 	6        0.049750  inv((exp(x0) + (x0 * x0)) + -0.87067163) * (x0...
# 	7        0.065012  inv(-0.89303243 + (exp(x0) + (x0 * x0))) * ((-...
# 	8        0.015316  inv(exp(3.1995702 * x0) + -0.662456) * (((exp(...
# 	9        0.086383  inv(exp(3.153176 * x0) + (inv(-0.82132673) + 0...
#
# 	       loss  complexity
# 	0  0.039633           1
# 	1  0.039423           5
# 	2  0.019603           6
# 	3  0.012849           8
# 	4  0.006337           9
# 	5  0.005169          11
# 	6  0.004679          13
# 	7  0.004109          15
# 	8  0.003924          18
# 	9  0.003600          19
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_dPdT.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')
# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=5
model_dPdT.sympy(chose)
# Out:
# x0/(x0*(-0.3978229) + exp(x0) - 0.9417839)

# %%
symb1=model_dPdT.predict(X_star[:len(T_exp)],chose)
plt.plot(X_star[:len(T_exp)], u_pred, label='PINN prediction')
plt.plot(X_star[:len(T_exp)], symb1, linestyle='--', label='Symbolic regresion')
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')

# plt.plot(T, P, linestyle=':', label='Exact')

plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()
