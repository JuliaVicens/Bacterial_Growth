# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import pandas as pd

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2 kanamycin 1.25 ug/mL Unnamed: 4  \
# 0    Cycle Nr.   Time [s]  Temp. [°C]                   A1         A2
# 1            1          0          30               0.0929     0.0971
# 2            2      678.6        30.5               0.0925     0.0962
# 3            3     1357.2        30.1               0.0926     0.0962
# 4            4     2035.8          30               0.0928     0.0981
# ..         ...        ...         ...                  ...        ...
# 338        338   228685.2        29.9               0.5954     0.6453
# 339        339   229363.7        29.8               0.5937     0.6448
# 340        340   230042.3        29.9               0.5923     0.6429
# 341        341   230720.9        30.3               0.5912     0.6419
# 342        342   231399.5        30.8               0.5902     0.6415
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 kanamycin 2.50 ug/mL  ...  \
# 0           A3         A4         A5         A6                   A7  ...
# 1       0.0948     0.0961     0.0939     0.0934               0.0938  ...
# 2       0.0946     0.0953     0.0935     0.0931               0.0933  ...
# 3        0.095     0.0954     0.0936     0.0932               0.0932  ...
# 4       0.0949     0.0956     0.0937     0.0934               0.0934  ...
# ..         ...        ...        ...        ...                  ...  ...
# 338     0.6513     0.6593     0.6599     0.6576               0.5901  ...
# 339     0.6495     0.6568     0.6572     0.6564               0.5898  ...
# 340     0.6487     0.6575     0.6589     0.6572               0.5889  ...
# 341     0.6484     0.6568      0.657     0.6548               0.5888  ...
# 342     0.6481     0.6563     0.6565     0.6552               0.5872  ...
#
#     Unnamed: 88 Unnamed: 89 Unnamed: 90 Unnamed: 91 Unnamed: 92      LB  \
# 0            H2          H3          H4          H5          H6      H7
# 1        0.0913      0.0914      0.0924      0.0916      0.0925  0.0921
# 2        0.0913      0.0916      0.0926       0.092      0.0914  0.0921
# 3        0.0916      0.0917      0.0927      0.0918      0.0917  0.0922
# 4         0.092      0.0921      0.0931      0.0922      0.0922  0.0928
# ..          ...         ...         ...         ...         ...     ...
# 338      0.0926      0.0926      0.0935      0.0924      0.0949  1.0018
# 339      0.0926      0.0927      0.0934      0.0926      0.0953  1.0017
# 340      0.0925      0.0925      0.0933      0.0923      0.0947  1.0009
# 341      0.0923      0.0924      0.0932      0.0921      0.0942  1.0004
# 342      0.0923      0.0924      0.0933      0.0921      0.0934  1.0014
#
#     Unnamed: 94 Unnamed: 95 Unnamed: 96 Unnamed: 97
# 0            H8          H9         H10         H11
# 1         0.092       0.093      0.0927       0.093
# 2        0.0921      0.0931      0.0932      0.0925
# 3        0.0923      0.0932      0.0932      0.0927
# 4        0.0926      0.0936      0.0937       0.093
# ..          ...         ...         ...         ...
# 338      0.9769      0.9848      0.9871      0.9972
# 339        0.98      0.9857      0.9868      0.9976
# 340      0.9758      0.9833      0.9846      0.9963
# 341      0.9763      0.9843      0.9845      0.9981
# 342      0.9772      0.9853      0.9843      0.9956
#
# [343 rows x 98 columns]

# %%
df1.iloc[:, 3:]
# Out:
#          G4      G5      G6      G7      G8      G9     G10     G11     G12  \
# 0    0.0922  0.0928  0.0928  0.0931  0.0928  0.0927  0.0916  0.0921  0.0911
# 1    0.0951  0.0957  0.0959  0.0959  0.0957  0.0953  0.0947  0.0951  0.0941
# 2    0.0951  0.0958  0.0957  0.0960  0.0958  0.0954  0.0947  0.0951  0.0943
# 3    0.0955  0.0962  0.0961  0.0965  0.0964  0.0958  0.0950  0.0957  0.0947
# 4    0.0960  0.0969  0.0965  0.0968  0.0968  0.0964  0.0956  0.0963  0.0953
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8186  0.8214  0.8188  0.8198  0.8221  0.8201  0.8296  0.8418  0.8292
# 495  0.8184  0.8222  0.8185  0.8178  0.8201  0.8182  0.8277  0.8379  0.8274
# 496  0.8183  0.8222  0.8169  0.8204  0.8214  0.8186  0.8287  0.8409  0.8289
# 497  0.8172  0.8211  0.8194  0.8206  0.8227  0.8201  0.8303  0.8417  0.8280
# 498  0.8191  0.8200  0.8186  0.8207  0.8226  0.8196  0.8285  0.8389  0.8276
#
#          H1      H2      H3      H4      H5      H6
# 0    0.0936  0.0925  0.0918  0.0929  0.0931  0.0931
# 1    0.0970  0.0958  0.0951  0.0963  0.0963  0.0962
# 2    0.0971  0.0959  0.0952  0.0965  0.0964  0.0963
# 3    0.0975  0.0964  0.0957  0.0969  0.0969  0.0969
# 4    0.0981  0.0969  0.0961  0.0974  0.0973  0.0973
# ..      ...     ...     ...     ...     ...     ...
# 494  0.4360  0.7711  0.8043  0.8181  0.8181  0.8153
# 495  0.4379  0.7729  0.8038  0.8198  0.8180  0.8154
# 496  0.4304  0.7719  0.8040  0.8187  0.8172  0.8154
# 497  0.4321  0.7717  0.8043  0.8194  0.8173  0.8143
# 498  0.4285  0.7712  0.8035  0.8189  0.8177  0.8150
#
# [499 rows x 15 columns]

# %%
N_exp=df1.iloc[:, 3:].shape[1]

# %%
for i in range(N_exp):
    plt.plot(df1['Time [s]'],df1.iloc[:, 3+i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
c=-1
P_exp=np.array(df1.iloc[:, 3:].drop('H1',axis=1))[:c]
T_exp=np.array(df1['Time [s]'])[:c]

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max
# Out:
# (14, 337235.3)

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 100 # Number of residual point
N_d = 300 #Number of data

u_star = P_exp.T.flatten().reshape([-1,1])
X_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
ub = X_star.max(0)  

# Initial Condition
xx1 = X_star[::len(T_exp)]
uu1 = u_star[::len(T_exp)]

# Additional data
idx = np.random.choice(u_star.shape[0], N_d-len(uu1), replace=False)
xxd = X_star[idx]
uud = u_star[idx]

X_u_train = np.concatenate((xx1,xxd)).reshape([-1,1])
u_train = np.concatenate((uu1,uud)).reshape([-1,1])

X_f_train = lb + (ub-lb)*lhs(1, N_f)
# X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
u_train_tf =   tf.convert_to_tensor(u_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
u_star_tf = tf.convert_to_tensor(u_star, dtype=tf.float32)

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    A = 2.0*(X - lb)/(ub - lb) - 1.0
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 

def train_vars_total(W, b, lambda_r, lambda_b):
    return W + b + lambda_r + lambda_b

def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r, 1]), dtype=tf.float32)
    return alpha_r, alpha_b

#@tf.function(jit_compile=True)
@tf.function()
def net_f(t, W_p, b_p, W_phi, b_phi):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([t])
        p=net(t, W_p, b_p)
        phi=net(tf.concat([p,t],1), W_phi, b_phi)
    p_t = tape1.gradient(p, t) 
    f = p_t - phi
    return f


#@tf.function()
@tf.function()
def train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, u_train_tf, X_f_train_tf, u_star_tf, lambda_r, lambda_b, opt):
    t_u = X_u_train_tf
    t_f = X_f_train_tf

    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, lambda_r, lambda_b])
        u_nn = net(t_u, W_p, b_p) 
        f_nn = net_f(t_f, W_p, b_p, W_phi, b_phi)
        loss_u = tf.square(lambda_b*(u_nn - u_train_tf))
        loss_f = tf.square(lambda_r*f_nn) 
        loss =  tf.reduce_mean(loss_u) + tf.reduce_mean(loss_f)
    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
   
    return loss, tf.reduce_mean(loss_u), tf.reduce_mean(loss_f)



layers = [1, 50, 50, 1]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 50, 50, 1]


W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lambda_r, lambda_b = loss_weight(N_f, N_d)

# %%
plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')

for i in range(N_exp):
    plt.plot(X_star[i*len(T_exp):(i+1)*len(T_exp)],u_star[i*len(T_exp):(i+1)*len(T_exp)])

# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('t (ms)')
plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
lr = 1e-4
# Nmax = 4*10**4
Nmax = 15000



optimizer = tf.optimizers.Adam(learning_rate=lr)

start_time = time.time()
n=0
loss = []
loss_unk=[]
while n <= Nmax:
    loss_, loss_u, loss_f = train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, u_train_tf, X_f_train_tf,u_star_tf,  lambda_r, lambda_b, optimizer)
    loss.append(loss_)
    loss_unk.append(loss_f)
    if n % 10 == 0:
        print(f"Iteration is: {n}")
        print(f"Total loss is: {loss_}")

        print(f"Data loss is: {loss_u}")
        print(f"Physicial loss is: {loss_f}")

    n+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Total loss is: 748693.25
# Data loss is: 748693.125
# Physicial loss is: 0.12022913247346878
# Iteration is: 10
# Total loss is: 717878.5
# Data loss is: 717878.4375
# Physicial loss is: 0.03128722682595253
# Iteration is: 20
# Total loss is: 685619.0625
# Data loss is: 685619.0625
# Physicial loss is: 0.022890686988830566
# Iteration is: 30
# Total loss is: 653626.0
# Data loss is: 653625.9375
# Physicial loss is: 0.03211703523993492
# Iteration is: 40
# Total loss is: 620056.4375
# Data loss is: 620056.4375
# Physicial loss is: 0.013430971652269363
# Iteration is: 50
# Total loss is: 584425.4375
# Data loss is: 584425.4375
# Physicial loss is: 0.0010863421484827995
# Iteration is: 60
# Total loss is: 547171.125
# Data loss is: 547171.125
# Physicial loss is: 0.0017080316320061684
# Iteration is: 70
# Total loss is: 508243.625
# Data loss is: 508243.625
# Physicial loss is: 0.0016978996573016047
# Iteration is: 80
# Total loss is: 467753.375
# Data loss is: 467753.375
# Physicial loss is: 0.0005420781672000885
# Iteration is: 90
# Total loss is: 426057.4375
# Data loss is: 426057.4375
# Physicial loss is: 0.00019707423052750528
# Iteration is: 100
# Total loss is: 383645.78125
# Data loss is: 383645.78125
# Physicial loss is: 0.00019984573009423912
# Iteration is: 110
# Total loss is: 341160.46875
# Data loss is: 341160.46875
# Physicial loss is: 0.0003088077064603567
# Iteration is: 120
# Total loss is: 299387.78125
# Data loss is: 299387.78125
# Physicial loss is: 0.0005159755819477141
# Iteration is: 130
# Total loss is: 259220.828125
# Data loss is: 259220.828125
# Physicial loss is: 0.0007806255016475916
# Iteration is: 140
# Total loss is: 221593.6875
# Data loss is: 221593.6875
# Physicial loss is: 0.0011190554359927773
# Iteration is: 150
# Total loss is: 187391.390625
# Data loss is: 187391.390625
# Physicial loss is: 0.0015594384167343378
# Iteration is: 160
# Total loss is: 157351.40625
# Data loss is: 157351.40625
# Physicial loss is: 0.0020517611410468817
# Iteration is: 170
# Total loss is: 131973.6875
# Data loss is: 131973.6875
# Physicial loss is: 0.002444614190608263
# Iteration is: 180
# Total loss is: 111453.34375
# Data loss is: 111453.34375
# Physicial loss is: 0.0025437409058213234
# Iteration is: 190
# Total loss is: 95653.4921875
# Data loss is: 95653.4921875
# Physicial loss is: 0.002232427941635251
# Iteration is: 200
# Total loss is: 84129.890625
# Data loss is: 84129.890625
# Physicial loss is: 0.001598006347194314
# Iteration is: 210
# Total loss is: 76207.6953125
# Data loss is: 76207.6953125
# Physicial loss is: 0.000920679944101721
# Iteration is: 220
# Total loss is: 71095.484375
# Data loss is: 71095.484375
# Physicial loss is: 0.0004529802827164531
# Iteration is: 230
# Total loss is: 68007.46875
# Data loss is: 68007.46875
# Physicial loss is: 0.00023032192257232964
# Iteration is: 240
# Total loss is: 66261.6796875
# Data loss is: 66261.6796875
# Physicial loss is: 0.00014635585830546916
# Iteration is: 250
# Total loss is: 65333.421875
# Data loss is: 65333.421875
# Physicial loss is: 0.00011648720101220533
# Iteration is: 260
# Total loss is: 64861.87890625
# Data loss is: 64861.87890625
# Physicial loss is: 0.00010957453196169809
# Iteration is: 270
# Total loss is: 64623.8984375
# Data loss is: 64623.8984375
# Physicial loss is: 0.00011305048974463716
# Iteration is: 280
# Total loss is: 64494.83984375
# Data loss is: 64494.83984375
# Physicial loss is: 0.0001208357498398982
# Iteration is: 290
# Total loss is: 64411.6015625
# Data loss is: 64411.6015625
# Physicial loss is: 0.00013127562124282122
# Iteration is: 300
# Total loss is: 64345.1328125
# Data loss is: 64345.1328125
# Physicial loss is: 0.00014376848412211984
# Iteration is: 310
# Total loss is: 64283.33203125
# Data loss is: 64283.33203125
# Physicial loss is: 0.00015790427278261632
# Iteration is: 320
# Total loss is: 64221.640625
# Data loss is: 64221.640625
# Physicial loss is: 0.00017356936587020755
# Iteration is: 330
# Total loss is: 64158.4921875
# Data loss is: 64158.4921875
# Physicial loss is: 0.00019076373428106308
# Iteration is: 340
# Total loss is: 64093.3984375
# Data loss is: 64093.3984375
# Physicial loss is: 0.0002095135278068483
# Iteration is: 350
# Total loss is: 64026.19140625
# Data loss is: 64026.19140625
# Physicial loss is: 0.00022986881958786398
# Iteration is: 360
# Total loss is: 63956.79296875
# Data loss is: 63956.79296875
# Physicial loss is: 0.0002519124245736748
# Iteration is: 370
# Total loss is: 63885.12109375
# Data loss is: 63885.12109375
# Physicial loss is: 0.00027575867716223
# Iteration is: 380
# Total loss is: 63811.09375
# Data loss is: 63811.09375
# Physicial loss is: 0.00030154516571201384
# Iteration is: 390
# Total loss is: 63734.6328125
# Data loss is: 63734.6328125
# Physicial loss is: 0.0003294250345788896
# Iteration is: 400
# Total loss is: 63655.640625
# Data loss is: 63655.640625
# Physicial loss is: 0.00035957046202383935
# Iteration is: 410
# Total loss is: 63574.0
# Data loss is: 63574.0
# Physicial loss is: 0.0003921675670426339
# Iteration is: 420
# Total loss is: 63489.6328125
# Data loss is: 63489.6328125
# Physicial loss is: 0.0004274198436178267
# Iteration is: 430
# Total loss is: 63402.3984375
# Data loss is: 63402.3984375
# Physicial loss is: 0.0004655544471461326
# Iteration is: 440
# Total loss is: 63312.19140625
# Data loss is: 63312.19140625
# Physicial loss is: 0.0005068159662187099
# Iteration is: 450
# Total loss is: 63218.90625
# Data loss is: 63218.90625
# Physicial loss is: 0.0005514785880222917
# Iteration is: 460
# Total loss is: 63122.375
# Data loss is: 63122.375
# Physicial loss is: 0.0005998405977152288
# Iteration is: 470
# Total loss is: 63022.46484375
# Data loss is: 63022.46484375
# Physicial loss is: 0.0006522354669868946
# Iteration is: 480
# Total loss is: 62919.0390625
# Data loss is: 62919.0390625
# Physicial loss is: 0.10237754136323929
# Iteration is: 1010
# Total loss is: 42725.48828125
# Data loss is: 42725.375
# Physicial loss is: 0.11277801543474197
# Iteration is: 1020
# Total loss is: 41846.1953125
# Data loss is: 41846.0703125
# Physicial loss is: 0.12397855520248413
# Iteration is: 1030
# Total loss is: 40953.80859375
# Data loss is: 40953.671875
# Physicial loss is: 0.13598273694515228
# Iteration is: 1040
# Total loss is: 40051.0703125
# Data loss is: 40050.921875
# Physicial loss is: 0.1487816721200943
# Iteration is: 1050
# Total loss is: 39140.90625
# Data loss is: 39140.7421875
# Physicial loss is: 0.16235285997390747
# Iteration is: 1060
# Total loss is: 38226.515625
# Data loss is: 38226.33984375
# Physicial loss is: 0.17665906250476837
# Iteration is: 1070
# Total loss is: 37311.26953125
# Data loss is: 37311.078125
# Physicial loss is: 0.19164809584617615
# Iteration is: 1080
# Total loss is: 36398.7265625
# Data loss is: 36398.51953125
# Physicial loss is: 0.20725414156913757
# Iteration is: 1090
# Total loss is: 35492.55078125
# Data loss is: 35492.328125
# Physicial loss is: 0.22340017557144165
# Iteration is: 1100
# Total loss is: 34596.453125
# Data loss is: 34596.21484375
# Physicial loss is: 0.24000275135040283
# Iteration is: 1110
# Total loss is: 33714.13671875
# Data loss is: 33713.87890625
# Physicial loss is: 0.2569773495197296
# Iteration is: 1120
# Total loss is: 32849.296875
# Data loss is: 32849.0234375
# Physicial loss is: 0.2742474675178528
# Iteration is: 1130
# Total loss is: 32005.45703125
# Data loss is: 32005.166015625
# Physicial loss is: 0.29175257682800293
# Iteration is: 1140
# Total loss is: 31185.984375
# Data loss is: 31185.67578125
# Physicial loss is: 0.3094567358493805
# Iteration is: 1150
# Total loss is: 30394.03515625
# Data loss is: 30393.70703125
# Physicial loss is: 0.3273542821407318
# Iteration is: 1160
# Total loss is: 29632.416015625
# Data loss is: 29632.0703125
# Physicial loss is: 0.3454723358154297
# Iteration is: 1170
# Total loss is: 28903.642578125
# Data loss is: 28903.279296875
# Physicial loss is: 0.3638658821582794
# Iteration is: 1180
# Total loss is: 28209.7890625
# Data loss is: 28209.40625
# Physicial loss is: 0.3826063275337219
# Iteration is: 1190
# Total loss is: 27552.58203125
# Data loss is: 27552.1796875
# Physicial loss is: 0.4017605483531952
# Iteration is: 1200
# Total loss is: 26933.251953125
# Data loss is: 26932.830078125
# Physicial loss is: 0.4213668406009674
# Iteration is: 1210
# Total loss is: 26352.654296875
# Data loss is: 26352.212890625
# Physicial loss is: 0.4414092004299164
# Iteration is: 1220
# Total loss is: 25811.12109375
# Data loss is: 25810.66015625
# Physicial loss is: 0.46179935336112976
# Iteration is: 1230
# Total loss is: 25308.634765625
# Data loss is: 25308.15234375
# Physicial loss is: 0.48236945271492004
# Iteration is: 1240
# Total loss is: 24844.732421875
# Data loss is: 24844.23046875
# Physicial loss is: 0.5028786063194275
# Iteration is: 1250
# Total loss is: 24418.583984375
# Data loss is: 24418.060546875
# Physicial loss is: 0.5230275988578796
# Iteration is: 1260
# Total loss is: 24029.052734375
# Iteration is: 1520
# Total loss is: 20909.384765625
# Data loss is: 20908.896484375
# Physicial loss is: 0.48734158277511597
# Iteration is: 1530
# Total loss is: 20887.658203125
# Data loss is: 20887.1875
# Physicial loss is: 0.4711652100086212
# Iteration is: 1540
# Total loss is: 20866.9375
# Data loss is: 20866.482421875
# Physicial loss is: 0.45482566952705383
# Iteration is: 1550
# Total loss is: 20847.044921875
# Data loss is: 20846.607421875
# Physicial loss is: 0.43839430809020996
# Iteration is: 1560
# Total loss is: 20827.845703125
# Data loss is: 20827.423828125
# Physicial loss is: 0.42193618416786194
# Iteration is: 1570
# Total loss is: 20809.208984375
# Data loss is: 20808.802734375
# Physicial loss is: 0.40551140904426575
# Iteration is: 1580
# Total loss is: 20791.0625
# Data loss is: 20790.673828125
# Physicial loss is: 0.3891729414463043
# Iteration is: 1590
# Total loss is: 20773.2734375
# Data loss is: 20772.900390625
# Physicial loss is: 0.37296926975250244
# Iteration is: 1600
# Total loss is: 20755.822265625
# Data loss is: 20755.46484375
# Physicial loss is: 0.35694336891174316
# Iteration is: 1610
# Total loss is: 20738.634765625
# Data loss is: 20738.29296875
# Physicial loss is: 0.34113380312919617
# Iteration is: 1620
# Total loss is: 20721.662109375
# Data loss is: 20721.3359375
# Physicial loss is: 0.32557418942451477
# Iteration is: 1630
# Total loss is: 20704.876953125
# Data loss is: 20704.56640625
# Physicial loss is: 0.31029635667800903
# Iteration is: 1640
# Total loss is: 20688.25390625
# Data loss is: 20687.958984375
# Physicial loss is: 0.29532694816589355
# Iteration is: 1650
# Total loss is: 20671.74609375
# Data loss is: 20671.46484375
# Physicial loss is: 0.28069087862968445
# Iteration is: 1660
# Total loss is: 20655.36328125
# Data loss is: 20655.09765625
# Physicial loss is: 0.2664104402065277
# Iteration is: 1670
# Total loss is: 20639.068359375
# Data loss is: 20638.81640625
# Physicial loss is: 0.2525056004524231
# Iteration is: 1680
# Total loss is: 20622.85546875
# Data loss is: 20622.6171875
# Physicial loss is: 0.23899376392364502
# Iteration is: 1690
# Total loss is: 20606.708984375
# Data loss is: 20606.482421875
# Physicial loss is: 0.22589123249053955
# Iteration is: 1700
# Total loss is: 20590.6328125
# Data loss is: 20590.419921875
# Physicial loss is: 0.21321168541908264
# Iteration is: 1710
# Total loss is: 20574.607421875
# Data loss is: 20574.40625
# Physicial loss is: 0.20096684992313385
# Iteration is: 1720
# Total loss is: 20558.642578125
# Data loss is: 20558.453125
# Physicial loss is: 0.1891668289899826
# Iteration is: 1730
# Total loss is: 20542.71484375
# Data loss is: 20542.537109375
# Physicial loss is: 0.1778191775083542
# Iteration is: 1740
# Total loss is: 20526.853515625
# Data loss is: 20526.6875
# Physicial loss is: 0.16692984104156494
# Iteration is: 1750
# Total loss is: 20511.013671875
# Data loss is: 20510.857421875
# Physicial loss is: 0.1565023958683014
# Iteration is: 1760
# Total loss is: 20495.2265625
# Data loss is: 20495.080078125
# Physicial loss is: 0.14653818309307098
# Iteration is: 1770
# Total loss is: 20479.47265625
# Data loss is: 20479.3359375
# Physicial loss is: 0.13703720271587372
# Iteration is: 1780
# Total loss is: 20463.748046875
# Data loss is: 20463.619140625
# Physicial loss is: 0.12799720466136932
# Iteration is: 1790
# Total loss is: 20448.076171875
# Data loss is: 20447.95703125
# Physicial loss is: 0.11941436678171158
# Iteration is: 1800
# Total loss is: 20432.431640625
# Data loss is: 20432.3203125
# Physicial loss is: 0.11128310859203339
# Iteration is: 1810
# Total loss is: 20416.81640625
# Data loss is: 20416.712890625
# Physicial loss is: 0.10359658300876617
# Iteration is: 1820
# Total loss is: 20401.240234375
# Data loss is: 20401.14453125
# Physicial loss is: 0.09634634852409363
# Iteration is: 1830
# Total loss is: 20385.708984375
# Data loss is: 20385.619140625
# Physicial loss is: 0.08952272683382034
# Iteration is: 1840
# Total loss is: 20370.203125
# Data loss is: 20370.119140625
# Physicial loss is: 0.08311441540718079
# Iteration is: 1850
# Total loss is: 20354.73046875
# Data loss is: 20354.654296875
# Physicial loss is: 0.07710929214954376
# Iteration is: 1860
# Total loss is: 20339.291015625
# Data loss is: 20339.21875
# Physicial loss is: 0.07149353623390198
# Iteration is: 1870
# Total loss is: 20323.89453125
# Data loss is: 20323.828125
# Physicial loss is: 0.06625261902809143
# Iteration is: 1880
# Total loss is: 20308.537109375
# Data loss is: 20308.4765625
# Physicial loss is: 0.061370640993118286
# Iteration is: 1890
# Total loss is: 20293.203125
# Data loss is: 20293.146484375
# Physicial loss is: 0.05683129280805588
# Iteration is: 1900
# Total loss is: 20277.90234375
# Data loss is: 20277.849609375
# Physicial loss is: 0.05261732637882233
# Iteration is: 1910
# Total loss is: 20262.642578125
# Data loss is: 20262.59375
# Physicial loss is: 0.04871146380901337
# Iteration is: 1920
# Total loss is: 20247.41796875
# Data loss is: 20247.373046875
# Physicial loss is: 0.04509592056274414
# Iteration is: 1930
# Total loss is: 20232.234375
# Data loss is: 20232.193359375
# Physicial loss is: 0.041752979159355164
# Iteration is: 1940
# Total loss is: 20217.080078125
# Data loss is: 20217.041015625
# Physicial loss is: 0.038665127009153366
# Iteration is: 1950
# Total loss is: 20201.97265625
# Data loss is: 20201.9375
# Physicial loss is: 0.03581543266773224
# Iteration is: 1960
# Total loss is: 20186.876953125
# Data loss is: 20186.84375
# Physicial loss is: 0.03318720683455467
# Iteration is: 1970
# Total loss is: 20171.84375
# Data loss is: 20171.8125
# Physicial loss is: 0.030764417722821236
# Iteration is: 1980
# Total loss is: 20156.83984375
# Data loss is: 20156.810546875
# Physicial loss is: 0.028531832620501518
# Iteration is: 1990
# Total loss is: 20141.8671875
# Data loss is: 20141.83984375
# Physicial loss is: 0.02647511474788189
# Iteration is: 2000
# Total loss is: 20126.93359375
# Data loss is: 20126.908203125
# Physicial loss is: 0.0245804563164711
# Iteration is: 2010
# Total loss is: 20112.041015625
# Data loss is: 20112.017578125
# Physicial loss is: 0.02283512055873871
# Iteration is: 2020
# Total loss is: 20097.1875
# Data loss is: 20097.166015625
# Physicial loss is: 0.02122711017727852
# Iteration is: 2030
# Total loss is: 20082.373046875
# Data loss is: 20082.353515625
# Physicial loss is: 0.01974540762603283
# Iteration is: 2040
# Total loss is: 20067.58984375
# Data loss is: 20067.572265625
# Physicial loss is: 0.01837967336177826
# Iteration is: 2050
# Total loss is: 20052.857421875
# Data loss is: 20052.83984375
# Physicial loss is: 0.017120512202382088
# Iteration is: 2060
# Total loss is: 20038.15625
# Data loss is: 20038.140625
# Physicial loss is: 0.015959132462739944
# Iteration is: 2070
# Total loss is: 20023.501953125
# Data loss is: 20023.486328125
# Physicial loss is: 0.014887623488903046
# Iteration is: 2080
# Total loss is: 20008.87890625
# Data loss is: 20008.865234375
# Physicial loss is: 0.013898525387048721
# Iteration is: 2090
# Total loss is: 19994.296875
# Data loss is: 19994.283203125
# Physicial loss is: 0.012985196895897388
# Iteration is: 2100
# Total loss is: 19979.755859375
# Data loss is: 19979.744140625
# Physicial loss is: 0.012141469866037369
# Iteration is: 2110
# Total loss is: 19965.26171875
# Data loss is: 19965.25
# Physicial loss is: 0.011361786164343357
# Iteration is: 2120
# Total loss is: 19950.806640625
# Data loss is: 19950.796875
# Physicial loss is: 0.01064093317836523
# Iteration is: 2130
# Total loss is: 19936.390625
# Data loss is: 19936.380859375
# Physicial loss is: 0.009974317625164986
# Iteration is: 2140
# Total loss is: 19922.02734375
# Data loss is: 19922.017578125
# Physicial loss is: 0.009357611648738384
# Iteration is: 2150
# Total loss is: 19907.6953125
# Data loss is: 19907.6875
# Physicial loss is: 0.008786898106336594
# Iteration is: 2160
# Total loss is: 19893.41015625
# Data loss is: 19893.40234375
# Physicial loss is: 0.008258603513240814
# Iteration is: 2170
# Total loss is: 19879.16796875
# Data loss is: 19879.16015625
# Physicial loss is: 0.007769444026052952
# Iteration is: 2180
# Total loss is: 19864.96875
# Data loss is: 19864.9609375
# Physicial loss is: 0.007316433358937502
# Iteration is: 2190
# Total loss is: 19850.814453125
# Data loss is: 19850.806640625
# Physicial loss is: 0.00689677894115448
# Iteration is: 2200
# Total loss is: 19836.705078125
# Data loss is: 19836.69921875
# Physicial loss is: 0.0065079922787845135
# Iteration is: 2210
# Total loss is: 19822.638671875
# Data loss is: 19822.6328125
# Physicial loss is: 0.006147724576294422
# Iteration is: 2220
# Total loss is: 19808.615234375
# Data loss is: 19808.609375
# Physicial loss is: 0.005813885480165482
# Iteration is: 2230
# Total loss is: 19794.642578125
# Data loss is: 19794.63671875
# Physicial loss is: 0.005504445638507605
# Iteration is: 2240
# Total loss is: 19780.712890625
# Data loss is: 19780.70703125
# Physicial loss is: 0.0052176606841385365
# Iteration is: 2250
# Total loss is: 19766.8359375
# Data loss is: 19766.830078125
# Physicial loss is: 0.004951775539666414
# Iteration is: 2260
# Total loss is: 19752.986328125
# Data loss is: 19752.982421875
# Physicial loss is: 0.004705269820988178
# Iteration is: 2270
# Total loss is: 19739.212890625
# Data loss is: 19739.208984375
# Physicial loss is: 0.004476711619645357
# Iteration is: 2280
# Total loss is: 19725.455078125
# Data loss is: 19725.451171875
# Physicial loss is: 0.10623055696487427
# Iteration is: 14910
# Total loss is: 509.78021240234375
# Data loss is: 509.6719665527344
# Physicial loss is: 0.10824210941791534
# Iteration is: 14920
# Total loss is: 508.90386962890625
# Data loss is: 508.7970886230469
# Physicial loss is: 0.10678774118423462
# Iteration is: 14930
# Total loss is: 508.0628967285156
# Data loss is: 507.9555358886719
# Physicial loss is: 0.1073482483625412
# Iteration is: 14940
# Total loss is: 507.9317932128906
# Data loss is: 507.8237609863281
# Physicial loss is: 0.10802481323480606
# Iteration is: 14950
# Total loss is: 507.6927795410156
# Data loss is: 507.58447265625
# Physicial loss is: 0.10830517113208771
# Iteration is: 14960
# Total loss is: 507.52099609375
# Data loss is: 507.4123840332031
# Physicial loss is: 0.10861329734325409
# Iteration is: 14970
# Total loss is: 507.4815368652344
# Data loss is: 507.3724365234375
# Physicial loss is: 0.10911300778388977
# Iteration is: 14980
# Total loss is: 507.2501220703125
# Data loss is: 507.140625
# Physicial loss is: 0.10950624197721481
# Iteration is: 14990
# Total loss is: 507.03009033203125
# Data loss is: 506.9201965332031
# Physicial loss is: 0.10988814383745193
# Iteration is: 15000
# Total loss is: 506.7984924316406
# Data loss is: 506.688232421875
# Physicial loss is: 0.11027213931083679
# Training time: 14.2810

# %%
it = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,int(Nmax))]
loss_phi_list = [loss_unk[i].numpy() for i in range(0,int(Nmax))]

plt.semilogy(it, np.asarray(loss_list), 'b-', linewidth = 2, label = 'Total')  
plt.semilogy(it, np.asarray(loss_phi_list), 'r-', linewidth = 2, label = '$\phi$')       

plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
def predict(X_star_tf, w, b):
    x_star = X_star_tf
    u_pred = net(x_star, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star[:len(T_exp)], dtype=tf.float32)    
u_pred = predict(X_star_tf, W_p, b_p)

## Evaluating unknown function
u_pred_tf = tf.convert_to_tensor(u_pred, dtype=tf.float32) 
phi_pred = predict(tf.concat([u_pred_tf,X_star[:len(T_exp)]],1), W_phi, b_phi)

# %%
plt.plot(X_star[:len(T_exp)], u_pred, label='Prediction')
# for i in range(N_exp):
#     plt.plot(X_star[i*len(T_exp):(i+1)*len(T_exp)],u_star[i*len(T_exp):(i+1)*len(T_exp)],linestyle=':')

plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('t')
plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(u_pred, phi_pred, label='Prediction')
# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(X_star[:len(T_exp)], phi_pred, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
Nt=10000
T_symb=np.zeros(Nt)
P_int=np.zeros(Nt)
dt=0.0001

T_symb[0]=0
P_int[0]=np.mean(uu1) #Initial conditions

for i in range(1,Nt):

    X_p=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(T_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    P_int[i]=P_int[i-1]+predict(X_p , W_phi, b_phi)*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_int, label='Numeric integration symb dPdT')

plt.plot(X_star[:len(T_exp)], u_pred, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# Si N_max es muy alto, hay overfitting y la reconstrucción no es buena. Las pinns aprenden primero las frecuencas más pequeñas, es decir los rasgos más genersles. Esto, para físicos amantes de las vacas redondas nos viene excelentemente bien. Por tanto, buscaremos el punto donde haya aprendido el caso más general con éxito

# %%
# Create and train the PySR model
model_phi = PySRRegressor(
    niterations=1000,
    binary_operators=["+", "*", "/"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    # unary_operators=[ "exp",  "inv(x) = 1/x"],
    unary_operators=["inv(x) = 1/x"],

    extra_sympy_mappings={"inv": lambda x: 1 / x},
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # maxsize=50,
    # ^ Allow greater complexity.
    maxdepth=6
    # ^ But, avoid deep nesting.
)

# Fit phi
model_phi.fit(tf.concat([u_pred_tf,X_star[:len(T_exp)]],1), np.array(phi_pred))
print(model_phi)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 2.400e+05
# Head worker occupation: 31.7%
# Progress: 513 / 15000 total iterations (3.420%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.327e+00  1.389e-02  y = 0.51903 / x₀
# 4           6.799e+00  2.027e-01  y = inv(0.17907 + x₁)
# 5           6.386e+00  6.275e-02  y = (-7.3789 * x₀) + 7.1661
# 6           4.703e+00  3.059e-01  y = inv(x₁ + 0.099267) + -1.7347
# 7           4.701e+00  4.020e-04  y = inv(inv(9.9837) + x₁) + -1.686
# 8           2.121e+00  7.957e-01  y = inv(x₁ + (0.013053 / x₀)) + -2.3824
# 10          1.073e+00  3.408e-01  y = -2.5196 + inv((x₁ * x₀) + (0.018242 / x₀))
# 12          6.772e-01  2.302e-01  y = (-3.1005 + inv((0.016672 / x₀) + (x₀ * x₁))) + x₁
# 13          6.589e-01  2.733e-02  y = x₀ + (inv(-1.249 + x₀) + inv((0.017393 / x₀) + x₁))
# 14          3.396e-01  6.628e-01  y = (x₁ * 4.19) + (-4.5444 + inv((0.014427 / x₀) + (x₁ * x₀)))
# 15          1.270e-01  9.838e-01  y = ((inv(x₀ + -1.2178) / x₀) + inv((0.0086103 / x₀) + x₁)) + ...
#                                   1.5396
# 17          1.088e-01  7.750e-02  y = ((inv(-1.2237 + x₀) / x₀) + inv(x₁ + (0.0079183 / x₀))) + ...
#                                   (x₁ + 0.93939)
# 19          1.082e-01  2.602e-03  y = ((inv(-1.2237 + x₀) / x₀) + inv(x₁ + (0.0079183 / x₀))) + ...
#                                   ((x₁ * x₀) + 0.99545)
# 20          9.624e-02  1.171e-01  y = ((inv(-1.2237 + x₀) / x₀) + inv(x₁ + (0.0079183 / x₀))) + ...
#                                   ((x₁ * x₁) + inv(0.89987))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.600e+05
# Head worker occupation: 30.5%
# Progress: 1121 / 15000 total iterations (7.473%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39591 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           6.386e+00  6.275e-02  y = (-7.3789 * x₀) + 7.1661
# 6           4.701e+00  3.063e-01  y = -1.6841 + inv(x₁ + 0.10037)
# 7           4.701e+00  3.099e-06  y = inv(inv(9.9837) + x₁) + -1.686
# 8           2.120e+00  7.961e-01  y = -2.3978 + inv((0.012989 / x₀) + x₁)
# 10          1.073e+00  3.407e-01  y = -2.5196 + inv((0.018176 / x₀) + (x₁ * x₀))
# 12          6.772e-01  2.300e-01  y = x₁ + (inv((0.016692 / x₀) + (x₁ * x₀)) + -3.1005)
# 13          4.007e-01  5.247e-01  y = inv((0.020131 / x₀) + (x₁ * x₀)) + inv(-1.3545 + x₀)
# 14          2.416e-01  5.060e-01  y = (x₁ * 3.4383) + (-4.4105 + inv((0.014833 / x₀) + (x₁ * x₀)...
#                                   ))
# 15          1.255e-01  6.547e-01  y = ((inv(x₀ + -1.2178) / x₀) + inv((0.0086103 / x₀) + x₁)) + ...
#                                   1.5715
# 16          1.247e-01  6.583e-03  y = inv(0.59536) + ((inv(x₀ + -1.2132) / x₀) + inv((0.0086759 ...
#                                   / x₀) + x₁))
# 17          1.088e-01  1.368e-01  y = ((inv(-1.2237 + x₀) / x₀) + inv((0.0079183 / x₀) + x₁)) + ...
#                                   (x₁ + 0.93707)
# 19          1.003e-01  4.045e-02  y = (inv((0.0079183 / x₀) + x₁) + (inv(x₀ + -1.2237) / x₀)) + ...
#                                   ((x₁ * x₁) + 1.0396)
# 20          9.624e-02  4.134e-02  y = ((inv(-1.2237 + x₀) / x₀) + inv(x₁ + (0.0079183 / x₀))) + ...
#                                   ((x₁ * x₁) + inv(0.89987))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.620e+05
# Head worker occupation: 30.9%
# Progress: 1690 / 15000 total iterations (11.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39591 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           6.280e+00  7.951e-02  y = 0.39576 / (x₁ + 0.1002)
# 6           4.701e+00  2.896e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           4.206e+00  1.112e-01  y = 0.39591 / ((0.0086103 / x₀) + x₁)
# 8           2.120e+00  6.851e-01  y = -2.3978 + inv((0.012891 / x₀) + x₁)
# 10          1.072e+00  3.408e-01  y = inv((x₁ * x₀) + (0.018004 / x₀)) + -2.5196
# 11          9.686e-01  1.018e-01  y = inv((0.016206 / x₀) + x₁) + inv(x₀ + -1.3215)
# 12          6.772e-01  3.579e-01  y = x₁ + (inv((0.016692 / x₀) + (x₁ * x₀)) + -3.1005)
# 13          3.513e-01  6.562e-01  y = inv(-1.3089 + x₀) + inv((0.020131 / x₀) + (x₁ * x₀))
# 14          2.416e-01  3.746e-01  y = (x₁ * 3.4383) + (-4.4105 + inv((0.014833 / x₀) + (x₁ * x₀)...
#                                   ))
# 15          1.230e-01  6.747e-01  y = ((inv(x₀ + -1.2144) / x₀) + inv((0.0086103 / x₀) + x₁)) + ...
#                                   1.6436
# 17          1.088e-01  6.171e-02  y = ((inv(-1.2237 + x₀) / x₀) + inv((0.0079183 / x₀) + x₁)) + ...
#                                   (x₁ + 0.93707)
# 19          8.809e-02  1.054e-01  y = ((inv(-1.2237 + x₀) / x₀) + inv((0.0079183 / x₀) + (x₁ * 0...
#                                   .93234))) + (x₁ + 0.75345)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.670e+05
# Head worker occupation: 32.4%
# Progress: 2318 / 15000 total iterations (15.453%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.957e+00  1.322e-01  y = 0.57239 / (0.1002 + x₁)
# 6           4.701e+00  2.369e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           4.141e+00  1.269e-01  y = 0.4143 / ((0.0086103 / x₀) + x₁)
# 8           2.120e+00  6.693e-01  y = -2.3978 + inv((0.012891 / x₀) + x₁)
# 10          1.072e+00  3.412e-01  y = inv((0.018009 / x₀) + (x₀ * x₁)) + -2.54
# 11          8.058e-01  2.851e-01  y = (0.39408 / ((0.01206 / x₀) + (-0.058437 + x₁))) + -1.622
# 12          6.772e-01  1.738e-01  y = x₁ + (inv((0.016692 / x₀) + (x₁ * x₀)) + -3.1005)
# 13          3.290e-01  7.220e-01  y = inv((0.02199 / x₀) + (x₁ * x₀)) + inv(-1.3262 + x₀)
# 14          2.416e-01  3.088e-01  y = (x₁ * 3.4383) + (-4.4105 + inv((0.014833 / x₀) + (x₁ * x₀)...
#                                   ))
# 15          1.230e-01  6.747e-01  y = ((inv(x₀ + -1.2144) / x₀) + inv((0.0086103 / x₀) + x₁)) + ...
#                                   1.6436
# 17          8.973e-02  1.579e-01  y = ((inv(x₀ + -1.2368) / (x₁ + x₀)) + inv(x₁ + (0.0083887 / x...
#                                   ₀))) * 1.1451
# 19          8.763e-02  1.181e-02  y = ((inv(-1.2237 + x₀) / x₀) + inv((0.0079183 / x₀) + (x₁ * 0...
#                                   .93234))) + (x₁ + 0.73466)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.730e+05
# Head worker occupation: 32.4%
# Progress: 2870 / 15000 total iterations (19.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           4.022e+00  1.560e-01  y = 0.48087 / ((0.0086103 / x₀) + x₁)
# 8           2.120e+00  6.402e-01  y = inv(x₁ + (0.012648 / x₀)) + -2.422
# 9           2.084e+00  1.703e-02  y = (0.93248 / ((0.012383 / x₀) + x₁)) + -2.2094
# 10          1.072e+00  6.654e-01  y = inv((0.018009 / x₀) + (x₀ * x₁)) + -2.54
# 11          6.443e-01  5.087e-01  y = (0.26675 / ((-0.073549 + x₁) + (0.0158 / x₀))) + -0.82295
# 12          6.360e-01  1.299e-02  y = -0.8709 + (inv((x₁ + -0.073549) + (0.0158 / x₀)) * 0.28561...
#                                   )
# 13          3.290e-01  6.592e-01  y = inv((0.02199 / x₀) + (x₁ * x₀)) + inv(-1.3262 + x₀)
# 14          2.349e-01  3.369e-01  y = (x₁ * 3.4166) + (-4.3909 + inv((x₁ * x₀) + (0.014304 / x₀)...
#                                   ))
# 15          1.230e-01  6.467e-01  y = ((inv(-1.2138 + x₀) / x₀) + inv((0.0086103 / x₀) + x₁)) + ...
#                                   1.6436
# 16          1.230e-01  1.973e-05  y = 1.6441 + (inv((0.0086103 / x₀) + x₁) + (inv(-1.2138 + x₀) ...
#                                   * inv(x₀)))
# 17          8.651e-02  3.522e-01  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) / 0.89129
# 18          8.651e-02  5.960e-08  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) * inv(0.89129)
# 19          7.914e-02  8.898e-02  y = (inv((x₁ * 0.885) + (0.0081489 / x₀)) + (inv(-1.2135 + x₀)...
#                                    / (x₀ + x₁))) + 0.0081489
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.680e+05
# Head worker occupation: 34.2%
# Progress: 3411 / 15000 total iterations (22.740%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           4.022e+00  1.560e-01  y = 0.48087 / ((0.0086103 / x₀) + x₁)
# 8           2.120e+00  6.404e-01  y = inv(x₁ + (0.012916 / x₀)) + -2.422
# 9           2.077e+00  2.029e-02  y = (0.91362 / ((0.011817 / x₀) + x₁)) + -2.173
# 10          1.072e+00  6.620e-01  y = inv((0.018009 / x₀) + (x₀ * x₁)) + -2.54
# 11          6.310e-01  5.296e-01  y = (0.26675 / ((0.015933 / x₀) + (-0.075207 + x₁))) + -0.9466...
#                                   3
# 12          6.149e-01  2.587e-02  y = (inv((x₁ + -0.073548) + (0.015825 / x₀)) * 0.28561) + -1.0...
#                                   358
# 13          3.290e-01  6.255e-01  y = inv((0.02199 / x₀) + (x₁ * x₀)) + inv(-1.3262 + x₀)
# 14          2.349e-01  3.370e-01  y = (x₁ * 3.4166) + (-4.3909 + inv((x₁ * x₀) + (0.014337 / x₀)...
#                                   ))
# 15          1.230e-01  6.465e-01  y = 1.6441 + (inv((0.0086103 / x₀) + x₁) + inv((-1.2138 + x₀) ...
#                                   * x₀))
# 17          8.651e-02  1.761e-01  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) / 0.89129
# 18          8.651e-02  5.960e-08  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) * inv(0.89129)
# 19          7.891e-02  9.187e-02  y = -0.0076362 + (inv((0.0081489 / x₀) + (x₁ * 0.885)) + (inv(...
#                                   x₀ + -1.2135) / (x₀ + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.670e+05
# Head worker occupation: 34.7%
# Progress: 3961 / 15000 total iterations (26.407%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           4.022e+00  1.560e-01  y = 0.48087 / ((0.0086103 / x₀) + x₁)
# 8           2.120e+00  6.404e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.072e+00  6.613e-01  y = inv((0.018009 / x₀) + (x₀ * x₁)) + -2.54
# 11          6.310e-01  5.296e-01  y = (0.26675 / ((-0.075203 + x₁) + (0.016038 / x₀))) + -0.9466...
#                                   3
# 12          5.973e-01  5.488e-02  y = -1.1196 + (inv((x₁ + -0.064778) + (0.013277 / x₀)) * 0.324...
#                                   03)
# 13          3.273e-01  6.015e-01  y = inv((x₁ * x₀) + (0.021183 / x₀)) + inv(-1.3285 + x₀)
# 14          2.349e-01  3.320e-01  y = (x₁ * 3.4166) + (-4.3909 + inv((x₁ * x₀) + (0.014337 / x₀)...
#                                   ))
# 15          1.216e-01  6.579e-01  y = 1.6441 + (inv((0.0083887 / x₀) + x₁) + inv(x₀ * (-1.2138 +...
#                                    x₀)))
# 17          8.651e-02  1.704e-01  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) / 0.89129
# 18          8.651e-02  5.960e-08  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) * inv(0.89129)
# 19          7.891e-02  9.187e-02  y = -0.0076362 + (inv((0.0081489 / x₀) + (x₁ * 0.885)) + (inv(...
#                                   x₀ + -1.2135) / (x₀ + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.670e+05
# Head worker occupation: 34.7%
# Progress: 4579 / 15000 total iterations (30.527%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           4.013e+00  1.582e-01  y = 0.48391 / ((0.008108 / x₀) + x₁)
# 8           2.120e+00  6.383e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.072e+00  6.613e-01  y = inv((0.018009 / x₀) + (x₀ * x₁)) + -2.54
# 11          6.310e-01  5.296e-01  y = (0.26675 / ((-0.075203 + x₁) + (0.016038 / x₀))) + -0.9466...
#                                   3
# 12          5.873e-01  7.171e-02  y = -1.1186 + (0.31483 * inv((0.014487 / x₀) + (x₁ + -0.068204...
#                                   )))
# 13          3.273e-01  5.846e-01  y = inv((x₁ * x₀) + (0.021183 / x₀)) + inv(-1.3285 + x₀)
# 14          2.349e-01  3.320e-01  y = (x₁ * 3.4166) + (-4.3909 + inv((x₁ * x₀) + (0.014337 / x₀)...
#                                   ))
# 15          1.215e-01  6.586e-01  y = 1.6399 + (inv((0.0083887 / x₀) + x₁) + inv(x₀ * (-1.2138 +...
#                                    x₀)))
# 17          8.651e-02  1.700e-01  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) / 0.89129
# 18          8.651e-02  5.960e-08  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) * inv(0.89129)
# 19          7.891e-02  9.187e-02  y = -0.0076362 + (inv((0.0081489 / x₀) + (x₁ * 0.885)) + (inv(...
#                                   x₀ + -1.2135) / (x₀ + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+05
# Head worker occupation: 32.0%
# Progress: 5268 / 15000 total iterations (35.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.943e+00  1.758e-01  y = 0.098246 / (0.01318 + (x₁ * x₁))
# 8           2.120e+00  6.207e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.072e+00  6.613e-01  y = inv((0.018009 / x₀) + (x₀ * x₁)) + -2.54
# 11          6.309e-01  5.298e-01  y = (0.26755 / ((-0.075203 + x₁) + (0.016038 / x₀))) + -0.9466...
#                                   3
# 12          5.870e-01  7.204e-02  y = (0.31483 * inv((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1...
#                                   046
# 13          3.273e-01  5.841e-01  y = inv((x₁ * x₀) + (0.021183 / x₀)) + inv(-1.3285 + x₀)
# 14          2.349e-01  3.320e-01  y = (inv((x₁ * x₀) + (0.014338 / x₀)) + -4.3909) + (3.4166 * x...
#                                   ₁)
# 15          1.215e-01  6.589e-01  y = 1.64 + (inv((0.0084402 / x₀) + x₁) + inv(x₀ * (-1.2141 + x...
#                                   ₀)))
# 17          8.651e-02  1.699e-01  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) / 0.89129
# 18          8.651e-02  5.960e-08  y = ((inv(x₀ + -1.2368) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) * inv(0.89129)
# 19          7.891e-02  9.187e-02  y = -0.0076362 + (inv((0.0081489 / x₀) + (x₁ * 0.885)) + (inv(...
#                                   x₀ + -1.2135) / (x₀ + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.930e+05
# Head worker occupation: 30.6%
# Progress: 5901 / 15000 total iterations (39.340%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.071e+00  6.615e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1046
# 13          3.273e-01  2.921e-01  y = inv((x₁ * x₀) + (0.021183 / x₀)) + inv(-1.3285 + x₀)
# 14          2.349e-01  3.320e-01  y = (inv((x₁ * x₀) + (0.014338 / x₀)) + -4.3909) + (3.4166 * x...
#                                   ₁)
# 15          1.215e-01  6.589e-01  y = 1.64 + (inv((0.0084402 / x₀) + x₁) + inv(x₀ * (-1.2141 + x...
#                                   ₀)))
# 17          8.629e-02  1.712e-01  y = ((inv(x₀ + -1.2328) / (x₀ + x₁)) + inv(x₁ + (0.0083887 / x...
#                                   ₀))) / 0.89129
# 19          7.863e-02  4.647e-02  y = -0.0076362 + (inv((0.0081489 / x₀) + (x₁ * 0.885)) + (inv(...
#                                   x₀ + -1.2141) / (x₀ + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.060e+05
# Head worker occupation: 30.8%
# Progress: 6561 / 15000 total iterations (43.740%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17907 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.071e+00  6.615e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1046
# 13          3.273e-01  2.921e-01  y = inv((x₁ * x₀) + (0.021183 / x₀)) + inv(-1.3285 + x₀)
# 14          2.349e-01  3.320e-01  y = (inv((x₁ * x₀) + (0.014338 / x₀)) + -4.3909) + (3.4166 * x...
#                                   ₁)
# 15          1.215e-01  6.589e-01  y = 1.64 + (inv((0.0084402 / x₀) + x₁) + inv(x₀ * (-1.2141 + x...
#                                   ₀)))
# 17          8.629e-02  1.712e-01  y = ((inv(x₀ + -1.2328) / (x₀ + x₁)) + inv(x₁ + (0.0083887 / x...
#                                   ₀))) / 0.89129
# 18          8.556e-02  8.474e-03  y = ((inv(-1.2354 + x₀) / (x₀ + x₁)) + inv((0.0083887 / x₀) + ...
#                                   x₁)) * inv(0.89129)
# 19          6.289e-02  3.078e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.304 + x₀)) + ((...
#                                   x₁ + -0.26317) / x₀)
# 20          6.289e-02  -0.000e+00  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.304 + x₀)) + ((...
#                                   -0.26317 + x₁) * inv(x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.120e+05
# Head worker occupation: 28.6%
# Progress: 7207 / 15000 total iterations (48.047%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.071e+00  6.615e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1046
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.349e-01  3.263e-01  y = (inv((x₁ * x₀) + (0.014338 / x₀)) + -4.3909) + (3.4166 * x...
#                                   ₁)
# 15          1.215e-01  6.589e-01  y = 1.64 + (inv((0.0084402 / x₀) + x₁) + inv(x₀ * (-1.2141 + x...
#                                   ₀)))
# 16          1.214e-01  6.361e-04  y = inv(0.61371) + (inv(x₁ + (0.0084402 / x₀)) + inv(x₀ * (-1....
#                                   2141 + x₀)))
# 17          8.556e-02  3.501e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.289e-02  1.539e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.304 + x₀)) + ((...
#                                   x₁ + -0.26317) / x₀)
# 20          6.285e-02  6.476e-04  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) * inv(x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+05
# Head worker occupation: 27.8%
# Progress: 7859 / 15000 total iterations (52.393%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           2.076e+00  2.085e-02  y = (0.91045 / ((0.011577 / x₀) + x₁)) + -2.1899
# 10          1.071e+00  6.615e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1046
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.349e-01  3.263e-01  y = (inv((x₁ * x₀) + (0.014338 / x₀)) + -4.3909) + (3.4166 * x...
#                                   ₁)
# 15          1.214e-01  6.595e-01  y = 1.6344 + (inv((0.0084402 / x₀) + x₁) + inv((x₀ + -1.2141) ...
#                                   * x₀))
# 16          1.214e-01  1.591e-04  y = inv(0.61315) + (inv(x₁ + (0.008442 / x₀)) + inv(x₀ * (-1.2...
#                                   145 + x₀)))
# 17          8.556e-02  3.501e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+05
# Head worker occupation: 27.9%
# Progress: 8532 / 15000 total iterations (56.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.798e+00  1.644e-01  y = 0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))
# 10          1.071e+00  5.179e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1046
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.298e-01  3.482e-01  y = (inv((x₁ * x₀) + (0.0142 / x₀)) + -4.4925) + (3.5206 * x₁)
# 15          1.214e-01  6.376e-01  y = 1.6344 + (inv((0.0084402 / x₀) + x₁) + inv((x₀ + -1.2141) ...
#                                   * x₀))
# 16          1.214e-01  1.591e-04  y = inv(0.61315) + (inv(x₁ + (0.008442 / x₀)) + inv(x₀ * (-1.2...
#                                   145 + x₀)))
# 17          8.556e-02  3.501e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.010e+05
# Head worker occupation: 30.1%
# Progress: 9111 / 15000 total iterations (60.740%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46142 / (0.061993 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.428e+00  3.952e-01  y = 0.25302 / ((0.014487 / x₀) + (x₁ + -0.068204))
# 10          1.071e+00  2.872e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1046
# 12          5.870e-01  2.497e-05  y = inv(-0.90938) + (0.31483 / ((0.014487 / x₀) + (-0.068204 +...
#                                    x₁)))
# 13          3.254e-01  5.898e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.298e-01  3.482e-01  y = (inv((x₁ * x₀) + (0.0142 / x₀)) + -4.4925) + (3.5206 * x₁)
# 15          1.214e-01  6.376e-01  y = 1.6344 + (inv((0.0084402 / x₀) + x₁) + inv((x₀ + -1.2141) ...
#                                   * x₀))
# 16          1.214e-01  1.823e-04  y = inv(0.61315) + (inv(x₀ * (-1.2145 + x₀)) + inv(x₁ + (0.008...
#                                   442 / x₀)))
# 17          8.556e-02  3.500e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.980e+05
# Head worker occupation: 31.3%
# Progress: 9746 / 15000 total iterations (64.973%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / ((0.012846 / x₀) + (x₁ + -0.068204))
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1018
# 12          5.870e-01  4.172e-07  y = inv(-0.90938) + (0.31483 / ((0.014487 / x₀) + (-0.068204 +...
#                                    x₁)))
# 13          3.254e-01  5.898e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.298e-01  3.482e-01  y = (inv((x₁ * x₀) + (0.0142 / x₀)) + -4.4925) + (3.5206 * x₁)
# 15          1.213e-01  6.385e-01  y = 1.622 + (inv(x₀ * (-1.2145 + x₀)) + inv(x₁ + (0.0083887 / ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.000e+05
# Head worker occupation: 31.3%
# Progress: 10413 / 15000 total iterations (69.420%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090968 / (0.011745 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = (0.31483 / ((0.014487 / x₀) + (x₁ + -0.068204))) + -1.1018
# 12          5.870e-01  4.172e-07  y = inv(-0.90938) + (0.31483 / ((0.014487 / x₀) + (-0.068204 +...
#                                    x₁)))
# 13          3.254e-01  5.898e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.298e-01  3.482e-01  y = (inv((x₁ * x₀) + (0.0142 / x₀)) + -4.4925) + (3.5206 * x₁)
# 15          1.213e-01  6.386e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.010e+05
# Head worker occupation: 31.3%
# Progress: 11064 / 15000 total iterations (73.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090751 / (0.01172 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = -1.1006 + (0.31483 / ((0.014487 / x₀) + (-0.068204 + x₁)))
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.298e-01  3.482e-01  y = (inv((x₁ * x₀) + (0.0142 / x₀)) + -4.4925) + (3.5206 * x₁)
# 15          1.213e-01  6.386e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+05
# Head worker occupation: 30.2%
# Progress: 11712 / 15000 total iterations (78.080%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090751 / (0.01172 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = -1.1006 + (0.31483 / ((0.014487 / x₀) + (-0.068204 + x₁)))
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.298e-01  3.482e-01  y = (inv((x₁ * x₀) + (0.0142 / x₀)) + -4.4925) + (3.5206 * x₁)
# 15          1.213e-01  6.386e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.100e+05
# Head worker occupation: 27.8%
# Progress: 12367 / 15000 total iterations (82.447%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090751 / (0.01172 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = -1.1006 + (0.31483 / ((0.014487 / x₀) + (-0.068204 + x₁)))
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.297e-01  3.485e-01  y = (inv((x₀ * x₁) + (0.0142 / x₀)) + -4.4925) + (x₁ * 3.5283)
# 15          1.213e-01  6.383e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+05
# Head worker occupation: 28.9%
# Progress: 13023 / 15000 total iterations (86.820%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090751 / (0.01172 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = -1.1006 + (0.31483 / ((0.014487 / x₀) + (-0.068204 + x₁)))
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.297e-01  3.485e-01  y = (inv((x₀ * x₁) + (0.0142 / x₀)) + -4.4925) + (x₁ * 3.5283)
# 15          1.213e-01  6.383e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.090e+05
# Head worker occupation: 30.4%
# Progress: 13685 / 15000 total iterations (91.233%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090751 / (0.01172 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = -1.1006 + (0.31483 / ((0.014487 / x₀) + (-0.068204 + x₁)))
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.297e-01  3.485e-01  y = (inv((x₀ * x₁) + (0.0142 / x₀)) + -4.4925) + (x₁ * 3.5283)
# 15          1.213e-01  6.383e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+05
# Head worker occupation: 31.4%
# Progress: 14323 / 15000 total iterations (95.487%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.562e+00  1.594e+01  y = 0.71617
# 3           8.247e+00  1.873e-02  y = 0.39593 / x₀
# 4           6.799e+00  1.931e-01  y = inv(0.17899 + x₁)
# 5           5.794e+00  1.600e-01  y = 0.46106 / (0.061956 + x₁)
# 6           4.701e+00  2.090e-01  y = inv(0.1002 + x₁) + -1.6853
# 7           3.931e+00  1.788e-01  y = 0.090751 / (0.01172 + (x₁ * x₁))
# 8           2.120e+00  6.176e-01  y = -2.4225 + inv(x₁ + (0.012846 / x₀))
# 9           1.279e+00  5.050e-01  y = 0.22315 / (((0.012846 / x₀) + x₁) + -0.068204)
# 10          1.071e+00  1.774e-01  y = inv((0.017942 / x₀) + (x₀ * x₁)) + -2.5457
# 11          5.870e-01  6.017e-01  y = -1.1006 + (0.31483 / ((0.014487 / x₀) + (-0.068204 + x₁)))
# 13          3.254e-01  2.949e-01  y = inv(-1.3239 + x₀) + inv((x₁ * x₀) + (0.021496 / x₀))
# 14          2.297e-01  3.485e-01  y = (inv((x₀ * x₁) + (0.0142 / x₀)) + -4.4925) + (x₁ * 3.5283)
# 15          1.213e-01  6.383e-01  y = 1.622 + (inv((0.0084103 / x₀) + x₁) + inv(x₀ * (-1.2146 + ...
#                                   x₀)))
# 17          8.556e-02  1.746e-01  y = (inv(x₁ + (0.0083887 / x₀)) + (inv(-1.2354 + x₀) / (x₀ + x...
#                                   ₁))) / 0.89129
# 19          6.285e-02  1.542e-01  y = (inv((0.018492 / x₀) + (x₁ * x₀)) + inv(-1.3038 + x₀)) + (...
#                                   (-0.26317 + x₁) / x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         0.71617377
# 	1         0.018726                                    0.39592555 / x0
# 	2         0.193058                               inv(0.17898506 + x1)
# 	3         0.160046                     0.4610567 / (0.061956495 + x1)
# 	4         0.209018                  inv(0.10020177 + x1) + -1.6853043
# 	5         0.178828              0.09075114 / (0.01171967 + (x1 * x1))
# 	6         0.617621           -2.422477 + inv(x1 + (0.012845822 / x0))
# 	7         0.504969  0.22314829 / (((0.012845822 / x0) + x1) + -0.0...
# 	8         0.177371    inv((0.017941685 / x0) + (x0 * x1)) + -2.545673
# 	9         0.601684  -1.1005614 + (0.3148261 / ((0.014487386 / x0) ...
# 	10        0.294922  inv(-1.3239386 + x0) + inv((x1 * x0) + (0.0214...
# 	11        0.348547  (inv((x0 * x1) + (0.014199865 / x0)) + -4.4924...
# 	12        0.638273  1.6220175 + (inv((0.008410312 / x0) + x1) + in...
# 	13  >>>>  0.174582  (inv(x1 + (0.008388663 / x0)) + (inv(-1.235411...
# 	14        0.154206  (inv((0.018491961 / x0) + (x1 * x0)) + inv(-1....
#
# 	        loss  complexity
# 	0   8.562088           1
# 	1   8.247349           3
# 	2   6.799399           4
# 	3   5.793800           5
# 	4   4.700980           6
# 	5   3.931191           7
# 	6   2.119800           8
# 	7   1.279351           9
# 	8   1.071416          10
# 	9   0.587017          11
# 	10  0.325450          13
# 	11  0.229674          14
# 	12  0.121315          15
# 	13  0.085561          17
# 	14  0.062854          19
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_phi.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
import sympy 
chose=14
expr=model_phi.sympy(chose)
sympy.together(expr)
# Out:
# (x0**2*(x0 - 1.303803) + x0*(x0**2*x1 + 0.018491961) + (x0 - 1.303803)*(x1 - 0.2631747)*(x0**2*x1 + 0.018491961))/(x0*(x0 - 1.303803)*(x0**2*x1 + 0.018491961))

# %%
symb1=model_phi.predict(tf.concat([u_pred_tf,X_star[:len(T_exp)]],1),chose)
plt.plot(u_pred, phi_pred, label='PINN prediction')
plt.plot(u_pred, symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('P')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
plt.plot(X_star[:len(T_exp)], phi_pred, label='PINN prediction')
plt.plot(X_star[:len(T_exp)], symb1, linestyle='--', label='Symbolic regresion')

plt.xlabel('t')
plt.ylabel('$\phi (P,t)$')
plt.show()

# %%
Nt=10000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
dt=0.0001

P_symb[0]=np.mean(uu1) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    # P_symb[i]=P_symb[i-1]+(1/(T_symb[i-1]*(P_symb[i-1]-0.598)+0.068)+1.607/(P_symb[i-1]*(P_symb[i-1]-1.314)))*dt
    P_symb[i]=P_symb[i-1]+model_phi.predict(tf.concat([np.reshape(P_symb[i-1],[-1,1]),np.reshape(T_symb[i-1],[-1,1])],1),chose)*dt
    T_symb[i]=T_symb[i-1]+dt

# %%
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')
plt.plot(T_symb, P_int, label='Numeric integration PINN dPdT')
plt.plot(X_star[:len(T_exp)], u_pred, label='PINN prediction')
plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Debería hacer una tabla donde haga ticks en los términos que aparecen que hace que se ajuste
# ¿Debería probar dependencia con dP/dt?

# %%
# Fit dP/dt
# Create and train the PySR model
model_dPdT = PySRRegressor(
    niterations=50,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    unary_operators=[ "exp",  "inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    # complexity_of_operators={"exp": 2},
    constraints={'exp': (1)},
    weight_randomize=0.1,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # maxsize=50,
    # ^ Allow greater complexity.
    maxdepth=6
    # ^ But, avoid deep nesting.
)

model_dPdT.fit(X_star[:len(T_exp)], u_pred)
print(model_dPdT)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.950e+05
# Head worker occupation: 38.3%
# Progress: 483 / 750 total iterations (64.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.963e-02  1.594e+01  y = 0.87312
# 5           3.942e-02  1.329e-03  y = 0.84806 + (0.050131 * x₀)
# 6           1.960e-02  6.987e-01  y = x₀ * inv(x₀ + 0.030431)
# 8           1.285e-02  2.112e-01  y = inv(exp(exp(2.0005 + (x₀ * -40.851))))
# 9           7.483e-03  5.407e-01  y = (x₀ * inv(exp(x₀) + -0.9352)) * 1.4362
# 11          5.554e-03  1.490e-01  y = (x₀ + x₀) * inv(-0.89112 + exp(1.2925 * x₀))
# 13          4.679e-03  8.568e-02  y = inv(-0.87067 + (exp(x₀) + (x₀ * x₀))) * (x₀ + x₀)
# 15          4.109e-03  6.501e-02  y = inv(-0.89303 + (exp(x₀) + (x₀ * x₀))) * ((-0.018023 + x₀) ...
#                                   + x₀)
# 19          3.600e-03  3.308e-02  y = inv(exp(3.1532 * x₀) + (inv(-0.82133) + 0.57066)) * ((exp(...
#                                   exp(x₀)) + exp(1.0605)) * x₀)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          0.8731237
# 	1        0.001329                     0.8480602 + (0.050130635 * x0)
# 	2        0.698659                         x0 * inv(x0 + 0.030430797)
# 	3        0.211207        inv(exp(exp(2.0004773 + (x0 * -40.85126))))
# 	4        0.706799        (x0 * 1.384012) * inv(-0.9351896 + exp(x0))
# 	5  >>>>  0.101912  x0 * inv(-0.9417839 + (exp(x0) + (x0 * -0.3978...
# 	6        0.049750  inv((exp(x0) + (x0 * x0)) + -0.87067163) * (x0...
# 	7        0.065012  inv(-0.89303243 + (exp(x0) + (x0 * x0))) * ((-...
# 	8        0.015316  inv(exp(3.1995702 * x0) + -0.662456) * (((exp(...
# 	9        0.086383  inv(exp(3.153176 * x0) + (inv(-0.82132673) + 0...
#
# 	       loss  complexity
# 	0  0.039633           1
# 	1  0.039423           5
# 	2  0.019603           6
# 	3  0.012849           8
# 	4  0.006337           9
# 	5  0.005169          11
# 	6  0.004679          13
# 	7  0.004109          15
# 	8  0.003924          18
# 	9  0.003600          19
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_dPdT.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')
# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=5
model_dPdT.sympy(chose)
# Out:
# x0/(x0*(-0.3978229) + exp(x0) - 0.9417839)

# %%
symb1=model_dPdT.predict(X_star[:len(T_exp)],chose)
plt.plot(X_star[:len(T_exp)], u_pred, label='PINN prediction')
plt.plot(X_star[:len(T_exp)], symb1, linestyle='--', label='Symbolic regresion')
plt.plot(T_symb, P_symb, label='Numeric integration symb dPdT')

# plt.plot(T, P, linestyle=':', label='Exact')

plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()
