# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
df1.iloc[:, 3:]
# Out:
#          G4      G5      G6      G7      G8      G9     G10     G11     G12  \
# 0    0.0922  0.0928  0.0928  0.0931  0.0928  0.0927  0.0916  0.0921  0.0911
# 1    0.0951  0.0957  0.0959  0.0959  0.0957  0.0953  0.0947  0.0951  0.0941
# 2    0.0951  0.0958  0.0957  0.0960  0.0958  0.0954  0.0947  0.0951  0.0943
# 3    0.0955  0.0962  0.0961  0.0965  0.0964  0.0958  0.0950  0.0957  0.0947
# 4    0.0960  0.0969  0.0965  0.0968  0.0968  0.0964  0.0956  0.0963  0.0953
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8186  0.8214  0.8188  0.8198  0.8221  0.8201  0.8296  0.8418  0.8292
# 495  0.8184  0.8222  0.8185  0.8178  0.8201  0.8182  0.8277  0.8379  0.8274
# 496  0.8183  0.8222  0.8169  0.8204  0.8214  0.8186  0.8287  0.8409  0.8289
# 497  0.8172  0.8211  0.8194  0.8206  0.8227  0.8201  0.8303  0.8417  0.8280
# 498  0.8191  0.8200  0.8186  0.8207  0.8226  0.8196  0.8285  0.8389  0.8276
#
#          H1      H2      H3      H4      H5      H6
# 0    0.0936  0.0925  0.0918  0.0929  0.0931  0.0931
# 1    0.0970  0.0958  0.0951  0.0963  0.0963  0.0962
# 2    0.0971  0.0959  0.0952  0.0965  0.0964  0.0963
# 3    0.0975  0.0964  0.0957  0.0969  0.0969  0.0969
# 4    0.0981  0.0969  0.0961  0.0974  0.0973  0.0973
# ..      ...     ...     ...     ...     ...     ...
# 494  0.4360  0.7711  0.8043  0.8181  0.8181  0.8153
# 495  0.4379  0.7729  0.8038  0.8198  0.8180  0.8154
# 496  0.4304  0.7719  0.8040  0.8187  0.8172  0.8154
# 497  0.4321  0.7717  0.8043  0.8194  0.8173  0.8143
# 498  0.4285  0.7712  0.8035  0.8189  0.8177  0.8150
#
# [499 rows x 15 columns]

# %%
c=-1
P_exp=np.array(df1.iloc[:, 3:].drop('H1',axis=1))[:c]
T_exp=np.array(df1['Time [s]'])[:c]

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max
# Out:
# (14, 337235.3)

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 100 # Number of residual point
N_d = 300 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = T_star.min(0)
ub = T_star.max(0) 

# Initial Condition
xx1 = T_star[::len(T_exp)]
uu1 = P_star[::len(T_exp)]

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu1), replace=False)
xxd = T_star[idx]
uud = P_star[idx]

T_u_train = np.concatenate((xx1,xxd)).reshape([-1,1])
p_train = np.concatenate((uu1,uud)).reshape([-1,1])

T_f_train = lb + (ub-lb)*lhs(1, N_f)

T_u_train_tf = tf.convert_to_tensor(T_u_train, dtype=tf.float32)
p_train_tf =   tf.convert_to_tensor(p_train, dtype=tf.float32)
T_f_train_tf = tf.convert_to_tensor(T_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    A = 2.0*(X - lb)/(ub - lb) - 1.0
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 

def train_vars_total(W, b, lambda_r, lambda_b):
    return W + b + lambda_r + lambda_b

def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r, 1]), dtype=tf.float32)
    return alpha_r, alpha_b

#@tf.function(jit_compile=True)
@tf.function()
def net_f(t, m, W_p, b_p, W_phi, b_phi):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([t])
        u=net(t, W_p, b_p)
        phi=net(u, W_phi, b_phi)
        p=u[:,0:1]
        s=u[:,1:2]
        phi_p=phi[:,0:1]
        phi_s=phi[:,1:2]
    p_t = tape1.gradient(p, t) 
    s_t = tape1.gradient(s, t) 
    f_p = p_t - phi_p
    f_s = s_t - phi_s
    return f_p, f_s


#@tf.function()
@tf.function()
def train_step(W_p, b_p, W_phi, b_phi, X_u_train_tf, p_train_tf, X_f_train_tf, lambda_r, lambda_b, m, opt):
    
    t_u = X_u_train_tf
    t_f = X_f_train_tf

    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, lambda_r, lambda_b])
        u_nn = net(t_u, W_p, b_p) 
        f_p, f_s = net_f(t_f, m, W_p, b_p, W_phi, b_phi)
        p_nn = u_nn[:,0:1]
        loss_p = tf.square(lambda_b*(p_nn - p_train_tf))
        loss_fp = tf.square(lambda_r*f_p) 
        loss_fs = tf.square(lambda_r*f_s) 
        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)
    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    # grads_m = tape.gradient(loss, m)

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    # opt.apply_gradients(zip(grads_m, m))
   
    return loss, tf.reduce_mean(loss_p), tf.reduce_mean(loss_fp), tf.reduce_mean(loss_fs)



layers = [1, 50, 50, 2]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [2, 50, 50, 2]


W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lambda_r, lambda_b = loss_weight(N_f, N_d)
m = [tf.Variable(tf.ones([1,1]), dtype=tf.float32)]

# %%
lr = 1e-4
Nmax = 10**5

optimizer = tf.optimizers.Adam(learning_rate=lr)

start_time = time.time()
n=0
loss = []
loss_d = []
loss_fisp = []
loss_fiss = []

while n <= Nmax:
    loss_, loss_p, loss_fp, loss_fs = train_step(W_p, b_p, W_phi, b_phi, T_u_train_tf, p_train_tf, T_f_train_tf, lambda_r, lambda_b, m, optimizer)
    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp.append(loss_fp)
    loss_fiss.append(loss_fs)


    if n % 10 == 0:
        print(f"Iteration is: {n}")
        print(f"Total loss is: {loss_}")

        print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p is: {loss_fp}")
        print(f"Physicial loss of s is: {loss_fs}")

    n+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Total loss is: 769094.625
# Data loss is: 769094.0625
# Physicial loss of p is: 0.3506796360015869
# Physicial loss of s is: 0.1682427078485489
# Iteration is: 10
# Total loss is: 735398.25
# Data loss is: 735398.0
# Physicial loss of p is: 0.1538493037223816
# Physicial loss of s is: 0.10108762979507446
# Iteration is: 20
# Total loss is: 698516.25
# Data loss is: 698516.1875
# Physicial loss of p is: 0.028764288872480392
# Physicial loss of s is: 0.03940407186746597
# Iteration is: 30
# Total loss is: 662575.5625
# Data loss is: 662575.5625
# Physicial loss of p is: 0.0027353435289114714
# Physicial loss of s is: 0.005528337322175503
# Iteration is: 40
# Total loss is: 628962.0
# Data loss is: 628962.0
# Physicial loss of p is: 0.01916836015880108
# Physicial loss of s is: 0.0015489745419472456
# Iteration is: 50
# Total loss is: 596367.875
# Data loss is: 596367.875
# Physicial loss of p is: 0.02589113637804985
# Physicial loss of s is: 0.006479910109192133
# Iteration is: 60
# Total loss is: 563382.375
# Data loss is: 563382.375
# Physicial loss of p is: 0.01781020313501358
# Physicial loss of s is: 0.006722381338477135
# Iteration is: 70
# Total loss is: 529388.5625
# Data loss is: 529388.5625
# Physicial loss of p is: 0.00801317673176527
# Physicial loss of s is: 0.003918253816664219
# Iteration is: 80
# Total loss is: 494270.8125
# Data loss is: 494270.8125
# Physicial loss of p is: 0.002773707266896963
# Physicial loss of s is: 0.0019528188277035952
# Iteration is: 90
# Total loss is: 458088.84375
# Data loss is: 458088.84375
# Physicial loss of p is: 0.0010635866783559322
# Physicial loss of s is: 0.0013047716347500682
# Iteration is: 100
# Total loss is: 421015.53125
# Data loss is: 421015.53125
# Physicial loss of p is: 0.0007851611590012908
# Physicial loss of s is: 0.0011919460957869887
# Iteration is: 110
# Total loss is: 383362.5
# Data loss is: 383362.5
# Physicial loss of p is: 0.001102518872357905
# Physicial loss of s is: 0.0012111188843846321
# Iteration is: 120
# Total loss is: 345577.71875
# Data loss is: 345577.71875
# Physicial loss of p is: 0.001787465182133019
# Physicial loss of s is: 0.001293894019909203
# Iteration is: 130
# Total loss is: 308218.25
# Data loss is: 308218.25
# Physicial loss of p is: 0.0026073730550706387
# Physicial loss of s is: 0.001406951225362718
# Iteration is: 140
# Total loss is: 271917.90625
# Data loss is: 271917.90625
# Physicial loss of p is: 0.0033618209417909384
# Physicial loss of s is: 0.0015021944418549538
# Iteration is: 150
# Total loss is: 237350.03125
# Data loss is: 237350.03125
# Physicial loss of p is: 0.003989711403846741
# Physicial loss of s is: 0.0015545565402135253
# Iteration is: 160
# Total loss is: 205180.40625
# Data loss is: 205180.40625
# Physicial loss of p is: 0.0045145610347390175
# Physicial loss of s is: 0.001565988757647574
# Iteration is: 170
# Total loss is: 176013.765625
# Data loss is: 176013.765625
# Physicial loss of p is: 0.004955099895596504
# Physicial loss of s is: 0.0015462487936019897
# Iteration is: 180
# Total loss is: 150336.984375
# Data loss is: 150336.984375
# Physicial loss of p is: 0.005303698591887951
# Physicial loss of s is: 0.0015005874447524548
# Iteration is: 190
# Total loss is: 128467.2109375
# Data loss is: 128467.203125
# Physicial loss of p is: 0.005562507547438145
# Physicial loss of s is: 0.0014302432537078857
# Iteration is: 200
# Total loss is: 110513.7734375
# Data loss is: 110513.765625
# Physicial loss of p is: 0.005779697094112635
# Physicial loss of s is: 0.0013383979676291347
# Iteration is: 210
# Total loss is: 96363.65625
# Data loss is: 96363.6484375
# Physicial loss of p is: 0.006041548680514097
# Physicial loss of s is: 0.0012337699299678206
# Iteration is: 220
# Total loss is: 85696.859375
# Data loss is: 85696.8515625
# Physicial loss of p is: 0.0064227646216750145
# Physicial loss of s is: 0.0011282042833045125
# Iteration is: 230
# Total loss is: 78032.59375
# Data loss is: 78032.5859375
# Physicial loss of p is: 0.00693861860781908
# Physicial loss of s is: 0.0010306596523150802
# Iteration is: 240
# Total loss is: 72798.375
# Data loss is: 72798.3671875
# Physicial loss of p is: 0.0075395964086055756
# Physicial loss of s is: 0.0009436912951059639
# Iteration is: 250
# Total loss is: 69406.65625
# Data loss is: 69406.6484375
# Physicial loss of p is: 0.008146225474774837
# Physicial loss of s is: 0.0008651741081848741
# Iteration is: 260
# Total loss is: 67321.59375
# Data loss is: 67321.5859375
# Physicial loss of p is: 0.00868893787264824
# Physicial loss of s is: 0.0007921929936856031
# Iteration is: 270
# Total loss is: 66102.5625
# Data loss is: 66102.5546875
# Physicial loss of p is: 0.009127256460487843
# Physicial loss of s is: 0.0007231041672639549
# Iteration is: 280
# Total loss is: 65419.99609375
# Data loss is: 65419.98828125
# Physicial loss of p is: 0.009448752738535404
# Physicial loss of s is: 0.0006574742728844285
# Iteration is: 290
# Total loss is: 65048.15625
# Data loss is: 65048.1484375
# Physicial loss of p is: 0.00965961068868637
# Physicial loss of s is: 0.0005953785730525851
# Iteration is: 300
# Total loss is: 64844.61328125
# Data loss is: 64844.6015625
# Physicial loss of p is: 0.009775567799806595
# Physicial loss of s is: 0.0005369506543502212
# Iteration is: 310
# Total loss is: 64726.29296875
# Data loss is: 64726.28125
# Physicial loss of p is: 0.009815624915063381
# Physicial loss of s is: 0.00048227363731712103
# Iteration is: 320
# Total loss is: 64647.984375
# Data loss is: 64647.97265625
# Physicial loss of p is: 0.009798511862754822
# Physicial loss of s is: 0.00043138713226653636
# Iteration is: 330
# Total loss is: 64586.8203125
# Data loss is: 64586.8125
# Physicial loss of p is: 0.009740766137838364
# Physicial loss of s is: 0.00038430493441410363
# Iteration is: 340
# Total loss is: 64531.9296875
# Data loss is: 64531.921875
# Physicial loss of p is: 0.009655876085162163
# Physicial loss of s is: 0.0003410083882045001
# Iteration is: 350
# Total loss is: 64478.43359375
# Data loss is: 64478.42578125
# Physicial loss of p is: 0.009554092772305012
# Physicial loss of s is: 0.0003014526446349919
# Iteration is: 360
# Total loss is: 64424.2890625
# Data loss is: 64424.28125
# Physicial loss of p is: 0.009442904964089394
# Physicial loss of s is: 0.00026556957163847983
# Iteration is: 370
# Total loss is: 64368.6484375
# Data loss is: 64368.640625
# Physicial loss of p is: 0.009327499195933342
# Physicial loss of s is: 0.0002332758012926206
# Iteration is: 380
# Total loss is: 64311.16796875
# Data loss is: 64311.16015625
# Physicial loss of p is: 0.009211371652781963
# Physicial loss of s is: 0.0002044813008978963
# Iteration is: 390
# Total loss is: 64251.6875
# Data loss is: 64251.6796875
# Physicial loss of p is: 0.009096771478652954
# Physicial loss of s is: 0.00017908986774273217
# Iteration is: 400
# Total loss is: 64190.1015625
# Data loss is: 64190.09375
# Physicial loss of p is: 0.008985143154859543
# Physicial loss of s is: 0.00015700579388067126
# Iteration is: 410
# Total loss is: 64126.30859375
# Data loss is: 64126.30078125
# Physicial loss of p is: 0.008877390995621681
# Physicial loss of s is: 0.00013813390978612006
# Iteration is: 420
# Total loss is: 64060.22265625
# Data loss is: 64060.21484375
# Physicial loss of p is: 0.008774043060839176
# Physicial loss of s is: 0.00012238124327268451
# Iteration is: 430
# Total loss is: 63991.7421875
# Data loss is: 63991.734375
# Physicial loss of p is: 0.008675461634993553
# Physicial loss of s is: 0.00010965961701003835
# Iteration is: 440
# Total loss is: 63920.78125
# Data loss is: 63920.7734375
# Physicial loss of p is: 0.008581898175179958
# Physicial loss of s is: 9.988470264943317e-05
# Iteration is: 450
# Total loss is: 63847.234375
# Data loss is: 63847.2265625
# Physicial loss of p is: 0.008493504486978054
# Physicial loss of s is: 9.2978028988e-05
# Iteration is: 460
# Total loss is: 63770.98828125
# Data loss is: 63770.98046875
# Physicial loss of p is: 0.008410458452999592
# Physicial loss of s is: 8.886549767339602e-05
# Iteration is: 470
# Total loss is: 63691.9140625
# Data loss is: 63691.90625
# Physicial loss of p is: 0.008332905359566212
# Physicial loss of s is: 8.747955871513113e-05
# Iteration is: 480
# Total loss is: 63609.90234375
# Data loss is: 63609.89453125
# Physicial loss of p is: 0.008261006325483322
# Physicial loss of s is: 8.875902858562768e-05
# Iteration is: 490
# Total loss is: 63524.84765625
# Data loss is: 63524.83984375
# Physicial loss of p is: 0.008194930851459503
# Physicial loss of s is: 9.264981054002419e-05
# Iteration is: 500
# Total loss is: 63436.57421875
# Data loss is: 63436.56640625
# Physicial loss of p is: 0.008134865202009678
# Physicial loss of s is: 9.910334483720362e-05
# Iteration is: 510
# Total loss is: 63344.953125
# Data loss is: 63344.9453125
# Physicial loss of p is: 0.008081013336777687
# Physicial loss of s is: 0.00010808134538820013
# Iteration is: 520
# Total loss is: 63249.85546875
# Data loss is: 63249.84765625
# Physicial loss of p is: 0.008033613674342632
# Physicial loss of s is: 0.00011955108493566513
# Iteration is: 530
# Total loss is: 63151.1328125
# Data loss is: 63151.125
# Physicial loss of p is: 0.00799289345741272
# Physicial loss of s is: 0.0001334893750026822
# Iteration is: 540
# Total loss is: 63048.609375
# Data loss is: 63048.6015625
# Physicial loss of p is: 0.007959133014082909
# Physicial loss of s is: 0.00014988143811933696
# Iteration is: 550
# Total loss is: 62942.11328125
# Data loss is: 62942.10546875
# Physicial loss of p is: 0.007932598702609539
# Physicial loss of s is: 0.00016872193373274058
# Iteration is: 560
# Total loss is: 62831.49609375
# Data loss is: 62831.48828125
# Physicial loss of p is: 0.007913614623248577
# Physicial loss of s is: 0.00019001640612259507
# Iteration is: 570
# Total loss is: 62716.5546875
# Data loss is: 62716.546875
# Physicial loss of p is: 0.007902505807578564
# Physicial loss of s is: 0.0002137794508598745
# Iteration is: 580
# Total loss is: 62597.109375
# Data loss is: 62597.1015625
# Physicial loss of p is: 0.007899638265371323
# Physicial loss of s is: 0.00024003774160519242
# Iteration is: 590
# Total loss is: 62472.94140625
# Data loss is: 62472.93359375
# Physicial loss of p is: 0.00790538638830185
# Physicial loss of s is: 0.000268828182015568
# Iteration is: 600
# Total loss is: 62343.8828125
# Data loss is: 62343.875
# Physicial loss of p is: 0.007920170202851295
# Physicial loss of s is: 0.00030020010308362544
# Iteration is: 610
# Total loss is: 62209.7265625
# Data loss is: 62209.71875
# Physicial loss of p is: 0.007944430224597454
# Physicial loss of s is: 0.0003342174750287086
# Iteration is: 620
# Total loss is: 62070.20703125
# Data loss is: 62070.19921875
# Physicial loss of p is: 0.007978631183505058
# Physicial loss of s is: 0.0003709520387928933
# Iteration is: 630
# Total loss is: 61925.16015625
# Data loss is: 61925.15234375
# Physicial loss of p is: 0.008023294620215893
# Physicial loss of s is: 0.0004104962863493711
# Iteration is: 640
# Total loss is: 61774.29296875
# Data loss is: 61774.28515625
# Physicial loss of p is: 0.00807894952595234
# Physicial loss of s is: 0.00045295123709365726
# Iteration is: 650
# Total loss is: 61617.4296875
# Data loss is: 61617.421875
# Physicial loss of p is: 0.008146172389388084
# Physicial loss of s is: 0.0004984342376701534
# Iteration is: 660
# Total loss is: 61454.2890625
# Data loss is: 61454.28125
# Physicial loss of p is: 0.008225579746067524
# Physicial loss of s is: 0.0005470807664096355
# Iteration is: 670
# Total loss is: 61284.609375
# Data loss is: 61284.6015625
# Physicial loss of p is: 0.008317801170051098
# Physicial loss of s is: 0.0005990404752083123
# Iteration is: 680
# Total loss is: 61108.16015625
# Data loss is: 61108.15234375
# Physicial loss of p is: 0.008423524908721447
# Physicial loss of s is: 0.0006544786738231778
# Iteration is: 690
# Total loss is: 60924.67578125
# Data loss is: 60924.66796875
# Physicial loss of p is: 0.008543474599719048
# Physicial loss of s is: 0.000713579123839736
# Iteration is: 700
# Total loss is: 60733.875
# Data loss is: 60733.8671875
# Physicial loss of p is: 0.008678410202264786
# Physicial loss of s is: 0.0007765492773614824
# Iteration is: 710
# Total loss is: 60535.48828125
# Data loss is: 60535.48046875
# Physicial loss of p is: 0.008829120546579361
# Physicial loss of s is: 0.0008436054922640324
# Iteration is: 720
# Total loss is: 60329.26171875
# Data loss is: 60329.25390625
# Physicial loss of p is: 0.00899642612785101
# Physicial loss of s is: 0.0009149961406365037
# Iteration is: 730
# Total loss is: 60114.89453125
# Data loss is: 60114.88671875
# Physicial loss of p is: 0.009181206114590168
# Physicial loss of s is: 0.0009909754153341055
# Iteration is: 740
# Total loss is: 59892.11328125
# Data loss is: 59892.10546875
# Physicial loss of p is: 0.009384337812662125
# Physicial loss of s is: 0.0010718369157984853
# Iteration is: 750
# Total loss is: 59660.62109375
# Data loss is: 59660.61328125
# Physicial loss of p is: 0.009606749750673771
# Physicial loss of s is: 0.001157881342805922
# Iteration is: 760
# Total loss is: 59420.171875
# Data loss is: 59420.16015625
# Physicial loss of p is: 0.00984940305352211
# Physicial loss of s is: 0.0012494331458583474
# Iteration is: 770
# Total loss is: 59170.4375
# Data loss is: 59170.42578125
# Physicial loss of p is: 0.01011329609900713
# Physicial loss of s is: 0.001346832257695496
# Iteration is: 780
# Total loss is: 58911.16015625
# Data loss is: 58911.1484375
# Physicial loss of p is: 0.01039943564683199
# Physicial loss of s is: 0.001450447249226272
# Iteration is: 790
# Total loss is: 58642.078125
# Data loss is: 58642.06640625
# Physicial loss of p is: 0.010708860121667385
# Physicial loss of s is: 0.0015606426168233156
# Iteration is: 800
# Total loss is: 58362.890625
# Data loss is: 58362.87890625
# Physicial loss of p is: 0.011042723432183266
# Physicial loss of s is: 0.0016777935670688748
# Iteration is: 810
# Total loss is: 58073.37109375
# Data loss is: 58073.359375
# Physicial loss of p is: 0.011402156203985214
# Physicial loss of s is: 0.0018022715812548995
# Iteration is: 820
# Total loss is: 57773.23828125
# Data loss is: 57773.2265625
# Physicial loss of p is: 0.011788427829742432
# Physicial loss of s is: 0.0019344332395121455
# Iteration is: 830
# Total loss is: 57462.26171875
# Data loss is: 57462.24609375
# Physicial loss of p is: 0.012202884070575237
# Physicial loss of s is: 0.0020745969377458096
# Iteration is: 840
# Total loss is: 57140.2421875
# Data loss is: 57140.2265625
# Physicial loss of p is: 0.012647125869989395
# Physicial loss of s is: 0.002223019255325198
# Iteration is: 850
# Total loss is: 56806.9140625
# Data loss is: 56806.8984375
# Physicial loss of p is: 0.013122930191457272
# Physicial loss of s is: 0.0023798728361725807
# Iteration is: 860
# Total loss is: 56462.140625
# Data loss is: 56462.125
# Physicial loss of p is: 0.013632494956254959
# Physicial loss of s is: 0.002545199589803815
# Iteration is: 870
# Total loss is: 56105.75390625
# Data loss is: 56105.734375
# Physicial loss of p is: 0.014178452081978321
# Physicial loss of s is: 0.0027188891544938087
# Iteration is: 880
# Total loss is: 55737.59765625
# Data loss is: 55737.578125
# Physicial loss of p is: 0.014764199033379555
# Physicial loss of s is: 0.002900590654462576
# Iteration is: 890
# Total loss is: 55357.60546875
# Data loss is: 55357.5859375
# Physicial loss of p is: 0.0153939388692379
# Physicial loss of s is: 0.00308969896286726
# Iteration is: 900
# Total loss is: 54965.6796875
# Data loss is: 54965.66015625
# Physicial loss of p is: 0.016073139384388924
# Physicial loss of s is: 0.003285265527665615
# Iteration is: 910
# Total loss is: 54561.80078125
# Data loss is: 54561.78125
# Physicial loss of p is: 0.016808632761240005
# Physicial loss of s is: 0.0034859851002693176
# Iteration is: 920
# Total loss is: 54145.96484375
# Data loss is: 54145.94140625
# Physicial loss of p is: 0.0176091231405735
# Physicial loss of s is: 0.0036901296116411686
# Iteration is: 930
# Total loss is: 53718.25
# Data loss is: 53718.2265625
# Physicial loss of p is: 0.01848537288606167
# Physicial loss of s is: 0.0038955442141741514
# Iteration is: 940
# Total loss is: 53278.7578125
# Data loss is: 53278.734375
# Physicial loss of p is: 0.019450576975941658
# Physicial loss of s is: 0.004099676385521889
# Iteration is: 950
# Total loss is: 52827.62109375
# Data loss is: 52827.59765625
# Physicial loss of p is: 0.020520396530628204
# Physicial loss of s is: 0.0042996639385819435
# Iteration is: 960
# Total loss is: 52365.0625
# Data loss is: 52365.03515625
# Physicial loss of p is: 0.02171313762664795
# Physicial loss of s is: 0.004492398351430893
# Iteration is: 970
# Total loss is: 51891.33984375
# Data loss is: 51891.3125
# Physicial loss of p is: 0.023049285635352135
# Physicial loss of s is: 0.00467477273195982
# Iteration is: 980
# Total loss is: 51406.765625
# Data loss is: 51406.73828125
# Physicial loss of p is: 0.02455105260014534
# Physicial loss of s is: 0.0048438264057040215
# Iteration is: 990
# Total loss is: 50911.703125
# Data loss is: 50911.671875
# Physicial loss of p is: 0.026241611689329147
# Physicial loss of s is: 0.004996927455067635
# Iteration is: 1000
# Total loss is: 50406.546875
# Data loss is: 50406.515625
# Physicial loss of p is: 0.028143778443336487
# Physicial loss of s is: 0.005132011137902737
# Iteration is: 1010
# Total loss is: 49891.8125
# Data loss is: 49891.77734375
# Physicial loss of p is: 0.03027900494635105
# Physicial loss of s is: 0.005247543565928936
# Iteration is: 1020
# Total loss is: 49367.98046875
# Data loss is: 49367.9453125
# Physicial loss of p is: 0.03266609087586403
# Physicial loss of s is: 0.005342570599168539
# Iteration is: 1030
# Total loss is: 48835.6640625
# Data loss is: 48835.625
# Physicial loss of p is: 0.03532049059867859
# Physicial loss of s is: 0.005416560918092728
# Iteration is: 1040
# Total loss is: 48295.4296875
# Data loss is: 48295.38671875
# Physicial loss of p is: 0.038253992795944214
# Physicial loss of s is: 0.005469231400638819
# Iteration is: 1050
# Total loss is: 47747.9453125
# Data loss is: 47747.8984375
# Physicial loss of p is: 0.041474685072898865
# Physicial loss of s is: 0.005500455386936665
# Iteration is: 1060
# Total loss is: 47193.8984375
# Data loss is: 47193.84765625
# Physicial loss of p is: 0.044988133013248444
# Physicial loss of s is: 0.005510126240551472
# Iteration is: 1070
# Total loss is: 46634.03125
# Data loss is: 46633.98046875
# Physicial loss of p is: 0.048797961324453354
# Physicial loss of s is: 0.005498321261256933
# Iteration is: 1080
# Total loss is: 46069.05859375
# Data loss is: 46069.0
# Physicial loss of p is: 0.05290712043642998
# Physicial loss of s is: 0.005465294700115919
# Iteration is: 1090
# Total loss is: 45499.76953125
# Data loss is: 45499.70703125
# Physicial loss of p is: 0.0573187917470932
# Physicial loss of s is: 0.0054116989485919476
# Iteration is: 1100
# Total loss is: 44926.9453125
# Data loss is: 44926.87890625
# Physicial loss of p is: 0.0620371550321579
# Physicial loss of s is: 0.005338621791452169
# Iteration is: 1110
# Total loss is: 44351.39453125
# Data loss is: 44351.32421875
# Physicial loss of p is: 0.06706768274307251
# Physicial loss of s is: 0.005247569177299738
# Iteration is: 1120
# Total loss is: 43773.90625
# Data loss is: 43773.828125
# Physicial loss of p is: 0.07241737097501755
# Physicial loss of s is: 0.005140402354300022
# Iteration is: 1130
# Total loss is: 43195.296875
# Data loss is: 43195.21484375
# Physicial loss of p is: 0.07809486985206604
# Physicial loss of s is: 0.005019211210310459
# Iteration is: 1140
# Total loss is: 42616.3828125
# Data loss is: 42616.29296875
# Physicial loss of p is: 0.08411028236150742
# Physicial loss of s is: 0.004886206705123186
# Iteration is: 1150
# Total loss is: 42037.97265625
# Data loss is: 42037.87890625
# Physicial loss of p is: 0.09047532081604004
# Physicial loss of s is: 0.004743633791804314
# Iteration is: 1160
# Total loss is: 41460.83984375
# Data loss is: 41460.73828125
# Physicial loss of p is: 0.09720265120267868
# Physicial loss of s is: 0.004593702033162117
# Iteration is: 1170
# Total loss is: 40885.80078125
# Data loss is: 40885.69140625
# Physicial loss of p is: 0.10430575162172318
# Physicial loss of s is: 0.004438591189682484
# Iteration is: 1180
# Total loss is: 40313.6171875
# Data loss is: 40313.5
# Physicial loss of p is: 0.11179880052804947
# Physicial loss of s is: 0.004280415829271078
# Iteration is: 1190
# Total loss is: 39745.03125
# Data loss is: 39744.90625
# Physicial loss of p is: 0.1196959912776947
# Physicial loss of s is: 0.004121245816349983
# Iteration is: 1200
# Total loss is: 39180.80078125
# Data loss is: 39180.66796875
# Physicial loss of p is: 0.12801150977611542
# Physicial loss of s is: 0.003963092342019081
# Iteration is: 1210
# Total loss is: 38621.6328125
# Data loss is: 38621.4921875
# Physicial loss of p is: 0.13675889372825623
# Physicial loss of s is: 0.003807884408161044
# Iteration is: 1220
# Total loss is: 38068.2421875
# Data loss is: 38068.09375
# Physicial loss of p is: 0.14595064520835876
# Physicial loss of s is: 0.0036574983969330788
# Iteration is: 1230
# Total loss is: 37521.30078125
# Data loss is: 37521.140625
# Physicial loss of p is: 0.15559791028499603
# Physicial loss of s is: 0.0035137201193720102
# Iteration is: 1240
# Total loss is: 36981.4609375
# Data loss is: 36981.29296875
# Physicial loss of p is: 0.16570979356765747
# Physicial loss of s is: 0.0033782673999667168
# Iteration is: 1250
# Total loss is: 36449.359375
# Data loss is: 36449.1796875
# Physicial loss of p is: 0.17629289627075195
# Physicial loss of s is: 0.0032527593430131674
# Iteration is: 1260
# Total loss is: 35925.60546875
# Data loss is: 35925.4140625
# Physicial loss of p is: 0.18735066056251526
# Physicial loss of s is: 0.0031387179624289274
# Iteration is: 1270
# Total loss is: 35410.7578125
# Data loss is: 35410.5546875
# Physicial loss of p is: 0.198883056640625
# Physicial loss of s is: 0.003037553047761321
# Iteration is: 1280
# Total loss is: 34905.40625
# Data loss is: 34905.19140625
# Physicial loss of p is: 0.21088622510433197
# Physicial loss of s is: 0.002950520720332861
# Iteration is: 1290
# Total loss is: 34410.05859375
# Data loss is: 34409.83203125
# Physicial loss of p is: 0.22335132956504822
# Physicial loss of s is: 0.002878705970942974
# Iteration is: 1300
# Total loss is: 33925.19921875
# Data loss is: 33924.9609375
# Physicial loss of p is: 0.2362656146287918
# Physicial loss of s is: 0.002822990994900465
# Iteration is: 1310
# Total loss is: 33451.31640625
# Data loss is: 33451.0625
# Physicial loss of p is: 0.24961170554161072
# Physicial loss of s is: 0.0027840512339025736
# Iteration is: 1320
# Total loss is: 32988.83984375
# Data loss is: 32988.57421875
# Physicial loss of p is: 0.26336753368377686
# Physicial loss of s is: 0.0027623334899544716
# Iteration is: 1330
# Total loss is: 32538.16015625
# Data loss is: 32537.880859375
# Physicial loss of p is: 0.27750685811042786
# Physicial loss of s is: 0.002758113667368889
# Iteration is: 1340
# Total loss is: 32099.64453125
# Data loss is: 32099.349609375
# Physicial loss of p is: 0.2919995188713074
# Physicial loss of s is: 0.0027714723255485296
# Iteration is: 1350
# Total loss is: 31673.62890625
# Data loss is: 31673.3203125
# Physicial loss of p is: 0.3068118989467621
# Physicial loss of s is: 0.0028024124912917614
# Iteration is: 1360
# Total loss is: 31260.390625
# Data loss is: 31260.06640625
# Physicial loss of p is: 0.3219069540500641
# Physicial loss of s is: 0.0028508829418569803
# Iteration is: 1370
# Total loss is: 30860.185546875
# Data loss is: 30859.845703125
# Physicial loss of p is: 0.33724474906921387
# Physicial loss of s is: 0.002916867844760418
# Iteration is: 1380
# Total loss is: 30473.197265625
# Data loss is: 30472.83984375
# Physicial loss of p is: 0.3527824282646179
# Physicial loss of s is: 0.003000452881678939
# Iteration is: 1390
# Total loss is: 30099.61328125
# Data loss is: 30099.240234375
# Physicial loss of p is: 0.3684747815132141
# Physicial loss of s is: 0.0031018599402159452
# Iteration is: 1400
# Total loss is: 29739.53125
# Data loss is: 29739.142578125
# Physicial loss of p is: 0.3842737078666687
# Physicial loss of s is: 0.0032215446699410677
# Iteration is: 1410
# Total loss is: 29393.03125
# Data loss is: 29392.626953125
# Physicial loss of p is: 0.4001290500164032
# Physicial loss of s is: 0.003360159695148468
# Iteration is: 1420
# Total loss is: 29060.119140625
# Data loss is: 29059.69921875
# Physicial loss of p is: 0.4159877300262451
# Physicial loss of s is: 0.003518657758831978
# Iteration is: 1430
# Total loss is: 28740.8046875
# Data loss is: 28740.369140625
# Physicial loss of p is: 0.4317939877510071
# Physicial loss of s is: 0.0036982246674597263
# Iteration is: 1440
# Total loss is: 28434.98828125
# Data loss is: 28434.537109375
# Physicial loss of p is: 0.4474893808364868
# Physicial loss of s is: 0.003900352166965604
# Iteration is: 1450
# Total loss is: 28142.5859375
# Data loss is: 28142.119140625
# Physicial loss of p is: 0.4630129635334015
# Physicial loss of s is: 0.004126797895878553
# Iteration is: 1460
# Total loss is: 27863.41015625
# Data loss is: 27862.927734375
# Physicial loss of p is: 0.47830045223236084
# Physicial loss of s is: 0.00437964079901576
# Iteration is: 1470
# Total loss is: 27597.28515625
# Data loss is: 27596.787109375
# Physicial loss of p is: 0.4932846128940582
# Physicial loss of s is: 0.004661264829337597
# Iteration is: 1480
# Total loss is: 27343.947265625
# Data loss is: 27343.43359375
# Physicial loss of p is: 0.5078960061073303
# Physicial loss of s is: 0.004974352195858955
# Iteration is: 1490
# Total loss is: 27103.15625
# Data loss is: 27102.62890625
# Physicial loss of p is: 0.5220615267753601
# Physicial loss of s is: 0.005321943666785955
# Iteration is: 1500
# Total loss is: 26874.55859375
# Data loss is: 26874.017578125
# Physicial loss of p is: 0.5357059240341187
# Physicial loss of s is: 0.0057073356583714485
# Iteration is: 1510
# Total loss is: 26657.83203125
# Data loss is: 26657.27734375
# Physicial loss of p is: 0.5487509369850159
# Physicial loss of s is: 0.0061341868713498116
# Iteration is: 1520
# Total loss is: 26452.599609375
# Data loss is: 26452.033203125
# Physicial loss of p is: 0.5611165761947632
# Physicial loss of s is: 0.0066063906997442245
# Iteration is: 1530
# Total loss is: 26258.44921875
# Data loss is: 26257.869140625
# Physicial loss of p is: 0.5727202892303467
# Physicial loss of s is: 0.007128136232495308
# Iteration is: 1540
# Total loss is: 26074.9765625
# Data loss is: 26074.384765625
# Physicial loss of p is: 0.5834777355194092
# Physicial loss of s is: 0.007703777402639389
# Iteration is: 1550
# Total loss is: 25901.724609375
# Data loss is: 25901.123046875
# Physicial loss of p is: 0.5933041572570801
# Physicial loss of s is: 0.008337765000760555
# Iteration is: 1560
# Total loss is: 25738.248046875
# Data loss is: 25737.63671875
# Physicial loss of p is: 0.6021137833595276
# Physicial loss of s is: 0.009034666232764721
# Iteration is: 1570
# Total loss is: 25584.06640625
# Data loss is: 25583.447265625
# Physicial loss of p is: 0.6098214983940125
# Physicial loss of s is: 0.009798974730074406
# Iteration is: 1580
# Total loss is: 25438.736328125
# Data loss is: 25438.109375
# Physicial loss of p is: 0.6163434386253357
# Physicial loss of s is: 0.010634989477694035
# Iteration is: 1590
# Total loss is: 25301.755859375
# Data loss is: 25301.123046875
# Physicial loss of p is: 0.621599018573761
# Physicial loss of s is: 0.011546728201210499
# Iteration is: 1600
# Total loss is: 25172.6640625
# Data loss is: 25172.02734375
# Physicial loss of p is: 0.6255119442939758
# Physicial loss of s is: 0.012537841685116291
# Iteration is: 1610
# Total loss is: 25050.990234375
# Data loss is: 25050.34765625
# Physicial loss of p is: 0.6280124187469482
# Physicial loss of s is: 0.013611359521746635
# Iteration is: 1620
# Total loss is: 24936.28125
# Data loss is: 24935.63671875
# Physicial loss of p is: 0.6290377974510193
# Physicial loss of s is: 0.014769655652344227
# Iteration is: 1630
# Total loss is: 24828.05859375
# Data loss is: 24827.4140625
# Physicial loss of p is: 0.6285371780395508
# Physicial loss of s is: 0.016014277935028076
# Iteration is: 1640
# Total loss is: 24725.89453125
# Data loss is: 24725.25
# Physicial loss of p is: 0.6264711618423462
# Physicial loss of s is: 0.017345871776342392
# Iteration is: 1650
# Total loss is: 24629.353515625
# Data loss is: 24628.7109375
# Physicial loss of p is: 0.6228161454200745
# Physicial loss of s is: 0.018764030188322067
# Iteration is: 1660
# Total loss is: 24538.02734375
# Data loss is: 24537.390625
# Physicial loss of p is: 0.6175650954246521
# Physicial loss of s is: 0.02026727981865406
# Iteration is: 1670
# Total loss is: 24451.53125
# Data loss is: 24450.8984375
# Physicial loss of p is: 0.6107296943664551
# Physicial loss of s is: 0.021853040903806686
# Iteration is: 1680
# Total loss is: 24369.4609375
# Data loss is: 24368.8359375
# Physicial loss of p is: 0.602340817451477
# Physicial loss of s is: 0.023517513647675514
# Iteration is: 1690
# Total loss is: 24291.4765625
# Data loss is: 24290.859375
# Physicial loss of p is: 0.5924511551856995
# Physicial loss of s is: 0.0252557173371315
# Iteration is: 1700
# Total loss is: 24217.2421875
# Data loss is: 24216.6328125
# Physicial loss of p is: 0.5811336636543274
# Physicial loss of s is: 0.027061553671956062
# Iteration is: 1710
# Total loss is: 24146.43359375
# Data loss is: 24145.8359375
# Physicial loss of p is: 0.5684822797775269
# Physicial loss of s is: 0.028927752748131752
# Iteration is: 1720
# Total loss is: 24078.75
# Data loss is: 24078.1640625
# Physicial loss of p is: 0.5546107292175293
# Physicial loss of s is: 0.030845938250422478
# Iteration is: 1730
# Total loss is: 24013.916015625
# Data loss is: 24013.34375
# Physicial loss of p is: 0.5396502017974854
# Physicial loss of s is: 0.03280665725469589
# Iteration is: 1740
# Total loss is: 23951.66796875
# Data loss is: 23951.109375
# Physicial loss of p is: 0.5237481594085693
# Physicial loss of s is: 0.03479950875043869
# Iteration is: 1750
# Total loss is: 23891.798828125
# Data loss is: 23891.25390625
# Physicial loss of p is: 0.5070644617080688
# Physicial loss of s is: 0.03681306540966034
# Iteration is: 1760
# Total loss is: 23834.0546875
# Data loss is: 23833.525390625
# Physicial loss of p is: 0.4897700548171997
# Physicial loss of s is: 0.03883494436740875
# Iteration is: 1770
# Total loss is: 23778.24609375
# Data loss is: 23777.732421875
# Physicial loss of p is: 0.47204166650772095
# Physicial loss of s is: 0.04085215926170349
# Iteration is: 1780
# Total loss is: 23724.19140625
# Data loss is: 23723.6953125
# Physicial loss of p is: 0.4540597200393677
# Physicial loss of s is: 0.042850837111473083
# Iteration is: 1790
# Total loss is: 23671.724609375
# Data loss is: 23671.244140625
# Physicial loss of p is: 0.43600204586982727
# Physicial loss of s is: 0.04481678456068039
# Iteration is: 1800
# Total loss is: 23620.68359375
# Data loss is: 23620.21875
# Physicial loss of p is: 0.4180426001548767
# Physicial loss of s is: 0.046735409647226334
# Iteration is: 1810
# Total loss is: 23570.951171875
# Data loss is: 23570.501953125
# Physicial loss of p is: 0.40034550428390503
# Physicial loss of s is: 0.048592403531074524
# Iteration is: 1820
# Total loss is: 23522.384765625
# Data loss is: 23521.951171875
# Physicial loss of p is: 0.3830619156360626
# Physicial loss of s is: 0.050373625010252
# Iteration is: 1830
# Total loss is: 23474.8828125
# Data loss is: 23474.462890625
# Physicial loss of p is: 0.3663285970687866
# Physicial loss of s is: 0.052065733820199966
# Iteration is: 1840
# Total loss is: 23428.337890625
# Data loss is: 23427.935546875
# Physicial loss of p is: 0.35026031732559204
# Physicial loss of s is: 0.053656548261642456
# Iteration is: 1850
# Total loss is: 23382.677734375
# Data loss is: 23382.2890625
# Physicial loss of p is: 0.33495453000068665
# Physicial loss of s is: 0.05513514578342438
# Iteration is: 1860
# Total loss is: 23337.802734375
# Data loss is: 23337.42578125
# Physicial loss of p is: 0.320484459400177
# Physicial loss of s is: 0.056492291390895844
# Iteration is: 1870
# Total loss is: 23293.658203125
# Data loss is: 23293.29296875
# Physicial loss of p is: 0.30690106749534607
# Physicial loss of s is: 0.05772067606449127
# Iteration is: 1880
# Total loss is: 23250.1796875
# Data loss is: 23249.826171875
# Physicial loss of p is: 0.2942347228527069
# Physicial loss of s is: 0.05881505459547043
# Iteration is: 1890
# Total loss is: 23207.314453125
# Data loss is: 23206.970703125
# Physicial loss of p is: 0.2824929356575012
# Physicial loss of s is: 0.059772443026304245
# Iteration is: 1900
# Total loss is: 23165.001953125
# Data loss is: 23164.669921875
# Physicial loss of p is: 0.27166521549224854
# Physicial loss of s is: 0.06059177964925766
# Iteration is: 1910
# Total loss is: 23123.21875
# Data loss is: 23122.896484375
# Physicial loss of p is: 0.2617259621620178
# Physicial loss of s is: 0.06127435714006424
# Iteration is: 1920
# Total loss is: 23081.912109375
# Data loss is: 23081.59765625
# Physicial loss of p is: 0.25263291597366333
# Physicial loss of s is: 0.06182355433702469
# Iteration is: 1930
# Total loss is: 23041.052734375
# Data loss is: 23040.74609375
# Physicial loss of p is: 0.2443367838859558
# Physicial loss of s is: 0.06224388629198074
# Iteration is: 1940
# Total loss is: 23000.626953125
# Data loss is: 23000.328125
# Physicial loss of p is: 0.23677806556224823
# Physicial loss of s is: 0.06254222989082336
# Iteration is: 1950
# Total loss is: 22960.59375
# Data loss is: 22960.30078125
# Physicial loss of p is: 0.2298942506313324
# Physicial loss of s is: 0.0627259761095047
# Iteration is: 1960
# Total loss is: 22920.9375
# Data loss is: 22920.65234375
# Physicial loss of p is: 0.22362053394317627
# Physicial loss of s is: 0.0628039613366127
# Iteration is: 1970
# Total loss is: 22881.638671875
# Data loss is: 22881.357421875
# Physicial loss of p is: 0.21789290010929108
# Physicial loss of s is: 0.0627853199839592
# Iteration is: 1980
# Total loss is: 22842.6953125
# Data loss is: 22842.419921875
# Physicial loss of p is: 0.21264885365962982
# Physicial loss of s is: 0.06267984211444855
# Iteration is: 1990
# Total loss is: 22804.0859375
# Data loss is: 22803.81640625
# Physicial loss of p is: 0.20782989263534546
# Physicial loss of s is: 0.062496885657310486
# Iteration is: 2000
# Total loss is: 22765.79296875
# Data loss is: 22765.52734375
# Physicial loss of p is: 0.2033819705247879
# Physicial loss of s is: 0.062246065586805344
# Iteration is: 2010
# Total loss is: 22727.81640625
# Data loss is: 22727.5546875
# Physicial loss of p is: 0.19925586879253387
# Physicial loss of s is: 0.06193670257925987
# Iteration is: 2020
# Total loss is: 22690.134765625
# Data loss is: 22689.876953125
# Physicial loss of p is: 0.19540631771087646
# Physicial loss of s is: 0.0615784153342247
# Iteration is: 2030
# Total loss is: 22652.7578125
# Data loss is: 22652.505859375
# Physicial loss of p is: 0.19179782271385193
# Physicial loss of s is: 0.061176929622888565
# Iteration is: 2040
# Total loss is: 22615.673828125
# Data loss is: 22615.42578125
# Physicial loss of p is: 0.18839475512504578
# Physicial loss of s is: 0.060740094631910324
# Iteration is: 2050
# Total loss is: 22578.869140625
# Data loss is: 22578.623046875
# Physicial loss of p is: 0.18526478111743927
# Physicial loss of s is: 0.060186538845300674
# Iteration is: 2060
# Total loss is: 22542.349609375
# Data loss is: 22542.107421875
# Physicial loss of p is: 0.1821002960205078
# Physicial loss of s is: 0.05981317535042763
# Iteration is: 2070
# Total loss is: 22506.11328125
# Data loss is: 22505.875
# Physicial loss of p is: 0.17930147051811218
# Physicial loss of s is: 0.05922507867217064
# Iteration is: 2080
# Total loss is: 22470.154296875
# Data loss is: 22469.919921875
# Physicial loss of p is: 0.1763647049665451
# Physicial loss of s is: 0.058872073888778687
# Iteration is: 2090
# Total loss is: 22434.462890625
# Data loss is: 22434.23046875
# Physicial loss of p is: 0.17372821271419525
# Physicial loss of s is: 0.05830659717321396
# Iteration is: 2100
# Total loss is: 22399.064453125
# Data loss is: 22398.833984375
# Physicial loss of p is: 0.17114539444446564
# Physicial loss of s is: 0.05776787921786308
# Iteration is: 2110
# Total loss is: 22363.921875
# Data loss is: 22363.697265625
# Physicial loss of p is: 0.16859237849712372
# Physicial loss of s is: 0.0572674497961998
# Iteration is: 2120
# Total loss is: 22329.052734375
# Data loss is: 22328.830078125
# Physicial loss of p is: 0.16611021757125854
# Physicial loss of s is: 0.056757740676403046
# Iteration is: 2130
# Total loss is: 22294.45703125
# Data loss is: 22294.236328125
# Physicial loss of p is: 0.16369014978408813
# Physicial loss of s is: 0.05624181777238846
# Iteration is: 2140
# Total loss is: 22260.12890625
# Data loss is: 22259.91015625
# Physicial loss of p is: 0.16131870448589325
# Physicial loss of s is: 0.055727243423461914
# Iteration is: 2150
# Total loss is: 22226.0703125
# Data loss is: 22225.857421875
# Physicial loss of p is: 0.15898862481117249
# Physicial loss of s is: 0.05521925911307335
# Iteration is: 2160
# Total loss is: 22192.267578125
# Data loss is: 22192.056640625
# Physicial loss of p is: 0.15669110417366028
# Physicial loss of s is: 0.05472194775938988
# Iteration is: 2170
# Total loss is: 22158.748046875
# Data loss is: 22158.5390625
# Physicial loss of p is: 0.1544322520494461
# Physicial loss of s is: 0.05422544479370117
# Iteration is: 2180
# Total loss is: 22125.505859375
# Data loss is: 22125.298828125
# Physicial loss of p is: 0.15220141410827637
# Physicial loss of s is: 0.053739797323942184
# Iteration is: 2190
# Total loss is: 22092.5078125
# Data loss is: 22092.3046875
# Physicial loss of p is: 0.1499985307455063
# Physicial loss of s is: 0.05326148867607117
# Iteration is: 2200
# Total loss is: 22059.783203125
# Data loss is: 22059.58203125
# Physicial loss of p is: 0.1478174924850464
# Physicial loss of s is: 0.052795276045799255
# Iteration is: 2210
# Total loss is: 22027.33203125
# Data loss is: 22027.1328125
# Physicial loss of p is: 0.1455700397491455
# Physicial loss of s is: 0.0524338036775589
# Iteration is: 2220
# Total loss is: 21995.146484375
# Data loss is: 21994.951171875
# Physicial loss of p is: 0.14385885000228882
# Physicial loss of s is: 0.051613207906484604
# Iteration is: 2230
# Total loss is: 21963.220703125
# Data loss is: 21963.029296875
# Physicial loss of p is: 0.141556978225708
# Physicial loss of s is: 0.05136861652135849
# Iteration is: 2240
# Total loss is: 21931.572265625
# Data loss is: 21931.3828125
# Physicial loss of p is: 0.13933558762073517
# Physicial loss of s is: 0.05111214518547058
# Iteration is: 2250
# Total loss is: 21900.177734375
# Data loss is: 21899.990234375
# Physicial loss of p is: 0.1373191475868225
# Physicial loss of s is: 0.05067683383822441
# Iteration is: 2260
# Total loss is: 21869.0546875
# Data loss is: 21868.869140625
# Physicial loss of p is: 0.13534550368785858
# Physicial loss of s is: 0.050221968442201614
# Iteration is: 2270
# Total loss is: 21838.197265625
# Data loss is: 21838.013671875
# Physicial loss of p is: 0.13335475325584412
# Physicial loss of s is: 0.049809664487838745
# Iteration is: 2280
# Total loss is: 21807.599609375
# Data loss is: 21807.419921875
# Physicial loss of p is: 0.13136260211467743
# Physicial loss of s is: 0.049420151859521866
# Iteration is: 2290
# Total loss is: 21777.275390625
# Data loss is: 21777.09765625
# Physicial loss of p is: 0.12938132882118225
# Physicial loss of s is: 0.0490407794713974
# Iteration is: 2300
# Total loss is: 21747.21484375
# Data loss is: 21747.0390625
# Physicial loss of p is: 0.127413809299469
# Physicial loss of s is: 0.04866728186607361
# Iteration is: 2310
# Total loss is: 21717.416015625
# Data loss is: 21717.2421875
# Physicial loss of p is: 0.12546443939208984
# Physicial loss of s is: 0.04829452559351921
# Iteration is: 2320
# Total loss is: 21687.884765625
# Data loss is: 21687.712890625
# Physicial loss of p is: 0.12353155016899109
# Physicial loss of s is: 0.047924384474754333
# Iteration is: 2330
# Total loss is: 21658.6015625
# Data loss is: 21658.43359375
# Physicial loss of p is: 0.12160545587539673
# Physicial loss of s is: 0.047564972192049026
# Iteration is: 2340
# Total loss is: 21629.5859375
# Data loss is: 21629.419921875
# Physicial loss of p is: 0.11969146132469177
# Physicial loss of s is: 0.047210607677698135
# Iteration is: 2350
# Total loss is: 21600.84765625
# Data loss is: 21600.68359375
# Physicial loss of p is: 0.11778556555509567
# Physicial loss of s is: 0.046864595264196396
# Iteration is: 2360
# Total loss is: 21572.341796875
# Data loss is: 21572.1796875
# Physicial loss of p is: 0.11588730663061142
# Physicial loss of s is: 0.0465274415910244
# Iteration is: 2370
# Total loss is: 21544.1171875
# Data loss is: 21543.95703125
# Physicial loss of p is: 0.11391565203666687
# Physicial loss of s is: 0.046283408999443054
# Iteration is: 2380
# Total loss is: 21516.142578125
# Data loss is: 21515.986328125
# Physicial loss of p is: 0.11218360811471939
# Physicial loss of s is: 0.04581616073846817
# Iteration is: 2390
# Total loss is: 21488.43359375
# Data loss is: 21488.279296875
# Physicial loss of p is: 0.11030121147632599
# Physicial loss of s is: 0.04553328454494476
# Iteration is: 2400
# Total loss is: 21460.978515625
# Data loss is: 21460.82421875
# Physicial loss of p is: 0.10849915444850922
# Physicial loss of s is: 0.04518822580575943
# Iteration is: 2410
# Total loss is: 21433.775390625
# Data loss is: 21433.623046875
# Physicial loss of p is: 0.10667092353105545
# Physicial loss of s is: 0.044883307069540024
# Iteration is: 2420
# Total loss is: 21406.837890625
# Data loss is: 21406.6875
# Physicial loss of p is: 0.10483726859092712
# Physicial loss of s is: 0.04459618404507637
# Iteration is: 2430
# Total loss is: 21380.138671875
# Data loss is: 21379.990234375
# Physicial loss of p is: 0.1030125617980957
# Physicial loss of s is: 0.04431239143013954
# Iteration is: 2440
# Total loss is: 21353.697265625
# Data loss is: 21353.55078125
# Physicial loss of p is: 0.10121147334575653
# Physicial loss of s is: 0.04401624575257301
# Iteration is: 2450
# Total loss is: 21327.513671875
# Data loss is: 21327.37109375
# Physicial loss of p is: 0.09944124519824982
# Physicial loss of s is: 0.043699558824300766
# Iteration is: 2460
# Total loss is: 21301.5703125
# Data loss is: 21301.4296875
# Physicial loss of p is: 0.09767133742570877
# Physicial loss of s is: 0.04339363053441048
# Iteration is: 2470
# Total loss is: 21275.884765625
# Data loss is: 21275.74609375
# Physicial loss of p is: 0.09589264541864395
# Physicial loss of s is: 0.04310731589794159
# Iteration is: 2480
# Total loss is: 21250.4375
# Data loss is: 21250.30078125
# Physicial loss of p is: 0.09413791447877884
# Physicial loss of s is: 0.042806606739759445
# Iteration is: 2490
# Total loss is: 21225.248046875
# Data loss is: 21225.11328125
# Physicial loss of p is: 0.09238605201244354
# Physicial loss of s is: 0.04251343756914139
# Iteration is: 2500
# Total loss is: 21200.296875
# Data loss is: 21200.1640625
# Physicial loss of p is: 0.09064098447561264
# Physicial loss of s is: 0.04222343862056732
# Iteration is: 2510
# Total loss is: 21175.587890625
# Data loss is: 21175.45703125
# Physicial loss of p is: 0.08889532089233398
# Physicial loss of s is: 0.04194432124495506
# Iteration is: 2520
# Total loss is: 21151.123046875
# Data loss is: 21150.994140625
# Physicial loss of p is: 0.08694345504045486
# Physicial loss of s is: 0.041905418038368225
# Iteration is: 2530
# Total loss is: 21126.896484375
# Data loss is: 21126.76953125
# Physicial loss of p is: 0.08591161668300629
# Physicial loss of s is: 0.040969036519527435
# Iteration is: 2540
# Total loss is: 21102.908203125
# Data loss is: 21102.783203125
# Physicial loss of p is: 0.08393972367048264
# Physicial loss of s is: 0.040925282984972
# Iteration is: 2550
# Total loss is: 21079.162109375
# Data loss is: 21079.0390625
# Physicial loss of p is: 0.082071952521801
# Physicial loss of s is: 0.040823906660079956
# Iteration is: 2560
# Total loss is: 21055.640625
# Data loss is: 21055.51953125
# Physicial loss of p is: 0.08035454154014587
# Physicial loss of s is: 0.04059081897139549
# Iteration is: 2570
# Total loss is: 21032.3515625
# Data loss is: 21032.232421875
# Physicial loss of p is: 0.07870689034461975
# Physicial loss of s is: 0.04029542952775955
# Iteration is: 2580
# Total loss is: 21009.30859375
# Data loss is: 21009.193359375
# Physicial loss of p is: 0.07707469165325165
# Physicial loss of s is: 0.0399942509829998
# Iteration is: 2590
# Total loss is: 20986.4765625
# Data loss is: 20986.361328125
# Physicial loss of p is: 0.07544814050197601
# Physicial loss of s is: 0.03969784826040268
# Iteration is: 2600
# Total loss is: 20963.880859375
# Data loss is: 20963.767578125
# Physicial loss of p is: 0.07383032143115997
# Physicial loss of s is: 0.03940264880657196
# Iteration is: 2610
# Total loss is: 20941.515625
# Data loss is: 20941.404296875
# Physicial loss of p is: 0.07222381234169006
# Physicial loss of s is: 0.03910689055919647
# Iteration is: 2620
# Total loss is: 20919.365234375
# Data loss is: 20919.255859375
# Physicial loss of p is: 0.07062450051307678
# Physicial loss of s is: 0.038815245032310486
# Iteration is: 2630
# Total loss is: 20897.44140625
# Data loss is: 20897.333984375
# Physicial loss of p is: 0.0690285786986351
# Physicial loss of s is: 0.03853137046098709
# Iteration is: 2640
# Total loss is: 20875.740234375
# Data loss is: 20875.6328125
# Physicial loss of p is: 0.06745409220457077
# Physicial loss of s is: 0.03823864832520485
# Iteration is: 2650
# Total loss is: 20854.25390625
# Data loss is: 20854.150390625
# Physicial loss of p is: 0.06589256972074509
# Physicial loss of s is: 0.037945862859487534
# Iteration is: 2660
# Total loss is: 20832.978515625
# Data loss is: 20832.876953125
# Physicial loss of p is: 0.06434832513332367
# Physicial loss of s is: 0.03764910623431206
# Iteration is: 2670
# Total loss is: 20811.923828125
# Data loss is: 20811.82421875
# Physicial loss of p is: 0.062820203602314
# Physicial loss of s is: 0.03735020011663437
# Iteration is: 2680
# Total loss is: 20791.076171875
# Data loss is: 20790.978515625
# Physicial loss of p is: 0.06131697818636894
# Physicial loss of s is: 0.037042051553726196
# Iteration is: 2690
# Total loss is: 20770.443359375
# Data loss is: 20770.345703125
# Physicial loss of p is: 0.05991823598742485
# Physicial loss of s is: 0.03664811700582504
# Iteration is: 2700
# Total loss is: 20750.00390625
# Data loss is: 20749.91015625
# Physicial loss of p is: 0.05870874226093292
# Physicial loss of s is: 0.03611304983496666
# Iteration is: 2710
# Total loss is: 20729.783203125
# Data loss is: 20729.69140625
# Physicial loss of p is: 0.05717294663190842
# Physicial loss of s is: 0.03588319942355156
# Iteration is: 2720
# Total loss is: 20709.755859375
# Data loss is: 20709.666015625
# Physicial loss of p is: 0.0556081160902977
# Physicial loss of s is: 0.03570083528757095
# Iteration is: 2730
# Total loss is: 20689.935546875
# Data loss is: 20689.845703125
# Physicial loss of p is: 0.05411248654127121
# Physicial loss of s is: 0.03547865152359009
# Iteration is: 2740
# Total loss is: 20670.30859375
# Data loss is: 20670.220703125
# Physicial loss of p is: 0.052661266177892685
# Physicial loss of s is: 0.035236235707998276
# Iteration is: 2750
# Total loss is: 20650.888671875
# Data loss is: 20650.802734375
# Physicial loss of p is: 0.05126117542386055
# Physicial loss of s is: 0.03496543690562248
# Iteration is: 2760
# Total loss is: 20631.65234375
# Data loss is: 20631.56640625
# Physicial loss of p is: 0.049932852387428284
# Physicial loss of s is: 0.03464489057660103
# Iteration is: 2770
# Total loss is: 20612.61328125
# Data loss is: 20612.529296875
# Physicial loss of p is: 0.04864910617470741
# Physicial loss of s is: 0.03430257737636566
# Iteration is: 2780
# Total loss is: 20593.765625
# Data loss is: 20593.685546875
# Physicial loss of p is: 0.047349344938993454
# Physicial loss of s is: 0.0340011827647686
# Iteration is: 2790
# Total loss is: 20575.1015625
# Data loss is: 20575.021484375
# Physicial loss of p is: 0.04608919098973274
# Physicial loss of s is: 0.03368459269404411
# Iteration is: 2800
# Total loss is: 20556.623046875
# Data loss is: 20556.544921875
# Physicial loss of p is: 0.044855665415525436
# Physicial loss of s is: 0.033368274569511414
# Iteration is: 2810
# Total loss is: 20538.32421875
# Data loss is: 20538.248046875
# Physicial loss of p is: 0.04365464299917221
# Physicial loss of s is: 0.03304659202694893
# Iteration is: 2820
# Total loss is: 20520.208984375
# Data loss is: 20520.1328125
# Physicial loss of p is: 0.04248089715838432
# Physicial loss of s is: 0.03272566944360733
# Iteration is: 2830
# Total loss is: 20502.2578125
# Data loss is: 20502.18359375
# Physicial loss of p is: 0.04133984446525574
# Physicial loss of s is: 0.03240129351615906
# Iteration is: 2840
# Total loss is: 20484.505859375
# Data loss is: 20484.43359375
# Physicial loss of p is: 0.04027479141950607
# Physicial loss of s is: 0.03203168511390686
# Iteration is: 2850
# Total loss is: 20466.9140625
# Data loss is: 20466.84375
# Physicial loss of p is: 0.039915651082992554
# Physicial loss of s is: 0.031117357313632965
# Iteration is: 2860
# Total loss is: 20449.5
# Data loss is: 20449.4296875
# Physicial loss of p is: 0.03839932382106781
# Physicial loss of s is: 0.031160475686192513
# Iteration is: 2870
# Total loss is: 20432.248046875
# Data loss is: 20432.1796875
# Physicial loss of p is: 0.03728782758116722
# Physicial loss of s is: 0.030925368890166283
# Iteration is: 2880
# Total loss is: 20415.17578125
# Data loss is: 20415.107421875
# Physicial loss of p is: 0.03620709106326103
# Physicial loss of s is: 0.030696429312229156
# Iteration is: 2890
# Total loss is: 20398.251953125
# Data loss is: 20398.185546875
# Physicial loss of p is: 0.03518960624933243
# Physicial loss of s is: 0.030442487448453903
# Iteration is: 2900
# ...
# Iteration is: 99110
# Total loss is: 401.10150146484375
# Data loss is: 401.10150146484375
# Physicial loss of p is: 8.075548976194113e-06
# Physicial loss of s is: 7.2001507760433014e-06
# Iteration is: 99120
# Total loss is: 401.10174560546875
# Data loss is: 401.10174560546875
# Physicial loss of p is: 8.097119462036062e-06
# Physicial loss of s is: 7.190222277131397e-06
# Iteration is: 99130
# Total loss is: 401.1000061035156
# Data loss is: 401.1000061035156
# Physicial loss of p is: 8.055554644670337e-06
# Physicial loss of s is: 7.195598300313577e-06
# Iteration is: 99140
# Total loss is: 401.1015930175781
# Data loss is: 401.1015930175781
# Physicial loss of p is: 8.037271982175298e-06
# Physicial loss of s is: 7.1682402449368965e-06
# Iteration is: 99150
# Total loss is: 401.1009521484375
# Data loss is: 401.1009521484375
# Physicial loss of p is: 8.025785973586608e-06
# Physicial loss of s is: 7.167967396526365e-06
# Iteration is: 99160
# Total loss is: 401.10076904296875
# Data loss is: 401.10076904296875
# Physicial loss of p is: 8.074204743024893e-06
# Physicial loss of s is: 7.184054538811324e-06
# Iteration is: 99170
# Total loss is: 401.10357666015625
# Data loss is: 401.10357666015625
# Physicial loss of p is: 8.613500540377572e-06
# Physicial loss of s is: 7.5832595030078664e-06
# Iteration is: 99180
# Total loss is: 401.19158935546875
# Data loss is: 401.1915283203125
# Physicial loss of p is: 2.6382491341792047e-05
# Physicial loss of s is: 2.1954583644401282e-05
# Iteration is: 99190
# Total loss is: 402.92388916015625
# Data loss is: 402.9232177734375
# Physicial loss of p is: 0.00036022986751049757
# Physicial loss of s is: 0.00029484418337233365
# Iteration is: 99200
# Total loss is: 401.4826965332031
# Data loss is: 401.4825439453125
# Physicial loss of p is: 8.077770326053724e-05
# Physicial loss of s is: 6.61240192130208e-05
# Iteration is: 99210
# Total loss is: 401.1216735839844
# Data loss is: 401.1216735839844
# Physicial loss of p is: 1.2420096027199179e-05
# Physicial loss of s is: 1.1241681932006031e-05
# Iteration is: 99220
# Total loss is: 401.1742248535156
# Data loss is: 401.1741638183594
# Physicial loss of p is: 2.2755126337870024e-05
# Physicial loss of s is: 1.9559212887543254e-05
# Iteration is: 99230
# Total loss is: 401.10430908203125
# Data loss is: 401.10430908203125
# Physicial loss of p is: 8.766295650275424e-06
# Physicial loss of s is: 7.84382973506581e-06
# Iteration is: 99240
# Total loss is: 401.1027526855469
# Data loss is: 401.1027526855469
# Physicial loss of p is: 8.483100828016177e-06
# Physicial loss of s is: 7.5829912020708434e-06
# Iteration is: 99250
# Total loss is: 401.103759765625
# Data loss is: 401.103759765625
# Physicial loss of p is: 8.671177965879906e-06
# Physicial loss of s is: 7.626478691236116e-06
# Iteration is: 99260
# Total loss is: 401.1007995605469
# Data loss is: 401.1007995605469
# Physicial loss of p is: 8.208220606320538e-06
# Physicial loss of s is: 7.359471510426374e-06
# Iteration is: 99270
# Total loss is: 401.1012878417969
# Data loss is: 401.1012878417969
# Physicial loss of p is: 8.069593604886904e-06
# Physicial loss of s is: 7.179504791565705e-06
# Iteration is: 99280
# Total loss is: 401.1002197265625
# Data loss is: 401.1002197265625
# Physicial loss of p is: 7.990045560291037e-06
# Physicial loss of s is: 7.166902832977939e-06
# Iteration is: 99290
# Total loss is: 401.1001281738281
# Data loss is: 401.1001281738281
# Physicial loss of p is: 7.953150088724215e-06
# Physicial loss of s is: 7.114774689398473e-06
# Iteration is: 99300
# Total loss is: 401.09906005859375
# Data loss is: 401.09906005859375
# Physicial loss of p is: 7.927194019430317e-06
# Physicial loss of s is: 7.103619736881228e-06
# Iteration is: 99310
# Total loss is: 401.0994567871094
# Data loss is: 401.0994567871094
# Physicial loss of p is: 7.918438313936349e-06
# Physicial loss of s is: 7.103224106685957e-06
# Iteration is: 99320
# Total loss is: 401.1000671386719
# Data loss is: 401.1000671386719
# Physicial loss of p is: 8.075606274360325e-06
# Physicial loss of s is: 7.1708914219925646e-06
# Iteration is: 99330
# Total loss is: 401.1160583496094
# Data loss is: 401.11602783203125
# Physicial loss of p is: 1.9809307559626177e-05
# Physicial loss of s is: 1.0864921932807192e-05
# Iteration is: 99340
# Total loss is: 402.236083984375
# Data loss is: 402.23504638671875
# Physicial loss of p is: 0.0008025892311707139
# Physicial loss of s is: 0.00024258084886241704
# Iteration is: 99350
# Total loss is: 401.39208984375
# Data loss is: 401.39178466796875
# Physicial loss of p is: 0.00022757500119041651
# Physicial loss of s is: 9.69910470303148e-05
# Iteration is: 99360
# Total loss is: 401.2530212402344
# Data loss is: 401.25286865234375
# Physicial loss of p is: 0.00011902768164873123
# Physicial loss of s is: 3.9367234421661124e-05
# Iteration is: 99370
# Total loss is: 401.1211853027344
# Data loss is: 401.12115478515625
# Physicial loss of p is: 1.6663390852045268e-05
# Physicial loss of s is: 1.3230193872004747e-05
# Iteration is: 99380
# Total loss is: 401.1050720214844
# Data loss is: 401.1050720214844
# Physicial loss of p is: 1.0325289622414857e-05
# Physicial loss of s is: 8.80441893968964e-06
# Iteration is: 99390
# Total loss is: 401.1078796386719
# Data loss is: 401.1078796386719
# Physicial loss of p is: 1.2833364053221885e-05
# Physicial loss of s is: 9.914527254295535e-06
# Iteration is: 99400
# Total loss is: 401.1007385253906
# Data loss is: 401.1007385253906
# Physicial loss of p is: 8.333968253282364e-06
# Physicial loss of s is: 7.334762358368607e-06
# Iteration is: 99410
# Total loss is: 401.1009521484375
# Data loss is: 401.1009521484375
# Physicial loss of p is: 8.322089342982508e-06
# Physicial loss of s is: 7.373210792138707e-06
# Iteration is: 99420
# Total loss is: 401.1064147949219
# Data loss is: 401.1064147949219
# Physicial loss of p is: 9.01687417353969e-06
# Physicial loss of s is: 7.911541615612805e-06
# Iteration is: 99430
# Total loss is: 401.2747497558594
# Data loss is: 401.2746887207031
# Physicial loss of p is: 3.804582229349762e-05
# Physicial loss of s is: 2.3346916350419633e-05
# Iteration is: 99440
# Total loss is: 402.00250244140625
# Data loss is: 402.0022277832031
# Physicial loss of p is: 0.0001582270924700424
# Physicial loss of s is: 0.00011578447447391227
# Iteration is: 99450
# Total loss is: 401.24713134765625
# Data loss is: 401.2470703125
# Physicial loss of p is: 3.909849692718126e-05
# Physicial loss of s is: 3.320464747957885e-05
# Iteration is: 99460
# Total loss is: 401.0992126464844
# Data loss is: 401.0992126464844
# Physicial loss of p is: 7.89769364928361e-06
# Physicial loss of s is: 7.1097106228990015e-06
# Iteration is: 99470
# Total loss is: 401.1162109375
# Data loss is: 401.1162109375
# Physicial loss of p is: 1.156815324065974e-05
# Physicial loss of s is: 1.0105164619744755e-05
# Iteration is: 99480
# Total loss is: 401.1127624511719
# Data loss is: 401.1127624511719
# Physicial loss of p is: 1.0096730875375215e-05
# Physicial loss of s is: 8.684536624059547e-06
# Iteration is: 99490
# Total loss is: 401.10491943359375
# Data loss is: 401.10491943359375
# Physicial loss of p is: 8.87336500454694e-06
# Physicial loss of s is: 7.743315109109972e-06
# Iteration is: 99500
# Total loss is: 401.10107421875
# Data loss is: 401.10107421875
# Physicial loss of p is: 8.188386345864274e-06
# Physicial loss of s is: 7.38494463803363e-06
# Iteration is: 99510
# Total loss is: 401.09906005859375
# Data loss is: 401.09906005859375
# Physicial loss of p is: 7.910633030405734e-06
# Physicial loss of s is: 7.086593996064039e-06
# Iteration is: 99520
# Total loss is: 401.09930419921875
# Data loss is: 401.09930419921875
# Physicial loss of p is: 7.801925676176324e-06
# Physicial loss of s is: 7.027448646113044e-06
# Iteration is: 99530
# Total loss is: 401.09906005859375
# Data loss is: 401.09906005859375
# Physicial loss of p is: 7.816857760190032e-06
# Physicial loss of s is: 7.063217253744369e-06
# Iteration is: 99540
# Total loss is: 401.098388671875
# Data loss is: 401.098388671875
# Physicial loss of p is: 7.773434845148586e-06
# Physicial loss of s is: 7.022901172604179e-06
# Iteration is: 99550
# Total loss is: 401.0991516113281
# Data loss is: 401.0991516113281
# Physicial loss of p is: 7.77269815444015e-06
# Physicial loss of s is: 7.013233698671684e-06
# Iteration is: 99560
# Total loss is: 401.0985412597656
# Data loss is: 401.0985412597656
# Physicial loss of p is: 7.82261213316815e-06
# Physicial loss of s is: 7.0421770033135545e-06
# Iteration is: 99570
# Total loss is: 401.1058044433594
# Data loss is: 401.1058044433594
# Physicial loss of p is: 9.169074473902583e-06
# Physicial loss of s is: 8.034993697947357e-06
# Iteration is: 99580
# Total loss is: 401.48724365234375
# Data loss is: 401.4870910644531
# Physicial loss of p is: 7.70538390497677e-05
# Physicial loss of s is: 6.073494296288118e-05
# Iteration is: 99590
# Total loss is: 401.228759765625
# Data loss is: 401.22869873046875
# Physicial loss of p is: 4.362576510175131e-05
# Physicial loss of s is: 3.53849827661179e-05
# Iteration is: 99600
# Total loss is: 401.3408203125
# Data loss is: 401.3407287597656
# Physicial loss of p is: 5.0123515393352136e-05
# Physicial loss of s is: 3.657550041680224e-05
# Iteration is: 99610
# Total loss is: 401.175537109375
# Data loss is: 401.17547607421875
# Physicial loss of p is: 2.8559159545693547e-05
# Physicial loss of s is: 2.3875343686086126e-05
# Iteration is: 99620
# Total loss is: 401.1178283691406
# Data loss is: 401.1178283691406
# Physicial loss of p is: 1.2167375643912237e-05
# Physicial loss of s is: 8.286634511023294e-06
# Iteration is: 99630
# Total loss is: 401.1126708984375
# Data loss is: 401.1126708984375
# Physicial loss of p is: 1.098926441045478e-05
# Physicial loss of s is: 9.53538892645156e-06
# Iteration is: 99640
# Total loss is: 401.1002197265625
# Data loss is: 401.1002197265625
# Physicial loss of p is: 8.998709745355882e-06
# Physicial loss of s is: 7.609862223034725e-06
# Iteration is: 99650
# Total loss is: 401.09869384765625
# Data loss is: 401.09869384765625
# Physicial loss of p is: 8.333851837960538e-06
# Physicial loss of s is: 7.04828426023596e-06
# Iteration is: 99660
# Total loss is: 401.0982666015625
# Data loss is: 401.0982666015625
# Physicial loss of p is: 7.910711246950086e-06
# Physicial loss of s is: 7.0277337727020495e-06
# Iteration is: 99670
# Total loss is: 401.0979919433594
# Data loss is: 401.0979919433594
# Physicial loss of p is: 7.773389370413497e-06
# Physicial loss of s is: 6.970833510422381e-06
# Iteration is: 99680
# Total loss is: 401.0981750488281
# Data loss is: 401.0981750488281
# Physicial loss of p is: 7.720376743236557e-06
# Physicial loss of s is: 6.973411473154556e-06
# Iteration is: 99690
# Total loss is: 401.09796142578125
# Data loss is: 401.09796142578125
# Physicial loss of p is: 7.723991075181402e-06
# Physicial loss of s is: 6.956131983315572e-06
# Iteration is: 99700
# Total loss is: 401.0984802246094
# Data loss is: 401.0984802246094
# Physicial loss of p is: 7.694787200307474e-06
# Physicial loss of s is: 6.971218226681231e-06
# Iteration is: 99710
# Total loss is: 401.09759521484375
# Data loss is: 401.09759521484375
# Physicial loss of p is: 7.678590918658301e-06
# Physicial loss of s is: 6.95063681632746e-06
# Iteration is: 99720
# Total loss is: 401.097900390625
# Data loss is: 401.097900390625
# Physicial loss of p is: 7.681819624849595e-06
# Physicial loss of s is: 6.94663549438701e-06
# Iteration is: 99730
# Total loss is: 401.0970458984375
# Data loss is: 401.0970458984375
# Physicial loss of p is: 7.728566743026022e-06
# Physicial loss of s is: 6.9523734964604955e-06
# Iteration is: 99740
# Total loss is: 401.0981140136719
# Data loss is: 401.0981140136719
# Physicial loss of p is: 8.333533514814917e-06
# Physicial loss of s is: 7.197809281933587e-06
# Iteration is: 99750
# Total loss is: 401.12603759765625
# Data loss is: 401.1259765625
# Physicial loss of p is: 2.6508307200856507e-05
# Physicial loss of s is: 1.5824467482161708e-05
# Iteration is: 99760
# Total loss is: 401.83880615234375
# Data loss is: 401.8381042480469
# Physicial loss of p is: 0.0004703964223153889
# Physicial loss of s is: 0.00024162177578546107
# Iteration is: 99770
# Total loss is: 401.9050598144531
# Data loss is: 401.9045715332031
# Physicial loss of p is: 0.0003978317545261234
# Physicial loss of s is: 8.897883526515216e-05
# Iteration is: 99780
# Total loss is: 401.12884521484375
# Data loss is: 401.1288146972656
# Physicial loss of p is: 1.6984466128633358e-05
# Physicial loss of s is: 1.4238446055969689e-05
# Iteration is: 99790
# Total loss is: 401.1280822753906
# Data loss is: 401.1280212402344
# Physicial loss of p is: 3.039999137399718e-05
# Physicial loss of s is: 1.6148906070156954e-05
# Iteration is: 99800
# Total loss is: 401.1138916015625
# Data loss is: 401.1138610839844
# Physicial loss of p is: 1.6671998309902847e-05
# Physicial loss of s is: 1.2003258234472014e-05
# Iteration is: 99810
# Total loss is: 401.1080322265625
# Data loss is: 401.1080322265625
# Physicial loss of p is: 9.669882274465635e-06
# Physicial loss of s is: 8.726605301490054e-06
# Iteration is: 99820
# Total loss is: 401.1033630371094
# Data loss is: 401.1033630371094
# Physicial loss of p is: 1.0349531294195913e-05
# Physicial loss of s is: 7.560680387541652e-06
# Iteration is: 99830
# Total loss is: 401.09722900390625
# Data loss is: 401.09722900390625
# Physicial loss of p is: 7.883347279857844e-06
# Physicial loss of s is: 7.105883923941292e-06
# Iteration is: 99840
# Total loss is: 401.0977783203125
# Data loss is: 401.0977783203125
# Physicial loss of p is: 7.789141818648204e-06
# Physicial loss of s is: 6.96021925250534e-06
# Iteration is: 99850
# Total loss is: 401.0990905761719
# Data loss is: 401.0990905761719
# Physicial loss of p is: 7.988263860170264e-06
# Physicial loss of s is: 7.273210940184072e-06
# Iteration is: 99860
# Total loss is: 401.1213684082031
# Data loss is: 401.1213684082031
# Physicial loss of p is: 1.2124630302423611e-05
# Physicial loss of s is: 8.920901564124506e-06
# Iteration is: 99870
# Total loss is: 401.60107421875
# Data loss is: 401.6009216308594
# Physicial loss of p is: 9.585748193785548e-05
# Physicial loss of s is: 5.2915391279384494e-05
# Iteration is: 99880
# Total loss is: 401.12158203125
# Data loss is: 401.1215515136719
# Physicial loss of p is: 2.046530607913155e-05
# Physicial loss of s is: 1.4536860362568405e-05
# Iteration is: 99890
# Total loss is: 401.10772705078125
# Data loss is: 401.1076965332031
# Physicial loss of p is: 1.5823958165128715e-05
# Physicial loss of s is: 8.933494427765254e-06
# Iteration is: 99900
# Total loss is: 401.10198974609375
# Data loss is: 401.10198974609375
# Physicial loss of p is: 8.523993528797291e-06
# Physicial loss of s is: 7.364405973930843e-06
# Iteration is: 99910
# Total loss is: 401.09930419921875
# Data loss is: 401.09930419921875
# Physicial loss of p is: 8.695471478858963e-06
# Physicial loss of s is: 7.751808880129829e-06
# Iteration is: 99920
# Total loss is: 401.09722900390625
# Data loss is: 401.09722900390625
# Physicial loss of p is: 8.181515113392379e-06
# Physicial loss of s is: 7.045935944915982e-06
# Iteration is: 99930
# Total loss is: 401.0974426269531
# Data loss is: 401.0974426269531
# Physicial loss of p is: 7.870447916502599e-06
# Physicial loss of s is: 6.97887162459665e-06
# Iteration is: 99940
# Total loss is: 401.098388671875
# Data loss is: 401.098388671875
# Physicial loss of p is: 7.90951798990136e-06
# Physicial loss of s is: 7.088917755027069e-06
# Iteration is: 99950
# Total loss is: 401.0947570800781
# Data loss is: 401.0947570800781
# Physicial loss of p is: 7.559056484751636e-06
# Physicial loss of s is: 6.879390639369376e-06
# Iteration is: 99960
# Total loss is: 401.0975036621094
# Data loss is: 401.0975036621094
# Physicial loss of p is: 7.693628504057415e-06
# Physicial loss of s is: 6.9723482738481835e-06
# Iteration is: 99970
# Total loss is: 401.0978088378906
# Data loss is: 401.0978088378906
# Physicial loss of p is: 7.790513336658478e-06
# Physicial loss of s is: 7.04906415194273e-06
# Iteration is: 99980
# Total loss is: 401.1085510253906
# Data loss is: 401.1085510253906
# Physicial loss of p is: 9.804293767956551e-06
# Physicial loss of s is: 8.585543582739774e-06
# Iteration is: 99990
# Total loss is: 401.38818359375
# Data loss is: 401.3880615234375
# Physicial loss of p is: 6.185597885632887e-05
# Physicial loss of s is: 5.030281681683846e-05
# Iteration is: 100000
# Total loss is: 401.5865783691406
# Data loss is: 401.5863952636719
# Physicial loss of p is: 0.0001060719951055944
# Physicial loss of s is: 8.851541497278959e-05
# Training time: 135.7285

# %%
it = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip_list = [loss_fisp[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(it, np.asarray(loss_data_list), 'b-', linewidth = 2, label = 'Data')  
plt.semilogy(it, np.asarray(loss_phip_list), 'r-', linewidth = 2, label = '$\phi_p$')    
plt.semilogy(it, np.asarray(loss_phis_list), 'g-', linewidth = 2, label = '$\phi_s$')       


plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
T_star_tf = tf.convert_to_tensor(T_star[:len(T_exp)], dtype=tf.float32)    
u_pred = predict(T_star_tf, W_p, b_p)

# ## Evaluating unknown function
phi_pred = predict(u_pred, W_phi, b_phi)
phi_s=np.array(u_pred[:,0:1]*m[0])

# %%
plt.plot(T_star_tf, u_pred[:,0:1], label='Prediction P')
plt.plot(T_star_tf, u_pred[:,1:2], label='Prediction S')


# for i in range(N_exp):
#     plt.plot(T_star[i*len(T_exp):(i+1)*len(T_exp)],P_star[i*len(T_exp):(i+1)*len(T_exp)],linestyle=':')

plt.scatter(T_u_train, p_train, marker='x', color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(u_pred[:,0:1], u_pred[:,1:2])
plt.xlabel('P')
plt.ylabel('S')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.plot(u_pred[:,0:1], phi_pred, label='Prediction')
# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')
# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
Nt=10000
T_int=np.zeros(Nt)
P_int=np.zeros(Nt)
S_int=np.zeros(Nt)

dt=0.0001

T_int[0]=0
# P_int[0]=np.mean(uu1) #Initial conditions
P_int[0]=np.array(u_pred[0,0:1]) #Initial conditions
S_int[0]=np.array(u_pred[0,1:2]) #Initial conditions


for i in range(1,Nt):

    PS_p=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    PHI=predict(PS_p , W_phi, b_phi)
    P_int[i]=P_int[i-1]+PHI[:,0:1]*dt
    # P_int[i]=max(P_int[i],0)
    S_int[i]=S_int[i-1]+PHI[:,1:2]*dt
    # P_int[i]=max(S_int[i],0)
    T_int[i]=T_int[i-1]+dt

# %%
plt.plot(T_int, P_int, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle=':', label='Numeric integration dSdT')


plt.plot(T_star_tf, u_pred[:,0:1], label='PINN Prediction P')
plt.plot(T_star_tf, u_pred[:,1:2], label='PINN Prediction S')

plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
# Create and train the PySR model
model_phi = PySRRegressor(
    niterations=40,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
)

# %%
# Fit phi
model_phi.fit(u_star_tf, phi_pred)
print(model_phi)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 4.010e+04
# Head worker occupation: 18.4%
# Progress: 92 / 600 total iterations (15.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.622e+00  7.971e+00  y = inv(1.9905)
# 3           1.585e+00  2.297e-02  y = 0.17128 * x₁
# 5           1.571e+00  4.496e-03  y = (x₁ * 0.12122) + 0.19923
# 6           1.494e+00  5.047e-02  y = inv(2.0567 + x₀) * x₁
# 7           1.247e+00  1.804e-01  y = inv(x₀ + inv(x₀)) * x₁
# 8           1.204e+00  3.513e-02  y = inv(0.17128) * inv(x₀ + inv(x₀))
# 9           1.085e+00  1.039e-01  y = inv((x₀ + -1.1811) + inv(x₀)) * x₁
# 10          5.414e-01  6.956e-01  y = x₀ * (-1.4566 + (inv(x₀ + 1.486) * 12.161))
# 12          9.405e-04  3.178e+00  y = (((inv(x₀) + -0.1492) * x₀) * (x₁ * x₀)) + -0.0064077
# 14          9.319e-04  4.604e-03  y = (((inv(x₀) + -0.1492) * x₀) * ((0.0075088 + x₁) * x₀)) + -...
#                                   0.0064077
# 16          9.316e-04  1.427e-04  y = (((x₁ * x₀) * ((inv(x₀) + -0.14921) * x₀)) + inv(inv(-0.86...
#                                   87))) + 0.86593
# 17          9.242e-04  7.957e-03  y = (((x₁ * x₀) * (inv(x₀) + -0.14916)) + (inv(x₀) * (-0.00271...
#                                   94 * x₁))) * x₀
# 18          8.765e-04  5.307e-02  y = (((inv(x₀) + -0.1492) * x₀) * ((((-0.53271 + x₀) * 0.00553...
#                                   27) + x₁) * x₀)) + -0.0064077
# 20          8.764e-04  3.076e-05  y = (((inv(x₀) + -0.1492) * x₀) * ((((-0.53271 + (x₀ * 0.87639...
#                                   )) * 0.0055327) + x₁) * x₀)) + -0.0064077
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.210e+04
# Head worker occupation: 16.1%
# Progress: 181 / 600 total iterations (30.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.622e+00  7.971e+00  y = inv(1.9905)
# 3           1.585e+00  2.298e-02  y = 0.17245 * x₁
# 5           1.571e+00  4.491e-03  y = (x₁ * 0.12122) + 0.19923
# 6           1.494e+00  5.047e-02  y = inv(2.0567 + x₀) * x₁
# 7           1.247e+00  1.804e-01  y = inv(x₀ + inv(x₀)) * x₁
# 8           9.356e-01  2.876e-01  y = x₀ * ((inv(x₀) + -0.1448) * x₀)
# 10          9.354e-04  3.454e+00  y = ((inv(x₀) + -0.14922) * x₀) * (x₁ * x₀)
# 12          9.207e-04  7.915e-03  y = (x₀ * (x₀ + -0.0034615)) * (x₁ * (-0.14922 + inv(x₀)))
# 16          8.892e-04  8.717e-03  y = ((x₀ * (inv(x₀) + -0.1492)) * (((x₀ * 0.0055327) + x₁) * x...
#                                   ₀)) + -0.0064077
# 18          8.602e-04  1.657e-02  y = -0.0064077 + (((inv(x₀) + -0.1492) * x₀) * (x₀ * (((-2.429...
#                                   5 + x₀) * 0.0055327) + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.330e+04
# Head worker occupation: 17.4%
# Progress: 278 / 600 total iterations (46.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.622e+00  7.971e+00  y = inv(1.9909)
# 3           1.585e+00  2.298e-02  y = 0.17245 * x₁
# 5           1.571e+00  4.491e-03  y = (x₁ * 0.12122) + 0.19923
# 6           1.492e+00  5.160e-02  y = inv(x₀ + 2.1104) * x₁
# 7           1.247e+00  1.793e-01  y = inv(x₀ + inv(x₀)) * x₁
# 8           9.356e-01  2.876e-01  y = x₀ * ((inv(x₀) + -0.1448) * x₀)
# 10          9.354e-04  3.454e+00  y = ((inv(x₀) + -0.14922) * x₀) * (x₁ * x₀)
# 12          9.207e-04  7.915e-03  y = (x₀ * (x₀ + -0.0034615)) * (x₁ * (-0.14922 + inv(x₀)))
# 16          8.892e-04  8.717e-03  y = ((x₀ * (inv(x₀) + -0.1492)) * (((x₀ * 0.0055327) + x₁) * x...
#                                   ₀)) + -0.0064077
# 18          8.602e-04  1.657e-02  y = -0.0064077 + (((inv(x₀) + -0.1492) * x₀) * (x₀ * (((-2.429...
#                                   5 + x₀) * 0.0055327) + x₁)))
# 20          7.573e-04  6.370e-02  y = -0.0064077 + (((inv(x₀) + -0.1492) * x₀) * (x₀ * ((((-2.42...
#                                   95 + x₀) * 0.0055327) * x₁) + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.550e+04
# Head worker occupation: 16.3%
# Progress: 393 / 600 total iterations (65.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.622e+00  7.971e+00  y = inv(1.9909)
# 3           1.585e+00  2.298e-02  y = 0.17245 * x₁
# 5           1.571e+00  4.491e-03  y = (x₁ * 0.12122) + 0.19923
# 6           1.489e+00  5.370e-02  y = inv(2.2962 + x₀) * x₁
# 7           1.184e+00  2.293e-01  y = inv(x₀ + inv(x₀)) * 5.3741
# 8           9.356e-01  2.355e-01  y = x₀ * ((inv(x₀) + -0.1448) * x₀)
# 10          9.354e-04  3.454e+00  y = ((inv(x₀) + -0.14922) * x₀) * (x₁ * x₀)
# 12          9.207e-04  7.915e-03  y = (x₀ * (x₀ + -0.0034615)) * (x₁ * (-0.14922 + inv(x₀)))
# 16          7.745e-04  4.324e-02  y = ((x₀ * ((inv(x₀ + 0.35963) + -0.14164) * (x₀ + 0.32054))) ...
#                                   * 1.0682) * x₁
# 20          7.573e-04  5.612e-03  y = -0.0064077 + (((inv(x₀) + -0.1492) * x₀) * (x₀ * ((((-2.42...
#                                   95 + x₀) * 0.0055327) * x₁) + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.660e+04
# Head worker occupation: 15.8%
# Progress: 489 / 600 total iterations (81.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.622e+00  7.971e+00  y = inv(1.9909)
# 3           1.585e+00  2.298e-02  y = 0.17245 * x₁
# 5           1.571e+00  4.491e-03  y = (x₁ * 0.12122) + 0.19923
# 6           1.489e+00  5.370e-02  y = inv(2.2962 + x₀) * x₁
# 7           1.184e+00  2.293e-01  y = inv(x₀ + inv(x₀)) * 5.3741
# 8           9.356e-01  2.355e-01  y = x₀ * ((inv(x₀) + -0.1448) * x₀)
# 9           9.445e-04  6.898e+00  y = ((-0.1492 * (x₀ * x₁)) + x₁) * x₀
# 10          9.354e-04  9.688e-03  y = ((inv(x₀) + -0.14922) * x₀) * (x₁ * x₀)
# 12          9.207e-04  7.915e-03  y = (x₀ * (x₀ + -0.0034615)) * (x₁ * (-0.14922 + inv(x₀)))
# 14          9.116e-04  4.967e-03  y = (((inv(x₀) + -0.14923) * (x₀ + -0.0050207)) * (x₁ + 0.0077...
#                                   414)) * x₀
# 16          7.745e-04  8.151e-02  y = ((x₀ * ((inv(x₀ + 0.35963) + -0.14164) * (x₀ + 0.32054))) ...
#                                   * 1.0682) * x₁
# 20          7.573e-04  5.612e-03  y = -0.0064077 + (((inv(x₀) + -0.1492) * x₀) * (x₀ * ((((-2.42...
#                                   95 + x₀) * 0.0055327) * x₁) + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.700e+04
# Head worker occupation: 16.7%
# Progress: 580 / 600 total iterations (96.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.622e+00  7.971e+00  y = inv(1.9909)
# 3           1.585e+00  2.298e-02  y = 0.17245 * x₁
# 5           1.571e+00  4.491e-03  y = (x₁ * 0.12122) + 0.19923
# 6           1.489e+00  5.370e-02  y = inv(2.2962 + x₀) * x₁
# 7           1.184e+00  2.293e-01  y = inv(x₀ + inv(x₀)) * 5.3741
# 8           9.356e-01  2.355e-01  y = x₀ * ((inv(x₀) + -0.1448) * x₀)
# 9           9.445e-04  6.898e+00  y = ((-0.1492 * (x₀ * x₁)) + x₁) * x₀
# 10          9.354e-04  9.688e-03  y = ((inv(x₀) + -0.14922) * x₀) * (x₁ * x₀)
# 12          9.207e-04  7.915e-03  y = (x₀ * (x₀ + -0.0034615)) * (x₁ * (-0.14922 + inv(x₀)))
# 14          9.116e-04  4.967e-03  y = (((inv(x₀) + -0.14923) * (x₀ + -0.0050207)) * (x₁ + 0.0077...
#                                   414)) * x₀
# 16          7.745e-04  8.151e-02  y = ((x₀ * ((inv(x₀ + 0.35963) + -0.14164) * (x₀ + 0.32054))) ...
#                                   * 1.0682) * x₁
# 20          7.573e-04  5.612e-03  y = -0.0064077 + (((inv(x₀) + -0.1492) * x₀) * (x₀ * ((((-2.42...
#                                   95 + x₀) * 0.0055327) * x₁) + x₁)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                     inv(1.9908909)
# 	1         0.022976                                    0.17245397 * x1
# 	2         0.004491                    (x1 * 0.121221356) + 0.19923067
# 	3         0.053704                           inv(2.2962222 + x0) * x1
# 	4         0.229252                      inv(x0 + inv(x0)) * 5.3740544
# 	5         0.235478                x0 * ((inv(x0) + -0.14480335) * x0)
# 	6   >>>>  6.898240              ((-0.14919965 * (x0 * x1)) + x1) * x0
# 	7         0.009688          ((inv(x0) + -0.1492232) * x0) * (x1 * x0)
# 	8         0.007915  (x0 * (x0 + -0.0034615493)) * (x1 * (-0.149222...
# 	9         0.004967  (((inv(x0) + -0.14922567) * (x0 + -0.005020693...
# 	10        0.081511  ((x0 * ((inv(x0 + 0.35963106) + -0.14163613) *...
# 	11        0.005612  -0.0064077466 + (((inv(x0) + -0.14919965) * x0...
#
# 	        loss  complexity
# 	0   1.622243           2
# 	1   1.585396           3
# 	2   1.571219           5
# 	3   1.489064           6
# 	4   1.183997           7
# 	5   0.935586           8
# 	6   0.000945           9
# 	7   0.000935          10
# 	8   0.000921          12
# 	9   0.000912          14
# 	10  0.000774          16
# 	11  0.000757          20
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_phi.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
model_phi.sympy(6)
# Out:
# x0*(-0.14919965*x0*x1 + x1)

# %%
symb1=model_phi.predict(u_star_tf,6)

# %%
i=0
color = cmap(i % 10)
plt.scatter(P_star[i::len(R)], phi_pred[i::len(R)], color=color, s=5, label='Prediction, '+ f'r = {np.round(R[i],2)}')
plt.scatter(P_star[i::len(R)], phi_star[i::len(R)], color=color, s=5, label='Exact, '+ f'r = {np.round(R[i],2)}')
plt.plot(P_star[i::len(R)], symb1[i::len(R)], linestyle=':', label='Symbolic regresion')

for i in range(1,len(R)):

    color = cmap(i % 10)
    plt.plot(P_star[i::len(R)], phi_pred[i::len(R)], color=color, label='Prediction, '+ f'r = {np.round(R[i],2)}')
    plt.plot(P_star[i::len(R)], phi_star[i::len(R)], color=color,linestyle='--', label='Exact, '+ f'r = {np.round(R[i],2)}')
    plt.plot(P_star[i::len(R)], symb1[i::len(R)], linestyle=':', label='Symbolic regresion')


plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.xlabel('P')
plt.ylabel('$\phi$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
# Create and train the PySR model
model_dPdT = PySRRegressor(
    niterations=20,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    unary_operators=["exp", "inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
)

# %%
# Fit dP_dT
model_dPdT.fit(X_star_tf, u_pred)
print(model_dPdT)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1989: UserWarning: The discovered expressions are being reset. Please set `warm_start=True` if you wish to continue to start a search where you left off.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 4.200e+04
# Head worker occupation: 20.4%
# Progress: 100 / 300 total iterations (33.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.787e+01  7.971e+00  y = inv(0.93282)
# 3           5.233e+00  1.228e+00  y = x₁ + 1.4468
# 5           3.625e+00  1.837e-01  y = x₁ + (0.33351 * x₀)
# 7           3.434e+00  2.700e-02  y = (x₀ * 0.4641) + (x₁ + -0.90581)
# 8           2.948e+00  1.524e-01  y = (inv(0.34908 + x₁) * x₀) * x₁
# 10          2.848e+00  1.732e-02  y = x₁ + inv(0.17494 + inv(x₀ + inv(-0.50158)))
# 12          2.205e+00  1.279e-01  y = exp((inv(exp(-2.0837) + x₁) * x₀) * 0.29378) * x₁
# 13          2.199e+00  3.053e-03  y = exp((inv(exp(inv(-0.41165)) + x₁) * x₀) * 0.29378) * x₁
# 14          2.104e+00  4.387e-02  y = x₁ * exp((x₀ * inv((exp(x₁) + -1.7725) + x₀)) * x₁)
# 15          1.173e+00  5.845e-01  y = x₁ + inv(exp(inv((x₁ * -0.30115) + 0.17494)) + inv(x₀ + -1...
#                                   .8419))
# 17          1.065e+00  4.832e-02  y = x₁ + inv(exp(inv((x₁ * -0.30115) + 0.17494)) + inv(x₀ + (0...
#                                   .226 + -1.8419)))
# 18          9.358e-01  1.291e-01  y = x₁ + inv(exp(inv(exp(-0.30115) * ((-0.30115 * x₁) + 0.226)...
#                                   )) + inv(-2.1251 + x₀))
# 20          8.713e-01  3.574e-02  y = x₁ + inv(inv((0.17346 + -2.1772) + x₀) + exp(inv(((-0.2448...
#                                   2 * x₁) + 0.02893) * exp(-0.31744))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.370e+04
# Head worker occupation: 16.2%
# Progress: 187 / 300 total iterations (62.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.787e+01  7.971e+00  y = inv(0.93282)
# 3           5.233e+00  1.228e+00  y = x₁ + 1.4468
# 5           3.625e+00  1.837e-01  y = x₁ + (0.33351 * x₀)
# 7           3.433e+00  2.717e-02  y = -0.87509 + (x₁ + (x₀ * 0.46483))
# 8           2.890e+00  1.721e-01  y = (inv(0.17187 + x₁) * x₀) * x₁
# 10          2.084e+00  1.634e-01  y = ((x₀ + 2.2813) * inv(1.2699 + x₁)) * x₁
# 12          2.059e+00  5.981e-03  y = x₁ * ((x₀ + (1.2699 + 1.2699)) * inv(1.2699 + x₁))
# 13          2.026e+00  1.637e-02  y = (((x₀ + exp(1.2585)) * inv(1.2699 + x₁)) * x₁) * 0.84236
# 14          1.905e+00  6.185e-02  y = ((x₀ * inv(((x₁ * 0.78784) * x₁) + 0.38821)) * x₁) + x₁
# 15          1.045e+00  6.004e-01  y = x₁ + inv(exp(inv((x₁ * -0.30115) + 0.24949)) + inv(-1.8419...
#                                    + x₀))
# 17          9.638e-01  4.036e-02  y = x₁ + (inv(exp(inv((x₁ * -0.30115) + 0.24949)) + inv(-1.841...
#                                   9 + x₀)) + 0.36479)
# 18          8.999e-01  6.859e-02  y = x₁ + inv(exp(inv(((-0.24482 * x₁) + 0.02893) * exp(-0.3174...
#                                   4))) + inv(-2.1772 + x₀))
# 20          8.713e-01  1.615e-02  y = x₁ + inv(inv((0.17346 + -2.1772) + x₀) + exp(inv(((-0.2448...
#                                   2 * x₁) + 0.02893) * exp(-0.31744))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+04
# Head worker occupation: 15.6%
# Progress: 285 / 300 total iterations (95.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.326e+00  1.594e+01  y = x₁
# 3           5.233e+00  1.682e-01  y = x₁ + 1.4468
# 5           3.625e+00  1.837e-01  y = x₁ + (0.33351 * x₀)
# 7           3.433e+00  2.717e-02  y = -0.87509 + (x₁ + (x₀ * 0.46483))
# 8           2.890e+00  1.721e-01  y = (inv(0.17187 + x₁) * x₀) * x₁
# 10          2.084e+00  1.634e-01  y = ((x₀ + 2.2813) * inv(1.2699 + x₁)) * x₁
# 11          9.731e-01  7.617e-01  y = inv(0.12578 + inv((x₁ * x₀) + -0.71753)) + 0.52749
# 13          5.779e-01  2.606e-01  y = -0.91856 + inv(0.12208 + inv(((x₀ * x₀) * x₁) + 1.119))
# 14          5.557e-01  3.914e-02  y = -0.91856 + inv(0.12208 + inv(((x₀ * x₀) * x₁) + exp(-0.239...
#                                   71)))
# 15          5.088e-01  8.810e-02  y = inv(inv(((x₀ * x₀) * x₁) + inv(exp(x₁))) + 0.12208) + -0.9...
#                                   2607
# 16          4.443e-01  1.356e-01  y = -0.36586 + inv(inv(((0.12722 * x₁) * (x₁ * exp(x₀))) + 0.1...
#                                   4092) + 0.14092)
# 18          2.894e-01  2.143e-01  y = -0.36586 + inv(inv(0.1471 + ((0.16186 * x₁) * (x₁ * (exp(x...
#                                   ₀) + -1.1932)))) + 0.14092)
# 19          2.360e-01  2.039e-01  y = inv(inv(((x₁ * (x₁ * 0.10547)) * ((x₀ * x₀) * x₀)) + -0.01...
#                                   953) + 0.14217) + -0.051162
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                                 x1
# 	1         0.168220                                     x1 + 1.4467576
# 	2         0.183661                              x1 + (0.3335012 * x0)
# 	3         0.027171              -0.87509257 + (x1 + (x0 * 0.4648306))
# 	4         0.172110                   (inv(0.17186882 + x1) * x0) * x1
# 	5         0.163431      ((x0 + 2.2812572) * inv(1.2699376 + x1)) * x1
# 	6         0.870742  inv(inv((x1 * x0) + -1.1359394) + 0.12878644) ...
# 	7         0.225165  inv(0.122084714 + inv(((x0 * x0) * x1) + 0.839...
# 	8         0.000902  -0.91855526 + inv(0.122084714 + inv(((x0 * x0)...
# 	9         0.348535  exp(-0.3697843) * inv(0.10550415 + inv(exp(((x...
# 	10        0.151629  exp(-0.3697843) * inv(0.10550415 + inv(exp(((x...
# 	11  >>>>  0.720636  (exp(-0.2832356) * inv((inv(exp(x0 * x1)) * ex...
# 	12        0.010200  (exp(-0.2832356) * inv((inv(exp((x0 * x1) + -0...
#
# 	        loss  complexity
# 	0   7.326374           1
# 	1   5.233293           3
# 	2   3.624510           5
# 	3   3.432801           7
# 	4   2.890028           8
# 	5   2.084242          10
# 	6   0.872549          11
# 	7   0.556179          13
# 	8   0.555677          14
# 	9   0.392153          15
# 	10  0.336980          16
# 	11  0.163922          17
# 	12  0.160612          19
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_dPdT.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
model_dPdT.sympy(11)
# Out:
# 1.0543023 + 1/(0.12878644 + 1/(x0*x1 - 1.1359394))

# %%
symb2=model_dPdT.predict(X_star_tf,11)

# %%
cmap = plt.get_cmap("tab10")  # O puedes usar otro colormap como "viridis"

# Crear figura
plt.figure()

for i in range(len(R)):
    color = cmap(i % 10)  # Usa % 10 para que no exceda el número de colores en el colormap
    # Graficar P_star con el mismo color
    plt.plot(X_star_tf[:,0:1][i::len(R)], P_star[i::len(R)], color=color, label='Exact, '+ f'r = {np.round(R[i],2)}')
    # Graficar u_pred con el mismo color
    plt.plot(X_star_tf[:,0:1][i::len(R)], u_pred[i::len(R)], linestyle='--', color=color, label='Prediction, '+ f'r = {np.round(R[i],2)}') 
    plt.plot(X_star_tf[:,0:1][i::len(R)], symb2[i::len(R)], linestyle=':', label='Symbolic regresion')



# Mostrar leyenda
plt.xlabel('t')
plt.ylabel('P')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# # Adding data

# %%
r_symb=np.linspace(0,5,10).reshape([-1,1])
R_meshgrid_symb,T_meshgrid_symb = np.meshgrid(r_symb,t[::10])

# %%
X_star_symb = np.hstack((T_meshgrid_symb.flatten()[:,None], R_meshgrid_symb.flatten()[:,None]))
X_star_symb_tf= tf.convert_to_tensor(X_star_symb, dtype=tf.float32)

# %%
plt.title('Generated Data')
plt.scatter(X_star_symb[:,0:1],X_star_symb[:,1:2], s=5)
plt.xlabel('time')
plt.ylabel('r')
plt.show()

# %%
u_pred_symb = predict(X_star_symb_tf, W_p, b_p)

# %%
Nt=1000
k_t=K[2]


P_star_symb=np.zeros((Nt, len(r_symb)))
T_star_symb=np.zeros((Nt, len(r_symb)))

for j in range(len(r_symb)):
        dt=0.01
        P_star_symb[0,j]=0.02 #Initial conditions
        T_star_symb[0,j]=0
        for i in range(1,Nt):
            P_star_symb[i,j]=P_star_symb[i-1,j]+ P_star_symb[i-1,j]*r_symb[j]*(1-P_star_symb[i-1,j]/k_t)*dt
            T_star_symb[i,j]=T_star_symb[i-1,j]+dt

# %%
cmap = plt.get_cmap("tab10")  # O puedes usar otro colormap como "viridis"

# Crear figura
plt.figure()

for i in range(len(r_symb)):
    color = cmap(i % 10)  # Usa % 10 para que no exceda el número de colores en el colormap
    # Graficar P_star con el mismo color
    plt.plot(T_star_symb[:,i], P_star_symb[:,i], color=color, label='Exact, '+ f'r = {np.round(r_symb[i],2)}')
    # Graficar u_pred con el mismo color
    plt.plot(X_star_symb_tf[:,0:1][i::len(r_symb)], u_pred_symb[i::len(r_symb)], linestyle='--', color=color, label='Prediction, '+ f'r = {np.round(r_symb[i],2)}') 
    # # Graficar datos con el mismo color
# plt.scatter(X_u_train_tf[:,0:1], u_train_tf, marker='x', color='black', label=f'data')  



# Mostrar leyenda
plt.xlabel('t')
plt.ylabel('P')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
# Create and train the PySR model
model_dPdT_data = PySRRegressor(
    niterations=50,
    binary_operators=["+", "*"],
    # unary_operators=["cos", "exp", "sin", "inv(x) = 1/x"],
    unary_operators=["exp", "inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
)

# %%
# Fit dP_dT
model_dPdT_data.fit(X_star_symb_tf, u_pred_symb)
print(model_dPdT_data)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.660e+05
# Head worker occupation: 47.2%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 357 / 750 total iterations (47.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           8.313e+00  1.594e+01  y = x₁
# 2           8.205e+00  1.305e-02  y = exp(1.4396)
# 3           5.358e+00  4.263e-01  y = 1.7191 + x₁
# 5           3.037e+00  2.838e-01  y = x₁ + (0.40085 * x₀)
# 6           3.037e+00  -0.000e+00  y = x₁ + (inv(2.4947) * x₀)
# 7           2.760e+00  9.554e-02  y = -1.0443 + (x₁ + (x₀ * 0.55829))
# 9           2.752e+00  1.620e-03  y = ((x₁ * 1.0593) + (x₀ * 0.55829)) + -1.1925
# 10          2.206e+00  2.210e-01  y = 4.7437 + ((inv(x₀ + 2.2684) * -19.819) + x₁)
# 12          2.078e+00  2.992e-02  y = (4.7437 + ((inv(x₀ + 2.2684) * -19.819) + x₁)) * 1.0679
# 13          2.020e+00  2.822e-02  y = (x₁ + 2.0745) + ((inv(-0.13913) * exp(x₀ * -0.44056)) + 1....
#                                   3257)
# 14          8.956e-01  8.133e-01  y = exp(1.0502) + (3.8059 + (-6.6275 * inv(exp((x₀ * 0.13383) ...
#                                   * x₁))))
# 15          4.823e-01  6.190e-01  y = ((-38.434 * inv(exp((x₀ * 0.42992) * x₁) + 4.501)) + 5.819...
#                                   6) * 1.1903
# 16          3.384e-01  3.542e-01  y = exp(0.66198) + ((inv(2.4542 + exp((0.3069 * x₀) * x₁)) * -...
#                                   25.235) + 4.911)
# 17          2.882e-01  1.609e-01  y = ((5.7099 + (-32.777 * inv(exp((0.3389 * x₀) * x₁) + 3.5092...
#                                   ))) + 0.30002) + 0.84178
# 18          1.865e-01  4.349e-01  y = exp(-0.01866) + ((inv(4.501 + exp((0.42992 * (x₀ + -0.4122...
#                                   4)) * x₁)) * -38.434) + 5.8196)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.720e+05
# Head worker occupation: 43.1%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 734 / 750 total iterations (97.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.768e+00  1.594e+01  y = x₀
# 3           5.358e+00  1.858e-01  y = 1.7191 + x₁
# 5           3.037e+00  2.838e-01  y = x₁ + (0.40093 * x₀)
# 7           2.760e+00  4.777e-02  y = -1.0443 + (x₁ + (x₀ * 0.55829))
# 9           2.752e+00  1.620e-03  y = ((x₁ * 1.0593) + (x₀ * 0.55829)) + -1.1925
# 10          9.373e-01  1.077e+00  y = (inv((x₀ * x₁) + 5.2639) * -47.716) + 8.3786
# 11          9.301e-01  7.688e-03  y = 6.7455 + (inv(exp(x₀ * x₁) + 45.328) * -314.69)
# 12          8.981e-01  3.500e-02  y = (8.442 + (-57.017 * inv(6.0788 + (x₁ * x₀)))) + 0.24781
# 13          1.100e-01  2.100e+00  y = 6.7455 + (inv(exp((0.69893 * x₀) * x₁) + 45.328) * -314.69...
#                                   )
# 15          1.096e-01  1.512e-03  y = 6.7455 + (inv(exp((0.69893 * x₀) * x₁) + (45.328 + 0.12958...
#                                   )) * -314.69)
# 16          1.096e-01  6.942e-04  y = 6.7455 + (inv((exp((0.69893 * x₀) * x₁) + 45.328) + exp(-0...
#                                   .91832)) * -314.69)
# 17          9.526e-02  1.399e-01  y = ((-314.71 * inv(45.171 + exp((x₀ * 0.69859) * (x₁ + 0.0379...
#                                   04)))) + 4.6256) + 2.1307
# 18          8.539e-02  1.093e-01  y = exp(0.20068) + ((inv(27.819 + exp(x₁ * ((x₀ + -0.23598) * ...
#                                   0.65384))) * -195.91) + 5.5973)
# 20          8.246e-02  1.745e-02  y = (((-195.91 + x₀) * inv(27.819 + exp(x₁ * ((x₀ + -0.23598) ...
#                                   * 0.65384)))) + 5.5973) + exp(0.20068)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                                 x0
# 	1         0.185769                                     1.7191269 + x1
# 	2         0.283782                             x1 + (0.40092573 * x0)
# 	3         0.047770               -1.0443102 + (x1 + (x0 * 0.5582861))
# 	4         0.001620  ((x1 * 1.0592524) + (x0 * 0.55829245)) + -1.19...
# 	5         1.076947  (inv((x0 * x1) + 5.2639194) * -47.71619) + 8.3...
# 	6         0.007688  6.7455177 + (inv(exp(x0 * x1) + 45.328304) * -...
# 	7         0.034997  (8.441988 + (-57.016544 * inv(6.078847 + (x1 *...
# 	8   >>>>  2.100085  6.7455177 + (inv(exp((0.69892794 * x0) * x1) +...
# 	9         0.002758  6.7148995 + (inv((46.02633 + -0.25698552) + ex...
# 	10        0.069042  ((-314.71225 * inv(45.171486 + exp((x0 * 0.698...
# 	11        0.109331  exp(0.20067503) + ((inv(27.818958 + exp(x1 * (...
# 	12        0.017449  (((-195.9102 + x0) * inv(27.818958 + exp(x1 * ...
#
# 	        loss  complexity
# 	0   7.768235           1
# 	1   5.357541           3
# 	2   3.037216           5
# 	3   2.760469           7
# 	4   2.751537           9
# 	5   0.937267          10
# 	6   0.930089          11
# 	7   0.898101          12
# 	8   0.109969          13
# 	9   0.109364          15
# 	10  0.095259          17
# 	11  0.085393          18
# 	12  0.082465          20
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model_dPdT_data.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
model_dPdT_data.sympy(8)
# Out:
# 6.7455177 - 314.6875/(exp(0.69892794*x0*x1) + 45.328304)

# %%
symb_aug=model_dPdT_data.predict(X_star_symb_tf,8)

# %%
cmap = plt.get_cmap("tab10")  # O puedes usar otro colormap como "viridis"

# Crear figura
plt.figure()

for i in range(len(r_symb)):
    color = cmap(i % 10)  # Usa % 10 para que no exceda el número de colores en el colormap
    # Graficar P_star con el mismo color
    # plt.plot(X_star_symb_tf[:,0:1][i::len(R)], P_star[i::len(R)], color=color, label='Exact, '+ f'r = {np.round(R[i],2)}')
    # Graficar u_pred con el mismo color
    plt.plot(T_star_symb[:,i], P_star_symb[:,i], color=color, label='Exact, '+ f'r = {np.round(r_symb[i],2)}')
    plt.plot(X_star_symb_tf[:,0:1][i::len(r_symb)], u_pred_symb[i::len(r_symb)], linestyle='--', color=color, label='Prediction, '+ f'r = {np.round(r_symb[i],2)}') 
    plt.plot(X_star_symb_tf[:,0:1][i::len(r_symb)], symb_aug[i::len(r_symb)], linestyle=':', label='Symbolic regresion')



# Mostrar leyenda
plt.xlabel('t')
plt.ylabel('P')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=2)

plt.show()
