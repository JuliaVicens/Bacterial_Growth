# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x192b819c760>,
#  <matplotlib.lines.Line2D at 0x192b819c7c0>,
#  <matplotlib.lines.Line2D at 0x192b819c7f0>,
#  <matplotlib.lines.Line2D at 0x192b819c8e0>,
#  <matplotlib.lines.Line2D at 0x192b819c9d0>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.hstack((P0_exp,P1_exp,P2_exp,P3_exp))
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
n=np.array([P0_exp.shape[1],P1_exp.shape[1],P2_exp.shape[1],P3_exp.shape[1],])
A=np.array([0, 1.25, 2.50, 3.75])
N_exp,T_max, T_exp.shape, P_exp.shape, 342*23
# Out:
# (19, 231399.5, (342,), (342, 19), 7866)

# %%
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)

plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 1500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
Xa_star=[]
P0_star=np.empty((0, 1))
X_star = np.empty((0, 3))
for i in range(len(A)):
    P0=P_exp[0:1, np.sum(n[:i]):np.sum(n[:i+1])]
    P0_star=np.concatenate((P0_star,P0.T))
    T_meshgrid, P0_meshgrid, A_meshgrid = np.meshgrid(T_exp, P0, A[i])
    x=np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None], A_meshgrid.flatten()[:,None]))
    Xa_star += [x]
    X_star=np.vstack((X_star,x))


u_star=np.hstack((P_star,X_star[:,1:2]))

# %%
# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0_star)).reshape([-1,1]), P0_star.reshape([-1,1]), xx0[...,2:3]))

xx01=np.vstack((xx0, xx1))
uu01=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(3, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_tf = tf.convert_to_tensor(uu01, dtype=tf.float32)
# Out:
# 2024-12-11 14:06:27.098185: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-11 14:06:27.773079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3962 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:08:00.0, compute capability: 7.5

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        plt.plot(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_exp[:, (i + np.sum(n[:k]))], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('P0')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,2], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('A')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 3]), dtype=tf.float32)
    # alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1)))
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp * 2 * 2), (N_exp * 2, 2))) 
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)

        lnp1=u[:,0:1]
        lnp2=u[:,1:2]
        lns=u[:,2:3]

        p1=tf.exp(lnp1)
        p2=tf.exp(lnp2)
        s=tf.exp(lns)

        m=tf.exp(lnv[0:1])
        l1=tf.exp(lnv[1:2])
        l2=tf.exp(lnv[2:3])


        # phi=tf.exp(net(tf.concat([p, s, l],1), W_phi, b_phi))
        phi_s=tf.exp(net(s, W_phi, b_phi))
        phi_t=tf.exp(net(s, W_a, b_a))




    p1_t = tape1.gradient(p1, X_f)[...,0:1]
    p2_t = tape1.gradient(p2, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]

    f_p1 = p1_t - phi_s*p1 + phi_t*p1 + l1*p1
    f_p2 = p2_t - phi_s*p2 - phi_t*p1 + l2*p2
    f_s = s_t + m*(p1+p2)*s
    
    return f_p1, f_p2, f_s




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi, b_phi,  W_a, b_a,  X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, W_a, b_a, lambda_b, lambda_r, lambda_0, lnv])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp1=u_nn[:,0:1]
        lnp2=u_nn[:,1:2]
        p1_nn=tf.exp(lnp1)
        p2_nn=tf.exp(lnp2)
        f_p1, f_p2, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        u_00 = net(xx01_tf, W_p, b_p) 
        lns_0=u_00[:,2:3]
        s_00=tf.exp(lns_0)
        # p2_00=tf.exp(u_00[:,1:2])
        # p1_00=tf.exp(u_00[:,0:1])



        loss_p = tf.square(lambda_b*(p1_nn+p2_nn - P_train_tf))
        loss_0s = tf.square(lambda_0[:,0:1]*(s_00 - uu01_tf))
        # loss_0p1 = tf.square(lambda_0[:N_exp,1:2]*(p1_00[:N_exp] - uu01_tf[N_exp:])) #p1 al principio peque
        # loss_0p2 = tf.square(lambda_0[N_exp:,1:2]*(p2_00[N_exp:] - uu01_tf[N_exp:])) #p2 al final peque
        loss_fp1 = tf.square(lambda_r[:,0:1]*f_p1) 
        loss_fp2 = tf.square(lambda_r[:,1:2]*f_p2) 
        loss_fs = tf.square(lambda_r[:,2:3]*f_s) 


        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)
        # loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)+ tf.reduce_mean(loss_0p1)+ tf.reduce_mean(loss_0p2)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)


    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p1_nn+p2_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p1)), tf.reduce_mean(tf.square(f_p2)), tf.reduce_mean(tf.square(f_s))


layers = [3, 20, 20, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]

W_a = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_a = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]
L = len(layers)

W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 3), (3, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
def train_dynamic_step( W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_phi, b_phi, W_a, b_a, lambda_r, lnv])

        f_p, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        loss_fp = tf.square(lambda_r[0:1]*f_p) 
        loss_fs = tf.square(lambda_r[1:2]*f_s) 


        loss =  tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)


    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)



    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))

   
    return loss, 0, tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s))

# %%
lr = 5e-3




optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/10)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp1 = []
loss_fisp2 = []
loss_fiss = []
loss_reg=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf,  lambda_r, lambda_b, lambda_0, lnv, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, optimizer2)
# train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=2*10**5


while it <= Nmax:
    if it<10**5:
        loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    else:
        loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else
        # loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp1.append(loss_fp1)
    loss_fisp2.append(loss_fp2)
    loss_fiss.append(loss_fs)
    # loss_fisa.append(loss_fa)



    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        # print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p1 is: {loss_fp1}")
        print(f"Physicial loss of p2 is: {loss_fp2}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 20300
# Physicial loss of p1 is: 0.013647808693349361
# Physicial loss of p2 is: 0.008320012129843235
# Physicial loss of s is: 0.006939350161701441
# Iteration is: 20310
# Physicial loss of p1 is: 0.013572965748608112
# Physicial loss of p2 is: 0.008373635821044445
# Physicial loss of s is: 0.006856113206595182
# Iteration is: 20320
# Physicial loss of p1 is: 0.013531357981264591
# Physicial loss of p2 is: 0.00838604848831892
# Physicial loss of s is: 0.006815715227276087
# Iteration is: 20330
# Physicial loss of p1 is: 0.013509375043213367
# Physicial loss of p2 is: 0.008202449418604374
# Physicial loss of s is: 0.0067685386165976524
# Iteration is: 20340
# Physicial loss of p1 is: 0.013498222455382347
# Physicial loss of p2 is: 0.008130555972456932
# Physicial loss of s is: 0.0067097884602844715
# Iteration is: 20350
# Physicial loss of p1 is: 0.013482443057000637
# Physicial loss of p2 is: 0.008125538937747478
# Physicial loss of s is: 0.006659326143562794
# Iteration is: 20360
# Physicial loss of p1 is: 0.013454372994601727
# Physicial loss of p2 is: 0.00811169482767582
# Physicial loss of s is: 0.006615288555622101
# Iteration is: 20370
# Physicial loss of p1 is: 0.013403746299445629
# Physicial loss of p2 is: 0.008109147660434246
# Physicial loss of s is: 0.006572680082172155
# Iteration is: 20380
# Physicial loss of p1 is: 0.013384008780121803
# Physicial loss of p2 is: 0.00809394009411335
# Physicial loss of s is: 0.006527011748403311
# Iteration is: 20390
# Physicial loss of p1 is: 0.013363228179514408
# Physicial loss of p2 is: 0.008082077838480473
# Physicial loss of s is: 0.006483528763055801
# Iteration is: 20400
# Physicial loss of p1 is: 0.013320684432983398
# Physicial loss of p2 is: 0.00815876666456461
# Physicial loss of s is: 0.006440664641559124
# Iteration is: 20410
# Physicial loss of p1 is: 0.013438600115478039
# Physicial loss of p2 is: 0.035013023763895035
# Physicial loss of s is: 0.006371966563165188
# Iteration is: 20420
# Physicial loss of p1 is: 0.015403764322400093
# Physicial loss of p2 is: 0.04572199285030365
# Physicial loss of s is: 0.006354864686727524
# Iteration is: 20430
# Physicial loss of p1 is: 0.015740109607577324
# Physicial loss of p2 is: 0.04501846432685852
# Physicial loss of s is: 0.008158951997756958
# Iteration is: 20440
# Physicial loss of p1 is: 0.014849129132926464
# Physicial loss of p2 is: 0.028337804600596428
# Physicial loss of s is: 0.007387575693428516
# Iteration is: 20450
# Physicial loss of p1 is: 0.014080645516514778
# Physicial loss of p2 is: 0.009186814539134502
# Physicial loss of s is: 0.0068228296004235744
# Iteration is: 20460
# Physicial loss of p1 is: 0.013637463562190533
# Physicial loss of p2 is: 0.008273420855402946
# Physicial loss of s is: 0.006732257083058357
# Iteration is: 20470
# Physicial loss of p1 is: 0.013459705747663975
# Physicial loss of p2 is: 0.008388608694076538
# Physicial loss of s is: 0.006721505895256996
# Iteration is: 20480
# Physicial loss of p1 is: 0.013341500423848629
# Physicial loss of p2 is: 0.008288185112178326
# Physicial loss of s is: 0.006650257855653763
# Iteration is: 20490
# Physicial loss of p1 is: 0.013343282975256443
# Physicial loss of p2 is: 0.008086616173386574
# Physicial loss of s is: 0.006612136960029602
# Iteration is: 20500
# Physicial loss of p1 is: 0.013332465663552284
# Physicial loss of p2 is: 0.008009637705981731
# Physicial loss of s is: 0.006565870717167854
# Iteration is: 20510
# Physicial loss of p1 is: 0.013319567777216434
# Physicial loss of p2 is: 0.007985509932041168
# Physicial loss of s is: 0.006526906043291092
# Iteration is: 20520
# Physicial loss of p1 is: 0.013277471996843815
# Physicial loss of p2 is: 0.007960686460137367
# Physicial loss of s is: 0.00648648664355278
# Iteration is: 20530
# Physicial loss of p1 is: 0.013231676071882248
# Physicial loss of p2 is: 0.007960131391882896
# Physicial loss of s is: 0.00644778273999691
# Iteration is: 20540
# Physicial loss of p1 is: 0.013217352330684662
# Physicial loss of p2 is: 0.007937896065413952
# Physicial loss of s is: 0.006405294872820377
# Iteration is: 20550
# Physicial loss of p1 is: 0.01319922599941492
# Physicial loss of p2 is: 0.007924364879727364
# Physicial loss of s is: 0.006366526708006859
# Iteration is: 20560
# Physicial loss of p1 is: 0.013211032375693321
# Physicial loss of p2 is: 0.007978766225278378
# Physicial loss of s is: 0.006344972178339958
# Iteration is: 20570
# Physicial loss of p1 is: 0.014055157080292702
# Physicial loss of p2 is: 0.029266884550452232
# Physicial loss of s is: 0.006521052680909634
# Iteration is: 20580
# Physicial loss of p1 is: 0.012823414988815784
# Physicial loss of p2 is: 0.011198840104043484
# Physicial loss of s is: 0.007218360900878906
# Iteration is: 20590
# Physicial loss of p1 is: 0.01369657926261425
# Physicial loss of p2 is: 0.02455775812268257
# Physicial loss of s is: 0.00684518413618207
# Iteration is: 20600
# Physicial loss of p1 is: 0.01367314625531435
# Physicial loss of p2 is: 0.014803202822804451
# Physicial loss of s is: 0.006679911632090807
# Iteration is: 20610
# Physicial loss of p1 is: 0.013478564098477364
# Physicial loss of p2 is: 0.008339207619428635
# Physicial loss of s is: 0.006535449996590614
# Iteration is: 20620
# Physicial loss of p1 is: 0.013343983329832554
# Physicial loss of p2 is: 0.00812279898673296
# Physicial loss of s is: 0.0065065063536167145
# Iteration is: 20630
# Physicial loss of p1 is: 0.013265579007565975
# Physicial loss of p2 is: 0.007964381016790867
# Physicial loss of s is: 0.006486046593636274
# Iteration is: 20640
# Physicial loss of p1 is: 0.01323632337152958
# Physicial loss of p2 is: 0.007834111340343952
# Physicial loss of s is: 0.006446678191423416
# Iteration is: 20650
# Physicial loss of p1 is: 0.01320625189691782
# Physicial loss of p2 is: 0.007800831459462643
# Physicial loss of s is: 0.00639048358425498
# Iteration is: 20660
# Physicial loss of p1 is: 0.013154649175703526
# Physicial loss of p2 is: 0.007784021552652121
# Physicial loss of s is: 0.006349844858050346
# Iteration is: 20670
# Physicial loss of p1 is: 0.013111762702465057
# Physicial loss of p2 is: 0.007774060126394033
# Physicial loss of s is: 0.006303935311734676
# Iteration is: 20680
# Physicial loss of p1 is: 0.013066438026726246
# Physicial loss of p2 is: 0.007773190271109343
# Physicial loss of s is: 0.006262032315135002
# Iteration is: 20690
# Physicial loss of p1 is: 0.013027616776525974
# Physicial loss of p2 is: 0.007816021330654621
# Physicial loss of s is: 0.006219906732439995
# Iteration is: 20700
# Physicial loss of p1 is: 0.012963318265974522
# Physicial loss of p2 is: 0.012423868291079998
# Physicial loss of s is: 0.00616603996604681
# Iteration is: 20710
# Physicial loss of p1 is: 0.01712789759039879
# Physicial loss of p2 is: 0.26666519045829773
# Physicial loss of s is: 0.006377598270773888
# Iteration is: 20720
# Physicial loss of p1 is: 0.013538281433284283
# Physicial loss of p2 is: 0.03356119990348816
# Physicial loss of s is: 0.007043980993330479
# Iteration is: 20730
# Physicial loss of p1 is: 0.01303170807659626
# Physicial loss of p2 is: 0.018059372901916504
# Physicial loss of s is: 0.00646611861884594
# Iteration is: 20740
# Physicial loss of p1 is: 0.012972375378012657
# Physicial loss of p2 is: 0.010059201158583164
# Physicial loss of s is: 0.006594281177967787
# Iteration is: 20750
# Physicial loss of p1 is: 0.013028486631810665
# Physicial loss of p2 is: 0.007748199626803398
# Physicial loss of s is: 0.0067418962717056274
# Iteration is: 20760
# Physicial loss of p1 is: 0.013059106655418873
# Physicial loss of p2 is: 0.00791957601904869
# Physicial loss of s is: 0.0065227835439145565
# Iteration is: 20770
# Physicial loss of p1 is: 0.013040191493928432
# Physicial loss of p2 is: 0.007693573832511902
# Physicial loss of s is: 0.006348749622702599
# Iteration is: 20780
# Physicial loss of p1 is: 0.013028097338974476
# Physicial loss of p2 is: 0.007707810029387474
# Physicial loss of s is: 0.006314202211797237
# Iteration is: 20790
# Physicial loss of p1 is: 0.013022695668041706
# Physicial loss of p2 is: 0.007669141516089439
# Physicial loss of s is: 0.00627467455342412
# Iteration is: 20800
# Physicial loss of p1 is: 0.012994393706321716
# Physicial loss of p2 is: 0.00764435064047575
# Physicial loss of s is: 0.006228650454431772
# Iteration is: 20810
# Physicial loss of p1 is: 0.012935762293636799
# Physicial loss of p2 is: 0.007648061960935593
# Physicial loss of s is: 0.006191577762365341
# Iteration is: 20820
# Physicial loss of p1 is: 0.012903292663395405
# Physicial loss of p2 is: 0.007620696444064379
# Physicial loss of s is: 0.006150612607598305
# Iteration is: 20830
# Physicial loss of p1 is: 0.012889424338936806
# Physicial loss of p2 is: 0.007605086546391249
# Physicial loss of s is: 0.006108841393142939
# Iteration is: 20840
# Physicial loss of p1 is: 0.012874646112322807
# Physicial loss of p2 is: 0.007591198198497295
# Physicial loss of s is: 0.006070365197956562
# Iteration is: 20850
# Physicial loss of p1 is: 0.013038565404713154
# Physicial loss of p2 is: 0.010830914601683617
# Physicial loss of s is: 0.006047745700925589
# Iteration is: 20860
# Physicial loss of p1 is: 0.02034386433660984
# Physicial loss of p2 is: 0.2855970561504364
# Physicial loss of s is: 0.006304717157036066
# Iteration is: 20870
# Physicial loss of p1 is: 0.014801646582782269
# Physicial loss of p2 is: 0.05625846982002258
# Physicial loss of s is: 0.006440812721848488
# Iteration is: 20880
# Physicial loss of p1 is: 0.012687190435826778
# Physicial loss of p2 is: 0.008861609734594822
# Physicial loss of s is: 0.0077344453893601894
# Iteration is: 20890
# Physicial loss of p1 is: 0.012696173042058945
# Physicial loss of p2 is: 0.01454213261604309
# Physicial loss of s is: 0.008109132759273052
# Iteration is: 20900
# Physicial loss of p1 is: 0.013209883123636246
# Physicial loss of p2 is: 0.007667211350053549
# Physicial loss of s is: 0.006672358606010675
# Iteration is: 20910
# Physicial loss of p1 is: 0.013397465460002422
# Physicial loss of p2 is: 0.008066504262387753
# Physicial loss of s is: 0.006704145111143589
# Iteration is: 20920
# Physicial loss of p1 is: 0.013195611536502838
# Physicial loss of p2 is: 0.007702477276325226
# Physicial loss of s is: 0.0065153902396559715
# Iteration is: 20930
# Physicial loss of p1 is: 0.012986044399440289
# Physicial loss of p2 is: 0.007514688652008772
# Physicial loss of s is: 0.006407380104064941
# Iteration is: 20940
# Physicial loss of p1 is: 0.012898660264909267
# Physicial loss of p2 is: 0.007501308340579271
# Physicial loss of s is: 0.006359525956213474
# Iteration is: 20950
# Physicial loss of p1 is: 0.01285958755761385
# Physicial loss of p2 is: 0.007486781105399132
# Physicial loss of s is: 0.0063054258935153484
# Iteration is: 20960
# Physicial loss of p1 is: 0.012834367342293262
# Physicial loss of p2 is: 0.007468751631677151
# Physicial loss of s is: 0.006259497720748186
# Iteration is: 20970
# Physicial loss of p1 is: 0.012808541767299175
# Physicial loss of p2 is: 0.007456662133336067
# Physicial loss of s is: 0.006209559738636017
# Iteration is: 20980
# Physicial loss of p1 is: 0.012785407714545727
# Physicial loss of p2 is: 0.0074452124536037445
# Physicial loss of s is: 0.006161469500511885
# Iteration is: 20990
# Physicial loss of p1 is: 0.012765685096383095
# Physicial loss of p2 is: 0.007431588601320982
# Physicial loss of s is: 0.006116507574915886
# Iteration is: 21000
# Physicial loss of p1 is: 0.012745367363095284
# Physicial loss of p2 is: 0.0074192313477396965
# Physicial loss of s is: 0.006072705611586571
# Iteration is: 21010
# Physicial loss of p1 is: 0.012724586762487888
# Physicial loss of p2 is: 0.0074071381241083145
# Physicial loss of s is: 0.006030313204973936
# Iteration is: 21020
# Physicial loss of p1 is: 0.012704368680715561
# Physicial loss of p2 is: 0.007394236978143454
# Physicial loss of s is: 0.005989421159029007
# Iteration is: 21030
# Physicial loss of p1 is: 0.012687603011727333
# Physicial loss of p2 is: 0.007379576098173857
# Physicial loss of s is: 0.005949965212494135
# Iteration is: 21040
# Physicial loss of p1 is: 0.012779800221323967
# Physicial loss of p2 is: 0.008975346572697163
# Physicial loss of s is: 0.005918231792747974
# Iteration is: 21050
# Physicial loss of p1 is: 0.021740466356277466
# Physicial loss of p2 is: 0.37634697556495667
# Physicial loss of s is: 0.00604703463613987
# Iteration is: 21060
# Physicial loss of p1 is: 0.015316642820835114
# Physicial loss of p2 is: 0.06801697611808777
# Physicial loss of s is: 0.006231986917555332
# Iteration is: 21070
# Physicial loss of p1 is: 0.014164892956614494
# Physicial loss of p2 is: 0.03271652013063431
# Physicial loss of s is: 0.006136373151093721
# Iteration is: 21080
# Physicial loss of p1 is: 0.013088848441839218
# Physicial loss of p2 is: 0.011179578490555286
# Physicial loss of s is: 0.006243010982871056
# Iteration is: 21090
# Physicial loss of p1 is: 0.012726700864732265
# Physicial loss of p2 is: 0.007537277415394783
# Physicial loss of s is: 0.006663378328084946
# Iteration is: 21100
# Physicial loss of p1 is: 0.012626837939023972
# Physicial loss of p2 is: 0.0074729714542627335
# Physicial loss of s is: 0.006346622481942177
# Iteration is: 21110
# Physicial loss of p1 is: 0.01265386026352644
# Physicial loss of p2 is: 0.007403835188597441
# Physicial loss of s is: 0.0061899591237306595
# Iteration is: 21120
# Physicial loss of p1 is: 0.012629772536456585
# Physicial loss of p2 is: 0.00735892541706562
# Physicial loss of s is: 0.006075147073715925
# Iteration is: 21130
# Physicial loss of p1 is: 0.01262552198022604
# Physicial loss of p2 is: 0.007339602801948786
# Physicial loss of s is: 0.00603172741830349
# Iteration is: 21140
# Physicial loss of p1 is: 0.012596388347446918
# Physicial loss of p2 is: 0.007342877332121134
# Physicial loss of s is: 0.005980612710118294
# Iteration is: 21150
# Physicial loss of p1 is: 0.012583740055561066
# Physicial loss of p2 is: 0.007293187081813812
# Physicial loss of s is: 0.005947371944785118
# Iteration is: 21160
# Physicial loss of p1 is: 0.012563684955239296
# Physicial loss of p2 is: 0.007278739009052515
# Physicial loss of s is: 0.0059066712856292725
# Iteration is: 21170
# Physicial loss of p1 is: 0.01254437118768692
# Physicial loss of p2 is: 0.007269333116710186
# Physicial loss of s is: 0.005866766907274723
# Iteration is: 21180
# Physicial loss of p1 is: 0.012533229775726795
# Physicial loss of p2 is: 0.007251407019793987
# Physicial loss of s is: 0.005830777809023857
# Iteration is: 21190
# Physicial loss of p1 is: 0.012562881223857403
# Physicial loss of p2 is: 0.007439933717250824
# Physicial loss of s is: 0.005812110844999552
# Iteration is: 21200
# Physicial loss of p1 is: 0.013965056277811527
# Physicial loss of p2 is: 0.05347644165158272
# Physicial loss of s is: 0.005988748744130135
# Iteration is: 21210
# Physicial loss of p1 is: 0.012949824333190918
# Physicial loss of p2 is: 0.05699994042515755
# Physicial loss of s is: 0.005844373255968094
# Iteration is: 21220
# Physicial loss of p1 is: 0.012574117630720139
# Physicial loss of p2 is: 0.008256937377154827
# Physicial loss of s is: 0.006110736634582281
# Iteration is: 21230
# Physicial loss of p1 is: 0.012843307107686996
# Physicial loss of p2 is: 0.012127639725804329
# Physicial loss of s is: 0.006563190370798111
# Iteration is: 21240
# Physicial loss of p1 is: 0.012709181755781174
# Physicial loss of p2 is: 0.010038821026682854
# Physicial loss of s is: 0.006186361890286207
# Iteration is: 21250
# Physicial loss of p1 is: 0.012596704065799713
# Physicial loss of p2 is: 0.00734861521050334
# Physicial loss of s is: 0.006056452170014381
# Iteration is: 21260
# Physicial loss of p1 is: 0.012515644542872906
# Physicial loss of p2 is: 0.007360662799328566
# Physicial loss of s is: 0.005952741950750351
# Iteration is: 21270
# Physicial loss of p1 is: 0.012528142891824245
# Physicial loss of p2 is: 0.007169666234403849
# Physicial loss of s is: 0.005932655185461044
# Iteration is: 21280
# Physicial loss of p1 is: 0.012506166473031044
# Physicial loss of p2 is: 0.007120137568563223
# Physicial loss of s is: 0.005874876864254475
# Iteration is: 21290
# Physicial loss of p1 is: 0.012473156675696373
# Physicial loss of p2 is: 0.007110941223800182
# Physicial loss of s is: 0.005830117966979742
# Iteration is: 21300
# Physicial loss of p1 is: 0.01244315318763256
# Physicial loss of p2 is: 0.007108490914106369
# Physicial loss of s is: 0.005795815959572792
# Iteration is: 21310
# Physicial loss of p1 is: 0.012421069666743279
# Physicial loss of p2 is: 0.007087331265211105
# Physicial loss of s is: 0.005753994453698397
# Iteration is: 21320
# Physicial loss of p1 is: 0.01239877287298441
# Physicial loss of p2 is: 0.007083042990416288
# Physicial loss of s is: 0.005717094521969557
# Iteration is: 21330
# Physicial loss of p1 is: 0.01246245950460434
# Physicial loss of p2 is: 0.008082793094217777
# Physicial loss of s is: 0.005683868192136288
# Iteration is: 21340
# Physicial loss of p1 is: 0.017092149704694748
# Physicial loss of p2 is: 0.19075877964496613
# Physicial loss of s is: 0.005741180386394262
# Iteration is: 21350
# Physicial loss of p1 is: 0.01329138781875372
# Physicial loss of p2 is: 0.0524413026869297
# Physicial loss of s is: 0.006090250797569752
# Iteration is: 21360
# Physicial loss of p1 is: 0.012984500266611576
# Physicial loss of p2 is: 0.02480487897992134
# Physicial loss of s is: 0.005839878693223
# Iteration is: 21370
# Physicial loss of p1 is: 0.012486300431191921
# Physicial loss of p2 is: 0.015844866633415222
# Physicial loss of s is: 0.005882905796170235
# Iteration is: 21380
# Physicial loss of p1 is: 0.012469358742237091
# Physicial loss of p2 is: 0.009812656790018082
# Physicial loss of s is: 0.0059404983185231686
# Iteration is: 21390
# Physicial loss of p1 is: 0.012381731532514095
# Physicial loss of p2 is: 0.007113000378012657
# Physicial loss of s is: 0.00591456051915884
# Iteration is: 21400
# Physicial loss of p1 is: 0.012376966886222363
# Physicial loss of p2 is: 0.007143834605813026
# Physicial loss of s is: 0.005897917784750462
# Iteration is: 21410
# Physicial loss of p1 is: 0.012322584167122841
# Physicial loss of p2 is: 0.007043357938528061
# Physicial loss of s is: 0.005812918301671743
# Iteration is: 21420
# Physicial loss of p1 is: 0.012325580231845379
# Physicial loss of p2 is: 0.007015100680291653
# Physicial loss of s is: 0.005763793829828501
# Iteration is: 21430
# Physicial loss of p1 is: 0.012319055385887623
# Physicial loss of p2 is: 0.006984416861087084
# Physicial loss of s is: 0.0057120355777442455
# Iteration is: 21440
# Physicial loss of p1 is: 0.012305949814617634
# Physicial loss of p2 is: 0.006966509856283665
# Physicial loss of s is: 0.005679865833371878
# Iteration is: 21450
# Physicial loss of p1 is: 0.012269589118659496
# Physicial loss of p2 is: 0.006955495569854975
# Physicial loss of s is: 0.005638426169753075
# Iteration is: 21460
# Physicial loss of p1 is: 0.01223725825548172
# Physicial loss of p2 is: 0.006952874828130007
# Physicial loss of s is: 0.005601467564702034
# Iteration is: 21470
# Physicial loss of p1 is: 0.012212404981255531
# Physicial loss of p2 is: 0.006984293460845947
# Physicial loss of s is: 0.005562403704971075
# Iteration is: 21480
# Physicial loss of p1 is: 0.012165282852947712
# Physicial loss of p2 is: 0.014656741172075272
# Physicial loss of s is: 0.005507403519004583
# Iteration is: 21490
# Physicial loss of p1 is: 0.014126036316156387
# Physicial loss of p2 is: 0.1291806548833847
# Physicial loss of s is: 0.006219284608960152
# Iteration is: 21500
# Physicial loss of p1 is: 0.013170354068279266
# Physicial loss of p2 is: 0.03653259575366974
# Physicial loss of s is: 0.006398394238203764
# Iteration is: 21510
# Physicial loss of p1 is: 0.012946478091180325
# Physicial loss of p2 is: 0.00740453414618969
# Physicial loss of s is: 0.007656244095414877
# Iteration is: 21520
# Physicial loss of p1 is: 0.013121603056788445
# Physicial loss of p2 is: 0.007850893773138523
# Physicial loss of s is: 0.007196849677711725
# Iteration is: 21530
# Physicial loss of p1 is: 0.012671537697315216
# Physicial loss of p2 is: 0.006974656600505114
# Physicial loss of s is: 0.006185612641274929
# Iteration is: 21540
# Physicial loss of p1 is: 0.012311304919421673
# Physicial loss of p2 is: 0.006923394743353128
# Physicial loss of s is: 0.0059320367872715
# Iteration is: 21550
# Physicial loss of p1 is: 0.012177960947155952
# Physicial loss of p2 is: 0.006986572407186031
# Physicial loss of s is: 0.005941109266132116
# Iteration is: 21560
# Physicial loss of p1 is: 0.012195118702948093
# Physicial loss of p2 is: 0.006896240171045065
# Physicial loss of s is: 0.0058616152964532375
# Iteration is: 21570
# Physicial loss of p1 is: 0.012211310677230358
# Physicial loss of p2 is: 0.006830661557614803
# Physicial loss of s is: 0.005781846586614847
# Iteration is: 21580
# Physicial loss of p1 is: 0.012206151150166988
# Physicial loss of p2 is: 0.006810890976339579
# Physicial loss of s is: 0.005729412194341421
# Iteration is: 21590
# Physicial loss of p1 is: 0.012183954007923603
# Physicial loss of p2 is: 0.006800685077905655
# Physicial loss of s is: 0.005686214659363031
# Iteration is: 21600
# Physicial loss of p1 is: 0.012152685783803463
# Physicial loss of p2 is: 0.0067923590540885925
# Physicial loss of s is: 0.005640755407512188
# Iteration is: 21610
# Physicial loss of p1 is: 0.012128707021474838
# Physicial loss of p2 is: 0.006783531047403812
# Physicial loss of s is: 0.005597543902695179
# Iteration is: 21620
# Physicial loss of p1 is: 0.01210740301758051
# Physicial loss of p2 is: 0.0067721824161708355
# Physicial loss of s is: 0.005557429511100054
# Iteration is: 21630
# Physicial loss of p1 is: 0.012087578885257244
# Physicial loss of p2 is: 0.006760952528566122
# Physicial loss of s is: 0.005518211517482996
# Iteration is: 21640
# Physicial loss of p1 is: 0.012069862335920334
# Physicial loss of p2 is: 0.006748514715582132
# Physicial loss of s is: 0.0054801031947135925
# Iteration is: 21650
# Physicial loss of p1 is: 0.012087238021194935
# Physicial loss of p2 is: 0.00699170446023345
# Physicial loss of s is: 0.00544577045366168
# Iteration is: 21660
# Physicial loss of p1 is: 0.015518348664045334
# Physicial loss of p2 is: 0.15544730424880981
# Physicial loss of s is: 0.005478392355144024
# Iteration is: 21670
# Physicial loss of p1 is: 0.013604652136564255
# Physicial loss of p2 is: 0.08861619234085083
# Physicial loss of s is: 0.006266857031732798
# Iteration is: 21680
# Physicial loss of p1 is: 0.013219915330410004
# Physicial loss of p2 is: 0.019037233665585518
# Physicial loss of s is: 0.006457492243498564
# Iteration is: 21690
# Physicial loss of p1 is: 0.01264921110123396
# Physicial loss of p2 is: 0.007398324552923441
# Physicial loss of s is: 0.006378098390996456
# Iteration is: 21700
# Physicial loss of p1 is: 0.012606022879481316
# Physicial loss of p2 is: 0.007087036035954952
# Physicial loss of s is: 0.0059678140096366405
# Iteration is: 21710
# Physicial loss of p1 is: 0.01234393659979105
# Physicial loss of p2 is: 0.006963748950511217
# Physicial loss of s is: 0.005746773444116116
# Iteration is: 21720
# Physicial loss of p1 is: 0.012171066366136074
# Physicial loss of p2 is: 0.006775852758437395
# Physicial loss of s is: 0.005610822234302759
# Iteration is: 21730
# Physicial loss of p1 is: 0.012087234295904636
# Physicial loss of p2 is: 0.006812858395278454
# Physicial loss of s is: 0.005572520662099123
# Iteration is: 21740
# Physicial loss of p1 is: 0.01202224101871252
# Physicial loss of p2 is: 0.006795379798859358
# Physicial loss of s is: 0.00553241977468133
# Iteration is: 21750
# Physicial loss of p1 is: 0.012004852294921875
# Physicial loss of p2 is: 0.006692374590784311
# Physicial loss of s is: 0.0054963394068181515
# Iteration is: 21760
# Physicial loss of p1 is: 0.01198229193687439
# Physicial loss of p2 is: 0.006670042406767607
# Physicial loss of s is: 0.0054617105051875114
# Iteration is: 21770
# Physicial loss of p1 is: 0.011959902010858059
# Physicial loss of p2 is: 0.006668230518698692
# Physicial loss of s is: 0.00542635191231966
# Iteration is: 21780
# Physicial loss of p1 is: 0.011942336335778236
# Physicial loss of p2 is: 0.006646259222179651
# Physicial loss of s is: 0.005391168873757124
# Iteration is: 21790
# Physicial loss of p1 is: 0.011923618614673615
# Physicial loss of p2 is: 0.0066345506347715855
# Physicial loss of s is: 0.005358201917260885
# Iteration is: 21800
# Physicial loss of p1 is: 0.011942620389163494
# Physicial loss of p2 is: 0.0067565361969172955
# Physicial loss of s is: 0.005335274618119001
# Iteration is: 21810
# Physicial loss of p1 is: 0.012943611480295658
# Physicial loss of p2 is: 0.038322605192661285
# Physicial loss of s is: 0.005482938606292009
# Iteration is: 21820
# Physicial loss of p1 is: 0.01192150916904211
# Physicial loss of p2 is: 0.02490430511534214
# Physicial loss of s is: 0.005510237067937851
# Iteration is: 21830
# Physicial loss of p1 is: 0.012394188903272152
# Physicial loss of p2 is: 0.019970476627349854
# Physicial loss of s is: 0.0056387693621218204
# Iteration is: 21840
# Physicial loss of p1 is: 0.01245304848998785
# Physicial loss of p2 is: 0.01793772727251053
# Physicial loss of s is: 0.005991242825984955
# Iteration is: 21850
# Physicial loss of p1 is: 0.01212976686656475
# Physicial loss of p2 is: 0.009423741139471531
# Physicial loss of s is: 0.005635683424770832
# Iteration is: 21860
# Physicial loss of p1 is: 0.011962651275098324
# Physicial loss of p2 is: 0.006542551331222057
# Physicial loss of s is: 0.005568597931414843
# Iteration is: 21870
# Physicial loss of p1 is: 0.011895079165697098
# Physicial loss of p2 is: 0.007173551246523857
# Physicial loss of s is: 0.005489826668053865
# Iteration is: 21880
# Physicial loss of p1 is: 0.011924047954380512
# Physicial loss of p2 is: 0.006523809861391783
# Physicial loss of s is: 0.00546732172369957
# Iteration is: 21890
# Physicial loss of p1 is: 0.01189749501645565
# Physicial loss of p2 is: 0.006523652467876673
# Physicial loss of s is: 0.005414959508925676
# Iteration is: 21900
# Physicial loss of p1 is: 0.011851528659462929
# Physicial loss of p2 is: 0.006531539373099804
# Physicial loss of s is: 0.005371816456317902
# Iteration is: 21910
# Physicial loss of p1 is: 0.011833311058580875
# Physicial loss of p2 is: 0.006491962354630232
# Physicial loss of s is: 0.0053373537957668304
# Iteration is: 21920
# Physicial loss of p1 is: 0.011808611452579498
# Physicial loss of p2 is: 0.006482806988060474
# Physicial loss of s is: 0.0052984654903411865
# Iteration is: 21930
# Physicial loss of p1 is: 0.011783120222389698
# Physicial loss of p2 is: 0.006477357354015112
# Physicial loss of s is: 0.005261542741209269
# Iteration is: 21940
# Physicial loss of p1 is: 0.01176841277629137
# Physicial loss of p2 is: 0.006466523744165897
# Physicial loss of s is: 0.005225797183811665
# Iteration is: 21950
# Physicial loss of p1 is: 0.01182885468006134
# Physicial loss of p2 is: 0.007488158531486988
# Physicial loss of s is: 0.005196230951696634
# Iteration is: 21960
# Physicial loss of p1 is: 0.02061241865158081
# Physicial loss of p2 is: 0.3731175661087036
# Physicial loss of s is: 0.005301244556903839
# Iteration is: 21970
# Physicial loss of p1 is: 0.013608667068183422
# Physicial loss of p2 is: 0.027149111032485962
# Physicial loss of s is: 0.0059277769178152084
# Iteration is: 21980
# Physicial loss of p1 is: 0.013508331030607224
# Physicial loss of p2 is: 0.03496922180056572
# Physicial loss of s is: 0.006146233528852463
# Iteration is: 21990
# Physicial loss of p1 is: 0.012599428184330463
# Physicial loss of p2 is: 0.01673818938434124
# Physicial loss of s is: 0.005791361443698406
# Iteration is: 22000
# Physicial loss of p1 is: 0.012015189044177532
# Physicial loss of p2 is: 0.007062538061290979
# Physicial loss of s is: 0.005549805238842964
# Iteration is: 22010
# Physicial loss of p1 is: 0.01172235980629921
# Physicial loss of p2 is: 0.0065557691268622875
# Physicial loss of s is: 0.005614470690488815
# Iteration is: 22020
# Physicial loss of p1 is: 0.01171762216836214
# Physicial loss of p2 is: 0.006486943922936916
# Physicial loss of s is: 0.005560623481869698
# Iteration is: 22030
# Physicial loss of p1 is: 0.011709541082382202
# Physicial loss of p2 is: 0.006444153375923634
# Physicial loss of s is: 0.005435117520391941
# Iteration is: 22040
# Physicial loss of p1 is: 0.011689908802509308
# Physicial loss of p2 is: 0.006440370809286833
# Physicial loss of s is: 0.0053694951348006725
# Iteration is: 22050
# Physicial loss of p1 is: 0.011686294339597225
# Physicial loss of p2 is: 0.006413029506802559
# Physicial loss of s is: 0.005323254968971014
# Iteration is: 22060
# Physicial loss of p1 is: 0.011680644936859608
# Physicial loss of p2 is: 0.006393621675670147
# Physicial loss of s is: 0.005283196456730366
# Iteration is: 22070
# Physicial loss of p1 is: 0.011670141480863094
# Physicial loss of p2 is: 0.006373539566993713
# Physicial loss of s is: 0.005244504194706678
# Iteration is: 22080
# Physicial loss of p1 is: 0.01165574137121439
# Physicial loss of p2 is: 0.0063668000511825085
# Physicial loss of s is: 0.00520723033696413
# Iteration is: 22090
# Physicial loss of p1 is: 0.011639874428510666
# Physicial loss of p2 is: 0.006356656085699797
# Physicial loss of s is: 0.005172620061784983
# Iteration is: 22100
# Physicial loss of p1 is: 0.011622317135334015
# Physicial loss of p2 is: 0.00634809210896492
# Physicial loss of s is: 0.005138780921697617
# Iteration is: 22110
# Physicial loss of p1 is: 0.011599150486290455
# Physicial loss of p2 is: 0.006350488867610693
# Physicial loss of s is: 0.005105114076286554
# Iteration is: 22120
# Physicial loss of p1 is: 0.011550269089639187
# Physicial loss of p2 is: 0.007143439259380102
# Physicial loss of s is: 0.005061686970293522
# Iteration is: 22130
# Physicial loss of p1 is: 0.01524968072772026
# Physicial loss of p2 is: 0.21366086602210999
# Physicial loss of s is: 0.00488833524286747
# Iteration is: 22140
# Physicial loss of p1 is: 0.012855484150350094
# Physicial loss of p2 is: 0.04196581244468689
# Physicial loss of s is: 0.005538846366107464
# Iteration is: 22150
# Physicial loss of p1 is: 0.012361607514321804
# Physicial loss of p2 is: 0.01908467710018158
# Physicial loss of s is: 0.006242432631552219
# Iteration is: 22160
# Physicial loss of p1 is: 0.01181965135037899
# Physicial loss of p2 is: 0.009702660143375397
# Physicial loss of s is: 0.005594935268163681
# Iteration is: 22170
# Physicial loss of p1 is: 0.011868801899254322
# Physicial loss of p2 is: 0.007355724927037954
# Physicial loss of s is: 0.0056091537699103355
# Iteration is: 22180
# Physicial loss of p1 is: 0.01173944678157568
# Physicial loss of p2 is: 0.0068831490352749825
# Physicial loss of s is: 0.005473061464726925
# Iteration is: 22190
# Physicial loss of p1 is: 0.011774756945669651
# Physicial loss of p2 is: 0.006551835685968399
# Physicial loss of s is: 0.005429695826023817
# Iteration is: 22200
# Physicial loss of p1 is: 0.011727310717105865
# Physicial loss of p2 is: 0.0063095190562307835
# Physicial loss of s is: 0.005383551120758057
# Iteration is: 22210
# Physicial loss of p1 is: 0.011655252426862717
# Physicial loss of p2 is: 0.0061956443823874
# Physicial loss of s is: 0.005314944311976433
# Iteration is: 22220
# Physicial loss of p1 is: 0.011570252478122711
# Physicial loss of p2 is: 0.006222304422408342
# Physicial loss of s is: 0.0052612884901463985
# Iteration is: 22230
# Physicial loss of p1 is: 0.011539564467966557
# Physicial loss of p2 is: 0.006188732106238604
# Physicial loss of s is: 0.005226044449955225
# Iteration is: 22240
# Physicial loss of p1 is: 0.011533983051776886
# Physicial loss of p2 is: 0.006184784229844809
# Physicial loss of s is: 0.00518148485571146
# Iteration is: 22250
# Physicial loss of p1 is: 0.011517936363816261
# Physicial loss of p2 is: 0.006179346702992916
# Physicial loss of s is: 0.005141694564372301
# Iteration is: 22260
# Physicial loss of p1 is: 0.01149034220725298
# Physicial loss of p2 is: 0.006174806039780378
# Physicial loss of s is: 0.005104441195726395
# Iteration is: 22270
# Physicial loss of p1 is: 0.011476559564471245
# Physicial loss of p2 is: 0.006167076528072357
# Physicial loss of s is: 0.005068887956440449
# Iteration is: 22280
# Physicial loss of p1 is: 0.011453595943748951
# Physicial loss of p2 is: 0.006159279029816389
# Physicial loss of s is: 0.005034778732806444
# Iteration is: 22290
# Physicial loss of p1 is: 0.011441996321082115
# Physicial loss of p2 is: 0.006152201909571886
# Physicial loss of s is: 0.005002225283533335
# Iteration is: 22300
# Physicial loss of p1 is: 0.0115963164716959
# Physicial loss of p2 is: 0.010537640191614628
# Physicial loss of s is: 0.004978023003786802
# Iteration is: 22310
# Physicial loss of p1 is: 0.01741687022149563
# Physicial loss of p2 is: 0.21986496448516846
# Physicial loss of s is: 0.005083250347524881
# Iteration is: 22320
# Physicial loss of p1 is: 0.013691534288227558
# Physicial loss of p2 is: 0.07501522451639175
# Physicial loss of s is: 0.005380875896662474
# Iteration is: 22330
# Physicial loss of p1 is: 0.011769726872444153
# Physicial loss of p2 is: 0.006915335077792406
# Physicial loss of s is: 0.005107819568365812
# Iteration is: 22340
# Physicial loss of p1 is: 0.011571075767278671
# Physicial loss of p2 is: 0.014613679610192776
# Physicial loss of s is: 0.005380397196859121
# Iteration is: 22350
# Physicial loss of p1 is: 0.011521587148308754
# Physicial loss of p2 is: 0.011124336160719395
# Physicial loss of s is: 0.005194977391511202
# Iteration is: 22360
# Physicial loss of p1 is: 0.011516345664858818
# Physicial loss of p2 is: 0.007239839062094688
# Physicial loss of s is: 0.005151732359081507
# Iteration is: 22370
# Physicial loss of p1 is: 0.011467214673757553
# Physicial loss of p2 is: 0.0063839559443295
# Physicial loss of s is: 0.00513103324919939
# Iteration is: 22380
# Physicial loss of p1 is: 0.011422604322433472
# Physicial loss of p2 is: 0.0062439399771392345
# Physicial loss of s is: 0.005096993409097195
# Iteration is: 22390
# Physicial loss of p1 is: 0.011370314285159111
# Physicial loss of p2 is: 0.006204403471201658
# Physicial loss of s is: 0.00506823044270277
# Iteration is: 22400
# Physicial loss of p1 is: 0.011353597044944763
# Physicial loss of p2 is: 0.006164831109344959
# Physicial loss of s is: 0.005039222538471222
# Iteration is: 22410
# Physicial loss of p1 is: 0.011375893838703632
# Physicial loss of p2 is: 0.006121430080384016
# Physicial loss of s is: 0.005019994918256998
# Iteration is: 22420
# Physicial loss of p1 is: 0.011585271917283535
# Physicial loss of p2 is: 0.006378212943673134
# Physicial loss of s is: 0.00527129927650094
# Iteration is: 22430
# Physicial loss of p1 is: 0.011114848777651787
# Physicial loss of p2 is: 0.006095453631132841
# Physicial loss of s is: 0.0050597842782735825
# Iteration is: 22440
# Physicial loss of p1 is: 0.011433576233685017
# Physicial loss of p2 is: 0.006103364750742912
# Physicial loss of s is: 0.005206603556871414
# Iteration is: 22450
# Physicial loss of p1 is: 0.011392748914659023
# Physicial loss of p2 is: 0.006014356389641762
# Physicial loss of s is: 0.005124088376760483
# Iteration is: 22460
# Physicial loss of p1 is: 0.011281602084636688
# Physicial loss of p2 is: 0.005970167927443981
# Physicial loss of s is: 0.005038127768784761
# Iteration is: 22470
# Physicial loss of p1 is: 0.011274941265583038
# Physicial loss of p2 is: 0.005979987792670727
# Physicial loss of s is: 0.005014795809984207
# Iteration is: 22480
# Physicial loss of p1 is: 0.011308922432363033
# Physicial loss of p2 is: 0.006440045312047005
# Physicial loss of s is: 0.00496972631663084
# Iteration is: 22490
# Physicial loss of p1 is: 0.01188954059034586
# Physicial loss of p2 is: 0.030638109892606735
# Physicial loss of s is: 0.004954254254698753
# Iteration is: 22500
# Physicial loss of p1 is: 0.01172580849379301
# Physicial loss of p2 is: 0.01161057036370039
# Physicial loss of s is: 0.0050852540880441666
# Iteration is: 22510
# Physicial loss of p1 is: 0.011748848482966423
# Physicial loss of p2 is: 0.02346903458237648
# Physicial loss of s is: 0.00494778947904706
# Iteration is: 22520
# Physicial loss of p1 is: 0.011499694548547268
# Physicial loss of p2 is: 0.006612078286707401
# Physicial loss of s is: 0.0050886389799416065
# Iteration is: 22530
# Physicial loss of p1 is: 0.011417660862207413
# Physicial loss of p2 is: 0.008481630124151707
# Physicial loss of s is: 0.004993647802621126
# Iteration is: 22540
# Physicial loss of p1 is: 0.011318267323076725
# Physicial loss of p2 is: 0.0070446692407131195
# Physicial loss of s is: 0.004979316145181656
# Iteration is: 22550
# Physicial loss of p1 is: 0.011213738471269608
# Physicial loss of p2 is: 0.0063628326170146465
# Physicial loss of s is: 0.004906396381556988
# Iteration is: 22560
# Physicial loss of p1 is: 0.011236315593123436
# Physicial loss of p2 is: 0.005989841651171446
# Physicial loss of s is: 0.004879125393927097
# Iteration is: 22570
# Physicial loss of p1 is: 0.01118236780166626
# Physicial loss of p2 is: 0.006030730437487364
# Physicial loss of s is: 0.004847926553338766
# Iteration is: 22580
# Physicial loss of p1 is: 0.011166018433868885
# Physicial loss of p2 is: 0.0059506590478122234
# Physicial loss of s is: 0.004821212030947208
# Iteration is: 22590
# Physicial loss of p1 is: 0.011288225650787354
# Physicial loss of p2 is: 0.00874259602278471
# Physicial loss of s is: 0.00481343362480402
# Iteration is: 22600
# Physicial loss of p1 is: 0.01638662815093994
# Physicial loss of p2 is: 0.2198082059621811
# Physicial loss of s is: 0.004963256884366274
# Iteration is: 22610
# Physicial loss of p1 is: 0.011941173113882542
# Physicial loss of p2 is: 0.03538855165243149
# Physicial loss of s is: 0.005369717720896006
# Iteration is: 22620
# Physicial loss of p1 is: 0.011570489034056664
# Physicial loss of p2 is: 0.030017957091331482
# Physicial loss of s is: 0.005002980586141348
# Iteration is: 22630
# Physicial loss of p1 is: 0.011088898405432701
# Physicial loss of p2 is: 0.011523837223649025
# Physicial loss of s is: 0.005198793485760689
# Iteration is: 22640
# Physicial loss of p1 is: 0.011082946322858334
# Physicial loss of p2 is: 0.006056795362383127
# Physicial loss of s is: 0.005274330731481314
# Iteration is: 22650
# Physicial loss of p1 is: 0.01119706965982914
# Physicial loss of p2 is: 0.0059866830706596375
# Physicial loss of s is: 0.0050703855231404305
# Iteration is: 22660
# Physicial loss of p1 is: 0.011238708160817623
# Physicial loss of p2 is: 0.005841581616550684
# Physicial loss of s is: 0.005029795225709677
# Iteration is: 22670
# Physicial loss of p1 is: 0.011167489923536777
# Physicial loss of p2 is: 0.005844990722835064
# Physicial loss of s is: 0.004956995602697134
# Iteration is: 22680
# Physicial loss of p1 is: 0.0110978614538908
# Physicial loss of p2 is: 0.005811944603919983
# Physicial loss of s is: 0.004918355029076338
# Iteration is: 22690
# Physicial loss of p1 is: 0.011106659658253193
# Physicial loss of p2 is: 0.005820618011057377
# Physicial loss of s is: 0.004884675145149231
# Iteration is: 22700
# Physicial loss of p1 is: 0.01107199490070343
# Physicial loss of p2 is: 0.005796179175376892
# Physicial loss of s is: 0.004848156590014696
# Iteration is: 22710
# Physicial loss of p1 is: 0.011064153164625168
# Physicial loss of p2 is: 0.005793449934571981
# Physicial loss of s is: 0.004815732594579458
# Iteration is: 22720
# Physicial loss of p1 is: 0.011034625582396984
# Physicial loss of p2 is: 0.005788756534457207
# Physicial loss of s is: 0.004783512093126774
# Iteration is: 22730
# Physicial loss of p1 is: 0.01103213056921959
# Physicial loss of p2 is: 0.0058206552639603615
# Physicial loss of s is: 0.00475429417565465
# Iteration is: 22740
# Physicial loss of p1 is: 0.011460105888545513
# Physicial loss of p2 is: 0.02287786640226841
# Physicial loss of s is: 0.004745357669889927
# Iteration is: 22750
# Physicial loss of p1 is: 0.011492720805108547
# Physicial loss of p2 is: 0.0058766137808561325
# Physicial loss of s is: 0.005095904693007469
# Iteration is: 22760
# Physicial loss of p1 is: 0.01126464456319809
# Physicial loss of p2 is: 0.009332336485385895
# Physicial loss of s is: 0.004846274387091398
# Iteration is: 22770
# Physicial loss of p1 is: 0.011326884850859642
# Physicial loss of p2 is: 0.00785022508352995
# Physicial loss of s is: 0.004999771248549223
# Iteration is: 22780
# Physicial loss of p1 is: 0.011267255991697311
# Physicial loss of p2 is: 0.010454357601702213
# Physicial loss of s is: 0.004961006343364716
# Iteration is: 22790
# Physicial loss of p1 is: 0.011182019487023354
# Physicial loss of p2 is: 0.008743214420974255
# Physicial loss of s is: 0.00494150398299098
# Iteration is: 22800
# Physicial loss of p1 is: 0.011038845404982567
# Physicial loss of p2 is: 0.006902490276843309
# Physicial loss of s is: 0.004886244423687458
# Iteration is: 22810
# Physicial loss of p1 is: 0.011012028902769089
# Physicial loss of p2 is: 0.006107238586992025
# Physicial loss of s is: 0.004865917842835188
# Iteration is: 22820
# Physicial loss of p1 is: 0.011000506579875946
# Physicial loss of p2 is: 0.005812270101159811
# Physicial loss of s is: 0.004823913797736168
# Iteration is: 22830
# Physicial loss of p1 is: 0.010982156731188297
# Physicial loss of p2 is: 0.005763692315667868
# Physicial loss of s is: 0.00479821115732193
# Iteration is: 22840
# Physicial loss of p1 is: 0.010930122807621956
# Physicial loss of p2 is: 0.0057342140935361385
# Physicial loss of s is: 0.004761700984090567
# Iteration is: 22850
# Physicial loss of p1 is: 0.010706109926104546
# Physicial loss of p2 is: 0.006453410256654024
# Physicial loss of s is: 0.004770334810018539
# Iteration is: 22860
# Physicial loss of p1 is: 0.01104559376835823
# Physicial loss of p2 is: 0.005980194080621004
# Physicial loss of s is: 0.004978568758815527
# Iteration is: 22870
# Physicial loss of p1 is: 0.01079321838915348
# Physicial loss of p2 is: 0.006305012386292219
# Physicial loss of s is: 0.004901722073554993
# Iteration is: 22880
# Physicial loss of p1 is: 0.010946795344352722
# Physicial loss of p2 is: 0.005825759377330542
# Physicial loss of s is: 0.004850622732192278
# Iteration is: 22890
# Physicial loss of p1 is: 0.010935486294329166
# Physicial loss of p2 is: 0.005609341897070408
# Physicial loss of s is: 0.004833448212593794
# Iteration is: 22900
# Physicial loss of p1 is: 0.01085025817155838
# Physicial loss of p2 is: 0.005704685114324093
# Physicial loss of s is: 0.004764420446008444
# Iteration is: 22910
# Physicial loss of p1 is: 0.010895607061684132
# Physicial loss of p2 is: 0.00698682339861989
# Physicial loss of s is: 0.0047346982173621655
# Iteration is: 22920
# Physicial loss of p1 is: 0.011819089762866497
# Physicial loss of p2 is: 0.06424792110919952
# Physicial loss of s is: 0.0046775792725384235
# Iteration is: 22930
# Physicial loss of p1 is: 0.011837114579975605
# Physicial loss of p2 is: 0.022201532498002052
# Physicial loss of s is: 0.0048356507904827595
# Iteration is: 22940
# Physicial loss of p1 is: 0.011001398786902428
# Physicial loss of p2 is: 0.020512526854872704
# Physicial loss of s is: 0.004795507062226534
# Iteration is: 22950
# Physicial loss of p1 is: 0.01070764847099781
# Physicial loss of p2 is: 0.009429371915757656
# Physicial loss of s is: 0.00517849437892437
# Iteration is: 22960
# Physicial loss of p1 is: 0.01110789179801941
# Physicial loss of p2 is: 0.007523480337113142
# Physicial loss of s is: 0.004794534295797348
# Iteration is: 22970
# Physicial loss of p1 is: 0.010988038964569569
# Physicial loss of p2 is: 0.005636665038764477
# Physicial loss of s is: 0.004798374604433775
# Iteration is: 22980
# Physicial loss of p1 is: 0.010735795833170414
# Physicial loss of p2 is: 0.005760944448411465
# Physicial loss of s is: 0.004781763534992933
# Iteration is: 22990
# Physicial loss of p1 is: 0.010859091766178608
# Physicial loss of p2 is: 0.005632434971630573
# Physicial loss of s is: 0.004700008779764175
# Iteration is: 23000
# Physicial loss of p1 is: 0.01076123770326376
# Physicial loss of p2 is: 0.005596474278718233
# Physicial loss of s is: 0.004659485071897507
# Iteration is: 23010
# Physicial loss of p1 is: 0.010775944218039513
# Physicial loss of p2 is: 0.005602274090051651
# Physicial loss of s is: 0.0046278187073767185
# Iteration is: 23020
# Physicial loss of p1 is: 0.010715835727751255
# Physicial loss of p2 is: 0.0059244814328849316
# Physicial loss of s is: 0.004595038015395403
# Iteration is: 23030
# Physicial loss of p1 is: 0.011237887665629387
# Physicial loss of p2 is: 0.04383010417222977
# Physicial loss of s is: 0.004481895361095667
# Iteration is: 23040
# Physicial loss of p1 is: 0.011740819551050663
# Physicial loss of p2 is: 0.01625293865799904
# Physicial loss of s is: 0.005175151862204075
# Iteration is: 23050
# Physicial loss of p1 is: 0.011103841476142406
# Physicial loss of p2 is: 0.020986933261156082
# Physicial loss of s is: 0.00552704930305481
# Iteration is: 23060
# Physicial loss of p1 is: 0.01113057043403387
# Physicial loss of p2 is: 0.01449697557836771
# Physicial loss of s is: 0.004882215987890959
# Iteration is: 23070
# Physicial loss of p1 is: 0.010843167081475258
# Physicial loss of p2 is: 0.00823564175516367
# Physicial loss of s is: 0.004897071979939938
# Iteration is: 23080
# Physicial loss of p1 is: 0.010719179175794125
# Physicial loss of p2 is: 0.005922292824834585
# Physicial loss of s is: 0.004980699624866247
# Iteration is: 23090
# Physicial loss of p1 is: 0.010673293843865395
# Physicial loss of p2 is: 0.005510048475116491
# Physicial loss of s is: 0.004917792975902557
# Iteration is: 23100
# Physicial loss of p1 is: 0.010680919513106346
# Physicial loss of p2 is: 0.005496103782206774
# Physicial loss of s is: 0.004830407910048962
# Iteration is: 23110
# Physicial loss of p1 is: 0.01067856140434742
# Physicial loss of p2 is: 0.005538027733564377
# Physicial loss of s is: 0.004759635776281357
# Iteration is: 23120
# Physicial loss of p1 is: 0.010679914616048336
# Physicial loss of p2 is: 0.005470390431582928
# Physicial loss of s is: 0.004716749303042889
# Iteration is: 23130
# Physicial loss of p1 is: 0.010690245777368546
# Physicial loss of p2 is: 0.005474326200783253
# Physicial loss of s is: 0.004682498052716255
# Iteration is: 23140
# Physicial loss of p1 is: 0.010676847770810127
# Physicial loss of p2 is: 0.005461373366415501
# Physicial loss of s is: 0.0046523031778633595
# Iteration is: 23150
# Physicial loss of p1 is: 0.01064979750663042
# Physicial loss of p2 is: 0.005456812214106321
# Physicial loss of s is: 0.004622835665941238
# Iteration is: 23160
# Physicial loss of p1 is: 0.010624685324728489
# Physicial loss of p2 is: 0.005455148871988058
# Physicial loss of s is: 0.004595556762069464
# Iteration is: 23170
# Physicial loss of p1 is: 0.010611582547426224
# Physicial loss of p2 is: 0.005466935690492392
# Physicial loss of s is: 0.004568498115986586
# Iteration is: 23180
# Physicial loss of p1 is: 0.010606838390231133
# Physicial loss of p2 is: 0.00722589623183012
# Physicial loss of s is: 0.004540320485830307
# Iteration is: 23190
# Physicial loss of p1 is: 0.019210055470466614
# Physicial loss of p2 is: 0.4000827670097351
# Physicial loss of s is: 0.0047614797949790955
# Iteration is: 23200
# Physicial loss of p1 is: 0.011893375776708126
# Physicial loss of p2 is: 0.04007421061396599
# Physicial loss of s is: 0.0050863963551819324
# Iteration is: 23210
# Physicial loss of p1 is: 0.01101543940603733
# Physicial loss of p2 is: 0.032389819622039795
# Physicial loss of s is: 0.005121284630149603
# Iteration is: 23220
# Physicial loss of p1 is: 0.010763847269117832
# Physicial loss of p2 is: 0.019112423062324524
# Physicial loss of s is: 0.0053129964508116245
# Iteration is: 23230
# Physicial loss of p1 is: 0.010605192743241787
# Physicial loss of p2 is: 0.009299270808696747
# Physicial loss of s is: 0.004832217935472727
# Iteration is: 23240
# Physicial loss of p1 is: 0.010614213533699512
# Physicial loss of p2 is: 0.006207453086972237
# Physicial loss of s is: 0.004805608186870813
# Iteration is: 23250
# Physicial loss of p1 is: 0.010606424883008003
# Physicial loss of p2 is: 0.005621863529086113
# Physicial loss of s is: 0.004761872347444296
# Iteration is: 23260
# Physicial loss of p1 is: 0.010585612617433071
# Physicial loss of p2 is: 0.0055639357306063175
# Physicial loss of s is: 0.004723619669675827
# Iteration is: 23270
# Physicial loss of p1 is: 0.010560279712080956
# Physicial loss of p2 is: 0.005502913612872362
# Physicial loss of s is: 0.004697640426456928
# Iteration is: 23280
# Physicial loss of p1 is: 0.010549657978117466
# Physicial loss of p2 is: 0.00542049715295434
# Physicial loss of s is: 0.0046624732203781605
# Iteration is: 23290
# Physicial loss of p1 is: 0.010547894984483719
# Physicial loss of p2 is: 0.005372054874897003
# Physicial loss of s is: 0.004634335171431303
# Iteration is: 23300
# Physicial loss of p1 is: 0.010538935661315918
# Physicial loss of p2 is: 0.005366694647818804
# Physicial loss of s is: 0.004608722869306803
# Iteration is: 23310
# Physicial loss of p1 is: 0.010519054718315601
# Physicial loss of p2 is: 0.005364586133509874
# Physicial loss of s is: 0.00458409171551466
# Iteration is: 23320
# Physicial loss of p1 is: 0.010496149770915508
# Physicial loss of p2 is: 0.005351059138774872
# Physicial loss of s is: 0.004561600275337696
# Iteration is: 23330
# Physicial loss of p1 is: 0.010492689907550812
# Physicial loss of p2 is: 0.005361453630030155
# Physicial loss of s is: 0.004554223269224167
# Iteration is: 23340
# Physicial loss of p1 is: 0.01068397331982851
# Physicial loss of p2 is: 0.011829858645796776
# Physicial loss of s is: 0.004738057032227516
# Iteration is: 23350
# Physicial loss of p1 is: 0.010683518834412098
# Physicial loss of p2 is: 0.02239365316927433
# Physicial loss of s is: 0.004777614958584309
# Iteration is: 23360
# ...
# Iteration is: 36880
# Physicial loss of p1 is: 0.002669797046110034
# Physicial loss of p2 is: 0.0027293532621115446
# Physicial loss of s is: 0.0025302201975136995
# Iteration is: 36890
# Physicial loss of p1 is: 0.002826425712555647
# Physicial loss of p2 is: 0.012707836925983429
# Physicial loss of s is: 0.0022689427714794874
# Iteration is: 36900
# Physicial loss of p1 is: 0.0027753140311688185
# Physicial loss of p2 is: 0.008100043050944805
# Physicial loss of s is: 0.002228525700047612
# Iteration is: 36910
# Physicial loss of p1 is: 0.002696483861654997
# Physicial loss of p2 is: 0.003941525239497423
# Physicial loss of s is: 0.0021225314121693373
# Iteration is: 36920
# Physicial loss of p1 is: 0.0026821093633770943
# Physicial loss of p2 is: 0.0034269229508936405
# Physicial loss of s is: 0.0021095748525112867
# Iteration is: 36930
# Physicial loss of p1 is: 0.002652132883667946
# Physicial loss of p2 is: 0.002779396716505289
# Physicial loss of s is: 0.0020922143012285233
# Iteration is: 36940
# Physicial loss of p1 is: 0.0026801798958331347
# Physicial loss of p2 is: 0.005463922396302223
# Physicial loss of s is: 0.002083677565678954
# Iteration is: 36950
# Physicial loss of p1 is: 0.003306251484900713
# Physicial loss of p2 is: 0.02790641412138939
# Physicial loss of s is: 0.0021210038103163242
# Iteration is: 36960
# Physicial loss of p1 is: 0.0029420615173876286
# Physicial loss of p2 is: 0.013100288808345795
# Physicial loss of s is: 0.0020719936583191156
# Iteration is: 36970
# Physicial loss of p1 is: 0.002745292382314801
# Physicial loss of p2 is: 0.004712656140327454
# Physicial loss of s is: 0.002080159727483988
# Iteration is: 36980
# Physicial loss of p1 is: 0.0026840022765100002
# Physicial loss of p2 is: 0.002830022480338812
# Physicial loss of s is: 0.0020713037811219692
# Iteration is: 36990
# Physicial loss of p1 is: 0.0026777866296470165
# Physicial loss of p2 is: 0.0037738990504294634
# Physicial loss of s is: 0.002061754697933793
# Iteration is: 37000
# Physicial loss of p1 is: 0.0028376292902976274
# Physicial loss of p2 is: 0.011672216467559338
# Physicial loss of s is: 0.002069850917905569
# Iteration is: 37010
# Physicial loss of p1 is: 0.0035437277983874083
# Physicial loss of p2 is: 0.04059745371341705
# Physicial loss of s is: 0.0020350292325019836
# Iteration is: 37020
# Physicial loss of p1 is: 0.002907004440203309
# Physicial loss of p2 is: 0.013280772604048252
# Physicial loss of s is: 0.002077677519991994
# Iteration is: 37030
# Physicial loss of p1 is: 0.0026687737554311752
# Physicial loss of p2 is: 0.0026261452585458755
# Physicial loss of s is: 0.0021066630724817514
# Iteration is: 37040
# Physicial loss of p1 is: 0.0027389870956540108
# Physicial loss of p2 is: 0.00572279142215848
# Physicial loss of s is: 0.002047593705356121
# Iteration is: 37050
# Physicial loss of p1 is: 0.0027413424104452133
# Physicial loss of p2 is: 0.007217667531222105
# Physicial loss of s is: 0.0020636904519051313
# Iteration is: 37060
# Physicial loss of p1 is: 0.0031820086296647787
# Physicial loss of p2 is: 0.025843683630228043
# Physicial loss of s is: 0.0020733829587697983
# Iteration is: 37070
# Physicial loss of p1 is: 0.0028218955267220736
# Physicial loss of p2 is: 0.007903922349214554
# Physicial loss of s is: 0.0020625682082027197
# Iteration is: 37080
# Physicial loss of p1 is: 0.0027589681558310986
# Physicial loss of p2 is: 0.008036099374294281
# Physicial loss of s is: 0.002064949134364724
# Iteration is: 37090
# Physicial loss of p1 is: 0.0027481731958687305
# Physicial loss of p2 is: 0.007384088356047869
# Physicial loss of s is: 0.0020611132495105267
# Iteration is: 37100
# Physicial loss of p1 is: 0.0027267266996204853
# Physicial loss of p2 is: 0.006763152312487364
# Physicial loss of s is: 0.0020677715074270964
# Iteration is: 37110
# Physicial loss of p1 is: 0.003125435672700405
# Physicial loss of p2 is: 0.02471218630671501
# Physicial loss of s is: 0.002081778831779957
# Iteration is: 37120
# Physicial loss of p1 is: 0.0029056118801236153
# Physicial loss of p2 is: 0.013840926811099052
# Physicial loss of s is: 0.0021416584495455027
# Iteration is: 37130
# Physicial loss of p1 is: 0.0029145607259124517
# Physicial loss of p2 is: 0.013383390381932259
# Physicial loss of s is: 0.002034073229879141
# Iteration is: 37140
# Physicial loss of p1 is: 0.0026358591858297586
# Physicial loss of p2 is: 0.002605317858979106
# Physicial loss of s is: 0.0020526188891381025
# Iteration is: 37150
# Physicial loss of p1 is: 0.002722552279010415
# Physicial loss of p2 is: 0.0068311323411762714
# Physicial loss of s is: 0.0020802731160074472
# Iteration is: 37160
# Physicial loss of p1 is: 0.0032678882125765085
# Physicial loss of p2 is: 0.02960759960114956
# Physicial loss of s is: 0.0021442279685288668
# Iteration is: 37170
# Physicial loss of p1 is: 0.0026330160908401012
# Physicial loss of p2 is: 0.003736349754035473
# Physicial loss of s is: 0.002157662296667695
# Iteration is: 37180
# Physicial loss of p1 is: 0.0028363533783704042
# Physicial loss of p2 is: 0.01019902154803276
# Physicial loss of s is: 0.0020474272314459085
# Iteration is: 37190
# Physicial loss of p1 is: 0.0026770783588290215
# Physicial loss of p2 is: 0.004470780026167631
# Physicial loss of s is: 0.002039454411715269
# Iteration is: 37200
# Physicial loss of p1 is: 0.0026970314793288708
# Physicial loss of p2 is: 0.00733437342569232
# Physicial loss of s is: 0.0022097546607255936
# Iteration is: 37210
# Physicial loss of p1 is: 0.0038805874064564705
# Physicial loss of p2 is: 0.05577965825796127
# Physicial loss of s is: 0.0020539050456136465
# Iteration is: 37220
# Physicial loss of p1 is: 0.002862628549337387
# Physicial loss of p2 is: 0.008862358517944813
# Physicial loss of s is: 0.002463627839460969
# Iteration is: 37230
# Physicial loss of p1 is: 0.002602022374048829
# Physicial loss of p2 is: 0.0027362494729459286
# Physicial loss of s is: 0.00234807631932199
# Iteration is: 37240
# Physicial loss of p1 is: 0.002732824767008424
# Physicial loss of p2 is: 0.005206294823437929
# Physicial loss of s is: 0.0022774082608520985
# Iteration is: 37250
# Physicial loss of p1 is: 0.0025615431368350983
# Physicial loss of p2 is: 0.0025696149095892906
# Physicial loss of s is: 0.002239495748654008
# Iteration is: 37260
# Physicial loss of p1 is: 0.002580835949629545
# Physicial loss of p2 is: 0.003063009586185217
# Physicial loss of s is: 0.0020395582541823387
# Iteration is: 37270
# Physicial loss of p1 is: 0.004769740626215935
# Physicial loss of p2 is: 0.09194076806306839
# Physicial loss of s is: 0.002418474992737174
# Iteration is: 37280
# Physicial loss of p1 is: 0.0037934482097625732
# Physicial loss of p2 is: 0.04899614676833153
# Physicial loss of s is: 0.002540197689086199
# Iteration is: 37290
# Physicial loss of p1 is: 0.0030945544131100178
# Physicial loss of p2 is: 0.01741705648601055
# Physicial loss of s is: 0.0024590897373855114
# Iteration is: 37300
# Physicial loss of p1 is: 0.0026737393345683813
# Physicial loss of p2 is: 0.0059964656829833984
# Physicial loss of s is: 0.0021283093374222517
# Iteration is: 37310
# Physicial loss of p1 is: 0.0026258728466928005
# Physicial loss of p2 is: 0.005156319122761488
# Physicial loss of s is: 0.002488714177161455
# Iteration is: 37320
# Physicial loss of p1 is: 0.0026020260993391275
# Physicial loss of p2 is: 0.0037729362957179546
# Physicial loss of s is: 0.0020548657048493624
# Iteration is: 37330
# Physicial loss of p1 is: 0.0026310780085623264
# Physicial loss of p2 is: 0.005188249051570892
# Physicial loss of s is: 0.0020604548044502735
# Iteration is: 37340
# Physicial loss of p1 is: 0.002750308718532324
# Physicial loss of p2 is: 0.010650056414306164
# Physicial loss of s is: 0.0021224443335086107
# Iteration is: 37350
# Physicial loss of p1 is: 0.0026157177053391933
# Physicial loss of p2 is: 0.003961008507758379
# Physicial loss of s is: 0.002040624851360917
# Iteration is: 37360
# Physicial loss of p1 is: 0.002604043111205101
# Physicial loss of p2 is: 0.003945944830775261
# Physicial loss of s is: 0.002034582430496812
# Iteration is: 37370
# Physicial loss of p1 is: 0.002751218853518367
# Physicial loss of p2 is: 0.011243203654885292
# Physicial loss of s is: 0.0020509373862296343
# Iteration is: 37380
# Physicial loss of p1 is: 0.0032390961423516273
# Physicial loss of p2 is: 0.03008863888680935
# Physicial loss of s is: 0.0020574466325342655
# Iteration is: 37390
# Physicial loss of p1 is: 0.0026627921033650637
# Physicial loss of p2 is: 0.00774568784981966
# Physicial loss of s is: 0.002117794705554843
# Iteration is: 37400
# Physicial loss of p1 is: 0.002684215549379587
# Physicial loss of p2 is: 0.004795792978256941
# Physicial loss of s is: 0.0021581833716481924
# Iteration is: 37410
# Physicial loss of p1 is: 0.002620489802211523
# Physicial loss of p2 is: 0.0040629771538078785
# Physicial loss of s is: 0.0020260452292859554
# Iteration is: 37420
# Physicial loss of p1 is: 0.0028604173567146063
# Physicial loss of p2 is: 0.016410967335104942
# Physicial loss of s is: 0.002078260527923703
# Iteration is: 37430
# Physicial loss of p1 is: 0.0031903607305139303
# Physicial loss of p2 is: 0.02808954380452633
# Physicial loss of s is: 0.002004166366532445
# Iteration is: 37440
# Physicial loss of p1 is: 0.002853013575077057
# Physicial loss of p2 is: 0.01581822894513607
# Physicial loss of s is: 0.002079669153317809
# Iteration is: 37450
# Physicial loss of p1 is: 0.002619803650304675
# Physicial loss of p2 is: 0.0030206702649593353
# Physicial loss of s is: 0.0020401643123477697
# Iteration is: 37460
# Physicial loss of p1 is: 0.002704686252400279
# Physicial loss of p2 is: 0.008197958581149578
# Physicial loss of s is: 0.002012586919590831
# Iteration is: 37470
# Physicial loss of p1 is: 0.0025799048598855734
# Physicial loss of p2 is: 0.004110555164515972
# Physicial loss of s is: 0.0020205334294587374
# Iteration is: 37480
# Physicial loss of p1 is: 0.002719585783779621
# Physicial loss of p2 is: 0.011982756666839123
# Physicial loss of s is: 0.002326255664229393
# Iteration is: 37490
# Physicial loss of p1 is: 0.0034962696954607964
# Physicial loss of p2 is: 0.04307868331670761
# Physicial loss of s is: 0.001979966415092349
# Iteration is: 37500
# Physicial loss of p1 is: 0.0029505728743970394
# Physicial loss of p2 is: 0.01681518740952015
# Physicial loss of s is: 0.002078682417050004
# Iteration is: 37510
# Physicial loss of p1 is: 0.002593253506347537
# Physicial loss of p2 is: 0.003281485754996538
# Physicial loss of s is: 0.0020574862137436867
# Iteration is: 37520
# Physicial loss of p1 is: 0.0026444855611771345
# Physicial loss of p2 is: 0.005096192006021738
# Physicial loss of s is: 0.0020288887899369
# Iteration is: 37530
# Physicial loss of p1 is: 0.0025339126586914062
# Physicial loss of p2 is: 0.0026245589833706617
# Physicial loss of s is: 0.0020038920920342207
# Iteration is: 37540
# Physicial loss of p1 is: 0.0025162571109831333
# Physicial loss of p2 is: 0.0025534469168633223
# Physicial loss of s is: 0.002000219887122512
# Iteration is: 37550
# Physicial loss of p1 is: 0.0024940012954175472
# Physicial loss of p2 is: 0.002633766271173954
# Physicial loss of s is: 0.0020042257383465767
# Iteration is: 37560
# Physicial loss of p1 is: 0.005820665508508682
# Physicial loss of p2 is: 0.13646762073040009
# Physicial loss of s is: 0.002132242079824209
# Iteration is: 37570
# Physicial loss of p1 is: 0.004984172992408276
# Physicial loss of p2 is: 0.11726708710193634
# Physicial loss of s is: 0.0026014489121735096
# Iteration is: 37580
# Physicial loss of p1 is: 0.0028699443209916353
# Physicial loss of p2 is: 0.0033739875070750713
# Physicial loss of s is: 0.00234040105715394
# Iteration is: 37590
# Physicial loss of p1 is: 0.0027648364193737507
# Physicial loss of p2 is: 0.00637891935184598
# Physicial loss of s is: 0.0024230710696429014
# Iteration is: 37600
# Physicial loss of p1 is: 0.00276871002279222
# Physicial loss of p2 is: 0.0068189408630132675
# Physicial loss of s is: 0.0020611570216715336
# Iteration is: 37610
# Physicial loss of p1 is: 0.002677559619769454
# Physicial loss of p2 is: 0.005189389921724796
# Physicial loss of s is: 0.002040955238044262
# Iteration is: 37620
# Physicial loss of p1 is: 0.0025929303374141455
# Physicial loss of p2 is: 0.002637454541400075
# Physicial loss of s is: 0.002109178574755788
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 6
#       4 while it <= Nmax:
#       5     if it<10**5:
# ----> 6         loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#       7     else:
#       8         loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1601, in ConcreteFunction.__call__(self, *args, **kwargs)
#    1551 def __call__(self, *args, **kwargs):
#    1552   """Executes the wrapped function.
#    1553
#    1554   ConcreteFunctions have two signatures:
#    (...)
#    1599     TypeError: If the arguments do not match the function's signature.
#    1600   """
# -> 1601   return self._call_impl(args, kwargs)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1610, in ConcreteFunction._call_impl(self, args, kwargs, cancellation_manager)
#    1608 if self._function_spec is not None:
#    1609   try:
# -> 1610     return self._call_with_structured_signature(args, kwargs,
#    1611                                                 cancellation_manager)
#    1612   except TypeError as structured_err:
#    1613     try:
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1691, in ConcreteFunction._call_with_structured_signature(self, args, kwargs, cancellation_manager)
#    1689 self._structured_signature_check_unexpected_args(args, kwargs)
#    1690 self._structured_signature_check_arg_types(args, kwargs)
# -> 1691 return self._call_flat(
#    1692     filtered_flat_args,
#    1693     captured_inputs=self.captured_inputs,
#    1694     cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip1_list = [loss_fisp1[i].numpy() for i in range(0,Nmax)]
loss_phip2_list = [loss_fisp2[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(ep, np.asarray(loss_data_list), 'b-', linewidth = 2, alpha=0.6, label = 'Data')  
plt.semilogy(ep, np.asarray(loss_phip1_list), 'r-', linewidth = 2, alpha=0.6, label = '$\phi_p1$') 
plt.semilogy(ep, np.asarray(loss_phip2_list), 'y-', linewidth = 2, alpha=0.6, label = '$\phi_p2$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\phi_s$')       


plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
lnv[0], tf.exp(lnv[0]), lnv[1], tf.exp(lnv[1]), lnv[2], tf.exp(lnv[2])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([5.837798], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([343.02322], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([-3.3465362], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.03520609], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([3.735983], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([41.92922], dtype=float32)>)

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp1=u_pred[:,0:1]
lnp2=u_pred[:,1:2]
lns=u_pred[:,2:3]

p1=tf.exp(lnp1)
p2=tf.exp(lnp2)
s=tf.exp(lns)


phi_s = tf.exp(predict(s, W_phi, b_phi))
phi_t = tf.exp(predict(s, W_a, b_a))



m=tf.exp(lnv[0:1])
l1=tf.exp(lnv[1:2])
l2=tf.exp(lnv[2:3])



phi_s=-np.array((p1+p2)*s*m)

# %%
X_star_tf.shape, p1.shape
# Out:
# (TensorShape([6498, 3]), TensorShape([6498, 1]))

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],(p1+p2)[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

k=3
# Seleccionar el color correspondiente de la paleta
color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
for i in range(j):
    # Aquí puedes pasar el color seleccionado en cada iteración
    # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
    plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p1[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], linestyle=':',  color=color, label='Prediction P')
    plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)],   color=color, label='Prediction P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p1[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], linestyle=':',  color=color, label='Prediction P')
        plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)],   color=color, label='Prediction P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],s[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')



plt.xlabel('t (ms)')
plt.ylabel('S')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
# L_exp=len(P_exp[:,1])
# colors = plt.cm.tab10.colors

# for k, j in enumerate(n):
#     # Seleccionar el color correspondiente de la paleta
#     color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
#     for i in range(j):
#         # Aquí puedes pasar el color seleccionado en cada iteración
#         # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
#         plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,2],l2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, label='Prediction P')



# plt.xlabel('A')
# plt.ylabel('death rate')
# # plt.yscale('log')

# # plt.legend()

# # plt.ylabel('P')
# # plt.savefig('figures/P_phi.pdf')
# plt.show()

# %%
# l1

# %%
# plt.scatter(p, phi, s=3, label='Prediction')
plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
# plt.scatter(p, phi_s, s=3, label='Prediction')

plt.scatter(s, phi_t, s=3, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
n
# Out:
# array([5, 6, 5, 3])

# %%
k=3
p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]
# Out:
# <tf.Tensor: shape=(3, 1), dtype=float32, numpy=
# array([[0.00273348],
#        [0.00274091],
#        [0.00275076]], dtype=float32)>

# %%
p2[::L_exp]
# Out:
# <tf.Tensor: shape=(19, 1), dtype=float32, numpy=
# array([[0.0620701 ],
#        [0.06206512],
#        [0.06211488],
#        [0.06209995],
#        [0.06211488],
#        [0.05956096],
#        [0.05965592],
#        [0.05960366],
#        [0.05963312],
#        [0.05958338],
#        [0.05957216],
#        [0.09388996],
#        [0.09383988],
#        [0.0939801 ],
#        [0.09391004],
#        [0.09396005],
#        [0.06223344],
#        [0.06231068],
#        [0.06241292]], dtype=float32)>

# %%
p1[::L_exp]
# Out:
# <tf.Tensor: shape=(19, 1), dtype=float32, numpy=
# array([[0.03031386],
#        [0.03031013],
#        [0.03034757],
#        [0.03033634],
#        [0.03034757],
#        [0.02803481],
#        [0.02830412],
#        [0.02815664],
#        [0.02824   ],
#        [0.02809892],
#        [0.02806688],
#        [0.00863694],
#        [0.00861963],
#        [0.0086682 ],
#        [0.00864388],
#        [0.00866124],
#        [0.00273348],
#        [0.00274091],
#        [0.00275076]], dtype=float32)>

# %%
Nt=1000

# A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
A_int=np.array([0, 1.25, 2.5, 3.75])

for k, a in enumerate(A_int):

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    P1_int=np.zeros(Nt)
    P2_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P1_int[0]=np.mean(p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions
    P2_int[0]=np.mean(p2[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l2=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        PHI_T=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_a, b_a))

        P1_int[i]=P1_int[i-1]+(P1_int[i-1]*PHI_S + PHI_T*P1_int[i-1] - P1_int[i-1]*l1)*dt
        P2_int[i]=P2_int[i-1]+(P2_int[i-1]*PHI_S - PHI_T*P1_int[i-1] - P2_int[i-1]*l2)*dt
        S_int[i]=S_int[i-1]-(P1_int[i-1]+P2_int[i-1])*S_int[i-1]*np.array(m)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P1_int,  linestyle='-', label=f'Numeric integration dP1dT {a}')
    plt.plot(T_int, P2_int,  linestyle=':', label=f'Numeric integration dP2dT {a}')
    # plt.plot(T_int, P1_int+P2_int,  linestyle='-', label=f'Numeric integration dPdT {a}')

    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim(0,1.5)
plt.show()
# Out:
# C:\Users\u256063\AppData\Local\Temp\ipykernel_23776\4023875042.py:33: RuntimeWarning: overflow encountered in multiply
#   S_int[i]=S_int[i-1]-(P1_int[i-1]+P2_int[i-1])*S_int[i-1]*np.array(m)*dt
# C:\Users\u256063\AppData\Local\Temp\ipykernel_23776\4023875042.py:33: RuntimeWarning: invalid value encountered in subtract
#   S_int[i]=S_int[i-1]-(P1_int[i-1]+P2_int[i-1])*S_int[i-1]*np.array(m)*dt

# %%
Nt=1000

# A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
A_int=np.array([0, 1.25, 2.5, 3.75])

for k, a in enumerate(A_int):

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    P1_int=np.zeros(Nt)
    P2_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P1_int[0]=np.mean(p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions
    P2_int[0]=np.mean(p2[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l2=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        P1_int[i]=P1_int[i-1]+(P1_int[i-1]*PHI_S - P1_int[i-1]*l1)*dt
        P2_int[i]=P2_int[i-1]+(P2_int[i-1]*PHI_S - P2_int[i-1]*l2)*dt
        S_int[i]=S_int[i-1]-(P1_int[i-1]+P2_int[i-1])*S_int[i-1]*np.array(m)*dt
        T_int[i]=T_int[i-1]+dt

    # plt.plot(T_int, P1_int,  linestyle='-', label=f'Numeric integration dP1dT {a}')
    # plt.plot(T_int, P2_int,  linestyle=':', label=f'Numeric integration dP2dT {a}')
    plt.plot(T_int, P1_int+P2_int,  linestyle='-', label=f'Numeric integration dPdT {a}')

    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim(0,1.5)
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors
Nt=1000

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    # P_int[0]=np.array(p[0]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI_S - P_int[i-1]*l)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    # plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
# plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors
Nt=1000

for a in A:

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P_int[0]=np.mean(P0) #Initial conditions
    # P_int[0]=np.array(p[0]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(PSL , W_phi, b_phi))
        P_int[i]=P_int[i-1]+(P_int[i-1]*PHI_S - P_int[i-1]*l)*dt
        S_int[i]=S_int[i-1]-P_int[i-1]*S_int[i-1]*np.array(m)*dt
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P_int,  linestyle='-', label=f'Numeric integration dPdT {a}')
    # plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
# plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %% [markdown]
# # Symbolic Regresion

# %%
c=0
d=-1
plt.scatter( p[c:d], np.exp(phi[c:d]), s=2, label='Prediction P')
plt.scatter( s[c:d], np.exp(phi[c:d]), s=2, label='Prediction S')
# plt.plot( a[c:d], phi_p[c:d], label='Prediction S')


plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
X_star_tf[c:d][0], X_star_tf[c:d][-1]
# Out:
# (<tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.    , 0.0938], dtype=float32)>,
#  <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.9970674, 0.0923   ], dtype=float32)>)

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')




plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')


plt.vlines(X_star_tf[c:d][:,0][0],0,1.2, color='red', linestyle=':')
plt.vlines(X_star_tf[c:d][:,0][-1],0,1.2, color='red', linestyle=':')


plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
model = PySRRegressor(
    niterations=200,
    binary_operators=["+", "*", "inv(x, y) = x/(x + y)"],
    # binary_operators=["+", "*", "inv(x, y) = x/(x + y)", "^"],

    # unary_operators=[ "exp"],
    # unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={
            "inv": lambda x, y: x/(x+y),
        },
    # extra_sympy_mappings={"inv": lambda x: 1/x},
    constraints={"exp": 3, 'inv': (1, 1)},
    # complexity_of_operators={"/": 2},
    parsimony=0.00000001,
    # denoise=True,
    # complexity_of_variables=2,
    # complexity_of_constants=2,
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    random_state=42,   # Fija la semilla
    select_k_features=1,
    maxsize=40,
)

# %%
# p1s=tf.concat([p1[c:d], s[c:d]], axis=1)

min_cols_phi= tf.math.reduce_min(phi[c:d], axis=0)
max_cols_phi= tf.math.reduce_max(phi[c:d], axis=0)

phi_scaled = (phi[c:d]-min_cols_phi)/(max_cols_phi-min_cols_phi)
PS_tf=tf.concat([p[c:d], s[c:d]],1)

model.fit( PS_tf,phi_scaled)
print(model)
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Using features ['x1']
# [ Info: Started!
# Expressions evaluated per second: 2.780e+04
# Head worker occupation: 22.9%
# Progress: 75 / 3000 total iterations (2.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           3.955e-02  5.314e+00  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.478e-02  2.859e-02  y = ((inv(x1, 0.10223) * -0.30208) + (0.15902 + x1)) + 0.09950...
#                                   7
# 13          2.370e-02  2.218e-02  y = 0.099507 + ((0.18993 + x1) + ((-0.30208 * 1.3452) * inv(x1...
#                                   , 0.10223)))
# 17          2.215e-02  1.688e-02  y = 0.18608 + ((x1 + (((-1.0119 * x1) * x1) * (x1 * x1))) * (x...
#                                   1 + x1))
# 19          1.947e-02  6.449e-02  y = 0.25455 + (((((-0.85623 * x1) * x1) * x1) + x1) * ((x1 + 0...
#                                   .14507) + (-0.30395 + x1)))
# 21          1.793e-02  4.126e-02  y = 0.25004 + (((x1 + (((x1 + x1) + -0.66889) * 2.4278)) * (-0...
#                                   .39674 + inv(0.85065, x1))) * (x1 + x1))
# 25          1.672e-02  1.743e-02  y = (x1 * ((((x1 + x1) + -0.080258) * ((inv(x1, x1) + ((x1 * -...
#                                   0.92223) * (x1 * x1))) + 0.95982)) + -0.82044)) + 0.2704
# 27          1.306e-02  1.236e-01  y = ((((inv(1.4462, 2.2953) + ((x1 * (0.16588 + x1)) * -0.8808...
#                                   2)) + 0.62528) * ((x1 + ((2.9017 * x1) + -1.2808)) + x1)) * x1...
#                                   ) + 0.26349
# 31          1.115e-02  3.957e-02  y = (((((1.9312 + ((x1 * (0.56703 + x1)) * -1.3051)) + -0.1458...
#                                   1) * ((x1 + ((1.3124 * x1) + -1.0317)) + x1)) + ((-0.59911 + x...
#                                   1) + 0.079291)) * x1) + 0.29135
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.800e+04
# Head worker occupation: 19.6%
# Progress: 172 / 3000 total iterations (5.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 15          1.863e-02  3.620e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.855e-02  2.179e-03  y = 0.2407 + (((x1 * (((x1 * -0.96546) * x1) * x1)) + x1) * (x...
#                                   1 + x1))
# 19          1.180e-02  2.260e-01  y = ((((x1 + -0.9667) * 3.1557) * ((x1 * -2.4664) + inv(0.8407...
#                                   1, x1))) * x1) + (0.19285 + 0.10635)
# 21          1.096e-02  3.683e-02  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.19285 + 0.10635)
# 23          1.063e-02  1.558e-02  y = ((x1 * ((x1 + (x1 + (x1 + (x1 + -1.3504)))) * ((-1.5055 * ...
#                                   (x1 * 1.2765)) + 1.9003))) + 0.242) * 1.2304
# 29          1.061e-02  2.597e-04  y = (((((-1.2701 + (x1 + (inv(-0.22109, 1.2369) + x1))) + ((-0...
#                                   .23128 + x1) + x1)) + x1) * (((x1 * 0.97839) * -1.9394) + 1.87...
#                                   65)) * x1) + 0.30126
# 31          1.056e-02  2.149e-03  y = (1.0965 * ((((((x1 * x1) * -0.47626) + x1) + ((x1 + -0.415...
#                                   78) * (1.5945 + inv(-0.6427, 0.35635)))) * ((x1 * -1.9534) + 1...
#                                   .9355)) * x1)) + (0.27317 + 0.029663)
# 37          1.054e-02  4.362e-04  y = 0.29991 + (x1 * ((((((((x1 + x1) + -0.84768) + x1) + x1) +...
#                                    (((-0.041061 * x1) * x1) + ((-1.7349 + -1.0641) + x1))) + -1....
#                                   3884) + inv(0.15367, x1)) * ((x1 * -2.079) + 0.72708)))
# 39          1.003e-02  2.451e-02  y = (x1 * ((((x1 * (-1.9266 * 0.87892)) * x1) + 1.8833) * (((1...
#                                   .8833 + (x1 * ((-1.5986 * x1) + -0.2367))) * (((x1 + -1.3044) ...
#                                   + (x1 + 0.15884)) + (x1 + inv(0.047572, x1)))) + 0.043323))) +...
#                                    0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.780e+04
# Head worker occupation: 15.9%
# Progress: 250 / 3000 total iterations (8.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.623e-02  4.856e-03  y = (0.25948 * inv(0.25948, x1)) + (x1 * 0.74527)
# 11          2.153e-02  9.883e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          2.136e-02  3.898e-03  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * (x1 * 1.0785)...
#                                   )
# 15          1.863e-02  6.850e-02  y = ((x1 * (((-1.7881 * (x1 * x1)) * x1) + 1.8945)) * x1) + 0....
#                                   23612
# 17          1.245e-02  2.014e-01  y = (0.19285 + 0.086001) + ((((x1 + -0.9667) * 3.1557) * (0.90...
#                                   662 + (-2.7585 * x1))) * x1)
# 19          1.140e-02  4.434e-02  y = (((-0.10278 + (3.1557 * (x1 + -0.9667))) * ((x1 * -2.4664)...
#                                    + 0.84071)) * x1) + (0.10635 + 0.19285)
# 21          1.092e-02  2.120e-02  y = (((-0.10278 + ((-0.9667 + x1) * (3.1557 + x1))) * ((x1 * -...
#                                   2.4664) + 0.84071)) * x1) + (0.095392 + 0.19285)
# 23          1.062e-02  1.392e-02  y = ((x1 + -0.081559) * (((-2.2871 * x1) + 2.3214) * ((x1 * 2....
#                                   2758) + ((-1.1269 + x1) + (x1 + 0.11778))))) + 0.11195
# 27          1.045e-02  4.143e-03  y = (((-0.10278 + ((x1 + -0.9667) * (3.1557 + ((0.84071 + inv(...
#                                   x1, -1.3214)) + x1)))) * ((x1 * -2.4664) + 0.84071)) * x1) + (...
#                                   0.19285 + 0.10635)
# 29          1.041e-02  1.637e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + -0.33894) ...
#                                   * ((x1 + inv(0.047572, x1)) + (x1 + -1.3044))) + x1) + (x1 * 1...
#                                   .1842)))) + 0.30147
# 31          1.008e-02  1.639e-02  y = (x1 * (((-1.9266 * x1) + 1.8833) * (((1.8833 + 0.077362) *...
#                                    ((x1 + (inv(0.047572, x1) + -0.064585)) + ((x1 + x1) + -1.304...
#                                   4))) + (0.30147 * 1.1842)))) + 0.30147
# 37          9.843e-03  3.925e-03  y = (x1 * (((x1 * -1.9266) + 1.8833) * ((((1.8833 + inv(0.0773...
#                                   62, x1)) * ((x1 + inv(0.047572, x1)) + (inv(0.043323, 0.15884)...
#                                    + (x1 + -1.3044)))) + x1) + (x1 * inv(1.1842, 0.91425))))) + ...
#                                   0.30147
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.700e+04
# Head worker occupation: 14.5%
# Progress: 329 / 3000 total iterations (10.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.617e-02  1.432e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.4051)) *...
#                                    x1)
# 15          1.224e-02  1.390e-01  y = 0.28154 + (x1 * ((x1 + -0.99589) * (((-5.2648 + -1.9302) *...
#                                    x1) + 2.2863)))
# 17          1.167e-02  2.394e-02  y = 0.28154 + (x1 * ((x1 + -0.99589) * ((((-5.2648 + -1.1021) ...
#                                   + -1.2315) * x1) + 2.2863)))
# 19          1.070e-02  4.356e-02  y = 0.30839 + (x1 * (((1.8937 * (x1 + (-0.8686 + x1))) + x1) *...
#                                    (1.9877 + (x1 * -2.0051))))
# 23          1.061e-02  2.016e-03  y = 0.30131 + ((x1 * 1.6833) * (((-1.9277 * x1) + 1.9069) * ((...
#                                   0.54582 + (((0.51804 + -1.3234) + x1) * 1.9209)) + x1)))
# 27          9.929e-03  1.662e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + x1)))
# 29          9.905e-03  1.218e-03  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (x1 * -1.9302)) ...
#                                   * ((((x1 * x1) + (-0.83605 + x1)) * ((1.8246 + x1) * inv(x1, 0...
#                                   .31499))) + x1)))
# 31          8.648e-03  6.782e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1....
#                                   9302)) * (((x1 + (-0.83605 + x1)) * (1.8246 * inv(x1, 0.31499)...
#                                   )) + (0.20664 * inv(x1, x1)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.150e+04
# Head worker occupation: 14.2%
# Progress: 426 / 3000 total iterations (14.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.595e-02  1.594e+01  y = x1
# 3           3.955e-02  3.262e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.424e-02  4.430e-02  y = (inv(0.06044, x1) * 0.41807) + (-0.11859 + x1)
# 11          2.153e-02  5.939e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.052e-02  2.579e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * (((-4.6...
#                                   638 + (x1 * (x1 + -0.67368))) * x1) + 1.6117)))
# 25          1.050e-02  9.160e-04  y = (0.21074 + (x1 * ((-1.0022 + x1) * (2.4464 + ((-2.5247 + (...
#                                   (-5.2844 + (x1 * (x1 + x1))) * 0.9772)) * x1))))) * 1.4173
# 27          9.528e-03  4.841e-02  y = 0.29387 + (inv(x1, 0.059225) * ((1.9019 + (-1.9302 * x1)) ...
#                                   * (((x1 + (inv(-0.83605, 1.6945) + x1)) * (1.9019 * inv(x1, 0....
#                                   31499))) + x1)))
# 29          8.448e-03  6.015e-02  y = (inv(x1, 0.059225) * ((1.9019 + ((x1 * x1) * -1.9302)) * (...
#                                   ((1.8246 * inv(x1, 0.20664)) * (x1 + (-0.83605 + inv(x1, 0.791...
#                                   32)))) + 0.20664))) + 0.29387
# 33          5.125e-03  1.249e-01  y = ((inv(x1, 0.0098097) * 0.87837) * ((1.9533 + ((x1 * x1) * ...
#                                   -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2292)) * (x1 + (inv(x...
#                                   1, 0.7733) + -0.77502))) + 0.2292))) + 0.2292
# 35          4.691e-03  4.421e-02  y = ((inv(x1, 0.0098097) * 0.87837) * (((x1 * (-1.9397 * x1)) ...
#                                   + 1.8885) * (((((1.8202 + x1) + 0.20894) * inv(x1, 0.20894)) *...
#                                    ((-0.77502 + inv(x1, 0.7733)) + x1)) + 0.25046))) + 0.2292
# 37          3.741e-03  1.132e-01  y = (((inv(x1, 0.0098097) * 0.87837) + (-0.22058 * x1)) * ((1....
#                                   9533 + ((x1 * x1) * -1.9397)) * ((((1.9533 + x1) * inv(x1, 0.2...
#                                   292)) * (x1 + (inv(x1, 0.7733) + -0.77502))) + 0.2292))) + 0.2...
#                                   292
# 39          3.216e-03  7.559e-02  y = (((inv(x1, 0.0041438) * 0.87769) + (-0.22025 * (x1 + -0.15...
#                                   79))) * ((1.9537 + ((x1 * x1) * -1.9389)) * (0.22256 + (((1.95...
#                                   4 + x1) * inv(x1, 0.21981)) * (x1 + (inv(x1, 0.77348) + -0.778...
#                                   73)))))) + 0.19528
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.950e+04
# Head worker occupation: 14.8%
# Progress: 535 / 3000 total iterations (17.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  3.986e-03  y = 0.3052 + (x1 * (((-1.9641 * 1.0115) + (x1 + x1)) * ((-4.66...
#                                   38 * x1) + 1.6117)))
# 21          1.057e-02  1.804e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.367e-03  y = 0.3052 + (x1 * ((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 ...
#                                   + ((x1 * 1.1883) * x1)) * x1) + 1.6117)))
# 25          2.667e-03  6.852e-01  y = (((0.26613 + ((inv(x1, 0.19528) * 1.9537) * (x1 + (-0.7787...
#                                   3 + x1)))) * (1.9537 + (x1 * -1.9389))) * inv(x1, 0.0041438)) ...
#                                   + 0.19528
# 27          2.108e-03  1.176e-01  y = 0.19528 + (((0.26613 + ((x1 + (x1 + -0.77873)) * (inv(x1, ...
#                                   0.19528) * 1.9537))) * (1.9537 + ((0.97698 * x1) * -1.9389))) ...
#                                   * inv(x1, 0.0041438))
# 29          1.636e-03  1.269e-01  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 37          1.339e-03  1.250e-03  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.100e+04
# Head worker occupation: 15.0%
# Progress: 639 / 3000 total iterations (21.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54756)) + 0.2524
# 9           2.392e-02  5.110e-02  y = 0.28934 + (inv(x1, 0.068134) * (x1 + -0.27297))
# 11          2.153e-02  5.259e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.636e-03  9.570e-02  y = (((((x1 + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x...
#                                   1)) + 0.41962) * (0.72677 * (1.9752 + (-1.9035 * x1)))) * inv(...
#                                   x1, 0.0056867)) + 0.15887
# 33          1.345e-03  4.883e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.341e-03  1.548e-03  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + (x1 * 0.93073)) +...
#                                    inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.158...
#                                   87
# 37          1.339e-03  9.526e-04  y = ((0.017575 * inv(1.1059, x1)) + (((0.72677 * (1.9752 + (-1...
#                                   .9035 * x1))) * ((((x1 + -0.82737) + x1) * ((inv(x1, 0.060135)...
#                                    + x1) + inv(x1, 0.46748))) + 0.41962)) * inv(x1, 0.0056867)))...
#                                    + 0.15887
# 39          1.215e-03  4.855e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * (inv(1.2861, 0.84669) + -0.15182)))) * ((...
#                                   x1 + -0.87651) + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1...
#                                   , 0.0056867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 731 / 3000 total iterations (24.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.767e-02  1.594e+01  y = 0.41481
# 3           3.955e-02  1.885e-01  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.073e-02  2.038e-01  y = (((-1.9641 + (x1 + x1)) * ((x1 * -4.6638) + 1.6117)) * x1)...
#                                    + 0.3052
# 17          1.065e-02  4.030e-03  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + 0.3052
# 19          1.064e-02  4.041e-04  y = (((-1.9641 + (x1 + (0.98495 * x1))) * (1.6117 + (-4.6638 *...
#                                    x1))) * x1) + inv(0.3052, 0.70137)
# 21          1.057e-02  3.161e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          1.050e-02  3.413e-03  y = 0.3052 + (x1 * (((x1 + x1) + -1.9641) * (((((-4.6638 * inv...
#                                   (x1, 0.18751)) + x1) + -1.7912) * x1) + 1.6117)))
# 25          2.563e-03  7.051e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.981e-03  1.288e-01  y = 0.15887 + (inv(x1, 0.0056867) * (((-1.9035 * x1) + 1.9355)...
#                                    * (0.41962 + ((inv(x1, 0.060135) + x1) * (x1 + ((x1 + -0.8765...
#                                   1) * 1.0482))))))
# 29          1.631e-03  9.701e-02  y = 0.15887 + (((0.75672 * (1.9752 + (-1.9035 * x1))) * (((x1 ...
#                                   + (x1 + -0.82737)) * ((inv(x1, 0.060135) + x1) + x1)) + 0.4196...
#                                   2)) * inv(x1, 0.0056867))
# 31          1.403e-03  7.550e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.294e-03  1.938e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * ((((x1 + (inv(x1...
#                                   , 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651) ...
#                                   + x1)) + 0.41962) * 1.1182)) * inv(x1, 0.0056867)) + 0.15887
# 37          1.177e-03  4.740e-02  y = (((((-1.9035 * x1) + 1.9752) * 0.72677) * (((((x1 + (inv(x...
#                                   1, 0.060135) + (x1 * inv(1.2861, 1.0418)))) * ((x1 + -0.87651)...
#                                    + x1)) + 0.41962) * 1.0418) * 1.1182)) * inv(x1, 0.0056867)) ...
#                                   + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+04
# Head worker occupation: 14.3%
# Progress: 828 / 3000 total iterations (27.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.153e-02  4.885e-02  y = 0.2404 + ((x1 * ((x1 * -2.3216) + 2.6685)) * x1)
# 13          1.613e-02  1.443e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          8.340e-03  1.185e-01  y = ((((x1 * -1.9035) + 1.9752) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  6.129e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.491e-03  2.480e-01  y = ((((-1.9035 * x1) + 1.9752) * (((inv(x1, 0.060135) + x1) *...
#                                    ((-0.87651 + x1) + x1)) + inv(0.41962, 0.72301))) * inv(x1, 0...
#                                   .0056867)) + 0.15887
# 31          1.403e-03  1.520e-02  y = 0.18461 + (inv(x1, 0.0068143) * ((0.76767 * (1.9638 + (-1....
#                                   9201 * x1))) * (((x1 + (x1 + -0.853)) * ((inv(x1, 0.05348) + x...
#                                   1) + x1)) + inv(0.47709, 0.65812))))
# 33          1.345e-03  2.085e-02  y = (0.017575 + (((0.72677 * (1.9752 + (-1.9035 * x1))) * ((((...
#                                   x1 + -0.82737) + x1) * ((inv(x1, 0.060135) + x1) + inv(x1, 0.4...
#                                   6748))) + 0.41962)) * inv(x1, 0.0056867))) + 0.15887
# 35          1.191e-03  6.093e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((inv(x1, 1.4938) + inv(x1, 0.060135)) + x1) * ((-0.876...
#                                   51 + x1) + x1)) + 0.41962))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.173e-03  7.562e-03  y = ((((-1.9035 * x1) + 1.9752) * (((((inv(x1, 0.060135) + x1)...
#                                    + (inv(x1, 1.9457) * x1)) * ((-0.87651 + x1) + x1)) * inv(1.0...
#                                   821, 0.092927)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)...
#                                   ) + 0.15887
# 39          1.147e-03  1.132e-02  y = (((((-1.9035 * x1) + 1.9752) * (0.72677 * 1.0825)) * (1.11...
#                                   82 * ((((((inv(x1, 1.4938) * x1) + inv(x1, 0.060135)) * 1.0811...
#                                   ) + x1) * ((-0.87651 + x1) + x1)) + 0.41962))) * inv(x1, 0.005...
#                                   6867)) + 0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+04
# Head worker occupation: 14.7%
# Progress: 941 / 3000 total iterations (31.367%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          2.448e-03  3.101e-01  y = (((((x1 * x1) * -1.9035) + 1.9752) * (((x1 + (-0.99045 + x...
#                                   1)) * inv(x1, 0.060135)) + 0.41962)) * inv(x1, 0.0056867)) + 0...
#                                   .15887
# 27          1.309e-03  3.131e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.248e-03  2.389e-02  y = ((inv(x1, 0.0056867) + -0.012119) * (((((inv(x1, 0.060135)...
#                                    + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9...
#                                   752 + (-1.9035 * x1)))) + 0.15887
# 31          1.247e-03  2.635e-04  y = ((inv(x1, 0.0056867) + (-0.012119 * 1.1739)) * (((((inv(x1...
#                                   , 0.060135) + 0.045682) + x1) * ((x1 + -0.87651) + x1)) + 0.41...
#                                   962) * (1.9752 + (-1.9035 * x1)))) + 0.15887
# 35          1.162e-03  1.770e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.300e+04
# Head worker occupation: 15.3%
# Progress: 1029 / 3000 total iterations (34.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.240e-03  2.677e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * 0.89975)))) + 0.15887
# 31          1.214e-03  1.062e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.89975, 0.21942))))) + 0.15887
# 33          1.192e-03  9.391e-03  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.180e+04
# Head worker occupation: 15.1%
# Progress: 1119 / 3000 total iterations (37.300%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 21          1.057e-02  7.156e-04  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.740e-03  4.807e-01  y = (((((-1.8024 * x1) * x1) + 1.8824) * ((inv(x1, 0.065971) *...
#                                    (x1 + (x1 + -1.029))) + 0.39188)) * inv(x1, 0.0083457)) + 0.1...
#                                   8232
# 27          1.309e-03  1.425e-01  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.222e-03  3.409e-02  y = (((1.9752 + (-1.9035 * x1)) * (((((inv(x1, 0.060135) + x1)...
#                                    * ((x1 + -0.87651) + x1)) + 0.41962) + -0.04569) + 0.0067754)...
#                                   ) * inv(x1, 0.0056867)) + 0.15887
# 31          1.193e-03  1.213e-02  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.192e-03  5.541e-04  y = ((inv(x1, 0.0056867) * ((((((-0.75077 * (-0.46293 * x1)) +...
#                                    inv(x1, 0.060135)) + x1) * (x1 + (x1 + -0.87651))) + 0.41962)...
#                                    * ((-1.9035 * x1) + 1.9752))) + 0.15887) * 0.91387
# 35          1.162e-03  1.276e-02  y = ((((-1.9035 * x1) + 1.9752) * ((((inv(x1, 0.060135) + ((in...
#                                   v(x1, 0.58377) + -0.42413) * x1)) + x1) * ((-0.87651 + x1) + x...
#                                   1)) + inv(0.41962, 0.72301))) * inv(x1, 0.0056867)) + 0.15887
# 37          1.089e-03  3.212e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.920e+04
# Head worker occupation: 15.3%
# Progress: 1201 / 3000 total iterations (40.033%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.193e-03  1.789e-03  y = (inv(x1, 0.0056867) * ((1.9752 + (-1.9035 * x1)) * ((((inv...
#                                   (x1, 0.060135) + x1) * ((x1 + -0.87651) + x1)) + 0.41962) + (-...
#                                   0.04569 * inv(0.29458, x1))))) + 0.15887
# 33          1.175e-03  7.800e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962)...
#                                    + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.259e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# 37          1.089e-03  2.505e-02  y = ((((1.9752 + (-1.9243 * x1)) * (inv(0.72677, 0.43683) * 1....
#                                   3951)) * (((((inv(x1, 0.060135) * inv(1.3691, x1)) + x1) + x1)...
#                                    * ((-0.87651 + x1) + x1)) + 0.41962)) * inv(x1, 0.0056867)) +...
#                                    0.15887
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.650e+04
# Head worker occupation: 15.8%
# Progress: 1277 / 3000 total iterations (42.567%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.613e-02  1.332e-01  y = 0.28154 + (((-0.99589 + x1) * ((x1 * -5.2648) + 1.3696)) *...
#                                    x1)
# 15          1.062e-02  2.092e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          1.062e-02  2.831e-07  y = (x1 * (((x1 + x1) + (-1.9806 + (-0.00066981 * 0.30019))) *...
#                                    (1.5998 + (x1 * -4.6742)))) + 0.30019
# 21          1.057e-02  2.146e-03  y = (((-1.9641 + ((x1 * x1) + x1)) * (((-4.6638 + (x1 * x1)) *...
#                                    x1) + 1.6117)) * x1) + 0.3052
# 23          4.551e-03  4.213e-01  y = ((((x1 * -1.9173) + 2.2044) * (0.41962 + ((x1 + (-0.99045 ...
#                                   + x1)) * inv(x1, 0.060135)))) * inv(x1, 0.0056867)) + 0.15887
# 25          1.552e-03  5.380e-01  y = 0.16982 + (inv(x1, 0.0080999) * ((0.42 + ((inv(x1, 0.05110...
#                                   1) + x1) * (x1 + (-0.87657 + x1)))) * (1.9849 + (-1.9167 * x1)...
#                                   )))
# 27          1.309e-03  8.523e-02  y = (inv(x1, 0.0056867) * (((((inv(x1, 0.060135) + 0.045682) +...
#                                    x1) * ((x1 + -0.87651) + x1)) + 0.41962) * (1.9752 + (-1.9035...
#                                    * x1)))) + 0.15887
# 29          1.197e-03  4.444e-02  y = (inv(x1, 0.0056867) * ((((((inv(x1, 0.060135) + 0.045682) ...
#                                   + x1) * (x1 + (x1 + -0.87651))) + 0.41962) * 0.94971) * (1.975...
#                                   2 + (-1.9035 * x1)))) + 0.15887
# 31          1.176e-03  8.842e-03  y = (((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1) ...
#                                   * ((-0.87651 + x1) + (x1 + (0.15887 * 0.092764)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) + 0.15887
# 33          1.171e-03  2.279e-03  y = ((((1.9752 + (-1.9035 * x1)) * ((((inv(x1, 0.060135) + x1)...
#                                    * ((-0.87651 + x1) + (x1 + (0.15887 * 0.11004)))) + 0.41962) ...
#                                   + -0.04569)) * inv(x1, 0.0056867)) * 0.99874) + 0.15887
# 35          1.145e-03  1.106e-02  y = (inv(x1, 0.014572) * (((-1.8934 * x1) + 1.9195) * (0.74965...
#                                    + ((x1 + (-1.1155 + x1)) * (x1 + (inv(x1, 0.021711) * (1.0175...
#                                    + (x1 * x1)))))))) + (inv(0.6499, 2.7729) * 0.91268)
# ...
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.048e-03  4.028e-01  y = 0.16158 + ((inv(x1, 0.014288) + x1) * ((((-2.1275 * x1) * ...
#                                   x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ))))
# 27          9.974e-04  2.466e-02  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * ((((-2.12...
#                                   75 * x1) * x1) + 2.1916) * (0.71579 + ((-1.0184 + x1) * inv(x1...
#                                   , 0.016826)))))
# 29          9.888e-04  4.331e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.710e+04
# Head worker occupation: 16.4%
# Progress: 2823 / 3000 total iterations (94.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.803e-04  2.716e-03  y = 0.15984 + (((x1 + inv(x1, 0.014288)) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * (x1 * 0.98...
#                                   935)) + 2.1916) * (((x1 + -1.0184) * inv(x1, 0.016826)) + 0.71...
#                                   579)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.640e+04
# Head worker occupation: 16.6%
# Progress: 2906 / 3000 total iterations (96.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 23          2.345e-03  3.532e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  2.292e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.820e+04
# Head worker occupation: 16.3%
# Progress: 2999 / 3000 total iterations (99.967%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.684e-02  1.594e+01  y = 0.31079
# 3           3.955e-02  8.461e-02  y = 0.19077 + x1
# 5           2.797e-02  1.732e-01  y = (0.56075 * x1) + 0.24349
# 7           2.649e-02  2.721e-02  y = (x1 * inv(x1, 0.54793)) + 0.2524
# 9           2.374e-02  5.484e-02  y = (inv(x1, 0.080867) * (-0.328 + x1)) + 0.3052
# 11          2.106e-02  5.994e-02  y = (((-3.0716 * x1) + 3.3362) * (x1 * x1)) + 0.23874
# 13          1.502e-02  1.688e-01  y = (((-1.0817 + x1) * ((x1 * -4.708) + 1.2789)) * x1) + 0.273...
#                                   12
# 15          1.062e-02  1.736e-01  y = ((((-4.6742 * x1) + 1.5998) * (-1.9806 + (x1 + x1))) * x1)...
#                                    + 0.30019
# 19          9.632e-03  2.433e-02  y = 0.15984 + (inv(x1, 0.014288) * ((((inv(x1, 0.55679) + -1.0...
#                                   184) * inv(x1, 0.014288)) + 0.71579) * 2.1916))
# 21          9.452e-03  9.432e-03  y = (0.19018 + (inv(x1, 0.0097537) * (1.9599 * (0.62748 + ((in...
#                                   v(x1, 0.40694) + -1.0054) * inv(x1, 0.0212)))))) + -0.048795
# 23          2.345e-03  6.969e-01  y = (((inv(x1, 0.014288) + inv(x1, -1.4914)) + x1) * ((0.71579...
#                                    + (inv(x1, 0.016826) * (x1 + -1.0184))) * 2.1916)) + 0.15984
# 25          1.017e-03  4.180e-01  y = ((x1 + inv(x1, 0.014288)) * ((((-2.1275 * x1) * x1) + 2.20...
#                                   17) * (0.71579 + ((-1.0184 + x1) * inv(x1, 0.016826))))) + 0.1...
#                                   5984
# 27          9.925e-04  1.198e-02  y = 0.15984 + ((inv(x1, 0.014288) + (x1 * 1.094)) * ((((-2.127...
#                                   5 * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv(x1, 0.016826)...
#                                   ) + 0.71579)))
# 29          9.888e-04  1.834e-03  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + 0.014288) * x1) * x1) + 2.1916) * (((-1.0184 + x1) * inv...
#                                   (x1, 0.016826)) + 0.71579)))
# 31          9.882e-04  3.248e-04  y = 0.15984 + ((inv(x1, 0.014288) + (1.0623 * x1)) * (((((-2.1...
#                                   275 + (0.014288 * x1)) * x1) * x1) + 2.1916) * (((-1.0184 + x1...
#                                   ) * inv(x1, 0.016826)) + 0.71579)))
# 33          9.701e-04  9.250e-03  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * (x1 + -1.0184))) * x1)) + 2.1916) * (((-1.01...
#                                   84 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 35          9.688e-04  6.415e-04  y = 0.15984 + ((inv(x1, 0.014288) + x1) * (((x1 * ((-2.1275 + ...
#                                   ((x1 + -1.0184) * ((x1 + -1.0184) * 1.1219))) * x1)) + 2.1916)...
#                                    * (((-1.0184 + x1) * inv(x1, 0.016826)) + 0.71579)))
# 37          8.851e-04  4.520e-02  y = 0.15984 + (((inv(x1, 0.014288) + x1) + ((x1 * x1) * (-1.02...
#                                   65 * x1))) * ((((((-2.1275 + 0.16839) * x1) * x1) * x1) + 2.19...
#                                   16) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.016826)))))
# 39          8.802e-04  2.793e-03  y = 0.15984 + (((inv(x1, 0.014288) + x1) + (((x1 * x1) * -1.02...
#                                   65) * x1)) * (((((((-2.1275 + 0.16839) * x1) * 0.99061) * x1) ...
#                                   * x1) + 2.1916) * (0.71579 + ((x1 + -1.0184) * inv(x1, 0.01682...
#                                   6)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                           0.310787
# 	1         0.084607                                    0.19077079 + x1
# 	2         0.173234                      (0.5607476 * x1) + 0.24348809
# 	3         0.027205              (x1 * inv(x1, 0.5479253)) + 0.2523965
# 	4         0.054837  (inv(x1, 0.080867134) * (-0.32800326 + x1)) + ...
# 	5         0.059941  (((-3.07164 * x1) + 3.3362021) * (x1 * x1)) + ...
# 	6         0.168797  (((-1.0817221 + x1) * ((x1 * -4.7079844) + 1.2...
# 	7         0.173619  ((((-4.6741557 * x1) + 1.5998087) * (-1.980577...
# 	8         0.024327  0.15983854 + (inv(x1, 0.014288435) * ((((inv(x...
# 	9         0.009432  (0.19018486 + (inv(x1, 0.009753697) * (1.95994...
# 	10        0.696936  (((inv(x1, 0.014288435) + inv(x1, -1.4914056))...
# 	11  >>>>  0.417967  ((x1 + inv(x1, 0.014288435)) * ((((-2.1275125 ...
# 	12        0.011980  0.15983854 + ((inv(x1, 0.014288435) + (x1 * 1....
# 	13        0.001834  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	14        0.000325  0.15983854 + ((inv(x1, 0.014288435) + (1.06228...
# 	15        0.009251  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	16        0.000642  0.15983854 + ((inv(x1, 0.014288435) + x1) * ((...
# 	17        0.045198  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
# 	18        0.002793  0.15983854 + (((inv(x1, 0.014288435) + x1) + (...
#
# 	        loss  complexity
# 	0   0.046845           1
# 	1   0.039553           3
# 	2   0.027971           5
# 	3   0.026490           7
# 	4   0.023738           9
# 	5   0.021056          11
# 	6   0.015023          13
# 	7   0.010616          15
# 	8   0.009632          19
# 	9   0.009452          21
# 	10  0.002345          23
# 	11  0.001017          25
# 	12  0.000992          27
# 	13  0.000989          29
# 	14  0.000988          31
# 	15  0.000970          33
# 	16  0.000969          35
# 	17  0.000885          37
# 	18  0.000880          39
# ]

# %%
# Extraer las métricas de las ecuaciones
equations_df = model.equations_
# Obtener la complejidad y la puntuación (score) de cada ecuación
complejidades = equations_df['complexity']
errores = equations_df['loss']  # Por ejemplo, error MSE o cualquier métrica utilizada

# Crear el gráfico de dispersión
plt.scatter(complejidades, errores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, errores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')

# Añadir etiquetas y título
plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Loss (R²)')
plt.title('Frontera de Pareto: Error vs Complejidad')

# Mostrar gráfico
plt.yscale('log')
plt.show()

# %%
# Extraer complejidad y score
complejidades = equations_df['complexity']
scores = equations_df['score']

# Graficar score vs complejidad
plt.scatter(complejidades, scores)

# Añadir etiquetas de índice en cada punto
for i, (x, y) in enumerate(zip(complejidades, scores)):
    plt.annotate(i, (x, y), textcoords="offset points", xytext=(5,5), ha='center')


plt.xlabel('Complejidad de la ecuación')
plt.ylabel('Score')
plt.title('Score vs Complejidad')
plt.show()

# %%
chose=17
expr=model.sympy(chose)*(max_cols_phi-min_cols_phi)+min_cols_phi
expr
# Out:
# 21.7206382751465*((x1/(x1 + 0.016826037))*(x1 - 1.0184498) + 0.7157937)*(x1*x1*x1*(-2.1275125 + 0.16839427) + 2.1915646)*(x1*x1*(-1.0264988)*x1 + x1 + x1/(x1 + 0.014288435)) + 4.61513426687202

# %%
sympy.expand(expr)
# Out:
# 43.6809097560371*x1**8/(x1 + 0.016826037) - 44.4868138048541*x1**7/(x1 + 0.016826037) + 31.2665200136399*x1**6 - 42.5532984120752*x1**6/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 42.5532984120752*x1**6/(x1 + 0.016826037) + 43.3383982571183*x1**5/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 5.52518437470967*x1**5/(x1 + 0.016826037) - 30.4593829175835*x1**4 + 49.7651059586687*x1**4/(x1 + 0.016826037) - 30.4593829175835*x1**4/(x1 + 0.014288435) - 34.9762446072919*x1**3 + 47.6021819332161*x1**3/(x1**2 + 0.031114472*x1 + 0.000240417735982095) + 47.6021819332161*x1**3/(x1 + 0.016826037) - 48.4804326694475*x1**2/(x1**2 + 0.031114472*x1 + 0.000240417735982095) - 48.4804326694475*x1**2/(x1 + 0.016826037) + 34.0733419340499*x1 + 34.0733419340499*x1/(x1 + 0.014288435) + 4.61513426687202

# %%
sympy.simplify(expr)
# Out:
# (21.7206382751465*x1*(2.1915646 - 1.95911823*x1**3)*((1 - 1.0264988*x1**2)*(x1 + 0.014288435) + 1)*(x1*(x1 - 1.0184498) + 0.7157937*x1 + 0.0120439712805669) + 4.61513426687202*(x1 + 0.014288435)*(x1 + 0.016826037))/((x1 + 0.014288435)*(x1 + 0.016826037))

# %%
sympy.factor(expr)
# Out:
# 79.1383687168112*(0.55195615558295*x1**9 - 0.159166307767832*x1**8 - 0.533446731117839*x1**7 - 1.0*x1**6 + 0.336640788383156*x1**5 + 0.590170698599522*x1**4 + 0.427944668557383*x1**3 - 0.119088781949323*x1**2 + 0.00916254183022982*x1 + 1.40205079999211e-5)/((1.0*x1 + 0.014288435)*(1.0*x1 + 0.016826037))

# %%
symb_s=model.predict(tf.concat([p, s],1),chose)
symb_s=symb_s*(max_cols_phi-min_cols_phi)+min_cols_phi
plt.scatter(s, phi, s=3, label='PINN prediction')
plt.scatter(s, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
plt.scatter(p, phi, s=3, label='PINN prediction')
plt.scatter(p, symb_s, s=3,  linestyle='--', label='Symbolic regresion')
# plt.plot(tf.concat([p, s],1), 15.38-1.18*s, linestyle='--', label=r'$s\approx 0$')

# plt.plot( s, 200/(13+s), label='Real S')

plt.xlabel('P, S')
plt.ylabel('$\phi (P,t)$')
plt.legend()
plt.show()
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)

# %%
Nt=1000
P_symb=np.zeros(Nt)
T_symb=np.zeros(Nt)
S_symb=np.zeros(Nt)

dt=0.001

P_symb[0]=np.mean(P0) #Initial conditions
# P_symb[0]=np.mean(1) #Initial conditions

S_symb[0]=np.array(s[0]) #Initial conditions
T_symb[0]=0
for i in range(1,Nt):
    PS_p=tf.concat([tf.convert_to_tensor(P_symb[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_symb[i-1].reshape([-1,1]), dtype=tf.float32)],1)
    # PHI=predict(PS_p , W_phi, b_phi)
    # P_symb[i]=P_symb[i-1]+(PHI)*P_symb[i-1]*dt

    P_symb[i]=P_symb[i-1]+(model.predict(PS_p,chose)*(max_cols_phi-min_cols_phi)+min_cols_phi-np.array(l))*P_symb[i-1]*dt
    S_symb[i]=S_symb[i-1]-np.maximum(0, P_symb[i-1]*S_symb[i-1]*np.array(m))*dt
    T_symb[i]=T_symb[i-1]+dt
# Out:
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\julia\anaconda3\envs\pinns\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but PySRRegressor was fitted with feature names
#   warnings.warn(

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.ylim(0,1)
plt.legend()
plt.show()

# %%
plt.plot(T_int, P_int, color='blue', linestyle='--', label='Numeric integration dPdT')
plt.plot(T_int, S_int, color='orange', linestyle='--', label='Numeric integration dSdT')

plt.plot(T_symb, P_symb, color='blue', linestyle=':', label='Numeric integration dPdT')
plt.plot(T_symb, S_symb, color='orange', linestyle=':', label='Numeric integration dSdT')

plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
plt.scatter(X_star_tf[:,0], s, marker='x', s=1,  label='PINN Prediction S')
# plt.xlabel('t')
plt.ylabel('P')
plt.legend()
plt.show()

# %%
m, l
# Out:
# (<tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[42.86948]], dtype=float32)>,
#  <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[6.1390066]], dtype=float32)>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve
import sympy as sp

P, S = sp.symbols('P S')

# Definir la función que representa el sistema de ecuaciones
def system(vars):
    P, S = vars
    f_S = expr.subs({'x1': S})-6.1390066  # Cambia esta expresión por la de tu función f(S)
    dP = f_S * P 
    dS = -42.86948 * S * P
    return [dP, dS]


# Definir variables simbólicas
# P, S = sp.symbols('P S')
# Define tu función f(S) y asegúrate de que solo depende de S
f_S = expr.subs({'x1': S})-6.1390066   # Define aquí la función f(S) correctamente

# Convertir f(S) en una función numérica
f_S_func = sp.lambdify(S, f_S, 'numpy')

# Rango para el diagrama de fases
S_values = np.linspace(0, 1, 50)
P_values = np.linspace(0, 1, 50)

# Crear la cuadrícula
P_grid, S_grid = np.meshgrid(P_values, S_values)
dP_vals = f_S_func(S_grid) * P_grid
dS_vals = -42.86948 * S_grid * P_grid

# Encontrar los puntos fijos usando fsolve
fixed_points = []
for P_init in np.linspace(0, 1, 50):  # Asegúrate de elegir un buen rango de inicialización
    for S_init in np.linspace(0, 1, 50):
        point = fsolve(system, [P_init, S_init])
        # Evitar duplicados al agregar puntos
        if not any(np.allclose(point, fp) for fp in fixed_points):
            fixed_points.append(point)



import scipy.optimize as opt


# Usar fsolve para encontrar las raíces de f(S) en un rango inicial
S_initial_guesses = np.linspace(0, 1, 20)  # Puedes ajustar el rango de las conjeturas iniciales
S_roots = [opt.fsolve(f_S_func, S0) for S0 in S_initial_guesses]

# Imprimir las soluciones
S_roots = np.unique(np.array(S_roots).flatten())  # Aplanar el resultado para eliminar listas anidadas
print("Soluciones de f(S) = 0:", S_roots)

# Graficar las soluciones
S_values = np.linspace(0, 1, 100)
f_values = f_S_func(S_values)

plt.plot(S_values, f_values, label="f(S)")
plt.axhline(0, color='black', linestyle='--')
plt.scatter(S_roots, f_S_func(S_roots), color='red', label='Raíces')
plt.xlabel('S')
plt.ylabel('f(S)')
plt.legend()
plt.xlim(0,1)
plt.show()
# Out:
# Soluciones de f(S) = 0: [7.00220078e-04 3.67713783e-02 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 2.89489556e-01 2.89489556e-01 2.89489556e-01
#  2.89489556e-01 1.02094028e+00 1.02094028e+00 1.02094028e+00
#  1.31517768e+00]

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')



plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.ylim(0,1)
plt.xlim(0,1)

plt.legend()
plt.grid()
plt.show()

# %%
# Graficar el diagrama de fases con nulclinas y puntos fijos
plt.figure(figsize=(8, 6))
# plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue', alpha=0.5,scale=1, width=0.005)
plt.quiver(P_grid, S_grid, dP_vals, dS_vals, color='blue',scale=500, width=0.001)


# Graficar las nulclinas (solo como ejemplo)
plt.axhline(0, color='r', linestyle='--', label='Nulclina de $dP/dt = 0$')
plt.axvline(0, color='g', linestyle='--', label='Nulclina de $dS/dt = 0$')

# Graficar los puntos fijos
for point in fixed_points:
    P_val, S_val = point
    plt.plot(P_val, S_val, 'ko', markersize=5)

for nulclina_P in S_roots:
    plt.axhline(nulclina_P, color='r', linestyle='--')


plt.plot(P_int, S_int, color='green')
plt.xlabel('P')
plt.ylabel('S')
plt.title('Diagrama de Fases con Nulclinas y Puntos Fijos')
plt.legend()
plt.ylim(0,1)
plt.xlim(0,1)
plt.grid()
plt.show()
