# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x23e1e477f40>,
#  <matplotlib.lines.Line2D at 0x23e1e477fa0>,
#  <matplotlib.lines.Line2D at 0x23e1e477e50>,
#  <matplotlib.lines.Line2D at 0x23e28054370>,
#  <matplotlib.lines.Line2D at 0x23e2804aeb0>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.hstack((P0_exp,P1_exp,P2_exp,P3_exp))
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
n=np.array([P0_exp.shape[1],P1_exp.shape[1],P2_exp.shape[1],P3_exp.shape[1],])
A=np.array([0, 1.25, 2.50, 3.75])
N_exp,T_max, T_exp.shape, P_exp.shape, 342*23
# Out:
# (19, 231399.5, (342,), (342, 19), 7866)

# %%
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)

plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 1500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
Xa_star=[]
P0_star=np.empty((0, 1))
X_star = np.empty((0, 3))
for i in range(len(A)):
    P0=P_exp[0:1, np.sum(n[:i]):np.sum(n[:i+1])]
    P0_star=np.concatenate((P0_star,P0.T))
    T_meshgrid, P0_meshgrid, A_meshgrid = np.meshgrid(T_exp, P0, A[i])
    x=np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None], A_meshgrid.flatten()[:,None]))
    Xa_star += [x]
    X_star=np.vstack((X_star,x))


u_star=np.hstack((P_star,X_star[:,1:2]))

# %%
# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0_star)).reshape([-1,1]), P0_star.reshape([-1,1]), xx0[...,2:3]))

xx01=np.vstack((xx0, xx1))
uu01=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(3, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_tf = tf.convert_to_tensor(uu01, dtype=tf.float32)

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        plt.plot(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_exp[:, (i + np.sum(n[:k]))], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('P0')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,2], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('A')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 3]), dtype=tf.float32)
    # alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1)))
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp * 2 * 2), (N_exp * 2, 2))) 
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)

        lnp1=u[:,0:1]
        lnp2=u[:,1:2]
        lns=u[:,2:3]

        p1=tf.exp(lnp1)
        p2=tf.exp(lnp2)
        s=tf.exp(lns)
        m=tf.exp(lnv[0:1])
        lnl=net(X_f[...,2:3], W_a, b_a)
        l2=tf.exp(lnl)
        l1=tf.exp(lnv[1:2])
        mn=tf.exp(lnv[2:3])


        # phi=tf.exp(net(tf.concat([p, s, l],1), W_phi, b_phi))
        phi=tf.exp(net(s, W_phi, b_phi))



    p1_t = tape1.gradient(p1, X_f)[...,0:1]
    p2_t = tape1.gradient(p2, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]

    f_p1 = p1_t - phi*p1 + l1*p1
    f_p2 = p2_t - mn*phi*p2 + l2*p2
    f_s = s_t + m*(p1+p2)*s
    
    return f_p1, f_p2, f_s




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi, b_phi,  W_a, b_a,  X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, W_a, b_a, lambda_b, lambda_r, lambda_0, lnv])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp1=u_nn[:,0:1]
        lnp2=u_nn[:,1:2]
        p1_nn=tf.exp(lnp1)
        p2_nn=tf.exp(lnp2)
        f_p1, f_p2, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        u_00 = net(xx01_tf, W_p, b_p) 
        lns_0=u_00[:,2:3]
        s_00=tf.exp(lns_0)
        p2_00=tf.exp(u_00[:,1:2])
        p1_00=tf.exp(u_00[:,0:1])



        loss_p = tf.square(lambda_b*(p1_nn+p2_nn - P_train_tf))
        loss_0s = tf.square(lambda_0[:,0:1]*(s_00 - uu01_tf))
        loss_0p1 = tf.square(lambda_0[:N_exp,1:2]*(p1_00[:N_exp] - uu01_tf[N_exp:])) #p1 al principio peque
        loss_0p2 = tf.square(lambda_0[N_exp:,1:2]*(p2_00[N_exp:] - uu01_tf[N_exp:])) #p2 al final peque
        loss_fp1 = tf.square(lambda_r[:,0:1]*f_p1) 
        loss_fp2 = tf.square(lambda_r[:,1:2]*f_p2) 
        loss_fs = tf.square(lambda_r[:,2:3]*f_s) 


        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)+ tf.reduce_mean(loss_0p1)+ tf.reduce_mean(loss_0p2)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)


    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p1_nn+p2_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p1)), tf.reduce_mean(tf.square(f_p2)), tf.reduce_mean(tf.square(f_s))


layers = [3, 20, 20, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]

W_a = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_a = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]
L = len(layers)

W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 3), (3, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
def train_dynamic_step( W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_phi, b_phi, W_a, b_a, lambda_r, lnv])

        f_p, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        loss_fp = tf.square(lambda_r[0:1]*f_p) 
        loss_fs = tf.square(lambda_r[1:2]*f_s) 


        loss =  tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)


    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)



    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))

   
    return loss, 0, tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s))

# %%
lr = 5e-3




optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/10)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp1 = []
loss_fisp2 = []
loss_fiss = []
loss_reg=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf,  lambda_r, lambda_b, lambda_0, lnv, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, optimizer2)
# train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=2*10**5


while it <= Nmax:
    if it<10**5:
        loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    else:
        loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else
        # loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp1.append(loss_fp1)
    loss_fisp2.append(loss_fp2)
    loss_fiss.append(loss_fs)
    # loss_fisa.append(loss_fa)



    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        # print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p1 is: {loss_fp1}")
        print(f"Physicial loss of p2 is: {loss_fp2}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 57080
# Physicial loss of p1 is: 0.005265280604362488
# Physicial loss of p2 is: 0.0006100538303144276
# Physicial loss of s is: 0.003109969198703766
# Iteration is: 57090
# Physicial loss of p1 is: 0.0008485360303893685
# Physicial loss of p2 is: 0.0004996094503439963
# Physicial loss of s is: 0.002568603726103902
# Iteration is: 57100
# Physicial loss of p1 is: 0.0022423146292567253
# Physicial loss of p2 is: 0.00047232513315975666
# Physicial loss of s is: 0.0025384104810655117
# Iteration is: 57110
# Physicial loss of p1 is: 0.005440681241452694
# Physicial loss of p2 is: 0.0005306081147864461
# Physicial loss of s is: 0.0030432555358856916
# Iteration is: 57120
# Physicial loss of p1 is: 0.009417147375643253
# Physicial loss of p2 is: 0.0006543903145939112
# Physicial loss of s is: 0.004622006788849831
# Iteration is: 57130
# Physicial loss of p1 is: 0.0008410699083469808
# Physicial loss of p2 is: 0.00042459359974600375
# Physicial loss of s is: 0.002546642441302538
# Iteration is: 57140
# Physicial loss of p1 is: 0.0026907429564744234
# Physicial loss of p2 is: 0.0004972121096216142
# Physicial loss of s is: 0.002981976605951786
# Iteration is: 57150
# Physicial loss of p1 is: 0.009819552302360535
# Physicial loss of p2 is: 0.0011153074447065592
# Physicial loss of s is: 0.002814811421558261
# Iteration is: 57160
# Physicial loss of p1 is: 0.002940095029771328
# Physicial loss of p2 is: 0.0006114752031862736
# Physicial loss of s is: 0.002683495869860053
# Iteration is: 57170
# Physicial loss of p1 is: 0.004202912095934153
# Physicial loss of p2 is: 0.0005684689967893064
# Physicial loss of s is: 0.0025354691315442324
# Iteration is: 57180
# Physicial loss of p1 is: 0.001764695974998176
# Physicial loss of p2 is: 0.0004886611131951213
# Physicial loss of s is: 0.0033201880287379026
# Iteration is: 57190
# Physicial loss of p1 is: 0.0035290748346596956
# Physicial loss of p2 is: 0.00048182185855694115
# Physicial loss of s is: 0.002811232814565301
# Iteration is: 57200
# Physicial loss of p1 is: 0.01039911899715662
# Physicial loss of p2 is: 0.0006671811570413411
# Physicial loss of s is: 0.0034588943235576153
# Iteration is: 57210
# Physicial loss of p1 is: 0.002607425907626748
# Physicial loss of p2 is: 0.000488829507958144
# Physicial loss of s is: 0.003317555645480752
# Iteration is: 57220
# Physicial loss of p1 is: 0.0010086894035339355
# Physicial loss of p2 is: 0.0004422444908414036
# Physicial loss of s is: 0.002672394970431924
# Iteration is: 57230
# Physicial loss of p1 is: 0.004166495520621538
# Physicial loss of p2 is: 0.0005163236637599766
# Physicial loss of s is: 0.0028127417899668217
# Iteration is: 57240
# Physicial loss of p1 is: 0.012755016796290874
# Physicial loss of p2 is: 0.0012952323304489255
# Physicial loss of s is: 0.004167512990534306
# Iteration is: 57250
# Physicial loss of p1 is: 0.0012216157047078013
# Physicial loss of p2 is: 0.0004410616820678115
# Physicial loss of s is: 0.0025594050530344248
# Iteration is: 57260
# Physicial loss of p1 is: 0.003906955476850271
# Physicial loss of p2 is: 0.00047422366333194077
# Physicial loss of s is: 0.0028809334617108107
# Iteration is: 57270
# Physicial loss of p1 is: 0.0017403638921678066
# Physicial loss of p2 is: 0.0005816253833472729
# Physicial loss of s is: 0.002924524713307619
# Iteration is: 57280
# Physicial loss of p1 is: 0.002962215803563595
# Physicial loss of p2 is: 0.0006089378730393946
# Physicial loss of s is: 0.00353047251701355
# Iteration is: 57290
# Physicial loss of p1 is: 0.01444263942539692
# Physicial loss of p2 is: 0.0007854128489270806
# Physicial loss of s is: 0.002945905551314354
# Iteration is: 57300
# Physicial loss of p1 is: 0.0013945967657491565
# Physicial loss of p2 is: 0.000509079429320991
# Physicial loss of s is: 0.002594258636236191
# Iteration is: 57310
# Physicial loss of p1 is: 0.0035617770627141
# Physicial loss of p2 is: 0.0005996387917548418
# Physicial loss of s is: 0.0026642214506864548
# Iteration is: 57320
# Physicial loss of p1 is: 0.0022541240323334932
# Physicial loss of p2 is: 0.0005033615161664784
# Physicial loss of s is: 0.003253300441429019
# Iteration is: 57330
# Physicial loss of p1 is: 0.003432569559663534
# Physicial loss of p2 is: 0.0005845109117217362
# Physicial loss of s is: 0.003709340002387762
# Iteration is: 57340
# Physicial loss of p1 is: 0.008945233188569546
# Physicial loss of p2 is: 0.0011186839547008276
# Physicial loss of s is: 0.0029592523351311684
# Iteration is: 57350
# Physicial loss of p1 is: 0.002306989161297679
# Physicial loss of p2 is: 0.00045684882206842303
# Physicial loss of s is: 0.00259784166701138
# Iteration is: 57360
# Physicial loss of p1 is: 0.0014338563196361065
# Physicial loss of p2 is: 0.0004420555487740785
# Physicial loss of s is: 0.0025360542349517345
# Iteration is: 57370
# Physicial loss of p1 is: 0.004675815813243389
# Physicial loss of p2 is: 0.00047998304944485426
# Physicial loss of s is: 0.003064966294914484
# Iteration is: 57380
# Physicial loss of p1 is: 0.01302020251750946
# Physicial loss of p2 is: 0.0010648872703313828
# Physicial loss of s is: 0.005164086353033781
# Iteration is: 57390
# Physicial loss of p1 is: 0.0008620076114311814
# Physicial loss of p2 is: 0.00043169589480385184
# Physicial loss of s is: 0.002657766453921795
# Iteration is: 57400
# Physicial loss of p1 is: 0.003681256202980876
# Physicial loss of p2 is: 0.0005146947223693132
# Physicial loss of s is: 0.002752146450802684
# Iteration is: 57410
# Physicial loss of p1 is: 0.003923064563423395
# Physicial loss of p2 is: 0.0004934989847242832
# Physicial loss of s is: 0.0025891915429383516
# Iteration is: 57420
# Physicial loss of p1 is: 0.004478533752262592
# Physicial loss of p2 is: 0.0006183303776197135
# Physicial loss of s is: 0.0028491541743278503
# Iteration is: 57430
# Physicial loss of p1 is: 0.005658459849655628
# Physicial loss of p2 is: 0.0006643313681706786
# Physicial loss of s is: 0.0033878430258482695
# Iteration is: 57440
# Physicial loss of p1 is: 0.0032412693835794926
# Physicial loss of p2 is: 0.0005157879204489291
# Physicial loss of s is: 0.003053555730730295
# Iteration is: 57450
# Physicial loss of p1 is: 0.0015483496244996786
# Physicial loss of p2 is: 0.0004801335744559765
# Physicial loss of s is: 0.0027317062485963106
# Iteration is: 57460
# Physicial loss of p1 is: 0.0028511190321296453
# Physicial loss of p2 is: 0.0007351799285970628
# Physicial loss of s is: 0.0028250832110643387
# Iteration is: 57470
# Physicial loss of p1 is: 0.01850050687789917
# Physicial loss of p2 is: 0.0014356866013258696
# Physicial loss of s is: 0.003186663379892707
# Iteration is: 57480
# Physicial loss of p1 is: 0.0032583693973720074
# Physicial loss of p2 is: 0.0005485683213919401
# Physicial loss of s is: 0.0031256312504410744
# Iteration is: 57490
# Physicial loss of p1 is: 0.001135722966864705
# Physicial loss of p2 is: 0.00043274086783640087
# Physicial loss of s is: 0.0028392761014401913
# Iteration is: 57500
# Physicial loss of p1 is: 0.0017934150528162718
# Physicial loss of p2 is: 0.0004420462064445019
# Physicial loss of s is: 0.0025658186059445143
# Iteration is: 57510
# Physicial loss of p1 is: 0.000980850076302886
# Physicial loss of p2 is: 0.0005008961888961494
# Physicial loss of s is: 0.002631925279274583
# Iteration is: 57520
# Physicial loss of p1 is: 0.002971179550513625
# Physicial loss of p2 is: 0.0005405877600423992
# Physicial loss of s is: 0.004251394886523485
# Iteration is: 57530
# Physicial loss of p1 is: 0.015340089797973633
# Physicial loss of p2 is: 0.0010556980269029737
# Physicial loss of s is: 0.00380116724409163
# Iteration is: 57540
# Physicial loss of p1 is: 0.0029640288557857275
# Physicial loss of p2 is: 0.0004413856368046254
# Physicial loss of s is: 0.00279579171910882
# Iteration is: 57550
# Physicial loss of p1 is: 0.0016415325226262212
# Physicial loss of p2 is: 0.0005474031204357743
# Physicial loss of s is: 0.002589267212897539
# Iteration is: 57560
# Physicial loss of p1 is: 0.0018349296879023314
# Physicial loss of p2 is: 0.0004359214217402041
# Physicial loss of s is: 0.002545538591220975
# Iteration is: 57570
# Physicial loss of p1 is: 0.00419907970353961
# Physicial loss of p2 is: 0.0005602766759693623
# Physicial loss of s is: 0.003008828032761812
# Iteration is: 57580
# Physicial loss of p1 is: 0.008807572536170483
# Physicial loss of p2 is: 0.0007013771100901067
# Physicial loss of s is: 0.003411516547203064
# Iteration is: 57590
# Physicial loss of p1 is: 0.0014097170205786824
# Physicial loss of p2 is: 0.00044018111657351255
# Physicial loss of s is: 0.002625435357913375
# Iteration is: 57600
# Physicial loss of p1 is: 0.00147039454896003
# Physicial loss of p2 is: 0.0004999786615371704
# Physicial loss of s is: 0.0025569929275661707
# Iteration is: 57610
# Physicial loss of p1 is: 0.007464495021849871
# Physicial loss of p2 is: 0.0010293180821463466
# Physicial loss of s is: 0.0032464584801346064
# Iteration is: 57620
# Physicial loss of p1 is: 0.00984443910419941
# Physicial loss of p2 is: 0.0007826412911526859
# Physicial loss of s is: 0.0035234622191637754
# Iteration is: 57630
# Physicial loss of p1 is: 0.00199340982362628
# Physicial loss of p2 is: 0.0010002648923546076
# Physicial loss of s is: 0.0025921559426933527
# Iteration is: 57640
# Physicial loss of p1 is: 0.0016984303947538137
# Physicial loss of p2 is: 0.0006997003802098334
# Physicial loss of s is: 0.0028953535947948694
# Iteration is: 57650
# Physicial loss of p1 is: 0.0034359104465693235
# Physicial loss of p2 is: 0.0005876596551388502
# Physicial loss of s is: 0.002593760611489415
# Iteration is: 57660
# Physicial loss of p1 is: 0.00927099958062172
# Physicial loss of p2 is: 0.0006523009506054223
# Physicial loss of s is: 0.004045027773827314
# Iteration is: 57670
# Physicial loss of p1 is: 0.0019459547474980354
# Physicial loss of p2 is: 0.0005611567758023739
# Physicial loss of s is: 0.003593596164137125
# Iteration is: 57680
# Physicial loss of p1 is: 0.0020786456298083067
# Physicial loss of p2 is: 0.0004956618067808449
# Physicial loss of s is: 0.0032128849998116493
# Iteration is: 57690
# Physicial loss of p1 is: 0.005977083928883076
# Physicial loss of p2 is: 0.0005448595038615167
# Physicial loss of s is: 0.002561272354796529
# Iteration is: 57700
# Physicial loss of p1 is: 0.008347741328179836
# Physicial loss of p2 is: 0.0007024139049462974
# Physicial loss of s is: 0.002888682298362255
# Iteration is: 57710
# Physicial loss of p1 is: 0.0009970684768632054
# Physicial loss of p2 is: 0.0004290402866899967
# Physicial loss of s is: 0.0027099421713501215
# Iteration is: 57720
# Physicial loss of p1 is: 0.0011619222350418568
# Physicial loss of p2 is: 0.00042772621964104474
# Physicial loss of s is: 0.002535406965762377
# Iteration is: 57730
# Physicial loss of p1 is: 0.006982468534260988
# Physicial loss of p2 is: 0.000592187512665987
# Physicial loss of s is: 0.003323295619338751
# Iteration is: 57740
# Physicial loss of p1 is: 0.00767124630510807
# Physicial loss of p2 is: 0.0010175644420087337
# Physicial loss of s is: 0.0033848967868834734
# Iteration is: 57750
# Physicial loss of p1 is: 0.005756619852036238
# Physicial loss of p2 is: 0.0005305165541358292
# Physicial loss of s is: 0.003106810851022601
# Iteration is: 57760
# Physicial loss of p1 is: 0.000904161250218749
# Physicial loss of p2 is: 0.0004424205399118364
# Physicial loss of s is: 0.0025405585765838623
# Iteration is: 57770
# Physicial loss of p1 is: 0.0020345267839729786
# Physicial loss of p2 is: 0.00046097932499833405
# Physicial loss of s is: 0.0025317177642136812
# Iteration is: 57780
# Physicial loss of p1 is: 0.0059675551019608974
# Physicial loss of p2 is: 0.0004946588887833059
# Physicial loss of s is: 0.002639307174831629
# Iteration is: 57790
# Physicial loss of p1 is: 0.006487676873803139
# Physicial loss of p2 is: 0.0007501067011617124
# Physicial loss of s is: 0.003022188087925315
# Iteration is: 57800
# Physicial loss of p1 is: 0.0009402548894286156
# Physicial loss of p2 is: 0.0005433211335912347
# Physicial loss of s is: 0.004079819656908512
# Iteration is: 57810
# Physicial loss of p1 is: 0.0008421513484790921
# Physicial loss of p2 is: 0.000823070527985692
# Physicial loss of s is: 0.00258677639067173
# Iteration is: 57820
# Physicial loss of p1 is: 0.0012949607335031033
# Physicial loss of p2 is: 0.0006019124994054437
# Physicial loss of s is: 0.0025420638266950846
# Iteration is: 57830
# Physicial loss of p1 is: 0.018252912908792496
# Physicial loss of p2 is: 0.000792981474660337
# Physicial loss of s is: 0.0036338577046990395
# Iteration is: 57840
# Physicial loss of p1 is: 0.0009114955901168287
# Physicial loss of p2 is: 0.0004263842711225152
# Physicial loss of s is: 0.0027032895013689995
# Iteration is: 57850
# Physicial loss of p1 is: 0.0016403060872107744
# Physicial loss of p2 is: 0.0005629494553431869
# Physicial loss of s is: 0.003316599177196622
# Iteration is: 57860
# Physicial loss of p1 is: 0.002517110900953412
# Physicial loss of p2 is: 0.00045597547432407737
# Physicial loss of s is: 0.0026906051207333803
# Iteration is: 57870
# Physicial loss of p1 is: 0.0008316350867971778
# Physicial loss of p2 is: 0.0004534597392193973
# Physicial loss of s is: 0.0025355948600918055
# Iteration is: 57880
# Physicial loss of p1 is: 0.001230214606039226
# Physicial loss of p2 is: 0.00041965089621953666
# Physicial loss of s is: 0.00257959496229887
# Iteration is: 57890
# Physicial loss of p1 is: 0.008785184472799301
# Physicial loss of p2 is: 0.0005473166238516569
# Physicial loss of s is: 0.0036032882053405046
# Iteration is: 57900
# Physicial loss of p1 is: 0.006449956446886063
# Physicial loss of p2 is: 0.0008679632446728647
# Physicial loss of s is: 0.0033313361927866936
# Iteration is: 57910
# Physicial loss of p1 is: 0.004679323639720678
# Physicial loss of p2 is: 0.0006107776425778866
# Physicial loss of s is: 0.0033061900176107883
# Iteration is: 57920
# Physicial loss of p1 is: 0.0009730550809763372
# Physicial loss of p2 is: 0.0004153831396251917
# Physicial loss of s is: 0.002525530755519867
# Iteration is: 57930
# Physicial loss of p1 is: 0.0016830537933856249
# Physicial loss of p2 is: 0.0004398544260766357
# Physicial loss of s is: 0.0028713312931358814
# Iteration is: 57940
# Physicial loss of p1 is: 0.006785380654036999
# Physicial loss of p2 is: 0.000514152692630887
# Physicial loss of s is: 0.003010626183822751
# Iteration is: 57950
# Physicial loss of p1 is: 0.010954086668789387
# Physicial loss of p2 is: 0.001223986386321485
# Physicial loss of s is: 0.0026903613470494747
# Iteration is: 57960
# Physicial loss of p1 is: 0.0017429578583687544
# Physicial loss of p2 is: 0.000482147210277617
# Physicial loss of s is: 0.003378559136763215
# Iteration is: 57970
# Physicial loss of p1 is: 0.0034167012199759483
# Physicial loss of p2 is: 0.00046087006921879947
# Physicial loss of s is: 0.002565048635005951
# Iteration is: 57980
# Physicial loss of p1 is: 0.0009969768580049276
# Physicial loss of p2 is: 0.00042024574941024184
# Physicial loss of s is: 0.002512066625058651
# Iteration is: 57990
# Physicial loss of p1 is: 0.000893238524440676
# Physicial loss of p2 is: 0.0004258599365130067
# Physicial loss of s is: 0.0026018922217190266
# Iteration is: 58000
# Physicial loss of p1 is: 0.00442468049004674
# Physicial loss of p2 is: 0.0005142457666806877
# Physicial loss of s is: 0.0032793604768812656
# Iteration is: 58010
# Physicial loss of p1 is: 0.012446625158190727
# Physicial loss of p2 is: 0.0022704617585986853
# Physicial loss of s is: 0.004883728921413422
# Iteration is: 58020
# Physicial loss of p1 is: 0.008198128081858158
# Physicial loss of p2 is: 0.0006659108912572265
# Physicial loss of s is: 0.003914388827979565
# Iteration is: 58030
# Physicial loss of p1 is: 0.0015046936459839344
# Physicial loss of p2 is: 0.0006684577674604952
# Physicial loss of s is: 0.003451781813055277
# Iteration is: 58040
# Physicial loss of p1 is: 0.0012801429256796837
# Physicial loss of p2 is: 0.0004321854212321341
# Physicial loss of s is: 0.002716713584959507
# Iteration is: 58050
# Physicial loss of p1 is: 0.0008982408326119184
# Physicial loss of p2 is: 0.00043348484905436635
# Physicial loss of s is: 0.002602490596473217
# Iteration is: 58060
# Physicial loss of p1 is: 0.0011608771746978164
# Physicial loss of p2 is: 0.0004189261526335031
# Physicial loss of s is: 0.0024972695391625166
# Iteration is: 58070
# Physicial loss of p1 is: 0.015960155054926872
# Physicial loss of p2 is: 0.0007233262294903398
# Physicial loss of s is: 0.0029319224413484335
# Iteration is: 58080
# Physicial loss of p1 is: 0.000813059916254133
# Physicial loss of p2 is: 0.0004556522471830249
# Physicial loss of s is: 0.002560810884460807
# Iteration is: 58090
# Physicial loss of p1 is: 0.001338991685770452
# Physicial loss of p2 is: 0.0006546247750520706
# Physicial loss of s is: 0.0030063227750360966
# Iteration is: 58100
# Physicial loss of p1 is: 0.0021796091459691525
# Physicial loss of p2 is: 0.0005094623193144798
# Physicial loss of s is: 0.002831151243299246
# Iteration is: 58110
# Physicial loss of p1 is: 0.0012591120321303606
# Physicial loss of p2 is: 0.0005211614188738167
# Physicial loss of s is: 0.0025080384220927954
# Iteration is: 58120
# Physicial loss of p1 is: 0.0012936412822455168
# Physicial loss of p2 is: 0.0004239551490172744
# Physicial loss of s is: 0.0026233363896608353
# Iteration is: 58130
# Physicial loss of p1 is: 0.005348497070372105
# Physicial loss of p2 is: 0.0005183123867027462
# Physicial loss of s is: 0.0038210097700357437
# Iteration is: 58140
# Physicial loss of p1 is: 0.011980046518146992
# Physicial loss of p2 is: 0.0010987739078700542
# Physicial loss of s is: 0.003914125729352236
# Iteration is: 58150
# Physicial loss of p1 is: 0.002129519125446677
# Physicial loss of p2 is: 0.00048000470269471407
# Physicial loss of s is: 0.003024511272087693
# Iteration is: 58160
# Physicial loss of p1 is: 0.0027599043678492308
# Physicial loss of p2 is: 0.00047624169383198023
# Physicial loss of s is: 0.002533091465011239
# Iteration is: 58170
# Physicial loss of p1 is: 0.0008758360636420548
# Physicial loss of p2 is: 0.00041860612691380084
# Physicial loss of s is: 0.002518048509955406
# Iteration is: 58180
# Physicial loss of p1 is: 0.0008181293378584087
# Physicial loss of p2 is: 0.0004271788930054754
# Physicial loss of s is: 0.002495967783033848
# Iteration is: 58190
# Physicial loss of p1 is: 0.0010182884288951755
# Physicial loss of p2 is: 0.0004253567603882402
# Physicial loss of s is: 0.0025004190392792225
# Iteration is: 58200
# Physicial loss of p1 is: 0.024892186746001244
# Physicial loss of p2 is: 0.0009686818229965866
# Physicial loss of s is: 0.004553733393549919
# Iteration is: 58210
# Physicial loss of p1 is: 0.00411651935428381
# Physicial loss of p2 is: 0.0005636736168526113
# Physicial loss of s is: 0.003239493118599057
# Iteration is: 58220
# Physicial loss of p1 is: 0.002741447417065501
# Physicial loss of p2 is: 0.0005290692206472158
# Physicial loss of s is: 0.0025824233889579773
# Iteration is: 58230
# Physicial loss of p1 is: 0.0011563815642148256
# Physicial loss of p2 is: 0.0006295748171396554
# Physicial loss of s is: 0.0025412626564502716
# Iteration is: 58240
# Physicial loss of p1 is: 0.0008220192976295948
# Physicial loss of p2 is: 0.0004410366527736187
# Physicial loss of s is: 0.0025193076580762863
# Iteration is: 58250
# Physicial loss of p1 is: 0.0013798298314213753
# Physicial loss of p2 is: 0.00043076687143184245
# Physicial loss of s is: 0.0025177402421832085
# Iteration is: 58260
# Physicial loss of p1 is: 0.0012585765216499567
# Physicial loss of p2 is: 0.0004175609501544386
# Physicial loss of s is: 0.0024890403728932142
# Iteration is: 58270
# Physicial loss of p1 is: 0.0034901241306215525
# Physicial loss of p2 is: 0.0004499130300246179
# Physicial loss of s is: 0.002632785588502884
# Iteration is: 58280
# Physicial loss of p1 is: 0.014710890129208565
# Physicial loss of p2 is: 0.0009759083040989935
# Physicial loss of s is: 0.005040599964559078
# Iteration is: 58290
# Physicial loss of p1 is: 0.0031324292067438364
# Physicial loss of p2 is: 0.0005944091244600713
# Physicial loss of s is: 0.002835212042555213
# Iteration is: 58300
# Physicial loss of p1 is: 0.001618608133867383
# Physicial loss of p2 is: 0.000432380911661312
# Physicial loss of s is: 0.0028642481192946434
# Iteration is: 58310
# Physicial loss of p1 is: 0.0018084644107148051
# Physicial loss of p2 is: 0.00044654065277427435
# Physicial loss of s is: 0.002503941999748349
# Iteration is: 58320
# Physicial loss of p1 is: 0.0032066761050373316
# Physicial loss of p2 is: 0.0004755373520310968
# Physicial loss of s is: 0.002930643269792199
# Iteration is: 58330
# Physicial loss of p1 is: 0.008460523560643196
# Physicial loss of p2 is: 0.0006636859616264701
# Physicial loss of s is: 0.0030967621132731438
# Iteration is: 58340
# Physicial loss of p1 is: 0.00295534310862422
# Physicial loss of p2 is: 0.0004917929763905704
# Physicial loss of s is: 0.002553024562075734
# Iteration is: 58350
# Physicial loss of p1 is: 0.001148689305409789
# Physicial loss of p2 is: 0.00042315557948313653
# Physicial loss of s is: 0.0024878268595784903
# Iteration is: 58360
# Physicial loss of p1 is: 0.004836822394281626
# Physicial loss of p2 is: 0.0005007103318348527
# Physicial loss of s is: 0.0026694212574511766
# Iteration is: 58370
# Physicial loss of p1 is: 0.013054613955318928
# Physicial loss of p2 is: 0.0008649314986541867
# Physicial loss of s is: 0.004706597421318293
# Iteration is: 58380
# Physicial loss of p1 is: 0.0009642428485676646
# Physicial loss of p2 is: 0.000508268247358501
# Physicial loss of s is: 0.0031747808679938316
# Iteration is: 58390
# Physicial loss of p1 is: 0.003644883632659912
# Physicial loss of p2 is: 0.0005816780612803996
# Physicial loss of s is: 0.0030182967893779278
# Iteration is: 58400
# Physicial loss of p1 is: 0.0025578332133591175
# Physicial loss of p2 is: 0.0004686606989707798
# Physicial loss of s is: 0.002583453431725502
# Iteration is: 58410
# Physicial loss of p1 is: 0.003872093977406621
# Physicial loss of p2 is: 0.0006361802807077765
# Physicial loss of s is: 0.0026615974493324757
# Iteration is: 58420
# Physicial loss of p1 is: 0.010025033727288246
# Physicial loss of p2 is: 0.0007785539492033422
# Physicial loss of s is: 0.0028672432526946068
# Iteration is: 58430
# Physicial loss of p1 is: 0.0011637106072157621
# Physicial loss of p2 is: 0.00043083008495159447
# Physicial loss of s is: 0.0026435640174895525
# Iteration is: 58440
# Physicial loss of p1 is: 0.0020622711163014174
# Physicial loss of p2 is: 0.0005334453890100121
# Physicial loss of s is: 0.0024979105219244957
# Iteration is: 58450
# Physicial loss of p1 is: 0.004907621536403894
# Physicial loss of p2 is: 0.0005545350722968578
# Physicial loss of s is: 0.002649897476658225
# Iteration is: 58460
# Physicial loss of p1 is: 0.011840161867439747
# Physicial loss of p2 is: 0.0007427810924127698
# Physicial loss of s is: 0.005853341892361641
# Iteration is: 58470
# Physicial loss of p1 is: 0.0008179130381904542
# Physicial loss of p2 is: 0.000411644927226007
# Physicial loss of s is: 0.002482979092746973
# Iteration is: 58480
# Physicial loss of p1 is: 0.003311766544356942
# Physicial loss of p2 is: 0.0005372028099372983
# Physicial loss of s is: 0.0026838413905352354
# Iteration is: 58490
# Physicial loss of p1 is: 0.005449153482913971
# Physicial loss of p2 is: 0.0009283720864914358
# Physicial loss of s is: 0.0026250313967466354
# Iteration is: 58500
# Physicial loss of p1 is: 0.004535827785730362
# Physicial loss of p2 is: 0.0004928777343593538
# Physicial loss of s is: 0.0028238766826689243
# Iteration is: 58510
# Physicial loss of p1 is: 0.0015473081730306149
# Physicial loss of p2 is: 0.00043593643931671977
# Physicial loss of s is: 0.0024855979718267918
# Iteration is: 58520
# Physicial loss of p1 is: 0.001705232192762196
# Physicial loss of p2 is: 0.0004579197848215699
# Physicial loss of s is: 0.0025495518930256367
# Iteration is: 58530
# Physicial loss of p1 is: 0.012389606796205044
# Physicial loss of p2 is: 0.0007397439912892878
# Physicial loss of s is: 0.0032407441176474094
# Iteration is: 58540
# Physicial loss of p1 is: 0.0021132484544068575
# Physicial loss of p2 is: 0.0007250437047332525
# Physicial loss of s is: 0.0028363193850964308
# Iteration is: 58550
# Physicial loss of p1 is: 0.005283620674163103
# Physicial loss of p2 is: 0.0005741481436416507
# Physicial loss of s is: 0.0029606292955577374
# Iteration is: 58560
# Physicial loss of p1 is: 0.0009056253475137055
# Physicial loss of p2 is: 0.0004223733558319509
# Physicial loss of s is: 0.002556509105488658
# Iteration is: 58570
# Physicial loss of p1 is: 0.0022733372170478106
# Physicial loss of p2 is: 0.0004919352359138429
# Physicial loss of s is: 0.0025780294090509415
# Iteration is: 58580
# Physicial loss of p1 is: 0.006720609962940216
# Physicial loss of p2 is: 0.0005661094910465181
# Physicial loss of s is: 0.0035472640302032232
# Iteration is: 58590
# Physicial loss of p1 is: 0.004512859508395195
# Physicial loss of p2 is: 0.0007353288237936795
# Physicial loss of s is: 0.004046503454446793
# Iteration is: 58600
# Physicial loss of p1 is: 0.0008612560341134667
# Physicial loss of p2 is: 0.0004375630524009466
# Physicial loss of s is: 0.0027445675805211067
# Iteration is: 58610
# Physicial loss of p1 is: 0.0020454437471926212
# Physicial loss of p2 is: 0.000577744678594172
# Physicial loss of s is: 0.0025852995458990335
# Iteration is: 58620
# Physicial loss of p1 is: 0.016989881172776222
# Physicial loss of p2 is: 0.0008667012443765998
# Physicial loss of s is: 0.0026382957585155964
# Iteration is: 58630
# Physicial loss of p1 is: 0.0010560550726950169
# Physicial loss of p2 is: 0.0005001880927011371
# Physicial loss of s is: 0.0030032608192414045
# Iteration is: 58640
# Physicial loss of p1 is: 0.0035879104398190975
# Physicial loss of p2 is: 0.0006477926508523524
# Physicial loss of s is: 0.003000369295477867
# Iteration is: 58650
# Physicial loss of p1 is: 0.0008796608890406787
# Physicial loss of p2 is: 0.0005111935315653682
# Physicial loss of s is: 0.002558465115725994
# Iteration is: 58660
# Physicial loss of p1 is: 0.0008058120729401708
# Physicial loss of p2 is: 0.00043960195034742355
# Physicial loss of s is: 0.0024876685347408056
# Iteration is: 58670
# Physicial loss of p1 is: 0.0011714904103428125
# Physicial loss of p2 is: 0.00042583694448694587
# Physicial loss of s is: 0.002554171485826373
# Iteration is: 58680
# Physicial loss of p1 is: 0.0286315456032753
# Physicial loss of p2 is: 0.0008307970711030066
# Physicial loss of s is: 0.004346207249909639
# Iteration is: 58690
# Physicial loss of p1 is: 0.0020652026869356632
# Physicial loss of p2 is: 0.00048760222853161395
# Physicial loss of s is: 0.002746882615610957
# Iteration is: 58700
# Physicial loss of p1 is: 0.0008203989127650857
# Physicial loss of p2 is: 0.0006119203753769398
# Physicial loss of s is: 0.0030485931783914566
# Iteration is: 58710
# Physicial loss of p1 is: 0.0014285229844972491
# Physicial loss of p2 is: 0.0004409586836118251
# Physicial loss of s is: 0.0028184857219457626
# Iteration is: 58720
# Physicial loss of p1 is: 0.0015456870896741748
# Physicial loss of p2 is: 0.00048255143337883055
# Physicial loss of s is: 0.002573724603280425
# Iteration is: 58730
# Physicial loss of p1 is: 0.0011700185714289546
# Physicial loss of p2 is: 0.000454440014436841
# Physicial loss of s is: 0.0025612569879740477
# Iteration is: 58740
# Physicial loss of p1 is: 0.0028258468955755234
# Physicial loss of p2 is: 0.00046530604595318437
# Physicial loss of s is: 0.0027677116449922323
# Iteration is: 58750
# Physicial loss of p1 is: 0.014856778085231781
# Physicial loss of p2 is: 0.0008443756378255785
# Physicial loss of s is: 0.003987989854067564
# Iteration is: 58760
# Physicial loss of p1 is: 0.0009829547489061952
# Physicial loss of p2 is: 0.00040436015115119517
# Physicial loss of s is: 0.0024801292456686497
# Iteration is: 58770
# Physicial loss of p1 is: 0.0037071274127811193
# Physicial loss of p2 is: 0.0006669246358796954
# Physicial loss of s is: 0.0029767330270260572
# Iteration is: 58780
# Physicial loss of p1 is: 0.0008251090184785426
# Physicial loss of p2 is: 0.000410532666137442
# Physicial loss of s is: 0.002569241914898157
# Iteration is: 58790
# Physicial loss of p1 is: 0.0010566989658400416
# Physicial loss of p2 is: 0.0005171163356862962
# Physicial loss of s is: 0.0028348523192107677
# Iteration is: 58800
# Physicial loss of p1 is: 0.004328310489654541
# Physicial loss of p2 is: 0.0005431664176285267
# Physicial loss of s is: 0.0028315712697803974
# Iteration is: 58810
# Physicial loss of p1 is: 0.01592378132045269
# Physicial loss of p2 is: 0.0013894388685002923
# Physicial loss of s is: 0.006841519381850958
# Iteration is: 58820
# Physicial loss of p1 is: 0.007000600453466177
# Physicial loss of p2 is: 0.0006184331723488867
# Physicial loss of s is: 0.0038143291603773832
# Iteration is: 58830
# Physicial loss of p1 is: 0.0009816508973017335
# Physicial loss of p2 is: 0.0004835098225157708
# Physicial loss of s is: 0.0026325550861656666
# Iteration is: 58840
# Physicial loss of p1 is: 0.001968902302905917
# Physicial loss of p2 is: 0.00042639876483008265
# Physicial loss of s is: 0.002501012058928609
# Iteration is: 58850
# Physicial loss of p1 is: 0.0008113051299005747
# Physicial loss of p2 is: 0.0004154664638917893
# Physicial loss of s is: 0.0024777203798294067
# Iteration is: 58860
# Physicial loss of p1 is: 0.0008780733915045857
# Physicial loss of p2 is: 0.00041715751285664737
# Physicial loss of s is: 0.0024787746369838715
# Iteration is: 58870
# Physicial loss of p1 is: 0.004659683909267187
# Physicial loss of p2 is: 0.0004726247861981392
# Physicial loss of s is: 0.0026039290241897106
# Iteration is: 58880
# Physicial loss of p1 is: 0.016507992520928383
# Physicial loss of p2 is: 0.0024165648501366377
# Physicial loss of s is: 0.004857730586081743
# Iteration is: 58890
# Physicial loss of p1 is: 0.00837151613086462
# Physicial loss of p2 is: 0.0005702570197172463
# Physicial loss of s is: 0.0034809818025678396
# Iteration is: 58900
# Physicial loss of p1 is: 0.003616923466324806
# Physicial loss of p2 is: 0.0006060518207959831
# Physicial loss of s is: 0.00313193304464221
# Iteration is: 58910
# Physicial loss of p1 is: 0.001283488585613668
# Physicial loss of p2 is: 0.0004174923524260521
# Physicial loss of s is: 0.0024898662231862545
# Iteration is: 58920
# Physicial loss of p1 is: 0.0013145204866304994
# Physicial loss of p2 is: 0.0004167750012129545
# Physicial loss of s is: 0.002515965374186635
# Iteration is: 58930
# Physicial loss of p1 is: 0.0008975975215435028
# Physicial loss of p2 is: 0.00040742973214946687
# Physicial loss of s is: 0.0024553718976676464
# Iteration is: 58940
# Physicial loss of p1 is: 0.0015972895780578256
# Physicial loss of p2 is: 0.0004488799022510648
# Physicial loss of s is: 0.0025125276297330856
# Iteration is: 58950
# Physicial loss of p1 is: 0.021473439410328865
# Physicial loss of p2 is: 0.001078830217011273
# Physicial loss of s is: 0.004068709444254637
# Iteration is: 58960
# Physicial loss of p1 is: 0.0021462508011609316
# Physicial loss of p2 is: 0.000426596961915493
# Physicial loss of s is: 0.0025424298364669085
# Iteration is: 58970
# Physicial loss of p1 is: 0.0009138871100731194
# Physicial loss of p2 is: 0.0005389715079218149
# Physicial loss of s is: 0.003274443093687296
# Iteration is: 58980
# Physicial loss of p1 is: 0.0021323238033801317
# Physicial loss of p2 is: 0.0004939333302900195
# Physicial loss of s is: 0.002498675137758255
# Iteration is: 58990
# Physicial loss of p1 is: 0.0011226589558646083
# Physicial loss of p2 is: 0.00044187961611896753
# Physicial loss of s is: 0.0024500370491296053
# Iteration is: 59000
# Physicial loss of p1 is: 0.002197857014834881
# Physicial loss of p2 is: 0.0005020386888645589
# Physicial loss of s is: 0.0024514934048056602
# Iteration is: 59010
# Physicial loss of p1 is: 0.009936017915606499
# Physicial loss of p2 is: 0.000514618179295212
# Physicial loss of s is: 0.0026453605387359858
# Iteration is: 59020
# Physicial loss of p1 is: 0.0048686303198337555
# Physicial loss of p2 is: 0.0006750886095687747
# Physicial loss of s is: 0.007463592570275068
# Iteration is: 59030
# Physicial loss of p1 is: 0.002831693273037672
# Physicial loss of p2 is: 0.0006743380799889565
# Physicial loss of s is: 0.004468504339456558
# Iteration is: 59040
# Physicial loss of p1 is: 0.0020054883789271116
# Physicial loss of p2 is: 0.00041780556784942746
# Physicial loss of s is: 0.002552098361775279
# Iteration is: 59050
# Physicial loss of p1 is: 0.0009530154056847095
# Physicial loss of p2 is: 0.00040036169230006635
# Physicial loss of s is: 0.002509856130927801
# Iteration is: 59060
# Physicial loss of p1 is: 0.0011088005267083645
# Physicial loss of p2 is: 0.0004550565790850669
# Physicial loss of s is: 0.0025846899952739477
# Iteration is: 59070
# Physicial loss of p1 is: 0.010018635541200638
# Physicial loss of p2 is: 0.0016122990055009723
# Physicial loss of s is: 0.002976680174469948
# Iteration is: 59080
# Physicial loss of p1 is: 0.0010165564017370343
# Physicial loss of p2 is: 0.00047543400432914495
# Physicial loss of s is: 0.00251253810711205
# Iteration is: 59090
# Physicial loss of p1 is: 0.0010438289027661085
# Physicial loss of p2 is: 0.0006803343421779573
# Physicial loss of s is: 0.0025444147177040577
# Iteration is: 59100
# Physicial loss of p1 is: 0.0010041323257610202
# Physicial loss of p2 is: 0.0005731442361138761
# Physicial loss of s is: 0.0026922854594886303
# Iteration is: 59110
# Physicial loss of p1 is: 0.0013238711981102824
# Physicial loss of p2 is: 0.0004194634093437344
# Physicial loss of s is: 0.0028100875206291676
# Iteration is: 59120
# Physicial loss of p1 is: 0.000798409222625196
# Physicial loss of p2 is: 0.0004148225416429341
# Physicial loss of s is: 0.002560717286542058
# Iteration is: 59130
# Physicial loss of p1 is: 0.00131027156021446
# Physicial loss of p2 is: 0.00041017303010448813
# Physicial loss of s is: 0.0024558452423661947
# Iteration is: 59140
# Physicial loss of p1 is: 0.006385408341884613
# Physicial loss of p2 is: 0.000529143784660846
# Physicial loss of s is: 0.003100327216088772
# Iteration is: 59150
# Physicial loss of p1 is: 0.007038270588964224
# Physicial loss of p2 is: 0.00078554917126894
# Physicial loss of s is: 0.0035412318538874388
# Iteration is: 59160
# Physicial loss of p1 is: 0.004408090375363827
# Physicial loss of p2 is: 0.0005411169258877635
# Physicial loss of s is: 0.0029762370977550745
# Iteration is: 59170
# Physicial loss of p1 is: 0.0014322006609290838
# Physicial loss of p2 is: 0.0004030114214401692
# Physicial loss of s is: 0.0025018395390361547
# Iteration is: 59180
# Physicial loss of p1 is: 0.0011961415875703096
# Physicial loss of p2 is: 0.00041902760858647525
# Physicial loss of s is: 0.0024819127283990383
# Iteration is: 59190
# Physicial loss of p1 is: 0.005360783077776432
# Physicial loss of p2 is: 0.0005482331034727395
# Physicial loss of s is: 0.0029644095338881016
# Iteration is: 59200
# Physicial loss of p1 is: 0.009748249314725399
# Physicial loss of p2 is: 0.0008521797135472298
# Physicial loss of s is: 0.00385908130556345
# Iteration is: 59210
# Physicial loss of p1 is: 0.002343295607715845
# Physicial loss of p2 is: 0.00046688722795806825
# Physicial loss of s is: 0.0025404593907296658
# Iteration is: 59220
# Physicial loss of p1 is: 0.0030725798569619656
# Physicial loss of p2 is: 0.0004329129296820611
# Physicial loss of s is: 0.002751308726146817
# Iteration is: 59230
# Physicial loss of p1 is: 0.0010952182346954942
# Physicial loss of p2 is: 0.000427725026383996
# Physicial loss of s is: 0.002757737645879388
# Iteration is: 59240
# Physicial loss of p1 is: 0.0016265636077150702
# Physicial loss of p2 is: 0.0004330134252086282
# Physicial loss of s is: 0.0031595141626894474
# Iteration is: 59250
# Physicial loss of p1 is: 0.018116498365998268
# Physicial loss of p2 is: 0.0008264190400950611
# Physicial loss of s is: 0.003793912474066019
# Iteration is: 59260
# Physicial loss of p1 is: 0.0012814047513529658
# Physicial loss of p2 is: 0.0006194001180119812
# Physicial loss of s is: 0.0026275403797626495
# Iteration is: 59270
# Physicial loss of p1 is: 0.00376781914383173
# Physicial loss of p2 is: 0.0007034143200144172
# Physicial loss of s is: 0.002739028073847294
# Iteration is: 59280
# Physicial loss of p1 is: 0.0022413129918277264
# Physicial loss of p2 is: 0.0004698235134128481
# Physicial loss of s is: 0.0026775572914630175
# Iteration is: 59290
# Physicial loss of p1 is: 0.0020959714893251657
# Physicial loss of p2 is: 0.00042315502651035786
# Physicial loss of s is: 0.0025589298456907272
# Iteration is: 59300
# Physicial loss of p1 is: 0.0025349557399749756
# Physicial loss of p2 is: 0.0004529328434728086
# Physicial loss of s is: 0.002869928255677223
# Iteration is: 59310
# Physicial loss of p1 is: 0.010917499661445618
# Physicial loss of p2 is: 0.0006797283422201872
# Physicial loss of s is: 0.004326047841459513
# Iteration is: 59320
# Physicial loss of p1 is: 0.0030743598472326994
# Physicial loss of p2 is: 0.0005046829464845359
# Physicial loss of s is: 0.0026188623160123825
# Iteration is: 59330
# Physicial loss of p1 is: 0.0017908656736835837
# Physicial loss of p2 is: 0.0004570030723698437
# Physicial loss of s is: 0.003083295188844204
# Iteration is: 59340
# Physicial loss of p1 is: 0.0035887642297893763
# Physicial loss of p2 is: 0.00048758069169707596
# Physicial loss of s is: 0.0026304160710424185
# Iteration is: 59350
# Physicial loss of p1 is: 0.008699549362063408
# Physicial loss of p2 is: 0.0008449845481663942
# Physicial loss of s is: 0.0025507567916065454
# Iteration is: 59360
# Physicial loss of p1 is: 0.0020002147648483515
# Physicial loss of p2 is: 0.0005931725609116256
# Physicial loss of s is: 0.002794297644868493
# Iteration is: 59370
# Physicial loss of p1 is: 0.0014167249901220202
# Physicial loss of p2 is: 0.0005666528595611453
# Physicial loss of s is: 0.0024496926926076412
# Iteration is: 59380
# Physicial loss of p1 is: 0.003610496176406741
# Physicial loss of p2 is: 0.00044209338375367224
# Physicial loss of s is: 0.0029450026340782642
# Iteration is: 59390
# Physicial loss of p1 is: 0.014642021618783474
# Physicial loss of p2 is: 0.0007448442629538476
# Physicial loss of s is: 0.004101148806512356
# Iteration is: 59400
# Physicial loss of p1 is: 0.0007957817288115621
# Physicial loss of p2 is: 0.0004281250585336238
# Physicial loss of s is: 0.00245048850774765
# Iteration is: 59410
# Physicial loss of p1 is: 0.003412132151424885
# Physicial loss of p2 is: 0.0005859947414137423
# Physicial loss of s is: 0.002793560503050685
# Iteration is: 59420
# Physicial loss of p1 is: 0.0035881237126886845
# Physicial loss of p2 is: 0.0005297954194247723
# Physicial loss of s is: 0.002674003131687641
# Iteration is: 59430
# Physicial loss of p1 is: 0.004370367620140314
# Physicial loss of p2 is: 0.0005229305243119597
# Physicial loss of s is: 0.002764458069577813
# Iteration is: 59440
# Physicial loss of p1 is: 0.006027751602232456
# Physicial loss of p2 is: 0.0006207604892551899
# Physicial loss of s is: 0.0032024821266531944
# Iteration is: 59450
# Physicial loss of p1 is: 0.0030488348565995693
# Physicial loss of p2 is: 0.0005018736119382083
# Physicial loss of s is: 0.00302673177793622
# Iteration is: 59460
# Physicial loss of p1 is: 0.001420714776031673
# Physicial loss of p2 is: 0.0004243089642841369
# Physicial loss of s is: 0.0026355604641139507
# Iteration is: 59470
# Physicial loss of p1 is: 0.00327096413820982
# Physicial loss of p2 is: 0.000488979509100318
# Physicial loss of s is: 0.0027810337487608194
# Iteration is: 59480
# Physicial loss of p1 is: 0.01584159955382347
# Physicial loss of p2 is: 0.0012105676578357816
# Physicial loss of s is: 0.003485431196168065
# Iteration is: 59490
# Physicial loss of p1 is: 0.0016464900691062212
# Physicial loss of p2 is: 0.000440834992332384
# Physicial loss of s is: 0.0033730168361216784
# Iteration is: 59500
# Physicial loss of p1 is: 0.0022098254412412643
# Physicial loss of p2 is: 0.0004852163838222623
# Physicial loss of s is: 0.003376580076292157
# Iteration is: 59510
# Physicial loss of p1 is: 0.001609425526112318
# Physicial loss of p2 is: 0.0004452214343473315
# Physicial loss of s is: 0.002676559379324317
# Iteration is: 59520
# Physicial loss of p1 is: 0.0035933624021708965
# Physicial loss of p2 is: 0.00046029791701585054
# Physicial loss of s is: 0.002613985678181052
# Iteration is: 59530
# Physicial loss of p1 is: 0.007798135280609131
# Physicial loss of p2 is: 0.0006365207955241203
# Physicial loss of s is: 0.002631507581099868
# Iteration is: 59540
# Physicial loss of p1 is: 0.002889126306399703
# Physicial loss of p2 is: 0.0008154980605468154
# Physicial loss of s is: 0.0025478678289800882
# Iteration is: 59550
# Physicial loss of p1 is: 0.000832391669973731
# Physicial loss of p2 is: 0.0004600544343702495
# Physicial loss of s is: 0.0024338210932910442
# Iteration is: 59560
# Physicial loss of p1 is: 0.0019020597683265805
# Physicial loss of p2 is: 0.0004176146467216313
# Physicial loss of s is: 0.0024682553485035896
# Iteration is: 59570
# Physicial loss of p1 is: 0.018065784126520157
# Physicial loss of p2 is: 0.0005810141447000206
# Physicial loss of s is: 0.002613911172375083
# Iteration is: 59580
# Physicial loss of p1 is: 0.0016332586528733373
# Physicial loss of p2 is: 0.0007340605952776968
# Physicial loss of s is: 0.006716200150549412
# Iteration is: 59590
# Physicial loss of p1 is: 0.002141497563570738
# Physicial loss of p2 is: 0.0008366575348190963
# Physicial loss of s is: 0.0038297378923743963
# Iteration is: 59600
# Physicial loss of p1 is: 0.0012398147955536842
# Physicial loss of p2 is: 0.00042947751353494823
# Physicial loss of s is: 0.00251865666359663
# Iteration is: 59610
# Physicial loss of p1 is: 0.0012843707809224725
# Physicial loss of p2 is: 0.0004002716450486332
# Physicial loss of s is: 0.002490706741809845
# Iteration is: 59620
# Physicial loss of p1 is: 0.005945877637714148
# Physicial loss of p2 is: 0.0005322135984897614
# Physicial loss of s is: 0.003169157076627016
# Iteration is: 59630
# Physicial loss of p1 is: 0.008633168414235115
# Physicial loss of p2 is: 0.0010108622955158353
# Physicial loss of s is: 0.003457865444943309
# Iteration is: 59640
# Physicial loss of p1 is: 0.006295578554272652
# Physicial loss of p2 is: 0.0005466960137709975
# Physicial loss of s is: 0.003204272361472249
# Iteration is: 59650
# Physicial loss of p1 is: 0.0007909651030786335
# Physicial loss of p2 is: 0.00040499577880837023
# Physicial loss of s is: 0.0024442581925541162
# Iteration is: 59660
# Physicial loss of p1 is: 0.00259965262375772
# Physicial loss of p2 is: 0.0004424880025908351
# Physicial loss of s is: 0.0025672833435237408
# Iteration is: 59670
# Physicial loss of p1 is: 0.003642523195594549
# Physicial loss of p2 is: 0.0004659685946535319
# Physicial loss of s is: 0.0028382667805999517
# Iteration is: 59680
# Physicial loss of p1 is: 0.0068881013430655
# Physicial loss of p2 is: 0.0005832129972986877
# Physicial loss of s is: 0.003219268750399351
# Iteration is: 59690
# Physicial loss of p1 is: 0.003644786775112152
# Physicial loss of p2 is: 0.0006114018615335226
# Physicial loss of s is: 0.002600514329969883
# Iteration is: 59700
# Physicial loss of p1 is: 0.0009874803945422173
# Physicial loss of p2 is: 0.0004308670468162745
# Physicial loss of s is: 0.002436454175040126
# Iteration is: 59710
# Physicial loss of p1 is: 0.000791762548033148
# Physicial loss of p2 is: 0.0004004895163234323
# Physicial loss of s is: 0.0024162069894373417
# Iteration is: 59720
# Physicial loss of p1 is: 0.0007911933935247362
# Physicial loss of p2 is: 0.0004001497873105109
# Physicial loss of s is: 0.0024162684567272663
# Iteration is: 59730
# Physicial loss of p1 is: 0.0008366191177628934
# Physicial loss of p2 is: 0.00048445863649249077
# Physicial loss of s is: 0.002509199781343341
# Iteration is: 59740
# Physicial loss of p1 is: 0.00772256450727582
# Physicial loss of p2 is: 0.0012317091459408402
# Physicial loss of s is: 0.003092133905738592
# Iteration is: 59750
# Physicial loss of p1 is: 0.0008645393536426127
# Physicial loss of p2 is: 0.001984263537451625
# Physicial loss of s is: 0.008299179375171661
# Iteration is: 59760
# Physicial loss of p1 is: 0.0009766685543581843
# Physicial loss of p2 is: 0.000656639167573303
# Physicial loss of s is: 0.0030051954090595245
# Iteration is: 59770
# Physicial loss of p1 is: 0.0010027170646935701
# Physicial loss of p2 is: 0.0005215033888816833
# Physicial loss of s is: 0.002446246799081564
# Iteration is: 59780
# Physicial loss of p1 is: 0.0009332252666354179
# Physicial loss of p2 is: 0.0004601838008966297
# Physicial loss of s is: 0.0024517562706023455
# Iteration is: 59790
# Physicial loss of p1 is: 0.000808520766440779
# Physicial loss of p2 is: 0.0004401469195727259
# Physicial loss of s is: 0.0024585940409451723
# Iteration is: 59800
# Physicial loss of p1 is: 0.0010276143439114094
# Physicial loss of p2 is: 0.00039786865818314254
# Physicial loss of s is: 0.002530872356146574
# Iteration is: 59810
# Physicial loss of p1 is: 0.0011817201739177108
# Physicial loss of p2 is: 0.00040760193951427937
# Physicial loss of s is: 0.002476463094353676
# Iteration is: 59820
# Physicial loss of p1 is: 0.0035257209092378616
# Physicial loss of p2 is: 0.0004174956411588937
# Physicial loss of s is: 0.002613414078950882
# Iteration is: 59830
# Physicial loss of p1 is: 0.016488265246152878
# Physicial loss of p2 is: 0.0006822245195508003
# Physicial loss of s is: 0.003579541342332959
# Iteration is: 59840
# Physicial loss of p1 is: 0.002051234943792224
# Physicial loss of p2 is: 0.00043601193465292454
# Physicial loss of s is: 0.0025474659632891417
# Iteration is: 59850
# Physicial loss of p1 is: 0.0025812562089413404
# Physicial loss of p2 is: 0.0004562311223708093
# Physicial loss of s is: 0.0025956139434129
# Iteration is: 59860
# Physicial loss of p1 is: 0.0008525770390406251
# Physicial loss of p2 is: 0.0003971914993599057
# Physicial loss of s is: 0.0024229222908616066
# Iteration is: 59870
# Physicial loss of p1 is: 0.0027756178751587868
# Physicial loss of p2 is: 0.0004381733015179634
# Physicial loss of s is: 0.0025839947629719973
# Iteration is: 59880
# Physicial loss of p1 is: 0.01888938993215561
# Physicial loss of p2 is: 0.0009154413128271699
# Physicial loss of s is: 0.004073316231369972
# Iteration is: 59890
# Physicial loss of p1 is: 0.000867897120770067
# Physicial loss of p2 is: 0.0004100412770640105
# Physicial loss of s is: 0.0024333358742296696
# Iteration is: 59900
# Physicial loss of p1 is: 0.0035025435499846935
# Physicial loss of p2 is: 0.00046980136539787054
# Physicial loss of s is: 0.0027120783925056458
# Iteration is: 59910
# Physicial loss of p1 is: 0.0008020623354241252
# Physicial loss of p2 is: 0.0004662074497900903
# Physicial loss of s is: 0.0024577691219747066
# Iteration is: 59920
# Physicial loss of p1 is: 0.0009118863963522017
# Physicial loss of p2 is: 0.000394189526559785
# Physicial loss of s is: 0.00242397328838706
# Iteration is: 59930
# Physicial loss of p1 is: 0.005030889064073563
# Physicial loss of p2 is: 0.00044890769640915096
# Physicial loss of s is: 0.0028281600680202246
# Iteration is: 59940
# Physicial loss of p1 is: 0.01630440540611744
# Physicial loss of p2 is: 0.001569407875649631
# Physicial loss of s is: 0.0044267927296459675
# Iteration is: 59950
# Physicial loss of p1 is: 0.007319633383303881
# Physicial loss of p2 is: 0.0005460261600092053
# Physicial loss of s is: 0.003242338541895151
# Iteration is: 59960
# Physicial loss of p1 is: 0.0017715584253892303
# Physicial loss of p2 is: 0.0004721939912997186
# Physicial loss of s is: 0.0026387260295450687
# Iteration is: 59970
# Physicial loss of p1 is: 0.0012519852025434375
# Physicial loss of p2 is: 0.00039831839967519045
# Physicial loss of s is: 0.0025323359295725822
# Iteration is: 59980
# Physicial loss of p1 is: 0.0009575471631251276
# Physicial loss of p2 is: 0.0004088245041202754
# Physicial loss of s is: 0.0024102742318063974
# Iteration is: 59990
# Physicial loss of p1 is: 0.002185502788051963
# Physicial loss of p2 is: 0.0004219095571897924
# Physicial loss of s is: 0.0025181686505675316
# Iteration is: 60000
# Physicial loss of p1 is: 0.01578899286687374
# Physicial loss of p2 is: 0.0008326704264618456
# Physicial loss of s is: 0.004801289178431034
# Iteration is: 60010
# Physicial loss of p1 is: 0.0008669926901347935
# Physicial loss of p2 is: 0.0004009929543826729
# Physicial loss of s is: 0.002520122565329075
# Iteration is: 60020
# Physicial loss of p1 is: 0.003298033494502306
# Physicial loss of p2 is: 0.0005679823807440698
# Physicial loss of s is: 0.00278975791297853
# Iteration is: 60030
# Physicial loss of p1 is: 0.0007947810227051377
# Physicial loss of p2 is: 0.0005044155404902995
# Physicial loss of s is: 0.002524854149669409
# Iteration is: 60040
# Physicial loss of p1 is: 0.0013675439404323697
# Physicial loss of p2 is: 0.000427666847826913
# Physicial loss of s is: 0.002415928291156888
# Iteration is: 60050
# Physicial loss of p1 is: 0.011077520437538624
# Physicial loss of p2 is: 0.0009759428794495761
# Physicial loss of s is: 0.002727258950471878
# Iteration is: 60060
# Physicial loss of p1 is: 0.0024339379742741585
# Physicial loss of p2 is: 0.0005178570281714201
# Physicial loss of s is: 0.0026703972835093737
# Iteration is: 60070
# Physicial loss of p1 is: 0.004780417308211327
# Physicial loss of p2 is: 0.0005675608408637345
# Physicial loss of s is: 0.0027989691589027643
# Iteration is: 60080
# Physicial loss of p1 is: 0.0014550965279340744
# Physicial loss of p2 is: 0.0005760015337727964
# Physicial loss of s is: 0.0024726870469748974
# Iteration is: 60090
# Physicial loss of p1 is: 0.0009333685738965869
# Physicial loss of p2 is: 0.00043442397145554423
# Physicial loss of s is: 0.0024734141770750284
# ...
# Physicial loss of s is: 0.0024212878197431564
# Iteration is: 62580
# Physicial loss of p1 is: 0.010619471780955791
# Physicial loss of p2 is: 0.0005832344759255648
# Physicial loss of s is: 0.0029534343630075455
# Iteration is: 62590
# Physicial loss of p1 is: 0.002625633729621768
# Physicial loss of p2 is: 0.0005584174068644643
# Physicial loss of s is: 0.002459953771904111
# Iteration is: 62600
# Physicial loss of p1 is: 0.0010497375624254346
# Physicial loss of p2 is: 0.0004298097046557814
# Physicial loss of s is: 0.0023491757456213236
# Iteration is: 62610
# Physicial loss of p1 is: 0.004462150391191244
# Physicial loss of p2 is: 0.000403503276174888
# Physicial loss of s is: 0.0024001372512429953
# Iteration is: 62620
# Physicial loss of p1 is: 0.010531418956816196
# Physicial loss of p2 is: 0.0009916623821482062
# Physicial loss of s is: 0.0031100644264370203
# Iteration is: 62630
# Physicial loss of p1 is: 0.0007589637534692883
# Physicial loss of p2 is: 0.00039151086821220815
# Physicial loss of s is: 0.0023034042678773403
# Iteration is: 62640
# Physicial loss of p1 is: 0.00374425551854074
# Physicial loss of p2 is: 0.00041817527380771935
# Physicial loss of s is: 0.002532738260924816
# Iteration is: 62650
# Physicial loss of p1 is: 0.004466156475245953
# Physicial loss of p2 is: 0.0004168014565948397
# Physicial loss of s is: 0.002543168608099222
# Iteration is: 62660
# Physicial loss of p1 is: 0.004795621149241924
# Physicial loss of p2 is: 0.0005679163732565939
# Physicial loss of s is: 0.0027808500453829765
# Iteration is: 62670
# Physicial loss of p1 is: 0.005716381594538689
# Physicial loss of p2 is: 0.0005323056830093265
# Physicial loss of s is: 0.0028195944614708424
# Iteration is: 62680
# Physicial loss of p1 is: 0.0036028267350047827
# Physicial loss of p2 is: 0.0004298222193028778
# Physicial loss of s is: 0.002694537630304694
# Iteration is: 62690
# Physicial loss of p1 is: 0.0026717570144683123
# Physicial loss of p2 is: 0.00040034981793724
# Physicial loss of s is: 0.0026467146817594767
# Iteration is: 62700
# Physicial loss of p1 is: 0.006580661050975323
# Physicial loss of p2 is: 0.0005231519462540746
# Physicial loss of s is: 0.0030962552409619093
# Iteration is: 62710
# Physicial loss of p1 is: 0.007980293594300747
# Physicial loss of p2 is: 0.0010566523997113109
# Physicial loss of s is: 0.0034376021940261126
# Iteration is: 62720
# Physicial loss of p1 is: 0.0007568947039544582
# Physicial loss of p2 is: 0.00045471033081412315
# Physicial loss of s is: 0.0023662340827286243
# Iteration is: 62730
# Physicial loss of p1 is: 0.0026471999008208513
# Physicial loss of p2 is: 0.0004683058359660208
# Physicial loss of s is: 0.003171325195580721
# Iteration is: 62740
# Physicial loss of p1 is: 0.009297915734350681
# Physicial loss of p2 is: 0.0004962760722264647
# Physicial loss of s is: 0.0025453567504882812
# Iteration is: 62750
# Physicial loss of p1 is: 0.0018513952381908894
# Physicial loss of p2 is: 0.0008064351277425885
# Physicial loss of s is: 0.002352270530536771
# Iteration is: 62760
# Physicial loss of p1 is: 0.0009830070193856955
# Physicial loss of p2 is: 0.0004200213006697595
# Physicial loss of s is: 0.00231432868167758
# Iteration is: 62770
# Physicial loss of p1 is: 0.0045965248718857765
# Physicial loss of p2 is: 0.0004683434381149709
# Physicial loss of s is: 0.002387565327808261
# Iteration is: 62780
# Physicial loss of p1 is: 0.013876262120902538
# Physicial loss of p2 is: 0.001678557600826025
# Physicial loss of s is: 0.005341771990060806
# Iteration is: 62790
# Physicial loss of p1 is: 0.0010530062718316913
# Physicial loss of p2 is: 0.0005608387291431427
# Physicial loss of s is: 0.0023358191829174757
# Iteration is: 62800
# Physicial loss of p1 is: 0.0031586959958076477
# Physicial loss of p2 is: 0.0004767701611854136
# Physicial loss of s is: 0.002525586634874344
# Iteration is: 62810
# Physicial loss of p1 is: 0.0014813544694334269
# Physicial loss of p2 is: 0.00047326236381195486
# Physicial loss of s is: 0.002404547994956374
# Iteration is: 62820
# Physicial loss of p1 is: 0.002032594056800008
# Physicial loss of p2 is: 0.000372296228306368
# Physicial loss of s is: 0.0023186702746897936
# Iteration is: 62830
# Physicial loss of p1 is: 0.012675262987613678
# Physicial loss of p2 is: 0.0008025787537917495
# Physicial loss of s is: 0.0027755331248044968
# Iteration is: 62840
# Physicial loss of p1 is: 0.0012465334730222821
# Physicial loss of p2 is: 0.0004334922705311328
# Physicial loss of s is: 0.0028650411404669285
# Iteration is: 62850
# Physicial loss of p1 is: 0.0036624805070459843
# Physicial loss of p2 is: 0.00044198852265253663
# Physicial loss of s is: 0.0023121382109820843
# Iteration is: 62860
# Physicial loss of p1 is: 0.0007479905616492033
# Physicial loss of p2 is: 0.0004140694218222052
# Physicial loss of s is: 0.002784176729619503
# Iteration is: 62870
# Physicial loss of p1 is: 0.0007745861075818539
# Physicial loss of p2 is: 0.00037848539068363607
# Physicial loss of s is: 0.002559325424954295
# Iteration is: 62880
# Physicial loss of p1 is: 0.004344221204519272
# Physicial loss of p2 is: 0.0003907074860762805
# Physicial loss of s is: 0.002320005325600505
# Iteration is: 62890
# Physicial loss of p1 is: 0.017984727397561073
# Physicial loss of p2 is: 0.002065019216388464
# Physicial loss of s is: 0.007813365198671818
# Iteration is: 62900
# Physicial loss of p1 is: 0.0059196678921580315
# Physicial loss of p2 is: 0.0007385266362689435
# Physicial loss of s is: 0.0037802872247993946
# Iteration is: 62910
# Physicial loss of p1 is: 0.0011690094834193587
# Physicial loss of p2 is: 0.0005160279688425362
# Physicial loss of s is: 0.00267315236851573
# Iteration is: 62920
# Physicial loss of p1 is: 0.0017618756974115968
# Physicial loss of p2 is: 0.0004532027232926339
# Physicial loss of s is: 0.0023024645633995533
# Iteration is: 62930
# Physicial loss of p1 is: 0.0008105281740427017
# Physicial loss of p2 is: 0.0003717430226970464
# Physicial loss of s is: 0.002397004049271345
# Iteration is: 62940
# Physicial loss of p1 is: 0.001062000053934753
# Physicial loss of p2 is: 0.00037619133945554495
# Physicial loss of s is: 0.00227295677177608
# Iteration is: 62950
# Physicial loss of p1 is: 0.012745718471705914
# Physicial loss of p2 is: 0.0005312947323545814
# Physicial loss of s is: 0.002750162035226822
# Iteration is: 62960
# Physicial loss of p1 is: 0.0018233623122796416
# Physicial loss of p2 is: 0.0006607717950828373
# Physicial loss of s is: 0.0030092932283878326
# Iteration is: 62970
# Physicial loss of p1 is: 0.004500505514442921
# Physicial loss of p2 is: 0.0005019405507482588
# Physicial loss of s is: 0.003235201584175229
# Iteration is: 62980
# Physicial loss of p1 is: 0.002467856742441654
# Physicial loss of p2 is: 0.0008800184004940093
# Physicial loss of s is: 0.002682980615645647
# Iteration is: 62990
# Physicial loss of p1 is: 0.0011037748772650957
# Physicial loss of p2 is: 0.00041788743692450225
# Physicial loss of s is: 0.0023095307406038046
# Iteration is: 63000
# Physicial loss of p1 is: 0.0009130670805461705
# Physicial loss of p2 is: 0.0003943859483115375
# Physicial loss of s is: 0.0023314482532441616
# Iteration is: 63010
# Physicial loss of p1 is: 0.006054512225091457
# Physicial loss of p2 is: 0.0004929094575345516
# Physicial loss of s is: 0.002882071305066347
# Iteration is: 63020
# Physicial loss of p1 is: 0.006596616934984922
# Physicial loss of p2 is: 0.0009736396023072302
# Physicial loss of s is: 0.003998765721917152
# Iteration is: 63030
# Physicial loss of p1 is: 0.00322479335591197
# Physicial loss of p2 is: 0.0004504212993197143
# Physicial loss of s is: 0.003516635624691844
# Iteration is: 63040
# Physicial loss of p1 is: 0.0024300396908074617
# Physicial loss of p2 is: 0.0005026637809351087
# Physicial loss of s is: 0.002432715380564332
# Iteration is: 63050
# Physicial loss of p1 is: 0.000944393512327224
# Physicial loss of p2 is: 0.0003800838894676417
# Physicial loss of s is: 0.0024409268517047167
# Iteration is: 63060
# Physicial loss of p1 is: 0.0014497111551463604
# Physicial loss of p2 is: 0.0003625438257586211
# Physicial loss of s is: 0.002288664225488901
# Iteration is: 63070
# Physicial loss of p1 is: 0.02140245959162712
# Physicial loss of p2 is: 0.0009605360100977123
# Physicial loss of s is: 0.0028963142540305853
# Iteration is: 63080
# Physicial loss of p1 is: 0.0007953669410198927
# Physicial loss of p2 is: 0.00040644212276674807
# Physicial loss of s is: 0.002343995263800025
# Iteration is: 63090
# Physicial loss of p1 is: 0.0015409458428621292
# Physicial loss of p2 is: 0.0003972408885601908
# Physicial loss of s is: 0.0024509739596396685
# Iteration is: 63100
# Physicial loss of p1 is: 0.0022244250867515802
# Physicial loss of p2 is: 0.00040640897350385785
# Physicial loss of s is: 0.0023318554740399122
# Iteration is: 63110
# Physicial loss of p1 is: 0.0007535248878411949
# Physicial loss of p2 is: 0.00038737052818760276
# Physicial loss of s is: 0.002573128091171384
# Iteration is: 63120
# Physicial loss of p1 is: 0.000741990574169904
# Physicial loss of p2 is: 0.00036119669675827026
# Physicial loss of s is: 0.002332232892513275
# Iteration is: 63130
# Physicial loss of p1 is: 0.0007402097689919174
# Physicial loss of p2 is: 0.0003672949387691915
# Physicial loss of s is: 0.002317768754437566
# Iteration is: 63140
# Physicial loss of p1 is: 0.000807913311291486
# Physicial loss of p2 is: 0.0003983084170613438
# Physicial loss of s is: 0.0024404465220868587
# Iteration is: 63150
# Physicial loss of p1 is: 0.02600737288594246
# Physicial loss of p2 is: 0.0008855100604705513
# Physicial loss of s is: 0.007191757205873728
# Iteration is: 63160
# Physicial loss of p1 is: 0.0041601951234042645
# Physicial loss of p2 is: 0.0007617536466568708
# Physicial loss of s is: 0.005439432337880135
# Iteration is: 63170
# Physicial loss of p1 is: 0.001004603342153132
# Physicial loss of p2 is: 0.000562150264158845
# Physicial loss of s is: 0.0032082328107208014
# Iteration is: 63180
# Physicial loss of p1 is: 0.0009048267384059727
# Physicial loss of p2 is: 0.0004049209237564355
# Physicial loss of s is: 0.0023914258927106857
# Iteration is: 63190
# Physicial loss of p1 is: 0.0014488802989944816
# Physicial loss of p2 is: 0.0005018616211600602
# Physicial loss of s is: 0.0027066669426858425
# Iteration is: 63200
# Physicial loss of p1 is: 0.0008163547609001398
# Physicial loss of p2 is: 0.0003919702139683068
# Physicial loss of s is: 0.0022931634448468685
# Iteration is: 63210
# Physicial loss of p1 is: 0.0016593328909948468
# Physicial loss of p2 is: 0.0003647194826044142
# Physicial loss of s is: 0.0023096022196114063
# Iteration is: 63220
# Physicial loss of p1 is: 0.010469401255249977
# Physicial loss of p2 is: 0.00048446012078784406
# Physicial loss of s is: 0.002521002199500799
# Iteration is: 63230
# Physicial loss of p1 is: 0.002348132897168398
# Physicial loss of p2 is: 0.00040034743142314255
# Physicial loss of s is: 0.00237686256878078
# Iteration is: 63240
# Physicial loss of p1 is: 0.004528169985860586
# Physicial loss of p2 is: 0.0004493827873375267
# Physicial loss of s is: 0.0025128384586423635
# Iteration is: 63250
# Physicial loss of p1 is: 0.0010397511068731546
# Physicial loss of p2 is: 0.0003612132859416306
# Physicial loss of s is: 0.002283044857904315
# Iteration is: 63260
# Physicial loss of p1 is: 0.0009679680806584656
# Physicial loss of p2 is: 0.0003659678332041949
# Physicial loss of s is: 0.0022776303812861443
# Iteration is: 63270
# Physicial loss of p1 is: 0.005379901733249426
# Physicial loss of p2 is: 0.00046697197831235826
# Physicial loss of s is: 0.0025261661503463984
# Iteration is: 63280
# Physicial loss of p1 is: 0.010354162193834782
# Physicial loss of p2 is: 0.0009968793019652367
# Physicial loss of s is: 0.0034187855198979378
# Iteration is: 63290
# Physicial loss of p1 is: 0.00531634921208024
# Physicial loss of p2 is: 0.0004817953158635646
# Physicial loss of s is: 0.0025810084771364927
# Iteration is: 63300
# Physicial loss of p1 is: 0.0007944738026708364
# Physicial loss of p2 is: 0.00037524098297581077
# Physicial loss of s is: 0.002377735683694482
# Iteration is: 63310
# Physicial loss of p1 is: 0.0018718233332037926
# Physicial loss of p2 is: 0.00037655862979590893
# Physicial loss of s is: 0.0023753936402499676
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[459], line 6
#       4 while it <= Nmax:
#       5     if it<10**5:
# ----> 6         loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#       7     else:
#       8         loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1601, in ConcreteFunction.__call__(self, *args, **kwargs)
#    1551 def __call__(self, *args, **kwargs):
#    1552   """Executes the wrapped function.
#    1553
#    1554   ConcreteFunctions have two signatures:
#    (...)
#    1599     TypeError: If the arguments do not match the function's signature.
#    1600   """
# -> 1601   return self._call_impl(args, kwargs)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1610, in ConcreteFunction._call_impl(self, args, kwargs, cancellation_manager)
#    1608 if self._function_spec is not None:
#    1609   try:
# -> 1610     return self._call_with_structured_signature(args, kwargs,
#    1611                                                 cancellation_manager)
#    1612   except TypeError as structured_err:
#    1613     try:
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1691, in ConcreteFunction._call_with_structured_signature(self, args, kwargs, cancellation_manager)
#    1689 self._structured_signature_check_unexpected_args(args, kwargs)
#    1690 self._structured_signature_check_arg_types(args, kwargs)
# -> 1691 return self._call_flat(
#    1692     filtered_flat_args,
#    1693     captured_inputs=self.captured_inputs,
#    1694     cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip1_list = [loss_fisp1[i].numpy() for i in range(0,Nmax)]
loss_phip2_list = [loss_fisp2[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(ep, np.asarray(loss_data_list), 'b-', linewidth = 2, alpha=0.6, label = 'Data')  
plt.semilogy(ep, np.asarray(loss_phip1_list), 'r-', linewidth = 2, alpha=0.6, label = '$\phi_p1$') 
plt.semilogy(ep, np.asarray(loss_phip2_list), 'y-', linewidth = 2, alpha=0.6, label = '$\phi_p2$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\phi_s$')       


plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
lnv[0], tf.exp(lnv[0]), lnv[1], tf.exp(lnv[1]), lnv[2], tf.exp(lnv[2])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([5.016145], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([150.82877], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.8660528], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([2.377508], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([-2.399087], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.09080082], dtype=float32)>)

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp1=u_pred[:,0:1]
lnp2=u_pred[:,1:2]
lns=u_pred[:,2:3]

p1=tf.exp(lnp1)
p2=tf.exp(lnp2)
s=tf.exp(lns)

lnl2=predict(X_star_tf[...,2:3], W_a, b_a)

l2=tf.exp(lnl2)
# phi = tf.exp(predict(tf.concat([p, s, l],1), W_phi, b_phi))
phi = tf.exp(predict(s, W_phi, b_phi))


m=tf.exp(lnv[0:1])
l1=tf.exp(lnv[1:2])
mn=tf.exp(lnv[1:2])



phi_s=-np.array((p1+p2)*s*m)

# %%
X_star_tf.shape, p1.shape
# Out:
# (TensorShape([6498, 3]), TensorShape([6498, 1]))

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],(p1+p2)[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

k=3
# Seleccionar el color correspondiente de la paleta
color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
for i in range(j):
    # Aquí puedes pasar el color seleccionado en cada iteración
    # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
    plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p1[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], linestyle=':',  color=color, label='Prediction P')
    plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)],   color=color, label='Prediction P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p1[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], linestyle=':',  color=color, label='Prediction P')
        plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)],   color=color, label='Prediction P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
