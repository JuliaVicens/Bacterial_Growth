# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2024-12-30 22:24:03.233410: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-12-30 22:24:03.233731: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2024-12-30 22:24:03.234013: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2024-12-30 22:24:03.234297: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2024-12-30 22:24:03.234642: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2024-12-30 22:24:03.235005: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2024-12-30 22:24:03.235270: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2024-12-30 22:24:03.235531: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2024-12-30 22:24:03.235622: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# []
# Num GPUs Available:  0

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x28b84ee29a0>,
#  <matplotlib.lines.Line2D at 0x28b84ee2a00>,
#  <matplotlib.lines.Line2D at 0x28b84ee2a30>,
#  <matplotlib.lines.Line2D at 0x28b84ee2b20>,
#  <matplotlib.lines.Line2D at 0x28b84ee2c10>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.array(df2.iloc[:, 9:14])
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
N_exp,T_max, T_exp.shape, P_exp.shape
# Out:
# (5, 231399.5, (342,), (342, 5))

# %%
for i in range(N_exp):
    plt.plot(T_exp,P_exp[:, i])
plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
P0=P_exp[0,:]
T_meshgrid, P0_meshgrid, = np.meshgrid(T_exp, P0)
X_star = np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None]))
u_star=np.hstack((P_star,P0_meshgrid.flatten()[:,None]))


# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0)).reshape([-1,1]), P0.reshape([-1,1])))

xx01=np.vstack((xx0, xx1))
uu01=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(2, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_tf = tf.convert_to_tensor(uu01, dtype=tf.float32)
# Out:
# 2024-12-30 22:24:04.479379: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
L_exp=len(P_exp[:,1])
for i in range(N_exp):
    plt.plot(X_star[L_exp*i:L_exp*(i+1)][:,0],P_exp[:, i])
    plt.scatter(X_star[L_exp*i:L_exp*(i+1)][:,0],P_star[L_exp*i:L_exp*(i+1)], marker='x', s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for i in range(N_exp):
    plt.plot(X_star[L_exp*i:L_exp*(i+1)][:,1],P_exp[:, i])
    plt.scatter(X_star[L_exp*i:L_exp*(i+1)][:,1],P_star[L_exp*i:L_exp*(i+1)], marker='x', s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for i in range(N_exp):
    plt.scatter(X_star[L_exp*i:L_exp*(i+1)][:,0],P_star[L_exp*i:L_exp*(i+1)], marker='x', s=1)
    plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 3]), dtype=tf.float32)
    # alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1)))
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp * 2 * 2), (N_exp * 2, 2))) 
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p,  W_phi_1, b_phi_1, W_phi_2, b_phi_2, lnv):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)


        lnp1=u[:,0:1]
        lnp2=u[:,1:2]
        lns=u[:,2:3]

        p1=tf.exp(lnp1)
        p2=tf.exp(lnp2)
        s=tf.exp(lns)

        lnphi=net(s, W_phi_1, b_phi_1)
        phi11=tf.exp(lnphi[...,0:1])

        phi12=phi11

        phi2=tf.exp(lnphi[...,1:2])
        delta1=tf.exp(lnv[0:1])
        delta2=tf.exp(lnv[1:2])

  
    p1_t = tape1.gradient(p1, X_f)[...,0:1]
    p2_t = tape1.gradient(p2, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]

    f_p1 = p1_t - phi11*p1 - phi2*p1 +delta1*p1
    f_p2 = p2_t - phi12*p2 + phi2*p1 +delta2*p2
    f_s = s_t + phi11*p1 + phi12*p2
    
    return f_p1, f_p2, f_s




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi_1,b_phi_1, W_phi_2, b_phi_2,   X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi_1,b_phi_1, W_phi_2, b_phi_2,  lambda_b, lambda_r, lambda_0, lnv])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp1=u_nn[:,0:1]
        lnp2=u_nn[:,1:2]
        p1_nn=tf.exp(lnp1)
        p2_nn=tf.exp(lnp2)
        f_p1, f_p2, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi_1,b_phi_1, W_phi_2, b_phi_2,  lnv)

        u_00 = net(xx01_tf, W_p, b_p) 
      
        p1_00=tf.exp(u_00[:,0:1])
        p2_00=tf.exp(u_00[:,1:2])
        s_00=tf.exp(u_00[:,2:3])


        loss_p = tf.square(lambda_b*(p1_nn+p2_nn - P_train_tf))
        loss_0s = tf.square(lambda_0[:,0:1]*(s_00 - uu01_tf))
        loss_0p1 = tf.square(lambda_0[:N_exp,1:2]*(p1_00[:N_exp] - uu01_tf[N_exp:])) #p1 al principio peque
        loss_0p2 = tf.square(lambda_0[N_exp:,1:2]*(p2_00[:N_exp] - P_train_tf[:N_exp])) #p2 al principio la poblacion
        loss_1p2 = tf.square(lambda_0[N_exp:,1:2]*(p2_00[N_exp:] - uu01_tf[N_exp:])) #p2 al final peque
        loss_fp1 = tf.square(lambda_r[:,0:1]*f_p1) 
        loss_fp2 = tf.square(lambda_r[:,1:2]*f_p2) 
        loss_fs = tf.square(lambda_r[:,2:3]*f_s) 


        # loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)
        # loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)+ tf.reduce_mean(loss_0p1)+ tf.reduce_mean(loss_0p2)
        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi_1 = tape.gradient(loss, train_vars(W_phi_1, b_phi_1))
    # grads_phi_2 = tape.gradient(loss, train_vars(W_phi_2, b_phi_2))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)

    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi_1, train_vars(W_phi_1, b_phi_1)))
    # opt.apply_gradients(zip(grads_phi_2, train_vars(W_phi_2, b_phi_2)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p1_nn+p2_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p1)), tf.reduce_mean(tf.square(f_p2)), tf.reduce_mean(tf.square(f_s))


layers = [2, 20, 20, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 2]

W_phi_1 = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi_1 = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]
L = len(layers)

W_phi_2 = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi_2 = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 2), (2, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
lr = 5e-3




optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/10)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp1 = []
loss_fisp2 = []
loss_fiss = []
# loss_reg=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi_1, b_phi_1,  W_phi_2, b_phi_2, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf,  lambda_r, lambda_b, lambda_0, lnv, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi_1, b_phi_1,  W_phi_2, b_phi_2, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, optimizer2)
# train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=5*10**4


while it <= Nmax:
    # if it<10**5:
    loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi_1, b_phi_1,  W_phi_2, b_phi_2, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else:
    #     loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi_1, b_phi_1,  W_phi_2, b_phi_2, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else
        # loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp1.append(loss_fp1)
    loss_fisp2.append(loss_fp2)
    loss_fiss.append(loss_fs)
    # loss_fisa.append(loss_fa)



    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        # print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p1 is: {loss_fp1}")
        print(f"Physicial loss of p2 is: {loss_fp2}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Physicial loss of p1 is: 0.6487468481063843
# Physicial loss of p2 is: 6.01494836807251
# Physicial loss of s is: 1.8751184940338135
# Iteration is: 10
# Physicial loss of p1 is: 0.024136440828442574
# Physicial loss of p2 is: 0.09160199016332626
# Physicial loss of s is: 0.025838419795036316
# Iteration is: 20
# Physicial loss of p1 is: 0.03905560448765755
# Physicial loss of p2 is: 0.028377363458275795
# Physicial loss of s is: 0.11130865663290024
# Iteration is: 30
# Physicial loss of p1 is: 0.1854168325662613
# Physicial loss of p2 is: 0.1661793440580368
# Physicial loss of s is: 0.3066590428352356
# Iteration is: 40
# Physicial loss of p1 is: 0.1578211635351181
# Physicial loss of p2 is: 0.14022576808929443
# Physicial loss of s is: 0.23181265592575073
# Iteration is: 50
# Physicial loss of p1 is: 0.16561676561832428
# Physicial loss of p2 is: 0.15287333726882935
# Physicial loss of s is: 0.2241431623697281
# Iteration is: 60
# Physicial loss of p1 is: 0.14355002343654633
# Physicial loss of p2 is: 0.15233094990253448
# Physicial loss of s is: 0.26419252157211304
# Iteration is: 70
# Physicial loss of p1 is: 0.14068922400474548
# Physicial loss of p2 is: 0.3031969964504242
# Physicial loss of s is: 0.24977128207683563
# Iteration is: 80
# Physicial loss of p1 is: 0.1392877697944641
# Physicial loss of p2 is: 0.24036239087581635
# Physicial loss of s is: 0.3307323455810547
# Iteration is: 90
# Physicial loss of p1 is: 0.1789117008447647
# Physicial loss of p2 is: 0.40134936571121216
# Physicial loss of s is: 0.3067300319671631
# Iteration is: 100
# Physicial loss of p1 is: 0.21384166181087494
# Physicial loss of p2 is: 0.5462256669998169
# Physicial loss of s is: 0.30788514018058777
# Iteration is: 110
# Physicial loss of p1 is: 0.23565293848514557
# Physicial loss of p2 is: 0.5754643082618713
# Physicial loss of s is: 0.26984354853630066
# Iteration is: 120
# Physicial loss of p1 is: 0.26481208205223083
# Physicial loss of p2 is: 0.5958606600761414
# Physicial loss of s is: 0.2551414668560028
# Iteration is: 130
# Physicial loss of p1 is: 0.2561766505241394
# Physicial loss of p2 is: 0.5213860869407654
# Physicial loss of s is: 0.2936040759086609
# Iteration is: 140
# Physicial loss of p1 is: 0.2654433250427246
# Physicial loss of p2 is: 0.47165918350219727
# Physicial loss of s is: 0.2938920557498932
# Iteration is: 150
# Physicial loss of p1 is: 0.2711513638496399
# Physicial loss of p2 is: 0.4387323260307312
# Physicial loss of s is: 0.28987836837768555
# Iteration is: 160
# Physicial loss of p1 is: 0.2801014184951782
# Physicial loss of p2 is: 0.42509227991104126
# Physicial loss of s is: 0.2686413824558258
# Iteration is: 170
# Physicial loss of p1 is: 0.2783780097961426
# Physicial loss of p2 is: 0.41209670901298523
# Physicial loss of s is: 0.26748576760292053
# Iteration is: 180
# Physicial loss of p1 is: 0.2884892523288727
# Physicial loss of p2 is: 0.4158942997455597
# Physicial loss of s is: 0.24356809258460999
# Iteration is: 190
# Physicial loss of p1 is: 0.26233699917793274
# Physicial loss of p2 is: 0.38513320684432983
# Physicial loss of s is: 0.28907230496406555
# Iteration is: 200
# Physicial loss of p1 is: 0.2713093161582947
# Physicial loss of p2 is: 0.39219483733177185
# Physicial loss of s is: 0.2668509781360626
# Iteration is: 210
# Physicial loss of p1 is: 0.27587780356407166
# Physicial loss of p2 is: 0.394812673330307
# Physicial loss of s is: 0.2574019134044647
# Iteration is: 220
# Physicial loss of p1 is: 0.259640634059906
# Physicial loss of p2 is: 0.3757377564907074
# Physicial loss of s is: 0.2895689010620117
# Iteration is: 230
# Physicial loss of p1 is: 0.2674980163574219
# Physicial loss of p2 is: 0.38279613852500916
# Physicial loss of s is: 0.2743403911590576
# Iteration is: 240
# Physicial loss of p1 is: 0.26247575879096985
# Physicial loss of p2 is: 0.37616080045700073
# Physicial loss of s is: 0.28648367524147034
# Iteration is: 250
# Physicial loss of p1 is: 0.2517077624797821
# Physicial loss of p2 is: 0.3638627529144287
# Physicial loss of s is: 0.31250321865081787
# Iteration is: 260
# Physicial loss of p1 is: 0.2620583176612854
# Physicial loss of p2 is: 0.3758516311645508
# Physicial loss of s is: 0.2915360927581787
# Iteration is: 270
# Physicial loss of p1 is: 0.26199015974998474
# Physicial loss of p2 is: 0.3766442835330963
# Physicial loss of s is: 0.29376107454299927
# Iteration is: 280
# Physicial loss of p1 is: 0.2671409547328949
# Physicial loss of p2 is: 0.3846423327922821
# Physicial loss of s is: 0.28459736704826355
# Iteration is: 290
# Physicial loss of p1 is: 0.26947131752967834
# Physicial loss of p2 is: 0.39015495777130127
# Physicial loss of s is: 0.28124120831489563
# Iteration is: 300
# Physicial loss of p1 is: 0.2805843949317932
# Physicial loss of p2 is: 0.4070488214492798
# Physicial loss of s is: 0.2611513137817383
# Iteration is: 310
# Physicial loss of p1 is: 0.26838192343711853
# Physicial loss of p2 is: 0.39768990874290466
# Physicial loss of s is: 0.284898042678833
# Iteration is: 320
# Physicial loss of p1 is: 0.2581426501274109
# Physicial loss of p2 is: 0.3908500671386719
# Physicial loss of s is: 0.30698317289352417
# Iteration is: 330
# Physicial loss of p1 is: 0.2694602310657501
# Physicial loss of p2 is: 0.40815234184265137
# Physicial loss of s is: 0.285636305809021
# Iteration is: 340
# Physicial loss of p1 is: 0.26079824566841125
# Physicial loss of p2 is: 0.40363049507141113
# Physicial loss of s is: 0.3043842613697052
# Iteration is: 350
# Physicial loss of p1 is: 0.26983779668807983
# Physicial loss of p2 is: 0.41911426186561584
# Physicial loss of s is: 0.28848448395729065
# Iteration is: 360
# Physicial loss of p1 is: 0.25639212131500244
# Physicial loss of p2 is: 0.4102587103843689
# Physicial loss of s is: 0.3163694739341736
# Iteration is: 370
# Physicial loss of p1 is: 0.26817241311073303
# Physicial loss of p2 is: 0.4297329783439636
# Physicial loss of s is: 0.295137494802475
# Iteration is: 380
# Physicial loss of p1 is: 0.24709303677082062
# Physicial loss of p2 is: 0.41232430934906006
# Physicial loss of s is: 0.33905142545700073
# Iteration is: 390
# Physicial loss of p1 is: 0.2515988051891327
# Physicial loss of p2 is: 0.42263317108154297
# Physicial loss of s is: 0.33103466033935547
# Iteration is: 400
# Physicial loss of p1 is: 0.2574259340763092
# Physicial loss of p2 is: 0.43447020649909973
# Physicial loss of s is: 0.3206166625022888
# Iteration is: 410
# Physicial loss of p1 is: 0.2594224512577057
# Physicial loss of p2 is: 0.4397728741168976
# Physicial loss of s is: 0.31927821040153503
# Iteration is: 420
# Physicial loss of p1 is: 0.27080675959587097
# Physicial loss of p2 is: 0.45580339431762695
# Physicial loss of s is: 0.30009374022483826
# Iteration is: 430
# Physicial loss of p1 is: 0.2533930242061615
# Physicial loss of p2 is: 0.4358634948730469
# Physicial loss of s is: 0.3363092243671417
# Iteration is: 440
# Physicial loss of p1 is: 0.25722312927246094
# Physicial loss of p2 is: 0.4419339895248413
# Physicial loss of s is: 0.32900094985961914
# Iteration is: 450
# Physicial loss of p1 is: 0.2609361708164215
# Physicial loss of p2 is: 0.44694784283638
# Physicial loss of s is: 0.32171207666397095
# Iteration is: 460
# Physicial loss of p1 is: 0.2745454013347626
# Physicial loss of p2 is: 0.4648122489452362
# Physicial loss of s is: 0.2947540879249573
# Iteration is: 470
# Physicial loss of p1 is: 0.26508885622024536
# Physicial loss of p2 is: 0.450225830078125
# Physicial loss of s is: 0.3145712614059448
# Iteration is: 480
# Physicial loss of p1 is: 0.2595338523387909
# Physicial loss of p2 is: 0.4413749873638153
# Physicial loss of s is: 0.3280620872974396
# Iteration is: 490
# Physicial loss of p1 is: 0.26169276237487793
# Physicial loss of p2 is: 0.44134464859962463
# Physicial loss of s is: 0.32582148909568787
# Iteration is: 500
# Physicial loss of p1 is: 0.2535228729248047
# Physicial loss of p2 is: 0.42769965529441833
# Physicial loss of s is: 0.3482361137866974
# Iteration is: 510
# Physicial loss of p1 is: 0.2724814713001251
# Physicial loss of p2 is: 0.4497659504413605
# Physicial loss of s is: 0.30848243832588196
# Iteration is: 520
# Physicial loss of p1 is: 0.26450544595718384
# Physicial loss of p2 is: 0.43432819843292236
# Physicial loss of s is: 0.3315139412879944
# Iteration is: 530
# Physicial loss of p1 is: 0.28061187267303467
# Physicial loss of p2 is: 0.447640597820282
# Physicial loss of s is: 0.30479589104652405
# Iteration is: 540
# Physicial loss of p1 is: 0.26788529753685
# Physicial loss of p2 is: 0.41790884733200073
# Physicial loss of s is: 0.3470812439918518
# Iteration is: 550
# Physicial loss of p1 is: 0.2800520062446594
# Physicial loss of p2 is: 0.4146115779876709
# Physicial loss of s is: 0.33905813097953796
# Iteration is: 560
# Physicial loss of p1 is: 0.28580188751220703
# Physicial loss of p2 is: 0.41563981771469116
# Physicial loss of s is: 0.33454039692878723
# Iteration is: 570
# Physicial loss of p1 is: 0.29686328768730164
# Physicial loss of p2 is: 0.4248591363430023
# Physicial loss of s is: 0.31755274534225464
# Iteration is: 580
# Physicial loss of p1 is: 0.30261164903640747
# Physicial loss of p2 is: 0.42888906598091125
# Physicial loss of s is: 0.311069518327713
# Iteration is: 590
# Physicial loss of p1 is: 0.29117825627326965
# Physicial loss of p2 is: 0.4115532636642456
# Physicial loss of s is: 0.34083810448646545
# Iteration is: 600
# Physicial loss of p1 is: 0.30238601565361023
# Physicial loss of p2 is: 0.42492061853408813
# Physicial loss of s is: 0.31882697343826294
# Iteration is: 610
# Physicial loss of p1 is: 0.3020646274089813
# Physicial loss of p2 is: 0.42336568236351013
# Physicial loss of s is: 0.3220503628253937
# Iteration is: 620
# Physicial loss of p1 is: 0.30185478925704956
# Physicial loss of p2 is: 0.42233458161354065
# Physicial loss of s is: 0.324566513299942
# Iteration is: 630
# Physicial loss of p1 is: 0.31094104051589966
# Physicial loss of p2 is: 0.43447861075401306
# Physicial loss of s is: 0.3065749406814575
# Iteration is: 640
# Physicial loss of p1 is: 0.3076697587966919
# Physicial loss of p2 is: 0.42831510305404663
# Physicial loss of s is: 0.3161441385746002
# Iteration is: 650
# Physicial loss of p1 is: 0.30503493547439575
# Physicial loss of p2 is: 0.4249589741230011
# Physicial loss of s is: 0.3229540288448334
# Iteration is: 660
# Physicial loss of p1 is: 0.3031618893146515
# Physicial loss of p2 is: 0.4229515790939331
# Physicial loss of s is: 0.32805317640304565
# Iteration is: 670
# Physicial loss of p1 is: 0.30034956336021423
# Physicial loss of p2 is: 0.41888415813446045
# Physicial loss of s is: 0.33612680435180664
# Iteration is: 680
# Physicial loss of p1 is: 0.302506685256958
# Physicial loss of p2 is: 0.42090070247650146
# Physicial loss of s is: 0.3334473669528961
# Iteration is: 690
# Physicial loss of p1 is: 0.300593763589859
# Physicial loss of p2 is: 0.41802921891212463
# Physicial loss of s is: 0.3395344018936157
# Iteration is: 700
# Physicial loss of p1 is: 0.2891363799571991
# Physicial loss of p2 is: 0.40358930826187134
# Physicial loss of s is: 0.3680996596813202
# Iteration is: 710
# Physicial loss of p1 is: 0.3032115697860718
# Physicial loss of p2 is: 0.41986551880836487
# Physicial loss of s is: 0.337860107421875
# Iteration is: 720
# Physicial loss of p1 is: 0.3063129782676697
# Physicial loss of p2 is: 0.4231586456298828
# Physicial loss of s is: 0.3329748213291168
# Iteration is: 730
# Physicial loss of p1 is: 0.3078837990760803
# Physicial loss of p2 is: 0.4248885214328766
# Physicial loss of s is: 0.33126571774482727
# Iteration is: 740
# Physicial loss of p1 is: 0.3059239983558655
# Physicial loss of p2 is: 0.42192843556404114
# Physicial loss of s is: 0.3374590277671814
# Iteration is: 750
# Physicial loss of p1 is: 0.3057542145252228
# Physicial loss of p2 is: 0.42108309268951416
# Physicial loss of s is: 0.33986082673072815
# Iteration is: 760
# Physicial loss of p1 is: 0.3056706488132477
# Physicial loss of p2 is: 0.4202781915664673
# Physicial loss of s is: 0.3421022593975067
# Iteration is: 770
# Physicial loss of p1 is: 0.30183497071266174
# Physicial loss of p2 is: 0.41449010372161865
# Physicial loss of s is: 0.3532051146030426
# Iteration is: 780
# Physicial loss of p1 is: 0.31528913974761963
# Physicial loss of p2 is: 0.43162938952445984
# Physicial loss of s is: 0.3248220682144165
# Iteration is: 790
# Physicial loss of p1 is: 0.310314416885376
# Physicial loss of p2 is: 0.42458319664001465
# Physicial loss of s is: 0.33738866448402405
# Iteration is: 800
# Physicial loss of p1 is: 0.3085435926914215
# Physicial loss of p2 is: 0.4216243624687195
# Physicial loss of s is: 0.34330281615257263
# Iteration is: 810
# Physicial loss of p1 is: 0.30802738666534424
# Physicial loss of p2 is: 0.42031294107437134
# Physicial loss of s is: 0.34648436307907104
# Iteration is: 820
# Physicial loss of p1 is: 0.31059354543685913
# Physicial loss of p2 is: 0.4232051968574524
# Physicial loss of s is: 0.3424275815486908
# Iteration is: 830
# Physicial loss of p1 is: 0.31168845295906067
# Physicial loss of p2 is: 0.42412862181663513
# Physicial loss of s is: 0.3417336940765381
# Iteration is: 840
# Physicial loss of p1 is: 0.31265923380851746
# Physicial loss of p2 is: 0.4249991774559021
# Physicial loss of s is: 0.3412242829799652
# Iteration is: 850
# Physicial loss of p1 is: 0.3148133456707001
# Physicial loss of p2 is: 0.4276388883590698
# Physicial loss of s is: 0.3378928601741791
# Iteration is: 860
# Physicial loss of p1 is: 0.3210427761077881
# Physicial loss of p2 is: 0.43618759512901306
# Physicial loss of s is: 0.32540181279182434
# Iteration is: 870
# Physicial loss of p1 is: 0.3185877203941345
# Physicial loss of p2 is: 0.4325835704803467
# Physicial loss of s is: 0.33215662837028503
# Iteration is: 880
# Physicial loss of p1 is: 0.31601494550704956
# Physicial loss of p2 is: 0.42867761850357056
# Physicial loss of s is: 0.33941230177879333
# Iteration is: 890
# Physicial loss of p1 is: 0.3155738115310669
# Physicial loss of p2 is: 0.4275030195713043
# Physicial loss of s is: 0.3421350121498108
# Iteration is: 900
# Physicial loss of p1 is: 0.31605076789855957
# Physicial loss of p2 is: 0.4277513921260834
# Physicial loss of s is: 0.34258684515953064
# Iteration is: 910
# Physicial loss of p1 is: 0.3161698281764984
# Physicial loss of p2 is: 0.4274846315383911
# Physicial loss of s is: 0.34379842877388
# Iteration is: 920
# Physicial loss of p1 is: 0.31551024317741394
# Physicial loss of p2 is: 0.42584407329559326
# Physicial loss of s is: 0.3470112681388855
# Iteration is: 930
# Physicial loss of p1 is: 0.3164348304271698
# Physicial loss of p2 is: 0.42667651176452637
# Physicial loss of s is: 0.3462486267089844
# Iteration is: 940
# Physicial loss of p1 is: 0.3164873421192169
# Physicial loss of p2 is: 0.42604565620422363
# Physicial loss of s is: 0.34766077995300293
# Iteration is: 950
# Physicial loss of p1 is: 0.31669947504997253
# Physicial loss of p2 is: 0.4255920350551605
# Physicial loss of s is: 0.34868836402893066
# Iteration is: 960
# Physicial loss of p1 is: 0.3094777762889862
# Physicial loss of p2 is: 0.41248995065689087
# Physicial loss of s is: 0.3698946237564087
# Iteration is: 970
# Physicial loss of p1 is: 0.32346510887145996
# Physicial loss of p2 is: 0.4356015920639038
# Physicial loss of s is: 0.3343711197376251
# Iteration is: 980
# Physicial loss of p1 is: 0.3190106153488159
# Physicial loss of p2 is: 0.42718297243118286
# Physicial loss of s is: 0.3469664752483368
# Iteration is: 990
# Physicial loss of p1 is: 0.3173541724681854
# Physicial loss of p2 is: 0.4237994849681854
# Physicial loss of s is: 0.35247644782066345
# Iteration is: 1000
# Physicial loss of p1 is: 0.31804758310317993
# Physicial loss of p2 is: 0.42401668429374695
# Physicial loss of s is: 0.3521675169467926
# Iteration is: 1010
# Physicial loss of p1 is: 0.3191073536872864
# Physicial loss of p2 is: 0.4251737594604492
# Physicial loss of s is: 0.3505270481109619
# Iteration is: 1020
# Physicial loss of p1 is: 0.32022836804389954
# Physicial loss of p2 is: 0.42657601833343506
# Physicial loss of s is: 0.348542720079422
# Iteration is: 1030
# Physicial loss of p1 is: 0.32079586386680603
# Physicial loss of p2 is: 0.42703187465667725
# Physicial loss of s is: 0.347935289144516
# Iteration is: 1040
# Physicial loss of p1 is: 0.32040202617645264
# Physicial loss of p2 is: 0.4256192147731781
# Physicial loss of s is: 0.3499615788459778
# Iteration is: 1050
# Physicial loss of p1 is: 0.3210701644420624
# Physicial loss of p2 is: 0.4264546036720276
# Physicial loss of s is: 0.34878718852996826
# Iteration is: 1060
# Physicial loss of p1 is: 0.32152441143989563
# Physicial loss of p2 is: 0.42700061202049255
# Physicial loss of s is: 0.3480392396450043
# Iteration is: 1070
# Physicial loss of p1 is: 0.32687926292419434
# Physicial loss of p2 is: 0.4387223422527313
# Physicial loss of s is: 0.33270177245140076
# Iteration is: 1080
# Physicial loss of p1 is: 0.31503376364707947
# Physicial loss of p2 is: 0.41317683458328247
# Physicial loss of s is: 0.36817583441734314
# Iteration is: 1090
# Physicial loss of p1 is: 0.31761738657951355
# Physicial loss of p2 is: 0.41813915967941284
# Physicial loss of s is: 0.3604520559310913
# Iteration is: 1100
# Physicial loss of p1 is: 0.31935814023017883
# Physicial loss of p2 is: 0.4210638403892517
# Physicial loss of s is: 0.3558116853237152
# Iteration is: 1110
# Physicial loss of p1 is: 0.3201369345188141
# Physicial loss of p2 is: 0.4221630394458771
# Physicial loss of s is: 0.3538018465042114
# Iteration is: 1120
# Physicial loss of p1 is: 0.32090139389038086
# Physicial loss of p2 is: 0.4234042167663574
# Physicial loss of s is: 0.3515813946723938
# Iteration is: 1130
# Physicial loss of p1 is: 0.3219022750854492
# Physicial loss of p2 is: 0.42534705996513367
# Physicial loss of s is: 0.34836921095848083
# Iteration is: 1140
# Physicial loss of p1 is: 0.32155412435531616
# Physicial loss of p2 is: 0.4242447018623352
# Physicial loss of s is: 0.349195271730423
# Iteration is: 1150
# Physicial loss of p1 is: 0.3215142488479614
# Physicial loss of p2 is: 0.42391854524612427
# Physicial loss of s is: 0.34891095757484436
# Iteration is: 1160
# Physicial loss of p1 is: 0.3210430145263672
# Physicial loss of p2 is: 0.42258402705192566
# Physicial loss of s is: 0.34988394379615784
# Iteration is: 1170
# Physicial loss of p1 is: 0.3191647231578827
# Physicial loss of p2 is: 0.4177890717983246
# Physicial loss of s is: 0.35544243454933167
# Iteration is: 1180
# Physicial loss of p1 is: 0.3190094530582428
# Physicial loss of p2 is: 0.4182584583759308
# Physicial loss of s is: 0.35415974259376526
# Iteration is: 1190
# Physicial loss of p1 is: 0.31822866201400757
# Physicial loss of p2 is: 0.4159610867500305
# Physicial loss of s is: 0.3559620678424835
# Iteration is: 1200
# Physicial loss of p1 is: 0.3193816840648651
# Physicial loss of p2 is: 0.41798731684684753
# Physicial loss of s is: 0.35161808133125305
# Iteration is: 1210
# Physicial loss of p1 is: 0.31937962770462036
# Physicial loss of p2 is: 0.41793254017829895
# Physicial loss of s is: 0.3503395915031433
# Iteration is: 1220
# Physicial loss of p1 is: 0.31904831528663635
# Physicial loss of p2 is: 0.41718611121177673
# Physicial loss of s is: 0.34988728165626526
# Iteration is: 1230
# Physicial loss of p1 is: 0.319149911403656
# Physicial loss of p2 is: 0.41750186681747437
# Physicial loss of s is: 0.3478032350540161
# Iteration is: 1240
# Physicial loss of p1 is: 0.3195308744907379
# Physicial loss of p2 is: 0.4184677302837372
# Physicial loss of s is: 0.34468698501586914
# Iteration is: 1250
# Physicial loss of p1 is: 0.3186027705669403
# Physicial loss of p2 is: 0.4162232279777527
# Physicial loss of s is: 0.34575170278549194
# Iteration is: 1260
# Physicial loss of p1 is: 0.3184572458267212
# Physicial loss of p2 is: 0.4161720275878906
# Physicial loss of s is: 0.3439047038555145
# Iteration is: 1270
# Physicial loss of p1 is: 0.31788748502731323
# Physicial loss of p2 is: 0.4152519106864929
# Physicial loss of s is: 0.3432706296443939
# Iteration is: 1280
# Physicial loss of p1 is: 0.31910809874534607
# Physicial loss of p2 is: 0.41923704743385315
# Physicial loss of s is: 0.3364407420158386
# Iteration is: 1290
# Physicial loss of p1 is: 0.31272178888320923
# Physicial loss of p2 is: 0.40667951107025146
# Physicial loss of s is: 0.353188693523407
# Iteration is: 1300
# Physicial loss of p1 is: 0.31010517477989197
# Physicial loss of p2 is: 0.40543895959854126
# Physicial loss of s is: 0.3561120331287384
# Iteration is: 1310
# Physicial loss of p1 is: 0.3117750287055969
# Physicial loss of p2 is: 0.41127702593803406
# Physicial loss of s is: 0.3484072983264923
# Iteration is: 1320
# Physicial loss of p1 is: 0.31236666440963745
# Physicial loss of p2 is: 0.41734960675239563
# Physicial loss of s is: 0.3420368731021881
# Iteration is: 1330
# Physicial loss of p1 is: 0.31088945269584656
# Physicial loss of p2 is: 0.41894295811653137
# Physicial loss of s is: 0.3412666916847229
# Iteration is: 1340
# Physicial loss of p1 is: 0.30936044454574585
# Physicial loss of p2 is: 0.4182591140270233
# Physicial loss of s is: 0.3410864770412445
# Iteration is: 1350
# Physicial loss of p1 is: 0.3096855580806732
# Physicial loss of p2 is: 0.4198303520679474
# Physicial loss of s is: 0.33571338653564453
# Iteration is: 1360
# Physicial loss of p1 is: 0.31102705001831055
# Physicial loss of p2 is: 0.4234541356563568
# Physicial loss of s is: 0.32725265622138977
# Iteration is: 1370
# Physicial loss of p1 is: 0.30375948548316956
# Physicial loss of p2 is: 0.40903955698013306
# Physicial loss of s is: 0.3445852994918823
# Iteration is: 1380
# Physicial loss of p1 is: 0.30502450466156006
# Physicial loss of p2 is: 0.4134688377380371
# Physicial loss of s is: 0.335440456867218
# Iteration is: 1390
# Physicial loss of p1 is: 0.30539029836654663
# Physicial loss of p2 is: 0.4140399694442749
# Physicial loss of s is: 0.3308930993080139
# Iteration is: 1400
# Physicial loss of p1 is: 0.3046703338623047
# Physicial loss of p2 is: 0.41380298137664795
# Physicial loss of s is: 0.3282698094844818
# Iteration is: 1410
# Physicial loss of p1 is: 0.30258312821388245
# Physicial loss of p2 is: 0.41042545437812805
# Physicial loss of s is: 0.3298192024230957
# Iteration is: 1420
# Physicial loss of p1 is: 0.30081355571746826
# Physicial loss of p2 is: 0.4074532389640808
# Physicial loss of s is: 0.3305806815624237
# Iteration is: 1430
# Physicial loss of p1 is: 0.3001624047756195
# Physicial loss of p2 is: 0.4073401689529419
# Physicial loss of s is: 0.3273994028568268
# Iteration is: 1440
# Physicial loss of p1 is: 0.2990415692329407
# Physicial loss of p2 is: 0.40721043944358826
# Physicial loss of s is: 0.3246651589870453
# Iteration is: 1450
# Physicial loss of p1 is: 0.30203187465667725
# Physicial loss of p2 is: 0.41822144389152527
# Physicial loss of s is: 0.30790629982948303
# Iteration is: 1460
# Physicial loss of p1 is: 0.2926490604877472
# Physicial loss of p2 is: 0.392121821641922
# Physicial loss of s is: 0.3374401032924652
# Iteration is: 1470
# Physicial loss of p1 is: 0.29306918382644653
# Physicial loss of p2 is: 0.3944912850856781
# Physicial loss of s is: 0.3302345871925354
# Iteration is: 1480
# Physicial loss of p1 is: 0.29346686601638794
# Physicial loss of p2 is: 0.39776864647865295
# Physicial loss of s is: 0.32232651114463806
# Iteration is: 1490
# Physicial loss of p1 is: 0.2931453585624695
# Physicial loss of p2 is: 0.3985147178173065
# Physicial loss of s is: 0.3175888955593109
# Iteration is: 1500
# Physicial loss of p1 is: 0.2926636040210724
# Physicial loss of p2 is: 0.39399954676628113
# Physicial loss of s is: 0.3178248107433319
# Iteration is: 1510
# Physicial loss of p1 is: 0.290151983499527
# Physicial loss of p2 is: 0.39070865511894226
# Physicial loss of s is: 0.3188987374305725
# Iteration is: 1520
# Physicial loss of p1 is: 0.2882179617881775
# Physicial loss of p2 is: 0.3881094455718994
# Physicial loss of s is: 0.3186880648136139
# Iteration is: 1530
# Physicial loss of p1 is: 0.28852805495262146
# Physicial loss of p2 is: 0.3864699602127075
# Physicial loss of s is: 0.31520533561706543
# Iteration is: 1540
# Physicial loss of p1 is: 0.28719013929367065
# Physicial loss of p2 is: 0.3811703324317932
# Physicial loss of s is: 0.3168098032474518
# Iteration is: 1550
# Physicial loss of p1 is: 0.280764639377594
# Physicial loss of p2 is: 0.37255147099494934
# Physicial loss of s is: 0.32702770829200745
# Iteration is: 1560
# Physicial loss of p1 is: 0.2843679189682007
# Physicial loss of p2 is: 0.3843083083629608
# Physicial loss of s is: 0.30696824193000793
# Iteration is: 1570
# Physicial loss of p1 is: 0.2832435369491577
# Physicial loss of p2 is: 0.38318395614624023
# Physicial loss of s is: 0.3042309284210205
# Iteration is: 1580
# Physicial loss of p1 is: 0.28053051233291626
# Physicial loss of p2 is: 0.37474486231803894
# Physicial loss of s is: 0.30990874767303467
# Iteration is: 1590
# Physicial loss of p1 is: 0.2781977653503418
# Physicial loss of p2 is: 0.3787650465965271
# Physicial loss of s is: 0.30343499779701233
# Iteration is: 1600
# Physicial loss of p1 is: 0.27786752581596375
# Physicial loss of p2 is: 0.3741722106933594
# Physicial loss of s is: 0.3029729723930359
# Iteration is: 1610
# Physicial loss of p1 is: 0.27697306871414185
# Physicial loss of p2 is: 0.369561105966568
# Physicial loss of s is: 0.3030679523944855
# Iteration is: 1620
# Physicial loss of p1 is: 0.2686786651611328
# Physicial loss of p2 is: 0.3573218584060669
# Physicial loss of s is: 0.31843429803848267
# Iteration is: 1630
# Physicial loss of p1 is: 0.27369704842567444
# Physicial loss of p2 is: 0.37835678458213806
# Physicial loss of s is: 0.28802454471588135
# Iteration is: 1640
# Physicial loss of p1 is: 0.2718370258808136
# Physicial loss of p2 is: 0.36393335461616516
# Physicial loss of s is: 0.2978648543357849
# Iteration is: 1650
# Physicial loss of p1 is: 0.27058032155036926
# Physicial loss of p2 is: 0.3592781722545624
# Physicial loss of s is: 0.2982509434223175
# Iteration is: 1660
# Physicial loss of p1 is: 0.26942744851112366
# Physicial loss of p2 is: 0.3630562424659729
# Physicial loss of s is: 0.290543794631958
# Iteration is: 1670
# Physicial loss of p1 is: 0.267301082611084
# Physicial loss of p2 is: 0.35662537813186646
# Physicial loss of s is: 0.2933591306209564
# Iteration is: 1680
# Physicial loss of p1 is: 0.26583653688430786
# Physicial loss of p2 is: 0.35511159896850586
# Physicial loss of s is: 0.2908719480037689
# Iteration is: 1690
# Physicial loss of p1 is: 0.26455363631248474
# Physicial loss of p2 is: 0.35096248984336853
# Physicial loss of s is: 0.2906697392463684
# Iteration is: 1700
# Physicial loss of p1 is: 0.25714442133903503
# Physicial loss of p2 is: 0.33570292592048645
# Physicial loss of s is: 0.30806922912597656
# Iteration is: 1710
# Physicial loss of p1 is: 0.26094865798950195
# Physicial loss of p2 is: 0.3521875739097595
# Physicial loss of s is: 0.28228288888931274
# Iteration is: 1720
# Physicial loss of p1 is: 0.26223066449165344
# Physicial loss of p2 is: 0.35192161798477173
# Physicial loss of s is: 0.27589118480682373
# Iteration is: 1730
# Physicial loss of p1 is: 0.2577663064002991
# Physicial loss of p2 is: 0.3465694487094879
# Physicial loss of s is: 0.2798430919647217
# Iteration is: 1740
# Physicial loss of p1 is: 0.2561230957508087
# Physicial loss of p2 is: 0.340453177690506
# Physicial loss of s is: 0.28174763917922974
# Iteration is: 1750
# Physicial loss of p1 is: 0.25453951954841614
# Physicial loss of p2 is: 0.3421843945980072
# Physicial loss of s is: 0.27622199058532715
# Iteration is: 1760
# Physicial loss of p1 is: 0.2530602812767029
# Physicial loss of p2 is: 0.3373335301876068
# Physicial loss of s is: 0.27674832940101624
# Iteration is: 1770
# Physicial loss of p1 is: 0.2513120472431183
# Physicial loss of p2 is: 0.3364942967891693
# Physicial loss of s is: 0.27378398180007935
# Iteration is: 1780
# Physicial loss of p1 is: 0.24969181418418884
# Physicial loss of p2 is: 0.33604997396469116
# Physicial loss of s is: 0.27032753825187683
# Iteration is: 1790
# Physicial loss of p1 is: 0.2518033981323242
# Physicial loss of p2 is: 0.3559974730014801
# Physicial loss of s is: 0.24586568772792816
# Iteration is: 1800
# Physicial loss of p1 is: 0.24753357470035553
# Physicial loss of p2 is: 0.34058496356010437
# Physicial loss of s is: 0.25750094652175903
# Iteration is: 1810
# Physicial loss of p1 is: 0.24860776960849762
# Physicial loss of p2 is: 0.33290809392929077
# Physicial loss of s is: 0.2579535245895386
# Iteration is: 1820
# Physicial loss of p1 is: 0.24301427602767944
# Physicial loss of p2 is: 0.3303847312927246
# Physicial loss of s is: 0.2602807283401489
# Iteration is: 1830
# Physicial loss of p1 is: 0.24150067567825317
# Physicial loss of p2 is: 0.32590019702911377
# Physicial loss of s is: 0.26038873195648193
# Iteration is: 1840
# Physicial loss of p1 is: 0.24047863483428955
# Physicial loss of p2 is: 0.32238367199897766
# Physicial loss of s is: 0.2591575086116791
# Iteration is: 1850
# Physicial loss of p1 is: 0.237858384847641
# Physicial loss of p2 is: 0.31977057456970215
# Physicial loss of s is: 0.25868692994117737
# Iteration is: 1860
# Physicial loss of p1 is: 0.236316978931427
# Physicial loss of p2 is: 0.3159254789352417
# Physicial loss of s is: 0.2582707703113556
# Iteration is: 1870
# Physicial loss of p1 is: 0.2346605360507965
# Physicial loss of p2 is: 0.31488487124443054
# Physicial loss of s is: 0.25535592436790466
# Iteration is: 1880
# Physicial loss of p1 is: 0.23291988670825958
# Physicial loss of p2 is: 0.31179550290107727
# Physicial loss of s is: 0.25443220138549805
# Iteration is: 1890
# Physicial loss of p1 is: 0.23085424304008484
# Physicial loss of p2 is: 0.30546268820762634
# Physicial loss of s is: 0.25691837072372437
# Iteration is: 1900
# Physicial loss of p1 is: 0.22959506511688232
# Physicial loss of p2 is: 0.3129682242870331
# Physicial loss of s is: 0.2457420378923416
# Iteration is: 1910
# Physicial loss of p1 is: 0.22852811217308044
# Physicial loss of p2 is: 0.30903682112693787
# Physicial loss of s is: 0.24481624364852905
# Iteration is: 1920
# Physicial loss of p1 is: 0.22700199484825134
# Physicial loss of p2 is: 0.3073346018791199
# Physicial loss of s is: 0.24238654971122742
# Iteration is: 1930
# Physicial loss of p1 is: 0.22494184970855713
# Physicial loss of p2 is: 0.3042764961719513
# Physicial loss of s is: 0.24173834919929504
# Iteration is: 1940
# Physicial loss of p1 is: 0.22330158948898315
# Physicial loss of p2 is: 0.30038022994995117
# Physicial loss of s is: 0.24148710072040558
# Iteration is: 1950
# Physicial loss of p1 is: 0.2209121435880661
# Physicial loss of p2 is: 0.2970430850982666
# Physicial loss of s is: 0.24149006605148315
# Iteration is: 1960
# Physicial loss of p1 is: 0.2192711979150772
# Physicial loss of p2 is: 0.29384082555770874
# Physicial loss of s is: 0.2406025379896164
# Iteration is: 1970
# Physicial loss of p1 is: 0.21772029995918274
# Physicial loss of p2 is: 0.2930934727191925
# Physicial loss of s is: 0.2373446524143219
# Iteration is: 1980
# Physicial loss of p1 is: 0.21586932241916656
# Physicial loss of p2 is: 0.2898348867893219
# Physicial loss of s is: 0.23673854768276215
# Iteration is: 1990
# Physicial loss of p1 is: 0.21418188512325287
# Physicial loss of p2 is: 0.2855835556983948
# Physicial loss of s is: 0.23692156374454498
# Iteration is: 2000
# Physicial loss of p1 is: 0.2102447748184204
# Physicial loss of p2 is: 0.2678637206554413
# Physicial loss of s is: 0.2533038854598999
# Iteration is: 2010
# Physicial loss of p1 is: 0.20958521962165833
# Physicial loss of p2 is: 0.27317142486572266
# Physicial loss of s is: 0.24257877469062805
# Iteration is: 2020
# Physicial loss of p1 is: 0.2103564441204071
# Physicial loss of p2 is: 0.27639925479888916
# Physicial loss of s is: 0.232953742146492
# Iteration is: 2030
# Physicial loss of p1 is: 0.20662198960781097
# Physicial loss of p2 is: 0.2790828347206116
# Physicial loss of s is: 0.22880537807941437
# Iteration is: 2040
# Physicial loss of p1 is: 0.20459459722042084
# Physicial loss of p2 is: 0.27736738324165344
# Physicial loss of s is: 0.2270757257938385
# Iteration is: 2050
# Physicial loss of p1 is: 0.20389118790626526
# Physicial loss of p2 is: 0.27441608905792236
# Physicial loss of s is: 0.22515466809272766
# Iteration is: 2060
# Physicial loss of p1 is: 0.20240087807178497
# Physicial loss of p2 is: 0.27342668175697327
# Physicial loss of s is: 0.2222396284341812
# Iteration is: 2070
# Physicial loss of p1 is: 0.2004559338092804
# Physicial loss of p2 is: 0.2722262442111969
# Physicial loss of s is: 0.22001633048057556
# Iteration is: 2080
# Physicial loss of p1 is: 0.19834192097187042
# Physicial loss of p2 is: 0.270793080329895
# Physicial loss of s is: 0.21821370720863342
# Iteration is: 2090
# Physicial loss of p1 is: 0.1930380016565323
# Physicial loss of p2 is: 0.2824680507183075
# Physicial loss of s is: 0.20814062654972076
# Iteration is: 2100
# Physicial loss of p1 is: 0.19615674018859863
# Physicial loss of p2 is: 0.25349608063697815
# Physicial loss of s is: 0.2264280468225479
# Iteration is: 2110
# Physicial loss of p1 is: 0.1946163922548294
# Physicial loss of p2 is: 0.2593703269958496
# Physicial loss of s is: 0.21697397530078888
# Iteration is: 2120
# Physicial loss of p1 is: 0.19132782518863678
# Physicial loss of p2 is: 0.2643685042858124
# Physicial loss of s is: 0.21057091653347015
# Iteration is: 2130
# Physicial loss of p1 is: 0.19135095179080963
# Physicial loss of p2 is: 0.2615515887737274
# Physicial loss of s is: 0.20806431770324707
# Iteration is: 2140
# Physicial loss of p1 is: 0.1887381225824356
# Physicial loss of p2 is: 0.25679153203964233
# Physicial loss of s is: 0.2100939303636551
# Iteration is: 2150
# Physicial loss of p1 is: 0.18676403164863586
# Physicial loss of p2 is: 0.25795358419418335
# Physicial loss of s is: 0.20607206225395203
# Iteration is: 2160
# Physicial loss of p1 is: 0.18513700366020203
# Physicial loss of p2 is: 0.2559468448162079
# Physicial loss of s is: 0.2046659290790558
# Iteration is: 2170
# Physicial loss of p1 is: 0.17980094254016876
# Physicial loss of p2 is: 0.2725464999675751
# Physicial loss of s is: 0.19109132885932922
# Iteration is: 2180
# Physicial loss of p1 is: 0.1841096431016922
# Physicial loss of p2 is: 0.24369433522224426
# Physicial loss of s is: 0.2074868232011795
# Iteration is: 2190
# Physicial loss of p1 is: 0.17944157123565674
# Physicial loss of p2 is: 0.24979287385940552
# Physicial loss of s is: 0.20178546011447906
# Iteration is: 2200
# Physicial loss of p1 is: 0.1803736537694931
# Physicial loss of p2 is: 0.24633748829364777
# Physicial loss of s is: 0.19933125376701355
# Iteration is: 2210
# Physicial loss of p1 is: 0.17693530023097992
# Physicial loss of p2 is: 0.2466537058353424
# Physicial loss of s is: 0.19796429574489594
# Iteration is: 2220
# Physicial loss of p1 is: 0.1762470155954361
# Physicial loss of p2 is: 0.2430952936410904
# Physicial loss of s is: 0.19742350280284882
# Iteration is: 2230
# Physicial loss of p1 is: 0.1746980845928192
# Physicial loss of p2 is: 0.24208180606365204
# Physicial loss of s is: 0.19549325108528137
# Iteration is: 2240
# Physicial loss of p1 is: 0.17304964363574982
# Physicial loss of p2 is: 0.24222224950790405
# Physicial loss of s is: 0.1926947683095932
# Iteration is: 2250
# Physicial loss of p1 is: 0.1717018187046051
# Physicial loss of p2 is: 0.23950882256031036
# Physicial loss of s is: 0.1922788918018341
# Iteration is: 2260
# Physicial loss of p1 is: 0.1704464554786682
# Physicial loss of p2 is: 0.23701761662960052
# Physicial loss of s is: 0.1916482150554657
# Iteration is: 2270
# Physicial loss of p1 is: 0.17151589691638947
# Physicial loss of p2 is: 0.21551521122455597
# Physicial loss of s is: 0.207900270819664
# Iteration is: 2280
# Physicial loss of p1 is: 0.16670183837413788
# Physicial loss of p2 is: 0.2301982194185257
# Physicial loss of s is: 0.1939040571451187
# Iteration is: 2290
# Physicial loss of p1 is: 0.16445983946323395
# Physicial loss of p2 is: 0.23532560467720032
# Physicial loss of s is: 0.18742993474006653
# Iteration is: 2300
# Physicial loss of p1 is: 0.1647985428571701
# Physicial loss of p2 is: 0.23132693767547607
# Physicial loss of s is: 0.1869405061006546
# Iteration is: 2310
# Physicial loss of p1 is: 0.16287870705127716
# Physicial loss of p2 is: 0.23477786779403687
# Physicial loss of s is: 0.1819840967655182
# Iteration is: 2320
# Physicial loss of p1 is: 0.16223610937595367
# Physicial loss of p2 is: 0.23207658529281616
# Physicial loss of s is: 0.1815425157546997
# Iteration is: 2330
# Physicial loss of p1 is: 0.16084550321102142
# Physicial loss of p2 is: 0.2291382998228073
# Physicial loss of s is: 0.18219499289989471
# Iteration is: 2340
# Physicial loss of p1 is: 0.15991249680519104
# Physicial loss of p2 is: 0.22635166347026825
# Physicial loss of s is: 0.18238069117069244
# Iteration is: 2350
# Physicial loss of p1 is: 0.15909728407859802
# Physicial loss of p2 is: 0.21688370406627655
# Physicial loss of s is: 0.18918730318546295
# Iteration is: 2360
# Physicial loss of p1 is: 0.15830011665821075
# Physicial loss of p2 is: 0.21853449940681458
# Physicial loss of s is: 0.18518134951591492
# Iteration is: 2370
# Physicial loss of p1 is: 0.15640759468078613
# Physicial loss of p2 is: 0.22498087584972382
# Physicial loss of s is: 0.17805027961730957
# Iteration is: 2380
# Physicial loss of p1 is: 0.15469525754451752
# Physicial loss of p2 is: 0.22932842373847961
# Physicial loss of s is: 0.17310774326324463
# Iteration is: 2390
# Physicial loss of p1 is: 0.15436221659183502
# Physicial loss of p2 is: 0.22441540658473969
# Physicial loss of s is: 0.17514748871326447
# Iteration is: 2400
# Physicial loss of p1 is: 0.15237653255462646
# Physicial loss of p2 is: 0.22813448309898376
# Physicial loss of s is: 0.17145727574825287
# Iteration is: 2410
# Physicial loss of p1 is: 0.15123839676380157
# Physicial loss of p2 is: 0.23232080042362213
# Physicial loss of s is: 0.1666291058063507
# Iteration is: 2420
# Physicial loss of p1 is: 0.15135374665260315
# Physicial loss of p2 is: 0.22385567426681519
# Physicial loss of s is: 0.17166520655155182
# Iteration is: 2430
# Physicial loss of p1 is: 0.1499253511428833
# Physicial loss of p2 is: 0.2255537062883377
# Physicial loss of s is: 0.1695602387189865
# Iteration is: 2440
# Physicial loss of p1 is: 0.15065482258796692
# Physicial loss of p2 is: 0.21861521899700165
# Physicial loss of s is: 0.1732211709022522
# Iteration is: 2450
# Physicial loss of p1 is: 0.14919090270996094
# Physicial loss of p2 is: 0.21837276220321655
# Physicial loss of s is: 0.1731441169977188
# Iteration is: 2460
# Physicial loss of p1 is: 0.14665666222572327
# Physicial loss of p2 is: 0.22554045915603638
# Physicial loss of s is: 0.16767312586307526
# Iteration is: 2470
# Physicial loss of p1 is: 0.1447354555130005
# Physicial loss of p2 is: 0.23622342944145203
# Physicial loss of s is: 0.1593225747346878
# Iteration is: 2480
# Physicial loss of p1 is: 0.14609013497829437
# Physicial loss of p2 is: 0.22390836477279663
# Physicial loss of s is: 0.16679854691028595
# Iteration is: 2490
# Physicial loss of p1 is: 0.1461678296327591
# Physicial loss of p2 is: 0.22059865295886993
# Physicial loss of s is: 0.1685613989830017
# Iteration is: 2500
# Physicial loss of p1 is: 0.1437186747789383
# Physicial loss of p2 is: 0.22573456168174744
# Physicial loss of s is: 0.16543011367321014
# Iteration is: 2510
# Physicial loss of p1 is: 0.14283312857151031
# Physicial loss of p2 is: 0.22584256529808044
# Physicial loss of s is: 0.1653885394334793
# Iteration is: 2520
# Physicial loss of p1 is: 0.14055705070495605
# Physicial loss of p2 is: 0.23317433893680573
# Physicial loss of s is: 0.16103287041187286
# Iteration is: 2530
# Physicial loss of p1 is: 0.14413079619407654
# Physicial loss of p2 is: 0.2178466022014618
# Physicial loss of s is: 0.1699422150850296
# Iteration is: 2540
# Physicial loss of p1 is: 0.14110274612903595
# Physicial loss of p2 is: 0.2285345047712326
# Physicial loss of s is: 0.16295060515403748
# Iteration is: 2550
# Physicial loss of p1 is: 0.1413707435131073
# Physicial loss of p2 is: 0.22744454443454742
# Physicial loss of s is: 0.16321726143360138
# Iteration is: 2560
# Physicial loss of p1 is: 0.14276628196239471
# Physicial loss of p2 is: 0.22199253737926483
# Physicial loss of s is: 0.16646723449230194
# Iteration is: 2570
# Physicial loss of p1 is: 0.14158236980438232
# Physicial loss of p2 is: 0.21798765659332275
# Physicial loss of s is: 0.17158424854278564
# Iteration is: 2580
# Physicial loss of p1 is: 0.1415732055902481
# Physicial loss of p2 is: 0.21976342797279358
# Physicial loss of s is: 0.16989512741565704
# Iteration is: 2590
# Physicial loss of p1 is: 0.1387518048286438
# Physicial loss of p2 is: 0.22974757850170135
# Physicial loss of s is: 0.1638275384902954
# Iteration is: 2600
# Physicial loss of p1 is: 0.13975799083709717
# Physicial loss of p2 is: 0.22870409488677979
# Physicial loss of s is: 0.16389332711696625
# Iteration is: 2610
# Physicial loss of p1 is: 0.1387929618358612
# Physicial loss of p2 is: 0.23094183206558228
# Physicial loss of s is: 0.16331034898757935
# Iteration is: 2620
# Physicial loss of p1 is: 0.13850289583206177
# Physicial loss of p2 is: 0.23121900856494904
# Physicial loss of s is: 0.1638176292181015
# Iteration is: 2630
# Physicial loss of p1 is: 0.13362053036689758
# Physicial loss of p2 is: 0.24847851693630219
# Physicial loss of s is: 0.15651285648345947
# Iteration is: 2640
# Physicial loss of p1 is: 0.1379229873418808
# Physicial loss of p2 is: 0.23702210187911987
# Physicial loss of s is: 0.16060210764408112
# Iteration is: 2650
# Physicial loss of p1 is: 0.13919779658317566
# Physicial loss of p2 is: 0.23368892073631287
# Physicial loss of s is: 0.16278812289237976
# Iteration is: 2660
# Physicial loss of p1 is: 0.13936831057071686
# Physicial loss of p2 is: 0.23034924268722534
# Physicial loss of s is: 0.16631504893302917
# Iteration is: 2670
# Physicial loss of p1 is: 0.13946014642715454
# Physicial loss of p2 is: 0.23136000335216522
# Physicial loss of s is: 0.16611623764038086
# Iteration is: 2680
# Physicial loss of p1 is: 0.13795135915279388
# Physicial loss of p2 is: 0.23618543148040771
# Physicial loss of s is: 0.16429027915000916
# Iteration is: 2690
# Physicial loss of p1 is: 0.13923615217208862
# Physicial loss of p2 is: 0.23452211916446686
# Physicial loss of s is: 0.16527530550956726
# Iteration is: 2700
# Physicial loss of p1 is: 0.14160390198230743
# Physicial loss of p2 is: 0.23096176981925964
# Physicial loss of s is: 0.16705100238323212
# Iteration is: 2710
# Physicial loss of p1 is: 0.13840027153491974
# Physicial loss of p2 is: 0.23782142996788025
# Physicial loss of s is: 0.16514113545417786
# Iteration is: 2720
# Physicial loss of p1 is: 0.14248578250408173
# Physicial loss of p2 is: 0.2312648445367813
# Physicial loss of s is: 0.16791750490665436
# Iteration is: 2730
# Physicial loss of p1 is: 0.1395651400089264
# Physicial loss of p2 is: 0.23800960183143616
# Physicial loss of s is: 0.16564719378948212
# Iteration is: 2740
# Physicial loss of p1 is: 0.13783787190914154
# Physicial loss of p2 is: 0.24236543476581573
# Physicial loss of s is: 0.16467808187007904
# Iteration is: 2750
# Physicial loss of p1 is: 0.14026863873004913
# Physicial loss of p2 is: 0.2383195459842682
# Physicial loss of s is: 0.16657456755638123
# Iteration is: 2760
# Physicial loss of p1 is: 0.14077802002429962
# Physicial loss of p2 is: 0.23837725818157196
# Physicial loss of s is: 0.16694705188274384
# Iteration is: 2770
# Physicial loss of p1 is: 0.14655128121376038
# Physicial loss of p2 is: 0.2288195788860321
# Physicial loss of s is: 0.17146052420139313
# Iteration is: 2780
# Physicial loss of p1 is: 0.13595916330814362
# Physicial loss of p2 is: 0.2509188652038574
# Physicial loss of s is: 0.16358736157417297
# Iteration is: 2790
# Physicial loss of p1 is: 0.13936585187911987
# Physicial loss of p2 is: 0.24389953911304474
# Physicial loss of s is: 0.16632241010665894
# Iteration is: 2800
# Physicial loss of p1 is: 0.14211951196193695
# Physicial loss of p2 is: 0.2394963800907135
# Physicial loss of s is: 0.16819383203983307
# Iteration is: 2810
# Physicial loss of p1 is: 0.13939571380615234
# Physicial loss of p2 is: 0.2458585947751999
# Physicial loss of s is: 0.1663050353527069
# Iteration is: 2820
# Physicial loss of p1 is: 0.14171238243579865
# Physicial loss of p2 is: 0.24225617945194244
# Physicial loss of s is: 0.16773389279842377
# Iteration is: 2830
# Physicial loss of p1 is: 0.1435747742652893
# Physicial loss of p2 is: 0.23968099057674408
# Physicial loss of s is: 0.16891111433506012
# Iteration is: 2840
# Physicial loss of p1 is: 0.14561054110527039
# Physicial loss of p2 is: 0.23675520718097687
# Physicial loss of s is: 0.17039276659488678
# Iteration is: 2850
# Physicial loss of p1 is: 0.1413140445947647
# Physicial loss of p2 is: 0.2455715537071228
# Physicial loss of s is: 0.16734863817691803
# Iteration is: 2860
# Physicial loss of p1 is: 0.1407243013381958
# Physicial loss of p2 is: 0.2476055771112442
# Physicial loss of s is: 0.16687054932117462
# Iteration is: 2870
# Physicial loss of p1 is: 0.14299941062927246
# Physicial loss of p2 is: 0.24399548768997192
# Physicial loss of s is: 0.16809895634651184
# Iteration is: 2880
# Physicial loss of p1 is: 0.14312304556369781
# Physicial loss of p2 is: 0.24442057311534882
# Physicial loss of s is: 0.16809843480587006
# Iteration is: 2890
# Physicial loss of p1 is: 0.14284098148345947
# Physicial loss of p2 is: 0.24556419253349304
# Physicial loss of s is: 0.16784308850765228
# Iteration is: 2900
# Physicial loss of p1 is: 0.14472681283950806
# Physicial loss of p2 is: 0.24251273274421692
# Physicial loss of s is: 0.16900339722633362
# Iteration is: 2910
# Physicial loss of p1 is: 0.1427639275789261
# Physicial loss of p2 is: 0.24788586795330048
# Physicial loss of s is: 0.1666669249534607
# Iteration is: 2920
# Physicial loss of p1 is: 0.14117664098739624
# Physicial loss of p2 is: 0.25126299262046814
# Physicial loss of s is: 0.16616788506507874
# Iteration is: 2930
# Physicial loss of p1 is: 0.14084891974925995
# Physicial loss of p2 is: 0.2515632212162018
# Physicial loss of s is: 0.1664530634880066
# Iteration is: 2940
# Physicial loss of p1 is: 0.14331093430519104
# Physicial loss of p2 is: 0.24759234488010406
# Physicial loss of s is: 0.16706670820713043
# Iteration is: 2950
# Physicial loss of p1 is: 0.1441653072834015
# Physicial loss of p2 is: 0.24547070264816284
# Physicial loss of s is: 0.16816358268260956
# Iteration is: 2960
# Physicial loss of p1 is: 0.14459021389484406
# Physicial loss of p2 is: 0.24550896883010864
# Physicial loss of s is: 0.16773231327533722
# Iteration is: 2970
# Physicial loss of p1 is: 0.14434336125850677
# Physicial loss of p2 is: 0.2458142340183258
# Physicial loss of s is: 0.16777166724205017
# Iteration is: 2980
# Physicial loss of p1 is: 0.14436224102973938
# Physicial loss of p2 is: 0.24604134261608124
# Physicial loss of s is: 0.16752594709396362
# Iteration is: 2990
# Physicial loss of p1 is: 0.14457902312278748
# Physicial loss of p2 is: 0.24577197432518005
# Physicial loss of s is: 0.16743695735931396
# Iteration is: 3000
# Physicial loss of p1 is: 0.14483679831027985
# Physicial loss of p2 is: 0.24518191814422607
# Physicial loss of s is: 0.1675356924533844
# Iteration is: 3010
# Physicial loss of p1 is: 0.14480161666870117
# Physicial loss of p2 is: 0.2452632188796997
# Physicial loss of s is: 0.16730712354183197
# Iteration is: 3020
# Physicial loss of p1 is: 0.14494431018829346
# Physicial loss of p2 is: 0.24491101503372192
# Physicial loss of s is: 0.1672070026397705
# Iteration is: 3030
# Physicial loss of p1 is: 0.14500711858272552
# Physicial loss of p2 is: 0.24467357993125916
# Physicial loss of s is: 0.1670379936695099
# Iteration is: 3040
# Physicial loss of p1 is: 0.14426255226135254
# Physicial loss of p2 is: 0.24642354249954224
# Physicial loss of s is: 0.16601555049419403
# Iteration is: 3050
# Physicial loss of p1 is: 0.14338403940200806
# Physicial loss of p2 is: 0.24768371880054474
# Physicial loss of s is: 0.16588690876960754
# Iteration is: 3060
# Physicial loss of p1 is: 0.1479547768831253
# Physicial loss of p2 is: 0.239148810505867
# Physicial loss of s is: 0.1676395833492279
# Iteration is: 3070
# Physicial loss of p1 is: 0.14697246253490448
# Physicial loss of p2 is: 0.23870107531547546
# Physicial loss of s is: 0.16869580745697021
# Iteration is: 3080
# Physicial loss of p1 is: 0.1455894261598587
# Physicial loss of p2 is: 0.2424624264240265
# Physicial loss of s is: 0.1659712940454483
# Iteration is: 3090
# Physicial loss of p1 is: 0.14456792175769806
# Physicial loss of p2 is: 0.2436593770980835
# Physicial loss of s is: 0.1655227094888687
# Iteration is: 3100
# Physicial loss of p1 is: 0.14485491812229156
# Physicial loss of p2 is: 0.2428654432296753
# Physicial loss of s is: 0.16515854001045227
# Iteration is: 3110
# Physicial loss of p1 is: 0.14497458934783936
# Physicial loss of p2 is: 0.24181205034255981
# Physicial loss of s is: 0.16518716514110565
# Iteration is: 3120
# Physicial loss of p1 is: 0.14512209594249725
# Physicial loss of p2 is: 0.24101965129375458
# Physicial loss of s is: 0.1649201661348343
# Iteration is: 3130
# Physicial loss of p1 is: 0.1450750082731247
# Physicial loss of p2 is: 0.240338996052742
# Physicial loss of s is: 0.16470804810523987
# Iteration is: 3140
# Physicial loss of p1 is: 0.14511987566947937
# Physicial loss of p2 is: 0.2394995093345642
# Physicial loss of s is: 0.16447842121124268
# Iteration is: 3150
# Physicial loss of p1 is: 0.1450626701116562
# Physicial loss of p2 is: 0.23879827558994293
# Physicial loss of s is: 0.1641903668642044
# Iteration is: 3160
# Physicial loss of p1 is: 0.1449226289987564
# Physicial loss of p2 is: 0.23830091953277588
# Physicial loss of s is: 0.163756862282753
# Iteration is: 3170
# ...
# Iteration is: 49010
# Physicial loss of p1 is: 0.002136023947969079
# Physicial loss of p2 is: 0.0018715659389272332
# Physicial loss of s is: 0.0026672217063605785
# Iteration is: 49020
# Physicial loss of p1 is: 0.0017827192787081003
# Physicial loss of p2 is: 0.0006338044186122715
# Physicial loss of s is: 0.0010389403905719519
# Iteration is: 49030
# Physicial loss of p1 is: 0.0017340596532449126
# Physicial loss of p2 is: 0.00031612039310857654
# Physicial loss of s is: 0.0005378396599553525
# Iteration is: 49040
# Physicial loss of p1 is: 0.0017383425729349256
# Physicial loss of p2 is: 0.0003162268840242177
# Physicial loss of s is: 0.0005796311888843775
# Iteration is: 49050
# Physicial loss of p1 is: 0.0018011132488027215
# Physicial loss of p2 is: 0.0003536570875439793
# Physicial loss of s is: 0.0005856170901097357
# Iteration is: 49060
# Physicial loss of p1 is: 0.001788927591405809
# Physicial loss of p2 is: 0.0002847465220838785
# Physicial loss of s is: 0.0004871954442933202
# Iteration is: 49070
# Physicial loss of p1 is: 0.0017922602128237486
# Physicial loss of p2 is: 0.0002800796355586499
# Physicial loss of s is: 0.000486740522319451
# Iteration is: 49080
# Physicial loss of p1 is: 0.0018708670977503061
# Physicial loss of p2 is: 0.0002719425829127431
# Physicial loss of s is: 0.000543537549674511
# Iteration is: 49090
# Physicial loss of p1 is: 0.004306344781070948
# Physicial loss of p2 is: 0.0013912551803514361
# Physicial loss of s is: 0.0041215745732188225
# Iteration is: 49100
# Physicial loss of p1 is: 0.0025177227798849344
# Physicial loss of p2 is: 0.0006787428865209222
# Physicial loss of s is: 0.002484929747879505
# Iteration is: 49110
# Physicial loss of p1 is: 0.0023107901215553284
# Physicial loss of p2 is: 0.00197826256044209
# Physicial loss of s is: 0.0032951999455690384
# Iteration is: 49120
# Physicial loss of p1 is: 0.0018812618218362331
# Physicial loss of p2 is: 0.0007660459959879518
# Physicial loss of s is: 0.0012409803457558155
# Iteration is: 49130
# Physicial loss of p1 is: 0.0017281752079725266
# Physicial loss of p2 is: 0.00031341565772891045
# Physicial loss of s is: 0.0005106531898491085
# Iteration is: 49140
# Physicial loss of p1 is: 0.001745828427374363
# Physicial loss of p2 is: 0.00029459662619046867
# Physicial loss of s is: 0.0005457332008518279
# Iteration is: 49150
# Physicial loss of p1 is: 0.0017724285135045648
# Physicial loss of p2 is: 0.00034817098639905453
# Physicial loss of s is: 0.0005395858897827566
# Iteration is: 49160
# Physicial loss of p1 is: 0.0017928320448845625
# Physicial loss of p2 is: 0.000293092307401821
# Physicial loss of s is: 0.000523800146766007
# Iteration is: 49170
# Physicial loss of p1 is: 0.0018308492144569755
# Physicial loss of p2 is: 0.00029497643117792904
# Physicial loss of s is: 0.0005550637724809349
# Iteration is: 49180
# Physicial loss of p1 is: 0.002056084806099534
# Physicial loss of p2 is: 0.00031960668275132775
# Physicial loss of s is: 0.0008277749875560403
# Iteration is: 49190
# Physicial loss of p1 is: 0.0032228692434728146
# Physicial loss of p2 is: 0.00047314533730968833
# Physicial loss of s is: 0.002499555703252554
# Iteration is: 49200
# Physicial loss of p1 is: 0.0023037977516651154
# Physicial loss of p2 is: 0.0005924955476075411
# Physicial loss of s is: 0.0012956225546076894
# Iteration is: 49210
# Physicial loss of p1 is: 0.0019976140465587378
# Physicial loss of p2 is: 0.0019237777451053262
# Physicial loss of s is: 0.0031143876258283854
# Iteration is: 49220
# Physicial loss of p1 is: 0.002013929421082139
# Physicial loss of p2 is: 0.002161296783015132
# Physicial loss of s is: 0.0031999247148633003
# Iteration is: 49230
# Physicial loss of p1 is: 0.0018697550985962152
# Physicial loss of p2 is: 0.0009577797027304769
# Physicial loss of s is: 0.0017907944275066257
# Iteration is: 49240
# Physicial loss of p1 is: 0.0017330223927274346
# Physicial loss of p2 is: 0.00027033925289288163
# Physicial loss of s is: 0.0006523099145852029
# Iteration is: 49250
# Physicial loss of p1 is: 0.0017563622677698731
# Physicial loss of p2 is: 0.00044134099152870476
# Physicial loss of s is: 0.000703640456777066
# Iteration is: 49260
# Physicial loss of p1 is: 0.0017817569896578789
# Physicial loss of p2 is: 0.00032926889252848923
# Physicial loss of s is: 0.000625334563665092
# Iteration is: 49270
# Physicial loss of p1 is: 0.001880771480500698
# Physicial loss of p2 is: 0.00030170692480169237
# Physicial loss of s is: 0.0006410384085029364
# Iteration is: 49280
# Physicial loss of p1 is: 0.004064437001943588
# Physicial loss of p2 is: 0.0005488998722285032
# Physicial loss of s is: 0.0034691588953137398
# Iteration is: 49290
# Physicial loss of p1 is: 0.0025622607208788395
# Physicial loss of p2 is: 0.0004434126312844455
# Physicial loss of s is: 0.001668362645432353
# Iteration is: 49300
# Physicial loss of p1 is: 0.002094594994559884
# Physicial loss of p2 is: 0.00051536486716941
# Physicial loss of s is: 0.0014216994168236852
# Iteration is: 49310
# Physicial loss of p1 is: 0.0018910311628133059
# Physicial loss of p2 is: 0.0023010284639894962
# Physicial loss of s is: 0.003073916072025895
# Iteration is: 49320
# Physicial loss of p1 is: 0.001758812228217721
# Physicial loss of p2 is: 0.0004729224310722202
# Physicial loss of s is: 0.0006970187532715499
# Iteration is: 49330
# Physicial loss of p1 is: 0.0018317403737455606
# Physicial loss of p2 is: 0.0010381753090769053
# Physicial loss of s is: 0.0014118935214355588
# Iteration is: 49340
# Physicial loss of p1 is: 0.0017413754248991609
# Physicial loss of p2 is: 0.00029518440715037286
# Physicial loss of s is: 0.0004977252683602273
# Iteration is: 49350
# Physicial loss of p1 is: 0.0017427406273782253
# Physicial loss of p2 is: 0.00041793257696554065
# Physicial loss of s is: 0.0006903997855260968
# Iteration is: 49360
# Physicial loss of p1 is: 0.0021036595571786165
# Physicial loss of p2 is: 0.002534048166126013
# Physicial loss of s is: 0.003507171059027314
# Iteration is: 49370
# Physicial loss of p1 is: 0.0028274713549762964
# Physicial loss of p2 is: 0.0003656373010016978
# Physicial loss of s is: 0.001872790977358818
# Iteration is: 49380
# Physicial loss of p1 is: 0.0019659942481666803
# Physicial loss of p2 is: 0.0007023929501883686
# Physicial loss of s is: 0.0011040754616260529
# Iteration is: 49390
# Physicial loss of p1 is: 0.0017204729374498129
# Physicial loss of p2 is: 0.00032376425224356353
# Physicial loss of s is: 0.0005521401762962341
# Iteration is: 49400
# Physicial loss of p1 is: 0.0017438618233427405
# Physicial loss of p2 is: 0.0003138338215649128
# Physicial loss of s is: 0.0005796945770271122
# Iteration is: 49410
# Physicial loss of p1 is: 0.0017652871320024133
# Physicial loss of p2 is: 0.0012444964377209544
# Physicial loss of s is: 0.0018120396416634321
# Iteration is: 49420
# Physicial loss of p1 is: 0.0018826923333108425
# Physicial loss of p2 is: 0.0009162076166830957
# Physicial loss of s is: 0.001505776192061603
# Iteration is: 49430
# Physicial loss of p1 is: 0.0023863567039370537
# Physicial loss of p2 is: 0.0010585958370938897
# Physicial loss of s is: 0.002219065325334668
# Iteration is: 49440
# Physicial loss of p1 is: 0.0019318723352625966
# Physicial loss of p2 is: 0.0011935548391193151
# Physicial loss of s is: 0.0019847440999001265
# Iteration is: 49450
# Physicial loss of p1 is: 0.0017367288237437606
# Physicial loss of p2 is: 0.0003561936900950968
# Physicial loss of s is: 0.0006460871663875878
# Iteration is: 49460
# Physicial loss of p1 is: 0.0017978312680497766
# Physicial loss of p2 is: 0.000757214380428195
# Physicial loss of s is: 0.0010706643806770444
# Iteration is: 49470
# Physicial loss of p1 is: 0.0019236394437029958
# Physicial loss of p2 is: 0.0008770612184889615
# Physicial loss of s is: 0.0012558834860101342
# Iteration is: 49480
# Physicial loss of p1 is: 0.0037388999480754137
# Physicial loss of p2 is: 0.0018527378560975194
# Physicial loss of s is: 0.004098974633961916
# Iteration is: 49490
# Physicial loss of p1 is: 0.0021801728289574385
# Physicial loss of p2 is: 0.0003582566569093615
# Physicial loss of s is: 0.0013339731376618147
# Iteration is: 49500
# Physicial loss of p1 is: 0.0018140632892027497
# Physicial loss of p2 is: 0.0010864041978493333
# Physicial loss of s is: 0.0016264042351394892
# Iteration is: 49510
# Physicial loss of p1 is: 0.0017654660623520613
# Physicial loss of p2 is: 0.0003046619822271168
# Physicial loss of s is: 0.0006637818296439946
# Iteration is: 49520
# Physicial loss of p1 is: 0.0017068402376025915
# Physicial loss of p2 is: 0.00040167529368773103
# Physicial loss of s is: 0.0006224641692824662
# Iteration is: 49530
# Physicial loss of p1 is: 0.001965327188372612
# Physicial loss of p2 is: 0.002029596595093608
# Physicial loss of s is: 0.0028392423409968615
# Iteration is: 49540
# Physicial loss of p1 is: 0.0018581125186756253
# Physicial loss of p2 is: 0.00034031993709504604
# Physicial loss of s is: 0.0005895262002013624
# Iteration is: 49550
# Physicial loss of p1 is: 0.002024126471951604
# Physicial loss of p2 is: 0.0010843826457858086
# Physicial loss of s is: 0.0019261816050857306
# Iteration is: 49560
# Physicial loss of p1 is: 0.0017135385423898697
# Physicial loss of p2 is: 0.00042791152372956276
# Physicial loss of s is: 0.0005978349945507944
# Iteration is: 49570
# Physicial loss of p1 is: 0.001846061903052032
# Physicial loss of p2 is: 0.0013965978287160397
# Physicial loss of s is: 0.0019558416679501534
# Iteration is: 49580
# Physicial loss of p1 is: 0.0018658499466255307
# Physicial loss of p2 is: 0.0005974656087346375
# Physicial loss of s is: 0.000896360375918448
# Iteration is: 49590
# Physicial loss of p1 is: 0.002905811881646514
# Physicial loss of p2 is: 0.0013257417595013976
# Physicial loss of s is: 0.00271225837059319
# Iteration is: 49600
# Physicial loss of p1 is: 0.0018044929020106792
# Physicial loss of p2 is: 0.0005915708607062697
# Physicial loss of s is: 0.000967088679317385
# Iteration is: 49610
# Physicial loss of p1 is: 0.0017598745180293918
# Physicial loss of p2 is: 0.0010645814472809434
# Physicial loss of s is: 0.0016024734359234571
# Iteration is: 49620
# Physicial loss of p1 is: 0.0016834210837259889
# Physicial loss of p2 is: 0.000271129043539986
# Physicial loss of s is: 0.00045852098264731467
# Iteration is: 49630
# Physicial loss of p1 is: 0.0017573792720213532
# Physicial loss of p2 is: 0.000685135368257761
# Physicial loss of s is: 0.0009401716524735093
# Iteration is: 49640
# Physicial loss of p1 is: 0.0019000497413799167
# Physicial loss of p2 is: 0.0019189338199794292
# Physicial loss of s is: 0.002637899247929454
# Iteration is: 49650
# Physicial loss of p1 is: 0.002415664726868272
# Physicial loss of p2 is: 0.00028037908487021923
# Physicial loss of s is: 0.001133200479671359
# Iteration is: 49660
# Physicial loss of p1 is: 0.0017210589721798897
# Physicial loss of p2 is: 0.0008467987645417452
# Physicial loss of s is: 0.0012515598209574819
# Iteration is: 49670
# Physicial loss of p1 is: 0.0018441362772136927
# Physicial loss of p2 is: 0.0013396857539191842
# Physicial loss of s is: 0.002560765016824007
# Iteration is: 49680
# Physicial loss of p1 is: 0.0016651340993121266
# Physicial loss of p2 is: 0.0003125832590740174
# Physicial loss of s is: 0.0005998956621624529
# Iteration is: 49690
# Physicial loss of p1 is: 0.0017674408154562116
# Physicial loss of p2 is: 0.0009627426625229418
# Physicial loss of s is: 0.0013087224215269089
# Iteration is: 49700
# Physicial loss of p1 is: 0.0018706334521993995
# Physicial loss of p2 is: 0.0010576217900961637
# Physicial loss of s is: 0.0014584731543436646
# Iteration is: 49710
# Physicial loss of p1 is: 0.0018427280010655522
# Physicial loss of p2 is: 0.0007625605794601142
# Physicial loss of s is: 0.001084185903891921
# Iteration is: 49720
# Physicial loss of p1 is: 0.0018734527984634042
# Physicial loss of p2 is: 0.0009367571910843253
# Physicial loss of s is: 0.001321720890700817
# Iteration is: 49730
# Physicial loss of p1 is: 0.001993486424908042
# Physicial loss of p2 is: 0.0010538382921367884
# Physicial loss of s is: 0.0015572065021842718
# Iteration is: 49740
# Physicial loss of p1 is: 0.0018972523976117373
# Physicial loss of p2 is: 0.00037313977372832596
# Physicial loss of s is: 0.0007185328868217766
# Iteration is: 49750
# Physicial loss of p1 is: 0.0016827789368107915
# Physicial loss of p2 is: 0.0003437327977735549
# Physicial loss of s is: 0.0006076009012758732
# Iteration is: 49760
# Physicial loss of p1 is: 0.0019309428753331304
# Physicial loss of p2 is: 0.003826550440862775
# Physicial loss of s is: 0.004901031963527203
# Iteration is: 49770
# Physicial loss of p1 is: 0.0022367448545992374
# Physicial loss of p2 is: 0.0014681253815069795
# Physicial loss of s is: 0.0021708339918404818
# Iteration is: 49780
# Physicial loss of p1 is: 0.001986975083127618
# Physicial loss of p2 is: 0.0004095036129001528
# Physicial loss of s is: 0.0010522769298404455
# Iteration is: 49790
# Physicial loss of p1 is: 0.0018343429546803236
# Physicial loss of p2 is: 0.00035629316698759794
# Physicial loss of s is: 0.0009167504031211138
# Iteration is: 49800
# Physicial loss of p1 is: 0.001714671147055924
# Physicial loss of p2 is: 0.0006800551200285554
# Physicial loss of s is: 0.0009843322914093733
# Iteration is: 49810
# Physicial loss of p1 is: 0.0017208856297656894
# Physicial loss of p2 is: 0.0005872045876458287
# Physicial loss of s is: 0.0007937212940305471
# Iteration is: 49820
# Physicial loss of p1 is: 0.0018233933951705694
# Physicial loss of p2 is: 0.0007216018275357783
# Physicial loss of s is: 0.0010389129165560007
# Iteration is: 49830
# Physicial loss of p1 is: 0.003137021791189909
# Physicial loss of p2 is: 0.0017150911735370755
# Physicial loss of s is: 0.0033672675490379333
# Iteration is: 49840
# Physicial loss of p1 is: 0.0017170775681734085
# Physicial loss of p2 is: 0.00034081327612511814
# Physicial loss of s is: 0.0006429805653169751
# Iteration is: 49850
# Physicial loss of p1 is: 0.0016668769530951977
# Physicial loss of p2 is: 0.0008861383539624512
# Physicial loss of s is: 0.0013780647423118353
# Iteration is: 49860
# Physicial loss of p1 is: 0.0017392383888363838
# Physicial loss of p2 is: 0.0014811927685514092
# Physicial loss of s is: 0.0023258342407643795
# Iteration is: 49870
# Physicial loss of p1 is: 0.0017329365946352482
# Physicial loss of p2 is: 0.0004838748718611896
# Physicial loss of s is: 0.0007985965348780155
# Iteration is: 49880
# Physicial loss of p1 is: 0.0017811007564887404
# Physicial loss of p2 is: 0.0012771543115377426
# Physicial loss of s is: 0.0017617219127714634
# Iteration is: 49890
# Physicial loss of p1 is: 0.0016741784056648612
# Physicial loss of p2 is: 0.0004039954219479114
# Physicial loss of s is: 0.0005799484788440168
# Iteration is: 49900
# Physicial loss of p1 is: 0.0017355384770780802
# Physicial loss of p2 is: 0.0002890527539420873
# Physicial loss of s is: 0.0005301974597387016
# Iteration is: 49910
# Physicial loss of p1 is: 0.0032685452606528997
# Physicial loss of p2 is: 0.0013898038305342197
# Physicial loss of s is: 0.003207928966730833
# Iteration is: 49920
# Physicial loss of p1 is: 0.0020380693022161722
# Physicial loss of p2 is: 0.000650261586997658
# Physicial loss of s is: 0.001592265791259706
# Iteration is: 49930
# Physicial loss of p1 is: 0.0017741327174007893
# Physicial loss of p2 is: 0.0006205563549883664
# Physicial loss of s is: 0.0010308233322575688
# Iteration is: 49940
# Physicial loss of p1 is: 0.0017305550863966346
# Physicial loss of p2 is: 0.0006213573506101966
# Physicial loss of s is: 0.001074533094651997
# Iteration is: 49950
# Physicial loss of p1 is: 0.00161437236238271
# Physicial loss of p2 is: 0.0002926258312072605
# Physicial loss of s is: 0.00047071720473468304
# Iteration is: 49960
# Physicial loss of p1 is: 0.0016372232930734754
# Physicial loss of p2 is: 0.0002882538246922195
# Physicial loss of s is: 0.0004556613857857883
# Iteration is: 49970
# Physicial loss of p1 is: 0.0016927558463066816
# Physicial loss of p2 is: 0.0010004318319261074
# Physicial loss of s is: 0.001430378295481205
# Iteration is: 49980
# Physicial loss of p1 is: 0.0017850195290520787
# Physicial loss of p2 is: 0.0015342384576797485
# Physicial loss of s is: 0.0021067638881504536
# Iteration is: 49990
# Physicial loss of p1 is: 0.0018991150427609682
# Physicial loss of p2 is: 0.0013691368512809277
# Physicial loss of s is: 0.0021791313774883747
# Iteration is: 50000
# Physicial loss of p1 is: 0.0036663415376096964
# Physicial loss of p2 is: 0.0007401856710202992
# Physicial loss of s is: 0.0036844527348876
# Training time: 173.3212

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip1_list = [loss_fisp1[i].numpy() for i in range(0,Nmax)]
loss_phip2_list = [loss_fisp2[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(ep, np.asarray(loss_data_list), 'y-', linewidth = 2, alpha=0.6, label = '$\mathcal{L}_u$')  
plt.semilogy(ep, np.asarray(loss_phip1_list), 'r-', linewidth = 2, alpha=0.6, label = '$\mathcal{L}_{p1}$') 
plt.semilogy(ep, np.asarray(loss_phip2_list), 'b-', linewidth = 2, alpha=0.6, label = '$\mathcal{L}_{p2}$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\mathcal{L}_s$')       



plt.legend(fontsize=14, ncols=1, frameon=False)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('$\mathcal{L}$', fontsize=14)    
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)  
plt.tight_layout()
plt.savefig('../Img/700/Loss_split.png')
plt.savefig('../Img/700/Loss_split.pdf')
plt.savefig('../Img/700/Loss_split.svg')
plt.show()

# %%
lnv[0], tf.exp(lnv[0]), lnv[1], tf.exp(lnv[1])#, lnv[2], tf.exp(lnv[2])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([-0.6663783], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.5135652], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.7317036], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([5.650272], dtype=float32)>)

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp1=u_pred[:,0:1]
lnp2=u_pred[:,1:2]
lns=u_pred[:,2:3]

p1=tf.exp(lnp1)
p2=tf.exp(lnp2)
s=tf.exp(lns)

delta1=tf.exp(lnv[0:1])
delta2=tf.exp(lnv[1:2])


# lnphi11 = predict(tf.concat([p1, s],1), W_phi_1, b_phi_1)
# lnphi12 = predict(tf.concat([p2, s],1), W_phi_1, b_phi_1)

lnphi = predict(s, W_phi_1, b_phi_1)



phi11=tf.exp(lnphi[...,0:1])
phi12=phi11
phi2=tf.exp(lnphi[...,1:2])

# %%
X_star_tf.shape, p1.shape
# Out:
# (TensorShape([1710, 2]), TensorShape([1710, 1]))

# %%
colors = plt.cm.tab20.colors

# %%
for i in range(N_exp):
    plt.scatter(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], p1[L_exp*i:L_exp*(i+1)], marker='x', s=1, color=colors[2])
    plt.scatter(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], p2[L_exp*i:L_exp*(i+1)], marker='x', s=1,  color=colors[4])
    # plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for i in range(N_exp):
    plt.scatter(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], (p1+p2)[L_exp*i:L_exp*(i+1)], marker='x', s=1, color=colors[0])
    plt.scatter(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], s[L_exp*i:L_exp*(i+1)], marker='x', s=1, color=colors[1])
    plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()
plt.xlabel('t')
# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
for i in range(1, N_exp):
    # plt.plot(p[L_exp*i:L_exp*(i+1)][:,0], phi[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0])
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi11[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[1])
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi12[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0])

# %%
for i in range(0, N_exp):
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi11[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0])

# plt.plot(p, phi,linewidth=3)
# plt.plot(s, phi, linewidth=3)
# plt.scatter(X_f_train_tf, np.zeros_like(X_f_train), marker='x', s=5, color='green',label='$f$')

# plt.legend(fontsize=14, ncols=1, frameon=False,  bbox_to_anchor=(1, 0.7))
plt.legend(fontsize=14, ncols=1, frameon=False)

plt.xlabel('S', fontsize=14)

plt.ylabel('$\phi_1(S)$', fontsize=14)
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)  
plt.tight_layout()
plt.savefig('../Img/700/Result_phi_1.png')
plt.savefig('../Img/700/Result_phi_1.pdf')
plt.savefig('../Img/700/Result_phi_1.svg')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for i in range(0, N_exp):
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi2[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0])

# plt.plot(p, phi,linewidth=3)
# plt.plot(s, phi, linewidth=3)
# plt.scatter(X_f_train_tf, np.zeros_like(X_f_train), marker='x', s=5, color='green',label='$f$')

# plt.legend(fontsize=14, ncols=1, frameon=False,  bbox_to_anchor=(1, 0.7))
plt.legend(fontsize=14, ncols=1, frameon=False)

plt.xlabel('S', fontsize=14)

plt.ylabel('$\phi_2(S)$', fontsize=14)
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)  
plt.tight_layout()
plt.savefig('../Img/700/Result_phi_2.png')
plt.savefig('../Img/700/Result_phi_2.pdf')
plt.savefig('../Img/700/Result_phi_2.svg')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi11[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0], label=r'$\phi_1$')

for i in range(1, N_exp):
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi11[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0])


plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi2[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[2], label=r'$\phi_2$')

for i in range(1, N_exp):
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi2[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[2])

# plt.plot(p, phi,linewidth=3)
# plt.plot(s, phi, linewidth=3)
# plt.scatter(X_f_train_tf, np.zeros_like(X_f_train), marker='x', s=5, color='green',label='$f$')

# plt.legend(fontsize=14, ncols=1, frameon=False,  bbox_to_anchor=(1, 0.7))
plt.legend(fontsize=14, ncols=1, frameon=False)

plt.xlabel('S', fontsize=14)

# plt.ylabel('$\phi_2(S)$', fontsize=14)
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)  
plt.tight_layout()
plt.savefig('../Img/700/Result_phi.png')
plt.savefig('../Img/700/Result_phi.pdf')
plt.savefig('../Img/700/Result_phi.svg')
plt.show()

# %%
for i in range(1, N_exp):
    # plt.plot(p[L_exp*i:L_exp*(i+1)][:,0], phi[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[0])
    plt.plot(s[L_exp*i:L_exp*(i+1)][:,0], phi2[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[1])

# %%
p2[::L_exp]
# Out:
# <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[0.09090397],
#        [0.09240245],
#        [0.08827066],
#        [0.09031174],
#        [0.08884884]], dtype=float32)>

# %%
p1[::L_exp]
# Out:
# <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[0.0047705 ],
#        [0.0045898 ],
#        [0.00511431],
#        [0.00484482],
#        [0.00503583]], dtype=float32)>

# %%
Nt=1000
T_int=np.zeros(Nt)
P1_int=np.zeros(Nt)
P2_int=np.zeros(Nt)
S_int=np.zeros(Nt)


dt=0.001

T_int[0]=0
P1_int[0]=np.array(p1[0]+0.00025) #Initial conditions

P2_int[0]=np.array(p2[0]) #Initial conditions
S_int[0]=np.array(s[0]) #Initial conditions


# m=0.3

for i in range(1,Nt):

    S_int_tf= tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32)
    PHI=predict(S_int_tf , W_phi_1, b_phi_1)
    PHI11=tf.exp(PHI[...,0:1])
    PHI12=PHI11
    PHI2=tf.exp(PHI[...,1:2])

    # P1_int[i]=P1_int[i-1]+(PHI11*S_int[i-1]*P1_int[i-1] - PHI2*P1_int[i-1]-delta1*P1_int[i-1])*dt
    # P2_int[i]=P2_int[i-1]+(PHI12*S_int[i-1]*P2_int[i-1] + PHI2*P1_int[i-1]-delta2*P2_int[i-1])*dt

    
    P1_int[i]=P1_int[i-1]+(PHI11*P1_int[i-1] + PHI2*P1_int[i-1]-delta1*P1_int[i-1])*dt
    P2_int[i]=P2_int[i-1]+(PHI12*P2_int[i-1] - PHI2*P1_int[i-1]-delta2*P2_int[i-1])*dt

    S_int[i]=S_int[i-1]-(PHI11*P1_int[i-1]+PHI12*P2_int[i-1])*dt
    T_int[i]=T_int[i-1]+dt

# %%
i=0
plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], (p1+p2)[L_exp*i:L_exp*(i+1)], color=colors[1], linestyle='-',linewidth=2, label='$\hat{P}$')
plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], s[L_exp*i:L_exp*(i+1)], color=colors[3], linestyle='-',linewidth=2, label='$\hat{S}$')

plt.scatter(X_u_train[:,0], P_train, marker='x', color='black',label='$u$')
for i in range(1, N_exp):
    plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], (p1+p2)[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[1])
    plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], s[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[3])

    plt.scatter(X_u_train[:,0], P_train, marker='x',  color='black')

plt.plot(T_int, P1_int+P2_int, linestyle='-.',linewidth=3, color=colors[0], label='$P_{int}$')
plt.plot(T_int, S_int, linestyle='-.',linewidth=3, color=colors[2], label='$S_{int}$')
# plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
# plt.legend(fontsize=12, ncols=1, frameon=False,  bbox_to_anchor=(0.7, 0.4))
plt.legend(fontsize=14, ncols=2, frameon=False)

plt.xlabel('t', fontsize=14)
# plt.ylabel('P', fontsize=14)
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)  
plt.tight_layout()
plt.savefig('../Img/700/Result_int.png')
plt.savefig('../Img/700/Result_int.pdf')
plt.savefig('../Img/700/Result_int.svg')
plt.show()

# %%
i=0
plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], p1[L_exp*i:L_exp*(i+1)],  color=colors[5], linestyle='-',linewidth=2, label='$\hat{P1}$')
plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], p2[L_exp*i:L_exp*(i+1)],  color=colors[7], linestyle='-',linewidth=2, label='$\hat{P2}$')

# plt.scatter(X_u_train[:,0], P_train, marker='x', color='black',label='$u$')
for i in range(1, N_exp):
    plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], p1[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[5])
    plt.plot(X_star_tf[L_exp*i:L_exp*(i+1)][:,0], p2[L_exp*i:L_exp*(i+1)], linestyle='-',linewidth=2,  color=colors[7])

    # plt.scatter(X_u_train[:,0], P_train, marker='x',  color='black')

plt.plot(T_int, P1_int, linestyle='-.',linewidth=3, color=colors[4], label='$P1_{int}$')
plt.plot(T_int, P2_int, linestyle='-.',linewidth=3, color=colors[6], label='$P2_{int}$')
# plt.scatter(X_star_tf[:,0], p, marker='x', s=1,  label='PINN Prediction P')
# plt.legend(fontsize=12, ncols=1, frameon=False,  bbox_to_anchor=(0.7, 0.4))
plt.legend(fontsize=14, ncols=1, frameon=False)

plt.xlabel('t', fontsize=14)
# plt.ylabel('P', fontsize=14)
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)  
plt.tight_layout()
plt.savefig('../Img/700/Result_int_2.png')
plt.savefig('../Img/700/Result_int_2.pdf')
plt.savefig('../Img/700/Result_int_2.svg')
plt.show()
