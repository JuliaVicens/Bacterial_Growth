# %%
import sys
sys.path.insert(0, '../Utilities/')
import os

from scipy.interpolate import griddata
from pyDOE import lhs
from plotting import newfig, savefig
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
from pysr import PySRRegressor
import sympy 
import pandas as pd

# %%
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
# Configurar para usar solo la memoria necesaria
# physical_devices = tf.config.list_physical_devices('GPU')
# if physical_devices:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print('done')

# %%
# Carga los archivos .xlsx
file1 = '../DataExperiments/WT_in_LB_data_s1.XLSX'
file2 = '../DataExperiments/different_conditions_data_s2.XLSX'

# Lee las hojas de los archivos
df1 = pd.read_excel(file1, engine='openpyxl')  # Especifica la hoja si es necesario: sheet_name='nombre_hoja'
df2 = pd.read_excel(file2, engine='openpyxl')

# Cambiar la fila 0 a la nueva cabecera
df2.columns = df2.iloc[0]  # Establecer la primera fila como nueva cabecera
df2 = df2[1:]  # Eliminar la primera fila

# Reiniciar los índices (opcional, si quieres que empiece desde 0)
df2 = df2.reset_index(drop=True)

# Muestra los DataFrames
print("Archivo 1:")
display(df1)

print("Archivo 2:")
display(df2)
# Out:
# Archivo 1:
#      Cycle Nr.  Time [s]  Temp. [°C]      G4      G5      G6      G7      G8  \
# 0            1       0.0        30.8  0.0922  0.0928  0.0928  0.0931  0.0928
# 1            2     678.6        30.7  0.0951  0.0957  0.0959  0.0959  0.0957
# 2            3    1357.1        30.4  0.0951  0.0958  0.0957  0.0960  0.0958
# 3            4    2035.7        30.2  0.0955  0.0962  0.0961  0.0965  0.0964
# 4            5    2714.2        30.0  0.0960  0.0969  0.0965  0.0968  0.0968
# ..         ...       ...         ...     ...     ...     ...     ...     ...
# 494        495  335199.8        30.8  0.8186  0.8214  0.8188  0.8198  0.8221
# 495        496  335878.3        30.9  0.8184  0.8222  0.8185  0.8178  0.8201
# 496        497  336556.8        30.8  0.8183  0.8222  0.8169  0.8204  0.8214
# 497        498  337235.3        30.8  0.8172  0.8211  0.8194  0.8206  0.8227
# 498        499  337913.8        29.8  0.8191  0.8200  0.8186  0.8207  0.8226
#
#          G9     G10     G11     G12      H1      H2      H3      H4      H5  \
# 0    0.0927  0.0916  0.0921  0.0911  0.0936  0.0925  0.0918  0.0929  0.0931
# 1    0.0953  0.0947  0.0951  0.0941  0.0970  0.0958  0.0951  0.0963  0.0963
# 2    0.0954  0.0947  0.0951  0.0943  0.0971  0.0959  0.0952  0.0965  0.0964
# 3    0.0958  0.0950  0.0957  0.0947  0.0975  0.0964  0.0957  0.0969  0.0969
# 4    0.0964  0.0956  0.0963  0.0953  0.0981  0.0969  0.0961  0.0974  0.0973
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 494  0.8201  0.8296  0.8418  0.8292  0.4360  0.7711  0.8043  0.8181  0.8181
# 495  0.8182  0.8277  0.8379  0.8274  0.4379  0.7729  0.8038  0.8198  0.8180
# 496  0.8186  0.8287  0.8409  0.8289  0.4304  0.7719  0.8040  0.8187  0.8172
# 497  0.8201  0.8303  0.8417  0.8280  0.4321  0.7717  0.8043  0.8194  0.8173
# 498  0.8196  0.8285  0.8389  0.8276  0.4285  0.7712  0.8035  0.8189  0.8177
#
#          H6
# 0    0.0931
# 1    0.0962
# 2    0.0963
# 3    0.0969
# 4    0.0973
# ..      ...
# 494  0.8153
# 495  0.8154
# 496  0.8154
# 497  0.8143
# 498  0.8150
#
# [499 rows x 18 columns]
# Archivo 2:
# 0   Cycle Nr.  Time [s] Temp. [°C]      A1      A2      A3      A4      A5  \
# 0           1         0         30  0.0929  0.0971  0.0948  0.0961  0.0939
# 1           2     678.6       30.5  0.0925  0.0962  0.0946  0.0953  0.0935
# 2           3    1357.2       30.1  0.0926  0.0962   0.095  0.0954  0.0936
# 3           4    2035.8         30  0.0928  0.0981  0.0949  0.0956  0.0937
# 4           5    2714.4       30.3  0.0933  0.0985  0.0953   0.096  0.0942
# ..        ...       ...        ...     ...     ...     ...     ...     ...
# 337       338  228685.2       29.9  0.5954  0.6453  0.6513  0.6593  0.6599
# 338       339  229363.7       29.8  0.5937  0.6448  0.6495  0.6568  0.6572
# 339       340  230042.3       29.9  0.5923  0.6429  0.6487  0.6575  0.6589
# 340       341  230720.9       30.3  0.5912  0.6419  0.6484  0.6568   0.657
# 341       342  231399.5       30.8  0.5902  0.6415  0.6481  0.6563  0.6565
#
# 0        A6      A7  ...      H2      H3      H4      H5      H6      H7  \
# 0    0.0934  0.0938  ...  0.0913  0.0914  0.0924  0.0916  0.0925  0.0921
# 1    0.0931  0.0933  ...  0.0913  0.0916  0.0926   0.092  0.0914  0.0921
# 2    0.0932  0.0932  ...  0.0916  0.0917  0.0927  0.0918  0.0917  0.0922
# 3    0.0934  0.0934  ...   0.092  0.0921  0.0931  0.0922  0.0922  0.0928
# 4    0.0939  0.0938  ...  0.0925  0.0927  0.0937  0.0928   0.093  0.0933
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 337  0.6576  0.5901  ...  0.0926  0.0926  0.0935  0.0924  0.0949  1.0018
# 338  0.6564  0.5898  ...  0.0926  0.0927  0.0934  0.0926  0.0953  1.0017
# 339  0.6572  0.5889  ...  0.0925  0.0925  0.0933  0.0923  0.0947  1.0009
# 340  0.6548  0.5888  ...  0.0923  0.0924  0.0932  0.0921  0.0942  1.0004
# 341  0.6552  0.5872  ...  0.0923  0.0924  0.0933  0.0921  0.0934  1.0014
#
# 0        H8      H9     H10     H11
# 0     0.092   0.093  0.0927   0.093
# 1    0.0921  0.0931  0.0932  0.0925
# 2    0.0923  0.0932  0.0932  0.0927
# 3    0.0926  0.0936  0.0937   0.093
# 4    0.0933  0.0943  0.0944  0.0938
# ..      ...     ...     ...     ...
# 337  0.9769  0.9848  0.9871  0.9972
# 338    0.98  0.9857  0.9868  0.9976
# 339  0.9758  0.9833  0.9846  0.9963
# 340  0.9763  0.9843  0.9845  0.9981
# 341  0.9772  0.9853  0.9843  0.9956
#
# [342 rows x 98 columns]

# %%
P0_exp=df2.iloc[:, -5:]
P1_exp=df2.iloc[:, 3:9]
P2_exp=df2.iloc[:, 9:14]
P3_exp=df2.iloc[:, [15,19,20]]


P0_exp, P1_exp, P2_exp, P3_exp
# Out:
# (0        H7      H8      H9     H10     H11
#  0    0.0921   0.092   0.093  0.0927   0.093
#  1    0.0921  0.0921  0.0931  0.0932  0.0925
#  2    0.0922  0.0923  0.0932  0.0932  0.0927
#  3    0.0928  0.0926  0.0936  0.0937   0.093
#  4    0.0933  0.0933  0.0943  0.0944  0.0938
#  ..      ...     ...     ...     ...     ...
#  337  1.0018  0.9769  0.9848  0.9871  0.9972
#  338  1.0017    0.98  0.9857  0.9868  0.9976
#  339  1.0009  0.9758  0.9833  0.9846  0.9963
#  340  1.0004  0.9763  0.9843  0.9845  0.9981
#  341  1.0014  0.9772  0.9853  0.9843  0.9956
#
#  [342 rows x 5 columns],
#  0        A1      A2      A3      A4      A5      A6
#  0    0.0929  0.0971  0.0948  0.0961  0.0939  0.0934
#  1    0.0925  0.0962  0.0946  0.0953  0.0935  0.0931
#  2    0.0926  0.0962   0.095  0.0954  0.0936  0.0932
#  3    0.0928  0.0981  0.0949  0.0956  0.0937  0.0934
#  4    0.0933  0.0985  0.0953   0.096  0.0942  0.0939
#  ..      ...     ...     ...     ...     ...     ...
#  337  0.5954  0.6453  0.6513  0.6593  0.6599  0.6576
#  338  0.5937  0.6448  0.6495  0.6568  0.6572  0.6564
#  339  0.5923  0.6429  0.6487  0.6575  0.6589  0.6572
#  340  0.5912  0.6419  0.6484  0.6568   0.657  0.6548
#  341  0.5902  0.6415  0.6481  0.6563  0.6565  0.6552
#
#  [342 rows x 6 columns],
#  0        A7      A8      A9     A10     A11
#  0    0.0938  0.0933  0.0947   0.094  0.0945
#  1    0.0933  0.0932  0.0948  0.0937  0.0937
#  2    0.0932  0.0933  0.0948  0.0939  0.0939
#  3    0.0934  0.0935   0.095  0.0941  0.0941
#  4    0.0938  0.0939  0.0954  0.0945  0.0945
#  ..      ...     ...     ...     ...     ...
#  337  0.5901  0.6007  0.5678  0.5227  0.5631
#  338  0.5898  0.6002  0.5683  0.5222  0.5616
#  339  0.5889  0.5999  0.5681  0.5221  0.5621
#  340  0.5888  0.5992  0.5675  0.5211   0.561
#  341  0.5872  0.5982  0.5666  0.5205  0.5609
#
#  [342 rows x 5 columns],
#  0        B1      B5      B6
#  0    0.0931   0.095  0.0975
#  1    0.0926  0.0944  0.0961
#  2     0.093  0.0944  0.0962
#  3    0.0931  0.0946  0.0964
#  4    0.0935  0.0949  0.0966
#  ..      ...     ...     ...
#  337  0.1624  0.2816  0.1234
#  338  0.1624   0.284  0.1238
#  339  0.1625  0.2846  0.1239
#  340  0.1627  0.2858  0.1243
#  341  0.1626  0.2856  0.1245
#
#  [342 rows x 3 columns])

# %%
P2_exp.shape
# Out:
# (342, 5)

# %%
plt.plot(P2_exp)
# Out:
# [<matplotlib.lines.Line2D at 0x1eb2687e460>,
#  <matplotlib.lines.Line2D at 0x1eb2687e280>,
#  <matplotlib.lines.Line2D at 0x1eb2687eb50>,
#  <matplotlib.lines.Line2D at 0x1ead6f884c0>,
#  <matplotlib.lines.Line2D at 0x1eb40c39b50>]

# %%
P1_exp.shape
# Out:
# (342, 6)

# %%
c=-1
P_exp=np.hstack((P0_exp,P1_exp,P2_exp,P3_exp))
T_exp=np.array(df2['Time [s]'])

T_max=max(T_exp)
T_exp=T_exp/max(T_exp)
N_exp=P_exp.shape[1]
n=np.array([P0_exp.shape[1],P1_exp.shape[1],P2_exp.shape[1],P3_exp.shape[1],])
A=np.array([0, 1.25, 2.50, 3.75])
N_exp,T_max, T_exp.shape, P_exp.shape, 342*23
# Out:
# (19, 231399.5, (342,), (342, 19), 7866)

# %%
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)

plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
N_f = 1000 # Number of residual point
N_d = 1500 #Number of data

P_star = P_exp.T.flatten().reshape([-1,1])
Xa_star=[]
P0_star=np.empty((0, 1))
X_star = np.empty((0, 3))
for i in range(len(A)):
    P0=P_exp[0:1, np.sum(n[:i]):np.sum(n[:i+1])]
    P0_star=np.concatenate((P0_star,P0.T))
    T_meshgrid, P0_meshgrid, A_meshgrid = np.meshgrid(T_exp, P0, A[i])
    x=np.hstack((T_meshgrid.flatten()[:,None], P0_meshgrid.flatten()[:,None], A_meshgrid.flatten()[:,None]))
    Xa_star += [x]
    X_star=np.vstack((X_star,x))


u_star=np.hstack((P_star,X_star[:,1:2]))

# %%
# T_star = np.tile(T_exp,N_exp).reshape([-1,1])

# Doman bounds
lb = X_star.min(0)
lb[1]=lb[1]
ub = X_star.max(0) 
ub[1]=ub[1]


# Initial Condition
xx0 = X_star[::len(T_exp)]
uu0 = P_star[::len(T_exp)]

xx1= np.hstack((np.ones(len(P0_star)).reshape([-1,1]), P0_star.reshape([-1,1]), xx0[...,2:3]))

xx01=np.vstack((xx0, xx1))
uu01=np.array([1]*N_exp+[0]*N_exp).reshape([-1,1])

# Additional data
idx = np.random.choice(P_star.shape[0], N_d-len(uu0), replace=False)
xxd = X_star[idx]
uud = P_star[idx]

X_u_train = np.concatenate((xx0,xxd))
P_train = np.concatenate((uu0,uud))

X_f_train = lb + (ub-lb)*lhs(3, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

X_u_train_tf = tf.convert_to_tensor(X_u_train, dtype=tf.float32)
P_train_tf =   tf.convert_to_tensor(P_train, dtype=tf.float32)
X_f_train_tf = tf.convert_to_tensor(X_f_train, dtype=tf.float32)
P_star_tf = tf.convert_to_tensor(P_star, dtype=tf.float32)
xx01_tf = tf.convert_to_tensor(xx01, dtype=tf.float32)
uu01_tf = tf.convert_to_tensor(uu01, dtype=tf.float32)

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')
plt.show()

# %%
L_exp=len(P_exp[:,1])
for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        plt.plot(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_exp[:, (i + np.sum(n[:k]))], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,1],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, s=5)

plt.xlabel('t (ms)')
plt.ylabel('P ')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],P_star[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=5,  color=color)


plt.xlabel('t (ms)')
plt.ylabel('P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')

plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,1], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('P0')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
plt.scatter(X_f_train_tf[:,0], X_f_train_tf[:,2], s=5, marker='x', color='green',label='Data P')


plt.legend()
plt.xlabel('t')
plt.ylabel('A')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
np.random.seed(seed=1234)
tf.random.set_seed(1234)
tf.config.experimental.enable_tensor_float_32_execution(False)
#os.environ[‘TF_ENABLE_AUTO_MIXED_PRECISION’] = ‘1’



# Initalization of Network
def hyper_initial(size):
    in_dim = size[0]
    out_dim = size[1]
    std = np.sqrt(2.0/(in_dim + out_dim))
    return tf.Variable(tf.random.truncated_normal(shape=size, stddev = std))

# Neural Network 
def DNN(X, W, b):
    # A = 2.0*(X - lb)/(ub - lb) - 1.0
    A=X
    L = len(W)
    for i in range(L-1):
        A = tf.tanh(tf.add(tf.matmul(A, W[i]), b[i]))
    Y = tf.add(tf.matmul(A, W[-1]), b[-1])
    return Y

def train_vars(W, b):
    return W + b 


def net(t, w, b):
    p = DNN(t, w, b)
    return p

def loss_weight(N_r, N_b):
    alpha_b = tf.Variable(tf.reshape(tf.repeat(1000.0, N_b), (N_b, -1))) 
    alpha_r = tf.Variable(tf.ones(shape=[N_r+N_b, 3]), dtype=tf.float32)
    # alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp*2), (N_exp*2, -1)))
    alpha_0 = tf.Variable(tf.reshape(tf.repeat(1000.0, N_exp * 2 * 2), (N_exp * 2, 2))) 
    return alpha_r, alpha_b, alpha_0


#@tf.function(jit_compile=True)
@tf.function()
def net_f(X_f, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv):
    with tf.GradientTape(persistent=True) as tape1:
        tape1.watch([X_f])
        u=net(X_f, W_p, b_p)

        lnp1=u[:,0:1]
        lnp2=u[:,1:2]
        lns=u[:,2:3]

        p1=tf.exp(lnp1)
        p2=tf.exp(lnp2)
        s=tf.exp(lns)
        m=tf.exp(lnv[0:1])
        lnl=net(X_f[...,2:3], W_a, b_a)
        l2=tf.exp(lnl)
        l1=tf.exp(lnv[1:2])
        mn=tf.exp(lnv[2:3])


        # phi=tf.exp(net(tf.concat([p, s, l],1), W_phi, b_phi))
        phi=tf.exp(net(s, W_phi, b_phi))



    p1_t = tape1.gradient(p1, X_f)[...,0:1]
    p2_t = tape1.gradient(p2, X_f)[...,0:1]
    s_t = tape1.gradient(s, X_f)[...,0:1]

    f_p1 = p1_t - phi*p1 + l1*p1
    f_p2 = p2_t - mn*phi*p2 + l2*p2
    f_s = s_t + m*phi*(p1+mn*p2)*s
    
    return f_p1, f_p2, f_s




#@tf.function()
# @tf.function()
def train_step(W_p, b_p,  W_phi, b_phi,  W_a, b_a,  X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_p, b_p, W_phi, b_phi, W_a, b_a, lambda_b, lambda_r, lambda_0, lnv])
        u_nn = net(X_u_train_tf, W_p, b_p) 
        lnp1=u_nn[:,0:1]
        lnp2=u_nn[:,1:2]
        p1_nn=tf.exp(lnp1)
        p2_nn=tf.exp(lnp2)
        f_p1, f_p2, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        u_00 = net(xx01_tf, W_p, b_p) 
        lns_0=u_00[:,2:3]
        s_00=tf.exp(lns_0)
        p2_00=tf.exp(u_00[:,1:2])
        p1_00=tf.exp(u_00[:,0:1])



        loss_p = tf.square(lambda_b*(p1_nn+p2_nn - P_train_tf))
        loss_0s = tf.square(lambda_0[:,0:1]*(s_00 - uu01_tf))
        loss_0p1 = tf.square(lambda_0[:N_exp,1:2]*(p1_00[:N_exp] - uu01_tf[N_exp:])) #p1 al principio peque
        loss_0p2 = tf.square(lambda_0[N_exp:,1:2]*(p2_00[N_exp:] - uu01_tf[N_exp:])) #p2 al final peque
        loss_fp1 = tf.square(lambda_r[:,0:1]*f_p1) 
        loss_fp2 = tf.square(lambda_r[:,1:2]*f_p2) 
        loss_fs = tf.square(lambda_r[:,2:3]*f_s) 


        loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)+ tf.reduce_mean(loss_0p1)+ tf.reduce_mean(loss_0p2)
        # loss =  tf.reduce_mean(loss_p) + tf.reduce_mean(loss_fp1)+ tf.reduce_mean(loss_fp2)+ tf.reduce_mean(loss_fs)+ tf.reduce_mean(loss_0s)

    grads_p = tape.gradient(loss, train_vars(W_p, b_p))
    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)
    grads_b = tape.gradient(loss, lambda_b)
    grads_0 = tape.gradient(loss, lambda_0)


    opt.apply_gradients(zip(grads_p, train_vars(W_p, b_p)))
    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))
    opt.apply_gradients(zip([-grads_b], [lambda_b]))
    opt.apply_gradients(zip([-grads_0], [lambda_0]))

   
    return loss, tf.reduce_mean(tf.square((p1_nn+p2_nn - P_train_tf))), tf.reduce_mean(tf.square(f_p1)), tf.reduce_mean(tf.square(f_p2)), tf.reduce_mean(tf.square(f_s))


layers = [3, 20, 20, 3]

L = len(layers)
W_p = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_p = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]

W_a = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_a = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

layers = [1, 20, 20, 1]
L = len(layers)

W_phi = [hyper_initial([layers[l-1], layers[l]]) for l in range(1, L)] 
b_phi = [tf.Variable(tf.zeros([1, layers[l]])) for l in range(1, L)]

lnv = tf.Variable(tf.reshape(tf.repeat(1.0, 3), (3, -1)), dtype=tf.float32) 
lambda_r, lambda_b, lambda_0 = loss_weight(N_f, N_d)

# %%
def train_dynamic_step( W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, opt):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch([W_phi, b_phi, W_a, b_a, lambda_r, lnv])

        f_p, f_s = net_f(X_f_train_tf, W_p, b_p, W_phi, b_phi, W_a, b_a, lnv)

        loss_fp = tf.square(lambda_r[0:1]*f_p) 
        loss_fs = tf.square(lambda_r[1:2]*f_s) 


        loss =  tf.reduce_mean(loss_fp)+ tf.reduce_mean(loss_fs)


    grads_phi = tape.gradient(loss, train_vars(W_phi, b_phi))
    grads_a = tape.gradient(loss, train_vars(W_a, b_a))

    grads_lnv = tape.gradient(loss, lnv)
    grads_u = tape.gradient(loss, lambda_r)



    opt.apply_gradients(zip(grads_phi, train_vars(W_phi, b_phi)))
    opt.apply_gradients(zip(grads_a, train_vars(W_a, b_a)))

    opt.apply_gradients(zip([grads_lnv], [lnv]))
    opt.apply_gradients(zip([-grads_u], [lambda_r]))

   
    return loss, 0, tf.reduce_mean(tf.square(f_p)), tf.reduce_mean(tf.square(f_s))

# %%
lr = 5e-3




optimizer = tf.optimizers.Adam(learning_rate=lr)
optimizer2 = tf.optimizers.Adam(learning_rate=lr/10)
# optimizer3 = tf.optimizers.Adam(learning_rate=lr/100)
# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
optimizer3 = tf.optimizers.Adam(learning_rate=lr/40)

# optimizer3 = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9, clipnorm=10.0)


start_time = time.time()
it=0
loss = []
loss_d = []
loss_fisp1 = []
loss_fisp2 = []
loss_fiss = []
loss_reg=[]
# loss_fisa = []

# Make a new Function and ConcreteFunction for each optimizer.
train_step_1 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf,  lambda_r, lambda_b, lambda_0, lnv, optimizer)
train_step_2 = tf.function(train_step).get_concrete_function(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv, optimizer2)
# train_step_3 = tf.function(train_dynamic_step).get_concrete_function(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv, optimizer2)

# %%
Nmax=2*10**5


while it <= Nmax:
    if it<10**5:
        loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    else:
        loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
    # else
        # loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_3(W_phi, b_phi,  W_a, b_a, X_f_train_tf, lambda_r, lnv)

    loss.append(loss_)
    loss_d.append(loss_p)
    loss_fisp1.append(loss_fp1)
    loss_fisp2.append(loss_fp2)
    loss_fiss.append(loss_fs)
    # loss_fisa.append(loss_fa)



    if it % 10 == 0:

        print(f"Iteration is: {it}")
        # print(f"Total loss is: {loss_}")
        # print(f"Data loss is: {loss_p}")
        print(f"Physicial loss of p1 is: {loss_fp1}")
        print(f"Physicial loss of p2 is: {loss_fp2}")
        print(f"Physicial loss of s is: {loss_fs}")
        # if n%10000 ==0:
        #     loss_reg_=eval(W_p, b_p, W_phi_s, b_phi_s)
        #     loss_reg.append(loss_reg_)
        # print(f"Physicial loss of a is: {loss_fa}")

    it+=1

elapsed = time.time() - start_time                
print('Training time: %.4f' % (elapsed))
# Out:
# Iteration is: 0
# Physicial loss of p1 is: 2.6824381351470947
# Physicial loss of p2 is: 1.4432646036148071
# Physicial loss of s is: 56.64971160888672
# Iteration is: 10
# Physicial loss of p1 is: 0.6300234198570251
# Physicial loss of p2 is: 0.04267996922135353
# Physicial loss of s is: 0.07371015101671219
# Iteration is: 20
# Physicial loss of p1 is: 0.1506662666797638
# Physicial loss of p2 is: 0.0033864257857203484
# Physicial loss of s is: 0.17336907982826233
# Iteration is: 30
# Physicial loss of p1 is: 0.5188466906547546
# Physicial loss of p2 is: 0.004004090558737516
# Physicial loss of s is: 0.5651241540908813
# Iteration is: 40
# Physicial loss of p1 is: 2.2698888778686523
# Physicial loss of p2 is: 0.007392234168946743
# Physicial loss of s is: 1.222286581993103
# Iteration is: 50
# Physicial loss of p1 is: 0.8581016659736633
# Physicial loss of p2 is: 0.0026324810460209846
# Physicial loss of s is: 1.4227702617645264
# Iteration is: 60
# Physicial loss of p1 is: 1.4748709201812744
# Physicial loss of p2 is: 0.0030162387993186712
# Physicial loss of s is: 1.442372441291809
# Iteration is: 70
# Physicial loss of p1 is: 0.9632437229156494
# Physicial loss of p2 is: 0.003118312219157815
# Physicial loss of s is: 1.6180833578109741
# Iteration is: 80
# Physicial loss of p1 is: 0.6256648302078247
# Physicial loss of p2 is: 0.006660103797912598
# Physicial loss of s is: 1.417710542678833
# Iteration is: 90
# Physicial loss of p1 is: 0.13497298955917358
# Physicial loss of p2 is: 0.020938100293278694
# Physicial loss of s is: 0.5425758957862854
# Iteration is: 100
# Physicial loss of p1 is: 0.16214559972286224
# Physicial loss of p2 is: 0.01248874980956316
# Physicial loss of s is: 0.24901172518730164
# Iteration is: 110
# Physicial loss of p1 is: 0.14242422580718994
# Physicial loss of p2 is: 0.001745481276884675
# Physicial loss of s is: 0.27244600653648376
# Iteration is: 120
# Physicial loss of p1 is: 0.14542804658412933
# Physicial loss of p2 is: 0.005350370891392231
# Physicial loss of s is: 0.27405548095703125
# Iteration is: 130
# Physicial loss of p1 is: 0.1771513670682907
# Physicial loss of p2 is: 0.005587921943515539
# Physicial loss of s is: 0.3065018355846405
# Iteration is: 140
# Physicial loss of p1 is: 0.21165312826633453
# Physicial loss of p2 is: 0.00879184901714325
# Physicial loss of s is: 0.32558298110961914
# Iteration is: 150
# Physicial loss of p1 is: 0.246133491396904
# Physicial loss of p2 is: 0.01328345201909542
# Physicial loss of s is: 0.35572877526283264
# Iteration is: 160
# Physicial loss of p1 is: 0.28919336199760437
# Physicial loss of p2 is: 0.01918579824268818
# Physicial loss of s is: 0.38197773694992065
# Iteration is: 170
# Physicial loss of p1 is: 0.3463920056819916
# Physicial loss of p2 is: 0.024858327582478523
# Physicial loss of s is: 0.399269700050354
# Iteration is: 180
# Physicial loss of p1 is: 0.40837401151657104
# Physicial loss of p2 is: 0.03094295598566532
# Physicial loss of s is: 0.41441625356674194
# Iteration is: 190
# Physicial loss of p1 is: 0.4655742645263672
# Physicial loss of p2 is: 0.04042970761656761
# Physicial loss of s is: 0.41764622926712036
# Iteration is: 200
# Physicial loss of p1 is: 0.5077775120735168
# Physicial loss of p2 is: 0.05385546758770943
# Physicial loss of s is: 0.40461358428001404
# Iteration is: 210
# Physicial loss of p1 is: 0.5044684410095215
# Physicial loss of p2 is: 0.07640524953603745
# Physicial loss of s is: 0.3803758919239044
# Iteration is: 220
# Physicial loss of p1 is: 0.4180053174495697
# Physicial loss of p2 is: 0.11971014738082886
# Physicial loss of s is: 0.38555893301963806
# Iteration is: 230
# Physicial loss of p1 is: 0.2425009310245514
# Physicial loss of p2 is: 0.27503544092178345
# Physicial loss of s is: 0.5158374309539795
# Iteration is: 240
# Physicial loss of p1 is: 0.11993987113237381
# Physicial loss of p2 is: 0.3490615785121918
# Physicial loss of s is: 0.6403071284294128
# Iteration is: 250
# Physicial loss of p1 is: 0.1380537450313568
# Physicial loss of p2 is: 0.32236841320991516
# Physicial loss of s is: 0.5759437680244446
# Iteration is: 260
# Physicial loss of p1 is: 0.15971249341964722
# Physicial loss of p2 is: 0.29558196663856506
# Physicial loss of s is: 0.4596979022026062
# Iteration is: 270
# Physicial loss of p1 is: 0.17354804277420044
# Physicial loss of p2 is: 0.29744502902030945
# Physicial loss of s is: 0.43780264258384705
# Iteration is: 280
# Physicial loss of p1 is: 0.18240539729595184
# Physicial loss of p2 is: 0.30219677090644836
# Physicial loss of s is: 0.42362499237060547
# Iteration is: 290
# Physicial loss of p1 is: 0.19608058035373688
# Physicial loss of p2 is: 0.29515892267227173
# Physicial loss of s is: 0.40151944756507874
# Iteration is: 300
# Physicial loss of p1 is: 0.21265803277492523
# Physicial loss of p2 is: 0.2841530740261078
# Physicial loss of s is: 0.3892853558063507
# Iteration is: 310
# Physicial loss of p1 is: 0.22717517614364624
# Physicial loss of p2 is: 0.2715555727481842
# Physicial loss of s is: 0.3844073712825775
# Iteration is: 320
# Physicial loss of p1 is: 0.2439267635345459
# Physicial loss of p2 is: 0.25432807207107544
# Physicial loss of s is: 0.3812187612056732
# Iteration is: 330
# Physicial loss of p1 is: 0.26019152998924255
# Physicial loss of p2 is: 0.23554301261901855
# Physicial loss of s is: 0.3791455626487732
# Iteration is: 340
# Physicial loss of p1 is: 0.27612975239753723
# Physicial loss of p2 is: 0.21652856469154358
# Physicial loss of s is: 0.37983956933021545
# Iteration is: 350
# Physicial loss of p1 is: 0.2931823432445526
# Physicial loss of p2 is: 0.1976076066493988
# Physicial loss of s is: 0.38248172402381897
# Iteration is: 360
# Physicial loss of p1 is: 0.3055092692375183
# Physicial loss of p2 is: 0.1903887242078781
# Physicial loss of s is: 0.37122806906700134
# Iteration is: 370
# Physicial loss of p1 is: 0.33078423142433167
# Physicial loss of p2 is: 0.16378895938396454
# Physicial loss of s is: 0.3967885375022888
# Iteration is: 380
# Physicial loss of p1 is: 0.3375617563724518
# Physicial loss of p2 is: 0.15177401900291443
# Physicial loss of s is: 0.3817051351070404
# Iteration is: 390
# Physicial loss of p1 is: 0.3555537462234497
# Physicial loss of p2 is: 0.1381911188364029
# Physicial loss of s is: 0.38818615674972534
# Iteration is: 400
# Physicial loss of p1 is: 0.3728804588317871
# Physicial loss of p2 is: 0.1280299872159958
# Physicial loss of s is: 0.3894718289375305
# Iteration is: 410
# Physicial loss of p1 is: 0.3865557610988617
# Physicial loss of p2 is: 0.11862508207559586
# Physicial loss of s is: 0.3803231120109558
# Iteration is: 420
# Physicial loss of p1 is: 0.40668660402297974
# Physicial loss of p2 is: 0.11014536023139954
# Physicial loss of s is: 0.38473761081695557
# Iteration is: 430
# Physicial loss of p1 is: 0.4156956076622009
# Physicial loss of p2 is: 0.10291112959384918
# Physicial loss of s is: 0.36037594079971313
# Iteration is: 440
# Physicial loss of p1 is: 0.4339064061641693
# Physicial loss of p2 is: 0.09568275511264801
# Physicial loss of s is: 0.365393728017807
# Iteration is: 450
# Physicial loss of p1 is: 0.4533582627773285
# Physicial loss of p2 is: 0.08900471031665802
# Physicial loss of s is: 0.36936691403388977
# Iteration is: 460
# Physicial loss of p1 is: 0.4609287977218628
# Physicial loss of p2 is: 0.08267617225646973
# Physicial loss of s is: 0.35029423236846924
# Iteration is: 470
# Physicial loss of p1 is: 0.480472594499588
# Physicial loss of p2 is: 0.07731668651103973
# Physicial loss of s is: 0.35998180508613586
# Iteration is: 480
# Physicial loss of p1 is: 0.4884513318538666
# Physicial loss of p2 is: 0.07167280465364456
# Physicial loss of s is: 0.3483036160469055
# Iteration is: 490
# Physicial loss of p1 is: 0.5003783106803894
# Physicial loss of p2 is: 0.06693239510059357
# Physicial loss of s is: 0.34680789709091187
# Iteration is: 500
# Physicial loss of p1 is: 0.5195953845977783
# Physicial loss of p2 is: 0.0632416233420372
# Physicial loss of s is: 0.36017894744873047
# Iteration is: 510
# Physicial loss of p1 is: 0.532891571521759
# Physicial loss of p2 is: 0.05941997095942497
# Physicial loss of s is: 0.36458060145378113
# Iteration is: 520
# Physicial loss of p1 is: 0.5445854663848877
# Physicial loss of p2 is: 0.05616428703069687
# Physicial loss of s is: 0.36867207288742065
# Iteration is: 530
# Physicial loss of p1 is: 0.5446947813034058
# Physicial loss of p2 is: 0.05273625627160072
# Physicial loss of s is: 0.35945430397987366
# Iteration is: 540
# Physicial loss of p1 is: 0.5574841499328613
# Physicial loss of p2 is: 0.050418537110090256
# Physicial loss of s is: 0.3685752749443054
# Iteration is: 550
# Physicial loss of p1 is: 0.5651881098747253
# Physicial loss of p2 is: 0.04827801510691643
# Physicial loss of s is: 0.37202152609825134
# Iteration is: 560
# Physicial loss of p1 is: 0.5982322096824646
# Physicial loss of p2 is: 0.04760279506444931
# Physicial loss of s is: 0.4043341875076294
# Iteration is: 570
# Physicial loss of p1 is: 0.5793641805648804
# Physicial loss of p2 is: 0.045077353715896606
# Physicial loss of s is: 0.3796216547489166
# Iteration is: 580
# Physicial loss of p1 is: 0.6027170419692993
# Physicial loss of p2 is: 0.04475873336195946
# Physicial loss of s is: 0.40435242652893066
# Iteration is: 590
# Physicial loss of p1 is: 0.6030967831611633
# Physicial loss of p2 is: 0.04383383318781853
# Physicial loss of s is: 0.40039438009262085
# Iteration is: 600
# Physicial loss of p1 is: 0.6096694469451904
# Physicial loss of p2 is: 0.04341055825352669
# Physicial loss of s is: 0.4053764343261719
# Iteration is: 610
# Physicial loss of p1 is: 0.6178631782531738
# Physicial loss of p2 is: 0.0433383472263813
# Physicial loss of s is: 0.4121471643447876
# Iteration is: 620
# Physicial loss of p1 is: 0.6267303228378296
# Physicial loss of p2 is: 0.04354136809706688
# Physicial loss of s is: 0.41936030983924866
# Iteration is: 630
# Physicial loss of p1 is: 0.6313236355781555
# Physicial loss of p2 is: 0.043887797743082047
# Physicial loss of s is: 0.42319414019584656
# Iteration is: 640
# Physicial loss of p1 is: 0.6287115216255188
# Physicial loss of p2 is: 0.044052716344594955
# Physicial loss of s is: 0.42390063405036926
# Iteration is: 650
# Physicial loss of p1 is: 0.6443349123001099
# Physicial loss of p2 is: 0.045299168676137924
# Physicial loss of s is: 0.432755708694458
# Iteration is: 660
# Physicial loss of p1 is: 0.6442159414291382
# Physicial loss of p2 is: 0.04652436077594757
# Physicial loss of s is: 0.43443763256073
# Iteration is: 670
# Physicial loss of p1 is: 0.6496793627738953
# Physicial loss of p2 is: 0.04829782247543335
# Physicial loss of s is: 0.43696820735931396
# Iteration is: 680
# Physicial loss of p1 is: 0.6559733152389526
# Physicial loss of p2 is: 0.050135351717472076
# Physicial loss of s is: 0.4416519105434418
# Iteration is: 690
# Physicial loss of p1 is: 0.6624819040298462
# Physicial loss of p2 is: 0.052289851009845734
# Physicial loss of s is: 0.44562774896621704
# Iteration is: 700
# Physicial loss of p1 is: 0.6617845892906189
# Physicial loss of p2 is: 0.05459132045507431
# Physicial loss of s is: 0.44470956921577454
# Iteration is: 710
# Physicial loss of p1 is: 0.6552582383155823
# Physicial loss of p2 is: 0.05701218917965889
# Physicial loss of s is: 0.4454253017902374
# Iteration is: 720
# Physicial loss of p1 is: 0.6657775044441223
# Physicial loss of p2 is: 0.06065474823117256
# Physicial loss of s is: 0.4452446401119232
# Iteration is: 730
# Physicial loss of p1 is: 0.6645655035972595
# Physicial loss of p2 is: 0.06434417515993118
# Physicial loss of s is: 0.444303423166275
# Iteration is: 740
# Physicial loss of p1 is: 0.6663133502006531
# Physicial loss of p2 is: 0.06810130923986435
# Physicial loss of s is: 0.4429841935634613
# Iteration is: 750
# Physicial loss of p1 is: 0.6692546606063843
# Physicial loss of p2 is: 0.07145266979932785
# Physicial loss of s is: 0.44317197799682617
# Iteration is: 760
# Physicial loss of p1 is: 0.6676946878433228
# Physicial loss of p2 is: 0.07595937699079514
# Physicial loss of s is: 0.44049498438835144
# Iteration is: 770
# Physicial loss of p1 is: 0.6703575849533081
# Physicial loss of p2 is: 0.08039414137601852
# Physicial loss of s is: 0.4398450255393982
# Iteration is: 780
# Physicial loss of p1 is: 0.6664177179336548
# Physicial loss of p2 is: 0.08569832891225815
# Physicial loss of s is: 0.43471723794937134
# Iteration is: 790
# Physicial loss of p1 is: 0.6681663393974304
# Physicial loss of p2 is: 0.08953534066677094
# Physicial loss of s is: 0.4360073208808899
# Iteration is: 800
# Physicial loss of p1 is: 0.6593581438064575
# Physicial loss of p2 is: 0.09580167382955551
# Physicial loss of s is: 0.4272408187389374
# Iteration is: 810
# Physicial loss of p1 is: 0.6544913649559021
# Physicial loss of p2 is: 0.101651132106781
# Physicial loss of s is: 0.4224438965320587
# Iteration is: 820
# Physicial loss of p1 is: 0.6469249725341797
# Physicial loss of p2 is: 0.1091320663690567
# Physicial loss of s is: 0.42281287908554077
# Iteration is: 830
# Physicial loss of p1 is: 0.6508364081382751
# Physicial loss of p2 is: 0.11103343218564987
# Physicial loss of s is: 0.41433554887771606
# Iteration is: 840
# Physicial loss of p1 is: 0.6422036290168762
# Physicial loss of p2 is: 0.11791764944791794
# Physicial loss of s is: 0.4086968004703522
# Iteration is: 850
# Physicial loss of p1 is: 0.6360015273094177
# Physicial loss of p2 is: 0.12424778193235397
# Physicial loss of s is: 0.40661221742630005
# Iteration is: 860
# Physicial loss of p1 is: 0.6353470683097839
# Physicial loss of p2 is: 0.12699122726917267
# Physicial loss of s is: 0.3965015113353729
# Iteration is: 870
# Physicial loss of p1 is: 0.6377772688865662
# Physicial loss of p2 is: 0.13073329627513885
# Physicial loss of s is: 0.39397066831588745
# Iteration is: 880
# Physicial loss of p1 is: 0.627750039100647
# Physicial loss of p2 is: 0.13560891151428223
# Physicial loss of s is: 0.3853468894958496
# Iteration is: 890
# Physicial loss of p1 is: 0.6200063824653625
# Physicial loss of p2 is: 0.14080186188220978
# Physicial loss of s is: 0.37599241733551025
# Iteration is: 900
# Physicial loss of p1 is: 0.6141530871391296
# Physicial loss of p2 is: 0.14579051733016968
# Physicial loss of s is: 0.36993592977523804
# Iteration is: 910
# Physicial loss of p1 is: 0.6105715036392212
# Physicial loss of p2 is: 0.14807072281837463
# Physicial loss of s is: 0.3596573770046234
# Iteration is: 920
# Physicial loss of p1 is: 0.6038629412651062
# Physicial loss of p2 is: 0.15310144424438477
# Physicial loss of s is: 0.3542720675468445
# Iteration is: 930
# Physicial loss of p1 is: 0.5969077348709106
# Physicial loss of p2 is: 0.15888358652591705
# Physicial loss of s is: 0.3547765016555786
# Iteration is: 940
# Physicial loss of p1 is: 0.5950639843940735
# Physicial loss of p2 is: 0.15651386976242065
# Physicial loss of s is: 0.3377177119255066
# Iteration is: 950
# Physicial loss of p1 is: 0.5863160490989685
# Physicial loss of p2 is: 0.16161620616912842
# Physicial loss of s is: 0.3371517062187195
# Iteration is: 960
# Physicial loss of p1 is: 0.583378255367279
# Physicial loss of p2 is: 0.16070185601711273
# Physicial loss of s is: 0.34372588992118835
# Iteration is: 970
# Physicial loss of p1 is: 0.5662682056427002
# Physicial loss of p2 is: 0.16554796695709229
# Physicial loss of s is: 0.3101167678833008
# Iteration is: 980
# Physicial loss of p1 is: 0.5594165921211243
# Physicial loss of p2 is: 0.16937069594860077
# Physicial loss of s is: 0.3255998492240906
# Iteration is: 990
# Physicial loss of p1 is: 0.55576491355896
# Physicial loss of p2 is: 0.17003938555717468
# Physicial loss of s is: 0.30228182673454285
# Iteration is: 1000
# Physicial loss of p1 is: 0.5518101453781128
# Physicial loss of p2 is: 0.17277467250823975
# Physicial loss of s is: 0.3014490604400635
# Iteration is: 1010
# Physicial loss of p1 is: 0.5465282201766968
# Physicial loss of p2 is: 0.17130692303180695
# Physicial loss of s is: 0.29682642221450806
# Iteration is: 1020
# Physicial loss of p1 is: 0.5416484475135803
# Physicial loss of p2 is: 0.16939525306224823
# Physicial loss of s is: 0.290330708026886
# Iteration is: 1030
# Physicial loss of p1 is: 0.5358078479766846
# Physicial loss of p2 is: 0.1731267273426056
# Physicial loss of s is: 0.2927077114582062
# Iteration is: 1040
# Physicial loss of p1 is: 0.5303359031677246
# Physicial loss of p2 is: 0.16997377574443817
# Physicial loss of s is: 0.2867085337638855
# Iteration is: 1050
# Physicial loss of p1 is: 0.5250310897827148
# Physicial loss of p2 is: 0.17120042443275452
# Physicial loss of s is: 0.2864804267883301
# Iteration is: 1060
# Physicial loss of p1 is: 0.5200004577636719
# Physicial loss of p2 is: 0.1704157441854477
# Physicial loss of s is: 0.28467294573783875
# Iteration is: 1070
# Physicial loss of p1 is: 0.5161439180374146
# Physicial loss of p2 is: 0.1709798127412796
# Physicial loss of s is: 0.2850480377674103
# Iteration is: 1080
# Physicial loss of p1 is: 0.5095683336257935
# Physicial loss of p2 is: 0.16758793592453003
# Physicial loss of s is: 0.2784789204597473
# Iteration is: 1090
# Physicial loss of p1 is: 0.49910053610801697
# Physicial loss of p2 is: 0.16683027148246765
# Physicial loss of s is: 0.27609124779701233
# Iteration is: 1100
# Physicial loss of p1 is: 0.49280548095703125
# Physicial loss of p2 is: 0.16648776829242706
# Physicial loss of s is: 0.28644952178001404
# Iteration is: 1110
# Physicial loss of p1 is: 0.49101361632347107
# Physicial loss of p2 is: 0.16534928977489471
# Physicial loss of s is: 0.2869613766670227
# Iteration is: 1120
# Physicial loss of p1 is: 0.4893162250518799
# Physicial loss of p2 is: 0.16341504454612732
# Physicial loss of s is: 0.2846868336200714
# Iteration is: 1130
# Physicial loss of p1 is: 0.48828738927841187
# Physicial loss of p2 is: 0.1623544991016388
# Physicial loss of s is: 0.285508930683136
# Iteration is: 1140
# Physicial loss of p1 is: 0.486191064119339
# Physicial loss of p2 is: 0.1602933555841446
# Physicial loss of s is: 0.28657278418540955
# Iteration is: 1150
# Physicial loss of p1 is: 0.48450541496276855
# Physicial loss of p2 is: 0.15867897868156433
# Physicial loss of s is: 0.28735724091529846
# Iteration is: 1160
# Physicial loss of p1 is: 0.48314136266708374
# Physicial loss of p2 is: 0.15698124468326569
# Physicial loss of s is: 0.2879989445209503
# Iteration is: 1170
# Physicial loss of p1 is: 0.4818676710128784
# Physicial loss of p2 is: 0.1553424745798111
# Physicial loss of s is: 0.28897637128829956
# Iteration is: 1180
# Physicial loss of p1 is: 0.48056304454803467
# Physicial loss of p2 is: 0.15370683372020721
# Physicial loss of s is: 0.29018235206604004
# Iteration is: 1190
# Physicial loss of p1 is: 0.47967132925987244
# Physicial loss of p2 is: 0.15236467123031616
# Physicial loss of s is: 0.2911250591278076
# Iteration is: 1200
# Physicial loss of p1 is: 0.483233779668808
# Physicial loss of p2 is: 0.1510988473892212
# Physicial loss of s is: 0.2945532202720642
# Iteration is: 1210
# Physicial loss of p1 is: 0.4682011306285858
# Physicial loss of p2 is: 0.1509711742401123
# Physicial loss of s is: 0.3020186424255371
# Iteration is: 1220
# Physicial loss of p1 is: 0.4641909599304199
# Physicial loss of p2 is: 0.14900989830493927
# Physicial loss of s is: 0.2999294698238373
# Iteration is: 1230
# Physicial loss of p1 is: 0.4670201241970062
# Physicial loss of p2 is: 0.14831627905368805
# Physicial loss of s is: 0.29832351207733154
# Iteration is: 1240
# Physicial loss of p1 is: 0.46766117215156555
# Physicial loss of p2 is: 0.1479189395904541
# Physicial loss of s is: 0.30113065242767334
# Iteration is: 1250
# Physicial loss of p1 is: 0.4685521423816681
# Physicial loss of p2 is: 0.1463458240032196
# Physicial loss of s is: 0.3022393584251404
# Iteration is: 1260
# Physicial loss of p1 is: 0.4690805673599243
# Physicial loss of p2 is: 0.1448507308959961
# Physicial loss of s is: 0.30364978313446045
# Iteration is: 1270
# Physicial loss of p1 is: 0.46973782777786255
# Physicial loss of p2 is: 0.14411284029483795
# Physicial loss of s is: 0.30467477440834045
# Iteration is: 1280
# Physicial loss of p1 is: 0.47018858790397644
# Physicial loss of p2 is: 0.14298683404922485
# Physicial loss of s is: 0.30585819482803345
# Iteration is: 1290
# Physicial loss of p1 is: 0.470430463552475
# Physicial loss of p2 is: 0.14206621050834656
# Physicial loss of s is: 0.3072563111782074
# Iteration is: 1300
# Physicial loss of p1 is: 0.47034814953804016
# Physicial loss of p2 is: 0.14130687713623047
# Physicial loss of s is: 0.30892622470855713
# Iteration is: 1310
# Physicial loss of p1 is: 0.47017914056777954
# Physicial loss of p2 is: 0.14065630733966827
# Physicial loss of s is: 0.3104609549045563
# Iteration is: 1320
# Physicial loss of p1 is: 0.4697960913181305
# Physicial loss of p2 is: 0.1398315727710724
# Physicial loss of s is: 0.31219449639320374
# Iteration is: 1330
# Physicial loss of p1 is: 0.47112953662872314
# Physicial loss of p2 is: 0.14227589964866638
# Physicial loss of s is: 0.32490167021751404
# Iteration is: 1340
# Physicial loss of p1 is: 0.46361249685287476
# Physicial loss of p2 is: 0.1379934400320053
# Physicial loss of s is: 0.31862854957580566
# Iteration is: 1350
# Physicial loss of p1 is: 0.45478349924087524
# Physicial loss of p2 is: 0.13964678347110748
# Physicial loss of s is: 0.32641416788101196
# Iteration is: 1360
# Physicial loss of p1 is: 0.45811793208122253
# Physicial loss of p2 is: 0.14144134521484375
# Physicial loss of s is: 0.3235791325569153
# Iteration is: 1370
# Physicial loss of p1 is: 0.45962491631507874
# Physicial loss of p2 is: 0.1415090262889862
# Physicial loss of s is: 0.3257286250591278
# Iteration is: 1380
# Physicial loss of p1 is: 0.4615464210510254
# Physicial loss of p2 is: 0.14035461843013763
# Physicial loss of s is: 0.3257371187210083
# Iteration is: 1390
# Physicial loss of p1 is: 0.4630254805088043
# Physicial loss of p2 is: 0.13927125930786133
# Physicial loss of s is: 0.32623764872550964
# Iteration is: 1400
# Physicial loss of p1 is: 0.4643346071243286
# Physicial loss of p2 is: 0.13908733427524567
# Physicial loss of s is: 0.3267999589443207
# Iteration is: 1410
# Physicial loss of p1 is: 0.46536827087402344
# Physicial loss of p2 is: 0.13873359560966492
# Physicial loss of s is: 0.32738402485847473
# Iteration is: 1420
# Physicial loss of p1 is: 0.46599188446998596
# Physicial loss of p2 is: 0.13832072913646698
# Physicial loss of s is: 0.328377902507782
# Iteration is: 1430
# Physicial loss of p1 is: 0.4662633240222931
# Physicial loss of p2 is: 0.13820695877075195
# Physicial loss of s is: 0.329515278339386
# Iteration is: 1440
# Physicial loss of p1 is: 0.46631181240081787
# Physicial loss of p2 is: 0.1381058394908905
# Physicial loss of s is: 0.33063340187072754
# Iteration is: 1450
# Physicial loss of p1 is: 0.46628573536872864
# Physicial loss of p2 is: 0.13786861300468445
# Physicial loss of s is: 0.33168548345565796
# Iteration is: 1460
# Physicial loss of p1 is: 0.46614110469818115
# Physicial loss of p2 is: 0.13753613829612732
# Physicial loss of s is: 0.33273547887802124
# Iteration is: 1470
# Physicial loss of p1 is: 0.46604907512664795
# Physicial loss of p2 is: 0.13891910016536713
# Physicial loss of s is: 0.3373928964138031
# Iteration is: 1480
# Physicial loss of p1 is: 0.46322089433670044
# Physicial loss of p2 is: 0.14215624332427979
# Physicial loss of s is: 0.3492400050163269
# Iteration is: 1490
# Physicial loss of p1 is: 0.4534040093421936
# Physicial loss of p2 is: 0.14078833162784576
# Physicial loss of s is: 0.35320088267326355
# Iteration is: 1500
# Physicial loss of p1 is: 0.4562061131000519
# Physicial loss of p2 is: 0.1405314952135086
# Physicial loss of s is: 0.3428659439086914
# Iteration is: 1510
# Physicial loss of p1 is: 0.4575943946838379
# Physicial loss of p2 is: 0.14069385826587677
# Physicial loss of s is: 0.3420907258987427
# Iteration is: 1520
# Physicial loss of p1 is: 0.4588702619075775
# Physicial loss of p2 is: 0.14138861000537872
# Physicial loss of s is: 0.34407874941825867
# Iteration is: 1530
# Physicial loss of p1 is: 0.4598521590232849
# Physicial loss of p2 is: 0.14048956334590912
# Physicial loss of s is: 0.3444945812225342
# Iteration is: 1540
# Physicial loss of p1 is: 0.46133241057395935
# Physicial loss of p2 is: 0.1402527093887329
# Physicial loss of s is: 0.3436781167984009
# Iteration is: 1550
# Physicial loss of p1 is: 0.4621466398239136
# Physicial loss of p2 is: 0.14017920196056366
# Physicial loss of s is: 0.3438265323638916
# Iteration is: 1560
# Physicial loss of p1 is: 0.46274760365486145
# Physicial loss of p2 is: 0.14011938869953156
# Physicial loss of s is: 0.34425175189971924
# Iteration is: 1570
# Physicial loss of p1 is: 0.4630013108253479
# Physicial loss of p2 is: 0.1400245577096939
# Physicial loss of s is: 0.344485878944397
# Iteration is: 1580
# Physicial loss of p1 is: 0.46305254101753235
# Physicial loss of p2 is: 0.1401018500328064
# Physicial loss of s is: 0.34482210874557495
# Iteration is: 1590
# Physicial loss of p1 is: 0.4631253480911255
# Physicial loss of p2 is: 0.13987168669700623
# Physicial loss of s is: 0.34473174810409546
# Iteration is: 1600
# Physicial loss of p1 is: 0.4664074182510376
# Physicial loss of p2 is: 0.13726817071437836
# Physicial loss of s is: 0.34701284766197205
# Iteration is: 1610
# Physicial loss of p1 is: 0.45446082949638367
# Physicial loss of p2 is: 0.1443857103586197
# Physicial loss of s is: 0.3694458603858948
# Iteration is: 1620
# Physicial loss of p1 is: 0.4517683684825897
# Physicial loss of p2 is: 0.14366833865642548
# Physicial loss of s is: 0.35999152064323425
# Iteration is: 1630
# Physicial loss of p1 is: 0.453708678483963
# Physicial loss of p2 is: 0.14336596429347992
# Physicial loss of s is: 0.3524688482284546
# Iteration is: 1640
# Physicial loss of p1 is: 0.45494145154953003
# Physicial loss of p2 is: 0.1438797414302826
# Physicial loss of s is: 0.3519335091114044
# Iteration is: 1650
# Physicial loss of p1 is: 0.45571136474609375
# Physicial loss of p2 is: 0.14396581053733826
# Physicial loss of s is: 0.35493940114974976
# Iteration is: 1660
# Physicial loss of p1 is: 0.45751309394836426
# Physicial loss of p2 is: 0.14291687309741974
# Physicial loss of s is: 0.35180091857910156
# Iteration is: 1670
# Physicial loss of p1 is: 0.45824986696243286
# Physicial loss of p2 is: 0.14324569702148438
# Physicial loss of s is: 0.352163702249527
# Iteration is: 1680
# Physicial loss of p1 is: 0.45910346508026123
# Physicial loss of p2 is: 0.1427801251411438
# Physicial loss of s is: 0.3507475256919861
# Iteration is: 1690
# Physicial loss of p1 is: 0.4593089818954468
# Physicial loss of p2 is: 0.14284354448318481
# Physicial loss of s is: 0.35098907351493835
# Iteration is: 1700
# Physicial loss of p1 is: 0.4593266546726227
# Physicial loss of p2 is: 0.1430530697107315
# Physicial loss of s is: 0.35112637281417847
# Iteration is: 1710
# Physicial loss of p1 is: 0.45918092131614685
# Physicial loss of p2 is: 0.14338666200637817
# Physicial loss of s is: 0.35158252716064453
# Iteration is: 1720
# Physicial loss of p1 is: 0.45884737372398376
# Physicial loss of p2 is: 0.14503946900367737
# Physicial loss of s is: 0.35671475529670715
# Iteration is: 1730
# Physicial loss of p1 is: 0.4552939534187317
# Physicial loss of p2 is: 0.14753663539886475
# Physicial loss of s is: 0.3679562211036682
# Iteration is: 1740
# Physicial loss of p1 is: 0.4474409222602844
# Physicial loss of p2 is: 0.14699335396289825
# Physicial loss of s is: 0.3717721104621887
# Iteration is: 1750
# Physicial loss of p1 is: 0.4495980441570282
# Physicial loss of p2 is: 0.1466812789440155
# Physicial loss of s is: 0.35776156187057495
# Iteration is: 1760
# Physicial loss of p1 is: 0.45017188787460327
# Physicial loss of p2 is: 0.1465764343738556
# Physicial loss of s is: 0.3547108769416809
# Iteration is: 1770
# Physicial loss of p1 is: 0.4509750008583069
# Physicial loss of p2 is: 0.14734306931495667
# Physicial loss of s is: 0.3575597107410431
# Iteration is: 1780
# Physicial loss of p1 is: 0.4522629380226135
# Physicial loss of p2 is: 0.1463816612958908
# Physicial loss of s is: 0.3556796610355377
# Iteration is: 1790
# Physicial loss of p1 is: 0.45330601930618286
# Physicial loss of p2 is: 0.1461489200592041
# Physicial loss of s is: 0.3541775047779083
# Iteration is: 1800
# Physicial loss of p1 is: 0.45414501428604126
# Physicial loss of p2 is: 0.14599043130874634
# Physicial loss of s is: 0.35277867317199707
# Iteration is: 1810
# Physicial loss of p1 is: 0.4543510675430298
# Physicial loss of p2 is: 0.14598451554775238
# Physicial loss of s is: 0.35265347361564636
# Iteration is: 1820
# Physicial loss of p1 is: 0.45445623993873596
# Physicial loss of p2 is: 0.14593252539634705
# Physicial loss of s is: 0.35187196731567383
# Iteration is: 1830
# Physicial loss of p1 is: 0.4543188512325287
# Physicial loss of p2 is: 0.1460295170545578
# Physicial loss of s is: 0.35135865211486816
# Iteration is: 1840
# Physicial loss of p1 is: 0.45412328839302063
# Physicial loss of p2 is: 0.14605726301670074
# Physicial loss of s is: 0.3506808876991272
# Iteration is: 1850
# Physicial loss of p1 is: 0.454730749130249
# Physicial loss of p2 is: 0.1451048105955124
# Physicial loss of s is: 0.3481869697570801
# Iteration is: 1860
# Physicial loss of p1 is: 0.4523065984249115
# Physicial loss of p2 is: 0.14402911067008972
# Physicial loss of s is: 0.34805819392204285
# Iteration is: 1870
# Physicial loss of p1 is: 0.44267895817756653
# Physicial loss of p2 is: 0.1445888727903366
# Physicial loss of s is: 0.36246615648269653
# Iteration is: 1880
# Physicial loss of p1 is: 0.44244712591171265
# Physicial loss of p2 is: 0.14850911498069763
# Physicial loss of s is: 0.35663044452667236
# Iteration is: 1890
# Physicial loss of p1 is: 0.4419254958629608
# Physicial loss of p2 is: 0.15091076493263245
# Physicial loss of s is: 0.35563817620277405
# Iteration is: 1900
# Physicial loss of p1 is: 0.4431940019130707
# Physicial loss of p2 is: 0.15141455829143524
# Physicial loss of s is: 0.3570871651172638
# Iteration is: 1910
# Physicial loss of p1 is: 0.4447040557861328
# Physicial loss of p2 is: 0.15064898133277893
# Physicial loss of s is: 0.3562043011188507
# Iteration is: 1920
# Physicial loss of p1 is: 0.4462727904319763
# Physicial loss of p2 is: 0.1496075838804245
# Physicial loss of s is: 0.3523835837841034
# Iteration is: 1930
# Physicial loss of p1 is: 0.4472620487213135
# Physicial loss of p2 is: 0.1494932770729065
# Physicial loss of s is: 0.35075339674949646
# Iteration is: 1940
# Physicial loss of p1 is: 0.4476076662540436
# Physicial loss of p2 is: 0.1493183672428131
# Physicial loss of s is: 0.34996241331100464
# Iteration is: 1950
# Physicial loss of p1 is: 0.44777607917785645
# Physicial loss of p2 is: 0.14918765425682068
# Physicial loss of s is: 0.3489280641078949
# Iteration is: 1960
# Physicial loss of p1 is: 0.44763970375061035
# Physicial loss of p2 is: 0.14928433299064636
# Physicial loss of s is: 0.34822696447372437
# Iteration is: 1970
# Physicial loss of p1 is: 0.4473579227924347
# Physicial loss of p2 is: 0.14944113790988922
# Physicial loss of s is: 0.34775376319885254
# Iteration is: 1980
# Physicial loss of p1 is: 0.4470018446445465
# Physicial loss of p2 is: 0.14959830045700073
# Physicial loss of s is: 0.3471711575984955
# Iteration is: 1990
# Physicial loss of p1 is: 0.446532666683197
# Physicial loss of p2 is: 0.1498224437236786
# Physicial loss of s is: 0.34674498438835144
# Iteration is: 2000
# Physicial loss of p1 is: 0.4458814561367035
# Physicial loss of p2 is: 0.15035365521907806
# Physicial loss of s is: 0.34716904163360596
# Iteration is: 2010
# Physicial loss of p1 is: 0.4453263580799103
# Physicial loss of p2 is: 0.1556352972984314
# Physicial loss of s is: 0.3649342358112335
# Iteration is: 2020
# Physicial loss of p1 is: 0.441678524017334
# Physicial loss of p2 is: 0.14720535278320312
# Physicial loss of s is: 0.3491097092628479
# Iteration is: 2030
# Physicial loss of p1 is: 0.43402764201164246
# Physicial loss of p2 is: 0.15198804438114166
# Physicial loss of s is: 0.35437798500061035
# Iteration is: 2040
# Physicial loss of p1 is: 0.4326809048652649
# Physicial loss of p2 is: 0.15518628060817719
# Physicial loss of s is: 0.3541572391986847
# Iteration is: 2050
# Physicial loss of p1 is: 0.43399688601493835
# Physicial loss of p2 is: 0.15605701506137848
# Physicial loss of s is: 0.3526856303215027
# Iteration is: 2060
# Physicial loss of p1 is: 0.4354894459247589
# Physicial loss of p2 is: 0.15431056916713715
# Physicial loss of s is: 0.34970933198928833
# Iteration is: 2070
# Physicial loss of p1 is: 0.43747764825820923
# Physicial loss of p2 is: 0.1533251255750656
# Physicial loss of s is: 0.34620457887649536
# Iteration is: 2080
# Physicial loss of p1 is: 0.4379173219203949
# Physicial loss of p2 is: 0.15355823934078217
# Physicial loss of s is: 0.3455899953842163
# Iteration is: 2090
# Physicial loss of p1 is: 0.438640832901001
# Physicial loss of p2 is: 0.15299803018569946
# Physicial loss of s is: 0.34328773617744446
# Iteration is: 2100
# Physicial loss of p1 is: 0.43867167830467224
# Physicial loss of p2 is: 0.1530333310365677
# Physicial loss of s is: 0.3427301347255707
# Iteration is: 2110
# Physicial loss of p1 is: 0.4385903775691986
# Physicial loss of p2 is: 0.15292663872241974
# Physicial loss of s is: 0.34155765175819397
# Iteration is: 2120
# Physicial loss of p1 is: 0.4382932186126709
# Physicial loss of p2 is: 0.15307089686393738
# Physicial loss of s is: 0.3409171998500824
# Iteration is: 2130
# Physicial loss of p1 is: 0.43784427642822266
# Physicial loss of p2 is: 0.15322843194007874
# Physicial loss of s is: 0.3403303623199463
# Iteration is: 2140
# Physicial loss of p1 is: 0.43730252981185913
# Physicial loss of p2 is: 0.1534528285264969
# Physicial loss of s is: 0.339844286441803
# Iteration is: 2150
# Physicial loss of p1 is: 0.43644824624061584
# Physicial loss of p2 is: 0.1542147397994995
# Physicial loss of s is: 0.3405415415763855
# Iteration is: 2160
# Physicial loss of p1 is: 0.4352167546749115
# Physicial loss of p2 is: 0.16035248339176178
# Physicial loss of s is: 0.361141175031662
# Iteration is: 2170
# Physicial loss of p1 is: 0.4316146969795227
# Physicial loss of p2 is: 0.15054361522197723
# Physicial loss of s is: 0.3424434959888458
# Iteration is: 2180
# Physicial loss of p1 is: 0.42570760846138
# Physicial loss of p2 is: 0.15533721446990967
# Physicial loss of s is: 0.3440292179584503
# Iteration is: 2190
# Physicial loss of p1 is: 0.42369237542152405
# Physicial loss of p2 is: 0.15874072909355164
# Physicial loss of s is: 0.345962256193161
# Iteration is: 2200
# Physicial loss of p1 is: 0.42520371079444885
# Physicial loss of p2 is: 0.1589559018611908
# Physicial loss of s is: 0.3437809646129608
# Iteration is: 2210
# Physicial loss of p1 is: 0.4267842173576355
# Physicial loss of p2 is: 0.15696154534816742
# Physicial loss of s is: 0.3401268720626831
# Iteration is: 2220
# Physicial loss of p1 is: 0.4278661608695984
# Physicial loss of p2 is: 0.15686847269535065
# Physicial loss of s is: 0.33873364329338074
# Iteration is: 2230
# Physicial loss of p1 is: 0.4284789562225342
# Physicial loss of p2 is: 0.1566745638847351
# Physicial loss of s is: 0.3370474576950073
# Iteration is: 2240
# Physicial loss of p1 is: 0.4288209080696106
# Physicial loss of p2 is: 0.15633374452590942
# Physicial loss of s is: 0.3355623483657837
# Iteration is: 2250
# Physicial loss of p1 is: 0.42878827452659607
# Physicial loss of p2 is: 0.15627232193946838
# Physicial loss of s is: 0.33461132645606995
# Iteration is: 2260
# Physicial loss of p1 is: 0.42839130759239197
# Physicial loss of p2 is: 0.15639688074588776
# Physicial loss of s is: 0.3340663015842438
# Iteration is: 2270
# Physicial loss of p1 is: 0.4280279278755188
# Physicial loss of p2 is: 0.15643684566020966
# Physicial loss of s is: 0.3332648277282715
# Iteration is: 2280
# Physicial loss of p1 is: 0.42751386761665344
# Physicial loss of p2 is: 0.15656273066997528
# Physicial loss of s is: 0.33262500166893005
# Iteration is: 2290
# Physicial loss of p1 is: 0.42675644159317017
# Physicial loss of p2 is: 0.15695542097091675
# Physicial loss of s is: 0.33245450258255005
# Iteration is: 2300
# Physicial loss of p1 is: 0.42509472370147705
# Physicial loss of p2 is: 0.16044016182422638
# Physicial loss of s is: 0.33956632018089294
# Iteration is: 2310
# Physicial loss of p1 is: 0.419254869222641
# Physicial loss of p2 is: 0.159208282828331
# Physicial loss of s is: 0.33850404620170593
# Iteration is: 2320
# Physicial loss of p1 is: 0.41124609112739563
# Physicial loss of p2 is: 0.16174863278865814
# Physicial loss of s is: 0.3517612814903259
# Iteration is: 2330
# Physicial loss of p1 is: 0.4119936525821686
# Physicial loss of p2 is: 0.1624651551246643
# Physicial loss of s is: 0.3424185812473297
# Iteration is: 2340
# Physicial loss of p1 is: 0.4137023091316223
# Physicial loss of p2 is: 0.16140751540660858
# Physicial loss of s is: 0.3351426124572754
# Iteration is: 2350
# Physicial loss of p1 is: 0.4156072735786438
# Physicial loss of p2 is: 0.1601407676935196
# Physicial loss of s is: 0.33309435844421387
# Iteration is: 2360
# Physicial loss of p1 is: 0.41657134890556335
# Physicial loss of p2 is: 0.16033285856246948
# Physicial loss of s is: 0.33268922567367554
# Iteration is: 2370
# Physicial loss of p1 is: 0.41736918687820435
# Physicial loss of p2 is: 0.15972116589546204
# Physicial loss of s is: 0.33063358068466187
# Iteration is: 2380
# Physicial loss of p1 is: 0.4180637300014496
# Physicial loss of p2 is: 0.15930940210819244
# Physicial loss of s is: 0.32870757579803467
# Iteration is: 2390
# Physicial loss of p1 is: 0.41789764165878296
# Physicial loss of p2 is: 0.15933704376220703
# Physicial loss of s is: 0.3281128704547882
# Iteration is: 2400
# Physicial loss of p1 is: 0.41771504282951355
# Physicial loss of p2 is: 0.1592298299074173
# Physicial loss of s is: 0.32723578810691833
# Iteration is: 2410
# Physicial loss of p1 is: 0.4174211919307709
# Physicial loss of p2 is: 0.15916012227535248
# Physicial loss of s is: 0.3264066278934479
# Iteration is: 2420
# Physicial loss of p1 is: 0.4168868064880371
# Physicial loss of p2 is: 0.15923918783664703
# Physicial loss of s is: 0.32584667205810547
# Iteration is: 2430
# Physicial loss of p1 is: 0.4163304567337036
# Physicial loss of p2 is: 0.15931448340415955
# Physicial loss of s is: 0.3252767324447632
# Iteration is: 2440
# Physicial loss of p1 is: 0.4157244563102722
# Physicial loss of p2 is: 0.15939953923225403
# Physicial loss of s is: 0.32474491000175476
# Iteration is: 2450
# Physicial loss of p1 is: 0.41499093174934387
# Physicial loss of p2 is: 0.15963123738765717
# Physicial loss of s is: 0.3243381977081299
# Iteration is: 2460
# Physicial loss of p1 is: 0.41329139471054077
# Physicial loss of p2 is: 0.16233573853969574
# Physicial loss of s is: 0.3271200656890869
# Iteration is: 2470
# Physicial loss of p1 is: 0.4058195948600769
# Physicial loss of p2 is: 0.1658555120229721
# Physicial loss of s is: 0.3430333733558655
# Iteration is: 2480
# Physicial loss of p1 is: 0.39458465576171875
# Physicial loss of p2 is: 0.16411134600639343
# Physicial loss of s is: 0.350185751914978
# Iteration is: 2490
# Physicial loss of p1 is: 0.39543309807777405
# Physicial loss of p2 is: 0.16582921147346497
# Physicial loss of s is: 0.33769333362579346
# Iteration is: 2500
# Physicial loss of p1 is: 0.39547842741012573
# Physicial loss of p2 is: 0.1670028120279312
# Physicial loss of s is: 0.33400091528892517
# Iteration is: 2510
# Physicial loss of p1 is: 0.39860308170318604
# Physicial loss of p2 is: 0.16580355167388916
# Physicial loss of s is: 0.3311036229133606
# Iteration is: 2520
# Physicial loss of p1 is: 0.4011452794075012
# Physicial loss of p2 is: 0.1641710251569748
# Physicial loss of s is: 0.3279701769351959
# Iteration is: 2530
# Physicial loss of p1 is: 0.4031526744365692
# Physicial loss of p2 is: 0.16298949718475342
# Physicial loss of s is: 0.32482150197029114
# Iteration is: 2540
# Physicial loss of p1 is: 0.4043816328048706
# Physicial loss of p2 is: 0.16232357919216156
# Physicial loss of s is: 0.32257401943206787
# Iteration is: 2550
# Physicial loss of p1 is: 0.4044533967971802
# Physicial loss of p2 is: 0.16222530603408813
# Physicial loss of s is: 0.3216683566570282
# Iteration is: 2560
# Physicial loss of p1 is: 0.4044647514820099
# Physicial loss of p2 is: 0.16217263042926788
# Physicial loss of s is: 0.3209993541240692
# Iteration is: 2570
# Physicial loss of p1 is: 0.4043821692466736
# Physicial loss of p2 is: 0.16189926862716675
# Physicial loss of s is: 0.3201092481613159
# Iteration is: 2580
# Physicial loss of p1 is: 0.4039836525917053
# Physicial loss of p2 is: 0.16189390420913696
# Physicial loss of s is: 0.31953731179237366
# Iteration is: 2590
# Physicial loss of p1 is: 0.40358906984329224
# Physicial loss of p2 is: 0.16182561218738556
# Physicial loss of s is: 0.3189266324043274
# Iteration is: 2600
# Physicial loss of p1 is: 0.40309208631515503
# Physicial loss of p2 is: 0.16180527210235596
# Physicial loss of s is: 0.3184468746185303
# Iteration is: 2610
# Physicial loss of p1 is: 0.40258994698524475
# Physicial loss of p2 is: 0.16176728904247284
# Physicial loss of s is: 0.31793707609176636
# Iteration is: 2620
# Physicial loss of p1 is: 0.4020349681377411
# Physicial loss of p2 is: 0.161763995885849
# Physicial loss of s is: 0.31747835874557495
# Iteration is: 2630
# Physicial loss of p1 is: 0.40145766735076904
# Physicial loss of p2 is: 0.16177420318126678
# Physicial loss of s is: 0.3170284628868103
# Iteration is: 2640
# Physicial loss of p1 is: 0.40086209774017334
# Physicial loss of p2 is: 0.16177311539649963
# Physicial loss of s is: 0.3166015148162842
# Iteration is: 2650
# Physicial loss of p1 is: 0.4002997577190399
# Physicial loss of p2 is: 0.16167189180850983
# Physicial loss of s is: 0.3162171244621277
# Iteration is: 2660
# Physicial loss of p1 is: 0.4005260467529297
# Physicial loss of p2 is: 0.16031017899513245
# Physicial loss of s is: 0.31745800375938416
# Iteration is: 2670
# Physicial loss of p1 is: 0.41309911012649536
# Physicial loss of p2 is: 0.155740424990654
# Physicial loss of s is: 0.3124717175960541
# Iteration is: 2680
# Physicial loss of p1 is: 0.38655832409858704
# Physicial loss of p2 is: 0.16249249875545502
# Physicial loss of s is: 0.3252817392349243
# Iteration is: 2690
# Physicial loss of p1 is: 0.3830331563949585
# Physicial loss of p2 is: 0.16454653441905975
# Physicial loss of s is: 0.32382720708847046
# Iteration is: 2700
# Physicial loss of p1 is: 0.38176530599594116
# Physicial loss of p2 is: 0.16640108823776245
# Physicial loss of s is: 0.32275843620300293
# Iteration is: 2710
# Physicial loss of p1 is: 0.383862167596817
# Physicial loss of p2 is: 0.1671181619167328
# Physicial loss of s is: 0.32152143120765686
# Iteration is: 2720
# Physicial loss of p1 is: 0.385570764541626
# Physicial loss of p2 is: 0.16611932218074799
# Physicial loss of s is: 0.32048848271369934
# Iteration is: 2730
# Physicial loss of p1 is: 0.38808584213256836
# Physicial loss of p2 is: 0.1649661809206009
# Physicial loss of s is: 0.31764841079711914
# Iteration is: 2740
# Physicial loss of p1 is: 0.38938573002815247
# Physicial loss of p2 is: 0.16407747566699982
# Physicial loss of s is: 0.31565040349960327
# Iteration is: 2750
# Physicial loss of p1 is: 0.38968425989151
# Physicial loss of p2 is: 0.16389717161655426
# Physicial loss of s is: 0.31443414092063904
# Iteration is: 2760
# Physicial loss of p1 is: 0.3896586298942566
# Physicial loss of p2 is: 0.16381330788135529
# Physicial loss of s is: 0.3139701187610626
# Iteration is: 2770
# Physicial loss of p1 is: 0.389667809009552
# Physicial loss of p2 is: 0.16346228122711182
# Physicial loss of s is: 0.31320756673812866
# Iteration is: 2780
# Physicial loss of p1 is: 0.38933491706848145
# Physicial loss of p2 is: 0.163385808467865
# Physicial loss of s is: 0.3126700818538666
# Iteration is: 2790
# Physicial loss of p1 is: 0.3890102207660675
# Physicial loss of p2 is: 0.16323021054267883
# Physicial loss of s is: 0.3121495842933655
# Iteration is: 2800
# Physicial loss of p1 is: 0.3885962963104248
# Physicial loss of p2 is: 0.16314300894737244
# Physicial loss of s is: 0.31171301007270813
# Iteration is: 2810
# Physicial loss of p1 is: 0.3881731927394867
# Physicial loss of p2 is: 0.16301433742046356
# Physicial loss of s is: 0.31128835678100586
# Iteration is: 2820
# Physicial loss of p1 is: 0.3877080976963043
# Physicial loss of p2 is: 0.16292406618595123
# Physicial loss of s is: 0.31087711453437805
# Iteration is: 2830
# Physicial loss of p1 is: 0.3872212767601013
# Physicial loss of p2 is: 0.16283515095710754
# Physicial loss of s is: 0.3104836344718933
# Iteration is: 2840
# Physicial loss of p1 is: 0.3867676854133606
# Physicial loss of p2 is: 0.16264933347702026
# Physicial loss of s is: 0.31013134121894836
# Iteration is: 2850
# Physicial loss of p1 is: 0.38696205615997314
# Physicial loss of p2 is: 0.1614631563425064
# Physicial loss of s is: 0.31058013439178467
# Iteration is: 2860
# Physicial loss of p1 is: 0.39905986189842224
# Physicial loss of p2 is: 0.1571262925863266
# Physicial loss of s is: 0.3077400028705597
# Iteration is: 2870
# Physicial loss of p1 is: 0.3696283996105194
# Physicial loss of p2 is: 0.1656743884086609
# Physicial loss of s is: 0.32555487751960754
# Iteration is: 2880
# Physicial loss of p1 is: 0.36683353781700134
# Physicial loss of p2 is: 0.16848039627075195
# Physicial loss of s is: 0.3213184177875519
# Iteration is: 2890
# Physicial loss of p1 is: 0.36737093329429626
# Physicial loss of p2 is: 0.1683809757232666
# Physicial loss of s is: 0.32004308700561523
# Iteration is: 2900
# Physicial loss of p1 is: 0.3707423210144043
# Physicial loss of p2 is: 0.16787827014923096
# Physicial loss of s is: 0.31620630621910095
# Iteration is: 2910
# Physicial loss of p1 is: 0.37388065457344055
# Physicial loss of p2 is: 0.1657116413116455
# Physicial loss of s is: 0.3127303421497345
# Iteration is: 2920
# Physicial loss of p1 is: 0.37663888931274414
# Physicial loss of p2 is: 0.164245143532753
# Physicial loss of s is: 0.3102695643901825
# Iteration is: 2930
# Physicial loss of p1 is: 0.37693339586257935
# Physicial loss of p2 is: 0.16428254544734955
# Physicial loss of s is: 0.309707909822464
# Iteration is: 2940
# Physicial loss of p1 is: 0.3772635757923126
# Physicial loss of p2 is: 0.16414421796798706
# Physicial loss of s is: 0.3084803819656372
# Iteration is: 2950
# Physicial loss of p1 is: 0.37755468487739563
# Physicial loss of p2 is: 0.16362538933753967
# Physicial loss of s is: 0.30781054496765137
# Iteration is: 2960
# Physicial loss of p1 is: 0.3773574233055115
# Physicial loss of p2 is: 0.1634872853755951
# Physicial loss of s is: 0.30727842450141907
# Iteration is: 2970
# Physicial loss of p1 is: 0.3771670460700989
# Physicial loss of p2 is: 0.16323500871658325
# Physicial loss of s is: 0.30670374631881714
# Iteration is: 2980
# Physicial loss of p1 is: 0.37687715888023376
# Physicial loss of p2 is: 0.1630391776561737
# Physicial loss of s is: 0.306245893239975
# Iteration is: 2990
# Physicial loss of p1 is: 0.37651920318603516
# Physicial loss of p2 is: 0.16288559138774872
# Physicial loss of s is: 0.3058226704597473
# Iteration is: 3000
# Physicial loss of p1 is: 0.37612810730934143
# Physicial loss of p2 is: 0.16273482143878937
# Physicial loss of s is: 0.3054242730140686
# Iteration is: 3010
# Physicial loss of p1 is: 0.37565290927886963
# Physicial loss of p2 is: 0.1626848578453064
# Physicial loss of s is: 0.30500808358192444
# Iteration is: 3020
# Physicial loss of p1 is: 0.37467139959335327
# Physicial loss of p2 is: 0.16346603631973267
# Physicial loss of s is: 0.3045309782028198
# Iteration is: 3030
# Physicial loss of p1 is: 0.3696393668651581
# Physicial loss of p2 is: 0.16988281905651093
# Physicial loss of s is: 0.3201616108417511
# Iteration is: 3040
# Physicial loss of p1 is: 0.3716282844543457
# Physicial loss of p2 is: 0.1589558869600296
# Physicial loss of s is: 0.3111515939235687
# Iteration is: 3050
# Physicial loss of p1 is: 0.36253711581230164
# Physicial loss of p2 is: 0.1628851741552353
# Physicial loss of s is: 0.30924132466316223
# Iteration is: 3060
# Physicial loss of p1 is: 0.3601742684841156
# Physicial loss of p2 is: 0.16511230170726776
# Physicial loss of s is: 0.3105611205101013
# Iteration is: 3070
# Physicial loss of p1 is: 0.36103320121765137
# Physicial loss of p2 is: 0.1663811057806015
# Physicial loss of s is: 0.3099289536476135
# Iteration is: 3080
# Physicial loss of p1 is: 0.36319735646247864
# Physicial loss of p2 is: 0.16526615619659424
# Physicial loss of s is: 0.3080825209617615
# Iteration is: 3090
# Physicial loss of p1 is: 0.36662232875823975
# Physicial loss of p2 is: 0.16338209807872772
# Physicial loss of s is: 0.3048412501811981
# Iteration is: 3100
# Physicial loss of p1 is: 0.367371529340744
# Physicial loss of p2 is: 0.16293269395828247
# Physicial loss of s is: 0.3039611279964447
# Iteration is: 3110
# Physicial loss of p1 is: 0.36744391918182373
# Physicial loss of p2 is: 0.16305671632289886
# Physicial loss of s is: 0.3029264807701111
# Iteration is: 3120
# Physicial loss of p1 is: 0.36785197257995605
# Physicial loss of p2 is: 0.1624109148979187
# Physicial loss of s is: 0.30208879709243774
# Iteration is: 3130
# Physicial loss of p1 is: 0.36764830350875854
# Physicial loss of p2 is: 0.1621994972229004
# Physicial loss of s is: 0.301547110080719
# Iteration is: 3140
# Physicial loss of p1 is: 0.3674359917640686
# Physicial loss of p2 is: 0.16189929842948914
# Physicial loss of s is: 0.3009794056415558
# Iteration is: 3150
# Physicial loss of p1 is: 0.36722710728645325
# Physicial loss of p2 is: 0.1615653783082962
# Physicial loss of s is: 0.30042222142219543
# Iteration is: 3160
# Physicial loss of p1 is: 0.36694252490997314
# Physicial loss of p2 is: 0.16123637557029724
# Physicial loss of s is: 0.29992082715034485
# Iteration is: 3170
# Physicial loss of p1 is: 0.3667047321796417
# ...
# Physicial loss of p2 is: 0.0071326508186757565
# Physicial loss of s is: 0.011035844683647156
# Iteration is: 16070
# Physicial loss of p1 is: 0.012975343503057957
# Physicial loss of p2 is: 0.0072316392324864864
# Physicial loss of s is: 0.011691171675920486
# Iteration is: 16080
# Physicial loss of p1 is: 0.016014689579606056
# Physicial loss of p2 is: 0.0073115709237754345
# Physicial loss of s is: 0.011701197363436222
# Iteration is: 16090
# Physicial loss of p1 is: 0.01317558716982603
# Physicial loss of p2 is: 0.007019424345344305
# Physicial loss of s is: 0.011209986172616482
# Iteration is: 16100
# Physicial loss of p1 is: 0.0122645553201437
# Physicial loss of p2 is: 0.007082659751176834
# Physicial loss of s is: 0.01062389463186264
# Iteration is: 16110
# Physicial loss of p1 is: 0.01385399792343378
# Physicial loss of p2 is: 0.007182991597801447
# Physicial loss of s is: 0.010464728809893131
# Iteration is: 16120
# Physicial loss of p1 is: 0.019375251606106758
# Physicial loss of p2 is: 0.007503528613597155
# Physicial loss of s is: 0.01064376626163721
# Iteration is: 16130
# Physicial loss of p1 is: 0.01203775405883789
# Physicial loss of p2 is: 0.0070228250697255135
# Physicial loss of s is: 0.011781048960983753
# Iteration is: 16140
# Physicial loss of p1 is: 0.01327881496399641
# Physicial loss of p2 is: 0.0070809293538331985
# Physicial loss of s is: 0.010964907705783844
# Iteration is: 16150
# Physicial loss of p1 is: 0.011937042698264122
# Physicial loss of p2 is: 0.0070131635293364525
# Physicial loss of s is: 0.01068525668233633
# Iteration is: 16160
# Physicial loss of p1 is: 0.012228348292410374
# Physicial loss of p2 is: 0.00704569648951292
# Physicial loss of s is: 0.010518169961869717
# Iteration is: 16170
# Physicial loss of p1 is: 0.017026619985699654
# Physicial loss of p2 is: 0.00744963064789772
# Physicial loss of s is: 0.012493928894400597
# Iteration is: 16180
# Physicial loss of p1 is: 0.011991692706942558
# Physicial loss of p2 is: 0.007059136405587196
# Physicial loss of s is: 0.010911105200648308
# Iteration is: 16190
# Physicial loss of p1 is: 0.014865499921143055
# Physicial loss of p2 is: 0.007199502550065517
# Physicial loss of s is: 0.010370553471148014
# Iteration is: 16200
# Physicial loss of p1 is: 0.012127257883548737
# Physicial loss of p2 is: 0.007215047255158424
# Physicial loss of s is: 0.015212001278996468
# Iteration is: 16210
# Physicial loss of p1 is: 0.01193816028535366
# Physicial loss of p2 is: 0.007034290116280317
# Physicial loss of s is: 0.010508907958865166
# Iteration is: 16220
# Physicial loss of p1 is: 0.01183491200208664
# Physicial loss of p2 is: 0.007012873888015747
# Physicial loss of s is: 0.01072283647954464
# Iteration is: 16230
# Physicial loss of p1 is: 0.013217687606811523
# Physicial loss of p2 is: 0.006987517699599266
# Physicial loss of s is: 0.010816780850291252
# Iteration is: 16240
# Physicial loss of p1 is: 0.017690790817141533
# Physicial loss of p2 is: 0.007628011517226696
# Physicial loss of s is: 0.013355891220271587
# Iteration is: 16250
# Physicial loss of p1 is: 0.011737735010683537
# Physicial loss of p2 is: 0.0069651734083890915
# Physicial loss of s is: 0.012793567031621933
# Iteration is: 16260
# Physicial loss of p1 is: 0.01167489867657423
# Physicial loss of p2 is: 0.007057670503854752
# Physicial loss of s is: 0.010808143764734268
# Iteration is: 16270
# Physicial loss of p1 is: 0.012118624523282051
# Physicial loss of p2 is: 0.007016113959252834
# Physicial loss of s is: 0.010390536859631538
# Iteration is: 16280
# Physicial loss of p1 is: 0.015227540396153927
# Physicial loss of p2 is: 0.00715312035754323
# Physicial loss of s is: 0.010173440910875797
# Iteration is: 16290
# Physicial loss of p1 is: 0.014830012805759907
# Physicial loss of p2 is: 0.007189033553004265
# Physicial loss of s is: 0.010424519889056683
# Iteration is: 16300
# Physicial loss of p1 is: 0.01199096255004406
# Physicial loss of p2 is: 0.006857779808342457
# Physicial loss of s is: 0.011006376706063747
# Iteration is: 16310
# Physicial loss of p1 is: 0.012297241017222404
# Physicial loss of p2 is: 0.0068967598490417
# Physicial loss of s is: 0.010590209625661373
# Iteration is: 16320
# Physicial loss of p1 is: 0.01259477436542511
# Physicial loss of p2 is: 0.007093877997249365
# Physicial loss of s is: 0.011481361463665962
# Iteration is: 16330
# Physicial loss of p1 is: 0.014778842218220234
# Physicial loss of p2 is: 0.007381566800177097
# Physicial loss of s is: 0.01304664183408022
# Iteration is: 16340
# Physicial loss of p1 is: 0.013239262625575066
# Physicial loss of p2 is: 0.00679707620292902
# Physicial loss of s is: 0.013797014020383358
# Iteration is: 16350
# Physicial loss of p1 is: 0.01177277136594057
# Physicial loss of p2 is: 0.007136440370231867
# Physicial loss of s is: 0.011319122277200222
# Iteration is: 16360
# Physicial loss of p1 is: 0.011529559269547462
# Physicial loss of p2 is: 0.006880811415612698
# Physicial loss of s is: 0.012197792530059814
# Iteration is: 16370
# Physicial loss of p1 is: 0.011591444723308086
# Physicial loss of p2 is: 0.007058427203446627
# Physicial loss of s is: 0.010979692451655865
# Iteration is: 16380
# Physicial loss of p1 is: 0.011405848897993565
# Physicial loss of p2 is: 0.006820984650403261
# Physicial loss of s is: 0.010579203255474567
# Iteration is: 16390
# Physicial loss of p1 is: 0.011541326530277729
# Physicial loss of p2 is: 0.006818441208451986
# Physicial loss of s is: 0.010284865275025368
# Iteration is: 16400
# Physicial loss of p1 is: 0.01438127737492323
# Physicial loss of p2 is: 0.007053953595459461
# Physicial loss of s is: 0.011002290062606335
# Iteration is: 16410
# Physicial loss of p1 is: 0.019614702090620995
# Physicial loss of p2 is: 0.007195043843239546
# Physicial loss of s is: 0.011224203743040562
# Iteration is: 16420
# Physicial loss of p1 is: 0.01602003537118435
# Physicial loss of p2 is: 0.007217742968350649
# Physicial loss of s is: 0.009928541257977486
# Iteration is: 16430
# Physicial loss of p1 is: 0.013182969763875008
# Physicial loss of p2 is: 0.006809199694544077
# Physicial loss of s is: 0.010839942842721939
# Iteration is: 16440
# Physicial loss of p1 is: 0.011764323338866234
# Physicial loss of p2 is: 0.006913492456078529
# Physicial loss of s is: 0.010192367248237133
# Iteration is: 16450
# Physicial loss of p1 is: 0.011248188093304634
# Physicial loss of p2 is: 0.006747313775122166
# Physicial loss of s is: 0.010353644378483295
# Iteration is: 16460
# Physicial loss of p1 is: 0.011404371820390224
# Physicial loss of p2 is: 0.00676969438791275
# Physicial loss of s is: 0.010173479095101357
# Iteration is: 16470
# Physicial loss of p1 is: 0.01159789226949215
# Physicial loss of p2 is: 0.006806388031691313
# Physicial loss of s is: 0.010235383175313473
# Iteration is: 16480
# Physicial loss of p1 is: 0.014808193780481815
# Physicial loss of p2 is: 0.007023970130831003
# Physicial loss of s is: 0.01093227043747902
# Iteration is: 16490
# Physicial loss of p1 is: 0.016994064673781395
# Physicial loss of p2 is: 0.007019083481281996
# Physicial loss of s is: 0.01086965948343277
# Iteration is: 16500
# Physicial loss of p1 is: 0.014482774771749973
# Physicial loss of p2 is: 0.007147595752030611
# Physicial loss of s is: 0.011225549504160881
# Iteration is: 16510
# Physicial loss of p1 is: 0.012339180335402489
# Physicial loss of p2 is: 0.0068670776672661304
# Physicial loss of s is: 0.010504007339477539
# Iteration is: 16520
# Physicial loss of p1 is: 0.010991985909640789
# Physicial loss of p2 is: 0.006789107341319323
# Physicial loss of s is: 0.010032011196017265
# Iteration is: 16530
# Physicial loss of p1 is: 0.011437789537012577
# Physicial loss of p2 is: 0.006758119910955429
# Physicial loss of s is: 0.010075806640088558
# Iteration is: 16540
# Physicial loss of p1 is: 0.011288718320429325
# Physicial loss of p2 is: 0.006901571061462164
# Physicial loss of s is: 0.010727673768997192
# Iteration is: 16550
# Physicial loss of p1 is: 0.015250155702233315
# Physicial loss of p2 is: 0.0076917000114917755
# Physicial loss of s is: 0.019850321114063263
# Iteration is: 16560
# Physicial loss of p1 is: 0.01328522339463234
# Physicial loss of p2 is: 0.0067408643662929535
# Physicial loss of s is: 0.012916368432343006
# Iteration is: 16570
# Physicial loss of p1 is: 0.011863736435770988
# Physicial loss of p2 is: 0.006951284594833851
# Physicial loss of s is: 0.010566974990069866
# Iteration is: 16580
# Physicial loss of p1 is: 0.010988062247633934
# Physicial loss of p2 is: 0.006720435339957476
# Physicial loss of s is: 0.011647454462945461
# Iteration is: 16590
# Physicial loss of p1 is: 0.012075388804078102
# Physicial loss of p2 is: 0.006817306391894817
# Physicial loss of s is: 0.009743194095790386
# Iteration is: 16600
# Physicial loss of p1 is: 0.019163032993674278
# Physicial loss of p2 is: 0.0073179337196052074
# Physicial loss of s is: 0.012408009730279446
# Iteration is: 16610
# Physicial loss of p1 is: 0.011448022909462452
# Physicial loss of p2 is: 0.00703821936622262
# Physicial loss of s is: 0.011884180828928947
# Iteration is: 16620
# Physicial loss of p1 is: 0.010852299630641937
# Physicial loss of p2 is: 0.006727502215653658
# Physicial loss of s is: 0.012274562381207943
# Iteration is: 16630
# Physicial loss of p1 is: 0.011978896334767342
# Physicial loss of p2 is: 0.0067382315173745155
# Physicial loss of s is: 0.010155368596315384
# Iteration is: 16640
# Physicial loss of p1 is: 0.012311979196965694
# Physicial loss of p2 is: 0.006617235019803047
# Physicial loss of s is: 0.010355203412473202
# Iteration is: 16650
# Physicial loss of p1 is: 0.0162107702344656
# Physicial loss of p2 is: 0.0068130819126963615
# Physicial loss of s is: 0.01060444675385952
# Iteration is: 16660
# Physicial loss of p1 is: 0.012335194274783134
# Physicial loss of p2 is: 0.00685521075502038
# Physicial loss of s is: 0.009923961944878101
# Iteration is: 16670
# Physicial loss of p1 is: 0.010700426064431667
# Physicial loss of p2 is: 0.006680388003587723
# Physicial loss of s is: 0.010538587346673012
# Iteration is: 16680
# Physicial loss of p1 is: 0.011439143680036068
# Physicial loss of p2 is: 0.006720180623233318
# Physicial loss of s is: 0.010076165199279785
# Iteration is: 16690
# Physicial loss of p1 is: 0.011737363412976265
# Physicial loss of p2 is: 0.006618262268602848
# Physicial loss of s is: 0.009977089241147041
# Iteration is: 16700
# Physicial loss of p1 is: 0.015257417224347591
# Physicial loss of p2 is: 0.006644365843385458
# Physicial loss of s is: 0.010892866179347038
# Iteration is: 16710
# Physicial loss of p1 is: 0.0115804523229599
# Physicial loss of p2 is: 0.006803731434047222
# Physicial loss of s is: 0.010421640239655972
# Iteration is: 16720
# Physicial loss of p1 is: 0.010935443453490734
# Physicial loss of p2 is: 0.006777667440474033
# Physicial loss of s is: 0.009947958402335644
# Iteration is: 16730
# Physicial loss of p1 is: 0.010689232498407364
# Physicial loss of p2 is: 0.006645078305155039
# Physicial loss of s is: 0.010837383568286896
# Iteration is: 16740
# Physicial loss of p1 is: 0.011025047861039639
# Physicial loss of p2 is: 0.0066735330037772655
# Physicial loss of s is: 0.010500144213438034
# Iteration is: 16750
# Physicial loss of p1 is: 0.014714432880282402
# Physicial loss of p2 is: 0.006877897772938013
# Physicial loss of s is: 0.009408317506313324
# Iteration is: 16760
# Physicial loss of p1 is: 0.017370138317346573
# Physicial loss of p2 is: 0.007087657228112221
# Physicial loss of s is: 0.009828852489590645
# Iteration is: 16770
# Physicial loss of p1 is: 0.012018758803606033
# Physicial loss of p2 is: 0.006593035999685526
# Physicial loss of s is: 0.011560829356312752
# Iteration is: 16780
# Physicial loss of p1 is: 0.010652600787580013
# Physicial loss of p2 is: 0.007058689836412668
# Physicial loss of s is: 0.013483661226928234
# Iteration is: 16790
# Physicial loss of p1 is: 0.010623129084706306
# Physicial loss of p2 is: 0.00654192641377449
# Physicial loss of s is: 0.011315012350678444
# Iteration is: 16800
# Physicial loss of p1 is: 0.010365129448473454
# Physicial loss of p2 is: 0.006587658077478409
# Physicial loss of s is: 0.009584074839949608
# Iteration is: 16810
# Physicial loss of p1 is: 0.010398357175290585
# Physicial loss of p2 is: 0.006603552959859371
# Physicial loss of s is: 0.009488292969763279
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[200], line 6
#       4 while it <= Nmax:
#       5     if it<10**5:
# ----> 6         loss_, loss_p, loss_fp1, loss_fp2, loss_fs = train_step_1(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#       7     else:
#       8         loss_, loss_p,  loss_fp1, loss_fp2, loss_fs = train_step_2(W_p, b_p, W_phi, b_phi, W_a, b_a, X_u_train_tf, P_train_tf, X_f_train_tf, xx01_tf, uu01_tf, lambda_r, lambda_b, lambda_0, lnv)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1601, in ConcreteFunction.__call__(self, *args, **kwargs)
#    1551 def __call__(self, *args, **kwargs):
#    1552   """Executes the wrapped function.
#    1553
#    1554   ConcreteFunctions have two signatures:
#    (...)
#    1599     TypeError: If the arguments do not match the function's signature.
#    1600   """
# -> 1601   return self._call_impl(args, kwargs)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1610, in ConcreteFunction._call_impl(self, args, kwargs, cancellation_manager)
#    1608 if self._function_spec is not None:
#    1609   try:
# -> 1610     return self._call_with_structured_signature(args, kwargs,
#    1611                                                 cancellation_manager)
#    1612   except TypeError as structured_err:
#    1613     try:
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1691, in ConcreteFunction._call_with_structured_signature(self, args, kwargs, cancellation_manager)
#    1689 self._structured_signature_check_unexpected_args(args, kwargs)
#    1690 self._structured_signature_check_arg_types(args, kwargs)
# -> 1691 return self._call_flat(
#    1692     filtered_flat_args,
#    1693     captured_inputs=self.captured_inputs,
#    1694     cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\u256063\AppData\Local\anaconda3\envs\tf2.8\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
Nmax=len(loss)
ep = np.arange(0,Nmax, 1)
loss_list = [loss[i].numpy() for i in range(0,Nmax)]
loss_data_list = [loss_d[i].numpy() for i in range(0,Nmax)]

loss_phip1_list = [loss_fisp1[i].numpy() for i in range(0,Nmax)]
loss_phip2_list = [loss_fisp2[i].numpy() for i in range(0,Nmax)]
loss_phis_list = [loss_fiss[i].numpy() for i in range(0,Nmax)]



plt.semilogy(ep, np.asarray(loss_data_list), 'b-', linewidth = 2, alpha=0.6, label = 'Data')  
plt.semilogy(ep, np.asarray(loss_phip1_list), 'r-', linewidth = 2, alpha=0.6, label = '$\phi_p1$') 
plt.semilogy(ep, np.asarray(loss_phip2_list), 'y-', linewidth = 2, alpha=0.6, label = '$\phi_p2$')    
plt.semilogy(ep, np.asarray(loss_phis_list), 'g-', linewidth = 2, alpha=0.6, label = '$\phi_s$')       


plt.xlabel('Iteration')
plt.ylabel('$\mathcal{L}$')  
plt.legend()  
# plt.savefig('figures/loss_phi.pdf')
plt.show()

# %%
lnv[0], tf.exp(lnv[0]), lnv[1], tf.exp(lnv[1]), lnv[2], tf.exp(lnv[2])
# Out:
# (<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.7576594], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([5.798849], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([-0.18111165], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.83434224], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([-0.32162023], dtype=float32)>,
#  <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.72497344], dtype=float32)>)

# %%
def predict(X_star_tf, w, b):
    u_pred = net(X_star_tf, w, b)
    return u_pred

## Evaluating total function
X_star_tf = tf.convert_to_tensor(X_star, dtype=tf.float32)  
# A_star_tf = tf.convert_to_tensor(A, dtype=tf.float32)    

u_pred = predict(X_star_tf, W_p, b_p)

# ## Evaluating unknown function
lnp1=u_pred[:,0:1]
lnp2=u_pred[:,1:2]
lns=u_pred[:,2:3]

p1=tf.exp(lnp1)
p2=tf.exp(lnp2)
s=tf.exp(lns)

lnl2=predict(X_star_tf[...,2:3], W_a, b_a)

l2=tf.exp(lnl2)
# phi = tf.exp(predict(tf.concat([p, s, l],1), W_phi, b_phi))
phi = tf.exp(predict(s, W_phi, b_phi))


m=tf.exp(lnv[0:1])
l1=tf.exp(lnv[1:2])
mn=tf.exp(lnv[1:2])



phi_s=-np.array((p1+p2)*s*m)

# %%
X_star_tf.shape, p1.shape
# Out:
# (TensorShape([6498, 3]), TensorShape([6498, 1]))

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],(p1+p2)[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')
plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

k=3
# Seleccionar el color correspondiente de la paleta
color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
for i in range(j):
    # Aquí puedes pasar el color seleccionado en cada iteración
    # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
    plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p1[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], linestyle=':',  color=color, label='Prediction P')
    plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)],   color=color, label='Prediction P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p1[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], linestyle=':',  color=color, label='Prediction P')
        plt.plot(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],p2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)],   color=color, label='Prediction P')

plt.scatter(X_u_train[:,0], P_train, marker='x', s=2, color='black',label='Data P')



plt.xlabel('t (ms)')
plt.ylabel('P')


# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,0],s[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', s=1,  color=color, label='Prediction P')



plt.xlabel('t (ms)')
plt.ylabel('S')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
L_exp=len(P_exp[:,1])
colors = plt.cm.tab10.colors

for k, j in enumerate(n):
    # Seleccionar el color correspondiente de la paleta
    color = colors[k % len(colors)]  # Asegurarse de que no se salga del rango de colores disponibles
    for i in range(j):
        # Aquí puedes pasar el color seleccionado en cada iteración
        # plt.plot(T_exp, P_exp[:, i + np.sum(n[:k])], color=color)
        plt.scatter(X_star_tf[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)][:,2],l2[L_exp*(i + np.sum(n[:k])):L_exp*((i + np.sum(n[:k]))+1)], marker='x', color=color, label='Prediction P')



plt.xlabel('A')
plt.ylabel('death rate')
# plt.yscale('log')

# plt.legend()

# plt.ylabel('P')
# plt.savefig('figures/P_phi.pdf')
plt.show()

# %%
l1
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.83434224]], dtype=float32)>

# %%
# plt.scatter(p, phi, s=3, label='Prediction')
plt.scatter(s, phi, s=3, label='Prediction')

# plt.plot(u_pred[:,1:2], phi_pred, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('P')
plt.ylabel('$\phi_p(P,S,A)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
# plt.scatter(p, phi_s, s=3, label='Prediction')

plt.scatter(s, phi_s, s=3, label='Prediction')

# plt.scatter(X_u_train, u_train, marker='x', color='black',label='Data')
# plt.scatter(X_f_train, np.zeros(len(X_f_train)), marker='x')
plt.legend()
plt.xlabel('S')
plt.ylabel('$\phi_p(P,S)$')
# plt.savefig('figures/phi.pdf')
plt.show()

# %%
n
# Out:
# array([5, 6, 5, 3])

# %%
k=3
p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]
# Out:
# <tf.Tensor: shape=(3, 1), dtype=float32, numpy=
# array([[0.00055608],
#        [0.00055591],
#        [0.00055569]], dtype=float32)>

# %%
p2[::L_exp]
# Out:
# <tf.Tensor: shape=(19, 1), dtype=float32, numpy=
# array([[0.08559664],
#        [0.08557624],
#        [0.08577951],
#        [0.08571859],
#        [0.08577951],
#        [0.08594915],
#        [0.0862631 ],
#        [0.08608963],
#        [0.08618724],
#        [0.08602276],
#        [0.08598589],
#        [0.06336954],
#        [0.06337634],
#        [0.06335737],
#        [0.06336687],
#        [0.06336012],
#        [0.05376669],
#        [0.05377547],
#        [0.05378701]], dtype=float32)>

# %%
p1[::L_exp]
# Out:
# <tf.Tensor: shape=(19, 1), dtype=float32, numpy=
# array([[0.00551449],
#        [0.00551422],
#        [0.00551697],
#        [0.00551614],
#        [0.00551697],
#        [0.00484615],
#        [0.00491544],
#        [0.00487758],
#        [0.00489901],
#        [0.00486271],
#        [0.00485443],
#        [0.00088691],
#        [0.00088667],
#        [0.00088734],
#        [0.000887  ],
#        [0.00088724],
#        [0.00055608],
#        [0.00055591],
#        [0.00055569]], dtype=float32)>

# %%
Nt=1000

# A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
A_int=np.array([0, 1.25, 2.5, 3.75])

for k, a in enumerate(A_int):

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    P1_int=np.zeros(Nt)
    P2_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P1_int[0]=np.mean(p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions
    P2_int[0]=np.mean(p2[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l2=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        P1_int[i]=P1_int[i-1]+(P1_int[i-1]*PHI_S - P1_int[i-1]*l1)*dt
        P2_int[i]=P2_int[i-1]+(mn*P2_int[i-1]*PHI_S - P2_int[i-1]*l2)*dt
        S_int[i]=S_int[i-1]-PHI_S*(P1_int[i-1]+mn*P2_int[i-1])*S_int[i-1]*np.array(m)*dt
        S_int[i]=np.maximum(S_int[i],0)
        T_int[i]=T_int[i-1]+dt

    plt.plot(T_int, P1_int,  linestyle='-', label=f'Numeric integration dP1dT {a}')
    plt.plot(T_int, P2_int,  linestyle=':', label=f'Numeric integration dP2dT {a}')
    # plt.plot(T_int, P1_int+P2_int,  linestyle='-', label=f'Numeric integration dPdT {a}')

    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim(0,1.5)
plt.show()

# %%
Nt=1000

# A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
A_int=np.array([0, 1.25, 2.5, 3.75])

for k, a in enumerate(A_int):

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    P1_int=np.zeros(Nt)
    P2_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P1_int[0]=np.mean(p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions
    P2_int[0]=np.mean(p2[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l2=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        P1_int[i]=P1_int[i-1]+(P1_int[i-1]*PHI_S - P1_int[i-1]*l1)*dt
        P2_int[i]=P2_int[i-1]+(mn*P2_int[i-1]*PHI_S - P2_int[i-1]*l2)*dt
        S_int[i]=S_int[i-1]-PHI_S*(P1_int[i-1]+mn*P2_int[i-1])*S_int[i-1]*np.array(m)*dt
        S_int[i]=np.maximum(S_int[i],0)
        T_int[i]=T_int[i-1]+dt

    # plt.plot(T_int, P1_int,  linestyle='-', label=f'Numeric integration dP1dT {a}')
    # plt.plot(T_int, P2_int,  linestyle=':', label=f'Numeric integration dP2dT {a}')
    plt.plot(T_int, P1_int+P2_int,  linestyle='-', label=f'Numeric integration dPdT {a}')

    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim(0,1.5)
plt.show()

# %%
Nt=1000

# A_int=np.array([0,0.75, 1.25,2, 2.5,3,3.75])
A_int=np.array([0, 1.25, 2.5, 3.75])

for k, a in enumerate(A_int):

    T_int=np.zeros(Nt)
    P_int=np.zeros(Nt)
    P1_int=np.zeros(Nt)
    P2_int=np.zeros(Nt)
    S_int=np.zeros(Nt)


    dt=0.001

    T_int[0]=0
    P1_int[0]=np.mean(p1[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions
    P2_int[0]=np.mean(p2[::L_exp][np.sum(n[:k]):np.sum(n[:k+1])]) #Initial conditions

    S_int[0]=np.array(s[0]) #Initial conditions
    l2=tf.exp(predict(tf.convert_to_tensor(a.reshape([-1,1]), dtype=tf.float32), W_a, b_a))
    for i in range(1,Nt):

        # PSL=tf.concat([tf.convert_to_tensor(P_int[i-1].reshape([-1,1]), dtype=tf.float32),tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32), l],1)

        # REVISAAAAAR
        PHI_S=tf.exp(predict(tf.convert_to_tensor(S_int[i-1].reshape([-1,1]), dtype=tf.float32) , W_phi, b_phi))
        P1_int[i]=P1_int[i-1]+(P1_int[i-1]*PHI_S - P1_int[i-1]*l1)*dt
        P2_int[i]=P2_int[i-1]+(mn*P2_int[i-1]*PHI_S - P2_int[i-1]*l2)*dt
        S_int[i]=S_int[i-1]-(P1_int[i-1]+P2_int[i-1])*S_int[i-1]*np.array(m)*dt
        T_int[i]=T_int[i-1]+dt

    # plt.plot(T_int, P1_int,  linestyle='-', label=f'Numeric integration dP1dT {a}')
    # plt.plot(T_int, P2_int,  linestyle=':', label=f'Numeric integration dP2dT {a}')
    plt.plot(T_int, P1_int+P2_int,  linestyle='-', label=f'Numeric integration dPdT {a}')

    plt.plot(T_int, S_int,  linestyle='--', label=f'Numeric integration dSdT {a}')

plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim(0,1.5)
plt.show()
